# %%
import numpy as np
#from lhereader import LHEReader

from LHCO_reader import LHCO_reader

import math
import os

# Plotting library
import matplotlib.pyplot as plt

# tells matplotlib to embed plots within the notebook
# %matplotlib inline

# %% [markdown]
# #### VLQ 2000GeV (test9)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/SLQ-1400GeV/'
Folder = '/home/perez/CompuTools/Trabajos/leptoquarks/LQsMadgraph/VLQtest9_2000GeV/Auto_Results_LHCO/'

VLQ_2000GeV_cross = 0.000174
VLQ_2000GeV_runs = 25

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_2000GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_2000GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_2000GeV_evs)
# Out:
# /home/perez/anaconda2/lib/python2.7/site-packages/LHCO_reader/LHCO_reader.py:359: UserWarning: Couldn't read total number of events from LHCO
#   warnings.warn("Couldn't read total number of events from LHCO")
# 1941
# 3751
# 5584
# 7655
# 9609
# 11560
# 13478
# 15309
# 17273
# 19395
# 21219
# 23259
# 25148
# 27008
# 29068
# 31026
# 32901
# 34719
# 36649
# 38392
# 40720
# 42508
# 44749
# 46416
# 48341
# ('# original events: ', 974396)
# ('# events that pass the cuts: ', 48341)

# %%
cross = VLQ_2000GeV_cross*1000
aceptancia = 1.*VLQ_2000GeV_evs/ev_original
luminosidad = 139

VLQ_2000GeV_fidcross = cross * aceptancia
VLQ_2000GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_2000GeV_fidcross)
print('S_expected: ', VLQ_2000GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.008632356865175965)
# ('S_expected: ', 1.1998976042594591)

# %% [markdown]
# #### LQ 1400GeV BR=1 (scalar)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/SLQ-1400GeV/'
Folder = '/home/perez/CompuTools/Trabajos/leptoquarks/LQsMadgraph/LQ-up-1400GeV-BRbtau1/'

SLQ_1400GeV_cross = 6.7541e-05
SLQ_1400GeV_runs = 25

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,SLQ_1400GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

SLQ_1400GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', SLQ_1400GeV_evs)
# Out:
# 1894
# 3672
# 5502
# 7342
# 9206
# 11068
# 13002
# 14827
# 16598
# 18430
# 20235
# 22128
# 23992
# 25864
# 27739
# 29643
# 31523
# 33349
# 35223
# 37029
# 38902
# 40769
# 42654
# 44541
# 46410
# ('# original events: ', 1250000)
# ('# events that pass the cuts: ', 46410)

# %%
cross = SLQ_1400GeV_cross*1000
aceptancia = 1.*SLQ_1400GeV_evs/ev_original
luminosidad = 139

SLQ_1400GeV_fidcross = cross * aceptancia
SLQ_1400GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', SLQ_1400GeV_fidcross)
print('S_expected: ', SLQ_1400GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.002507662248)
# ('S_expected: ', 0.348565052472)

# %% [markdown]
# #### VLQ 1800GeV BR=1 (test9 - minimal LQ model)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/SLQ-1400GeV/'
Folder = '/home/perez/CompuTools/Trabajos/leptoquarks/LQsMadgraph/VLQtest9-1800GeV-BRbtau1/'

VLQ_1800GeV_cross = 6.55662e-05
VLQ_1800GeV_runs = 20

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1800GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1800GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1800GeV_evs)
# Out:
# 1969
# 3945
# 5951
# 7932
# 9905
# 11784
# 13643
# 15663
# 17527
# 19518
# 21482
# 23407
# 25359
# 27313
# 29219
# 31145
# 33087
# 35038
# 37100
# 39042
# ('# original events: ', 1000000)
# ('# events that pass the cuts: ', 39042)

# %%
cross = VLQ_1800GeV_cross*1000
aceptancia = 1.*VLQ_1800GeV_evs/ev_original
luminosidad = 139

VLQ_1800GeV_fidcross = cross * aceptancia
VLQ_1800GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1800GeV_fidcross)
print('S_expected: ', VLQ_1800GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.0025598355804)
# ('S_expected: ', 0.3558171456756)

# %%
import matplotlib.pyplot as plt

ATLAS_sT = [0,1.2,1.2,1.8,1.8,1.3,1.3,1.25,1.25,0]
ATLAS_mTtau = [0,0.55,0.55,0.6,0.6,0.45,0.45,3.95,3.95,0]
ATLAS_mTbb = [0,0.9,0.9,1.25,1.25,1.3,1.3,5.2,5.2,0]
ATLAS_pT = [0,0.6,0.6,0.8,0.8,1,1,6,6,0]

plt.plot([800, 800, 1050, 1050, 1300, 1300, 1550, 1550, 1800, 1800], ATLAS_sT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$s_T$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



plt.plot([300, 300, 350, 350, 400, 400, 450, 450, 500, 500], ATLAS_mTtau, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  


plt.plot([700, 700, 900, 900, 1100, 1100, 1300, 1300, 1500, 1500], ATLAS_mTbb, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$\sum m_T(b_{1,2})$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show() 


plt.plot([50, 50, 100, 100, 150,150, 200, 200, 250, 250], ATLAS_pT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$p_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ## SIGNAL VLQ

# %% [markdown]
# #### VLQ-1200GeV (test3) betaL33=0.5

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest3/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0000183
VLQ_1200GeV_runs = 20

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 2487
# 5044
# 7531
# 9991
# 12593
# 15128
# 17645
# 20098
# 22642
# 25171
# 27655
# 30236
# 32757
# 35299
# 37710
# 40240
# 42763
# 45276
# 47832
# 50313
# ('# original events: ', 1000000)
# ('# events that pass the cuts: ', 50313)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.0009207279)
# ('S_expected: ', 0.12798117809999998)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest3/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0000183
VLQ_1200GeV_runs = 20

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 1000000)
# ('# events that pass the cuts: ', 31123)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.0005695509)
# ('S_expected: ', 0.0791675751)

# %%
k_factor_800 = sum(ATLAS_pT)/2 / VLQ_1200GeV_Sexpected_ATLAS
factor_weight_800 = (1./k_factor_800)*VLQ_1200GeV_evs_ATLAS/VLQ_1200GeV_Sexpected_ATLAS


BGttstau_store_sT_cap_800 = []
for i in range(len(BGttstau_store_sT)):
    if BGttstau_store_sT[i] > 1800:
        BGttstau_store_sT_cap_800.append( 1800 )
    else:
        BGttstau_store_sT_cap_800.append( BGttstau_store_sT[i] )
        
    
weights_sT_800 = np.ones_like(BGttstau_store_sT_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_sT_cap_800, weights=weights_sT_800, bins=[800, 1050, 1300, 1550, 1800], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([800, 800, 1050, 1050, 1300, 1300, 1550, 1550, 1800, 1800], ATLAS_sT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$s_T$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTtau_cap_800 = []
for i in range(len(BGttstau_store_mTtau)):
    if BGttstau_store_mTtau[i] > 500:
        BGttstau_store_mTtau_cap_800.append( 500 )
    else:
        BGttstau_store_mTtau_cap_800.append( BGttstau_store_mTtau[i] )
        
    
weights_mTtau_800 = np.ones_like(BGttstau_store_mTtau_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_mTtau_cap_800, weights=weights_mTtau_800, bins=[300, 350, 400, 450, 500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([300, 300, 350, 350, 400, 400, 450, 450, 500, 500], ATLAS_mTtau, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTb1b2_cap_800 = []
for i in range(len(BGttstau_store_mTb1b2)):
    if BGttstau_store_mTb1b2[i] > 1500:
        BGttstau_store_mTb1b2_cap_800.append( 1500 )
    else:
        BGttstau_store_mTb1b2_cap_800.append( BGttstau_store_mTb1b2[i] )
        
    
weights_mTb1b2_800 = np.ones_like(BGttstau_store_mTb1b2_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_mTb1b2_cap_800, weights=weights_mTb1b2_800, bins=[700, 900, 1100, 1300, 1500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([700, 700, 900, 900, 1100, 1100, 1300, 1300, 1500, 1500], ATLAS_mTbb, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$\sum m_T(b_{1,2})$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_pTtau_cap_800 = []
for i in range(len(BGttstau_store_pTtau)):
    if BGttstau_store_pTtau[i] > 250:
        BGttstau_store_pTtau_cap_800.append( 250 )
    else:
        BGttstau_store_pTtau_cap_800.append( BGttstau_store_pTtau[i] )
        
    
weights_pTtau_800 = np.ones_like(BGttstau_store_pTtau_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_pTtau_cap_800, weights=weights_pTtau_800, bins=[50, 100, 150, 200, 250], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([50, 50, 100, 100, 150,150, 200, 200, 250, 250], ATLAS_pT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$p_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# #### VLQ-1200GeV (test4) betaL33=1

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t4/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest4/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0004278
VLQ_1200GeV_runs = 4

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 2854
# 5714
# 8542
# 11379
# ('# original events: ', 200000)
# ('# events that pass the cuts: ', 11379)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.024339681000000002)
# ('S_expected: ', 3.383215659)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t4/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest4/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0004278
VLQ_1200GeV_runs = 4

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 200000)
# ('# events that pass the cuts: ', 6755)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.014448945)
# ('S_expected: ', 2.008403355)

# %%
k_factor_800 = sum(ATLAS_pT)/2 / VLQ_1200GeV_Sexpected_ATLAS
factor_weight_800 = (1./k_factor_800)*VLQ_1200GeV_evs_ATLAS/VLQ_1200GeV_Sexpected_ATLAS


BGttstau_store_sT_cap_800 = []
for i in range(len(BGttstau_store_sT)):
    if BGttstau_store_sT[i] > 1800:
        BGttstau_store_sT_cap_800.append( 1800 )
    else:
        BGttstau_store_sT_cap_800.append( BGttstau_store_sT[i] )
        
    
weights_sT_800 = np.ones_like(BGttstau_store_sT_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_sT_cap_800, weights=weights_sT_800, bins=[800, 1050, 1300, 1550, 1800], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([800, 800, 1050, 1050, 1300, 1300, 1550, 1550, 1800, 1800], ATLAS_sT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$s_T$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTtau_cap_800 = []
for i in range(len(BGttstau_store_mTtau)):
    if BGttstau_store_mTtau[i] > 500:
        BGttstau_store_mTtau_cap_800.append( 500 )
    else:
        BGttstau_store_mTtau_cap_800.append( BGttstau_store_mTtau[i] )
        
    
weights_mTtau_800 = np.ones_like(BGttstau_store_mTtau_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_mTtau_cap_800, weights=weights_mTtau_800, bins=[300, 350, 400, 450, 500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([300, 300, 350, 350, 400, 400, 450, 450, 500, 500], ATLAS_mTtau, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTb1b2_cap_800 = []
for i in range(len(BGttstau_store_mTb1b2)):
    if BGttstau_store_mTb1b2[i] > 1500:
        BGttstau_store_mTb1b2_cap_800.append( 1500 )
    else:
        BGttstau_store_mTb1b2_cap_800.append( BGttstau_store_mTb1b2[i] )
        
    
weights_mTb1b2_800 = np.ones_like(BGttstau_store_mTb1b2_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_mTb1b2_cap_800, weights=weights_mTb1b2_800, bins=[700, 900, 1100, 1300, 1500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([700, 700, 900, 900, 1100, 1100, 1300, 1300, 1500, 1500], ATLAS_mTbb, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$\sum m_T(b_{1,2})$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_pTtau_cap_800 = []
for i in range(len(BGttstau_store_pTtau)):
    if BGttstau_store_pTtau[i] > 250:
        BGttstau_store_pTtau_cap_800.append( 250 )
    else:
        BGttstau_store_pTtau_cap_800.append( BGttstau_store_pTtau[i] )
        
    
weights_pTtau_800 = np.ones_like(BGttstau_store_pTtau_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_pTtau_cap_800, weights=weights_pTtau_800, bins=[50, 100, 150, 200, 250], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([50, 50, 100, 100, 150,150, 200, 200, 250, 250], ATLAS_pT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$p_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# #### VLQ-1200GeV (test4 - 6to9) betaL33=1 resto de cosas super heavy y coupling chicos

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t4/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest4/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0003792
VLQ_1200GeV_runs = 9

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(6,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 2117
# 4243
# 6312
# 8368
# ('# original events: ', 151649)
# ('# events that pass the cuts: ', 8368)

# %%
VLQ_1200GeV_runs = 4

cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.020924276454180376)
# ('S_expected: ', 2.9084744271310723)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t4/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest4/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0003792
VLQ_1200GeV_runs = 9

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(6,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 151649)
# ('# events that pass the cuts: ', 5018)

# %%
VLQ_1200GeV_runs = 4

cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.012547564441572314)
# ('S_expected: ', 1.7441114573785517)

# %% [markdown]
# #### VLQ-1200GeV (test5) betaL33=-1

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t5/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest5/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0004278
VLQ_1200GeV_runs = 4

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(2,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 2088
# 4348
# 6524
# ('# original events: ', 115154)
# ('# events that pass the cuts: ', 6524)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.02423682373169842)
# ('S_expected: ', 3.3689184987060807)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t5/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest5/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0004278
VLQ_1200GeV_runs = 4

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(2,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 115154)
# ('# events that pass the cuts: ', 3805)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.014135670493426193)
# ('S_expected: ', 1.964858198586241)

# %%
k_factor_800 = sum(ATLAS_pT)/2 / VLQ_1200GeV_Sexpected_ATLAS
factor_weight_800 = (1./k_factor_800)*VLQ_1200GeV_evs_ATLAS/VLQ_1200GeV_Sexpected_ATLAS


BGttstau_store_sT_cap_800 = []
for i in range(len(BGttstau_store_sT)):
    if BGttstau_store_sT[i] > 1800:
        BGttstau_store_sT_cap_800.append( 1800 )
    else:
        BGttstau_store_sT_cap_800.append( BGttstau_store_sT[i] )
        
    
weights_sT_800 = np.ones_like(BGttstau_store_sT_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_sT_cap_800, weights=weights_sT_800, bins=[800, 1050, 1300, 1550, 1800], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([800, 800, 1050, 1050, 1300, 1300, 1550, 1550, 1800, 1800], ATLAS_sT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$s_T$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTtau_cap_800 = []
for i in range(len(BGttstau_store_mTtau)):
    if BGttstau_store_mTtau[i] > 500:
        BGttstau_store_mTtau_cap_800.append( 500 )
    else:
        BGttstau_store_mTtau_cap_800.append( BGttstau_store_mTtau[i] )
        
    
weights_mTtau_800 = np.ones_like(BGttstau_store_mTtau_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_mTtau_cap_800, weights=weights_mTtau_800, bins=[300, 350, 400, 450, 500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([300, 300, 350, 350, 400, 400, 450, 450, 500, 500], ATLAS_mTtau, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTb1b2_cap_800 = []
for i in range(len(BGttstau_store_mTb1b2)):
    if BGttstau_store_mTb1b2[i] > 1500:
        BGttstau_store_mTb1b2_cap_800.append( 1500 )
    else:
        BGttstau_store_mTb1b2_cap_800.append( BGttstau_store_mTb1b2[i] )
        
    
weights_mTb1b2_800 = np.ones_like(BGttstau_store_mTb1b2_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_mTb1b2_cap_800, weights=weights_mTb1b2_800, bins=[700, 900, 1100, 1300, 1500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([700, 700, 900, 900, 1100, 1100, 1300, 1300, 1500, 1500], ATLAS_mTbb, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$\sum m_T(b_{1,2})$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_pTtau_cap_800 = []
for i in range(len(BGttstau_store_pTtau)):
    if BGttstau_store_pTtau[i] > 250:
        BGttstau_store_pTtau_cap_800.append( 250 )
    else:
        BGttstau_store_pTtau_cap_800.append( BGttstau_store_pTtau[i] )
        
    
weights_pTtau_800 = np.ones_like(BGttstau_store_pTtau_cap_800)/factor_weight_800
        
plt.hist(BGttstau_store_pTtau_cap_800, weights=weights_pTtau_800, bins=[50, 100, 150, 200, 250], histtype='step', color='firebrick', linewidth=2, label=r'$m_{VLQ}=1200$ GeV')
plt.plot([50, 50, 100, 100, 150,150, 200, 200, 250, 250], ATLAS_pT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$p_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# #### VLQ-1200GeV (test6) betaL33=1 (default el resto de cosas del UFO, i.e vector fermions ~ TeV)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t6/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest6/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0005684
VLQ_1200GeV_runs = 5

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)
    
    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 2280
# 4520
# 6719
# 8905
# 11142
# ('# original events: ', 187622)
# ('# events that pass the cuts: ', 11142)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.03375463858182943)
# ('S_expected: ', 4.69189476287429)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t6/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest6/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0005684
VLQ_1200GeV_runs = 5

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 187622)
# ('# events that pass the cuts: ', 6473)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.019609924209314473)
# ('S_expected: ', 2.725779465094712)

# %% [markdown]
# #### VLQ-1200GeV (test7) betaL33=1 (default el resto de cosas del UFO, i.e vector fermions ~ TeV)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t7/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest7/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0005684
VLQ_1200GeV_runs = 20

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 3070
# 6058
# 9034
# 12076
# 15078
# 18101
# 21002
# 24063
# 26992
# 29938
# 32989
# 35879
# 38829
# 41759
# 44764
# 47718
# 50708
# 53656
# 56644
# 59654
# ('# original events: ', 1000000)
# ('# events that pass the cuts: ', 59654)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.0339073336)
# ('S_expected: ', 4.7131193704)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t7/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest7/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.0005684
VLQ_1200GeV_runs = 20

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 1000000)
# ('# events that pass the cuts: ', 34944)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.019862169600000004)
# ('S_expected: ', 2.7608415744000006)

# %% [markdown]
# #### VLQ-1200GeV (test8) betaL33=1, kappaU=1, decay AUTO (pero otras particulas extra TeV)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t7/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest8/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.01152
VLQ_1200GeV_runs = 5

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# /home/andres/anaconda3/envs/py2/lib/python2.7/site-packages/LHCO_reader/LHCO_reader.py:359: UserWarning: Couldn't read total number of events from LHCO
#   warnings.warn("Couldn't read total number of events from LHCO")
# 3139
# 6328
# 9481
# 12657
# 15792
# ('# original events: ', 250000)
# ('# events that pass the cuts: ', 15792)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.7276953600000001)
# ('S_expected: ', 101.14965504000001)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t7/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest8/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.01152
VLQ_1200GeV_runs = 5

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 250000)
# ('# events that pass the cuts: ', 9819)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.45245952000000006)
# ('S_expected: ', 62.891873280000006)

# %% [markdown]
# #### VLQ-1200GeV (test9) betaL33=1, kappaU=1, decay AUTO (pero otras particulas extra 10 TeV)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t7/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest9/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.009284
VLQ_1200GeV_runs = 5

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 2779
# 5755
# 8649
# 11534
# 14439
# ('# original events: ', 250000)
# ('# events that pass the cuts: ', 14439)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.536206704)
# ('S_expected: ', 74.532731856)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t7/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest9/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.009284
VLQ_1200GeV_runs = 5

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 250000)
# ('# events that pass the cuts: ', 9091)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.337603376)
# ('S_expected: ', 46.926869264000004)

# %% [markdown]
# #### VLQ-1200GeV (test10) betaL33=1, kappaU=0 (Y-M), decay AUTO (pero otras particulas extra 10 TeV)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t7/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest10/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.03819
VLQ_1200GeV_runs = 5

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 2605
# 5155
# 7739
# 10303
# 12934
# ('# original events: ', 250000)
# ('# events that pass the cuts: ', 12934)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 1.9757978400000002)
# ('S_expected: ', 274.63589976000003)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t7/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest10/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.03819
VLQ_1200GeV_runs = 5

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 250000)
# ('# events that pass the cuts: ', 8205)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 1.2533958000000003)
# ('S_expected: ', 174.22201620000004)

# %% [markdown]
# #### VLQ-1800GeV (test6) betaL33=1 (default el resto de cosas del UFO, i.e vector fermions ~ TeV)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t6/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest6/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.00005424
VLQ_1200GeV_runs = 10

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(6,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 2112
# 4119
# 6224
# 8330
# 10364
# ('# original events: ', 174450)
# ('# events that pass the cuts: ', 10364)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.003222375236457438)
# ('S_expected: ', 0.44791015786758387)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t6/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest6/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.00005424
VLQ_1200GeV_runs = 10

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(6,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 174450)
# ('# events that pass the cuts: ', 6688)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.0020794331900257958)
# ('S_expected: ', 0.28904121341358563)

# %% [markdown]
# #### VLQ-1800GeV (test6) betaL33=1 (default el resto de cosas del UFO, i.e vector fermions ~ TeV)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t6/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest6/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.00003826
VLQ_1200GeV_runs = 15

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(11,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)
                            
    print(len(ev))

VLQ_1200GeV_evs = len(ev)
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs)
# Out:
# 527
# 2376
# 3968
# 6726
# 9467
# ('# original events: ', 174273)
# ('# events that pass the cuts: ', 9467)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross = cross * aceptancia
VLQ_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', VLQ_1200GeV_fidcross)
print('S_expected: ', VLQ_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.002078390915402845)
# ('S_expected: ', 0.28889633724099545)

# %%
# Folder = '/media/andres/Elements/Leptoquarks-v3/signals/VLQ-1200GeV-t6/'
Folder = '/home/andres/CompuTools/MG5_aMC_v2_9_14/RUNS/VLQtest6/LO/Auto_Results_LHCO/'

VLQ_1200GeV_cross = 0.00003826
VLQ_1200GeV_runs = 15

ev = []
ev_original = 0

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(11,VLQ_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'run_0'+str(iev)+".lhco")
    ev_original += len(inputevents)

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

VLQ_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# original events: ', ev_original)
print('# events that pass the cuts: ', VLQ_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# original events: ', 174273)
# ('# events that pass the cuts: ', 6206)

# %%
cross = VLQ_1200GeV_cross*1000
aceptancia = 1.*VLQ_1200GeV_evs_ATLAS/ev_original
luminosidad = 139

VLQ_1200GeV_fidcross_ATLAS = cross * aceptancia
VLQ_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', VLQ_1200GeV_fidcross_ATLAS)
print('S_expected: ', VLQ_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.0013624689997876896)
# ('S_expected: ', 0.18938319097048886)

# %% [markdown]
# #### LQ-up-1000GeV

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1000GeV/Auto_Results_LHCO/'

LQup_1000GeV_cross = 0.003513
LQup_1000GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1000GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1000GeV_evs = len(ev)
print('# events that pass the cuts: ', LQup_1000GeV_evs)
# Out:
# ('# events that pass the cuts: ', 67081)

# %%
cross = LQup_1000GeV_cross*1000
aceptancia = LQup_1000GeV_evs/(50000.*LQup_1000GeV_runs)
luminosidad = 139

LQup_1000GeV_fidcross = cross * aceptancia
LQup_1000GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', LQup_1000GeV_fidcross)
print('S_expected: ', LQup_1000GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.1885244424)
# ('S_expected: ', 26.204897493599997)

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1000GeV/Auto_Results_LHCO/'

LQup_1000GeV_cross = 0.003513
LQup_1000GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1000GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1000GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# events that pass the cuts: ', LQup_1000GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# events that pass the cuts: ', 39022)

# %%
cross = LQup_1000GeV_cross*1000
aceptancia = LQup_1000GeV_evs_ATLAS/(50000.*LQup_1000GeV_runs)
luminosidad = 139

LQup_1000GeV_fidcross_ATLAS = cross * aceptancia
LQup_1000GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', LQup_1000GeV_fidcross_ATLAS)
print('S_expected: ', LQup_1000GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.10966742880000001)
# ('S_expected: ', 15.243772603200002)

# %%
k_factor_1000 = sum(ATLAS_pT)/2 / LQup_1000GeV_Sexpected_ATLAS
factor_weight_1000 = (1./k_factor_1000)*LQup_1000GeV_evs_ATLAS/LQup_1000GeV_Sexpected_ATLAS


BGttstau_store_sT_cap_1000 = []
for i in range(len(BGttstau_store_sT)):
    if BGttstau_store_sT[i] > 1800:
        BGttstau_store_sT_cap_1000.append( 1800 )
    else:
        BGttstau_store_sT_cap_1000.append( BGttstau_store_sT[i] )
        
    
weights_sT_1000 = np.ones_like(BGttstau_store_sT_cap_1000)/factor_weight_1000
        
plt.hist(BGttstau_store_sT_cap_1000, weights=weights_sT_1000, bins=[800, 1050, 1300, 1550, 1800], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1000$ GeV')
plt.plot([800, 800, 1050, 1050, 1300, 1300, 1550, 1550, 1800, 1800], ATLAS_sT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$s_T$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTtau_cap_1000 = []
for i in range(len(BGttstau_store_mTtau)):
    if BGttstau_store_mTtau[i] > 500:
        BGttstau_store_mTtau_cap_1000.append( 500 )
    else:
        BGttstau_store_mTtau_cap_1000.append( BGttstau_store_mTtau[i] )
        
    
weights_mTtau_1000 = np.ones_like(BGttstau_store_mTtau_cap_1000)/factor_weight_1000
        
plt.hist(BGttstau_store_mTtau_cap_1000, weights=weights_mTtau_1000, bins=[300, 350, 400, 450, 500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1000$ GeV')
plt.plot([300, 300, 350, 350, 400, 400, 450, 450, 500, 500], ATLAS_mTtau, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTb1b2_cap_1000 = []
for i in range(len(BGttstau_store_mTb1b2)):
    if BGttstau_store_mTb1b2[i] > 1500:
        BGttstau_store_mTb1b2_cap_1000.append( 1500 )
    else:
        BGttstau_store_mTb1b2_cap_1000.append( BGttstau_store_mTb1b2[i] )
        
    
weights_mTb1b2_1000 = np.ones_like(BGttstau_store_mTb1b2_cap_1000)/factor_weight_1000
        
plt.hist(BGttstau_store_mTb1b2_cap_1000, weights=weights_mTb1b2_1000, bins=[700, 900, 1100, 1300, 1500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1000$ GeV')
plt.plot([700, 700, 900, 900, 1100, 1100, 1300, 1300, 1500, 1500], ATLAS_mTbb, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$\sum m_T(b_{1,2})$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_pTtau_cap_1000 = []
for i in range(len(BGttstau_store_pTtau)):
    if BGttstau_store_pTtau[i] > 250:
        BGttstau_store_pTtau_cap_1000.append( 250 )
    else:
        BGttstau_store_pTtau_cap_1000.append( BGttstau_store_pTtau[i] )
        
    
weights_pTtau_1000 = np.ones_like(BGttstau_store_pTtau_cap_1000)/factor_weight_1000
        
plt.hist(BGttstau_store_pTtau_cap_1000, weights=weights_pTtau_1000, bins=[50, 100, 150, 200, 250], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1000$ GeV')
plt.plot([50, 50, 100, 100, 150,150, 200, 200, 250, 250], ATLAS_pT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$p_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# #### LQ-up-1200GeV

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1200GeV/Auto_Results_LHCO/'

LQup_1200GeV_cross = 0.000923
LQup_1200GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1200GeV_evs = len(ev)
print('# events that pass the cuts: ', LQup_1200GeV_evs)
# Out:
# ('# events that pass the cuts: ', 67075)

# %%
cross = LQup_1200GeV_cross*1000
aceptancia = LQup_1200GeV_evs/(50000.*LQup_1200GeV_runs)
luminosidad = 139

LQup_1200GeV_fidcross = cross * aceptancia
LQup_1200GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', LQup_1200GeV_fidcross)
print('S_expected: ', LQup_1200GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.049528180000000005)
# ('S_expected: ', 6.884417020000001)

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1200GeV/Auto_Results_LHCO/'

LQup_1200GeV_cross = 0.000923
LQup_1200GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1200GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1200GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# events that pass the cuts: ', LQup_1200GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# events that pass the cuts: ', 43354)

# %%
cross = LQup_1200GeV_cross*1000
aceptancia = LQup_1200GeV_evs_ATLAS/(50000.*LQup_1200GeV_runs)
luminosidad = 139

LQup_1200GeV_fidcross_ATLAS = cross * aceptancia
LQup_1200GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', LQup_1200GeV_fidcross_ATLAS)
print('S_expected: ', LQup_1200GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.0320125936)
# ('S_expected: ', 4.4497505104)

# %%
k_factor_1200 = sum(ATLAS_pT)/2 / LQup_1200GeV_Sexpected_ATLAS
factor_weight_1200 = (1./k_factor_1200)*LQup_1200GeV_evs_ATLAS/LQup_1200GeV_Sexpected_ATLAS


BGttstau_store_sT_cap_1200 = []
for i in range(len(BGttstau_store_sT)):
    if BGttstau_store_sT[i] > 1800:
        BGttstau_store_sT_cap_1200.append( 1800 )
    else:
        BGttstau_store_sT_cap_1200.append( BGttstau_store_sT[i] )
        
    
weights_sT_1200 = np.ones_like(BGttstau_store_sT_cap_1200)/factor_weight_1200
        
plt.hist(BGttstau_store_sT_cap_1200, weights=weights_sT_1200, bins=[800, 1050, 1300, 1550, 1800], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1200$ GeV')
plt.plot([800, 800, 1050, 1050, 1300, 1300, 1550, 1550, 1800, 1800], ATLAS_sT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$s_T$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTtau_cap_1200 = []
for i in range(len(BGttstau_store_mTtau)):
    if BGttstau_store_mTtau[i] > 500:
        BGttstau_store_mTtau_cap_1200.append( 500 )
    else:
        BGttstau_store_mTtau_cap_1200.append( BGttstau_store_mTtau[i] )
        
    
weights_mTtau_1200 = np.ones_like(BGttstau_store_mTtau_cap_1200)/factor_weight_1200
        
plt.hist(BGttstau_store_mTtau_cap_1200, weights=weights_mTtau_1200, bins=[300, 350, 400, 450, 500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1200$ GeV')
plt.plot([300, 300, 350, 350, 400, 400, 450, 450, 500, 500], ATLAS_mTtau, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTb1b2_cap_1200 = []
for i in range(len(BGttstau_store_mTb1b2)):
    if BGttstau_store_mTb1b2[i] > 1500:
        BGttstau_store_mTb1b2_cap_1200.append( 1500 )
    else:
        BGttstau_store_mTb1b2_cap_1200.append( BGttstau_store_mTb1b2[i] )
        
    
weights_mTb1b2_1200 = np.ones_like(BGttstau_store_mTb1b2_cap_1200)/factor_weight_1200
        
plt.hist(BGttstau_store_mTb1b2_cap_1200, weights=weights_mTb1b2_1200, bins=[700, 900, 1100, 1300, 1500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1200$ GeV')
plt.plot([700, 700, 900, 900, 1100, 1100, 1300, 1300, 1500, 1500], ATLAS_mTbb, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$\sum m_T(b_{1,2})$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_pTtau_cap_1200 = []
for i in range(len(BGttstau_store_pTtau)):
    if BGttstau_store_pTtau[i] > 250:
        BGttstau_store_pTtau_cap_1200.append( 250 )
    else:
        BGttstau_store_pTtau_cap_1200.append( BGttstau_store_pTtau[i] )
        
    
weights_pTtau_1200 = np.ones_like(BGttstau_store_pTtau_cap_1200)/factor_weight_1200
        
plt.hist(BGttstau_store_pTtau_cap_1200, weights=weights_pTtau_1200, bins=[50, 100, 150, 200, 250], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1200$ GeV')
plt.plot([50, 50, 100, 100, 150,150, 200, 200, 250, 250], ATLAS_pT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$p_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %%
print('global k-factor for all masses (taken from 1200GeV):', k_factor_1200)
# Out:
# ('global k-factor for all masses (taken from 1200GeV):', 1.8877462860822058)

# %% [markdown]
# #### LQ-up-1400GeV

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1400GeV/Auto_Results_LHCO/'

LQup_1400GeV_cross =  0.000264
LQup_1400GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1400GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1400GeV_evs = len(ev)
print('# events that pass the cuts: ', LQup_1400GeV_evs)
# Out:
# /home/andres/anaconda3/envs/py2/lib/python2.7/site-packages/LHCO_reader/LHCO_reader.py:1484: UserWarning: Adding empty event
#   warnings.warn("Adding empty event")
# ('# events that pass the cuts: ', 58769)

# %%
cross = LQup_1400GeV_cross*1000
aceptancia = LQup_1400GeV_evs/(50000.*LQup_1400GeV_runs)
luminosidad = 139

LQup_1400GeV_fidcross = cross * aceptancia
LQup_1400GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', LQup_1400GeV_fidcross)
print('S_expected: ', LQup_1400GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.0124120128)
# ('S_expected: ', 1.7252697792)

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1400GeV/Auto_Results_LHCO/'

LQup_1400GeV_cross = 0.000264
LQup_1400GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1400GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1400GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# events that pass the cuts: ', LQup_1400GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# events that pass the cuts: ', 40170)

# %%
cross = LQup_1400GeV_cross*1000
aceptancia = LQup_1400GeV_evs_ATLAS/(50000.*LQup_1400GeV_runs)
luminosidad = 139

LQup_1400GeV_fidcross_ATLAS = cross * aceptancia
LQup_1400GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', LQup_1400GeV_fidcross_ATLAS)
print('S_expected: ', LQup_1400GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.008483904)
# ('S_expected: ', 1.1792626560000001)

# %%
k_factor_1400 = sum(ATLAS_pT)/2 / LQup_1400GeV_Sexpected_ATLAS
factor_weight_1400 = (1./k_factor_1400)*LQup_1400GeV_evs_ATLAS/LQup_1400GeV_Sexpected_ATLAS


BGttstau_store_sT_cap_1400 = []
for i in range(len(BGttstau_store_sT)):
    if BGttstau_store_sT[i] > 1800:
        BGttstau_store_sT_cap_1400.append( 1800 )
    else:
        BGttstau_store_sT_cap_1400.append( BGttstau_store_sT[i] )
        
    
weights_sT_1400 = np.ones_like(BGttstau_store_sT_cap_1400)/factor_weight_1400
        
plt.hist(BGttstau_store_sT_cap_1400, weights=weights_sT_1400, bins=[800, 1050, 1300, 1550, 1800], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1400$ GeV')
plt.plot([800, 800, 1050, 1050, 1300, 1300, 1550, 1550, 1800, 1800], ATLAS_sT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$s_T$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTtau_cap_1400 = []
for i in range(len(BGttstau_store_mTtau)):
    if BGttstau_store_mTtau[i] > 500:
        BGttstau_store_mTtau_cap_1400.append( 500 )
    else:
        BGttstau_store_mTtau_cap_1400.append( BGttstau_store_mTtau[i] )
        
    
weights_mTtau_1400 = np.ones_like(BGttstau_store_mTtau_cap_1400)/factor_weight_1400
        
plt.hist(BGttstau_store_mTtau_cap_1400, weights=weights_mTtau_1400, bins=[300, 350, 400, 450, 500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1400$ GeV')
plt.plot([300, 300, 350, 350, 400, 400, 450, 450, 500, 500], ATLAS_mTtau, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTb1b2_cap_1400 = []
for i in range(len(BGttstau_store_mTb1b2)):
    if BGttstau_store_mTb1b2[i] > 1500:
        BGttstau_store_mTb1b2_cap_1400.append( 1500 )
    else:
        BGttstau_store_mTb1b2_cap_1400.append( BGttstau_store_mTb1b2[i] )
        
    
weights_mTb1b2_1400 = np.ones_like(BGttstau_store_mTb1b2_cap_1400)/factor_weight_1400
        
plt.hist(BGttstau_store_mTb1b2_cap_1400, weights=weights_mTb1b2_1400, bins=[700, 900, 1100, 1300, 1500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1400$ GeV')
plt.plot([700, 700, 900, 900, 1100, 1100, 1300, 1300, 1500, 1500], ATLAS_mTbb, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$\sum m_T(b_{1,2})$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_pTtau_cap_1400 = []
for i in range(len(BGttstau_store_pTtau)):
    if BGttstau_store_pTtau[i] > 250:
        BGttstau_store_pTtau_cap_1400.append( 250 )
    else:
        BGttstau_store_pTtau_cap_1400.append( BGttstau_store_pTtau[i] )
        
    
weights_pTtau_1400 = np.ones_like(BGttstau_store_pTtau_cap_1400)/factor_weight_1400
        
plt.hist(BGttstau_store_pTtau_cap_1400, weights=weights_pTtau_1400, bins=[50, 100, 150, 200, 250], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1400$ GeV')
plt.plot([50, 50, 100, 100, 150,150, 200, 200, 250, 250], ATLAS_pT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$p_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# #### LQ-up-1600GeV

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1600GeV/Auto_Results_LHCO/'

LQup_1600GeV_cross = 0.0000802
LQup_1600GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1600GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1600GeV_evs = len(ev)
print('# events that pass the cuts: ', LQup_1600GeV_evs)
# Out:
# ('# events that pass the cuts: ', 60653)

# %%
cross = LQup_1600GeV_cross*1000
aceptancia = LQup_1600GeV_evs/(50000.*LQup_1600GeV_runs)
luminosidad = 139

LQup_1600GeV_fidcross = cross * aceptancia
LQup_1600GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', LQup_1600GeV_fidcross)
print('S_expected: ', LQup_1600GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.0038914964799999997)
# ('S_expected: ', 0.54091801072)

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1600GeV/Auto_Results_LHCO/'

LQup_1600GeV_cross = 0.0000802
LQup_1600GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1600GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1600GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# events that pass the cuts: ', LQup_1600GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# events that pass the cuts: ', 43358)

# %%
cross = LQup_1600GeV_cross*1000
aceptancia = LQup_1600GeV_evs_ATLAS/(50000.*LQup_1600GeV_runs)
luminosidad = 139

LQup_1600GeV_fidcross_ATLAS = cross * aceptancia
LQup_1600GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', LQup_1600GeV_fidcross_ATLAS)
print('S_expected: ', LQup_1600GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.0027818492799999996)
# ('S_expected: ', 0.38667704991999996)

# %%
k_factor_1600 = sum(ATLAS_pT)/2 / LQup_1600GeV_Sexpected_ATLAS
factor_weight_1600 = (1./k_factor_1600)*LQup_1600GeV_evs_ATLAS/LQup_1600GeV_Sexpected_ATLAS


BGttstau_store_sT_cap_1600 = []
for i in range(len(BGttstau_store_sT)):
    if BGttstau_store_sT[i] > 1800:
        BGttstau_store_sT_cap_1600.append( 1800 )
    else:
        BGttstau_store_sT_cap_1600.append( BGttstau_store_sT[i] )
        
    
weights_sT_1600 = np.ones_like(BGttstau_store_sT_cap_1600)/factor_weight_1600
        
plt.hist(BGttstau_store_sT_cap_1600, weights=weights_sT_1600, bins=[800, 1050, 1300, 1550, 1800], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1600$ GeV')
plt.plot([800, 800, 1050, 1050, 1300, 1300, 1550, 1550, 1800, 1800], ATLAS_sT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$s_T$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTtau_cap_1600 = []
for i in range(len(BGttstau_store_mTtau)):
    if BGttstau_store_mTtau[i] > 500:
        BGttstau_store_mTtau_cap_1600.append( 500 )
    else:
        BGttstau_store_mTtau_cap_1600.append( BGttstau_store_mTtau[i] )
        
    
weights_mTtau_1600 = np.ones_like(BGttstau_store_mTtau_cap_1600)/factor_weight_1600
        
plt.hist(BGttstau_store_mTtau_cap_1600, weights=weights_mTtau_1600, bins=[300, 350, 400, 450, 500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1600$ GeV')
plt.plot([300, 300, 350, 350, 400, 400, 450, 450, 500, 500], ATLAS_mTtau, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTb1b2_cap_1600 = []
for i in range(len(BGttstau_store_mTb1b2)):
    if BGttstau_store_mTb1b2[i] > 1500:
        BGttstau_store_mTb1b2_cap_1600.append( 1500 )
    else:
        BGttstau_store_mTb1b2_cap_1600.append( BGttstau_store_mTb1b2[i] )
        
    
weights_mTb1b2_1600 = np.ones_like(BGttstau_store_mTb1b2_cap_1600)/factor_weight_1600
        
plt.hist(BGttstau_store_mTb1b2_cap_1600, weights=weights_mTb1b2_1600, bins=[700, 900, 1100, 1300, 1500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1600$ GeV')
plt.plot([700, 700, 900, 900, 1100, 1100, 1300, 1300, 1500, 1500], ATLAS_mTbb, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$\sum m_T(b_{1,2})$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_pTtau_cap_1600 = []
for i in range(len(BGttstau_store_pTtau)):
    if BGttstau_store_pTtau[i] > 250:
        BGttstau_store_pTtau_cap_1600.append( 250 )
    else:
        BGttstau_store_pTtau_cap_1600.append( BGttstau_store_pTtau[i] )
        
    
weights_pTtau_1600 = np.ones_like(BGttstau_store_pTtau_cap_1600)/factor_weight_1600
        
plt.hist(BGttstau_store_pTtau_cap_1600, weights=weights_pTtau_1600, bins=[50, 100, 150, 200, 250], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1600$ GeV')
plt.plot([50, 50, 100, 100, 150,150, 200, 200, 250, 250], ATLAS_pT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$p_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# #### LQ-up-1800GeV

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1800GeV/'

LQup_1800GeV_cross = 2.535349e-05
LQup_1800GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1800GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'lqu18-'+str(iev)+"/tag_1_delphes_events.lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1800GeV_evs = len(ev)
print('# events that pass the cuts: ', LQup_1800GeV_evs)
# Out:
# ('# events that pass the cuts: ', 56076)

# %%
cross = LQup_1800GeV_cross*1000
aceptancia = LQup_1800GeV_evs/(50000.*LQup_1800GeV_runs)
luminosidad = 139

LQup_1800GeV_fidcross = cross * aceptancia
LQup_1800GeV_Sexpected = cross * aceptancia * luminosidad

print('fiducial cross section: ', LQup_1800GeV_fidcross)
print('S_expected: ', LQup_1800GeV_Sexpected)
# Out:
# ('fiducial cross section: ', 0.001137377844192)
# ('S_expected: ', 0.15809552034268798)

# %%
Folder = '/media/andres/Elements/Leptoquarks/signals/LQup-1800GeV/'

LQup_1800GeV_cross = 2.535349e-05
LQup_1800GeV_runs = 25

ev = []

BGttstau_store_pTtau = []
BGttstau_store_sT = []
BGttstau_store_mTtau = []
BGttstau_store_mTb1b2 = []

for iev in range(1,LQup_1800GeV_runs+1):
    
    inputevents = LHCO_reader.Events(f_name=Folder+'lqu18-'+str(iev)+"/tag_1_delphes_events.lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0

        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    if mTtau > 150:
                    #if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5



                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        #if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            #print(mTb1b2)
                            #print(i)
                            #break

                            ev.append(i)

                            BGttstau_store_pTtau.append(inputevents[i]["tau"][0]["PT"])
                            BGttstau_store_sT.append(sT)
                            BGttstau_store_mTtau.append(mTtau)
                            BGttstau_store_mTb1b2.append(mTb1b2)

LQup_1800GeV_evs_ATLAS = len(ev)

print('ATLAS CUTS')
print('# events that pass the cuts: ', LQup_1800GeV_evs_ATLAS)
# Out:
# ATLAS CUTS
# ('# events that pass the cuts: ', 41287)

# %%
cross = LQup_1800GeV_cross*1000
aceptancia = LQup_1800GeV_evs_ATLAS/(50000.*LQup_1800GeV_runs)
luminosidad = 139

LQup_1800GeV_fidcross_ATLAS = cross * aceptancia
LQup_1800GeV_Sexpected_ATLAS = cross * aceptancia * luminosidad

print('ATLAS CUTS')
print('fiducial cross section: ', LQup_1800GeV_fidcross_ATLAS)
print('S_expected: ', LQup_1800GeV_Sexpected_ATLAS)
# Out:
# ATLAS CUTS
# ('fiducial cross section: ', 0.0008374156333039999)
# ('S_expected: ', 0.11640077302925599)

# %%
k_factor_1800 = sum(ATLAS_pT)/2 / LQup_1800GeV_Sexpected_ATLAS
factor_weight_1800 = (1./k_factor_1800)*LQup_1800GeV_evs_ATLAS/LQup_1800GeV_Sexpected_ATLAS


BGttstau_store_sT_cap_1800 = []
for i in range(len(BGttstau_store_sT)):
    if BGttstau_store_sT[i] > 1800:
        BGttstau_store_sT_cap_1800.append( 1800 )
    else:
        BGttstau_store_sT_cap_1800.append( BGttstau_store_sT[i] )
        
    
weights_sT_1800 = np.ones_like(BGttstau_store_sT_cap_1800)/factor_weight_1800
        
plt.hist(BGttstau_store_sT_cap_1800, weights=weights_sT_1800, bins=[800, 1050, 1300, 1550, 1800], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1800$ GeV')
plt.plot([800, 800, 1050, 1050, 1300, 1300, 1550, 1550, 1800, 1800], ATLAS_sT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$s_T$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTtau_cap_1800 = []
for i in range(len(BGttstau_store_mTtau)):
    if BGttstau_store_mTtau[i] > 500:
        BGttstau_store_mTtau_cap_1800.append( 500 )
    else:
        BGttstau_store_mTtau_cap_1800.append( BGttstau_store_mTtau[i] )
        
    
weights_mTtau_1800 = np.ones_like(BGttstau_store_mTtau_cap_1800)/factor_weight_1800
        
plt.hist(BGttstau_store_mTtau_cap_1800, weights=weights_mTtau_1800, bins=[300, 350, 400, 450, 500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1800$ GeV')
plt.plot([300, 300, 350, 350, 400, 400, 450, 450, 500, 500], ATLAS_mTtau, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_mTb1b2_cap_1800 = []
for i in range(len(BGttstau_store_mTb1b2)):
    if BGttstau_store_mTb1b2[i] > 1500:
        BGttstau_store_mTb1b2_cap_1800.append( 1500 )
    else:
        BGttstau_store_mTb1b2_cap_1800.append( BGttstau_store_mTb1b2[i] )
        
    
weights_mTb1b2_1800 = np.ones_like(BGttstau_store_mTb1b2_cap_1800)/factor_weight_1800
        
plt.hist(BGttstau_store_mTb1b2_cap_1800, weights=weights_mTb1b2_1800, bins=[700, 900, 1100, 1300, 1500], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1800$ GeV')
plt.plot([700, 700, 900, 900, 1100, 1100, 1300, 1300, 1500, 1500], ATLAS_mTbb, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$\sum m_T(b_{1,2})$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()  



BGttstau_store_pTtau_cap_1800 = []
for i in range(len(BGttstau_store_pTtau)):
    if BGttstau_store_pTtau[i] > 250:
        BGttstau_store_pTtau_cap_1800.append( 250 )
    else:
        BGttstau_store_pTtau_cap_1800.append( BGttstau_store_pTtau[i] )
        
    
weights_pTtau_1800 = np.ones_like(BGttstau_store_pTtau_cap_1800)/factor_weight_1800
        
plt.hist(BGttstau_store_pTtau_cap_1800, weights=weights_pTtau_1800, bins=[50, 100, 150, 200, 250], histtype='step', color='firebrick', linewidth=2, label=r'$m_{LQ}=1800$ GeV')
plt.plot([50, 50, 100, 100, 150,150, 200, 200, 250, 250], ATLAS_pT, color='black', linewidth=2, label=r'ATLAS')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$p_T(\tau)$ [GeV]",fontsize=16)
plt.ylabel("Events",fontsize=16)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# ### Expected number of events after cuts

# %%
mass = [800,1000,1200,1400,1600,1800]

S_exp_loose = [102.64388737032002,26.204897493599997,6.884417020000001,1.7252697792,0.54091801072,0.15809552034268798]
S_exp_ATLAS = [49.14829060272,15.243772603200002,4.4497505104,1.179262656,0.38667704991999996,0.11640077302925599]

S_k_factor = [1.8877462860822058] # LQ up

# %%
plt.plot(mass, S_exp_loose, color='red', linewidth=2, label=r'Loose cuts')
plt.plot(mass, S_exp_ATLAS, color='black', linewidth=2, label=r'ATLAS cuts')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.yscale('log')
plt.xlabel(r"$m_{LQ}^u$ [GeV]",fontsize=15)
plt.ylabel('Expected Number of Events', fontsize = 15)
plt.grid()
plt.legend(fontsize=14)
plt.show() 

plt.plot(mass, S_exp_loose, color='red', linewidth=2, label=r'Loose cuts')
plt.plot(mass, S_exp_ATLAS, color='black', linewidth=2, label=r'ATLAS cuts')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
plt.xlabel(r"$m_{LQ}^u$ [GeV]",fontsize=15)
plt.ylabel('Expected Number of Events', fontsize = 15)
plt.grid()
plt.legend(fontsize=14)
plt.savefig('LQup_expected_events.pdf', bbox_inches='tight')
plt.show()
