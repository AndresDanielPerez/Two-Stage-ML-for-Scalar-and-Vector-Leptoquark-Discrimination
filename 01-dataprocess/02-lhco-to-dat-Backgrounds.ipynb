# %%
import numpy as np
#from lhereader import LHEReader

from LHCO_reader import LHCO_reader

import math
import os

# Plotting library
import matplotlib.pyplot as plt

# %% [markdown]
# ### extract info for LQ paper

# %% [markdown]
# ### BACKGROUNDS

# %% [markdown]
# #### tt

# %%
Folder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/tt/LO/Auto_Results_LHCO/'
datFolder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/DATAplus/dats-ttBB/'


ev = []


# for iev in range(1,526):
for iev in range(527,551):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0
        HT = 0 # hadronic activity HT, defined as the scalar sum of the pT of all reconstructed jets
        
        b_pt = []
        b_eta = []
        b_phi = []
        
        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                HT += inputevents[i]["jet"][k]["PT"]
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5
                                        
                                    b_pt.append(inputevents[i]["jet"][j]["PT"])
                                    b_eta.append(inputevents[i]["jet"][j]["eta"])
                                    b_phi.append(inputevents[i]["jet"][j]["phi"])


                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            
                            # jets, no 2 most energetic b-tagged jets
                            jets_rest = []
                            for j in range(inputevents[i].number()["jet"]):
                                jet = inputevents[i]["jet"][j]
                                if jet["PT"] > 20 and abs(jet["eta"]) < 2.8:
                                    # check if this jet was already included as the 2 most energetic b-tagged jets
                                    if not (jet["PT"] == b_pt[0] and jet["eta"] == b_eta[0] and jet["phi"] == b_phi[0]) and not (jet["PT"] == b_pt[1] and jet["eta"] == b_eta[1] and jet["phi"] == b_phi[1]):
                                        jets_rest.append((jet["PT"], jet["eta"], jet["phi"]))

                            ev.append(i)
                            
                            # SAVE: 
                            # hadronic info
                            with open(datFolder+'hadinfo.dat', 'a') as f:
                                f.write('%f %d %d\n' % (HT, num_jets, num_btag))
                                
                            # jets (no 2 most energetic b-tagged jets)
                            with open(datFolder + 'jets_rest.dat', 'a') as f:
                                f.write('%d ' % len(jets_rest)) # number
                                
                                for (pt, eta, phi) in jets_rest:
                                    f.write('%f %f %f ' % (pt, eta, phi))
                                f.write('\n')
                            
                            # b info:
                            with open(datFolder+'b1.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[0], b_eta[0], b_phi[0]))
                            with open(datFolder+'b2.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[1], b_eta[1], b_phi[1]))
                                
                            # tau
                            with open(datFolder+'tau.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["tau"][0]["PT"],inputevents[i]["tau"][0]["eta"],inputevents[i]["tau"][0]["phi"]))
                            
                            # MET (eta=0 by def, but I save phi because I have many jets)
                            with open(datFolder+'MET.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["MET"][0]["PT"],inputevents[i]["MET"][0]["eta"],inputevents[i]["MET"][0]["phi"]))
                            

 
    print('run: ',iev, '   # events ok so far: ' , len(ev))
print(' ')
print('Total pasaron los cortes: ', len(ev))
# Out:
# ('run: ', 527, '   # events ok so far: ', 1514)
# ('run: ', 528, '   # events ok so far: ', 3101)
# ('run: ', 529, '   # events ok so far: ', 4632)
# ('run: ', 530, '   # events ok so far: ', 6177)
# ('run: ', 531, '   # events ok so far: ', 7726)
# ('run: ', 532, '   # events ok so far: ', 9297)
# ('run: ', 533, '   # events ok so far: ', 10859)
# ('run: ', 534, '   # events ok so far: ', 12403)
# ('run: ', 535, '   # events ok so far: ', 13945)
# ('run: ', 536, '   # events ok so far: ', 15481)
# ('run: ', 537, '   # events ok so far: ', 16965)
# ('run: ', 538, '   # events ok so far: ', 18547)
# ('run: ', 539, '   # events ok so far: ', 20104)
# ('run: ', 540, '   # events ok so far: ', 21683)
# ('run: ', 541, '   # events ok so far: ', 23310)
# ('run: ', 542, '   # events ok so far: ', 24877)
# ('run: ', 543, '   # events ok so far: ', 26422)
# ('run: ', 544, '   # events ok so far: ', 28021)
# ('run: ', 545, '   # events ok so far: ', 29637)
# ('run: ', 546, '   # events ok so far: ', 31236)
# ('run: ', 547, '   # events ok so far: ', 32732)
# ('run: ', 548, '   # events ok so far: ', 34291)
# ('run: ', 549, '   # events ok so far: ', 35894)
# ('run: ', 550, '   # events ok so far: ', 37452)
#
# ('Total pasaron los cortes: ', 37452)

# %%
# from run 1 to 525,  788570
# from run 527 to 550,   37452

# total: 788570+37452 = 826022

# %%
788570+37452
# Out:
# 826022

# %% [markdown]
# #### fake tt

# %%
Folder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/fakett/LO/Auto_Results_LHCO/'
datFolder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/DATAplus/dats-fakett/'


ev = []



for iev in range(1,126):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0
        HT = 0 # hadronic activity HT, defined as the scalar sum of the pT of all reconstructed jets
        
        b_pt = []
        b_eta = []
        b_phi = []
        
        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                HT += inputevents[i]["jet"][k]["PT"]
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5
                                        
                                    b_pt.append(inputevents[i]["jet"][j]["PT"])
                                    b_eta.append(inputevents[i]["jet"][j]["eta"])
                                    b_phi.append(inputevents[i]["jet"][j]["phi"])


                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            
                            # jets, no 2 most energetic b-tagged jets
                            jets_rest = []
                            for j in range(inputevents[i].number()["jet"]):
                                jet = inputevents[i]["jet"][j]
                                if jet["PT"] > 20 and abs(jet["eta"]) < 2.8:
                                    # check if this jet was already included as the 2 most energetic b-tagged jets
                                    if not (jet["PT"] == b_pt[0] and jet["eta"] == b_eta[0] and jet["phi"] == b_phi[0]) and not (jet["PT"] == b_pt[1] and jet["eta"] == b_eta[1] and jet["phi"] == b_phi[1]):
                                        jets_rest.append((jet["PT"], jet["eta"], jet["phi"]))

                            ev.append(i)
                            
                            # SAVE: 
                            # hadronic info
                            with open(datFolder+'hadinfo.dat', 'a') as f:
                                f.write('%f %d %d\n' % (HT, num_jets, num_btag))
                                
                            # jets (no 2 most energetic b-tagged jets)
                            with open(datFolder + 'jets_rest.dat', 'a') as f:
                                f.write('%d ' % len(jets_rest)) # number
                                
                                for (pt, eta, phi) in jets_rest:
                                    f.write('%f %f %f ' % (pt, eta, phi))
                                f.write('\n')
                            
                            # b info:
                            with open(datFolder+'b1.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[0], b_eta[0], b_phi[0]))
                            with open(datFolder+'b2.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[1], b_eta[1], b_phi[1]))
                                
                            # tau
                            with open(datFolder+'tau.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["tau"][0]["PT"],inputevents[i]["tau"][0]["eta"],inputevents[i]["tau"][0]["phi"]))
                            
                            # MET (eta=0 by def, but I save phi because I have many jets)
                            with open(datFolder+'MET.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["MET"][0]["PT"],inputevents[i]["MET"][0]["eta"],inputevents[i]["MET"][0]["phi"]))
                            

 
    print('run: ',iev, '   # events ok so far: ' , len(ev))
print(' ')
print('Total pasaron los cortes: ', len(ev))
# Out:
# ('run: ', 1, '   # events ok so far: ', 0)
# ('run: ', 2, '   # events ok so far: ', 0)
# ('run: ', 3, '   # events ok so far: ', 0)
# ('run: ', 4, '   # events ok so far: ', 0)
# ('run: ', 5, '   # events ok so far: ', 0)
# ('run: ', 6, '   # events ok so far: ', 0)
# ('run: ', 7, '   # events ok so far: ', 0)
# ('run: ', 8, '   # events ok so far: ', 1)
# ('run: ', 9, '   # events ok so far: ', 1)
# ('run: ', 10, '   # events ok so far: ', 1)
# ('run: ', 11, '   # events ok so far: ', 1)
# ('run: ', 12, '   # events ok so far: ', 1)
# ('run: ', 13, '   # events ok so far: ', 1)
# ('run: ', 14, '   # events ok so far: ', 1)
# ('run: ', 15, '   # events ok so far: ', 1)
# ('run: ', 16, '   # events ok so far: ', 1)
# ('run: ', 17, '   # events ok so far: ', 1)
# ('run: ', 18, '   # events ok so far: ', 1)
# ('run: ', 19, '   # events ok so far: ', 1)
# ('run: ', 20, '   # events ok so far: ', 1)
# ('run: ', 21, '   # events ok so far: ', 1)
# ('run: ', 22, '   # events ok so far: ', 1)
# ('run: ', 23, '   # events ok so far: ', 1)
# ('run: ', 24, '   # events ok so far: ', 1)
# ('run: ', 25, '   # events ok so far: ', 1)
# ('run: ', 26, '   # events ok so far: ', 1)
# ('run: ', 27, '   # events ok so far: ', 1)
# ('run: ', 28, '   # events ok so far: ', 2)
# ('run: ', 29, '   # events ok so far: ', 2)
# ('run: ', 30, '   # events ok so far: ', 2)
# ('run: ', 31, '   # events ok so far: ', 2)
# ('run: ', 32, '   # events ok so far: ', 2)
# ('run: ', 33, '   # events ok so far: ', 2)
# ('run: ', 34, '   # events ok so far: ', 2)
# ('run: ', 35, '   # events ok so far: ', 2)
# ('run: ', 36, '   # events ok so far: ', 2)
# ('run: ', 37, '   # events ok so far: ', 2)
# ('run: ', 38, '   # events ok so far: ', 2)
# ('run: ', 39, '   # events ok so far: ', 2)
# ('run: ', 40, '   # events ok so far: ', 2)
# ('run: ', 41, '   # events ok so far: ', 2)
# ('run: ', 42, '   # events ok so far: ', 2)
# ('run: ', 43, '   # events ok so far: ', 2)
# ('run: ', 44, '   # events ok so far: ', 2)
# ('run: ', 45, '   # events ok so far: ', 2)
# ('run: ', 46, '   # events ok so far: ', 2)
# ('run: ', 47, '   # events ok so far: ', 2)
# ('run: ', 48, '   # events ok so far: ', 2)
# ('run: ', 49, '   # events ok so far: ', 2)
# ('run: ', 50, '   # events ok so far: ', 2)
# ('run: ', 51, '   # events ok so far: ', 2)
# ('run: ', 52, '   # events ok so far: ', 2)
# ('run: ', 53, '   # events ok so far: ', 2)
# ('run: ', 54, '   # events ok so far: ', 2)
# ('run: ', 55, '   # events ok so far: ', 3)
# ('run: ', 56, '   # events ok so far: ', 3)
# ('run: ', 57, '   # events ok so far: ', 3)
# ('run: ', 58, '   # events ok so far: ', 3)
# ('run: ', 59, '   # events ok so far: ', 3)
# ('run: ', 60, '   # events ok so far: ', 3)
# ('run: ', 61, '   # events ok so far: ', 3)
# ('run: ', 62, '   # events ok so far: ', 4)
# ('run: ', 63, '   # events ok so far: ', 4)
# ('run: ', 64, '   # events ok so far: ', 4)
# ('run: ', 65, '   # events ok so far: ', 4)
# ('run: ', 66, '   # events ok so far: ', 4)
# ('run: ', 67, '   # events ok so far: ', 4)
# ('run: ', 68, '   # events ok so far: ', 4)
# ('run: ', 69, '   # events ok so far: ', 4)
# ('run: ', 70, '   # events ok so far: ', 4)
# ('run: ', 71, '   # events ok so far: ', 4)
# ('run: ', 72, '   # events ok so far: ', 4)
# ('run: ', 73, '   # events ok so far: ', 4)
# ('run: ', 74, '   # events ok so far: ', 4)
# ('run: ', 75, '   # events ok so far: ', 4)
# ('run: ', 76, '   # events ok so far: ', 4)
# ('run: ', 77, '   # events ok so far: ', 4)
# ('run: ', 78, '   # events ok so far: ', 4)
# ('run: ', 79, '   # events ok so far: ', 4)
# ('run: ', 80, '   # events ok so far: ', 5)
# ('run: ', 81, '   # events ok so far: ', 5)
# ('run: ', 82, '   # events ok so far: ', 5)
# ('run: ', 83, '   # events ok so far: ', 5)
# ('run: ', 84, '   # events ok so far: ', 5)
# ('run: ', 85, '   # events ok so far: ', 5)
# ('run: ', 86, '   # events ok so far: ', 5)
# ('run: ', 87, '   # events ok so far: ', 5)
# ('run: ', 88, '   # events ok so far: ', 5)
# ('run: ', 89, '   # events ok so far: ', 5)
# ('run: ', 90, '   # events ok so far: ', 5)
# ('run: ', 91, '   # events ok so far: ', 5)
# ('run: ', 92, '   # events ok so far: ', 5)
# ('run: ', 93, '   # events ok so far: ', 5)
# ('run: ', 94, '   # events ok so far: ', 6)
# ('run: ', 95, '   # events ok so far: ', 6)
# ('run: ', 96, '   # events ok so far: ', 7)
# ('run: ', 97, '   # events ok so far: ', 7)
# ('run: ', 98, '   # events ok so far: ', 7)
# ('run: ', 99, '   # events ok so far: ', 7)
# ('run: ', 100, '   # events ok so far: ', 7)
# ('run: ', 101, '   # events ok so far: ', 7)
# ('run: ', 102, '   # events ok so far: ', 7)
# ('run: ', 103, '   # events ok so far: ', 7)
# ('run: ', 104, '   # events ok so far: ', 7)
# ('run: ', 105, '   # events ok so far: ', 7)
# ('run: ', 106, '   # events ok so far: ', 7)
# ('run: ', 107, '   # events ok so far: ', 7)
# ('run: ', 108, '   # events ok so far: ', 7)
# ('run: ', 109, '   # events ok so far: ', 7)
# ('run: ', 110, '   # events ok so far: ', 7)
# ('run: ', 111, '   # events ok so far: ', 7)
# ('run: ', 112, '   # events ok so far: ', 8)
# ('run: ', 113, '   # events ok so far: ', 8)
# ('run: ', 114, '   # events ok so far: ', 8)
# ('run: ', 115, '   # events ok so far: ', 8)
# ('run: ', 116, '   # events ok so far: ', 8)
# ('run: ', 117, '   # events ok so far: ', 8)
# ('run: ', 118, '   # events ok so far: ', 8)
# ('run: ', 119, '   # events ok so far: ', 8)
# ('run: ', 120, '   # events ok so far: ', 8)
# ('run: ', 121, '   # events ok so far: ', 8)
# ('run: ', 122, '   # events ok so far: ', 8)
# ('run: ', 123, '   # events ok so far: ', 8)
# ('run: ', 124, '   # events ok so far: ', 8)
# ('run: ', 125, '   # events ok so far: ', 8)
#
# ('Total pasaron los cortes: ', 8)

# %%
# total: 8

# %% [markdown]
# #### single t part 1 (part of single t)

# %%
Folder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/singletP1/LO/Auto_Results_LHCO/'
datFolder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/DATAplus/dats-singletP1/'


ev = []



for iev in range(1,201):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0
        HT = 0 # hadronic activity HT, defined as the scalar sum of the pT of all reconstructed jets
        
        b_pt = []
        b_eta = []
        b_phi = []
        
        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                HT += inputevents[i]["jet"][k]["PT"]
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5
                                        
                                    b_pt.append(inputevents[i]["jet"][j]["PT"])
                                    b_eta.append(inputevents[i]["jet"][j]["eta"])
                                    b_phi.append(inputevents[i]["jet"][j]["phi"])


                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            
                            # jets, no 2 most energetic b-tagged jets
                            jets_rest = []
                            for j in range(inputevents[i].number()["jet"]):
                                jet = inputevents[i]["jet"][j]
                                if jet["PT"] > 20 and abs(jet["eta"]) < 2.8:
                                    # check if this jet was already included as the 2 most energetic b-tagged jets
                                    if not (jet["PT"] == b_pt[0] and jet["eta"] == b_eta[0] and jet["phi"] == b_phi[0]) and not (jet["PT"] == b_pt[1] and jet["eta"] == b_eta[1] and jet["phi"] == b_phi[1]):
                                        jets_rest.append((jet["PT"], jet["eta"], jet["phi"]))

                            ev.append(i)
                            
                            # SAVE: 
                            # hadronic info
                            with open(datFolder+'hadinfo.dat', 'a') as f:
                                f.write('%f %d %d\n' % (HT, num_jets, num_btag))
                                
                            # jets (no 2 most energetic b-tagged jets)
                            with open(datFolder + 'jets_rest.dat', 'a') as f:
                                f.write('%d ' % len(jets_rest)) # number
                                
                                for (pt, eta, phi) in jets_rest:
                                    f.write('%f %f %f ' % (pt, eta, phi))
                                f.write('\n')
                            
                            # b info:
                            with open(datFolder+'b1.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[0], b_eta[0], b_phi[0]))
                            with open(datFolder+'b2.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[1], b_eta[1], b_phi[1]))
                                
                            # tau
                            with open(datFolder+'tau.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["tau"][0]["PT"],inputevents[i]["tau"][0]["eta"],inputevents[i]["tau"][0]["phi"]))
                            
                            # MET (eta=0 by def, but I save phi because I have many jets)
                            with open(datFolder+'MET.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["MET"][0]["PT"],inputevents[i]["MET"][0]["eta"],inputevents[i]["MET"][0]["phi"]))
                            

 
    print('run: ',iev, '   # events ok so far: ' , len(ev))
print(' ')
print('Total pasaron los cortes: ', len(ev))
# Out:
# ('run: ', 1, '   # events ok so far: ', 260)
# ('run: ', 2, '   # events ok so far: ', 531)
# ('run: ', 3, '   # events ok so far: ', 783)
# ('run: ', 4, '   # events ok so far: ', 1037)
# ('run: ', 5, '   # events ok so far: ', 1283)
# ('run: ', 6, '   # events ok so far: ', 1528)
# ('run: ', 7, '   # events ok so far: ', 1770)
# ('run: ', 8, '   # events ok so far: ', 2040)
# ('run: ', 9, '   # events ok so far: ', 2276)
# ('run: ', 10, '   # events ok so far: ', 2518)
# ('run: ', 11, '   # events ok so far: ', 2769)
# ('run: ', 12, '   # events ok so far: ', 3032)
# ('run: ', 13, '   # events ok so far: ', 3286)
# ('run: ', 14, '   # events ok so far: ', 3532)
# ('run: ', 188, '   # events ok so far: ', 166216)
# ('run: ', 189, '   # events ok so far: ', 167357)
# ('run: ', 190, '   # events ok so far: ', 168494)
# ('run: ', 191, '   # events ok so far: ', 169540)
# ('run: ', 192, '   # events ok so far: ', 170675)
# ('run: ', 193, '   # events ok so far: ', 171781)
# ('run: ', 194, '   # events ok so far: ', 172907)
# ('run: ', 195, '   # events ok so far: ', 174039)
# ('run: ', 196, '   # events ok so far: ', 175143)
# ('run: ', 197, '   # events ok so far: ', 176249)
# ('run: ', 198, '   # events ok so far: ', 177393)
# ('run: ', 199, '   # events ok so far: ', 178551)
# ('run: ', 200, '   # events ok so far: ', 179677)
#
# ('Total pasaron los cortes: ', 179677)

# %%
# total: 179677

# %%
1100*200
# Out:
# 220000

# %% [markdown]
# #### single t comp (part of single t)

# %%
Folder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/singlet-comp/LO/Auto_Results_LHCO/'
datFolder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/DATAplus/dats-singlet-comp/'


ev = []



for iev in range(1,101):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0
        HT = 0 # hadronic activity HT, defined as the scalar sum of the pT of all reconstructed jets
        
        b_pt = []
        b_eta = []
        b_phi = []
        
        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                HT += inputevents[i]["jet"][k]["PT"]
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5
                                        
                                    b_pt.append(inputevents[i]["jet"][j]["PT"])
                                    b_eta.append(inputevents[i]["jet"][j]["eta"])
                                    b_phi.append(inputevents[i]["jet"][j]["phi"])


                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            
                            # jets, no 2 most energetic b-tagged jets
                            jets_rest = []
                            for j in range(inputevents[i].number()["jet"]):
                                jet = inputevents[i]["jet"][j]
                                if jet["PT"] > 20 and abs(jet["eta"]) < 2.8:
                                    # check if this jet was already included as the 2 most energetic b-tagged jets
                                    if not (jet["PT"] == b_pt[0] and jet["eta"] == b_eta[0] and jet["phi"] == b_phi[0]) and not (jet["PT"] == b_pt[1] and jet["eta"] == b_eta[1] and jet["phi"] == b_phi[1]):
                                        jets_rest.append((jet["PT"], jet["eta"], jet["phi"]))

                            ev.append(i)
                            
                            # SAVE: 
                            # hadronic info
                            with open(datFolder+'hadinfo.dat', 'a') as f:
                                f.write('%f %d %d\n' % (HT, num_jets, num_btag))
                                
                            # jets (no 2 most energetic b-tagged jets)
                            with open(datFolder + 'jets_rest.dat', 'a') as f:
                                f.write('%d ' % len(jets_rest)) # number
                                
                                for (pt, eta, phi) in jets_rest:
                                    f.write('%f %f %f ' % (pt, eta, phi))
                                f.write('\n')
                            
                            # b info:
                            with open(datFolder+'b1.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[0], b_eta[0], b_phi[0]))
                            with open(datFolder+'b2.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[1], b_eta[1], b_phi[1]))
                                
                            # tau
                            with open(datFolder+'tau.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["tau"][0]["PT"],inputevents[i]["tau"][0]["eta"],inputevents[i]["tau"][0]["phi"]))
                            
                            # MET (eta=0 by def, but I save phi because I have many jets)
                            with open(datFolder+'MET.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["MET"][0]["PT"],inputevents[i]["MET"][0]["eta"],inputevents[i]["MET"][0]["phi"]))
                            

 
    print('run: ',iev, '   # events ok so far: ' , len(ev))
print(' ')
print('Total pasaron los cortes: ', len(ev))
# Out:
# ('run: ', 1, '   # events ok so far: ', 930)
# ('run: ', 2, '   # events ok so far: ', 1871)
# ('run: ', 3, '   # events ok so far: ', 2757)
# ('run: ', 4, '   # events ok so far: ', 3646)
# ('run: ', 5, '   # events ok so far: ', 4586)
# ('run: ', 6, '   # events ok so far: ', 5528)
# ('run: ', 7, '   # events ok so far: ', 6478)
# ('run: ', 8, '   # events ok so far: ', 7444)
# ('run: ', 9, '   # events ok so far: ', 8373)
# ('run: ', 10, '   # events ok so far: ', 9306)
# ('run: ', 11, '   # events ok so far: ', 10269)
# ('run: ', 12, '   # events ok so far: ', 11203)
# ('run: ', 13, '   # events ok so far: ', 12187)
# ('run: ', 14, '   # events ok so far: ', 13133)
# ('run: ', 15, '   # events ok so far: ', 14073)
# ('run: ', 16, '   # events ok so far: ', 14984)
# ('run: ', 17, '   # events ok so far: ', 15923)
# ('run: ', 18, '   # events ok so far: ', 16884)
# ('run: ', 19, '   # events ok so far: ', 17813)
# ('run: ', 20, '   # events ok so far: ', 18774)
# ('run: ', 21, '   # events ok so far: ', 19712)
# ('run: ', 22, '   # events ok so far: ', 20654)
# ('run: ', 23, '   # events ok so far: ', 21651)
# ('run: ', 24, '   # events ok so far: ', 22610)
# ('run: ', 25, '   # events ok so far: ', 23584)
# ('run: ', 26, '   # events ok so far: ', 24510)
# ('run: ', 27, '   # events ok so far: ', 25464)
# ('run: ', 28, '   # events ok so far: ', 26397)
# ('run: ', 29, '   # events ok so far: ', 27349)
# ('run: ', 30, '   # events ok so far: ', 28270)
# ('run: ', 31, '   # events ok so far: ', 29156)
# ('run: ', 32, '   # events ok so far: ', 30110)
# ('run: ', 33, '   # events ok so far: ', 31061)
# ('run: ', 34, '   # events ok so far: ', 31985)
# ('run: ', 35, '   # events ok so far: ', 32931)
# ('run: ', 36, '   # events ok so far: ', 33850)
# ('run: ', 37, '   # events ok so far: ', 34845)
# ('run: ', 38, '   # events ok so far: ', 35738)
# ('run: ', 39, '   # events ok so far: ', 36686)
# ('run: ', 40, '   # events ok so far: ', 37606)
# ('run: ', 41, '   # events ok so far: ', 38546)
# ('run: ', 42, '   # events ok so far: ', 39471)
# ('run: ', 43, '   # events ok so far: ', 40409)
# ('run: ', 44, '   # events ok so far: ', 41333)
# ('run: ', 45, '   # events ok so far: ', 42279)
# ('run: ', 46, '   # events ok so far: ', 43213)
# ('run: ', 47, '   # events ok so far: ', 44142)
# ('run: ', 48, '   # events ok so far: ', 45115)
# ('run: ', 49, '   # events ok so far: ', 46065)
# ('run: ', 50, '   # events ok so far: ', 47045)
# ('run: ', 51, '   # events ok so far: ', 47917)
# ('run: ', 52, '   # events ok so far: ', 48883)
# ('run: ', 53, '   # events ok so far: ', 49833)
# ('run: ', 54, '   # events ok so far: ', 50813)
# ('run: ', 55, '   # events ok so far: ', 51772)
# ('run: ', 56, '   # events ok so far: ', 52719)
# ('run: ', 57, '   # events ok so far: ', 53662)
# ('run: ', 58, '   # events ok so far: ', 54650)
# ('run: ', 59, '   # events ok so far: ', 55594)
# ('run: ', 60, '   # events ok so far: ', 56554)
# ('run: ', 61, '   # events ok so far: ', 57521)
# ('run: ', 62, '   # events ok so far: ', 58503)
# ('run: ', 63, '   # events ok so far: ', 59424)
# ('run: ', 64, '   # events ok so far: ', 60348)
# ('run: ', 65, '   # events ok so far: ', 61272)
# ('run: ', 66, '   # events ok so far: ', 62157)
# ('run: ', 67, '   # events ok so far: ', 63079)
# ('run: ', 68, '   # events ok so far: ', 64036)
# ('run: ', 69, '   # events ok so far: ', 64928)
# ('run: ', 70, '   # events ok so far: ', 65852)
# ('run: ', 71, '   # events ok so far: ', 66812)
# ('run: ', 72, '   # events ok so far: ', 67713)
# ('run: ', 73, '   # events ok so far: ', 68685)
# ('run: ', 74, '   # events ok so far: ', 69626)
# ('run: ', 75, '   # events ok so far: ', 70559)
# ('run: ', 76, '   # events ok so far: ', 71483)
# ('run: ', 77, '   # events ok so far: ', 72416)
# ('run: ', 78, '   # events ok so far: ', 73374)
# ('run: ', 79, '   # events ok so far: ', 74346)
# ('run: ', 80, '   # events ok so far: ', 75244)
# ('run: ', 81, '   # events ok so far: ', 76230)
# ('run: ', 82, '   # events ok so far: ', 77122)
# ('run: ', 83, '   # events ok so far: ', 78066)
# ('run: ', 84, '   # events ok so far: ', 78980)
# ('run: ', 85, '   # events ok so far: ', 79914)
# ('run: ', 86, '   # events ok so far: ', 80862)
# ('run: ', 87, '   # events ok so far: ', 81841)
# ('run: ', 88, '   # events ok so far: ', 82820)
# ('run: ', 89, '   # events ok so far: ', 83726)
# ('run: ', 90, '   # events ok so far: ', 84662)
# ('run: ', 91, '   # events ok so far: ', 85655)
# ('run: ', 92, '   # events ok so far: ', 86593)
# ('run: ', 93, '   # events ok so far: ', 87584)
# ('run: ', 94, '   # events ok so far: ', 88495)
# ('run: ', 95, '   # events ok so far: ', 89417)
# ('run: ', 96, '   # events ok so far: ', 90374)
# ('run: ', 97, '   # events ok so far: ', 91310)
# ('run: ', 98, '   # events ok so far: ', 92289)
# ('run: ', 99, '   # events ok so far: ', 93258)
# ('run: ', 100, '   # events ok so far: ', 94219)
#
# ('Total pasaron los cortes: ', 94219)

# %%
# total: 94219

# %%
930*100
# Out:
# 93000

# %% [markdown]
# #### W plus b b jets

# %%
Folder = '/media/andres/Elements/Leptoquarks-v3/backgrounds
# ('run: ', 111, '   # events ok so far: ', 120405)
# ('run: ', 112, '   # events ok so far: ', 121501)
# ('run: ', 113, '   # events ok so far: ', 122633)
# ('run: ', 114, '   # events ok so far: ', 123688)
# ('run: ', 115, '   # events ok so far: ', 124793)
# ('run: ', 116, '   # events ok so far: ', 125884)
# ('run: ', 117, '   # events ok so far: ', 126965)
# ('run: ', 118, '   # events ok so far: ', 128045)
# ('run: ', 119, '   # events ok so far: ', 129097)
# ('run: ', 120, '   # events ok so far: ', 130168)
# ('run: ', 121, '   # events ok so far: ', 131252)
# ('run: ', 122, '   # events ok so far: ', 132295)
# ('run: ', 123, '   # events ok so far: ', 133353)
# ('run: ', 124, '   # events ok so far: ', 134421)
# ('run: ', 125, '   # events ok so far: ', 135466)
# ('run: ', 126, '   # events ok so far: ', 136521)
# ('run: ', 127, '   # events ok so far: ', 137615)
# ('run: ', 128, '   # events ok so far: ', 138684)
# ('run: ', 129, '   # events ok so far: ', 139753)
# ('run: ', 130, '   # events ok so far: ', 140861)
# ('run: ', 131, '   # events ok so far: ', 141999)
# ('run: ', 132, '   # events ok so far: ', 143093)
# ('run: ', 133, '   # events ok so far: ', 144190)
# ('run: ', 134, '   # events ok so far: ', 145222)
# ('run: ', 135, '   # events ok so far: ', 146341)
# ('run: ', 136, '   # events ok so far: ', 147365)
# ('run: ', 137, '   # events ok so far: ', 148450)
# ('run: ', 138, '   # events ok so far: ', 149520)
# ('run: ', 139, '   # events ok so far: ', 150578)
# ('run: ', 140, '   # events ok so far: ', 151690)
# ('run: ', 141, '   # events ok so far: ', 152795)
# ('run: ', 142, '   # events ok so far: ', 153849)
# ('run: ', 143, '   # events ok so far: ', 154932)
# ('run: ', 144, '   # events ok so far: ', 156005)
# ('run: ', 145, '   # events ok so far: ', 157070)
# ('run: ', 146, '   # events ok so far: ', 158158)
# ('run: ', 147, '   # events ok so far: ', 159258)
# ('run: ', 148, '   # events ok so far: ', 160325)
# ('run: ', 149, '   # events ok so far: ', 161361)
# ('run: ', 150, '   # events ok so far: ', 162448)
#
# ('Total pasaron los cortes: ', 162448)

# %%
# total: 162448

# %%
1076*150
# Out:
# 161400

# %% [markdown]
# #### Z plus b b jets

# %%
Folder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/Zbbjets/LO/Auto_Results_LHCO/'
datFolder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/DATAplus/dats-Zbbjets/'


ev = []



for iev in range(1,31):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0
        HT = 0 # hadronic activity HT, defined as the scalar sum of the pT of all reconstructed jets
        
        b_pt = []
        b_eta = []
        b_phi = []
        
        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                HT += inputevents[i]["jet"][k]["PT"]
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5
                                        
                                    b_pt.append(inputevents[i]["jet"][j]["PT"])
                                    b_eta.append(inputevents[i]["jet"][j]["eta"])
                                    b_phi.append(inputevents[i]["jet"][j]["phi"])


                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            
                            # jets, no 2 most energetic b-tagged jets
                            jets_rest = []
                            for j in range(inputevents[i].number()["jet"]):
                                jet = inputevents[i]["jet"][j]
                                if jet["PT"] > 20 and abs(jet["eta"]) < 2.8:
                                    # check if this jet was already included as the 2 most energetic b-tagged jets
                                    if not (jet["PT"] == b_pt[0] and jet["eta"] == b_eta[0] and jet["phi"] == b_phi[0]) and not (jet["PT"] == b_pt[1] and jet["eta"] == b_eta[1] and jet["phi"] == b_phi[1]):
                                        jets_rest.append((jet["PT"], jet["eta"], jet["phi"]))

                            ev.append(i)
                            
                            # SAVE: 
                            # hadronic info
                            with open(datFolder+'hadinfo.dat', 'a') as f:
                                f.write('%f %d %d\n' % (HT, num_jets, num_btag))
                                
                            # jets (no 2 most energetic b-tagged jets)
                            with open(datFolder + 'jets_rest.dat', 'a') as f:
                                f.write('%d ' % len(jets_rest)) # number
                                
                                for (pt, eta, phi) in jets_rest:
                                    f.write('%f %f %f ' % (pt, eta, phi))
                                f.write('\n')
                            
                            # b info:
                            with open(datFolder+'b1.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[0], b_eta[0], b_phi[0]))
                            with open(datFolder+'b2.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[1], b_eta[1], b_phi[1]))
                                
                            # tau
                            with open(datFolder+'tau.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["tau"][0]["PT"],inputevents[i]["tau"][0]["eta"],inputevents[i]["tau"][0]["phi"]))
                            
                            # MET (eta=0 by def, but I save phi because I have many jets)
                            with open(datFolder+'MET.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["MET"][0]["PT"],inputevents[i]["MET"][0]["eta"],inputevents[i]["MET"][0]["phi"]))
                            

 
    print('run: ',iev, '   # events ok so far: ' , len(ev))
print(' ')
print('Total pasaron los cortes: ', len(ev))
# Out:
# ('run: ', 1, '   # events ok so far: ', 111)
# ('run: ', 2, '   # events ok so far: ', 245)
# ('run: ', 3, '   # events ok so far: ', 362)
# ('run: ', 4, '   # events ok so far: ', 492)
# ('run: ', 5, '   # events ok so far: ', 612)
# ('run: ', 6, '   # events ok so far: ', 730)
# ('run: ', 7, '   # events ok so far: ', 846)
# ('run: ', 8, '   # events ok so far: ', 955)
# ('run: ', 9, '   # events ok so far: ', 1089)
# ('run: ', 10, '   # events ok so far: ', 1210)
# ('run: ', 11, '   # events ok so far: ', 1325)
# ('run: ', 12, '   # events ok so far: ', 1433)
# ('run: ', 13, '   # events ok so far: ', 1544)
# ('run: ', 14, '   # events ok so far: ', 1668)
# ('run: ', 15, '   # events ok so far: ', 1794)
# ('run: ', 16, '   # events ok so far: ', 1919)
# ('run: ', 17, '   # events ok so far: ', 2050)
# ('run: ', 18, '   # events ok so far: ', 2185)
# ('run: ', 19, '   # events ok so far: ', 2307)
# ('run: ', 20, '   # events ok so far: ', 2419)
# ('run: ', 21, '   # events ok so far: ', 2524)
# ('run: ', 22, '   # events ok so far: ', 2643)
# ('run: ', 23, '   # events ok so far: ', 2778)
# ('run: ', 24, '   # events ok so far: ', 2897)
# ('run: ', 25, '   # events ok so far: ', 3028)
# ('run: ', 26, '   # events ok so far: ', 3151)
# ('run: ', 27, '   # events ok so far: ', 3268)
# ('run: ', 28, '   # events ok so far: ', 3387)
# ('run: ', 29, '   # events ok so far: ', 3519)
# ('run: ', 30, '   # events ok so far: ', 3662)
#
# ('Total pasaron los cortes: ', 3662)

# %%
# total: 3662

# %%
111*30
# Out:
# 3330

# %% [markdown]
# #### ttW (part of ttV)

# %%
Folder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/ttW/LO/Auto_Results_LHCO/'
datFolder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/DATAplus/dats-ttW/'


ev = []



for iev in range(1,52):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0
        HT = 0 # hadronic activity HT, defined as the scalar sum of the pT of all reconstructed jets
        
        b_pt = []
        b_eta = []
        b_phi = []
        
        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                HT += inputevents[i]["jet"][k]["PT"]
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5
                                        
                                    b_pt.append(inputevents[i]["jet"][j]["PT"])
                                    b_eta.append(inputevents[i]["jet"][j]["eta"])
                                    b_phi.append(inputevents[i]["jet"][j]["phi"])


                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            
                            # jets, no 2 most energetic b-tagged jets
                            jets_rest = []
                            for j in range(inputevents[i].number()["jet"]):
                                jet = inputevents[i]["jet"][j]
                                if jet["PT"] > 20 and abs(jet["eta"]) < 2.8:
                                    # check if this jet was already included as the 2 most energetic b-tagged jets
                                    if not (jet["PT"] == b_pt[0] and jet["eta"] == b_eta[0] and jet["phi"] == b_phi[0]) and not (jet["PT"] == b_pt[1] and jet["eta"] == b_eta[1] and jet["phi"] == b_phi[1]):
                                        jets_rest.append((jet["PT"], jet["eta"], jet["phi"]))

                            ev.append(i)
                            
                            # SAVE: 
                            # hadronic info
                            with open(datFolder+'hadinfo.dat', 'a') as f:
                                f.write('%f %d %d\n' % (HT, num_jets, num_btag))
                                
                            # jets (no 2 most energetic b-tagged jets)
                            with open(datFolder + 'jets_rest.dat', 'a') as f:
                                f.write('%d ' % len(jets_rest)) # number
                                
                                for (pt, eta, phi) in jets_rest:
                                    f.write('%f %f %f ' % (pt, eta, phi))
                                f.write('\n')
                            
                            # b info:
                            with open(datFolder+'b1.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[0], b_eta[0], b_phi[0]))
                            with open(datFolder+'b2.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[1], b_eta[1], b_phi[1]))
                                
                            # tau
                            with open(datFolder+'tau.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["tau"][0]["PT"],inputevents[i]["tau"][0]["eta"],inputevents[i]["tau"][0]["phi"]))
                            
                            # MET (eta=0 by def, but I save phi because I have many jets)
                            with open(datFolder+'MET.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["MET"][0]["PT"],inputevents[i]["MET"][0]["eta"],inputevents[i]["MET"][0]["phi"]))
                            

 
    print('run: ',iev, '   # events ok so far: ' , len(ev))
print(' ')
print('Total pasaron los cortes: ', len(ev))
# Out:
# ('run: ', 1, '   # events ok so far: ', 2823)
# ('run: ', 2, '   # events ok so far: ', 5661)
# ('run: ', 3, '   # events ok so far: ', 8473)
# ('run: ', 4, '   # events ok so far: ', 11264)
# ('run: ', 5, '   # events ok so far: ', 14013)
# ('run: ', 6, '   # events ok so far: ', 16860)
# ('run: ', 7, '   # events ok so far: ', 19587)
# ('run: ', 8, '   # events ok so far: ', 22362)
# ('run: ', 9, '   # events ok so far: ', 25093)
# ('run: ', 10, '   # events ok so far: ', 27918)
# ('run: ', 11, '   # events ok so far: ', 30657)
# ('run: ', 12, '   # events ok so far: ', 33493)
# ('run: ', 13, '   # events ok so far: ', 36273)
# ('run: ', 14, '   # events ok so far: ', 38909)
# ('run: ', 15, '   # events ok so far: ', 41721)
# ('run: ', 16, '   # events ok so far: ', 44580)
# ('run: ', 17, '   # events ok so far: ', 47309)
# ('run: ', 18, '   # events ok so far: ', 50085)
# ('run: ', 19, '   # events ok so far: ', 52775)
# ('run: ', 20, '   # events ok so far: ', 55625)
# ('run: ', 21, '   # events ok so far: ', 58455)
# ('run: ', 22, '   # events ok so far: ', 61263)
# ('run: ', 23, '   # events ok so far: ', 64003)
# ('run: ', 24, '   # events ok so far: ', 66824)
# ('run: ', 25, '   # events ok so far: ', 69530)
# ('run: ', 26, '   # events ok so far: ', 72288)
# ('run: ', 27, '   # events ok so far: ', 75100)
# ('run: ', 28, '   # events ok so far: ', 77934)
# ('run: ', 29, '   # events ok so far: ', 80767)
# ('run: ', 30, '   # events ok so far: ', 83547)
# ('run: ', 31, '   # events ok so far: ', 86232)
# ('run: ', 32, '   # events ok so far: ', 89030)
# ('run: ', 33, '   # events ok so far: ', 91750)
# ('run: ', 34, '   # events ok so far: ', 94503)
# ('run: ', 35, '   # events ok so far: ', 97270)
# ('run: ', 36, '   # events ok so far: ', 100084)
# ('run: ', 37, '   # events ok so far: ', 102870)
# ('run: ', 38, '   # events ok so far: ', 105689)
# ('run: ', 39, '   # events ok so far: ', 108520)
# ('run: ', 40, '   # events ok so far: ', 111314)
# ('run: ', 41, '   # events ok so far: ', 114157)
# ('run: ', 42, '   # events ok so far: ', 116951)
# ('run: ', 43, '   # events ok so far: ', 119732)
# ('run: ', 44, '   # events ok so far: ', 122519)
# ('run: ', 45, '   # events ok so far: ', 125317)
# ('run: ', 46, '   # events ok so far: ', 128100)
# ('run: ', 47, '   # events ok so far: ', 130866)
# ('run: ', 48, '   # events ok so far: ', 133667)
# ('run: ', 49, '   # events ok so far: ', 136416)
# ('run: ', 50, '   # events ok so far: ', 139154)
# ('run: ', 51, '   # events ok so far: ', 141919)
#
# ('Total pasaron los cortes: ', 141919)

# %%
# total: 141919

# %%
2823*51
# Out:
# 143973

# %% [markdown]
# #### ttZ (part of ttV)

# %%
Folder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/ttZ/LO/Auto_Results_LHCO/'
datFolder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/DATAplus/dats-ttZ/'


ev = []



for iev in range(1,26):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0
        HT = 0 # hadronic activity HT, defined as the scalar sum of the pT of all reconstructed jets
        
        b_pt = []
        b_eta = []
        b_phi = []
        
        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                HT += inputevents[i]["jet"][k]["PT"]
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5
                                        
                                    b_pt.append(inputevents[i]["jet"][j]["PT"])
                                    b_eta.append(inputevents[i]["jet"][j]["eta"])
                                    b_phi.append(inputevents[i]["jet"][j]["phi"])


                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            
                            # jets, no 2 most energetic b-tagged jets
                            jets_rest = []
                            for j in range(inputevents[i].number()["jet"]):
                                jet = inputevents[i]["jet"][j]
                                if jet["PT"] > 20 and abs(jet["eta"]) < 2.8:
                                    # check if this jet was already included as the 2 most energetic b-tagged jets
                                    if not (jet["PT"] == b_pt[0] and jet["eta"] == b_eta[0] and jet["phi"] == b_phi[0]) and not (jet["PT"] == b_pt[1] and jet["eta"] == b_eta[1] and jet["phi"] == b_phi[1]):
                                        jets_rest.append((jet["PT"], jet["eta"], jet["phi"]))

                            ev.append(i)
                            
                            # SAVE: 
                            # hadronic info
                            with open(datFolder+'hadinfo.dat', 'a') as f:
                                f.write('%f %d %d\n' % (HT, num_jets, num_btag))
                                
                            # jets (no 2 most energetic b-tagged jets)
                            with open(datFolder + 'jets_rest.dat', 'a') as f:
                                f.write('%d ' % len(jets_rest)) # number
                                
                                for (pt, eta, phi) in jets_rest:
                                    f.write('%f %f %f ' % (pt, eta, phi))
                                f.write('\n')
                            
                            # b info:
                            with open(datFolder+'b1.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[0], b_eta[0], b_phi[0]))
                            with open(datFolder+'b2.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[1], b_eta[1], b_phi[1]))
                                
                            # tau
                            with open(datFolder+'tau.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["tau"][0]["PT"],inputevents[i]["tau"][0]["eta"],inputevents[i]["tau"][0]["phi"]))
                            
                            # MET (eta=0 by def, but I save phi because I have many jets)
                            with open(datFolder+'MET.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["MET"][0]["PT"],inputevents[i]["MET"][0]["eta"],inputevents[i]["MET"][0]["phi"]))
                            

 
    print('run: ',iev, '   # events ok so far: ' , len(ev))
print(' ')
print('Total pasaron los cortes: ', len(ev))
# Out:
# ('run: ', 1, '   # events ok so far: ', 659)
# ('run: ', 2, '   # events ok so far: ', 1319)
# ('run: ', 3, '   # events ok so far: ', 1974)
# ('run: ', 4, '   # events ok so far: ', 2611)
# ('run: ', 5, '   # events ok so far: ', 3306)
# ('run: ', 6, '   # events ok so far: ', 3956)
# ('run: ', 7, '   # events ok so far: ', 4620)
# ('run: ', 8, '   # events ok so far: ', 5229)
# ('run: ', 9, '   # events ok so far: ', 5873)
# ('run: ', 10, '   # events ok so far: ', 6514)
# ('run: ', 11, '   # events ok so far: ', 7200)
# ('run: ', 12, '   # events ok so far: ', 7841)
# ('run: ', 13, '   # events ok so far: ', 8423)
# ('run: ', 14, '   # events ok so far: ', 9084)
# ('run: ', 15, '   # events ok so far: ', 9743)
# ('run: ', 16, '   # events ok so far: ', 10382)
# ('run: ', 17, '   # events ok so far: ', 11046)
# ('run: ', 18, '   # events ok so far: ', 11706)
# ('run: ', 19, '   # events ok so far: ', 12338)
# ('run: ', 20, '   # events ok so far: ', 12973)
# ('run: ', 21, '   # events ok so far: ', 13614)
# ('run: ', 22, '   # events ok so far: ', 14266)
# ('run: ', 23, '   # events ok so far: ', 14894)
# ('run: ', 24, '   # events ok so far: ', 15558)
# ('run: ', 25, '   # events ok so far: ', 16178)
#
# ('Total pasaron los cortes: ', 16178)

# %%
# total: 16178

# %%
659*25
# Out:
# 16475

# %% [markdown]
# #### ttH

# %%
Folder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/ttH/LO/Auto_Results_LHCO/'
datFolder = '/media/andres/Elements/Leptoquarks-v3/backgrounds/DATAplus/dats-ttH/'


ev = []



for iev in range(1,26):
    
    inputevents = LHCO_reader.Events(f_name=Folder+"run_0"+str(iev)+".lhco")

    for i in range(len(inputevents)):

        num_es = 0
        num_mus = 0
        num_taus = 0
        num_jets = 0
        num_btag = 0
        index_tau = 0
        sT = 0
        mTtau = 0
        mTb1b2 = 0
        HT = 0 # hadronic activity HT, defined as the scalar sum of the pT of all reconstructed jets
        
        b_pt = []
        b_eta = []
        b_phi = []
        
        # to be considered e
        if inputevents[i].number()["electron"] > 0:
            for ll in range(inputevents[i].number()["electron"]):
                if inputevents[i]["electron"][ll]["PT"] > 10 and -2.47 < inputevents[i]["electron"][ll]["eta"] < 2.47:
                    num_es += 1
                    
        # to be considered mu
        if inputevents[i].number()["muon"] > 0:
            for ll in range(inputevents[i].number()["muon"]):
                if inputevents[i]["muon"][ll]["PT"] > 10 and -2.7 < inputevents[i]["muon"][ll]["eta"] < 2.7:
                    num_mus += 1
                    
        # to be considered tau
        if inputevents[i].number()["tau"] > 0:
            for ll in range(inputevents[i].number()["tau"]):
                if inputevents[i]["tau"][ll]["PT"] > 20 and (-2.5 < inputevents[i]["tau"][ll]["eta"] < -1.52 or -1.37 < inputevents[i]["tau"][ll]["eta"] < 1.37 or 1.52 < inputevents[i]["tau"][ll]["eta"] < 2.5):
                    num_taus += 1
                    index_tau = ll
                    
        # conditions A: 0 electrons, 0 muons, 1 tau and also EXTRA: require that the id tau has pT > 50 GeV
        #if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 50:
        if num_es == 0 and num_mus == 0 and num_taus == 1 and inputevents[i]["tau"][index_tau]["PT"] > 20:

            # MET
            if inputevents[i]["MET"][0]["PT"] > 280:

                # at least 2 jets
                if inputevents[i].number()["jet"] > 1:
                    
                    # transverse mass of leading tau (that was id as tau)
                    mTtau = (2 * inputevents[i]["tau"][index_tau]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["tau"][index_tau]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5

                    # condition B: mTtau > 150 GeV
                    #if mTtau > 150:
                    if mTtau > 0:
                        
                        # compute sT using the tau that was id as tau
                        sT = inputevents[i]["tau"][index_tau]["PT"]
                        
                        # add to sT the 2 leading jets (id as jets)
                        for k in range(inputevents[i].number()["jet"]):
                            if -2.8 < inputevents[i]["jet"][k]["eta"] < 2.8 and inputevents[i]["jet"][k]["PT"] > 20:
                                num_jets += 1
                                HT += inputevents[i]["jet"][k]["PT"]
                                if num_jets < 3:
                                    sT = sT + inputevents[i]["jet"][k]["PT"]

                        # check # of b-jets (id as b-tag, tighter request than jets)
                        for j in range(inputevents[i].number()["jet"]):
                            if inputevents[i]["jet"][j]["btag"] == 1 and inputevents[i]["jet"][j]["PT"] > 20 and -2.5 < inputevents[i]["jet"][j]["eta"] < 2.5:
                                num_btag += 1
                                if num_btag < 3:
                                    mTb1b2 += (2 * inputevents[i]["jet"][j]["PT"] * inputevents[i]["MET"][0]["PT"] * (1.0- np.cos(inputevents[i]["jet"][j]["phi"]-inputevents[i]["MET"][0]["phi"])) )**0.5
                                        
                                    b_pt.append(inputevents[i]["jet"][j]["PT"])
                                    b_eta.append(inputevents[i]["jet"][j]["eta"])
                                    b_phi.append(inputevents[i]["jet"][j]["phi"])


                        # conditions C: 2 or more jets, 2 or more b-jets, sT > 600 GeV and mTb1b2 > 700 GeV
                        #if num_jets > 1 and num_btag > 1 and sT > 600 and mTb1b2 > 700:
                        if num_jets > 1 and num_btag > 1 and sT > 0 and mTb1b2 > 0:
                            
                            # jets, no 2 most energetic b-tagged jets
                            jets_rest = []
                            for j in range(inputevents[i].number()["jet"]):
                                jet = inputevents[i]["jet"][j]
                                if jet["PT"] > 20 and abs(jet["eta"]) < 2.8:
                                    # check if this jet was already included as the 2 most energetic b-tagged jets
                                    if not (jet["PT"] == b_pt[0] and jet["eta"] == b_eta[0] and jet["phi"] == b_phi[0]) and not (jet["PT"] == b_pt[1] and jet["eta"] == b_eta[1] and jet["phi"] == b_phi[1]):
                                        jets_rest.append((jet["PT"], jet["eta"], jet["phi"]))

                            ev.append(i)
                            
                            # SAVE: 
                            # hadronic info
                            with open(datFolder+'hadinfo.dat', 'a') as f:
                                f.write('%f %d %d\n' % (HT, num_jets, num_btag))
                                
                            # jets (no 2 most energetic b-tagged jets)
                            with open(datFolder + 'jets_rest.dat', 'a') as f:
                                f.write('%d ' % len(jets_rest)) # number
                                
                                for (pt, eta, phi) in jets_rest:
                                    f.write('%f %f %f ' % (pt, eta, phi))
                                f.write('\n')
                            
                            # b info:
                            with open(datFolder+'b1.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[0], b_eta[0], b_phi[0]))
                            with open(datFolder+'b2.dat', 'a') as f:
                                f.write('%f %f %f\n' % (b_pt[1], b_eta[1], b_phi[1]))
                                
                            # tau
                            with open(datFolder+'tau.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["tau"][0]["PT"],inputevents[i]["tau"][0]["eta"],inputevents[i]["tau"][0]["phi"]))
                            
                            # MET (eta=0 by def, but I save phi because I have many jets)
                            with open(datFolder+'MET.dat', 'a') as f:
                                f.write('%f %f %f\n' % (inputevents[i]["MET"][0]["PT"],inputevents[i]["MET"][0]["eta"],inputevents[i]["MET"][0]["phi"]))
                            

 
    print('run: ',iev, '   # events ok so far: ' , len(ev))
print(' ')
print('Total pasaron los cortes: ', len(ev))
# Out:
# ('run: ', 1, '   # events ok so far: ', 480)
# ('run: ', 2, '   # events ok so far: ', 979)
# ('run: ', 3, '   # events ok so far: ', 1466)
# ('run: ', 4, '   # events ok so far: ', 1961)
# ('run: ', 5, '   # events ok so far: ', 2448)
# ('run: ', 6, '   # events ok so far: ', 2924)
# ('run: ', 7, '   # events ok so far: ', 3420)
# ('run: ', 8, '   # events ok so far: ', 3894)
# ('run: ', 9, '   # events ok so far: ', 4361)
# ('run: ', 10, '   # events ok so far: ', 4864)
# ('run: ', 11, '   # events ok so far: ', 5336)
# ('run: ', 12, '   # events ok so far: ', 5860)
# ('run: ', 13, '   # events ok so far: ', 6329)
# ('run: ', 14, '   # events ok so far: ', 6807)
# ('run: ', 15, '   # events ok so far: ', 7304)
# ('run: ', 16, '   # events ok so far: ', 7782)
# ('run: ', 17, '   # events ok so far: ', 8301)
# ('run: ', 18, '   # events ok so far: ', 8775)
# ('run: ', 19, '   # events ok so far: ', 9266)
# ('run: ', 20, '   # events ok so far: ', 9760)
# ('run: ', 21, '   # events ok so far: ', 10247)
# ('run: ', 22, '   # events ok so far: ', 10694)
# ('run: ', 23, '   # events ok so far: ', 11121)
# ('run: ', 24, '   # events ok so far: ', 11599)
# ('run: ', 25, '   # events ok so far: ', 12068)
#
# ('Total pasaron los cortes: ', 12068)

# %%
# total: 12068

# %%
480*25
# Out:
# 12000
