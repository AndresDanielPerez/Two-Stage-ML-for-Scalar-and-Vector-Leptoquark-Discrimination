# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mainfolder = '/content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec

import os
import joblib  # to save the scaler

from numba import njit # for the LQ mass reconstruction

from scipy.optimize import fsolve, minimize
from scipy import stats
from scipy.stats import poisson
from scipy.stats import ks_2samp
from scipy.stats import anderson_ksamp
from scipy.stats import wasserstein_distance
from scipy.stats import chisquare
from scipy.interpolate import interp1d

import math
import random

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc, accuracy_score
from sklearn.metrics import mean_squared_error, r2_score

from xgboost import XGBRegressor, XGBClassifier
import xgboost as xgb

# %% [markdown]
# # LOAD DATA

# %% [markdown]
# ## Background

# %%
CHs_selected = ["tt", "singletP1", "singletP2", "Wbbjets", "ttW", "ttZ", "ttH"]


df_B_all = {}
X_B_all = {}


output_folder = mainfolder + "../DATA/backgrounds/data_df/"

for CH_sel in CHs_selected:
    # Read the file
    if CH_sel == 'singletP2':
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-singlet-comp/df_' + CH_sel + ".csv"
    else:
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-' + CH_sel + '/df_' + CH_sel + ".csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_B_all[CH_sel] = df_temp
    X_B_all[CH_sel] = df_temp[feats_label].values

    # Print
    print(f"X_{CH_sel}.shape: {X_B_all[CH_sel].shape}")
# Out:
# X_tt.shape: (826022, 53)
# X_singletP1.shape: (179677, 53)
# X_singletP2.shape: (94219, 53)
# X_Wbbjets.shape: (162448, 53)
# X_ttW.shape: (141919, 53)
# X_ttZ.shape: (16178, 53)
# X_ttH.shape: (12068, 53)

# %% [markdown]
# ## Signal SLQ

# %%
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2200]
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]


df_SLQ_all = {}
X_SLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_SLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-SLQ-' + str(mass_sel) + 'GeV/df_SLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_SLQ_all[mass_sel] = df_temp
    X_SLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_SLQ_{mass_sel}GeV.shape: {X_SLQ_all[mass_sel].shape}")
# Out:
# X_SLQ_1000GeV.shape: (267452, 53)
# X_SLQ_1100GeV.shape: (271062, 53)
# X_SLQ_1200GeV.shape: (534247, 53)
# X_SLQ_1300GeV.shape: (196510, 53)
# X_SLQ_1400GeV.shape: (506381, 53)
# X_SLQ_1500GeV.shape: (185940, 53)
# X_SLQ_1600GeV.shape: (481827, 53)
# X_SLQ_1700GeV.shape: (173573, 53)
# X_SLQ_1800GeV.shape: (301687, 53)
# X_SLQ_1900GeV.shape: (64690, 53)

# %% [markdown]
# ## Signal VLQ

# %%
masses_VLQ = [1200, 1500, 1400, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
masses_VLQ = [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]


df_VLQ_all = {}
X_VLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_VLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-VLQ-' + str(mass_sel) + 'GeV/df_VLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_VLQ_all[mass_sel] = df_temp
    X_VLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_VLQ_{mass_sel}GeV.shape: {X_VLQ_all[mass_sel].shape}")
# Out:
# X_VLQ_1400GeV.shape: (139696, 53)
# X_VLQ_1500GeV.shape: (293700, 53)
# X_VLQ_1600GeV.shape: (134774, 53)
# X_VLQ_1700GeV.shape: (192819, 53)
# X_VLQ_1800GeV.shape: (127670, 53)
# X_VLQ_1900GeV.shape: (75898, 53)
# X_VLQ_2000GeV.shape: (184097, 53)
# X_VLQ_2100GeV.shape: (72762, 53)
# X_VLQ_2200GeV.shape: (232166, 53)
# X_VLQ_2300GeV.shape: (64705, 53)

# %% [markdown]
# # Cross Section

# %%
Lum = 3000

# %%
# -------------------------
# cross sections
# -------------------------
k_LQ = 1.8877462860822058

xsec_file_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV.txt'

xsec_data_14TeV = np.loadtxt(xsec_file_14TeV, comments='#')

# columns: 0=mass, 1=SLQ, 2=VLQ
masses_14TeV = xsec_data_14TeV[:,0].astype(int)
fidxsec_SLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,1]*k_LQ))
fidxsec_VLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,2]*k_LQ))


masses_SLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]
masses_VLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]

fidxsec_SLQ_non0_14TeV = [fidxsec_SLQ_14TeV[ii] for ii in masses_SLQ_14TeV]
fidxsec_VLQ_non0_14TeV = [fidxsec_VLQ_14TeV[ii] for ii in masses_VLQ_14TeV]


#  interpolate
f_xsec_SLQ_log_14TeV = interp1d(masses_SLQ_14TeV, np.log10(fidxsec_SLQ_non0_14TeV), kind='linear', fill_value="extrapolate")
f_xsec_VLQ_log_14TeV = interp1d(masses_VLQ_14TeV, np.log10(fidxsec_VLQ_non0_14TeV), kind='linear', fill_value="extrapolate")



# -------------------------
# cross sections
# -------------------------
xsec_file_betas_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV-betas.txt'

xsec_data_betas_14TeV = np.loadtxt(xsec_file_betas_14TeV, comments='#')

# columns: 0=beta, 1,...=SLQ, -1=ratio=fid_xsec(beta)/fid_xsec(beta=0.5)
betas = xsec_data_betas_14TeV[:,0]
ratio_mean_14TeV = xsec_data_betas_14TeV[:,-1]

#  interpolate
f_ratio_SLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")
f_ratio_VLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")



# FINAL FUNCTIONS
def fid_xsec_SLQ_14TeV(mass, beta):
    return 10**f_xsec_SLQ_log_14TeV(mass) * f_ratio_SLQ_log_14TeV(beta)

def fid_xsec_VLQ_14TeV(mass, beta):
    return 10**f_xsec_VLQ_log_14TeV(mass) * f_ratio_VLQ_log_14TeV(beta)

# %%
masses = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

beta = 0.5

fidxsec_SLQ = dict(zip(masses, fid_xsec_SLQ_14TeV(masses, beta)))
fidxsec_VLQ = dict(zip(masses, fid_xsec_VLQ_14TeV(masses, beta)))


print('masses: ', masses)
print(fidxsec_SLQ[1200], '[fb]')
print(fidxsec_VLQ[1600], '[fb]')
# Out:
# masses:  [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# 0.2474345231655215 [fb]
# 0.26523144909845914 [fb]

# %%
# -----------------------------------
# LQs number and fid cross sections
# -----------------------------------


for m_it in masses_SLQ:
    print(f"# eventos SLQ {m_it} GeV:", len(X_SLQ_all[m_it]), "  fid_xsec = ", fidxsec_SLQ[m_it], "[fb]")

print(" ")
for m_it in masses_VLQ:
    print(f"# eventos VLQ {m_it} GeV:", len(X_VLQ_all[m_it]), "  fid_xsec = ", fidxsec_VLQ[m_it], "[fb]")
# Out:
# # eventos SLQ 1000 GeV: 267452   fid_xsec =  0.7748869590226768 [fb]
# # eventos SLQ 1100 GeV: 271062   fid_xsec =  0.4378741659574781 [fb]
# # eventos SLQ 1200 GeV: 534247   fid_xsec =  0.2474345231655215 [fb]
# # eventos SLQ 1300 GeV: 196510   fid_xsec =  0.13982063344676618 [fb]
# # eventos SLQ 1400 GeV: 506381   fid_xsec =  0.07901003177465696 [fb]
# # eventos SLQ 1500 GeV: 185940   fid_xsec =  0.04581708431512623 [fb]
# # eventos SLQ 1600 GeV: 481827   fid_xsec =  0.02656884408205899 [fb]
# # eventos SLQ 1700 GeV: 173573   fid_xsec =  0.015388910834251649 [fb]
# # eventos SLQ 1800 GeV: 301687   fid_xsec =  0.00891339404654277 [fb]
# # eventos SLQ 1900 GeV: 64690   fid_xsec =  0.005260680024994185 [fb]
#
# # eventos VLQ 1400 GeV: 139696   fid_xsec =  0.7980588250285466 [fb]
# # eventos VLQ 1500 GeV: 293700   fid_xsec =  0.46007640520693416 [fb]
# # eventos VLQ 1600 GeV: 134774   fid_xsec =  0.26523144909845914 [fb]
# # eventos VLQ 1700 GeV: 192819   fid_xsec =  0.15538479377277226 [fb]
# # eventos VLQ 1800 GeV: 127670   fid_xsec =  0.09103156589414883 [fb]
# # eventos VLQ 1900 GeV: 75898   fid_xsec =  0.054409658330071796 [fb]
# # eventos VLQ 2000 GeV: 184097   fid_xsec =  0.03252070741085026 [fb]
# # eventos VLQ 2100 GeV: 72762   fid_xsec =  0.019810348629947013 [fb]
# # eventos VLQ 2200 GeV: 232166   fid_xsec =  0.012067692989639755 [fb]
# # eventos VLQ 2300 GeV: 64705   fid_xsec =  0.007351168665050899 [fb]

# %%
# FOR 14 TeV

k_fakett = 1.1053030485310749
crossfid_fakett = 0.244
k_tt = 1.2593273872014419
crossfid_tt = (7.74198*k_tt) + (crossfid_fakett * k_fakett)


fidxsec_SM = {'tt': crossfid_tt,
              'singletP1': 0.632632 * 3.440676833094312,
              'singletP2': 0.3182704 * 3.440676833094312,
              'Wbbjets': 1.6542420183645095 * 0.9781509289273502,
              'ttW': 0.03683196 * 3.056401327463198,
              'ttZ': 0.0715444 * 3.056401327463198,
              'ttH': 0.03630132 * 2.2127445612386474
              }

for ch_it in fidxsec_SM:
    print(f"# eventos {ch_it}:", len(X_B_all[ch_it]), "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]")
# Out:
# # eventos tt: 826022   fid_xsec =  10.019381389007401 [fb]
# # eventos singletP1: 179677   fid_xsec =  2.1766822662741205 [fb]
# # eventos singletP2: 94219   fid_xsec =  1.09506559193966 [fb]
# # eventos Wbbjets: 162448   fid_xsec =  1.6180983669338997 [fb]
# # eventos ttW: 141919   fid_xsec =  0.1125732514370714 [fb]
# # eventos ttZ: 16178   fid_xsec =  0.218668399132558 [fb]
# # eventos ttH: 12068   fid_xsec =  0.08032554839578374 [fb]

# %%
# MAX SM dataset
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])


weigth_gen_SM = {}

for ch_it in fidxsec_SM:

    print(f"fraction of {ch_it}:", fidxsec_SM[ch_it] / totalcrossSM )

    weigth_gen_SM[ch_it] = len(X_B_all[ch_it]) / (fidxsec_SM[ch_it] / totalcrossSM)

print('\nchannel limiting the SM background: ', min(weigth_gen_SM, key=weigth_gen_SM.get) , '\n')


max_evs_SM = {}

for ch_it in fidxsec_SM:
    max_evs_SM[ch_it] = round( min(weigth_gen_SM.values()) * (fidxsec_SM[ch_it] / totalcrossSM) )
    print(f"# eventos {ch_it} (max):", max_evs_SM[ch_it])

max_SM_dataset = sum(max_evs_SM.values())
print('\nmax SM dataset length: ', max_SM_dataset )
# Out:
# fraction of tt: 0.6539726894865112
# fraction of singletP1: 0.14207371698562551
# fraction of singletP2: 0.07147576906400852
# fraction of Wbbjets: 0.10561451848099845
# fraction of ttW: 0.0073477422555561795
# fraction of ttZ: 0.014272653723245071
# fraction of ttH: 0.005242910004055022
#
# channel limiting the SM background:  ttZ
#
# # eventos tt (max): 741276
# # eventos singletP1 (max): 161040
# # eventos singletP2 (max): 81018
# # eventos Wbbjets (max): 119714
# # eventos ttW (max): 8329
# # eventos ttZ (max): 16178
# # eventos ttH (max): 5943
#
# max SM dataset length:  1133498

# %% [markdown]
# ## Number of events to get a balanced dataset

# %%
# -------------------------
# Step 1: minimim number of events in LQs (selected mass)
# -------------------------

num_data_SLQ = [len(X_SLQ_all[m_it]) for m_it in masses_SLQ]

num_data_VLQ = [len(X_VLQ_all[m_it]) for m_it in masses_VLQ]


max_SM_dataset = min(1000000, max_SM_dataset)

num_data_NP = min(int(max_SM_dataset / (len(masses_SLQ) + len(masses_VLQ))) , min(num_data_SLQ + num_data_VLQ) )

print('SIGNAL: # events per-class chosen =', num_data_NP)



# -------------------------
# Step 2: background total fid_xsec
# -------------------------
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])



# -------------------------
# Step 3: number of events per chanel, proportional to xsec
# -------------------------
num_data_SM_dict = {}
for ch_it in fidxsec_SM:
    if ch_it == 'tt':
        # set at the end to have exactly the same # events (otherwise can be a difference of 1 due to rounding)
        continue
    fraction = fidxsec_SM[ch_it]/totalcrossSM
    num_data_SM_dict[ch_it] = round(num_data_NP * fraction * (len(masses_SLQ) + len(masses_VLQ)) )

# Set tt such that the total matches num_data_NP
num_data_SM_dict['tt'] = num_data_NP * (len(masses_SLQ) + len(masses_VLQ)) - sum([v for k,v in num_data_SM_dict.items() if k != 'tt'])




print('\nBACKGROUND events chosen (weighted by xsec):')
for ch_it in fidxsec_SM:
    print(f'# {ch_it}: {num_data_SM_dict[ch_it]}')
print('# total B events chosen: ', sum(num_data_SM_dict.values()))
# Out:
# SIGNAL: # events per-class chosen = 50000
#
# BACKGROUND events chosen (weighted by xsec):
# # tt: 653971
# # singletP1: 142074
# # singletP2: 71476
# # Wbbjets: 105615
# # ttW: 7348
# # ttZ: 14273
# # ttH: 5243
# # total B events chosen:  1000000

# %%
# keep just the events needed

for m_it in masses_SLQ:
    X_SLQ_all[m_it] = X_SLQ_all[m_it][:num_data_NP]
    df_SLQ_all[m_it] = df_SLQ_all[m_it][:num_data_NP]

print(" ")
for m_it in masses_VLQ:
    X_VLQ_all[m_it] = X_VLQ_all[m_it][:num_data_NP]
    df_VLQ_all[m_it] = df_VLQ_all[m_it][:num_data_NP]

print("")
for ch_it in fidxsec_SM:
    X_B_all[ch_it] = X_B_all[ch_it][:num_data_SM_dict[ch_it]]
    df_B_all[ch_it] = df_B_all[ch_it][:num_data_SM_dict[ch_it]]

# %%
B_expected = round(Lum * totalcrossSM)    # luminosity * cross * aceptance
print('B_expected: ', B_expected)

for ch_it in fidxsec_SM:
    print(f" channel {ch_it}:", "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]", " B_exp_ch: ", round(Lum * fidxsec_SM[ch_it]) )



S_expected_SLQ = []

for m_it in masses_SLQ:
    S_expected_SLQ.append( round(Lum * fidxsec_SLQ[m_it]) )

print('\nmasses:           ', masses_SLQ)
print('S_expected (SLQ): ', S_expected_SLQ)    # luminosity * cross * aceptance



S_expected_VLQ = []

for m_it in masses_VLQ:
    S_expected_VLQ.append( round(Lum * fidxsec_VLQ[m_it]) )

print('\nmasses:           ', masses_VLQ)
print('S_expected (VLQ): ', S_expected_VLQ)    # luminosity * cross * aceptance
# Out:
# B_expected:  45962
#  channel tt:   fid_xsec =  10.019381389007401 [fb]  B_exp_ch:  30058
#  channel singletP1:   fid_xsec =  2.1766822662741205 [fb]  B_exp_ch:  6530
#  channel singletP2:   fid_xsec =  1.09506559193966 [fb]  B_exp_ch:  3285
#  channel Wbbjets:   fid_xsec =  1.6180983669338997 [fb]  B_exp_ch:  4854
#  channel ttW:   fid_xsec =  0.1125732514370714 [fb]  B_exp_ch:  338
#  channel ttZ:   fid_xsec =  0.218668399132558 [fb]  B_exp_ch:  656
#  channel ttH:   fid_xsec =  0.08032554839578374 [fb]  B_exp_ch:  241
#
# masses:            [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_expected (SLQ):  [2325, 1314, 742, 419, 237, 137, 80, 46, 27, 16]
#
# masses:            [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_expected (VLQ):  [2394, 1380, 796, 466, 273, 163, 98, 59, 36, 22]

# %%
plt.plot(masses_SLQ, S_expected_SLQ, color='red', label='SLQ')
plt.plot(masses_VLQ, S_expected_VLQ, color='green', label='VLQ')
# plt.yscale('log')
plt.xlabel("$m_{LQ}$ [GeV]", fontsize=16)
plt.ylabel("S expected", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # 1. DATA FORMAT for CLASSIFIERS

# %%
# to save memory
del X_SLQ_all
del X_VLQ_all
del X_B_all

# %%
# ---------------------------
# Concatenate all for normalization
# ---------------------------
df_SM = pd.concat(df_B_all.values(), ignore_index=True)
del df_B_all

df_all = pd.concat([df_SM] + list(df_SLQ_all.values()) + list(df_VLQ_all.values()), ignore_index=True)

# ---------------------------
# Normalization
# ---------------------------
scaler = MinMaxScaler()
scaler.fit(df_all)

# Save the scaler
# joblib.dump(scaler, mainfolder + 'saved-models/scaler_features.pkl')

# Apply normalization
df_SM_norm = pd.DataFrame(scaler.transform(df_SM), columns=df_SM.columns)
df_SLQ_norm = {mass: pd.DataFrame(scaler.transform(df_SLQ_all[mass]), columns=df_SLQ_all[mass].columns) for mass in df_SLQ_all}
df_VLQ_norm = {mass: pd.DataFrame(scaler.transform(df_VLQ_all[mass]), columns=df_VLQ_all[mass].columns) for mass in df_VLQ_all}






# ---------------------------
# Divide datasets into train/val/test/pseudo
# ---------------------------
def split_class(df, test_ratio=0.25, val_ratio=0.10, pseudo_ratio=0.25):
    X = df.values
    aux_val_ratio = val_ratio / (1 - test_ratio)
    aux_pseudo_ratio = pseudo_ratio / (1 - test_ratio - val_ratio)

    X_aux, X_test = train_test_split(X, test_size=test_ratio, random_state=42, shuffle=True)
    X_aux2, X_val = train_test_split(X_aux, test_size=aux_val_ratio, random_state=42, shuffle=True)
    X_train, X_pseudo = train_test_split(X_aux2, test_size=aux_pseudo_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, X_pseudo



# ---------------------------
# Divide the datasets
# ---------------------------
split_SM = split_class(df_SM_norm)
split_SLQ = {mass: split_class(df_SLQ_norm[mass]) for mass in df_SLQ_norm}
split_VLQ = {mass: split_class(df_VLQ_norm[mass]) for mass in df_VLQ_norm}



# Example of how to use them
X_train_SM, X_val_SM, X_test_SM, X_pseudo_SM = split_SM
X_train_SLQ1200, X_val_SLQ1200, X_test_SLQ1200, X_pseudo_SLQ1200 = split_SLQ[1200]
X_train_VLQ1600, X_val_VLQ1600, X_test_VLQ1600, X_pseudo_VLQ1600 = split_VLQ[1600]

print('')
print('X_train_SM : ', X_train_SM.shape)
print('X_val_SM : ', X_val_SM.shape)
print('X_test_SM : ', X_test_SM.shape)
print('X_pseudo_SM : ', X_pseudo_SM.shape)

print('')
print('X_train_SLQ1200 : ', X_train_SLQ1200.shape)
print('X_val_SLQ1200 : ', X_val_SLQ1200.shape)
print('X_test_SLQ1200 : ', X_test_SLQ1200.shape)
print('X_pseudo_SLQ1200 : ', X_pseudo_SLQ1200.shape)

print('')
print('X_train_VLQ1600 : ', X_train_VLQ1600.shape)
print('X_val_VLQ1600 : ', X_val_VLQ1600.shape)
print('X_test_VLQ1600 : ', X_test_VLQ1600.shape)
print('X_pseudo_VLQ1600 : ', X_pseudo_VLQ1600.shape)
# Out:
# X_train_SM :  (400000, 53)
# X_val_SM :  (100000, 53)
# X_test_SM :  (250000, 53)
# X_pseudo_SM :  (250000, 53)
#
# X_train_SLQ1200 :  (20000, 53)
# X_val_SLQ1200 :  (5000, 53)
# X_test_SLQ1200 :  (12500, 53)
# X_pseudo_SLQ1200 :  (12500, 53)
#
# X_train_VLQ1600 :  (20000, 53)
# X_val_VLQ1600 :  (5000, 53)
# X_test_VLQ1600 :  (12500, 53)
# X_pseudo_VLQ1600 :  (12500, 53)

# %%
# to save memory
del df_SM
del df_SLQ_all
del df_VLQ_all

# %% [markdown]
# ## SM vs LQ

# %%
# --- 1. Combinar todos los LQ en un solo DataFrame ---
df_LQ_list = list(df_SLQ_norm.values()) + list(df_VLQ_norm.values())
df_LQ_norm = pd.concat(df_LQ_list, ignore_index=True)


# --- 2. Igualar número de eventos con SM ---
n_SM = len(df_SM_norm)
n_LQ = len(df_LQ_norm)
n_events = min(n_SM, n_LQ)

print(n_SM, n_LQ, n_events)

df_SM_sample = df_SM_norm.sample(n=n_events, random_state=42)
df_LQ_sample = df_LQ_norm.sample(n=n_events, random_state=42)


# --- 3. Crear X, y ---
X = pd.concat([df_SM_sample, df_LQ_sample], ignore_index=True)
y = np.hstack([np.zeros(n_events), np.ones(n_events)])  # 0=SM, 1=LQ


def split_class(X, Y, test_ratio=0.25, val_ratio=0.25):

    aux_val_ratio = val_ratio / (1 - test_ratio)

    X_aux, X_test, Y_aux, Y_test = train_test_split(X, Y, test_size=test_ratio, random_state=42, shuffle=True)
    X_train, X_val, Y_train, Y_val = train_test_split(X_aux, Y_aux, test_size=val_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, Y_train, Y_val, Y_test


# Divide into train, validation and test
X_train, X_val, X_test, y_train, y_val, y_test = split_class(X, y)


print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# 1000000 1000000 1000000
# (1125000, 53)
# (375000, 53)
# (500000, 53)

# %%
# LOAD
xgb_clf = XGBClassifier()
xgb_clf.load_model(mainfolder + "saved-models/modelA_SMLQ_14TeV_full.json")


# Evaluate
y_pred = xgb_clf.predict(X_test)
y_pred_proba = xgb_clf.predict_proba(X_test)[:,1]

acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)
print(f"Accuracy: {acc:.3f}, ROC-AUC: {auc:.5f}")

# ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC={auc:.3f}')
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SM vs LQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + "saved-results/ROC_classA.pdf", bbox_inches='tight')
plt.show()


# Feature importance
keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$'])

feature_important = xgb_clf.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=14).remove()
plt.title(r'SM vs LQ', fontsize=14)
# plt.savefig(mainfolder + "saved-results/XG_feature_importance_classA.pdf", bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Accuracy: 0.973, ROC-AUC: 0.99660
# [52, 47, 35, 17, 15, 36, 50, 46, 32, 45, 6, 37, 51, 38, 12]

# %% [markdown]
# ## Compute S_pred for pseudo-experiments

# %%
# output of all the background events
scores_B = xgb_clf.predict_proba( df_SM_norm )[:, 1]

# output of all the signal events (for the pdf of the general LQ case)
scores_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]

# %%
# output of all the signal events per class (to build the pseudo-experiments)
scores_S_SLQ = {mass: xgb_clf.predict_proba(df_SLQ_norm[mass])[:, 1] for mass in df_SLQ_norm}
scores_S_VLQ = {mass: xgb_clf.predict_proba(df_VLQ_norm[mass])[:, 1] for mass in df_VLQ_norm}

# %%
def Z_asimov(S, B):
    if S <= 0 or B <= 0:
        return 0
    return np.sqrt(2 * ((S+B) * np.log(1 + S/B) - S))

# %% [markdown]
# ###### binned likelihood fit

# %%
bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scores_B, bins=bins, density=True)
hist_S, _ = np.histogram(scores_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %%
# FOR SLQ #

S_expected = S_expected_SLQ


n_pseudo = 1000


# to save
S_mean_fit_N = {}
S_std_fit_N  = {}
Z_fit_N = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_N[S_it] = []
    S_std_fit_N[S_it]  = []
    Z_fit_N[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_SLQ[masses_SLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_N[S_it].append(mean_muS)
    S_std_fit_N[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_N[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  2325
# S = 1861.7685800293827 +- 49.89854959093912
# Z = 76.5941754634679
#
#
# ----------------
# S_expected =  1314
# S = 1144.4181470899089 +- 39.90232140250016
# Z = 55.07246835160773
#
#
# ----------------
# S_expected =  742
# S = 691.5087181067555 +- 32.89318355561731
# Z = 39.43500212540729
#
#
# ----------------
# S_expected =  419
# S = 406.7398708161937 +- 25.13407213461056
# Z = 26.170600870340717
#
#
# ----------------
# S_expected =  237
# S = 238.19477686535595 +- 20.062421217126964
# Z = 15.789533690244316
#
#
# ----------------
# S_expected =  137
# S = 140.83962761334334 +- 16.741544233866907
# Z = 10.709581845266316
#
#
# ----------------
# S_expected =  80
# S = 84.1326353407099 +- 15.139716444769794
# Z = 6.406955953724034
#
#
# ----------------
# S_expected =  46
# S = 49.87661804653299 +- 13.836416248768007
# Z = 2.594317394781894
#
#
# ----------------
# S_expected =  27
# S = 29.786532063369577 +- 12.677260658348205
# Z = 3.295463260266425
#
#
# ----------------
# S_expected =  16
# S = 17.577025989101674 +- 11.527667341190908
# Z = 1.9081705419068091

# %%
# FOR VLQ #

S_expected = S_expected_SLQ # same number of events


n_pseudo = 1000


# to save
S_mean_fit_V = {}
S_std_fit_V  = {}
Z_fit_V = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_V[S_it] = []
    S_std_fit_V[S_it]  = []
    Z_fit_V[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_VLQ[masses_VLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_V[S_it].append(mean_muS)
    S_std_fit_V[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_V[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  2325
# S = 2267.4125040756016 +- 66.15733440189975
# Z = 91.64764495633172
#
#
# ----------------
# S_expected =  1314
# S = 1295.1137467234669 +- 37.40897192304798
# Z = 62.584085025116714
#
#
# ----------------
# S_expected =  742
# S = 741.5694252733347 +- 29.744341527923687
# Z = 42.58339620878821
#
#
# ----------------
# S_expected =  419
# S = 424.28507521738203 +- 23.730603057090416
# Z = 27.86417794040888
#
#
# ----------------
# S_expected =  237
# S = 242.59897831280685 +- 19.54446110129825
# Z = 17.78402301923322
#
#
# ----------------
# S_expected =  137
# S = 141.24043032934244 +- 17.07666981150608
# Z = 10.093698612926483
#
#
# ----------------
# S_expected =  80
# S = 82.55114150558882 +- 14.82463672243568
# Z = 5.488625759718754
#
#
# ----------------
# S_expected =  46
# S = 47.65702515838112 +- 13.898908875867669
# Z = 2.6975394797011325
#
#
# ----------------
# S_expected =  27
# S = 28.326110918227226 +- 12.615469509544905
# Z = 2.37901635078646
#
#
# ----------------
# S_expected =  16
# S = 17.432296814740294 +- 11.216261477666018
# Z = 2.006141929750775

# %%
# mean between scalar and vector
S_mean_fit_both = []
S_std_fit_both = []

for i in S_mean_fit_N:

    S_mean_fit_both.append( np.mean([S_mean_fit_N[i][0], S_mean_fit_V[i][0]]) )
    S_std_fit_both.append( np.mean([S_std_fit_N[i][0], S_std_fit_V[i][0]]) )

# %% [markdown]
# # SLQ vs VLQ (include Poisson S_expected)

# %%
X_train_list, y_train_list, S_poiss_train_list = [], [], []
X_val_list,   y_val_list,   S_poiss_val_list   = [], [], []
X_test_list,  y_test_list,  S_poiss_test_list  = [], [], []

for iit, m_s in enumerate(masses_SLQ):

        # -------- SLQ --------
        X_train_s, X_val_s, X_test_s, _ = split_SLQ[masses_SLQ[iit]]

        X_train_list.append(X_train_s)
        y_train_list.append(np.zeros(len(X_train_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_s))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_s)
        y_val_list.append(np.zeros(len(X_val_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_s))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_s)
        y_test_list.append(np.zeros(len(X_test_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_s))
        S_poiss_test_list.append(poisson_samples)


# for iit, m_v in enumerate(masses_VLQ):

        # -------- VLQ --------
        X_train_v, X_val_v, X_test_v, _ = split_VLQ[masses_VLQ[iit]]

        X_train_list.append(X_train_v)
        y_train_list.append(np.ones(len(X_train_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_v))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_v)
        y_val_list.append(np.ones(len(X_val_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_v))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_v)
        y_test_list.append(np.ones(len(X_test_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_v))
        S_poiss_test_list.append(poisson_samples)


# Concatenate
# TRAIN
X_train_spin = np.vstack(X_train_list)
y_train_spin = np.concatenate(y_train_list)
S_poiss_train = np.concatenate(S_poiss_train_list)

# add S_poiss as extra feature
X_train_spin = np.column_stack([X_train_spin, S_poiss_train])


# VAL
X_val_spin = np.vstack(X_val_list)
y_val_spin = np.concatenate(y_val_list)
S_poiss_val = np.concatenate(S_poiss_val_list)

X_val_spin = np.column_stack([X_val_spin, S_poiss_val])


# TEST
X_test_spin = np.vstack(X_test_list)
y_test_spin = np.concatenate(y_test_list)
S_poiss_test = np.concatenate(S_poiss_test_list)

X_test_spin = np.column_stack([X_test_spin, S_poiss_test])


print(X_train_spin.shape)
print(X_val_spin.shape)
print(X_test_spin.shape)
# Out:
# (400000, 54)
# (100000, 54)
# (250000, 54)

# %%
classifier_spin = XGBClassifier(
    n_estimators=1500,
    learning_rate=0.1,
    max_depth=5,
    reg_lambda=1.0,
    reg_alpha=0.0,
    gamma=0.0,
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    random_state=42,
    early_stopping_rounds=50
)

classifier_spin.fit(
    X_train_spin, y_train_spin,
    eval_set=[(X_train_spin, y_train_spin),
              (X_val_spin, y_val_spin)],
    verbose=True
)

classifier_spin.save_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta05.json")
# Out:
# [0]	validation_0-logloss:0.68605	validation_1-logloss:0.68615
# [1]	validation_0-logloss:0.68011	validation_1-logloss:0.68030
# [2]	validation_0-logloss:0.67470	validation_1-logloss:0.67492
# [3]	validation_0-logloss:0.67018	validation_1-logloss:0.67046
# [4]	validation_0-logloss:0.66614	validation_1-logloss:0.66645
# [5]	validation_0-logloss:0.66276	validation_1-logloss:0.66315
# [6]	validation_0-logloss:0.65946	validation_1-logloss:0.65988
# [7]	validation_0-logloss:0.65661	validation_1-logloss:0.65712
# [8]	validation_0-logloss:0.65400	validation_1-logloss:0.65458
# [9]	validation_0-logloss:0.65156	validation_1-logloss:0.65224
# [10]	validation_0-logloss:0.64944	validation_1-logloss:0.65018
# [11]	validation_0-logloss:0.64745	validation_1-logloss:0.64828
# [12]	validation_0-logloss:0.64548	validation_1-logloss:0.64635
# [13]	validation_0-logloss:0.64396	validation_1-logloss:0.64489
# [14]	validation_0-logloss:0.64236	validation_1-logloss:0.64329
# [15]	validation_0-logloss:0.64026	validation_1-logloss:0.64124
# [16]	validation_0-logloss:0.63891	validation_1-logloss:0.63993
# [17]	validation_0-logloss:0.63756	validation_1-logloss:0.63864
# [18]	validation_0-logloss:0.63649	validation_1-logloss:0.63764
# [19]	validation_0-logloss:0.63510	validation_1-logloss:0.63633
# [20]	validation_0-logloss:0.63417	validation_1-logloss:0.63546
# [21]	validation_0-logloss:0.63295	validation_1-logloss:0.63427
# [22]	validation_0-logloss:0.63198	validation_1-logloss:0.63328
# [23]	validation_0-logloss:0.63095	validation_1-logloss:0.63236
# [24]	validation_0-logloss:0.63028	validation_1-logloss:0.63175
# [25]	validation_0-logloss:0.62859	validation_1-logloss:0.63009
# [26]	validation_0-logloss:0.62791	validation_1-logloss:0.62948
# [27]	validation_0-logloss:0.62724	validation_1-logloss:0.62883
# [28]	validation_0-logloss:0.62657	validation_1-logloss:0.62820
# [29]	validation_0-logloss:0.62583	validation_1-logloss:0.62750
# [30]	validation_0-logloss:0.62446	validation_1-logloss:0.62619
# [31]	validation_0-logloss:0.62352	validation_1-logloss:0.62530
# [32]	validation_0-logloss:0.62294	validation_1-logloss:0.62478
# [33]	validation_0-logloss:0.62250	validation_1-logloss:0.62439
# [34]	validation_0-logloss:0.62215	validation_1-logloss:0.62408
# [35]	validation_0-logloss:0.62130	validation_1-logloss:0.62327
# [36]	validation_0-logloss:0.62086	validation_1-logloss:0.62287
# [37]	validation_0-logloss:0.62011	validation_1-logloss:0.62218
# [38]	validation_0-logloss:0.61957	validation_1-logloss:0.62167
# [39]	validation_0-logloss:0.61827	validation_1-logloss:0.62044
# [40]	validation_0-logloss:0.61791	validation_1-logloss:0.62015
# [41]	validation_0-logloss:0.61728	validation_1-logloss:0.61956
# [42]	validation_0-logloss:0.61662	validation_1-logloss:0.61891
# [43]	validation_0-logloss:0.61627	validation_1-logloss:0.61863
# [44]	validation_0-logloss:0.61575	validation_1-logloss:0.61814
# [45]	validation_0-logloss:0.61528	validation_1-logloss:0.61776
# [46]	validation_0-logloss:0.61505	validation_1-logloss:0.61757
# [47]	validation_0-logloss:0.61456	validation_1-logloss:0.61715
# [48]	validation_0-logloss:0.61421	validation_1-logloss:0.61684
# [49]	validation_0-logloss:0.61377	validation_1-logloss:0.61646
# [50]	validation_0-logloss:0.61304	validation_1-logloss:0.61573
# [51]	validation_0-logloss:0.61266	validation_1-logloss:0.61541
# [52]	validation_0-logloss:0.61237	validation_1-logloss:0.61516
# [53]	validation_0-logloss:0.61200	validation_1-logloss:0.61481
# [54]	validation_0-logloss:0.61159	validation_1-logloss:0.61448
# [55]	validation_0-logloss:0.61117	validation_1-logloss:0.61409
# [56]	validation_0-logloss:0.61095	validation_1-logloss:0.61394
# [57]	validation_0-logloss:0.61075	validation_1-logloss:0.61378
# [58]	validation_0-logloss:0.61023	validation_1-logloss:0.61332
# [59]	validation_0-logloss:0.60999	validation_1-logloss:0.61317
# [60]	validation_0-logloss:0.60968	validation_1-logloss:0.61293
# [61]	validation_0-logloss:0.60940	validation_1-logloss:0.61267
# [62]	validation_0-logloss:0.60914	validation_1-logloss:0.61245
# [63]	validation_0-logloss:0.60895	validation_1-logloss:0.61229
# [64]	validation_0-logloss:0.60868	validation_1-logloss:0.61207
# [65]	validation_0-logloss:0.60833	validation_1-logloss:0.61178
# [66]	validation_0-logloss:0.60805	validation_1-logloss:0.61156
# [67]	validation_0-logloss:0.60775	validation_1-logloss:0.61132
# [68]	validation_0-logloss:0.60756	validation_1-logloss:0.61118
# [69]	validation_0-logloss:0.60679	validation_1-logloss:0.61047
# [70]	validation_0-logloss:0.60659	validation_1-logloss:0.61032
# [71]	validation_0-logloss:0.60638	validation_1-logloss:0.61015
# [72]	validation_0-logloss:0.60621	validation_1-logloss:0.61006
# [73]	validation_0-logloss:0.60597	validation_1-logloss:0.60989
# [74]	validation_0-logloss:0.60576	validation_1-logloss:0.60972
# [75]	validation_0-logloss:0.60558	validation_1-logloss:0.60955
# [76]	validation_0-logloss:0.60517	validation_1-logloss:0.60918
# [77]	validation_0-logloss:0.60502	validation_1-logloss:0.60909
# [78]	validation_0-logloss:0.60484	validation_1-logloss:0.60899
# [79]	validation_0-logloss:0.60470	validation_1-logloss:0.60888
# [80]	validation_0-logloss:0.60451	validation_1-logloss:0.60875
# [81]	validation_0-logloss:0.60430	validation_1-logloss:0.60856
# [82]	validation_0-logloss:0.60405	validation_1-logloss:0.60839
# [83]	validation_0-logloss:0.60391	validation_1-logloss:0.60830
# [84]	validation_0-logloss:0.60375	validation_1-logloss:0.60820
# [85]	validation_0-logloss:0.60357	validation_1-logloss:0.60806
# [86]	validation_0-logloss:0.60344	validation_1-logloss:0.60799
# [87]	validation_0-logloss:0.60334	validation_1-logloss:0.60794
# [88]	validation_0-logloss:0.60319	validation_1-logloss:0.60787
# [89]	validation_0-logloss:0.60307	validation_1-logloss:0.60781
# [90]	validation_0-logloss:0.60287	validation_1-logloss:0.60769
# [91]	validation_0-logloss:0.60274	validation_1-logloss:0.60760
# [92]	validation_0-logloss:0.60265	validation_1-logloss:0.60757
# [93]	validation_0-logloss:0.60245	validation_1-logloss:0.60741
# [94]	validation_0-logloss:0.60224	validation_1-logloss:0.60725
# [95]	validation_0-logloss:0.60180	validation_1-logloss:0.60686
# [96]	validation_0-logloss:0.60161	validation_1-logloss:0.60673
# [97]	validation_0-logloss:0.60151	validation_1-logloss:0.60668
# [98]	validation_0-logloss:0.60139	validation_1-logloss:0.60658
# [99]	validation_0-logloss:0.60102	validation_1-logloss:0.60630
# [100]	validation_0-logloss:0.60085	validation_1-logloss:0.60618
# [101]	validation_0-logloss:0.60073	validation_1-logloss:0.60613
# [102]	validation_0-logloss:0.60043	validation_1-logloss:0.60587
# [103]	validation_0-logloss:0.60018	validation_1-logloss:0.60568
# [104]	validation_0-logloss:0.60008	validation_1-logloss:0.60563
# [105]	validation_0-logloss:0.59984	validation_1-logloss:0.60544
# [106]	validation_0-logloss:0.59973	validation_1-logloss:0.60541
# [107]	validation_0-logloss:0.59950	validation_1-logloss:0.60523
# [108]	validation_0-logloss:0.59910	validation_1-logloss:0.60491
# [109]	validation_0-logloss:0.59881	validation_1-logloss:0.60470
# [110]	validation_0-logloss:0.59845	validation_1-logloss:0.60441
# [111]	validation_0-logloss:0.59836	validation_1-logloss:0.60435
# [112]	validation_0-logloss:0.59815	validation_1-logloss:0.60417
# [113]	validation_0-logloss:0.59800	validation_1-logloss:0.60408
# [114]	validation_0-logloss:0.59787	validation_1-logloss:0.60400
# [115]	validation_0-logloss:0.59777	validation_1-logloss:0.60396
# [116]	validation_0-logloss:0.59767	validation_1-logloss:0.60391
# [117]	validation_0-logloss:0.59758	validation_1-logloss:0.60388
# [118]	validation_0-logloss:0.59740	validation_1-logloss:0.60375
# [119]	validation_0-logloss:0.59725	validation_1-logloss:0.60364
# [120]	validation_0-logloss:0.59705	validation_1-logloss:0.60348
# [121]	validation_0-logloss:0.59694	validation_1-logloss:0.60344
# [122]	validation_0-logloss:0.59685	validation_1-logloss:0.60342
# [123]	validation_0-logloss:0.59671	validation_1-logloss:0.60335
# [124]	validation_0-logloss:0.59647	validation_1-logloss:0.60315
# [125]	validation_0-logloss:0.59628	validation_1-logloss:0.60302
# [126]	validation_0-logloss:0.59619	validation_1-logloss:0.60300
# [127]	validation_0-logloss:0.59600	validation_1-logloss:0.60284
# [128]	validation_0-logloss:0.59579	validation_1-logloss:0.60268
# [129]	validation_0-logloss:0.59548	validation_1-logloss:0.60242
# [130]	validation_0-logloss:0.59525	validation_1-logloss:0.60224
# [131]	validation_0-logloss:0.59506	validation_1-logloss:0.60208
# [132]	validation_0-logloss:0.59495	validation_1-logloss:0.60204
# [133]	validation_0-logloss:0.59486	validation_1-logloss:0.60201
# [134]	validation_0-logloss:0.59465	validation_1-logloss:0.60184
# [135]	validation_0-logloss:0.59460	validation_1-logloss:0.60184
# [136]	validation_0-logloss:0.59449	validation_1-logloss:0.60181
# [137]	validation_0-logloss:0.59424	validation_1-logloss:0.60161
# [138]	validation_0-logloss:0.59407	validation_1-logloss:0.60154
# [139]	validation_0-logloss:0.59379	validation_1-logloss:0.60130
# [140]	validation_0-logloss:0.59363	validation_1-logloss:0.60119
# [141]	validation_0-logloss:0.59351	validation_1-logloss:0.60112
# [142]	validation_0-logloss:0.59327	validation_1-logloss:0.60096
# [143]	validation_0-logloss:0.59318	validation_1-logloss:0.60092
# [144]	validation_0-logloss:0.59311	validation_1-logloss:0.60089
# [145]	validation_0-logloss:0.59292	validation_1-logloss:0.60074
# [146]	validation_0-logloss:0.59285	validation_1-logloss:0.60071
# [147]	validation_0-logloss:0.59272	validation_1-logloss:0.60066
# [148]	validation_0-logloss:0.59265	validation_1-logloss:0.60064
# [149]	validation_0-logloss:0.59256	validation_1-logloss:0.60062
# [150]	validation_0-logloss:0.59239	validation_1-logloss:0.60051
# [151]	validation_0-logloss:0.59227	validation_1-logloss:0.60045
# [152]	validation_0-logloss:0.59218	validation_1-logloss:0.60042
# [153]	validation_0-logloss:0.59208	validation_1-logloss:0.60039
# [154]	validation_0-logloss:0.59200	validation_1-logloss:0.60037
# [155]	validation_0-logloss:0.59183	validation_1-logloss:0.60026
# [156]	validation_0-logloss:0.59171	validation_1-logloss:0.60018
# [157]	validation_0-logloss:0.59162	validation_1-logloss:0.60015
# [158]	validation_0-logloss:0.59148	validation_1-logloss:0.60005
# [159]	validation_0-logloss:0.59141	validation_1-logloss:0.60004
# [160]	validation_0-logloss:0.59130	validation_1-logloss:0.59997
# [161]	validation_0-logloss:0.59117	validation_1-logloss:0.59990
# [162]	validation_0-logloss:0.59104	validation_1-logloss:0.59979
# [163]	validation_0-logloss:0.59095	validation_1-logloss:0.59977
# [164]	validation_0-logloss:0.59080	validation_1-logloss:0.59966
# [165]	validation_0-logloss:0.59071	validation_1-logloss:0.59966
# [166]	validation_0-logloss:0.59062	validation_1-logloss:0.59962
# [167]	validation_0-logloss:0.59051	validation_1-logloss:0.59956
# [168]	validation_0-logloss:0.59045	validation_1-logloss:0.59954
# [169]	validation_0-logloss:0.59038	validation_1-logloss:0.59952
# [170]	validation_0-logloss:0.59030	validation_1-logloss:0.59950
# [171]	validation_0-logloss:0.59024	validation_1-logloss:0.59949
# [172]	validation_0-logloss:0.59018	validation_1-logloss:0.59949
# [173]	validation_0-logloss:0.59011	validation_1-logloss:0.59948
# [174]	validation_0-logloss:0.58991	validation_1-logloss:0.59936
# [175]	validation_0-logloss:0.58964	validation_1-logloss:0.59914
# [176]	validation_0-logloss:0.58955	validation_1-logloss:0.59909
# [177]	validation_0-logloss:0.58935	validation_1-logloss:0.59895
# [178]	validation_0-logloss:0.58920	validation_1-logloss:0.59887
# [179]	validation_0-logloss:0.58905	validation_1-logloss:0.59878
# [180]	validation_0-logloss:0.58898	validation_1-logloss:0.59876
# [181]	validation_0-logloss:0.58889	validation_1-logloss:0.59873
# [182]	validation_0-logloss:0.58879	validation_1-logloss:0.59866
# [183]	validation_0-logloss:0.58865	validation_1-logloss:0.59859
# [184]	validation_0-logloss:0.58858	validation_1-logloss:0.59856
# [185]	validation_0-logloss:0.58850	validation_1-logloss:0.59855
# [186]	validation_0-logloss:0.58844	validation_1-logloss:0.59855
# [187]	validation_0-logloss:0.58834	validation_1-logloss:0.59849
# [188]	validation_0-logloss:0.58826	validation_1-logloss:0.59849
# [189]	validation_0-logloss:0.58814	validation_1-logloss:0.59841
# [190]	validation_0-logloss:0.58807	validation_1-logloss:0.59839
# [191]	validation_0-logloss:0.58799	validation_1-logloss:0.59839
# [192]	validation_0-logloss:0.58787	validation_1-logloss:0.59831
# [193]	validation_0-logloss:0.58772	validation_1-logloss:0.59822
# [194]	validation_0-logloss:0.58763	validation_1-logloss:0.59818
# [195]	validation_0-logloss:0.58749	validation_1-logloss:0.59808
# [196]	validation_0-logloss:0.58742	validation_1-logloss:0.59805
# [197]	validation_0-logloss:0.58733	validation_1-logloss:0.59801
# [198]	validation_0-logloss:0.58723	validation_1-logloss:0.59798
# [199]	validation_0-logloss:0.58710	validation_1-logloss:0.59789
# [200]	validation_0-logloss:0.58701	validation_1-logloss:0.59788
# [201]	validation_0-logloss:0.58693	validation_1-logloss:0.59787
# [202]	validation_0-logloss:0.58687	validation_1-logloss:0.59785
# [203]	validation_0-logloss:0.58676	validation_1-logloss:0.59779
# [204]	validation_0-logloss:0.58668	validation_1-logloss:0.59777
# [205]	validation_0-logloss:0.58658	validation_1-logloss:0.59774
# [206]	validation_0-logloss:0.58651	validation_1-logloss:0.59773
# [207]	validation_0-logloss:0.58644	validation_1-logloss:0.59772
# [208]	validation_0-logloss:0.58636	validation_1-logloss:0.59769
# [209]	validation_0-logloss:0.58624	validation_1-logloss:0.59764
# [210]	validation_0-logloss:0.58614	validation_1-logloss:0.59760
# [211]	validation_0-logloss:0.58603	validation_1-logloss:0.59755
# [212]	validation_0-logloss:0.58593	validation_1-logloss:0.59751
# [213]	validation_0-logloss:0.58585	validation_1-logloss:0.59749
# [214]	validation_0-logloss:0.58581	validation_1-logloss:0.59749
# [215]	validation_0-logloss:0.58573	validation_1-logloss:0.59747
# [216]	validation_0-logloss:0.58567	validation_1-logloss:0.59747
# [217]	validation_0-logloss:0.58559	validation_1-logloss:0.59745
# [218]	validation_0-logloss:0.58549	validation_1-logloss:0.59739
# [219]	validation_0-logloss:0.58542	validation_1-logloss:0.59736
# [220]	validation_0-logloss:0.58535	validation_1-logloss:0.59735
# [221]	validation_0-logloss:0.58523	validation_1-logloss:0.59729
# [222]	validation_0-logloss:0.58511	validation_1-logloss:0.59722
# [223]	validation_0-logloss:0.58495	validation_1-logloss:0.59713
# [224]	validation_0-logloss:0.58488	validation_1-logloss:0.59711
# [225]	validation_0-logloss:0.58482	validation_1-logloss:0.59710
# [226]	validation_0-logloss:0.58475	validation_1-logloss:0.59707
# [227]	validation_0-logloss:0.58461	validation_1-logloss:0.59698
# [228]	validation_0-logloss:0.58450	validation_1-logloss:0.59691
# [229]	validation_0-logloss:0.58439	validation_1-logloss:0.59685
# [230]	validation_0-logloss:0.58433	validation_1-logloss:0.59684
# [231]	validation_0-logloss:0.58423	validation_1-logloss:0.59682
# [232]	validation_0-logloss:0.58416	validation_1-logloss:0.59681
# [233]	validation_0-logloss:0.58409	validation_1-logloss:0.59680
# [234]	validation_0-logloss:0.58403	validation_1-logloss:0.59679
# [235]	validation_0-logloss:0.58398	validation_1-logloss:0.59678
# [236]	validation_0-logloss:0.58392	validation_1-logloss:0.59678
# [237]	validation_0-logloss:0.58386	validation_1-logloss:0.59678
# [238]	validation_0-logloss:0.58381	validation_1-logloss:0.59677
# [239]	validation_0-logloss:0.58375	validation_1-logloss:0.59677
# [240]	validation_0-logloss:0.58370	validation_1-logloss:0.59676
# [241]	validation_0-logloss:0.58354	validation_1-logloss:0.59665
# [242]	validation_0-logloss:0.58348	validation_1-logloss:0.59664
# [243]	validation_0-logloss:0.58341	validation_1-logloss:0.59663
# [244]	validation_0-logloss:0.58326	validation_1-logloss:0.59653
# [245]	validation_0-logloss:0.58314	validation_1-logloss:0.59647
# [246]	validation_0-logloss:0.58301	validation_1-logloss:0.59641
# [247]	validation_0-logloss:0.58296	validation_1-logloss:0.59639
# [248]	validation_0-logloss:0.58288	validation_1-logloss:0.59638
# [249]	validation_0-logloss:0.58281	validation_1-logloss:0.59639
# [250]	validation_0-logloss:0.58275	validation_1-logloss:0.59639
# [251]	validation_0-logloss:0.58269	validation_1-logloss:0.59635
# [252]	validation_0-logloss:0.58258	validation_1-logloss:0.59629
# [253]	validation_0-logloss:0.58251	validation_1-logloss:0.59627
# [254]	validation_0-logloss:0.58242	validation_1-logloss:0.59625
# [255]	validation_0-logloss:0.58231	validation_1-logloss:0.59620
# [256]	validation_0-logloss:0.58221	validation_1-logloss:0.59619
# [257]	validation_0-logloss:0.58212	validation_1-logloss:0.59616
# [258]	validation_0-logloss:0.58204	validation_1-logloss:0.59614
# [259]	validation_0-logloss:0.58199	validation_1-logloss:0.59614
# [260]	validation_0-logloss:0.58194	validation_1-logloss:0.59614
# [261]	validation_0-logloss:0.58185	validation_1-logloss:0.59610
# [262]	validation_0-logloss:0.58176	validation_1-logloss:0.59606
# [263]	validation_0-logloss:0.58169	validation_1-logloss:0.59605
# [264]	validation_0-logloss:0.58156	validation_1-logloss:0.59596
# [265]	validation_0-logloss:0.58149	validation_1-logloss:0.59594
# [266]	validation_0-logloss:0.58142	validation_1-logloss:0.59594
# [267]	validation_0-logloss:0.58134	validation_1-logloss:0.59593
# [268]	validation_0-logloss:0.58123	validation_1-logloss:0.59588
# [269]	validation_0-logloss:0.58116	validation_1-logloss:0.59587
# [270]	validation_0-logloss:0.58105	validation_1-logloss:0.59577
# [271]	validation_0-logloss:0.58096	validation_1-logloss:0.59573
# [272]	validation_0-logloss:0.58091	validation_1-logloss:0.59571
# [273]	validation_0-logloss:0.58084	validation_1-logloss:0.59567
# [274]	validation_0-logloss:0.58074	validation_1-logloss:0.59563
# [275]	validation_0-logloss:0.58069	validation_1-logloss:0.59562
# [276]	validation_0-logloss:0.58064	validation_1-logloss:0.59563
# [277]	validation_0-logloss:0.58059	validation_1-logloss:0.59562
# [278]	validation_0-logloss:0.58049	validation_1-logloss:0.59557
# [279]	validation_0-logloss:0.58044	validation_1-logloss:0.59556
# [280]	validation_0-logloss:0.58037	validation_1-logloss:0.59555
# [281]	validation_0-logloss:0.58032	validation_1-logloss:0.59555
# [282]	validation_0-logloss:0.58027	validation_1-logloss:0.59553
# [283]	validation_0-logloss:0.58019	validation_1-logloss:0.59550
# [284]	validation_0-logloss:0.58014	validation_1-logloss:0.59549
# [285]	validation_0-logloss:0.58008	validation_1-logloss:0.59550
# [286]	validation_0-logloss:0.57998	validation_1-logloss:0.59546
# [287]	validation_0-logloss:0.57991	validation_1-logloss:0.59543
# [288]	validation_0-logloss:0.57979	validation_1-logloss:0.59537
# [289]	validation_0-logloss:0.57958	validation_1-logloss:0.59517
# [290]	validation_0-logloss:0.57950	validation_1-logloss:0.59515
# [291]	validation_0-logloss:0.57943	validation_1-logloss:0.59514
# [292]	validation_0-logloss:0.57935	validation_1-logloss:0.59511
# [293]	validation_0-logloss:0.57925	validation_1-logloss:0.59507
# [294]	validation_0-logloss:0.57915	validation_1-logloss:0.59500
# [295]	validation_0-logloss:0.57906	validation_1-logloss:0.59495
# [296]	validation_0-logloss:0.57894	validation_1-logloss:0.59488
# [297]	validation_0-logloss:0.57889	validation_1-logloss:0.59487
# [298]	validation_0-logloss:0.57882	validation_1-logloss:0.59486
# [299]	validation_0-logloss:0.57876	validation_1-logloss:0.59487
# [300]	validation_0-logloss:0.57869	validation_1-logloss:0.59486
# [301]	validation_0-logloss:0.57862	validation_1-logloss:0.59485
# [302]	validation_0-logloss:0.57855	validation_1-logloss:0.59485
# [303]	validation_0-logloss:0.57848	validation_1-logloss:0.59484
# [304]	validation_0-logloss:0.57837	validation_1-logloss:0.59477
# [305]	validation_0-logloss:0.57831	validation_1-logloss:0.59478
# [306]	validation_0-logloss:0.57824	validation_1-logloss:0.59474
# [307]	validation_0-logloss:0.57816	validation_1-logloss:0.59473
# [308]	validation_0-logloss:0.57811	validation_1-logloss:0.59473
# [309]	validation_0-logloss:0.57805	validation_1-logloss:0.59471
# [310]	validation_0-logloss:0.57799	validation_1-logloss:0.59470
# [311]	validation_0-logloss:0.57794	validation_1-logloss:0.59469
# [312]	validation_0-logloss:0.57780	validation_1-logloss:0.59462
# [313]	validation_0-logloss:0.57766	validation_1-logloss:0.59453
# [314]	validation_0-logloss:0.57759	validation_1-logloss:0.59453
# [315]	validation_0-logloss:0.57749	validation_1-logloss:0.59450
# [316]	validation_0-logloss:0.57743	validation_1-logloss:0.59449
# [317]	validation_0-logloss:0.57734	validation_1-logloss:0.59444
# [318]	validation_0-logloss:0.57722	validation_1-logloss:0.59436
# [319]	validation_0-logloss:0.57716	validation_1-logloss:0.59435
# [320]	validation_0-logloss:0.57708	validation_1-logloss:0.59431
# [321]	validation_0-logloss:0.57699	validation_1-logloss:0.59430
# [322]	validation_0-logloss:0.57694	validation_1-logloss:0.59432
# [323]	validation_0-logloss:0.57689	validation_1-logloss:0.59432
# [324]	validation_0-logloss:0.57684	validation_1-logloss:0.59431
# [325]	validation_0-logloss:0.57677	validation_1-logloss:0.59431
# [326]	validation_0-logloss:0.57671	validation_1-logloss:0.59431
# [327]	validation_0-logloss:0.57662	validation_1-logloss:0.59428
# [328]	validation_0-logloss:0.57657	validation_1-logloss:0.59426
# [329]	validation_0-logloss:0.57651	validation_1-logloss:0.59426
# [330]	validation_0-logloss:0.57644	validation_1-logloss:0.59425
# [331]	validation_0-logloss:0.57635	validation_1-logloss:0.59422
# [332]	validation_0-logloss:0.57626	validation_1-logloss:0.59421
# [333]	validation_0-logloss:0.57619	validation_1-logloss:0.59420
# [334]	validation_0-logloss:0.57614	validation_1-logloss:0.59420
# [335]	validation_0-logloss:0.57607	validation_1-logloss:0.59418
# [336]	validation_0-logloss:0.57601	validation_1-logloss:0.59419
# [337]	validation_0-logloss:0.57595	validation_1-logloss:0.59419
# [338]	validation_0-logloss:0.57589	validation_1-logloss:0.59419
# [339]	validation_0-logloss:0.57583	validation_1-logloss:0.59421
# [340]	validation_0-logloss:0.57577	validation_1-logloss:0.59421
# [341]	validation_0-logloss:0.57571	validation_1-logloss:0.59419
# [342]	validation_0-logloss:0.57564	validation_1-logloss:0.59418
# [343]	validation_0-logloss:0.57557	validation_1-logloss:0.59418
# [344]	validation_0-logloss:0.57551	validation_1-logloss:0.59418
# [345]	validation_0-logloss:0.57545	validation_1-logloss:0.59418
# [346]	validation_0-logloss:0.57540	validation_1-logloss:0.59418
# [347]	validation_0-logloss:0.57530	validation_1-logloss:0.59414
# [348]	validation_0-logloss:0.57524	validation_1-logloss:0.59412
# [349]	validation_0-logloss:0.57518	validation_1-logloss:0.59412
# [350]	validation_0-logloss:0.57513	validation_1-logloss:0.59412
# [351]	validation_0-logloss:0.57507	validation_1-logloss:0.59411
# [352]	validation_0-logloss:0.57501	validation_1-logloss:0.59410
# [353]	validation_0-logloss:0.57492	validation_1-logloss:0.59406
# [354]	validation_0-logloss:0.57486	validation_1-logloss:0.59406
# [355]	validation_0-logloss:0.57482	validation_1-logloss:0.59406
# [356]	validation_0-logloss:0.57472	validation_1-logloss:0.59403
# [357]	validation_0-logloss:0.57466	validation_1-logloss:0.59404
# [358]	validation_0-logloss:0.57460	validation_1-logloss:0.59404
# [359]	validation_0-logloss:0.57449	validation_1-logloss:0.59399
# [360]	validation_0-logloss:0.57441	validation_1-logloss:0.59397
# [361]	validation_0-logloss:0.57437	validation_1-logloss:0.59397
# [362]	validation_0-logloss:0.57431	validation_1-logloss:0.59397
# [363]	validation_0-logloss:0.57422	validation_1-logloss:0.59394
# [364]	validation_0-logloss:0.57412	validation_1-logloss:0.59390
# [365]	validation_0-logloss:0.57402	validation_1-logloss:0.59386
# [366]	validation_0-logloss:0.57394	validation_1-logloss:0.59384
# [367]	validation_0-logloss:0.57388	validation_1-logloss:0.59383
# [368]	validation_0-logloss:0.57381	validation_1-logloss:0.59382
# [369]	validation_0-logloss:0.57375	validation_1-logloss:0.59382
# [370]	validation_0-logloss:0.57371	validation_1-logloss:0.59383
# [371]	validation_0-logloss:0.57365	validation_1-logloss:0.59382
# [372]	validation_0-logloss:0.57358	validation_1-logloss:0.59382
# [373]	validation_0-logloss:0.57351	validation_1-logloss:0.59379
# [374]	validation_0-logloss:0.57345	validation_1-logloss:0.59379
# [375]	validation_0-logloss:0.57340	validation_1-logloss:0.59378
# [376]	validation_0-logloss:0.57333	validation_1-logloss:0.59379
# [377]	validation_0-logloss:0.57328	validation_1-logloss:0.59379
# [378]	validation_0-logloss:0.57322	validation_1-logloss:0.59378
# [379]	validation_0-logloss:0.57317	validation_1-logloss:0.59377
# [380]	validation_0-logloss:0.57313	validation_1-logloss:0.59377
# [381]	validation_0-logloss:0.57306	validation_1-logloss:0.59376
# [382]	validation_0-logloss:0.57299	validation_1-logloss:0.59374
# [383]	validation_0-logloss:0.57294	validation_1-logloss:0.59374
# [384]	validation_0-logloss:0.57288	validation_1-logloss:0.59373
# [385]	validation_0-logloss:0.57283	validation_1-logloss:0.59373
# [386]	validation_0-logloss:0.57275	validation_1-logloss:0.59373
# [387]	validation_0-logloss:0.57269	validation_1-logloss:0.59374
# [388]	validation_0-logloss:0.57263	validation_1-logloss:0.59373
# [389]	validation_0-logloss:0.57256	validation_1-logloss:0.59373
# [390]	validation_0-logloss:0.57246	validation_1-logloss:0.59367
# [391]	validation_0-logloss:0.57234	validation_1-logloss:0.59359
# [392]	validation_0-logloss:0.57228	validation_1-logloss:0.59357
# [393]	validation_0-logloss:0.57221	validation_1-logloss:0.59356
# [394]	validation_0-logloss:0.57216	validation_1-logloss:0.59356
# [395]	validation_0-logloss:0.57208	validation_1-logloss:0.59355
# [396]	validation_0-logloss:0.57201	validation_1-logloss:0.59354
# [397]	validation_0-logloss:0.57194	validation_1-logloss:0.59352
# [398]	validation_0-logloss:0.57186	validation_1-logloss:0.59350
# [399]	validation_0-logloss:0.57181	validation_1-logloss:0.59349
# [400]	validation_0-logloss:0.57167	validation_1-logloss:0.59338
# [401]	validation_0-logloss:0.57162	validation_1-logloss:0.59338
# [402]	validation_0-logloss:0.57156	validation_1-logloss:0.59336
# [403]	validation_0-logloss:0.57151	validation_1-logloss:0.59337
# [404]	validation_0-logloss:0.57141	validation_1-logloss:0.59333
# [405]	validation_0-logloss:0.57135	validation_1-logloss:0.59334
# [406]	validation_0-logloss:0.57127	validation_1-logloss:0.59331
# [407]	validation_0-logloss:0.57122	validation_1-logloss:0.59332
# [408]	validation_0-logloss:0.57114	validation_1-logloss:0.59331
# [409]	validation_0-logloss:0.57104	validation_1-logloss:0.59326
# [410]	validation_0-logloss:0.57098	validation_1-logloss:0.59326
# [411]	validation_0-logloss:0.57092	validation_1-logloss:0.59325
# [412]	validation_0-logloss:0.57088	validation_1-logloss:0.59325
# [413]	validation_0-logloss:0.57082	validation_1-logloss:0.59325
# [414]	validation_0-logloss:0.57076	validation_1-logloss:0.59324
# [415]	validation_0-logloss:0.57069	validation_1-logloss:0.59324
# [416]	validation_0-logloss:0.57063	validation_1-logloss:0.59325
# [417]	validation_0-logloss:0.57058	validation_1-logloss:0.59325
# [418]	validation_0-logloss:0.57051	validation_1-logloss:0.59323
# [419]	validation_0-logloss:0.57045	validation_1-logloss:0.59323
# [420]	validation_0-logloss:0.57039	validation_1-logloss:0.59323
# [421]	validation_0-logloss:0.57034	validation_1-logloss:0.59323
# [422]	validation_0-logloss:0.57028	validation_1-logloss:0.59324
# [423]	validation_0-logloss:0.57021	validation_1-logloss:0.59324
# [424]	validation_0-logloss:0.57014	validation_1-logloss:0.59322
# [425]	validation_0-logloss:0.57008	validation_1-logloss:0.59322
# [426]	validation_0-logloss:0.57002	validation_1-logloss:0.59322
# [427]	validation_0-logloss:0.56994	validation_1-logloss:0.59320
# [428]	validation_0-logloss:0.56986	validation_1-logloss:0.59319
# [429]	validation_0-logloss:0.56977	validation_1-logloss:0.59314
# [430]	validation_0-logloss:0.56969	validation_1-logloss:0.59312
# [431]	validation_0-logloss:0.56961	validation_1-logloss:0.59309
# [432]	validation_0-logloss:0.56951	validation_1-logloss:0.59305
# [433]	validation_0-logloss:0.56941	validation_1-logloss:0.59299
# [434]	validation_0-logloss:0.56935	validation_1-logloss:0.59298
# [435]	validation_0-logloss:0.56929	validation_1-logloss:0.59297
# [436]	validation_0-logloss:0.56926	validation_1-logloss:0.59297
# [437]	validation_0-logloss:0.56919	validation_1-logloss:0.59297
# [438]	validation_0-logloss:0.56912	validation_1-logloss:0.59296
# [439]	validation_0-logloss:0.56907	validation_1-logloss:0.59297
# [440]	validation_0-logloss:0.56900	validation_1-logloss:0.59296
# [441]	validation_0-logloss:0.56889	validation_1-logloss:0.59288
# [442]	validation_0-logloss:0.56881	validation_1-logloss:0.59286
# [443]	validation_0-logloss:0.56875	validation_1-logloss:0.59286
# [444]	validation_0-logloss:0.56869	validation_1-logloss:0.59287
# [445]	validation_0-logloss:0.56861	validation_1-logloss:0.59286
# [446]	validation_0-logloss:0.56856	validation_1-logloss:0.59286
# [447]	validation_0-logloss:0.56848	validation_1-logloss:0.59285
# [448]	validation_0-logloss:0.56844	validation_1-logloss:0.59284
# [449]	validation_0-logloss:0.56838	validation_1-logloss:0.59285
# [450]	validation_0-logloss:0.56831	validation_1-logloss:0.59284
# [451]	validation_0-logloss:0.56825	validation_1-logloss:0.59283
# [452]	validation_0-logloss:0.56818	validation_1-logloss:0.59282
# [453]	validation_0-logloss:0.56813	validation_1-logloss:0.59284
# [454]	validation_0-logloss:0.56804	validation_1-logloss:0.59281
# [455]	validation_0-logloss:0.56798	validation_1-logloss:0.59281
# [456]	validation_0-logloss:0.56792	validation_1-logloss:0.59278
# [457]	validation_0-logloss:0.56786	validation_1-logloss:0.59277
# [458]	validation_0-logloss:0.56779	validation_1-logloss:0.59276
# [459]	validation_0-logloss:0.56775	validation_1-logloss:0.59274
# [460]	validation_0-logloss:0.56769	validation_1-logloss:0.59271
# [461]	validation_0-logloss:0.56765	validation_1-logloss:0.59272
# [462]	validation_0-logloss:0.56760	validation_1-logloss:0.59272
# [463]	validation_0-logloss:0.56754	validation_1-logloss:0.59273
# [464]	validation_0-logloss:0.56748	validation_1-logloss:0.59272
# [465]	validation_0-logloss:0.56742	validation_1-logloss:0.59272
# [466]	validation_0-logloss:0.56738	validation_1-logloss:0.59271
# [467]	validation_0-logloss:0.56732	validation_1-logloss:0.59271
# [468]	validation_0-logloss:0.56727	validation_1-logloss:0.59270
# [469]	validation_0-logloss:0.56722	validation_1-logloss:0.59270
# [470]	validation_0-logloss:0.56713	validation_1-logloss:0.59266
# [471]	validation_0-logloss:0.56707	validation_1-logloss:0.59267
# [472]	validation_0-logloss:0.56699	validation_1-logloss:0.59263
# [473]	validation_0-logloss:0.56689	validation_1-logloss:0.59257
# [474]	validation_0-logloss:0.56682	validation_1-logloss:0.59255
# [475]	validation_0-logloss:0.56675	validation_1-logloss:0.59252
# [476]	validation_0-logloss:0.56671	validation_1-logloss:0.59252
# [477]	validation_0-logloss:0.56664	validation_1-logloss:0.59250
# [478]	validation_0-logloss:0.56659	validation_1-logloss:0.59249
# [479]	validation_0-logloss:0.56653	validation_1-logloss:0.59249
# [480]	validation_0-logloss:0.56649	validation_1-logloss:0.59249
# [481]	validation_0-logloss:0.56640	validation_1-logloss:0.59245
# [482]	validation_0-logloss:0.56628	validation_1-logloss:0.59240
# [483]	validation_0-logloss:0.56622	validation_1-logloss:0.59238
# [484]	validation_0-logloss:0.56619	validation_1-logloss:0.59237
# [485]	validation_0-logloss:0.56613	validation_1-logloss:0.59238
# [486]	validation_0-logloss:0.56608	validation_1-logloss:0.59237
# [487]	validation_0-logloss:0.56600	validation_1-logloss:0.59234
# [488]	validation_0-logloss:0.56593	validation_1-logloss:0.59234
# [489]	validation_0-logloss:0.56588	validation_1-logloss:0.59234
# [490]	validation_0-logloss:0.56582	validation_1-logloss:0.59232
# [491]	validation_0-logloss:0.56574	validation_1-logloss:0.59231
# [492]	validation_0-logloss:0.56569	validation_1-logloss:0.59230
# [493]	validation_0-logloss:0.56563	validation_1-logloss:0.59230
# [494]	validation_0-logloss:0.56557	validation_1-logloss:0.59230
# [495]	validation_0-logloss:0.56550	validation_1-logloss:0.59227
# [496]	validation_0-logloss:0.56541	validation_1-logloss:0.59224
# [497]	validation_0-logloss:0.56535	validation_1-logloss:0.59224
# [498]	validation_0-logloss:0.56528	validation_1-logloss:0.59221
# [499]	validation_0-logloss:0.56523	validation_1-logloss:0.59221
# [500]	validation_0-logloss:0.56517	validation_1-logloss:0.59221
# [501]	validation_0-logloss:0.56511	validation_1-logloss:0.59221
# [502]	validation_0-logloss:0.56505	validation_1-logloss:0.59222
# [503]	validation_0-logloss:0.56501	validation_1-logloss:0.59222
# [504]	validation_0-logloss:0.56497	validation_1-logloss:0.59222
# [505]	validation_0-logloss:0.56489	validation_1-logloss:0.59219
# [506]	validation_0-logloss:0.56482	validation_1-logloss:0.59219
# [507]	validation_0-logloss:0.56472	validation_1-logloss:0.59214
# [508]	validation_0-logloss:0.56466	validation_1-logloss:0.59213
# [509]	validation_0-logloss:0.56462	validation_1-logloss:0.59214
# [510]	validation_0-logloss:0.56456	validation_1-logloss:0.59213
# [511]	validation_0-logloss:0.56449	validation_1-logloss:0.59212
# [512]	validation_0-logloss:0.56443	validation_1-logloss:0.59212
# [513]	validation_0-logloss:0.56436	validation_1-logloss:0.59211
# [514]	validation_0-logloss:0.56430	validation_1-logloss:0.59211
# [515]	validation_0-logloss:0.56425	validation_1-logloss:0.59211
# [516]	validation_0-logloss:0.56420	validation_1-logloss:0.59211
# [517]	validation_0-logloss:0.56415	validation_1-logloss:0.59210
# [518]	validation_0-logloss:0.56408	validation_1-logloss:0.59209
# [519]	validation_0-logloss:0.56402	validation_1-logloss:0.59207
# [520]	validation_0-logloss:0.56397	validation_1-logloss:0.59208
# [521]	validation_0-logloss:0.56392	validation_1-logloss:0.59208
# [522]	validation_0-logloss:0.56383	validation_1-logloss:0.59204
# [523]	validation_0-logloss:0.56378	validation_1-logloss:0.59203
# [524]	validation_0-logloss:0.56372	validation_1-logloss:0.59202
# [525]	validation_0-logloss:0.56367	validation_1-logloss:0.59202
# [526]	validation_0-logloss:0.56361	validation_1-logloss:0.59202
# [527]	validation_0-logloss:0.56353	validation_1-logloss:0.59198
# [528]	validation_0-logloss:0.56347	validation_1-logloss:0.59199
# [529]	validation_0-logloss:0.56343	validation_1-logloss:0.59199
# [530]	validation_0-logloss:0.56337	validation_1-logloss:0.59198
# [531]	validation_0-logloss:0.56330	validation_1-logloss:0.59195
# [532]	validation_0-logloss:0.56323	validation_1-logloss:0.59195
# [533]	validation_0-logloss:0.56317	validation_1-logloss:0.59194
# [534]	validation_0-logloss:0.56311	validation_1-logloss:0.59194
# [535]	validation_0-logloss:0.56307	validation_1-logloss:0.59194
# [536]	validation_0-logloss:0.56301	validation_1-logloss:0.59194
# [537]	validation_0-logloss:0.56293	validation_1-logloss:0.59190
# [538]	validation_0-logloss:0.56289	validation_1-logloss:0.59191
# [539]	validation_0-logloss:0.56284	validation_1-logloss:0.59190
# [540]	validation_0-logloss:0.56278	validation_1-logloss:0.59189
# [541]	validation_0-logloss:0.56272	validation_1-logloss:0.59190
# [542]	validation_0-logloss:0.56264	validation_1-logloss:0.59188
# [543]	validation_0-logloss:0.56259	validation_1-logloss:0.59188
# [544]	validation_0-logloss:0.56254	validation_1-logloss:0.59187
# [545]	validation_0-logloss:0.56247	validation_1-logloss:0.59187
# [546]	validation_0-logloss:0.56242	validation_1-logloss:0.59185
# [547]	validation_0-logloss:0.56237	validation_1-logloss:0.59185
# [548]	validation_0-logloss:0.56231	validation_1-logloss:0.59185
# [549]	validation_0-logloss:0.56224	validation_1-logloss:0.59185
# [550]	validation_0-logloss:0.56217	validation_1-logloss:0.59184
# [551]	validation_0-logloss:0.56212	validation_1-logloss:0.59183
# [552]	validation_0-logloss:0.56206	validation_1-logloss:0.59181
# [553]	validation_0-logloss:0.56202	validation_1-logloss:0.59183
# [554]	validation_0-logloss:0.56197	validation_1-logloss:0.59183
# [555]	validation_0-logloss:0.56187	validation_1-logloss:0.59179
# [556]	validation_0-logloss:0.56181	validation_1-logloss:0.59177
# [557]	validation_0-logloss:0.56176	validation_1-logloss:0.59178
# [558]	validation_0-logloss:0.56169	validation_1-logloss:0.59177
# [559]	validation_0-logloss:0.56163	validation_1-logloss:0.59177
# [560]	validation_0-logloss:0.56158	validation_1-logloss:0.59177
# [561]	validation_0-logloss:0.56151	validation_1-logloss:0.59176
# [562]	validation_0-logloss:0.56145	validation_1-logloss:0.59176
# [563]	validation_0-logloss:0.56139	validation_1-logloss:0.59176
# [564]	validation_0-logloss:0.56132	validation_1-logloss:0.59175
# [565]	validation_0-logloss:0.56127	validation_1-logloss:0.59175
# [566]	validation_0-logloss:0.56121	validation_1-logloss:0.59174
# [567]	validation_0-logloss:0.56117	validation_1-logloss:0.59174
# [568]	validation_0-logloss:0.56111	validation_1-logloss:0.59174
# [569]	validation_0-logloss:0.56106	validation_1-logloss:0.59176
# [570]	validation_0-logloss:0.56100	validation_1-logloss:0.59175
# [571]	validation_0-logloss:0.56092	validation_1-logloss:0.59172
# [572]	validation_0-logloss:0.56086	validation_1-logloss:0.59169
# [573]	validation_0-logloss:0.56073	validation_1-logloss:0.59162
# [574]	validation_0-logloss:0.56068	validation_1-logloss:0.59160
# [575]	validation_0-logloss:0.56064	validation_1-logloss:0.59161
# [576]	validation_0-logloss:0.56055	validation_1-logloss:0.59157
# [577]	validation_0-logloss:0.56049	validation_1-logloss:0.59157
# [578]	validation_0-logloss:0.56043	validation_1-logloss:0.59156
# [579]	validation_0-logloss:0.56036	validation_1-logloss:0.59155
# [580]	validation_0-logloss:0.56028	validation_1-logloss:0.59152
# [581]	validation_0-logloss:0.56021	validation_1-logloss:0.59152
# [582]	validation_0-logloss:0.56015	validation_1-logloss:0.59150
# [583]	validation_0-logloss:0.56009	validation_1-logloss:0.59151
# [584]	validation_0-logloss:0.56005	validation_1-logloss:0.59150
# [585]	validation_0-logloss:0.56001	validation_1-logloss:0.59150
# [586]	validation_0-logloss:0.55994	validation_1-logloss:0.59150
# [587]	validation_0-logloss:0.55990	validation_1-logloss:0.59148
# [588]	validation_0-logloss:0.55984	validation_1-logloss:0.59149
# [589]	validation_0-logloss:0.55980	validation_1-logloss:0.59149
# [590]	validation_0-logloss:0.55974	validation_1-logloss:0.59148
# [591]	validation_0-logloss:0.55964	validation_1-logloss:0.59144
# [592]	validation_0-logloss:0.55956	validation_1-logloss:0.59140
# [593]	validation_0-logloss:0.55950	validation_1-logloss:0.59138
# [594]	validation_0-logloss:0.55943	validation_1-logloss:0.59136
# [595]	validation_0-logloss:0.55936	validation_1-logloss:0.59135
# [596]	validation_0-logloss:0.55932	validation_1-logloss:0.59135
# [597]	validation_0-logloss:0.55926	validation_1-logloss:0.59135
# [598]	validation_0-logloss:0.55921	validation_1-logloss:0.59135
# [599]	validation_0-logloss:0.55914	validation_1-logloss:0.59136
# [600]	validation_0-logloss:0.55910	validation_1-logloss:0.59136
# [601]	validation_0-logloss:0.55904	validation_1-logloss:0.59134
# [602]	validation_0-logloss:0.55898	validation_1-logloss:0.59134
# [603]	validation_0-logloss:0.55892	validation_1-logloss:0.59135
# [604]	validation_0-logloss:0.55884	validation_1-logloss:0.59133
# [605]	validation_0-logloss:0.55881	validation_1-logloss:0.59134
# [606]	validation_0-logloss:0.55870	validation_1-logloss:0.59129
# [607]	validation_0-logloss:0.55864	validation_1-logloss:0.59130
# [608]	validation_0-logloss:0.55859	validation_1-logloss:0.59131
# [609]	validation_0-logloss:0.55853	validation_1-logloss:0.59132
# [610]	validation_0-logloss:0.55848	validation_1-logloss:0.59132
# [611]	validation_0-logloss:0.55843	validation_1-logloss:0.59133
# [612]	validation_0-logloss:0.55839	validation_1-logloss:0.59133
# [613]	validation_0-logloss:0.55831	validation_1-logloss:0.59132
# [614]	validation_0-logloss:0.55827	validation_1-logloss:0.59133
# [615]	validation_0-logloss:0.55823	validation_1-logloss:0.59133
# [616]	validation_0-logloss:0.55817	validation_1-logloss:0.59133
# [617]	validation_0-logloss:0.55812	validation_1-logloss:0.59133
# [618]	validation_0-logloss:0.55806	validation_1-logloss:0.59133
# [619]	validation_0-logloss:0.55800	validation_1-logloss:0.59134
# [620]	validation_0-logloss:0.55794	validation_1-logloss:0.59132
# [621]	validation_0-logloss:0.55787	validation_1-logloss:0.59130
# [622]	validation_0-logloss:0.55781	validation_1-logloss:0.59130
# [623]	validation_0-logloss:0.55777	validation_1-logloss:0.59130
# [624]	validation_0-logloss:0.55773	validation_1-logloss:0.59131
# [625]	validation_0-logloss:0.55767	validation_1-logloss:0.59132
# [626]	validation_0-logloss:0.55761	validation_1-logloss:0.59132
# [627]	validation_0-logloss:0.55754	validation_1-logloss:0.59132
# [628]	validation_0-logloss:0.55747	validation_1-logloss:0.59131
# [629]	validation_0-logloss:0.55742	validation_1-logloss:0.59132
# [630]	validation_0-logloss:0.55735	validation_1-logloss:0.59130
# [631]	validation_0-logloss:0.55729	validation_1-logloss:0.59129
# [632]	validation_0-logloss:0.55724	validation_1-logloss:0.59129
# [633]	validation_0-logloss:0.55720	validation_1-logloss:0.59130
# [634]	validation_0-logloss:0.55714	validation_1-logloss:0.59129
# [635]	validation_0-logloss:0.55709	validation_1-logloss:0.59128
# [636]	validation_0-logloss:0.55703	validation_1-logloss:0.59126
# [637]	validation_0-logloss:0.55697	validation_1-logloss:0.59127
# [638]	validation_0-logloss:0.55692	validation_1-logloss:0.59127
# [639]	validation_0-logloss:0.55687	validation_1-logloss:0.59128
# [640]	validation_0-logloss:0.55682	validation_1-logloss:0.59128
# [641]	validation_0-logloss:0.55676	validation_1-logloss:0.59130
# [642]	validation_0-logloss:0.55671	validation_1-logloss:0.59130
# [643]	validation_0-logloss:0.55666	validation_1-logloss:0.59131
# [644]	validation_0-logloss:0.55660	validation_1-logloss:0.59130
# [645]	validation_0-logloss:0.55655	validation_1-logloss:0.59130
# [646]	validation_0-logloss:0.55649	validation_1-logloss:0.59129
# [647]	validation_0-logloss:0.55644	validation_1-logloss:0.59130
# [648]	validation_0-logloss:0.55637	validation_1-logloss:0.59130
# [649]	validation_0-logloss:0.55630	validation_1-logloss:0.59127
# [650]	validation_0-logloss:0.55625	validation_1-logloss:0.59126
# [651]	validation_0-logloss:0.55620	validation_1-logloss:0.59127
# [652]	validation_0-logloss:0.55614	validation_1-logloss:0.59127
# [653]	validation_0-logloss:0.55609	validation_1-logloss:0.59127
# [654]	validation_0-logloss:0.55603	validation_1-logloss:0.59127
# [655]	validation_0-logloss:0.55599	validation_1-logloss:0.59127
# [656]	validation_0-logloss:0.55594	validation_1-logloss:0.59128
# [657]	validation_0-logloss:0.55589	validation_1-logloss:0.59128
# [658]	validation_0-logloss:0.55584	validation_1-logloss:0.59128
# [659]	validation_0-logloss:0.55577	validation_1-logloss:0.59127
# [660]	validation_0-logloss:0.55573	validation_1-logloss:0.59127
# [661]	validation_0-logloss:0.55568	validation_1-logloss:0.59128
# [662]	validation_0-logloss:0.55562	validation_1-logloss:0.59127
# [663]	validation_0-logloss:0.55557	validation_1-logloss:0.59126
# [664]	validation_0-logloss:0.55552	validation_1-logloss:0.59127
# [665]	validation_0-logloss:0.55546	validation_1-logloss:0.59127
# [666]	validation_0-logloss:0.55540	validation_1-logloss:0.59127
# [667]	validation_0-logloss:0.55537	validation_1-logloss:0.59126
# [668]	validation_0-logloss:0.55531	validation_1-logloss:0.59126
# [669]	validation_0-logloss:0.55528	validation_1-logloss:0.59125
# [670]	validation_0-logloss:0.55521	validation_1-logloss:0.59126
# [671]	validation_0-logloss:0.55516	validation_1-logloss:0.59126
# [672]	validation_0-logloss:0.55510	validation_1-logloss:0.59126
# [673]	validation_0-logloss:0.55502	validation_1-logloss:0.59122
# [674]	validation_0-logloss:0.55499	validation_1-logloss:0.59124
# [675]	validation_0-logloss:0.55493	validation_1-logloss:0.59122
# [676]	validation_0-logloss:0.55487	validation_1-logloss:0.59120
# [677]	validation_0-logloss:0.55480	validation_1-logloss:0.59119
# [678]	validation_0-logloss:0.55474	validation_1-logloss:0.59120
# [679]	validation_0-logloss:0.55469	validation_1-logloss:0.59120
# [680]	validation_0-logloss:0.55464	validation_1-logloss:0.59119
# [681]	validation_0-logloss:0.55458	validation_1-logloss:0.59120
# [682]	validation_0-logloss:0.55454	validation_1-logloss:0.59120
# [683]	validation_0-logloss:0.55450	validation_1-logloss:0.59121
# [684]	validation_0-logloss:0.55445	validation_1-logloss:0.59121
# [685]	validation_0-logloss:0.55439	validation_1-logloss:0.59121
# [686]	validation_0-logloss:0.55433	validation_1-logloss:0.59122
# [687]	validation_0-logloss:0.55428	validation_1-logloss:0.59120
# [688]	validation_0-logloss:0.55423	validation_1-logloss:0.59120
# [689]	validation_0-logloss:0.55416	validation_1-logloss:0.59118
# [690]	validation_0-logloss:0.55410	validation_1-logloss:0.59119
# [691]	validation_0-logloss:0.55405	validation_1-logloss:0.59118
# [692]	validation_0-logloss:0.55401	validation_1-logloss:0.59118
# [693]	validation_0-logloss:0.55396	validation_1-logloss:0.59118
# [694]	validation_0-logloss:0.55390	validation_1-logloss:0.59117
# [695]	validation_0-logloss:0.55385	validation_1-logloss:0.59118
# [696]	validation_0-logloss:0.55378	validation_1-logloss:0.59118
# [697]	validation_0-logloss:0.55372	validation_1-logloss:0.59117
# [698]	validation_0-logloss:0.55366	validation_1-logloss:0.59117
# [699]	validation_0-logloss:0.55359	validation_1-logloss:0.59117
# [700]	validation_0-logloss:0.55353	validation_1-logloss:0.59116
# [701]	validation_0-logloss:0.55348	validation_1-logloss:0.59116
# [702]	validation_0-logloss:0.55342	validation_1-logloss:0.59115
# [703]	validation_0-logloss:0.55336	validation_1-logloss:0.59115
# [704]	validation_0-logloss:0.55328	validation_1-logloss:0.59113
# [705]	validation_0-logloss:0.55322	validation_1-logloss:0.59115
# [706]	validation_0-logloss:0.55316	validation_1-logloss:0.59113
# [707]	validation_0-logloss:0.55311	validation_1-logloss:0.59113
# [708]	validation_0-logloss:0.55306	validation_1-logloss:0.59112
# [709]	validation_0-logloss:0.55300	validation_1-logloss:0.59111
# [710]	validation_0-logloss:0.55293	validation_1-logloss:0.59111
# [711]	validation_0-logloss:0.55287	validation_1-logloss:0.59110
# [712]	validation_0-logloss:0.55282	validation_1-logloss:0.59111
# [713]	validation_0-logloss:0.55276	validation_1-logloss:0.59112
# [714]	validation_0-logloss:0.55271	validation_1-logloss:0.59113
# [715]	validation_0-logloss:0.55266	validation_1-logloss:0.59114
# [716]	validation_0-logloss:0.55256	validation_1-logloss:0.59109
# [717]	validation_0-logloss:0.55251	validation_1-logloss:0.59110
# [718]	validation_0-logloss:0.55246	validation_1-logloss:0.59110
# [719]	validation_0-logloss:0.55243	validation_1-logloss:0.59111
# [720]	validation_0-logloss:0.55235	validation_1-logloss:0.59109
# [721]	validation_0-logloss:0.55227	validation_1-logloss:0.59106
# [722]	validation_0-logloss:0.55222	validation_1-logloss:0.59107
# [723]	validation_0-logloss:0.55216	validation_1-logloss:0.59107
# [724]	validation_0-logloss:0.55212	validation_1-logloss:0.59106
# [725]	validation_0-logloss:0.55206	validation_1-logloss:0.59106
# [726]	validation_0-logloss:0.55200	validation_1-logloss:0.59106
# [727]	validation_0-logloss:0.55194	validation_1-logloss:0.59106
# [728]	validation_0-logloss:0.55189	validation_1-logloss:0.59107
# [729]	validation_0-logloss:0.55183	validation_1-logloss:0.59107
# [730]	validation_0-logloss:0.55176	validation_1-logloss:0.59107
# [731]	validation_0-logloss:0.55171	validation_1-logloss:0.59108
# [732]	validation_0-logloss:0.55166	validation_1-logloss:0.59108
# [733]	validation_0-logloss:0.55159	validation_1-logloss:0.59108
# [734]	validation_0-logloss:0.55153	validation_1-logloss:0.59109
# [735]	validation_0-logloss:0.55148	validation_1-logloss:0.59109
# [736]	validation_0-logloss:0.55142	validation_1-logloss:0.59109
# [737]	validation_0-logloss:0.55137	validation_1-logloss:0.59110
# [738]	validation_0-logloss:0.55132	validation_1-logloss:0.59107
# [739]	validation_0-logloss:0.55125	validation_1-logloss:0.59107
# [740]	validation_0-logloss:0.55120	validation_1-logloss:0.59108
# [741]	validation_0-logloss:0.55111	validation_1-logloss:0.59103
# [742]	validation_0-logloss:0.55105	validation_1-logloss:0.59102
# [743]	validation_0-logloss:0.55099	validation_1-logloss:0.59103
# [744]	validation_0-logloss:0.55094	validation_1-logloss:0.59103
# [745]	validation_0-logloss:0.55089	validation_1-logloss:0.59105
# [746]	validation_0-logloss:0.55083	validation_1-logloss:0.59104
# [747]	validation_0-logloss:0.55077	validation_1-logloss:0.59104
# [748]	validation_0-logloss:0.55073	validation_1-logloss:0.59104
# [749]	validation_0-logloss:0.55065	validation_1-logloss:0.59103
# [750]	validation_0-logloss:0.55058	validation_1-logloss:0.59102
# ...
# [818]	validation_0-logloss:0.54678	validation_1-logloss:0.59071
# [819]	validation_0-logloss:0.54674	validation_1-logloss:0.59071
# [820]	validation_0-logloss:0.54661	validation_1-logloss:0.59064
# [821]	validation_0-logloss:0.54657	validation_1-logloss:0.59065
# [822]	validation_0-logloss:0.54651	validation_1-logloss:0.59065
# [823]	validation_0-logloss:0.54646	validation_1-logloss:0.59066
# [824]	validation_0-logloss:0.54641	validation_1-logloss:0.59066
# [825]	validation_0-logloss:0.54634	validation_1-logloss:0.59066
# [826]	validation_0-logloss:0.54630	validation_1-logloss:0.59067
# [827]	validation_0-logloss:0.54624	validation_1-logloss:0.59066
# [828]	validation_0-logloss:0.54619	validation_1-logloss:0.59066
# [829]	validation_0-logloss:0.54614	validation_1-logloss:0.59066
# [830]	validation_0-logloss:0.54609	validation_1-logloss:0.59066
# [831]	validation_0-logloss:0.54604	validation_1-logloss:0.59067
# [832]	validation_0-logloss:0.54601	validation_1-logloss:0.59067
# [833]	validation_0-logloss:0.54597	validation_1-logloss:0.59068
# [834]	validation_0-logloss:0.54591	validation_1-logloss:0.59068
# [835]	validation_0-logloss:0.54588	validation_1-logloss:0.59069
# [836]	validation_0-logloss:0.54583	validation_1-logloss:0.59069
# [837]	validation_0-logloss:0.54578	validation_1-logloss:0.59069
# [838]	validation_0-logloss:0.54572	validation_1-logloss:0.59069
# [839]	validation_0-logloss:0.54566	validation_1-logloss:0.59068
# [840]	validation_0-logloss:0.54560	validation_1-logloss:0.59068
# [841]	validation_0-logloss:0.54555	validation_1-logloss:0.59068
# [842]	validation_0-logloss:0.54551	validation_1-logloss:0.59068
# [843]	validation_0-logloss:0.54545	validation_1-logloss:0.59067
# [844]	validation_0-logloss:0.54541	validation_1-logloss:0.59067
# [845]	validation_0-logloss:0.54537	validation_1-logloss:0.59066
# [846]	validation_0-logloss:0.54534	validation_1-logloss:0.59067
# [847]	validation_0-logloss:0.54530	validation_1-logloss:0.59068
# [848]	validation_0-logloss:0.54524	validation_1-logloss:0.59066
# [849]	validation_0-logloss:0.54519	validation_1-logloss:0.59067
# [850]	validation_0-logloss:0.54513	validation_1-logloss:0.59066
# [851]	validation_0-logloss:0.54507	validation_1-logloss:0.59066
# [852]	validation_0-logloss:0.54501	validation_1-logloss:0.59066
# [853]	validation_0-logloss:0.54496	validation_1-logloss:0.59066
# [854]	validation_0-logloss:0.54491	validation_1-logloss:0.59065
# [855]	validation_0-logloss:0.54484	validation_1-logloss:0.59064
# [856]	validation_0-logloss:0.54480	validation_1-logloss:0.59064
# [857]	validation_0-logloss:0.54475	validation_1-logloss:0.59065
# [858]	validation_0-logloss:0.54470	validation_1-logloss:0.59066
# [859]	validation_0-logloss:0.54465	validation_1-logloss:0.59066
# [860]	validation_0-logloss:0.54459	validation_1-logloss:0.59066
# [861]	validation_0-logloss:0.54454	validation_1-logloss:0.59065
# [862]	validation_0-logloss:0.54449	validation_1-logloss:0.59064
# [863]	validation_0-logloss:0.54443	validation_1-logloss:0.59065
# [864]	validation_0-logloss:0.54437	validation_1-logloss:0.59065
# [865]	validation_0-logloss:0.54432	validation_1-logloss:0.59065
# [866]	validation_0-logloss:0.54428	validation_1-logloss:0.59064
# [867]	validation_0-logloss:0.54422	validation_1-logloss:0.59064
# [868]	validation_0-logloss:0.54417	validation_1-logloss:0.59063
# [869]	validation_0-logloss:0.54411	validation_1-logloss:0.59063
# [870]	validation_0-logloss:0.54405	validation_1-logloss:0.59062
# [871]	validation_0-logloss:0.54394	validation_1-logloss:0.59055
# [872]	validation_0-logloss:0.54388	validation_1-logloss:0.59056
# [873]	validation_0-logloss:0.54384	validation_1-logloss:0.59057
# [874]	validation_0-logloss:0.54378	validation_1-logloss:0.59056
# [875]	validation_0-logloss:0.54372	validation_1-logloss:0.59056
# [876]	validation_0-logloss:0.54368	validation_1-logloss:0.59056
# [877]	validation_0-logloss:0.54363	validation_1-logloss:0.59056
# [878]	validation_0-logloss:0.54357	validation_1-logloss:0.59055
# [879]	validation_0-logloss:0.54352	validation_1-logloss:0.59056
# [880]	validation_0-logloss:0.54348	validation_1-logloss:0.59057
# [881]	validation_0-logloss:0.54342	validation_1-logloss:0.59058
# [882]	validation_0-logloss:0.54338	validation_1-logloss:0.59059
# [883]	validation_0-logloss:0.54332	validation_1-logloss:0.59059
# [884]	validation_0-logloss:0.54327	validation_1-logloss:0.59060
# [885]	validation_0-logloss:0.54319	validation_1-logloss:0.59055
# [886]	validation_0-logloss:0.54314	validation_1-logloss:0.59056
# [887]	validation_0-logloss:0.54308	validation_1-logloss:0.59056
# [888]	validation_0-logloss:0.54303	validation_1-logloss:0.59054
# [889]	validation_0-logloss:0.54297	validation_1-logloss:0.59054
# [890]	validation_0-logloss:0.54292	validation_1-logloss:0.59054
# [891]	validation_0-logloss:0.54286	validation_1-logloss:0.59053
# [892]	validation_0-logloss:0.54282	validation_1-logloss:0.59053
# [893]	validation_0-logloss:0.54277	validation_1-logloss:0.59053
# [894]	validation_0-logloss:0.54271	validation_1-logloss:0.59054
# [895]	validation_0-logloss:0.54265	validation_1-logloss:0.59053
# [896]	validation_0-logloss:0.54259	validation_1-logloss:0.59054
# [897]	validation_0-logloss:0.54254	validation_1-logloss:0.59052
# [898]	validation_0-logloss:0.54248	validation_1-logloss:0.59052
# [899]	validation_0-logloss:0.54242	validation_1-logloss:0.59051
# [900]	validation_0-logloss:0.54236	validation_1-logloss:0.59052
# [901]	validation_0-logloss:0.54230	validation_1-logloss:0.59050
# [902]	validation_0-logloss:0.54226	validation_1-logloss:0.59049
# [903]	validation_0-logloss:0.54221	validation_1-logloss:0.59048
# [904]	validation_0-logloss:0.54217	validation_1-logloss:0.59049
# [905]	validation_0-logloss:0.54212	validation_1-logloss:0.59048
# [906]	validation_0-logloss:0.54208	validation_1-logloss:0.59049
# [907]	validation_0-logloss:0.54205	validation_1-logloss:0.59049
# [908]	validation_0-logloss:0.54199	validation_1-logloss:0.59050
# [909]	validation_0-logloss:0.54194	validation_1-logloss:0.59051
# [910]	validation_0-logloss:0.54188	validation_1-logloss:0.59050
# [911]	validation_0-logloss:0.54183	validation_1-logloss:0.59050
# [912]	validation_0-logloss:0.54178	validation_1-logloss:0.59051
# [913]	validation_0-logloss:0.54173	validation_1-logloss:0.59051
# [914]	validation_0-logloss:0.54169	validation_1-logloss:0.59052
# [915]	validation_0-logloss:0.54162	validation_1-logloss:0.59052
# [916]	validation_0-logloss:0.54157	validation_1-logloss:0.59052
# [917]	validation_0-logloss:0.54153	validation_1-logloss:0.59053
# [918]	validation_0-logloss:0.54148	validation_1-logloss:0.59053
# [919]	validation_0-logloss:0.54145	validation_1-logloss:0.59053
# [920]	validation_0-logloss:0.54139	validation_1-logloss:0.59053
# [921]	validation_0-logloss:0.54134	validation_1-logloss:0.59055
# [922]	validation_0-logloss:0.54129	validation_1-logloss:0.59054
# [923]	validation_0-logloss:0.54121	validation_1-logloss:0.59052
# [924]	validation_0-logloss:0.54116	validation_1-logloss:0.59053
# [925]	validation_0-logloss:0.54110	validation_1-logloss:0.59052
# [926]	validation_0-logloss:0.54105	validation_1-logloss:0.59052
# [927]	validation_0-logloss:0.54100	validation_1-logloss:0.59051
# [928]	validation_0-logloss:0.54095	validation_1-logloss:0.59052
# [929]	validation_0-logloss:0.54090	validation_1-logloss:0.59051
# [930]	validation_0-logloss:0.54085	validation_1-logloss:0.59052
# [931]	validation_0-logloss:0.54081	validation_1-logloss:0.59051
# [932]	validation_0-logloss:0.54076	validation_1-logloss:0.59052
# [933]	validation_0-logloss:0.54072	validation_1-logloss:0.59052
# [934]	validation_0-logloss:0.54066	validation_1-logloss:0.59050
# [935]	validation_0-logloss:0.54061	validation_1-logloss:0.59050
# [936]	validation_0-logloss:0.54055	validation_1-logloss:0.59048
# [937]	validation_0-logloss:0.54049	validation_1-logloss:0.59048
# [938]	validation_0-logloss:0.54045	validation_1-logloss:0.59048
# [939]	validation_0-logloss:0.54040	validation_1-logloss:0.59048
# [940]	validation_0-logloss:0.54035	validation_1-logloss:0.59048
# [941]	validation_0-logloss:0.54031	validation_1-logloss:0.59048
# [942]	validation_0-logloss:0.54025	validation_1-logloss:0.59049
# [943]	validation_0-logloss:0.54019	validation_1-logloss:0.59047
# [944]	validation_0-logloss:0.54015	validation_1-logloss:0.59048
# [945]	validation_0-logloss:0.54010	validation_1-logloss:0.59049
# [946]	validation_0-logloss:0.54005	validation_1-logloss:0.59048
# [947]	validation_0-logloss:0.53997	validation_1-logloss:0.59046
# [948]	validation_0-logloss:0.53992	validation_1-logloss:0.59047
# [949]	validation_0-logloss:0.53988	validation_1-logloss:0.59047
# [950]	validation_0-logloss:0.53983	validation_1-logloss:0.59047
# [951]	validation_0-logloss:0.53978	validation_1-logloss:0.59048
# [952]	validation_0-logloss:0.53972	validation_1-logloss:0.59048
# [953]	validation_0-logloss:0.53968	validation_1-logloss:0.59048
# [954]	validation_0-logloss:0.53963	validation_1-logloss:0.59048
# [955]	validation_0-logloss:0.53960	validation_1-logloss:0.59049
# [956]	validation_0-logloss:0.53955	validation_1-logloss:0.59049
# [957]	validation_0-logloss:0.53949	validation_1-logloss:0.59048
# [958]	validation_0-logloss:0.53945	validation_1-logloss:0.59048
# [959]	validation_0-logloss:0.53939	validation_1-logloss:0.59048
# [960]	validation_0-logloss:0.53933	validation_1-logloss:0.59048
# [961]	validation_0-logloss:0.53927	validation_1-logloss:0.59047
# [962]	validation_0-logloss:0.53922	validation_1-logloss:0.59047
# [963]	validation_0-logloss:0.53916	validation_1-logloss:0.59046
# [964]	validation_0-logloss:0.53912	validation_1-logloss:0.59045
# [965]	validation_0-logloss:0.53908	validation_1-logloss:0.59045
# [966]	validation_0-logloss:0.53904	validation_1-logloss:0.59045
# [967]	validation_0-logloss:0.53898	validation_1-logloss:0.59044
# [968]	validation_0-logloss:0.53893	validation_1-logloss:0.59044
# [969]	validation_0-logloss:0.53887	validation_1-logloss:0.59044
# [970]	validation_0-logloss:0.53883	validation_1-logloss:0.59044
# [971]	validation_0-logloss:0.53878	validation_1-logloss:0.59044
# [972]	validation_0-logloss:0.53874	validation_1-logloss:0.59044
# [973]	validation_0-logloss:0.53870	validation_1-logloss:0.59044
# [974]	validation_0-logloss:0.53863	validation_1-logloss:0.59041
# [975]	validation_0-logloss:0.53858	validation_1-logloss:0.59041
# [976]	validation_0-logloss:0.53854	validation_1-logloss:0.59041
# [977]	validation_0-logloss:0.53851	validation_1-logloss:0.59041
# [978]	validation_0-logloss:0.53845	validation_1-logloss:0.59041
# [979]	validation_0-logloss:0.53839	validation_1-logloss:0.59042
# [980]	validation_0-logloss:0.53836	validation_1-logloss:0.59043
# [981]	validation_0-logloss:0.53831	validation_1-logloss:0.59043
# [982]	validation_0-logloss:0.53827	validation_1-logloss:0.59043
# [983]	validation_0-logloss:0.53823	validation_1-logloss:0.59043
# [984]	validation_0-logloss:0.53818	validation_1-logloss:0.59043
# [985]	validation_0-logloss:0.53813	validation_1-logloss:0.59042
# [986]	validation_0-logloss:0.53807	validation_1-logloss:0.59043
# [987]	validation_0-logloss:0.53801	validation_1-logloss:0.59043
# [988]	validation_0-logloss:0.53797	validation_1-logloss:0.59043
# [989]	validation_0-logloss:0.53792	validation_1-logloss:0.59043
# [990]	validation_0-logloss:0.53786	validation_1-logloss:0.59044
# [991]	validation_0-logloss:0.53781	validation_1-logloss:0.59043
# [992]	validation_0-logloss:0.53776	validation_1-logloss:0.59042
# [993]	validation_0-logloss:0.53771	validation_1-logloss:0.59042
# [994]	validation_0-logloss:0.53765	validation_1-logloss:0.59044
# [995]	validation_0-logloss:0.53758	validation_1-logloss:0.59041
# [996]	validation_0-logloss:0.53753	validation_1-logloss:0.59041
# [997]	validation_0-logloss:0.53747	validation_1-logloss:0.59042
# [998]	validation_0-logloss:0.53744	validation_1-logloss:0.59041
# [999]	validation_0-logloss:0.53738	validation_1-logloss:0.59040
# [1000]	validation_0-logloss:0.53734	validation_1-logloss:0.59039
# [1001]	validation_0-logloss:0.53728	validation_1-logloss:0.59039
# [1002]	validation_0-logloss:0.53723	validation_1-logloss:0.59039
# [1003]	validation_0-logloss:0.53718	validation_1-logloss:0.59037
# [1004]	validation_0-logloss:0.53713	validation_1-logloss:0.59037
# [1005]	validation_0-logloss:0.53709	validation_1-logloss:0.59036
# [1006]	validation_0-logloss:0.53705	validation_1-logloss:0.59036
# [1007]	validation_0-logloss:0.53700	validation_1-logloss:0.59037
# [1008]	validation_0-logloss:0.53696	validation_1-logloss:0.59036
# [1009]	validation_0-logloss:0.53691	validation_1-logloss:0.59036
# [1010]	validation_0-logloss:0.53686	validation_1-logloss:0.59036
# [1011]	validation_0-logloss:0.53682	validation_1-logloss:0.59037
# [1012]	validation_0-logloss:0.53678	validation_1-logloss:0.59037
# [1013]	validation_0-logloss:0.53671	validation_1-logloss:0.59036
# [1014]	validation_0-logloss:0.53666	validation_1-logloss:0.59034
# [1015]	validation_0-logloss:0.53660	validation_1-logloss:0.59033
# [1016]	validation_0-logloss:0.53657	validation_1-logloss:0.59033
# [1017]	validation_0-logloss:0.53652	validation_1-logloss:0.59034
# [1018]	validation_0-logloss:0.53648	validation_1-logloss:0.59034
# [1019]	validation_0-logloss:0.53644	validation_1-logloss:0.59036
# [1020]	validation_0-logloss:0.53640	validation_1-logloss:0.59035
# [1021]	validation_0-logloss:0.53636	validation_1-logloss:0.59035
# [1022]	validation_0-logloss:0.53632	validation_1-logloss:0.59036
# [1023]	validation_0-logloss:0.53628	validation_1-logloss:0.59037
# [1024]	validation_0-logloss:0.53621	validation_1-logloss:0.59037
# [1025]	validation_0-logloss:0.53617	validation_1-logloss:0.59037
# [1026]	validation_0-logloss:0.53613	validation_1-logloss:0.59038
# [1027]	validation_0-logloss:0.53608	validation_1-logloss:0.59038
# [1028]	validation_0-logloss:0.53602	validation_1-logloss:0.59037
# [1029]	validation_0-logloss:0.53597	validation_1-logloss:0.59037
# [1030]	validation_0-logloss:0.53592	validation_1-logloss:0.59037
# [1031]	validation_0-logloss:0.53588	validation_1-logloss:0.59037
# [1032]	validation_0-logloss:0.53583	validation_1-logloss:0.59038
# [1033]	validation_0-logloss:0.53579	validation_1-logloss:0.59039
# [1034]	validation_0-logloss:0.53574	validation_1-logloss:0.59040
# [1035]	validation_0-logloss:0.53569	validation_1-logloss:0.59041
# [1036]	validation_0-logloss:0.53564	validation_1-logloss:0.59042
# [1037]	validation_0-logloss:0.53558	validation_1-logloss:0.59042
# [1038]	validation_0-logloss:0.53555	validation_1-logloss:0.59042
# [1039]	validation_0-logloss:0.53551	validation_1-logloss:0.59042
# [1040]	validation_0-logloss:0.53547	validation_1-logloss:0.59042
# [1041]	validation_0-logloss:0.53543	validation_1-logloss:0.59043
# [1042]	validation_0-logloss:0.53536	validation_1-logloss:0.59041
# [1043]	validation_0-logloss:0.53530	validation_1-logloss:0.59040
# [1044]	validation_0-logloss:0.53525	validation_1-logloss:0.59040
# [1045]	validation_0-logloss:0.53520	validation_1-logloss:0.59040
# [1046]	validation_0-logloss:0.53515	validation_1-logloss:0.59039
# [1047]	validation_0-logloss:0.53509	validation_1-logloss:0.59037
# [1048]	validation_0-logloss:0.53506	validation_1-logloss:0.59038
# [1049]	validation_0-logloss:0.53501	validation_1-logloss:0.59037
# [1050]	validation_0-logloss:0.53496	validation_1-logloss:0.59037
# [1051]	validation_0-logloss:0.53492	validation_1-logloss:0.59037
# [1052]	validation_0-logloss:0.53489	validation_1-logloss:0.59038
# [1053]	validation_0-logloss:0.53484	validation_1-logloss:0.59039
# [1054]	validation_0-logloss:0.53478	validation_1-logloss:0.59038
# [1055]	validation_0-logloss:0.53475	validation_1-logloss:0.59039
# [1056]	validation_0-logloss:0.53470	validation_1-logloss:0.59039
# [1057]	validation_0-logloss:0.53466	validation_1-logloss:0.59040
# [1058]	validation_0-logloss:0.53462	validation_1-logloss:0.59040
# [1059]	validation_0-logloss:0.53457	validation_1-logloss:0.59039
# [1060]	validation_0-logloss:0.53451	validation_1-logloss:0.59039
# [1061]	validation_0-logloss:0.53447	validation_1-logloss:0.59041
# [1062]	validation_0-logloss:0.53441	validation_1-logloss:0.59041
# [1063]	validation_0-logloss:0.53437	validation_1-logloss:0.59041
# [1064]	validation_0-logloss:0.53431	validation_1-logloss:0.59041
# [1065]	validation_0-logloss:0.53425	validation_1-logloss:0.59041

# %%
# LOAD
classifier_spin = XGBClassifier()
classifier_spin.load_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta05.json")


y_score = classifier_spin.predict_proba(X_test_spin)[:, 1]


fpr, tpr, thresholds = roc_curve(y_test_spin, y_score)
roc_auc = roc_auc_score(y_test_spin, y_score)

print("Global AUC =", roc_auc)


plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + 'saved-results/ROC_classB.pdf', bbox_inches='tight')
plt.show()




keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$',
                #  r'$m_{\mathrm{LQ}}^{\mathrm{reg}}$',
                 r'$S_{\mathrm{Poiss}}$'])

feature_important = classifier_spin.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())


data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=12).remove()
plt.title(r'SLQ vs VLQ', fontsize=14)
# plt.savefig(mainfolder + 'saved-results/XG_feature_importance_classB.pdf', bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Global AUC = 0.744574974336
# [52, 19, 22, 53, 35, 18, 9, 15, 36, 38, 37, 45, 3, 48, 46]

# %%
S_column = X_test_spin[:, -1]

# mSLQ_plot = [1200, 1500, 1800]
# mVLQ_plot = [1600, 1900, 2200]

linestyles = ['-','-','-', '--','--','--', ':', ':', ':']
# colors_SLQ = ['lightcoral', 'red', 'firebrick']
# colors_VLQ = ['limegreen', 'green', 'darkgreen']

plt.figure(figsize=(6,5))

# evaluate per sector
for iit, S_id in enumerate(S_expected_SLQ):
    # if iit == 0 or iit == 1 or iit == 9:
    #     continue
    # else:
    if iit == 2 or iit == 5 or iit == 8:

        mask = (S_column < S_id * 1.1) & (0.9 * S_id < S_column)

        y_true_Spoiss = y_test_spin[mask]
        y_score_Spoiss = y_score[mask]

        fpr, tpr, _ = roc_curve(y_true_Spoiss, y_score_Spoiss)
        auc_sector = roc_auc_score(y_true_Spoiss, y_score_Spoiss)

        print(f"$m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV,   AUC = {auc_sector:.5f}")


        plt.plot(fpr, tpr, color='darkorange', linestyle=linestyles[iit], lw=2, label=f"AUC = {auc_sector:.3f}, $m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV - $m_{{LQ_3^V}}=${masses_VLQ[iit]} GeV")



plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=11.3)
# plt.savefig(mainfolder + 'saved-results/ROC_classB_multi.pdf', bbox_inches='tight')
plt.show()
# Out:
# $m_{LQ_3^S}=$1200 GeV,   AUC = 0.77429
# $m_{LQ_3^S}=$1500 GeV,   AUC = 0.73324
# $m_{LQ_3^S}=$1800 GeV,   AUC = 0.70063

# %% [markdown]
# # JOIN BOTH ML

# %%
# --- Clasificador A: SM vs LQ ---

scoresA_SM = xgb_clf.predict_proba( df_SM_norm )[:,1]

scoresA_SLQ = {}
scoresA_VLQ = {}

m_SLQ = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
m_VLQ = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

S_exp_SLQ = S_expected_SLQ[2:]
S_exp_both = S_mean_fit_both[2:]

for m in m_SLQ:
    scoresA_SLQ[m] = xgb_clf.predict_proba( df_SLQ_norm[m] )[:,1]

for m in m_VLQ:
    scoresA_VLQ[m] = xgb_clf.predict_proba( df_VLQ_norm[m] )[:,1]

# %%
# --- Clasificador B: SLQ vs VLQ ---

X_sm = df_SM_norm

rand_samples_B =np.random.randint(1, S_exp_both[0] + S_std_fit_both[0], size=len(X_sm))

X_sm = np.column_stack([X_sm, rand_samples_B])

scoresB_SM = classifier_spin.predict_proba(X_sm)[:,1]


scoresB_SLQ = {}
scoresB_VLQ = {}

for iit, S_id in enumerate(m_SLQ):

    X_s = df_SLQ_norm[m_SLQ[iit]].values
    X_v = df_VLQ_norm[m_VLQ[iit]].values

    poisson_samples_SLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_s))
    poisson_samples_VLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_v))

    X_s = np.column_stack([X_s, poisson_samples_SLQ])
    X_v = np.column_stack([X_v, poisson_samples_VLQ])

    scoresB_SLQ[m_SLQ[iit]] = classifier_spin.predict_proba(X_s)[:,1]
    scoresB_VLQ[m_VLQ[iit]] = classifier_spin.predict_proba(X_v)[:,1]

# %%
# --- Juntar los scores del clasificador A y B

events_SM = np.column_stack([scoresA_SM, scoresB_SM])

events_SLQ = {}
for m in scoresA_SLQ:
    events_SLQ[m] = np.column_stack([scoresA_SLQ[m], scoresB_SLQ[m]])

events_VLQ = {}
for m in scoresA_VLQ:
    events_VLQ[m] = np.column_stack([scoresA_VLQ[m], scoresB_VLQ[m]])

# %% [markdown]
# #### Define the test statistic

# %%
def compute_test_statistic(scoresA, scoresB, threshold):
    """
    Sum of Log-Likelihood Ratios (LLR)

    T = Sum log (P(VLQ) / P(SLQ))

    P(VLQ) = score SLQ vs VLQ classifier
    P(SLQ) = 1 - score SLQ vs VLQ classifier
    """

    mask = scoresA > threshold

    scoresB_sel = scoresB[mask]

    if len(scoresB_sel) == 0:
        return 0

    eps = 1e-6
    s = np.clip(scoresB_sel, eps, 1-eps)

    T = np.sum(np.log(s/(1-s)))

    return T

# %% [markdown]
# ### For all the masses

# %%
# funcion para generar pseudo experimentos (da los scores de ambos clasificadores para ese pseudo)

def generate_pseudo(events_B, events_S, N_B, N_S):

    sample_B = events_B[np.random.randint(len(events_B), size=N_B)]
    sample_S = events_S[np.random.randint(len(events_S), size=N_S)]

    sample_all = np.vstack([sample_B, sample_S])

    scoresA = sample_all[:,0]
    scoresB = sample_all[:,1]

    return scoresA, scoresB

# %%
B_expected = 45962

S_exp_SLQ = [round(fid_xsec_SLQ_14TeV(mmm, beta) * Lum) for mmm in m_SLQ]
S_exp_VLQ = [round(fid_xsec_VLQ_14TeV(mmm, beta) * Lum) for mmm in m_VLQ]

print('beta = ', beta)
print('\nB_expected: ', B_expected)
print('\nS_exp_SLQ: ', S_exp_SLQ, '   m =', m_SLQ)
print('S_exp_VLQ: ', S_exp_VLQ, '   m =', m_VLQ)
print('S_exp_both: ', S_exp_both)
# Out:
# beta =  0.5
#
# B_expected:  45962
#
# S_exp_SLQ:  [742, 419, 237, 137, 80, 46, 27, 16]    m = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_exp_VLQ:  [796, 466, 273, 163, 98, 59, 36, 22]    m = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_exp_both:  [np.float64(716.5390716900451), np.float64(415.51247301678785), np.float64(240.39687758908138), np.float64(141.0400289713429), np.float64(83.34188842314936), np.float64(48.76682160245706), np.float64(29.056321490798403), np.float64(17.504661401920984)]

# %% [markdown]
# #### Distribution of the statistic with only SLQ and only VLQ

# %%
n_pseudo_TRUE = 1000
threshold_A = 0.95

# %%
mu_S = []
mu_V = []

sigma_S = []
sigma_V = []

for S_it in range(len(S_exp_SLQ)):

    print("\n==========================")
    print("S_expected SLQ =", S_exp_SLQ[S_it])
    # print("S_expected VLQ =", S_exp_VLQ[S_it]) # same number of events

    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[S_it]
    mass_VLQ = m_VLQ[S_it]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    for i in range(n_pseudo_TRUE):

        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_exp_SLQ[S_it])

        scoresA, scoresB = generate_pseudo( events_SM, events_SLQ[mass_SLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)


        N_S = np.random.poisson(S_exp_SLQ[S_it]) # same number of events

        scoresA, scoresB = generate_pseudo( events_SM, events_VLQ[mass_VLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

        # Compute the Z of the distributions
    mu_S.append( np.mean(T_SLQ) )
    mu_V.append( np.mean(T_VLQ) )

    sigma_S.append( np.std(T_SLQ) )
    sigma_V.append( np.std(T_VLQ) )

print(mu_S)
print(mu_V)

print(sigma_S)
print(sigma_V)
# Out:
# ==========================
# S_expected SLQ = 742
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
#
# ==========================
# S_expected SLQ = 419
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
#
# ==========================
# S_expected SLQ = 237
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
#
# ==========================
# S_expected SLQ = 137
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
#
# ==========================
# S_expected SLQ = 80
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
#
# ==========================
# S_expected SLQ = 46
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
#
# ==========================
# S_expected SLQ = 27
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
#
# ==========================
# S_expected SLQ = 16
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# [np.float32(-317.2854), np.float32(-187.64868), np.float32(-111.04605), np.float32(-72.859764), np.float32(-50.683586), np.float32(-39.14717), np.float32(-32.07821), np.float32(-28.372362)]
# [np.float32(488.93344), np.float32(226.93213), np.float32(98.72759), np.float32(40.17714), np.float32(9.018736), np.float32(-6.719428), np.float32(-13.369871), np.float32(-17.87195)]
# [np.float32(26.63966), np.float32(20.2794), np.float32(16.006886), np.float32(13.571372), np.float32(12.19982), np.float32(11.431946), np.float32(11.3327465), np.float32(10.583824)]
# [np.float32(38.91754), np.float32(28.59329), np.float32(20.30921), np.float32(16.537203), np.float32(13.651253), np.float32(12.542689), np.float32(11.423927), np.float32(10.8552885)]

# %%
f_mu_S = interp1d(S_exp_SLQ, mu_S, kind='linear', fill_value="extrapolate")
f_mu_V = interp1d(S_exp_SLQ, mu_V, kind='linear', fill_value="extrapolate")

f_sigma_S = interp1d(S_exp_SLQ, sigma_S, kind='linear', fill_value="extrapolate")
f_sigma_V = interp1d(S_exp_SLQ, sigma_V, kind='linear', fill_value="extrapolate")



S_plot = np.linspace(min(S_exp_SLQ), max(S_exp_SLQ), 100)



plt.scatter(S_exp_SLQ, mu_S, marker='o')
plt.plot(S_plot, f_mu_S(S_plot))
plt.scatter(S_exp_SLQ, mu_V, marker='o')
plt.plot(S_plot, f_mu_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\mu$", fontsize=14)

plt.grid()
plt.show()


plt.scatter(S_exp_SLQ, sigma_S, marker='o')
plt.plot(S_plot, f_sigma_S(S_plot))
plt.scatter(S_exp_SLQ, sigma_V, marker='o')
plt.plot(S_plot, f_sigma_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\sigma$", fontsize=14)

plt.grid()
plt.show()

# %%
Z_threshold = 5

results_Z_gauss = []

for pair_it in range(len(mu_S)):
    Z = abs(mu_V[pair_it] - mu_S[pair_it]) / np.sqrt(sigma_S[pair_it]**2 + sigma_V[pair_it]**2)

    results_Z_gauss.append(Z)


plt.plot(S_exp_SLQ, results_Z_gauss, marker='o')

plt.xlabel("Expected signal events", fontsize=14)
plt.ylabel("Distribution discrimination Z", fontsize=14)

plt.grid()
plt.show()


#  interpolate
f_results_Z = interp1d(S_exp_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mSLQ = interp1d(m_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mVLQ = interp1d(m_VLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")


# find the S or the mass such that we get Z_threshold
S_threshold = fsolve(lambda x: f_results_Z(x) - Z_threshold,150)[0]
mSLQ_threshold = fsolve(lambda x: f_results_Z_mSLQ(x) - Z_threshold,1500)[0]
mVLQ_threshold = fsolve(lambda x: f_results_Z_mVLQ(x) - Z_threshold,1900)[0]

print(' Z:       ', Z_threshold)
print(' S:       ', S_threshold)
print(' m_SLQ:   ', mSLQ_threshold, ' [GeV]')
print(' m_VLQ:   ', mVLQ_threshold, ' [GeV]\n')
# Out:
#  Z:        5
#  S:        129.0025168129327
#  m_SLQ:    1514.0306722580128  [GeV]
#  m_VLQ:    1914.0306722580128  [GeV]

# %% [markdown]
# #### Prepare the data

# %% [markdown]
# ##### To compute S_expected for each pseudo using the 1st classifier we need the PDFs

# %%
# --- Clasificador A: SM vs LQ ---

# output of all the signal events
scoresA_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]



bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scoresA_SM, bins=bins, density=True)
hist_S, _ = np.histogram(scoresA_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %% [markdown]
# ##### to compute the closest mass/index/bechmark

# %%
def search_bench(S_pseudo, S_list_means, S_list_std, masses_list=None):
    """ finds the index of the closest benchmark

    Inputs:
    -----------
    S_pseudo : float -> S computed or fitted (e.g. muS_fits_SLQ[i]).
    S_list_means : list/array -> S_mean_fit_both_NEW.
    S_list_std : list/array -> S_std_fit_both_NEW.
    masses_list : list/array (optional) -> masses_NEW.

    Outputs:
    --------
    if masses_list es None -> returns only the index
    if masses_list se incluye -> returns (index, closest mass).
    """
    # convert to array
    means = np.array(S_list_means)
    stds = np.array(S_list_std)

    # do not divide by 0
    stds = np.where(stds == 0, 1e-10, stds)

    # compute the distance to the means, weighted by the std
    z_scores = np.abs(S_pseudo - means) / stds

    # seach the closest index
    idx_min = np.argmin(z_scores)

    # if you also want the mass
    if masses_list is not None:
        best_mass = masses_list[idx_min]
        return idx_min, best_mass

    return idx_min

# %% [markdown]
# ### Super loop

# %%
Z_threshold = 1.96

n_pseudo = 1000

# benchmarks
classification_SLQ_BPOK = []
classification_VLQ_BPOK = []

# interpolate
classification_SLQ_inter = []
classification_VLQ_inter = []

# previously known PDFs
classification_SLQ_prev = []
classification_VLQ_prev = []


Z_SLQ_BPOK = []
Z_VLQ_BPOK = []

Z_SLQ_inter = []
Z_VLQ_inter = []

Z_SLQ_prev = []
Z_VLQ_prev = []


mu_TSLQ = []
std_TSLQ = []
mu_TVLQ = []
std_TVLQ = []



for ii_S, S_exp in enumerate(S_exp_SLQ):

    print("\n==========================")

    print("S_expected_SLQ =", S_exp_SLQ[ii_S])
    # print("S_expected_VLQ =", S_exp_VLQ[ii_S]) # same number of events


    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[ii_S]
    mass_VLQ = m_VLQ[ii_S]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    # compute the number of events
    muS_fits_SLQ = []
    muS_fits_VLQ = []


    for i in range(n_pseudo):

        N_B = np.random.poisson(B_expected)

        # indices of the events
        idx_B = np.random.choice(len(events_SM[:,0]), N_B)

        scoresA_B = events_SM[:,0][idx_B]
        scoresB_B = events_SM[:,1][idx_B]



        ###########
        # FOR SLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S])

        # indices of the events
        idx_S = np.random.choice(len(events_SLQ[mass_SLQ][:,0]), N_S)

        scoresA_S = events_SLQ[mass_SLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_SLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_S = df_SLQ_norm[mass_SLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_S = np.column_stack([X_pseudo_S, np.full(len(X_pseudo_S), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_S)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)




        ###########
        # FOR VLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S]) # same number of events

        # indices of the events
        idx_S = np.random.choice(len(events_VLQ[mass_VLQ][:,0]), N_S)

        scoresA_S = events_VLQ[mass_VLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_VLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_V = df_VLQ_norm[mass_VLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_V = np.column_stack([X_pseudo_V, np.full(len(X_pseudo_V), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_V)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

    # Compute the characteristics of the psedo-experiment T distributions
    mu_TSLQ.append( np.mean(T_SLQ) )
    mu_TVLQ.append( np.mean(T_VLQ) )

    std_TSLQ.append( np.std(T_SLQ) )
    std_TVLQ.append( np.std(T_VLQ) )




    # rango común para plotear
    xmin = min(np.min(T_SLQ), np.min(T_VLQ))
    xmax = max(np.max(T_SLQ), np.max(T_VLQ))
    x = np.linspace(xmin, xmax, 500)

    # gaussianas
    gauss_S = (1/(sigma_S[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_S[ii_S])**2 / (2*sigma_S[ii_S]**2))
    gauss_V = (1/(sigma_V[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_V[ii_S])**2 / (2*sigma_V[ii_S]**2))


    # plot gaussian PDFs + pseudo-experiments (of the same sector) distributions
    plt.figure(figsize=(6,5))

    plt.hist(T_SLQ, bins=20, density=True, color='red', alpha=0.6, label="SLQ pseudos")
    plt.hist(T_VLQ, bins=20, density=True, color='green', alpha=0.6, label="VLQ pseudos")

    # gaussianas
    plt.plot(x, gauss_S, color='darkred', linewidth=2, linestyle='--', label=f"Gaussian SLQ true\nμ={mu_S[ii_S]:.2f}, σ={sigma_S[ii_S]:.2f}")
    plt.plot(x, gauss_V, color='darkgreen', linewidth=2, linestyle='--', label=f"Gaussian VLQ true\nμ={mu_V[ii_S]:.2f}, σ={sigma_V[ii_S]:.2f}")

    plt.xlabel("Test statistic T")
    plt.ylabel("Probability density")
    plt.title(f"S_expected = {S_exp}")
    plt.legend()

    plt.show()


    plt.hist(muS_fits_SLQ, bins=10, histtype='step', linestyle='--', edgecolor='red', linewidth=2, density=True)
    plt.hist(muS_fits_SLQ, bins=10, color='red', alpha=0.6, density=True)
    plt.hist(muS_fits_VLQ, bins=10, histtype='step', linestyle=':', edgecolor='green', linewidth=2, density=True)
    plt.hist(muS_fits_VLQ, bins=10, color='green', alpha=0.6, density=True)
    plt.xlabel("S")
    plt.ylabel("Fraction (prediction)")
    plt.show()

    print('S mean SLQ: ', np.mean(muS_fits_SLQ))
    print('S std SLQ: ', np.std(muS_fits_SLQ))
    print('S mean VLQ: ', np.mean(muS_fits_VLQ))
    print('S std VLQ: ', np.std(muS_fits_VLQ))
    print('')


    # COMPARING WITH DISCRETE MASS EXAMPLES (following S)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_BPOK_step = []
    Z_VLQ_BPOK_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        index_pseudo = search_bench(muS_fits_SLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_SLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        index_pseudo = search_bench(muS_fits_VLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_VLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_BPOK.append(np.array(Z_SLQ_BPOK_step))
    Z_VLQ_BPOK.append(np.array(Z_VLQ_BPOK_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH DISCRETE MASS EXAMPLES (following S) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_BPOK.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_BPOK.append(pred_counts_VLQ)





    # COMPARING WITH CONTINUOUS MASSES (interpolation)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_inter_step = []
    Z_VLQ_inter_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_SLQ[i])) / f_sigma_S(muS_fits_SLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_SLQ[i])) / f_sigma_V(muS_fits_SLQ[i])

        Z_SLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_VLQ[i])) / f_sigma_S(muS_fits_VLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_VLQ[i])) / f_sigma_V(muS_fits_VLQ[i])

        Z_VLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_inter.append(np.array(Z_SLQ_inter_step))
    Z_VLQ_inter.append(np.array(Z_VLQ_inter_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH CONTINUOUS MASSES (interpolation) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_inter.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_inter.append(pred_counts_VLQ)





    # COMPARING WITH THE PREVIOUSLY KNOWN PDF

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_prev_step = []
    Z_VLQ_prev_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_SLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_VLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_prev.append(np.array(Z_SLQ_prev_step))
    Z_VLQ_prev.append(np.array(Z_VLQ_prev_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH THE PREVIOUSLY KNOWN PDF ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_prev.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_prev.append(pred_counts_VLQ)
# Out:
# ==========================
# S_expected_SLQ = 742
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
# S mean SLQ:  690.2689756746147
# S std SLQ:  34.39502956419331
# S mean VLQ:  741.2238758989323
# S std VLQ:  28.85434863089557
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.894
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.106
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.849
# 2 = both     : 0.0
# 3 = neither  : 0.151
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.759
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.241
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.956
# 2 = both     : 0.0
# 3 = neither  : 0.044
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.94
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.06
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.917
# 2 = both     : 0.0
# 3 = neither  : 0.083
#
# ==========================
# S_expected_SLQ = 419
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
# S mean SLQ:  407.52067800466995
# S std SLQ:  23.23796563382449
# S mean VLQ:  424.5507551309725
# S std VLQ:  24.48558087683722
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.954
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.046
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.767
# 2 = both     : 0.0
# 3 = neither  : 0.233
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.892
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.108
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.914
# 2 = both     : 0.0
# 3 = neither  : 0.086
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.957
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.043
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.768
# 2 = both     : 0.0
# 3 = neither  : 0.232
#
# ==========================
# S_expected_SLQ = 237
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
# S mean SLQ:  238.69161583518317
# S std SLQ:  19.859999658579305
# S mean VLQ:  243.7067994144232
# S std VLQ:  20.391058383783808
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.95
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.05
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.905
# 2 = both     : 0.0
# 3 = neither  : 0.095
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.938
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.062
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.958
# 2 = both     : 0.0
# 3 = neither  : 0.042
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.954
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.046
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.897
# 2 = both     : 0.0
# 3 = neither  : 0.103
#
# ==========================
# S_expected_SLQ = 137
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
# S mean SLQ:  141.37185110572946
# S std SLQ:  17.11940882672502
# S mean VLQ:  141.7278304902278
# S std VLQ:  17.012425111927467
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.956
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.044
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.939
# 2 = both     : 0.0
# 3 = neither  : 0.061
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.956
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.044
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.954
# 2 = both     : 0.0
# 3 = neither  : 0.046
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.957
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.043
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.932
# 2 = both     : 0.0
# 3 = neither  : 0.068
#
# ==========================
# S_expected_SLQ = 80
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
# S mean SLQ:  84.89626525403071
# S std SLQ:  15.511718221284452
# S mean VLQ:  83.72277482229354
# S std VLQ:  15.2187792311414
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.915
# 1 = VLQ only : 0.006
# 2 = both     : 0.006
# 3 = neither  : 0.073
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.004
# 1 = VLQ only : 0.946
# 2 = both     : 0.006
# 3 = neither  : 0.044
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.934
# 1 = VLQ only : 0.003
# 2 = both     : 0.003
# 3 = neither  : 0.06
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.004
# 1 = VLQ only : 0.951
# 2 = both     : 0.003
# 3 = neither  : 0.042
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.957
# 1 = VLQ only : 0.009
# 2 = both     : 0.0
# 3 = neither  : 0.034
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.004
# 1 = VLQ only : 0.935
# 2 = both     : 0.0
# 3 = neither  : 0.061
#
# ==========================
# S_expected_SLQ = 46
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
# S mean SLQ:  50.23040409953036
# S std SLQ:  13.986744704324929
# S mean VLQ:  48.183147489239126
# S std VLQ:  13.342522602211956
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.71
# 1 = VLQ only : 0.023
# 2 = both     : 0.232
# 3 = neither  : 0.035
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.023
# 1 = VLQ only : 0.7
# 2 = both     : 0.248
# 3 = neither  : 0.029
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.742
# 1 = VLQ only : 0.036
# 2 = both     : 0.208
# 3 = neither  : 0.014
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.029
# 1 = VLQ only : 0.731
# 2 = both     : 0.22
# 3 = neither  : 0.02
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.694
# 1 = VLQ only : 0.029
# 2 = both     : 0.26
# 3 = neither  : 0.017
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.021
# 1 = VLQ only : 0.742
# 2 = both     : 0.217
# 3 = neither  : 0.02
#
# ==========================
# S_expected_SLQ = 27
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
# S mean SLQ:  30.038202431284457
# S std SLQ:  12.672891841482283
# S mean VLQ:  29.36474117864851
# S std VLQ:  12.423033735248707
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.359
# 1 = VLQ only : 0.037
# 2 = both     : 0.587
# 3 = neither  : 0.017
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.036
# 1 = VLQ only : 0.389
# 2 = both     : 0.555
# 3 = neither  : 0.02
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.336
# 1 = VLQ only : 0.038
# 2 = both     : 0.605
# 3 = neither  : 0.021
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.035
# 1 = VLQ only : 0.364
# 2 = both     : 0.576
# 3 = neither  : 0.025
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.331
# 1 = VLQ only : 0.021
# 2 = both     : 0.628
# 3 = neither  : 0.02
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.023
# 1 = VLQ only : 0.32
# 2 = both     : 0.637
# 3 = neither  : 0.02
#
# ==========================
# S_expected_SLQ = 16
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# S mean SLQ:  18.300860118006486
# S std SLQ:  11.555936810558524
# S mean VLQ:  17.835254172713125
# S std VLQ:  11.58344877556762
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.202
# 1 = VLQ only : 0.041
# 2 = both     : 0.742
# 3 = neither  : 0.015
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.043
# 1 = VLQ only : 0.227
# 2 = both     : 0.715
# 3 = neither  : 0.015
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.172
# 1 = VLQ only : 0.036
# 2 = both     : 0.764
# 3 = neither  : 0.028
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.043
# 1 = VLQ only : 0.172
# 2 = both     : 0.741
# 3 = neither  : 0.044
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.146
# 1 = VLQ only : 0.029
# 2 = both     : 0.794
# 3 = neither  : 0.031
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.021
# 1 = VLQ only : 0.163
# 2 = both     : 0.785
# 3 = neither  : 0.031

# %%
def Z_processor(lista_Z, select):
    """computes the median and error (percentiles 16 y 84)
    select = 1 ---> SLQ (true) vs VLQ
    select = 0 ---> VLQ (true) vs SLQ
    """
    medians = []
    err_inf = []
    err_sup = []

    for z_matriz in lista_Z:
        z_valores = z_matriz[:, select]
        med = np.median(z_valores)
        p16 = np.percentile(z_valores, 16)
        p84 = np.percentile(z_valores, 84)

        medians.append(med)
        err_inf.append(med - p16)  # percentile
        err_sup.append(p84 - med)  # percentile

    return np.array(medians), [np.array(err_inf), np.array(err_sup)]

# Compute
z_BPOK_SLQ, err_BPOK_SLQ = Z_processor(Z_SLQ_BPOK, select=1)
z_BPOK_VLQ, err_BPOK_VLQ = Z_processor(Z_VLQ_BPOK, select=0)
z_inter_SLQ, err_inter_SLQ = Z_processor(Z_SLQ_inter, select=1)
z_inter_VLQ, err_inter_VLQ = Z_processor(Z_VLQ_inter, select=0)
z_prev_SLQ, err_prev_SLQ = Z_processor(Z_SLQ_prev, select=1)
z_prev_VLQ, err_prev_VLQ = Z_processor(Z_VLQ_prev, select=0)



# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(m_SLQ), z_BPOK_SLQ, err_BPOK_SLQ)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(m_VLQ), z_BPOK_VLQ, err_BPOK_VLQ)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(m_SLQ), z_inter_SLQ, err_inter_SLQ)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(m_VLQ), z_inter_VLQ, err_inter_VLQ)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(m_SLQ), z_prev_SLQ, err_prev_SLQ)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(m_VLQ), z_prev_VLQ, err_prev_VLQ)


# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')


# PLOT
plt.figure(figsize=(7, 6))

plt.errorbar(m_SLQ, z_BPOK_SLQ, yerr=err_BPOK_SLQ, color='red', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Benchmarks)')
plt.errorbar(m_VLQ, z_BPOK_VLQ, yerr=err_BPOK_VLQ, color='green', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Benchmarks)')
plt.errorbar(m_SLQ, z_inter_SLQ, yerr=err_inter_SLQ, color='darkred', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Interpolated)')
plt.errorbar(m_VLQ, z_inter_VLQ, yerr=err_inter_VLQ, color='darkgreen', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Interpolated)')
plt.errorbar(m_SLQ, z_prev_SLQ, yerr=err_prev_SLQ, color='pink', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Known PDF)')
plt.errorbar(m_VLQ, z_prev_VLQ, yerr=err_prev_VLQ, color='lime', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Known PDF)')

plt.axhline(y=5.0, color='blue', linestyle='-', linewidth=1.5, label='5σ')

# plt.ylim(0, 25)
plt.xlabel(r"$m_{LQ}$ [GeV]", fontsize=12)
plt.ylabel(r"$Z$", fontsize=12)
plt.grid(True)
plt.legend(fontsize=12, loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1574.8748748748749 [GeV]      ( 1541.2412412412414 - 1614.8148148148148 )
# VLQ mass:  1997.2972972972973 [GeV]      ( 1962.962962962963 - 2055.455455455455 )
#
# Interpolated
# SLQ mass:  1577.6776776776776 [GeV]      ( 1541.2412412412414 - 1616.9169169169168 )
# VLQ mass:  1998.6986986986988 [GeV]      ( 1962.962962962963 - 2058.258258258258 )
#
# Known PDF
# SLQ mass:  1573.4734734734734 [GeV]      ( 1540.5405405405404 - 1607.1071071071071 )
# VLQ mass:  1996.5965965965966 [GeV]      ( 1964.3643643643643 - 2051.2512512512512 )

# %%
class_SLQ_BPOK_array = np.array(classification_SLQ_BPOK) # Forma (N, 4)
class_VLQ_BPOK_array = np.array(classification_VLQ_BPOK) # Forma (N, 4)

class_SLQ_inter_array = np.array(classification_SLQ_inter) # Forma (N, 4)
class_VLQ_inter_array = np.array(classification_VLQ_inter) # Forma (N, 4)

class_SLQ_prev_array = np.array(classification_SLQ_prev) # Forma (N, 4)
class_VLQ_prev_array = np.array(classification_VLQ_prev) # Forma (N, 4)

# SAVE

file_path = mainfolder + 'saved-results/vs14TeV_err_beta05.txt'

# Combine all data into a single array
data_to_save = np.column_stack([
    S_expected_SLQ[2:],
    m_SLQ,
    m_VLQ,
    mu_S,
    sigma_S,
    mu_V,
    sigma_V,
    mu_TSLQ,
    std_TSLQ,
    mu_TVLQ,
    std_TVLQ,
    class_SLQ_BPOK_array,
    class_VLQ_BPOK_array,
    class_SLQ_inter_array,
    class_VLQ_inter_array,
    class_SLQ_prev_array,
    class_VLQ_prev_array,
    z_BPOK_SLQ,
    err_BPOK_SLQ[0],
    err_BPOK_SLQ[1],
    z_BPOK_VLQ,
    err_BPOK_VLQ[0],
    err_BPOK_VLQ[1],
    z_inter_SLQ,
    err_inter_SLQ[0],
    err_inter_SLQ[1],
    z_inter_VLQ,
    err_inter_VLQ[0],
    err_inter_VLQ[1],
    z_prev_SLQ,
    err_prev_SLQ[0],
    err_prev_SLQ[1],
    z_prev_VLQ,
    err_prev_VLQ[0],
    err_prev_VLQ[1],
])

# Save data to a text file
np.savetxt(file_path, data_to_save, fmt='%.6f',
           header='# S_expected mass_list_SLQ mass_list_SLQ mu_S sigma_S mu_V sigma_V mu_TSLQ std_TSLQ mu_TVLQ std_TVLQ classification_SLQ classification_VLQ',
           comments='')

print(f"Data saved to: {file_path}")
# Out:
# Data saved to: /content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/saved-results/vs14TeV_err_beta05.txt

# %%
# LOAD

file_path = mainfolder + 'saved-results/vs14TeV_err_beta05.txt'

loaded_data = np.loadtxt(file_path)

S_expected = loaded_data[:, 0]
mass_list_SLQ = loaded_data[:, 1]
mass_list_VLQ = loaded_data[:, 2]
mu_S = loaded_data[:, 3]
sigma_S = loaded_data[:, 4]
mu_V = loaded_data[:, 5]
sigma_V = loaded_data[:, 6]
mu_TSLQ = loaded_data[:, 7]
std_TSLQ = loaded_data[:, 8]
mu_TVLQ = loaded_data[:, 9]
std_TVLQ = loaded_data[:, 10]
classification_SLQ_BPOK = loaded_data[:, 11:15]
classification_VLQ_BPOK = loaded_data[:, 15:19]
classification_SLQ_inter = loaded_data[:, 19:23]
classification_VLQ_inter = loaded_data[:, 23:27]
classification_SLQ_prev = loaded_data[:, 27:31]
classification_VLQ_prev = loaded_data[:, 31:35]
z_BPOK_SLQ = loaded_data[:, 35]
err_BPOK_SLQ = np.concatenate([loaded_data[:, 36], loaded_data[:, 37]])
z_BPOK_VLQ = loaded_data[:, 38]
err_BPOK_VLQ = np.concatenate([loaded_data[:, 39], loaded_data[:, 40]])
z_inter_SLQ = loaded_data[:, 41]
err_inter_SLQ = np.concatenate([loaded_data[:, 42], loaded_data[:, 43]])
z_inter_VLQ = loaded_data[:, 44]
err_inter_VLQ = np.concatenate([loaded_data[:, 45], loaded_data[:, 46]])
z_prev_SLQ = loaded_data[:, 47]
err_prev_SLQ = np.concatenate([loaded_data[:, 48], loaded_data[:, 49]])
z_prev_VLQ = loaded_data[:, 50]
err_prev_VLQ = np.concatenate([loaded_data[:, 51], loaded_data[:, 52]])





n_pseudo_TRUE = 1000
threshold_A = 0.95

print('n_pseudo_TRUE: ', n_pseudo_TRUE)
print('threshold_A: ', threshold_A)
# Out:
# n_pseudo_TRUE:  1000
# threshold_A:  0.95

# %%
# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_BPOK_SLQ, err_BPOK_SLQ, z_target=5.0)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_BPOK_VLQ, err_BPOK_VLQ, z_target=5.0)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_inter_SLQ, err_inter_SLQ, z_target=5.0)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_inter_VLQ, err_inter_VLQ, z_target=5.0)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_prev_SLQ, err_prev_SLQ, z_target=5.0)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_prev_VLQ, err_prev_VLQ, z_target=5.0)

# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1574.8748748748749 [GeV]      ( 1548.2482482482483 - 1602.902902902903 )
# VLQ mass:  1997.2972972972973 [GeV]      ( 1951.051051051051 - 2114.3143143143143 )
#
# Interpolated
# SLQ mass:  1577.6776776776776 [GeV]      ( 1548.948948948949 - 1605.7057057057057 )
# VLQ mass:  1998.6986986986988 [GeV]      ( 1955.2552552552552 - 2114.3143143143143 )
#
# Known PDF
# SLQ mass:  1573.4734734734734 [GeV]      ( 1546.8468468468468 - 1601.5015015015015 )
# VLQ mass:  1996.5965965965966 [GeV]      ( 1951.051051051051 - 2111.5115115115113 )

# %%
# LOAD

file_path = mainfolder + 'saved-results/Z13TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_13TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_13TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_13TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_13TeV = loaded_data[:, 4]
m_BL_exc_SLQ_13TeV = loaded_data[:, 5]
m_BL_dis_SLQ_13TeV = loaded_data[:, 6]
m_BL_exc_VLQ_13TeV = loaded_data[:, 7]
m_BL_dis_VLQ_13TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_13TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_13TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_13TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_13TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_13TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_13TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_13TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_13TeV = loaded_data[:, 16]


# LOAD

file_path = mainfolder + 'saved-results/Z136TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_136TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_136TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_136TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_136TeV = loaded_data[:, 4]
m_BL_exc_SLQ_136TeV = loaded_data[:, 5]
m_BL_dis_SLQ_136TeV = loaded_data[:, 6]
m_BL_exc_VLQ_136TeV = loaded_data[:, 7]
m_BL_dis_VLQ_136TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_136TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_136TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_136TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_136TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_136TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_136TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_136TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_136TeV = loaded_data[:, 16]




# LOAD

file_path = mainfolder + 'saved-results/Z14TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_14TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_14TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_14TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_14TeV = loaded_data[:, 4]
m_BL_exc_SLQ_14TeV = loaded_data[:, 5]
m_BL_dis_SLQ_14TeV = loaded_data[:, 6]
m_BL_exc_VLQ_14TeV = loaded_data[:, 7]
m_BL_dis_VLQ_14TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_14TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_14TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_14TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_14TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_14TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_14TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_14TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_14TeV = loaded_data[:, 16]

# %%
# plot BINNED LIKEHOOD

plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_SLQ_13TeV, betas, 'o:', c='red', label='13 TeV, 139 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_high_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_14TeV, betas, 'o-', c='red', label='14 TeV, 3000 fb-1 (Dis SLQ)')
plt.plot(m_BL_dis_SLQ_low_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_high_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_14TeV, betas, 'o--', c='red', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_14TeV, betas, '--', c='red', alpha=0.25)
plt.plot(m_BL_exc_SLQ_high_14TeV, betas, '--', c='red', alpha=0.25)


# benchmarks
m_SLQ_T_Z5 = [[m5_BPOK_SLQ - m5_BPOK_SLQ_inf], [m5_BPOK_SLQ_sup - m5_BPOK_SLQ]]
plt.errorbar(m5_BPOK_SLQ, 0.54, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (BP)')

# interpolated
m_SLQ_T_Z5 = [[m5_inter_SLQ - m5_inter_SLQ_inf], [m5_inter_SLQ_sup - m5_inter_SLQ]]
plt.errorbar(m5_inter_SLQ, 0.5, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (interpolated)')

# known pdf
m_SLQ_T_Z5 = [[m5_prev_SLQ - m5_prev_SLQ_inf], [m5_prev_SLQ_sup - m5_prev_SLQ]]
plt.errorbar(m5_prev_SLQ, 0.46, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()





plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_VLQ_13TeV, betas, 'o:', c='green', label='13 TeV, 139 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_high_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_14TeV, betas, 'o-', c='green', label='14 TeV, 3000 fb-1 (Dis VLQ)')
plt.plot(m_BL_dis_VLQ_low_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_high_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_14TeV, betas, 'o--', c='green', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_14TeV, betas, '-', c='green', alpha=0.25)
plt.plot(m_BL_exc_VLQ_high_14TeV, betas, '-', c='green', alpha=0.25)


# benchmarks
m_VLQ_T_Z5 = [[m5_BPOK_VLQ - m5_BPOK_VLQ_inf], [m5_BPOK_VLQ_sup - m5_BPOK_VLQ]]
plt.errorbar(m5_BPOK_VLQ, 0.54, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (BP)')

# interpolated
m_VLQ_T_Z5 = [[m5_inter_VLQ - m5_inter_VLQ_inf], [m5_inter_VLQ_sup - m5_inter_VLQ]]
plt.errorbar(m5_inter_VLQ, 0.5, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (interpolated)')

# knwon pdf
m_VLQ_T_Z5 = [[m5_prev_VLQ - m5_prev_VLQ_inf], [m5_prev_VLQ_sup - m5_prev_VLQ]]
plt.errorbar(m5_prev_VLQ, 0.46, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
