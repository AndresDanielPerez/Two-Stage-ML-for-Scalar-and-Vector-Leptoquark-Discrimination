# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mainfolder = '/content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec

import os
import joblib  # to save the scaler

from numba import njit # for the LQ mass reconstruction

from scipy.optimize import fsolve, minimize
from scipy import stats
from scipy.stats import poisson
from scipy.stats import ks_2samp
from scipy.stats import anderson_ksamp
from scipy.stats import wasserstein_distance
from scipy.stats import chisquare
from scipy.interpolate import interp1d

import math
import random

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc, accuracy_score
from sklearn.metrics import mean_squared_error, r2_score

from xgboost import XGBRegressor, XGBClassifier
import xgboost as xgb

# %% [markdown]
# # LOAD DATA

# %% [markdown]
# ## Background

# %%
CHs_selected = ["tt", "singletP1", "singletP2", "Wbbjets", "ttW", "ttZ", "ttH"]


df_B_all = {}
X_B_all = {}


output_folder = mainfolder + "../DATA/backgrounds/data_df/"

for CH_sel in CHs_selected:
    # Read the file
    if CH_sel == 'singletP2':
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-singlet-comp/df_' + CH_sel + ".csv"
    else:
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-' + CH_sel + '/df_' + CH_sel + ".csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_B_all[CH_sel] = df_temp
    X_B_all[CH_sel] = df_temp[feats_label].values

    # Print
    print(f"X_{CH_sel}.shape: {X_B_all[CH_sel].shape}")
# Out:
# X_tt.shape: (826022, 53)
# X_singletP1.shape: (179677, 53)
# X_singletP2.shape: (94219, 53)
# X_Wbbjets.shape: (162448, 53)
# X_ttW.shape: (141919, 53)
# X_ttZ.shape: (16178, 53)
# X_ttH.shape: (12068, 53)

# %% [markdown]
# ## Signal SLQ

# %%
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2200]
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]


df_SLQ_all = {}
X_SLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_SLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-SLQ-' + str(mass_sel) + 'GeV/df_SLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_SLQ_all[mass_sel] = df_temp
    X_SLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_SLQ_{mass_sel}GeV.shape: {X_SLQ_all[mass_sel].shape}")
# Out:
# X_SLQ_1000GeV.shape: (267452, 53)
# X_SLQ_1100GeV.shape: (271062, 53)
# X_SLQ_1200GeV.shape: (534247, 53)
# X_SLQ_1300GeV.shape: (196510, 53)
# X_SLQ_1400GeV.shape: (506381, 53)
# X_SLQ_1500GeV.shape: (185940, 53)
# X_SLQ_1600GeV.shape: (481827, 53)
# X_SLQ_1700GeV.shape: (173573, 53)
# X_SLQ_1800GeV.shape: (301687, 53)
# X_SLQ_1900GeV.shape: (64690, 53)

# %% [markdown]
# ## Signal VLQ

# %%
masses_VLQ = [1200, 1500, 1400, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
masses_VLQ = [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]


df_VLQ_all = {}
X_VLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_VLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-VLQ-' + str(mass_sel) + 'GeV/df_VLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_VLQ_all[mass_sel] = df_temp
    X_VLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_VLQ_{mass_sel}GeV.shape: {X_VLQ_all[mass_sel].shape}")
# Out:
# X_VLQ_1400GeV.shape: (139696, 53)
# X_VLQ_1500GeV.shape: (293700, 53)
# X_VLQ_1600GeV.shape: (134774, 53)
# X_VLQ_1700GeV.shape: (192819, 53)
# X_VLQ_1800GeV.shape: (127670, 53)
# X_VLQ_1900GeV.shape: (75898, 53)
# X_VLQ_2000GeV.shape: (184097, 53)
# X_VLQ_2100GeV.shape: (72762, 53)
# X_VLQ_2200GeV.shape: (232166, 53)
# X_VLQ_2300GeV.shape: (64705, 53)

# %% [markdown]
# # Cross Section

# %%
Lum = 3000

# %%
# -------------------------
# cross sections
# -------------------------
k_LQ = 1.8877462860822058

xsec_file_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV.txt'

xsec_data_14TeV = np.loadtxt(xsec_file_14TeV, comments='#')

# columns: 0=mass, 1=SLQ, 2=VLQ
masses_14TeV = xsec_data_14TeV[:,0].astype(int)
fidxsec_SLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,1]*k_LQ))
fidxsec_VLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,2]*k_LQ))


masses_SLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]
masses_VLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]

fidxsec_SLQ_non0_14TeV = [fidxsec_SLQ_14TeV[ii] for ii in masses_SLQ_14TeV]
fidxsec_VLQ_non0_14TeV = [fidxsec_VLQ_14TeV[ii] for ii in masses_VLQ_14TeV]


#  interpolate
f_xsec_SLQ_log_14TeV = interp1d(masses_SLQ_14TeV, np.log10(fidxsec_SLQ_non0_14TeV), kind='linear', fill_value="extrapolate")
f_xsec_VLQ_log_14TeV = interp1d(masses_VLQ_14TeV, np.log10(fidxsec_VLQ_non0_14TeV), kind='linear', fill_value="extrapolate")



# -------------------------
# cross sections
# -------------------------
xsec_file_betas_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV-betas.txt'

xsec_data_betas_14TeV = np.loadtxt(xsec_file_betas_14TeV, comments='#')

# columns: 0=beta, 1,...=SLQ, -1=ratio=fid_xsec(beta)/fid_xsec(beta=0.5)
betas = xsec_data_betas_14TeV[:,0]
ratio_mean_14TeV = xsec_data_betas_14TeV[:,-1]

#  interpolate
f_ratio_SLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")
f_ratio_VLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")



# FINAL FUNCTIONS
def fid_xsec_SLQ_14TeV(mass, beta):
    return 10**f_xsec_SLQ_log_14TeV(mass) * f_ratio_SLQ_log_14TeV(beta)

def fid_xsec_VLQ_14TeV(mass, beta):
    return 10**f_xsec_VLQ_log_14TeV(mass) * f_ratio_VLQ_log_14TeV(beta)

# %%
masses = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

beta = 0.0

fidxsec_SLQ = dict(zip(masses, fid_xsec_SLQ_14TeV(masses, beta)))
fidxsec_VLQ = dict(zip(masses, fid_xsec_VLQ_14TeV(masses, beta)))


print('masses: ', masses)
print(fidxsec_SLQ[1200], '[fb]')
print(fidxsec_VLQ[1600], '[fb]')
# Out:
# masses:  [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# 0.03266226761689409 [fb]
# 0.03501152733272929 [fb]

# %%
# -----------------------------------
# LQs number and fid cross sections
# -----------------------------------


for m_it in masses_SLQ:
    print(f"# eventos SLQ {m_it} GeV:", len(X_SLQ_all[m_it]), "  fid_xsec = ", fidxsec_SLQ[m_it], "[fb]")

print(" ")
for m_it in masses_VLQ:
    print(f"# eventos VLQ {m_it} GeV:", len(X_VLQ_all[m_it]), "  fid_xsec = ", fidxsec_VLQ[m_it], "[fb]")
# Out:
# # eventos SLQ 1000 GeV: 267452   fid_xsec =  0.10228793017500255 [fb]
# # eventos SLQ 1100 GeV: 271062   fid_xsec =  0.05780100128331783 [fb]
# # eventos SLQ 1200 GeV: 534247   fid_xsec =  0.03266226761689409 [fb]
# # eventos SLQ 1300 GeV: 196510   fid_xsec =  0.01845683815490422 [fb]
# # eventos SLQ 1400 GeV: 506381   fid_xsec =  0.01042961495117165 [fb]
# # eventos SLQ 1500 GeV: 185940   fid_xsec =  0.006048023736466943 [fb]
# # eventos SLQ 1600 GeV: 481827   fid_xsec =  0.003507185192178009 [fb]
# # eventos SLQ 1700 GeV: 173573   fid_xsec =  0.002031392861313088 [fb]
# # eventos SLQ 1800 GeV: 301687   fid_xsec =  0.001176600815433737 [fb]
# # eventos SLQ 1900 GeV: 64690   fid_xsec =  0.0006944291226017244 [fb]
#
# # eventos VLQ 1400 GeV: 139696   fid_xsec =  0.10534670176024427 [fb]
# # eventos VLQ 1500 GeV: 293700   fid_xsec =  0.06073177856848647 [fb]
# # eventos VLQ 1600 GeV: 134774   fid_xsec =  0.03501152733272929 [fb]
# # eventos VLQ 1700 GeV: 192819   fid_xsec =  0.020511364594047024 [fb]
# # eventos VLQ 1800 GeV: 127670   fid_xsec =  0.012016501694190138 [fb]
# # eventos VLQ 1900 GeV: 75898   fid_xsec =  0.007182275127112133 [fb]
# # eventos VLQ 2000 GeV: 184097   fid_xsec =  0.004292853054435507 [fb]
# # eventos VLQ 2100 GeV: 72762   fid_xsec =  0.0026150389212359643 [fb]
# # eventos VLQ 2200 GeV: 232166   fid_xsec =  0.0015929798837426498 [fb]
# # eventos VLQ 2300 GeV: 64705   fid_xsec =  0.0009703813160874061 [fb]

# %%
# FOR 14 TeV

k_fakett = 1.1053030485310749
crossfid_fakett = 0.244
k_tt = 1.2593273872014419
crossfid_tt = (7.74198*k_tt) + (crossfid_fakett * k_fakett)


fidxsec_SM = {'tt': crossfid_tt,
              'singletP1': 0.632632 * 3.440676833094312,
              'singletP2': 0.3182704 * 3.440676833094312,
              'Wbbjets': 1.6542420183645095 * 0.9781509289273502,
              'ttW': 0.03683196 * 3.056401327463198,
              'ttZ': 0.0715444 * 3.056401327463198,
              'ttH': 0.03630132 * 2.2127445612386474
              }

for ch_it in fidxsec_SM:
    print(f"# eventos {ch_it}:", len(X_B_all[ch_it]), "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]")
# Out:
# # eventos tt: 826022   fid_xsec =  10.019381389007401 [fb]
# # eventos singletP1: 179677   fid_xsec =  2.1766822662741205 [fb]
# # eventos singletP2: 94219   fid_xsec =  1.09506559193966 [fb]
# # eventos Wbbjets: 162448   fid_xsec =  1.6180983669338997 [fb]
# # eventos ttW: 141919   fid_xsec =  0.1125732514370714 [fb]
# # eventos ttZ: 16178   fid_xsec =  0.218668399132558 [fb]
# # eventos ttH: 12068   fid_xsec =  0.08032554839578374 [fb]

# %%
# MAX SM dataset
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])


weigth_gen_SM = {}

for ch_it in fidxsec_SM:

    print(f"fraction of {ch_it}:", fidxsec_SM[ch_it] / totalcrossSM )

    weigth_gen_SM[ch_it] = len(X_B_all[ch_it]) / (fidxsec_SM[ch_it] / totalcrossSM)

print('\nchannel limiting the SM background: ', min(weigth_gen_SM, key=weigth_gen_SM.get) , '\n')


max_evs_SM = {}

for ch_it in fidxsec_SM:
    max_evs_SM[ch_it] = round( min(weigth_gen_SM.values()) * (fidxsec_SM[ch_it] / totalcrossSM) )
    print(f"# eventos {ch_it} (max):", max_evs_SM[ch_it])

max_SM_dataset = sum(max_evs_SM.values())
print('\nmax SM dataset length: ', max_SM_dataset )
# Out:
# fraction of tt: 0.6539726894865112
# fraction of singletP1: 0.14207371698562551
# fraction of singletP2: 0.07147576906400852
# fraction of Wbbjets: 0.10561451848099845
# fraction of ttW: 0.0073477422555561795
# fraction of ttZ: 0.014272653723245071
# fraction of ttH: 0.005242910004055022
#
# channel limiting the SM background:  ttZ
#
# # eventos tt (max): 741276
# # eventos singletP1 (max): 161040
# # eventos singletP2 (max): 81018
# # eventos Wbbjets (max): 119714
# # eventos ttW (max): 8329
# # eventos ttZ (max): 16178
# # eventos ttH (max): 5943
#
# max SM dataset length:  1133498

# %% [markdown]
# ## Number of events to get a balanced dataset

# %%
# -------------------------
# Step 1: minimim number of events in LQs (selected mass)
# -------------------------

num_data_SLQ = [len(X_SLQ_all[m_it]) for m_it in masses_SLQ]

num_data_VLQ = [len(X_VLQ_all[m_it]) for m_it in masses_VLQ]


max_SM_dataset = min(1000000, max_SM_dataset)

num_data_NP = min(int(max_SM_dataset / (len(masses_SLQ) + len(masses_VLQ))) , min(num_data_SLQ + num_data_VLQ) )

print('SIGNAL: # events per-class chosen =', num_data_NP)



# -------------------------
# Step 2: background total fid_xsec
# -------------------------
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])



# -------------------------
# Step 3: number of events per chanel, proportional to xsec
# -------------------------
num_data_SM_dict = {}
for ch_it in fidxsec_SM:
    if ch_it == 'tt':
        # set at the end to have exactly the same # events (otherwise can be a difference of 1 due to rounding)
        continue
    fraction = fidxsec_SM[ch_it]/totalcrossSM
    num_data_SM_dict[ch_it] = round(num_data_NP * fraction * (len(masses_SLQ) + len(masses_VLQ)) )

# Set tt such that the total matches num_data_NP
num_data_SM_dict['tt'] = num_data_NP * (len(masses_SLQ) + len(masses_VLQ)) - sum([v for k,v in num_data_SM_dict.items() if k != 'tt'])




print('\nBACKGROUND events chosen (weighted by xsec):')
for ch_it in fidxsec_SM:
    print(f'# {ch_it}: {num_data_SM_dict[ch_it]}')
print('# total B events chosen: ', sum(num_data_SM_dict.values()))
# Out:
# SIGNAL: # events per-class chosen = 50000
#
# BACKGROUND events chosen (weighted by xsec):
# # tt: 653971
# # singletP1: 142074
# # singletP2: 71476
# # Wbbjets: 105615
# # ttW: 7348
# # ttZ: 14273
# # ttH: 5243
# # total B events chosen:  1000000

# %%
# keep just the events needed

for m_it in masses_SLQ:
    X_SLQ_all[m_it] = X_SLQ_all[m_it][:num_data_NP]
    df_SLQ_all[m_it] = df_SLQ_all[m_it][:num_data_NP]

print(" ")
for m_it in masses_VLQ:
    X_VLQ_all[m_it] = X_VLQ_all[m_it][:num_data_NP]
    df_VLQ_all[m_it] = df_VLQ_all[m_it][:num_data_NP]

print("")
for ch_it in fidxsec_SM:
    X_B_all[ch_it] = X_B_all[ch_it][:num_data_SM_dict[ch_it]]
    df_B_all[ch_it] = df_B_all[ch_it][:num_data_SM_dict[ch_it]]

# %%
B_expected = round(Lum * totalcrossSM)    # luminosity * cross * aceptance
print('B_expected: ', B_expected)

for ch_it in fidxsec_SM:
    print(f" channel {ch_it}:", "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]", " B_exp_ch: ", round(Lum * fidxsec_SM[ch_it]) )



S_expected_SLQ = []

for m_it in masses_SLQ:
    S_expected_SLQ.append( round(Lum * fidxsec_SLQ[m_it]) )

print('\nmasses:           ', masses_SLQ)
print('S_expected (SLQ): ', S_expected_SLQ)    # luminosity * cross * aceptance



S_expected_VLQ = []

for m_it in masses_VLQ:
    S_expected_VLQ.append( round(Lum * fidxsec_VLQ[m_it]) )

print('\nmasses:           ', masses_VLQ)
print('S_expected (VLQ): ', S_expected_VLQ)    # luminosity * cross * aceptance
# Out:
# B_expected:  45962
#  channel tt:   fid_xsec =  10.019381389007401 [fb]  B_exp_ch:  30058
#  channel singletP1:   fid_xsec =  2.1766822662741205 [fb]  B_exp_ch:  6530
#  channel singletP2:   fid_xsec =  1.09506559193966 [fb]  B_exp_ch:  3285
#  channel Wbbjets:   fid_xsec =  1.6180983669338997 [fb]  B_exp_ch:  4854
#  channel ttW:   fid_xsec =  0.1125732514370714 [fb]  B_exp_ch:  338
#  channel ttZ:   fid_xsec =  0.218668399132558 [fb]  B_exp_ch:  656
#  channel ttH:   fid_xsec =  0.08032554839578374 [fb]  B_exp_ch:  241
#
# masses:            [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_expected (SLQ):  [307, 173, 98, 55, 31, 18, 11, 6, 4, 2]
#
# masses:            [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_expected (VLQ):  [316, 182, 105, 62, 36, 22, 13, 8, 5, 3]

# %%
plt.plot(masses_SLQ, S_expected_SLQ, color='red', label='SLQ')
plt.plot(masses_VLQ, S_expected_VLQ, color='green', label='VLQ')
# plt.yscale('log')
plt.xlabel("$m_{LQ}$ [GeV]", fontsize=16)
plt.ylabel("S expected", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # 1. DATA FORMAT for CLASSIFIERS

# %%
# to save memory
del X_SLQ_all
del X_VLQ_all
del X_B_all

# %%
# ---------------------------
# Concatenate all for normalization
# ---------------------------
df_SM = pd.concat(df_B_all.values(), ignore_index=True)
del df_B_all

df_all = pd.concat([df_SM] + list(df_SLQ_all.values()) + list(df_VLQ_all.values()), ignore_index=True)

# ---------------------------
# Normalization
# ---------------------------
scaler = MinMaxScaler()
scaler.fit(df_all)

# Save the scaler
# joblib.dump(scaler, mainfolder + 'saved-models/scaler_features.pkl')

# Apply normalization
df_SM_norm = pd.DataFrame(scaler.transform(df_SM), columns=df_SM.columns)
df_SLQ_norm = {mass: pd.DataFrame(scaler.transform(df_SLQ_all[mass]), columns=df_SLQ_all[mass].columns) for mass in df_SLQ_all}
df_VLQ_norm = {mass: pd.DataFrame(scaler.transform(df_VLQ_all[mass]), columns=df_VLQ_all[mass].columns) for mass in df_VLQ_all}






# ---------------------------
# Divide datasets into train/val/test/pseudo
# ---------------------------
def split_class(df, test_ratio=0.25, val_ratio=0.10, pseudo_ratio=0.25):
    X = df.values
    aux_val_ratio = val_ratio / (1 - test_ratio)
    aux_pseudo_ratio = pseudo_ratio / (1 - test_ratio - val_ratio)

    X_aux, X_test = train_test_split(X, test_size=test_ratio, random_state=42, shuffle=True)
    X_aux2, X_val = train_test_split(X_aux, test_size=aux_val_ratio, random_state=42, shuffle=True)
    X_train, X_pseudo = train_test_split(X_aux2, test_size=aux_pseudo_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, X_pseudo



# ---------------------------
# Divide the datasets
# ---------------------------
split_SM = split_class(df_SM_norm)
split_SLQ = {mass: split_class(df_SLQ_norm[mass]) for mass in df_SLQ_norm}
split_VLQ = {mass: split_class(df_VLQ_norm[mass]) for mass in df_VLQ_norm}



# Example of how to use them
X_train_SM, X_val_SM, X_test_SM, X_pseudo_SM = split_SM
X_train_SLQ1200, X_val_SLQ1200, X_test_SLQ1200, X_pseudo_SLQ1200 = split_SLQ[1200]
X_train_VLQ1600, X_val_VLQ1600, X_test_VLQ1600, X_pseudo_VLQ1600 = split_VLQ[1600]

print('')
print('X_train_SM : ', X_train_SM.shape)
print('X_val_SM : ', X_val_SM.shape)
print('X_test_SM : ', X_test_SM.shape)
print('X_pseudo_SM : ', X_pseudo_SM.shape)

print('')
print('X_train_SLQ1200 : ', X_train_SLQ1200.shape)
print('X_val_SLQ1200 : ', X_val_SLQ1200.shape)
print('X_test_SLQ1200 : ', X_test_SLQ1200.shape)
print('X_pseudo_SLQ1200 : ', X_pseudo_SLQ1200.shape)

print('')
print('X_train_VLQ1600 : ', X_train_VLQ1600.shape)
print('X_val_VLQ1600 : ', X_val_VLQ1600.shape)
print('X_test_VLQ1600 : ', X_test_VLQ1600.shape)
print('X_pseudo_VLQ1600 : ', X_pseudo_VLQ1600.shape)
# Out:
# X_train_SM :  (400000, 53)
# X_val_SM :  (100000, 53)
# X_test_SM :  (250000, 53)
# X_pseudo_SM :  (250000, 53)
#
# X_train_SLQ1200 :  (20000, 53)
# X_val_SLQ1200 :  (5000, 53)
# X_test_SLQ1200 :  (12500, 53)
# X_pseudo_SLQ1200 :  (12500, 53)
#
# X_train_VLQ1600 :  (20000, 53)
# X_val_VLQ1600 :  (5000, 53)
# X_test_VLQ1600 :  (12500, 53)
# X_pseudo_VLQ1600 :  (12500, 53)

# %%
# to save memory
del df_SM
del df_SLQ_all
del df_VLQ_all

# %% [markdown]
# ## SM vs LQ

# %%
# --- 1. Combinar todos los LQ en un solo DataFrame ---
df_LQ_list = list(df_SLQ_norm.values()) + list(df_VLQ_norm.values())
df_LQ_norm = pd.concat(df_LQ_list, ignore_index=True)


# --- 2. Igualar número de eventos con SM ---
n_SM = len(df_SM_norm)
n_LQ = len(df_LQ_norm)
n_events = min(n_SM, n_LQ)

print(n_SM, n_LQ, n_events)

df_SM_sample = df_SM_norm.sample(n=n_events, random_state=42)
df_LQ_sample = df_LQ_norm.sample(n=n_events, random_state=42)


# --- 3. Crear X, y ---
X = pd.concat([df_SM_sample, df_LQ_sample], ignore_index=True)
y = np.hstack([np.zeros(n_events), np.ones(n_events)])  # 0=SM, 1=LQ


def split_class(X, Y, test_ratio=0.25, val_ratio=0.25):

    aux_val_ratio = val_ratio / (1 - test_ratio)

    X_aux, X_test, Y_aux, Y_test = train_test_split(X, Y, test_size=test_ratio, random_state=42, shuffle=True)
    X_train, X_val, Y_train, Y_val = train_test_split(X_aux, Y_aux, test_size=val_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, Y_train, Y_val, Y_test


# Divide into train, validation and test
X_train, X_val, X_test, y_train, y_val, y_test = split_class(X, y)


print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# 1000000 1000000 1000000
# (1125000, 53)
# (375000, 53)
# (500000, 53)

# %%
# LOAD
xgb_clf = XGBClassifier()
xgb_clf.load_model(mainfolder + "saved-models/modelA_SMLQ_14TeV_full.json")


# Evaluate
y_pred = xgb_clf.predict(X_test)
y_pred_proba = xgb_clf.predict_proba(X_test)[:,1]

acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)
print(f"Accuracy: {acc:.3f}, ROC-AUC: {auc:.5f}")

# ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC={auc:.3f}')
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SM vs LQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + "saved-results/ROC_classA.pdf", bbox_inches='tight')
plt.show()


# Feature importance
keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$'])

feature_important = xgb_clf.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=14).remove()
plt.title(r'SM vs LQ', fontsize=14)
# plt.savefig(mainfolder + "saved-results/XG_feature_importance_classA.pdf", bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Accuracy: 0.976, ROC-AUC: 0.99714
# [52, 47, 17, 35, 15, 36, 50, 46, 32, 45, 6, 37, 51, 43, 38]

# %% [markdown]
# ## Compute S_pred for pseudo-experiments

# %%
# output of all the background events
scores_B = xgb_clf.predict_proba( df_SM_norm )[:, 1]

# output of all the signal events (for the pdf of the general LQ case)
scores_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]

# %%
# output of all the signal events per class (to build the pseudo-experiments)
scores_S_SLQ = {mass: xgb_clf.predict_proba(df_SLQ_norm[mass])[:, 1] for mass in df_SLQ_norm}
scores_S_VLQ = {mass: xgb_clf.predict_proba(df_VLQ_norm[mass])[:, 1] for mass in df_VLQ_norm}

# %%
def Z_asimov(S, B):
    if S <= 0 or B <= 0:
        return 0
    return np.sqrt(2 * ((S+B) * np.log(1 + S/B) - S))

# %% [markdown]
# ###### binned likelihood fit

# %%
bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scores_B, bins=bins, density=True)
hist_S, _ = np.histogram(scores_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %%
# FOR SLQ #

S_expected = S_expected_SLQ


n_pseudo = 1000


# to save
S_mean_fit_N = {}
S_std_fit_N  = {}
Z_fit_N = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_N[S_it] = []
    S_std_fit_N[S_it]  = []
    Z_fit_N[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_SLQ[masses_SLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_N[S_it].append(mean_muS)
    S_std_fit_N[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_N[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  307
# S = 230.76048200815075 +- 20.67776307798405
# Z = 15.377435105383094
#
#
# ----------------
# S_expected =  173
# S = 147.63249214965097 +- 18.910903024331756
# Z = 10.033975154133316
#
#
# ----------------
# S_expected =  98
# S = 89.87082121826714 +- 16.995756998118292
# Z = 7.326566942811165
#
#
# ----------------
# S_expected =  55
# S = 52.752946519243444 +- 14.558408792580165
# Z = 4.567702540453689
#
#
# ----------------
# S_expected =  31
# S = 30.984093274159147 +- 13.21869399992436
# Z = 0.524021250749199
#
#
# ----------------
# S_expected =  18
# S = 18.55588549538396 +- 11.669720773864698
# Z = 1.626715822962631
#
#
# ----------------
# S_expected =  11
# /tmp/ipykernel_13959/1030940870.py:78: RuntimeWarning: invalid value encountered in sqrt
#   Z = np.sqrt(q0)
# S = 12.903555722780473 +- 10.26944890301349
# Z = nan
#
#
# ----------------
# S_expected =  6
# S = 9.010987803221918 +- 9.326039082957843
# Z = nan
#
#
# ----------------
# S_expected =  4
# S = 7.325437079277916 +- 8.607581030655476
# Z = nan
#
#
# ----------------
# S_expected =  2
# S = 5.7468299252375505 +- 7.825643658028217
# Z = 0.4255673092211402

# %%
# FOR VLQ #

S_expected = S_expected_SLQ # same number of events


n_pseudo = 1000


# to save
S_mean_fit_V = {}
S_std_fit_V  = {}
Z_fit_V = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_V[S_it] = []
    S_std_fit_V[S_it]  = []
    Z_fit_V[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_VLQ[masses_VLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_V[S_it].append(mean_muS)
    S_std_fit_V[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_V[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  307
# S = 293.2431381905416 +- 22.450298950652467
# Z = 16.998408081743932
#
#
# ----------------
# S_expected =  173
# S = 169.96317266546322 +- 18.32169176010273
# Z = 13.73350907959286
#
#
# ----------------
# S_expected =  98
# S = 97.6416478109009 +- 15.599097813313488
# Z = 7.620674279880216
#
#
# ----------------
# S_expected =  55
# S = 55.492194160256275 +- 14.511134634754455
# Z = 3.458011391419571
#
#
# ----------------
# S_expected =  31
# S = 31.836681437496562 +- 13.847876720152694
# Z = 3.101707419396448
#
#
# ----------------
# S_expected =  18
# /tmp/ipykernel_13959/2772170123.py:78: RuntimeWarning: invalid value encountered in sqrt
#   Z = np.sqrt(q0)
# S = 19.348639007685506 +- 12.350293891401035
# Z = nan
#
#
# ----------------
# S_expected =  11
# S = 12.388490971657044 +- 10.370371135501466
# Z = 1.2279604429067643
#
#
# ----------------
# S_expected =  6
# S = 8.70981941697415 +- 9.283892116008538
# Z = nan
#
#
# ----------------
# S_expected =  4
# S = 7.666673284236628 +- 8.800048591705124
# Z = nan
#
#
# ----------------
# S_expected =  2
# S = 5.924608348620255 +- 7.940543248387608
# Z = 0.7785054465895136

# %%
# mean between scalar and vector
S_mean_fit_both = []
S_std_fit_both = []

for i in S_mean_fit_N:

    S_mean_fit_both.append( np.mean([S_mean_fit_N[i][0], S_mean_fit_V[i][0]]) )
    S_std_fit_both.append( np.mean([S_std_fit_N[i][0], S_std_fit_V[i][0]]) )

# %% [markdown]
# # SLQ vs VLQ (include Poisson S_expected)

# %%
X_train_list, y_train_list, S_poiss_train_list = [], [], []
X_val_list,   y_val_list,   S_poiss_val_list   = [], [], []
X_test_list,  y_test_list,  S_poiss_test_list  = [], [], []

for iit, m_s in enumerate(masses_SLQ):

        # -------- SLQ --------
        X_train_s, X_val_s, X_test_s, _ = split_SLQ[masses_SLQ[iit]]

        X_train_list.append(X_train_s)
        y_train_list.append(np.zeros(len(X_train_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_s))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_s)
        y_val_list.append(np.zeros(len(X_val_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_s))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_s)
        y_test_list.append(np.zeros(len(X_test_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_s))
        S_poiss_test_list.append(poisson_samples)


# for iit, m_v in enumerate(masses_VLQ):

        # -------- VLQ --------
        X_train_v, X_val_v, X_test_v, _ = split_VLQ[masses_VLQ[iit]]

        X_train_list.append(X_train_v)
        y_train_list.append(np.ones(len(X_train_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_v))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_v)
        y_val_list.append(np.ones(len(X_val_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_v))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_v)
        y_test_list.append(np.ones(len(X_test_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_v))
        S_poiss_test_list.append(poisson_samples)


# Concatenate
# TRAIN
X_train_spin = np.vstack(X_train_list)
y_train_spin = np.concatenate(y_train_list)
S_poiss_train = np.concatenate(S_poiss_train_list)

# add S_poiss as extra feature
X_train_spin = np.column_stack([X_train_spin, S_poiss_train])


# VAL
X_val_spin = np.vstack(X_val_list)
y_val_spin = np.concatenate(y_val_list)
S_poiss_val = np.concatenate(S_poiss_val_list)

X_val_spin = np.column_stack([X_val_spin, S_poiss_val])


# TEST
X_test_spin = np.vstack(X_test_list)
y_test_spin = np.concatenate(y_test_list)
S_poiss_test = np.concatenate(S_poiss_test_list)

X_test_spin = np.column_stack([X_test_spin, S_poiss_test])


print(X_train_spin.shape)
print(X_val_spin.shape)
print(X_test_spin.shape)
# Out:
# (400000, 54)
# (100000, 54)
# (250000, 54)

# %%
classifier_spin = XGBClassifier(
    n_estimators=1500,
    learning_rate=0.1,
    max_depth=5,
    reg_lambda=1.0,
    reg_alpha=0.0,
    gamma=0.0,
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    random_state=42,
    early_stopping_rounds=50
)

classifier_spin.fit(
    X_train_spin, y_train_spin,
    eval_set=[(X_train_spin, y_train_spin),
              (X_val_spin, y_val_spin)],
    verbose=True
)

classifier_spin.save_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta0.json")
# Out:
# [0]	validation_0-logloss:0.68610	validation_1-logloss:0.68621
# [1]	validation_0-logloss:0.68017	validation_1-logloss:0.68039
# [2]	validation_0-logloss:0.67480	validation_1-logloss:0.67499
# [3]	validation_0-logloss:0.67040	validation_1-logloss:0.67068
# [4]	validation_0-logloss:0.66640	validation_1-logloss:0.66669
# [5]	validation_0-logloss:0.66286	validation_1-logloss:0.66324
# [6]	validation_0-logloss:0.66001	validation_1-logloss:0.66048
# [7]	validation_0-logloss:0.65721	validation_1-logloss:0.65780
# [8]	validation_0-logloss:0.65452	validation_1-logloss:0.65518
# [9]	validation_0-logloss:0.65119	validation_1-logloss:0.65190
# [10]	validation_0-logloss:0.64913	validation_1-logloss:0.64989
# [11]	validation_0-logloss:0.64722	validation_1-logloss:0.64805
# [12]	validation_0-logloss:0.64494	validation_1-logloss:0.64582
# [13]	validation_0-logloss:0.64336	validation_1-logloss:0.64427
# [14]	validation_0-logloss:0.64182	validation_1-logloss:0.64278
# [15]	validation_0-logloss:0.64034	validation_1-logloss:0.64136
# [16]	validation_0-logloss:0.63909	validation_1-logloss:0.64017
# [17]	validation_0-logloss:0.63785	validation_1-logloss:0.63894
# [18]	validation_0-logloss:0.63680	validation_1-logloss:0.63792
# [19]	validation_0-logloss:0.63587	validation_1-logloss:0.63707
# [20]	validation_0-logloss:0.63466	validation_1-logloss:0.63592
# [21]	validation_0-logloss:0.63345	validation_1-logloss:0.63471
# [22]	validation_0-logloss:0.63242	validation_1-logloss:0.63372
# [23]	validation_0-logloss:0.63157	validation_1-logloss:0.63292
# [24]	validation_0-logloss:0.63089	validation_1-logloss:0.63229
# [25]	validation_0-logloss:0.63026	validation_1-logloss:0.63171
# [26]	validation_0-logloss:0.62954	validation_1-logloss:0.63101
# [27]	validation_0-logloss:0.62889	validation_1-logloss:0.63040
# [28]	validation_0-logloss:0.62800	validation_1-logloss:0.62957
# [29]	validation_0-logloss:0.62689	validation_1-logloss:0.62855
# [30]	validation_0-logloss:0.62642	validation_1-logloss:0.62813
# [31]	validation_0-logloss:0.62564	validation_1-logloss:0.62736
# [32]	validation_0-logloss:0.62495	validation_1-logloss:0.62667
# [33]	validation_0-logloss:0.62431	validation_1-logloss:0.62610
# [34]	validation_0-logloss:0.62355	validation_1-logloss:0.62535
# [35]	validation_0-logloss:0.62270	validation_1-logloss:0.62451
# [36]	validation_0-logloss:0.62225	validation_1-logloss:0.62409
# [37]	validation_0-logloss:0.62108	validation_1-logloss:0.62296
# [38]	validation_0-logloss:0.62065	validation_1-logloss:0.62263
# [39]	validation_0-logloss:0.62034	validation_1-logloss:0.62236
# [40]	validation_0-logloss:0.61985	validation_1-logloss:0.62192
# [41]	validation_0-logloss:0.61952	validation_1-logloss:0.62165
# [42]	validation_0-logloss:0.61863	validation_1-logloss:0.62076
# [43]	validation_0-logloss:0.61813	validation_1-logloss:0.62027
# [44]	validation_0-logloss:0.61774	validation_1-logloss:0.61991
# [45]	validation_0-logloss:0.61713	validation_1-logloss:0.61934
# [46]	validation_0-logloss:0.61675	validation_1-logloss:0.61904
# [47]	validation_0-logloss:0.61602	validation_1-logloss:0.61832
# [48]	validation_0-logloss:0.61570	validation_1-logloss:0.61802
# [49]	validation_0-logloss:0.61542	validation_1-logloss:0.61780
# [50]	validation_0-logloss:0.61507	validation_1-logloss:0.61750
# [51]	validation_0-logloss:0.61474	validation_1-logloss:0.61721
# [52]	validation_0-logloss:0.61442	validation_1-logloss:0.61696
# [53]	validation_0-logloss:0.61360	validation_1-logloss:0.61620
# [54]	validation_0-logloss:0.61329	validation_1-logloss:0.61597
# [55]	validation_0-logloss:0.61274	validation_1-logloss:0.61544
# [56]	validation_0-logloss:0.61245	validation_1-logloss:0.61519
# [57]	validation_0-logloss:0.61219	validation_1-logloss:0.61497
# [58]	validation_0-logloss:0.61198	validation_1-logloss:0.61482
# [59]	validation_0-logloss:0.61150	validation_1-logloss:0.61444
# [60]	validation_0-logloss:0.61123	validation_1-logloss:0.61419
# [61]	validation_0-logloss:0.61108	validation_1-logloss:0.61407
# [62]	validation_0-logloss:0.61057	validation_1-logloss:0.61362
# [63]	validation_0-logloss:0.61032	validation_1-logloss:0.61341
# [64]	validation_0-logloss:0.60993	validation_1-logloss:0.61310
# [65]	validation_0-logloss:0.60976	validation_1-logloss:0.61297
# [66]	validation_0-logloss:0.60958	validation_1-logloss:0.61285
# [67]	validation_0-logloss:0.60942	validation_1-logloss:0.61273
# [68]	validation_0-logloss:0.60895	validation_1-logloss:0.61235
# [69]	validation_0-logloss:0.60869	validation_1-logloss:0.61216
# [70]	validation_0-logloss:0.60831	validation_1-logloss:0.61183
# [71]	validation_0-logloss:0.60815	validation_1-logloss:0.61173
# [72]	validation_0-logloss:0.60796	validation_1-logloss:0.61157
# [73]	validation_0-logloss:0.60778	validation_1-logloss:0.61144
# [74]	validation_0-logloss:0.60761	validation_1-logloss:0.61130
# [75]	validation_0-logloss:0.60734	validation_1-logloss:0.61111
# [76]	validation_0-logloss:0.60714	validation_1-logloss:0.61100
# [77]	validation_0-logloss:0.60703	validation_1-logloss:0.61094
# [78]	validation_0-logloss:0.60667	validation_1-logloss:0.61062
# [79]	validation_0-logloss:0.60649	validation_1-logloss:0.61051
# [80]	validation_0-logloss:0.60634	validation_1-logloss:0.61044
# [81]	validation_0-logloss:0.60617	validation_1-logloss:0.61031
# [82]	validation_0-logloss:0.60594	validation_1-logloss:0.61014
# [83]	validation_0-logloss:0.60578	validation_1-logloss:0.61004
# [84]	validation_0-logloss:0.60545	validation_1-logloss:0.60975
# [85]	validation_0-logloss:0.60533	validation_1-logloss:0.60967
# [86]	validation_0-logloss:0.60516	validation_1-logloss:0.60956
# [87]	validation_0-logloss:0.60479	validation_1-logloss:0.60923
# [88]	validation_0-logloss:0.60467	validation_1-logloss:0.60917
# [89]	validation_0-logloss:0.60450	validation_1-logloss:0.60905
# [90]	validation_0-logloss:0.60435	validation_1-logloss:0.60896
# [91]	validation_0-logloss:0.60410	validation_1-logloss:0.60878
# [92]	validation_0-logloss:0.60375	validation_1-logloss:0.60847
# [93]	validation_0-logloss:0.60363	validation_1-logloss:0.60839
# [94]	validation_0-logloss:0.60344	validation_1-logloss:0.60825
# [95]	validation_0-logloss:0.60324	validation_1-logloss:0.60812
# [96]	validation_0-logloss:0.60315	validation_1-logloss:0.60808
# [97]	validation_0-logloss:0.60279	validation_1-logloss:0.60778
# [98]	validation_0-logloss:0.60269	validation_1-logloss:0.60771
# [99]	validation_0-logloss:0.60259	validation_1-logloss:0.60766
# [100]	validation_0-logloss:0.60245	validation_1-logloss:0.60756
# [101]	validation_0-logloss:0.60222	validation_1-logloss:0.60734
# [102]	validation_0-logloss:0.60188	validation_1-logloss:0.60709
# [103]	validation_0-logloss:0.60154	validation_1-logloss:0.60680
# [104]	validation_0-logloss:0.60117	validation_1-logloss:0.60648
# [105]	validation_0-logloss:0.60091	validation_1-logloss:0.60624
# [106]	validation_0-logloss:0.60077	validation_1-logloss:0.60617
# [107]	validation_0-logloss:0.60040	validation_1-logloss:0.60587
# [108]	validation_0-logloss:0.60032	validation_1-logloss:0.60585
# [109]	validation_0-logloss:0.60022	validation_1-logloss:0.60580
# [110]	validation_0-logloss:0.60014	validation_1-logloss:0.60576
# [111]	validation_0-logloss:0.59988	validation_1-logloss:0.60554
# [112]	validation_0-logloss:0.59968	validation_1-logloss:0.60540
# [113]	validation_0-logloss:0.59946	validation_1-logloss:0.60524
# [114]	validation_0-logloss:0.59934	validation_1-logloss:0.60519
# [115]	validation_0-logloss:0.59924	validation_1-logloss:0.60519
# [116]	validation_0-logloss:0.59915	validation_1-logloss:0.60515
# [117]	validation_0-logloss:0.59899	validation_1-logloss:0.60507
# [118]	validation_0-logloss:0.59874	validation_1-logloss:0.60491
# [119]	validation_0-logloss:0.59830	validation_1-logloss:0.60453
# [120]	validation_0-logloss:0.59815	validation_1-logloss:0.60442
# [121]	validation_0-logloss:0.59794	validation_1-logloss:0.60426
# [122]	validation_0-logloss:0.59782	validation_1-logloss:0.60421
# [123]	validation_0-logloss:0.59776	validation_1-logloss:0.60420
# [124]	validation_0-logloss:0.59767	validation_1-logloss:0.60417
# [125]	validation_0-logloss:0.59759	validation_1-logloss:0.60413
# [126]	validation_0-logloss:0.59751	validation_1-logloss:0.60411
# [127]	validation_0-logloss:0.59721	validation_1-logloss:0.60387
# [128]	validation_0-logloss:0.59706	validation_1-logloss:0.60378
# [129]	validation_0-logloss:0.59688	validation_1-logloss:0.60366
# [130]	validation_0-logloss:0.59674	validation_1-logloss:0.60358
# [131]	validation_0-logloss:0.59666	validation_1-logloss:0.60355
# [132]	validation_0-logloss:0.59654	validation_1-logloss:0.60350
# [133]	validation_0-logloss:0.59627	validation_1-logloss:0.60330
# [134]	validation_0-logloss:0.59606	validation_1-logloss:0.60313
# [135]	validation_0-logloss:0.59600	validation_1-logloss:0.60312
# [136]	validation_0-logloss:0.59589	validation_1-logloss:0.60307
# [137]	validation_0-logloss:0.59573	validation_1-logloss:0.60294
# [138]	validation_0-logloss:0.59565	validation_1-logloss:0.60291
# [139]	validation_0-logloss:0.59539	validation_1-logloss:0.60271
# [140]	validation_0-logloss:0.59532	validation_1-logloss:0.60267
# [141]	validation_0-logloss:0.59518	validation_1-logloss:0.60258
# [142]	validation_0-logloss:0.59506	validation_1-logloss:0.60251
# [143]	validation_0-logloss:0.59494	validation_1-logloss:0.60243
# [144]	validation_0-logloss:0.59469	validation_1-logloss:0.60224
# [145]	validation_0-logloss:0.59456	validation_1-logloss:0.60216
# [146]	validation_0-logloss:0.59447	validation_1-logloss:0.60216
# [147]	validation_0-logloss:0.59430	validation_1-logloss:0.60201
# [148]	validation_0-logloss:0.59423	validation_1-logloss:0.60200
# [149]	validation_0-logloss:0.59413	validation_1-logloss:0.60197
# [150]	validation_0-logloss:0.59400	validation_1-logloss:0.60188
# [151]	validation_0-logloss:0.59392	validation_1-logloss:0.60185
# [152]	validation_0-logloss:0.59383	validation_1-logloss:0.60183
# [153]	validation_0-logloss:0.59376	validation_1-logloss:0.60181
# [154]	validation_0-logloss:0.59371	validation_1-logloss:0.60179
# [155]	validation_0-logloss:0.59356	validation_1-logloss:0.60171
# [156]	validation_0-logloss:0.59344	validation_1-logloss:0.60170
# [157]	validation_0-logloss:0.59336	validation_1-logloss:0.60168
# [158]	validation_0-logloss:0.59330	validation_1-logloss:0.60167
# [159]	validation_0-logloss:0.59321	validation_1-logloss:0.60163
# [160]	validation_0-logloss:0.59312	validation_1-logloss:0.60162
# [161]	validation_0-logloss:0.59303	validation_1-logloss:0.60159
# [162]	validation_0-logloss:0.59295	validation_1-logloss:0.60156
# [163]	validation_0-logloss:0.59288	validation_1-logloss:0.60153
# [164]	validation_0-logloss:0.59278	validation_1-logloss:0.60149
# [165]	validation_0-logloss:0.59271	validation_1-logloss:0.60148
# [166]	validation_0-logloss:0.59261	validation_1-logloss:0.60143
# [167]	validation_0-logloss:0.59249	validation_1-logloss:0.60135
# [168]	validation_0-logloss:0.59239	validation_1-logloss:0.60128
# [169]	validation_0-logloss:0.59233	validation_1-logloss:0.60128
# [170]	validation_0-logloss:0.59226	validation_1-logloss:0.60125
# [171]	validation_0-logloss:0.59217	validation_1-logloss:0.60123
# [172]	validation_0-logloss:0.59207	validation_1-logloss:0.60119
# [173]	validation_0-logloss:0.59201	validation_1-logloss:0.60115
# [174]	validation_0-logloss:0.59190	validation_1-logloss:0.60110
# [175]	validation_0-logloss:0.59183	validation_1-logloss:0.60109
# [176]	validation_0-logloss:0.59173	validation_1-logloss:0.60103
# [177]	validation_0-logloss:0.59163	validation_1-logloss:0.60102
# [178]	validation_0-logloss:0.59157	validation_1-logloss:0.60102
# [179]	validation_0-logloss:0.59148	validation_1-logloss:0.60101
# [180]	validation_0-logloss:0.59138	validation_1-logloss:0.60096
# [181]	validation_0-logloss:0.59129	validation_1-logloss:0.60094
# [182]	validation_0-logloss:0.59121	validation_1-logloss:0.60093
# [183]	validation_0-logloss:0.59116	validation_1-logloss:0.60093
# [184]	validation_0-logloss:0.59107	validation_1-logloss:0.60091
# [185]	validation_0-logloss:0.59093	validation_1-logloss:0.60082
# [186]	validation_0-logloss:0.59081	validation_1-logloss:0.60073
# [187]	validation_0-logloss:0.59071	validation_1-logloss:0.60070
# [188]	validation_0-logloss:0.59063	validation_1-logloss:0.60067
# [189]	validation_0-logloss:0.59054	validation_1-logloss:0.60064
# [190]	validation_0-logloss:0.59044	validation_1-logloss:0.60060
# [191]	validation_0-logloss:0.59036	validation_1-logloss:0.60057
# [192]	validation_0-logloss:0.59016	validation_1-logloss:0.60045
# [193]	validation_0-logloss:0.59002	validation_1-logloss:0.60038
# [194]	validation_0-logloss:0.58991	validation_1-logloss:0.60034
# [195]	validation_0-logloss:0.58980	validation_1-logloss:0.60029
# [196]	validation_0-logloss:0.58969	validation_1-logloss:0.60022
# [197]	validation_0-logloss:0.58952	validation_1-logloss:0.60009
# [198]	validation_0-logloss:0.58947	validation_1-logloss:0.60008
# [199]	validation_0-logloss:0.58939	validation_1-logloss:0.60008
# [200]	validation_0-logloss:0.58932	validation_1-logloss:0.60004
# [201]	validation_0-logloss:0.58925	validation_1-logloss:0.60003
# [202]	validation_0-logloss:0.58915	validation_1-logloss:0.59999
# [203]	validation_0-logloss:0.58907	validation_1-logloss:0.59996
# [204]	validation_0-logloss:0.58895	validation_1-logloss:0.59992
# [205]	validation_0-logloss:0.58886	validation_1-logloss:0.59989
# [206]	validation_0-logloss:0.58882	validation_1-logloss:0.59989
# [207]	validation_0-logloss:0.58865	validation_1-logloss:0.59976
# [208]	validation_0-logloss:0.58862	validation_1-logloss:0.59977
# [209]	validation_0-logloss:0.58848	validation_1-logloss:0.59969
# [210]	validation_0-logloss:0.58840	validation_1-logloss:0.59966
# [211]	validation_0-logloss:0.58829	validation_1-logloss:0.59958
# [212]	validation_0-logloss:0.58824	validation_1-logloss:0.59957
# [213]	validation_0-logloss:0.58817	validation_1-logloss:0.59956
# [214]	validation_0-logloss:0.58811	validation_1-logloss:0.59954
# [215]	validation_0-logloss:0.58802	validation_1-logloss:0.59952
# [216]	validation_0-logloss:0.58793	validation_1-logloss:0.59948
# [217]	validation_0-logloss:0.58785	validation_1-logloss:0.59946
# [218]	validation_0-logloss:0.58776	validation_1-logloss:0.59943
# [219]	validation_0-logloss:0.58770	validation_1-logloss:0.59942
# [220]	validation_0-logloss:0.58765	validation_1-logloss:0.59942
# [221]	validation_0-logloss:0.58755	validation_1-logloss:0.59939
# [222]	validation_0-logloss:0.58743	validation_1-logloss:0.59933
# [223]	validation_0-logloss:0.58726	validation_1-logloss:0.59922
# [224]	validation_0-logloss:0.58719	validation_1-logloss:0.59920
# [225]	validation_0-logloss:0.58712	validation_1-logloss:0.59919
# [226]	validation_0-logloss:0.58704	validation_1-logloss:0.59919
# [227]	validation_0-logloss:0.58696	validation_1-logloss:0.59917
# [228]	validation_0-logloss:0.58690	validation_1-logloss:0.59917
# [229]	validation_0-logloss:0.58683	validation_1-logloss:0.59915
# [230]	validation_0-logloss:0.58675	validation_1-logloss:0.59912
# [231]	validation_0-logloss:0.58665	validation_1-logloss:0.59908
# [232]	validation_0-logloss:0.58656	validation_1-logloss:0.59905
# [233]	validation_0-logloss:0.58651	validation_1-logloss:0.59905
# [234]	validation_0-logloss:0.58642	validation_1-logloss:0.59899
# [235]	validation_0-logloss:0.58633	validation_1-logloss:0.59896
# [236]	validation_0-logloss:0.58620	validation_1-logloss:0.59888
# [237]	validation_0-logloss:0.58605	validation_1-logloss:0.59877
# [238]	validation_0-logloss:0.58599	validation_1-logloss:0.59876
# [239]	validation_0-logloss:0.58593	validation_1-logloss:0.59876
# [240]	validation_0-logloss:0.58587	validation_1-logloss:0.59874
# [241]	validation_0-logloss:0.58580	validation_1-logloss:0.59873
# [242]	validation_0-logloss:0.58574	validation_1-logloss:0.59872
# [243]	validation_0-logloss:0.58568	validation_1-logloss:0.59872
# [244]	validation_0-logloss:0.58560	validation_1-logloss:0.59870
# [245]	validation_0-logloss:0.58552	validation_1-logloss:0.59868
# [246]	validation_0-logloss:0.58536	validation_1-logloss:0.59857
# [247]	validation_0-logloss:0.58528	validation_1-logloss:0.59856
# [248]	validation_0-logloss:0.58516	validation_1-logloss:0.59847
# [249]	validation_0-logloss:0.58510	validation_1-logloss:0.59846
# [250]	validation_0-logloss:0.58500	validation_1-logloss:0.59844
# [251]	validation_0-logloss:0.58494	validation_1-logloss:0.59844
# [252]	validation_0-logloss:0.58486	validation_1-logloss:0.59844
# [253]	validation_0-logloss:0.58480	validation_1-logloss:0.59844
# [254]	validation_0-logloss:0.58471	validation_1-logloss:0.59840
# [255]	validation_0-logloss:0.58460	validation_1-logloss:0.59832
# [256]	validation_0-logloss:0.58454	validation_1-logloss:0.59831
# [257]	validation_0-logloss:0.58449	validation_1-logloss:0.59830
# [258]	validation_0-logloss:0.58443	validation_1-logloss:0.59829
# [259]	validation_0-logloss:0.58437	validation_1-logloss:0.59829
# [260]	validation_0-logloss:0.58431	validation_1-logloss:0.59829
# [261]	validation_0-logloss:0.58417	validation_1-logloss:0.59821
# [262]	validation_0-logloss:0.58403	validation_1-logloss:0.59810
# [263]	validation_0-logloss:0.58395	validation_1-logloss:0.59810
# [264]	validation_0-logloss:0.58388	validation_1-logloss:0.59807
# [265]	validation_0-logloss:0.58382	validation_1-logloss:0.59808
# [266]	validation_0-logloss:0.58375	validation_1-logloss:0.59804
# [267]	validation_0-logloss:0.58363	validation_1-logloss:0.59798
# [268]	validation_0-logloss:0.58356	validation_1-logloss:0.59795
# [269]	validation_0-logloss:0.58345	validation_1-logloss:0.59787
# [270]	validation_0-logloss:0.58337	validation_1-logloss:0.59786
# [271]	validation_0-logloss:0.58326	validation_1-logloss:0.59782
# [272]	validation_0-logloss:0.58321	validation_1-logloss:0.59781
# [273]	validation_0-logloss:0.58312	validation_1-logloss:0.59773
# [274]	validation_0-logloss:0.58303	validation_1-logloss:0.59770
# [275]	validation_0-logloss:0.58296	validation_1-logloss:0.59769
# [276]	validation_0-logloss:0.58291	validation_1-logloss:0.59769
# [277]	validation_0-logloss:0.58284	validation_1-logloss:0.59770
# [278]	validation_0-logloss:0.58278	validation_1-logloss:0.59769
# [279]	validation_0-logloss:0.58270	validation_1-logloss:0.59767
# [280]	validation_0-logloss:0.58264	validation_1-logloss:0.59767
# [281]	validation_0-logloss:0.58258	validation_1-logloss:0.59769
# [282]	validation_0-logloss:0.58252	validation_1-logloss:0.59768
# [283]	validation_0-logloss:0.58246	validation_1-logloss:0.59767
# [284]	validation_0-logloss:0.58241	validation_1-logloss:0.59766
# [285]	validation_0-logloss:0.58236	validation_1-logloss:0.59766
# [286]	validation_0-logloss:0.58223	validation_1-logloss:0.59759
# [287]	validation_0-logloss:0.58216	validation_1-logloss:0.59758
# [288]	validation_0-logloss:0.58207	validation_1-logloss:0.59756
# [289]	validation_0-logloss:0.58197	validation_1-logloss:0.59753
# [290]	validation_0-logloss:0.58188	validation_1-logloss:0.59751
# [291]	validation_0-logloss:0.58183	validation_1-logloss:0.59751
# [292]	validation_0-logloss:0.58173	validation_1-logloss:0.59747
# [293]	validation_0-logloss:0.58167	validation_1-logloss:0.59747
# [294]	validation_0-logloss:0.58162	validation_1-logloss:0.59747
# [295]	validation_0-logloss:0.58151	validation_1-logloss:0.59743
# [296]	validation_0-logloss:0.58141	validation_1-logloss:0.59739
# [297]	validation_0-logloss:0.58123	validation_1-logloss:0.59725
# [298]	validation_0-logloss:0.58116	validation_1-logloss:0.59724
# [299]	validation_0-logloss:0.58107	validation_1-logloss:0.59721
# [300]	validation_0-logloss:0.58101	validation_1-logloss:0.59720
# [301]	validation_0-logloss:0.58096	validation_1-logloss:0.59721
# [302]	validation_0-logloss:0.58090	validation_1-logloss:0.59721
# [303]	validation_0-logloss:0.58083	validation_1-logloss:0.59720
# [304]	validation_0-logloss:0.58077	validation_1-logloss:0.59720
# [305]	validation_0-logloss:0.58071	validation_1-logloss:0.59720
# [306]	validation_0-logloss:0.58064	validation_1-logloss:0.59717
# [307]	validation_0-logloss:0.58059	validation_1-logloss:0.59717
# [308]	validation_0-logloss:0.58050	validation_1-logloss:0.59715
# [309]	validation_0-logloss:0.58043	validation_1-logloss:0.59713
# [310]	validation_0-logloss:0.58037	validation_1-logloss:0.59712
# [311]	validation_0-logloss:0.58026	validation_1-logloss:0.59706
# [312]	validation_0-logloss:0.58019	validation_1-logloss:0.59705
# [313]	validation_0-logloss:0.58014	validation_1-logloss:0.59704
# [314]	validation_0-logloss:0.58006	validation_1-logloss:0.59700
# [315]	validation_0-logloss:0.58000	validation_1-logloss:0.59699
# [316]	validation_0-logloss:0.57994	validation_1-logloss:0.59697
# [317]	validation_0-logloss:0.57988	validation_1-logloss:0.59697
# [318]	validation_0-logloss:0.57979	validation_1-logloss:0.59693
# [319]	validation_0-logloss:0.57971	validation_1-logloss:0.59692
# [320]	validation_0-logloss:0.57963	validation_1-logloss:0.59689
# [321]	validation_0-logloss:0.57956	validation_1-logloss:0.59688
# [322]	validation_0-logloss:0.57950	validation_1-logloss:0.59688
# [323]	validation_0-logloss:0.57943	validation_1-logloss:0.59687
# [324]	validation_0-logloss:0.57936	validation_1-logloss:0.59686
# [325]	validation_0-logloss:0.57931	validation_1-logloss:0.59686
# [326]	validation_0-logloss:0.57921	validation_1-logloss:0.59681
# [327]	validation_0-logloss:0.57915	validation_1-logloss:0.59680
# [328]	validation_0-logloss:0.57909	validation_1-logloss:0.59679
# [329]	validation_0-logloss:0.57901	validation_1-logloss:0.59677
# [330]	validation_0-logloss:0.57897	validation_1-logloss:0.59676
# [331]	validation_0-logloss:0.57893	validation_1-logloss:0.59675
# [332]	validation_0-logloss:0.57888	validation_1-logloss:0.59676
# [333]	validation_0-logloss:0.57882	validation_1-logloss:0.59674
# [334]	validation_0-logloss:0.57876	validation_1-logloss:0.59673
# [335]	validation_0-logloss:0.57870	validation_1-logloss:0.59670
# [336]	validation_0-logloss:0.57864	validation_1-logloss:0.59671
# [337]	validation_0-logloss:0.57854	validation_1-logloss:0.59667
# [338]	validation_0-logloss:0.57846	validation_1-logloss:0.59662
# [339]	validation_0-logloss:0.57838	validation_1-logloss:0.59661
# [340]	validation_0-logloss:0.57829	validation_1-logloss:0.59658
# [341]	validation_0-logloss:0.57824	validation_1-logloss:0.59659
# [342]	validation_0-logloss:0.57818	validation_1-logloss:0.59659
# [343]	validation_0-logloss:0.57813	validation_1-logloss:0.59659
# [344]	validation_0-logloss:0.57807	validation_1-logloss:0.59660
# [345]	validation_0-logloss:0.57801	validation_1-logloss:0.59660
# [346]	validation_0-logloss:0.57796	validation_1-logloss:0.59660
# [347]	validation_0-logloss:0.57790	validation_1-logloss:0.59659
# [348]	validation_0-logloss:0.57781	validation_1-logloss:0.59653
# [349]	validation_0-logloss:0.57775	validation_1-logloss:0.59653
# [350]	validation_0-logloss:0.57769	validation_1-logloss:0.59652
# [351]	validation_0-logloss:0.57761	validation_1-logloss:0.59651
# [352]	validation_0-logloss:0.57754	validation_1-logloss:0.59651
# [353]	validation_0-logloss:0.57742	validation_1-logloss:0.59644
# [354]	validation_0-logloss:0.57732	validation_1-logloss:0.59637
# [355]	validation_0-logloss:0.57727	validation_1-logloss:0.59636
# [356]	validation_0-logloss:0.57719	validation_1-logloss:0.59635
# [357]	validation_0-logloss:0.57713	validation_1-logloss:0.59635
# [358]	validation_0-logloss:0.57708	validation_1-logloss:0.59635
# [359]	validation_0-logloss:0.57698	validation_1-logloss:0.59631
# [360]	validation_0-logloss:0.57684	validation_1-logloss:0.59621
# [361]	validation_0-logloss:0.57678	validation_1-logloss:0.59619
# [362]	validation_0-logloss:0.57670	validation_1-logloss:0.59616
# [363]	validation_0-logloss:0.57663	validation_1-logloss:0.59615
# [364]	validation_0-logloss:0.57658	validation_1-logloss:0.59614
# [365]	validation_0-logloss:0.57646	validation_1-logloss:0.59605
# [366]	validation_0-logloss:0.57640	validation_1-logloss:0.59605
# [367]	validation_0-logloss:0.57634	validation_1-logloss:0.59606
# [368]	validation_0-logloss:0.57629	validation_1-logloss:0.59606
# [369]	validation_0-logloss:0.57623	validation_1-logloss:0.59605
# [370]	validation_0-logloss:0.57617	validation_1-logloss:0.59605
# [371]	validation_0-logloss:0.57612	validation_1-logloss:0.59605
# [372]	validation_0-logloss:0.57607	validation_1-logloss:0.59606
# [373]	validation_0-logloss:0.57602	validation_1-logloss:0.59606
# [374]	validation_0-logloss:0.57596	validation_1-logloss:0.59606
# [375]	validation_0-logloss:0.57591	validation_1-logloss:0.59607
# [376]	validation_0-logloss:0.57587	validation_1-logloss:0.59607
# [377]	validation_0-logloss:0.57577	validation_1-logloss:0.59603
# [378]	validation_0-logloss:0.57569	validation_1-logloss:0.59597
# [379]	validation_0-logloss:0.57559	validation_1-logloss:0.59593
# [380]	validation_0-logloss:0.57553	validation_1-logloss:0.59591
# [381]	validation_0-logloss:0.57546	validation_1-logloss:0.59590
# [382]	validation_0-logloss:0.57539	validation_1-logloss:0.59590
# [383]	validation_0-logloss:0.57531	validation_1-logloss:0.59587
# [384]	validation_0-logloss:0.57522	validation_1-logloss:0.59584
# [385]	validation_0-logloss:0.57516	validation_1-logloss:0.59584
# [386]	validation_0-logloss:0.57513	validation_1-logloss:0.59584
# [387]	validation_0-logloss:0.57508	validation_1-logloss:0.59584
# [388]	validation_0-logloss:0.57504	validation_1-logloss:0.59585
# [389]	validation_0-logloss:0.57498	validation_1-logloss:0.59584
# [390]	validation_0-logloss:0.57492	validation_1-logloss:0.59583
# [391]	validation_0-logloss:0.57484	validation_1-logloss:0.59579
# [392]	validation_0-logloss:0.57477	validation_1-logloss:0.59578
# [393]	validation_0-logloss:0.57471	validation_1-logloss:0.59577
# [394]	validation_0-logloss:0.57465	validation_1-logloss:0.59576
# [395]	validation_0-logloss:0.57459	validation_1-logloss:0.59575
# [396]	validation_0-logloss:0.57450	validation_1-logloss:0.59572
# [397]	validation_0-logloss:0.57444	validation_1-logloss:0.59572
# [398]	validation_0-logloss:0.57437	validation_1-logloss:0.59572
# [399]	validation_0-logloss:0.57428	validation_1-logloss:0.59569
# [400]	validation_0-logloss:0.57411	validation_1-logloss:0.59558
# [401]	validation_0-logloss:0.57403	validation_1-logloss:0.59557
# [402]	validation_0-logloss:0.57398	validation_1-logloss:0.59556
# [403]	validation_0-logloss:0.57389	validation_1-logloss:0.59552
# [404]	validation_0-logloss:0.57383	validation_1-logloss:0.59553
# [405]	validation_0-logloss:0.57376	validation_1-logloss:0.59552
# [406]	validation_0-logloss:0.57368	validation_1-logloss:0.59551
# [407]	validation_0-logloss:0.57361	validation_1-logloss:0.59550
# [408]	validation_0-logloss:0.57355	validation_1-logloss:0.59551
# [409]	validation_0-logloss:0.57350	validation_1-logloss:0.59550
# [410]	validation_0-logloss:0.57343	validation_1-logloss:0.59549
# [411]	validation_0-logloss:0.57338	validation_1-logloss:0.59549
# [412]	validation_0-logloss:0.57332	validation_1-logloss:0.59549
# [413]	validation_0-logloss:0.57326	validation_1-logloss:0.59549
# [414]	validation_0-logloss:0.57320	validation_1-logloss:0.59548
# [415]	validation_0-logloss:0.57315	validation_1-logloss:0.59548
# [416]	validation_0-logloss:0.57305	validation_1-logloss:0.59543
# [417]	validation_0-logloss:0.57300	validation_1-logloss:0.59544
# [418]	validation_0-logloss:0.57293	validation_1-logloss:0.59543
# [419]	validation_0-logloss:0.57286	validation_1-logloss:0.59542
# [420]	validation_0-logloss:0.57279	validation_1-logloss:0.59541
# [421]	validation_0-logloss:0.57272	validation_1-logloss:0.59540
# [422]	validation_0-logloss:0.57267	validation_1-logloss:0.59540
# [423]	validation_0-logloss:0.57263	validation_1-logloss:0.59539
# [424]	validation_0-logloss:0.57256	validation_1-logloss:0.59539
# [425]	validation_0-logloss:0.57248	validation_1-logloss:0.59537
# [426]	validation_0-logloss:0.57232	validation_1-logloss:0.59526
# [427]	validation_0-logloss:0.57226	validation_1-logloss:0.59524
# [428]	validation_0-logloss:0.57220	validation_1-logloss:0.59523
# [429]	validation_0-logloss:0.57212	validation_1-logloss:0.59521
# [430]	validation_0-logloss:0.57206	validation_1-logloss:0.59521
# [431]	validation_0-logloss:0.57201	validation_1-logloss:0.59520
# [432]	validation_0-logloss:0.57191	validation_1-logloss:0.59514
# [433]	validation_0-logloss:0.57186	validation_1-logloss:0.59515
# [434]	validation_0-logloss:0.57180	validation_1-logloss:0.59515
# [435]	validation_0-logloss:0.57172	validation_1-logloss:0.59512
# [436]	validation_0-logloss:0.57166	validation_1-logloss:0.59511
# [437]	validation_0-logloss:0.57161	validation_1-logloss:0.59511
# [438]	validation_0-logloss:0.57149	validation_1-logloss:0.59504
# [439]	validation_0-logloss:0.57142	validation_1-logloss:0.59504
# [440]	validation_0-logloss:0.57136	validation_1-logloss:0.59505
# [441]	validation_0-logloss:0.57129	validation_1-logloss:0.59505
# [442]	validation_0-logloss:0.57122	validation_1-logloss:0.59502
# [443]	validation_0-logloss:0.57116	validation_1-logloss:0.59502
# [444]	validation_0-logloss:0.57109	validation_1-logloss:0.59503
# [445]	validation_0-logloss:0.57098	validation_1-logloss:0.59496
# [446]	validation_0-logloss:0.57091	validation_1-logloss:0.59497
# [447]	validation_0-logloss:0.57087	validation_1-logloss:0.59496
# [448]	validation_0-logloss:0.57084	validation_1-logloss:0.59495
# [449]	validation_0-logloss:0.57078	validation_1-logloss:0.59495
# [450]	validation_0-logloss:0.57072	validation_1-logloss:0.59493
# [451]	validation_0-logloss:0.57066	validation_1-logloss:0.59493
# [452]	validation_0-logloss:0.57058	validation_1-logloss:0.59491
# [453]	validation_0-logloss:0.57049	validation_1-logloss:0.59487
# [454]	validation_0-logloss:0.57037	validation_1-logloss:0.59480
# [455]	validation_0-logloss:0.57029	validation_1-logloss:0.59479
# [456]	validation_0-logloss:0.57022	validation_1-logloss:0.59479
# [457]	validation_0-logloss:0.57016	validation_1-logloss:0.59477
# [458]	validation_0-logloss:0.57011	validation_1-logloss:0.59476
# [459]	validation_0-logloss:0.57007	validation_1-logloss:0.59476
# [460]	validation_0-logloss:0.57000	validation_1-logloss:0.59473
# [461]	validation_0-logloss:0.56992	validation_1-logloss:0.59468
# [462]	validation_0-logloss:0.56988	validation_1-logloss:0.59467
# [463]	validation_0-logloss:0.56982	validation_1-logloss:0.59467
# [464]	validation_0-logloss:0.56976	validation_1-logloss:0.59466
# [465]	validation_0-logloss:0.56966	validation_1-logloss:0.59463
# [466]	validation_0-logloss:0.56961	validation_1-logloss:0.59462
# [467]	validation_0-logloss:0.56956	validation_1-logloss:0.59460
# [468]	validation_0-logloss:0.56951	validation_1-logloss:0.59461
# [469]	validation_0-logloss:0.56945	validation_1-logloss:0.59460
# [470]	validation_0-logloss:0.56938	validation_1-logloss:0.59457
# [471]	validation_0-logloss:0.56932	validation_1-logloss:0.59458
# [472]	validation_0-logloss:0.56928	validation_1-logloss:0.59458
# [473]	validation_0-logloss:0.56924	validation_1-logloss:0.59458
# [474]	validation_0-logloss:0.56920	validation_1-logloss:0.59458
# [475]	validation_0-logloss:0.56915	validation_1-logloss:0.59458
# [476]	validation_0-logloss:0.56907	validation_1-logloss:0.59456
# [477]	validation_0-logloss:0.56901	validation_1-logloss:0.59456
# [478]	validation_0-logloss:0.56895	validation_1-logloss:0.59456
# [479]	validation_0-logloss:0.56890	validation_1-logloss:0.59456
# [480]	validation_0-logloss:0.56884	validation_1-logloss:0.59458
# [481]	validation_0-logloss:0.56878	validation_1-logloss:0.59459
# [482]	validation_0-logloss:0.56873	validation_1-logloss:0.59458
# [483]	validation_0-logloss:0.56868	validation_1-logloss:0.59457
# [484]	validation_0-logloss:0.56861	validation_1-logloss:0.59454
# [485]	validation_0-logloss:0.56854	validation_1-logloss:0.59454
# [486]	validation_0-logloss:0.56848	validation_1-logloss:0.59452
# [487]	validation_0-logloss:0.56840	validation_1-logloss:0.59452
# [488]	validation_0-logloss:0.56835	validation_1-logloss:0.59452
# [489]	validation_0-logloss:0.56829	validation_1-logloss:0.59453
# [490]	validation_0-logloss:0.56820	validation_1-logloss:0.59449
# [491]	validation_0-logloss:0.56813	validation_1-logloss:0.59450
# [492]	validation_0-logloss:0.56807	validation_1-logloss:0.59450
# [493]	validation_0-logloss:0.56799	validation_1-logloss:0.59449
# [494]	validation_0-logloss:0.56794	validation_1-logloss:0.59450
# [495]	validation_0-logloss:0.56788	validation_1-logloss:0.59450
# [496]	validation_0-logloss:0.56784	validation_1-logloss:0.59451
# [497]	validation_0-logloss:0.56778	validation_1-logloss:0.59451
# [498]	validation_0-logloss:0.56771	validation_1-logloss:0.59449
# [499]	validation_0-logloss:0.56765	validation_1-logloss:0.59448
# [500]	validation_0-logloss:0.56758	validation_1-logloss:0.59446
# [501]	validation_0-logloss:0.56752	validation_1-logloss:0.59445
# [502]	validation_0-logloss:0.56747	validation_1-logloss:0.59445
# [503]	validation_0-logloss:0.56741	validation_1-logloss:0.59445
# [504]	validation_0-logloss:0.56734	validation_1-logloss:0.59443
# [505]	validation_0-logloss:0.56731	validation_1-logloss:0.59444
# [506]	validation_0-logloss:0.56726	validation_1-logloss:0.59444
# [507]	validation_0-logloss:0.56719	validation_1-logloss:0.59444
# [508]	validation_0-logloss:0.56713	validation_1-logloss:0.59443
# [509]	validation_0-logloss:0.56708	validation_1-logloss:0.59440
# [510]	validation_0-logloss:0.56702	validation_1-logloss:0.59439
# [511]	validation_0-logloss:0.56696	validation_1-logloss:0.59440
# [512]	validation_0-logloss:0.56692	validation_1-logloss:0.59440
# [513]	validation_0-logloss:0.56689	validation_1-logloss:0.59440
# [514]	validation_0-logloss:0.56683	validation_1-logloss:0.59441
# [515]	validation_0-logloss:0.56676	validation_1-logloss:0.59441
# [516]	validation_0-logloss:0.56671	validation_1-logloss:0.59441
# [517]	validation_0-logloss:0.56667	validation_1-logloss:0.59441
# [518]	validation_0-logloss:0.56661	validation_1-logloss:0.59441
# [519]	validation_0-logloss:0.56655	validation_1-logloss:0.59439
# [520]	validation_0-logloss:0.56650	validation_1-logloss:0.59439
# [521]	validation_0-logloss:0.56639	validation_1-logloss:0.59434
# [522]	validation_0-logloss:0.56631	validation_1-logloss:0.59431
# [523]	validation_0-logloss:0.56625	validation_1-logloss:0.59431
# [524]	validation_0-logloss:0.56620	validation_1-logloss:0.59432
# [525]	validation_0-logloss:0.56613	validation_1-logloss:0.59432
# [526]	validation_0-logloss:0.56605	validation_1-logloss:0.59430
# [527]	validation_0-logloss:0.56600	validation_1-logloss:0.59429
# [528]	validation_0-logloss:0.56592	validation_1-logloss:0.59428
# [529]	validation_0-logloss:0.56586	validation_1-logloss:0.59426
# [530]	validation_0-logloss:0.56581	validation_1-logloss:0.59425
# [531]	validation_0-logloss:0.56574	validation_1-logloss:0.59424
# [532]	validation_0-logloss:0.56568	validation_1-logloss:0.59423
# [533]	validation_0-logloss:0.56562	validation_1-logloss:0.59423
# [534]	validation_0-logloss:0.56556	validation_1-logloss:0.59422
# [535]	validation_0-logloss:0.56549	validation_1-logloss:0.59422
# [536]	validation_0-logloss:0.56543	validation_1-logloss:0.59422
# [537]	validation_0-logloss:0.56540	validation_1-logloss:0.59422
# [538]	validation_0-logloss:0.56535	validation_1-logloss:0.59422
# [539]	validation_0-logloss:0.56531	validation_1-logloss:0.59424
# [540]	validation_0-logloss:0.56525	validation_1-logloss:0.59420
# [541]	validation_0-logloss:0.56520	validation_1-logloss:0.59420
# [542]	validation_0-logloss:0.56514	validation_1-logloss:0.59420
# [543]	validation_0-logloss:0.56507	validation_1-logloss:0.59419
# [544]	validation_0-logloss:0.56502	validation_1-logloss:0.59419
# [545]	validation_0-logloss:0.56497	validation_1-logloss:0.59419
# [546]	validation_0-logloss:0.56493	validation_1-logloss:0.59419
# [547]	validation_0-logloss:0.56487	validation_1-logloss:0.59419
# [548]	validation_0-logloss:0.56482	validation_1-logloss:0.59420
# [549]	validation_0-logloss:0.56476	validation_1-logloss:0.59420
# [550]	validation_0-logloss:0.56471	validation_1-logloss:0.59420
# [551]	validation_0-logloss:0.56466	validation_1-logloss:0.59421
# [552]	validation_0-logloss:0.56461	validation_1-logloss:0.59421
# [553]	validation_0-logloss:0.56455	validation_1-logloss:0.59421
# [554]	validation_0-logloss:0.56449	validation_1-logloss:0.59421
# [555]	validation_0-logloss:0.56443	validation_1-logloss:0.59421
# [556]	validation_0-logloss:0.56439	validation_1-logloss:0.59421
# [557]	validation_0-logloss:0.56432	validation_1-logloss:0.59421
# [558]	validation_0-logloss:0.56425	validation_1-logloss:0.59417
# [559]	validation_0-logloss:0.56421	validation_1-logloss:0.59419
# [560]	validation_0-logloss:0.56414	validation_1-logloss:0.59417
# [561]	validation_0-logloss:0.56408	validation_1-logloss:0.59418
# [562]	validation_0-logloss:0.56403	validation_1-logloss:0.59417
# [563]	validation_0-logloss:0.56390	validation_1-logloss:0.59408
# [564]	validation_0-logloss:0.56386	validation_1-logloss:0.59408
# [565]	validation_0-logloss:0.56379	validation_1-logloss:0.59405
# [566]	validation_0-logloss:0.56372	validation_1-logloss:0.59404
# [567]	validation_0-logloss:0.56363	validation_1-logloss:0.59402
# [568]	validation_0-logloss:0.56355	validation_1-logloss:0.59400
# [569]	validation_0-logloss:0.56349	validation_1-logloss:0.59398
# [570]	validation_0-logloss:0.56343	validation_1-logloss:0.59396
# [571]	validation_0-logloss:0.56338	validation_1-logloss:0.59396
# [572]	validation_0-logloss:0.56331	validation_1-logloss:0.59397
# [573]	validation_0-logloss:0.56324	validation_1-logloss:0.59397
# [574]	validation_0-logloss:0.56317	validation_1-logloss:0.59395
# [575]	validation_0-logloss:0.56311	validation_1-logloss:0.59393
# [576]	validation_0-logloss:0.56303	validation_1-logloss:0.59391
# [577]	validation_0-logloss:0.56297	validation_1-logloss:0.59392
# [578]	validation_0-logloss:0.56292	validation_1-logloss:0.59393
# [579]	validation_0-logloss:0.56284	validation_1-logloss:0.59391
# [580]	validation_0-logloss:0.56278	validation_1-logloss:0.59390
# [581]	validation_0-logloss:0.56274	validation_1-logloss:0.59391
# [582]	validation_0-logloss:0.56270	validation_1-logloss:0.59390
# [583]	validation_0-logloss:0.56264	validation_1-logloss:0.59390
# [584]	validation_0-logloss:0.56260	validation_1-logloss:0.59389
# [585]	validation_0-logloss:0.56253	validation_1-logloss:0.59387
# [586]	validation_0-logloss:0.56247	validation_1-logloss:0.59388
# [587]	validation_0-logloss:0.56241	validation_1-logloss:0.59387
# [588]	validation_0-logloss:0.56236	validation_1-logloss:0.59386
# [589]	validation_0-logloss:0.56229	validation_1-logloss:0.59384
# [590]	validation_0-logloss:0.56224	validation_1-logloss:0.59384
# [591]	validation_0-logloss:0.56218	validation_1-logloss:0.59385
# [592]	validation_0-logloss:0.56214	validation_1-logloss:0.59385
# [593]	validation_0-logloss:0.56209	validation_1-logloss:0.59385
# [594]	validation_0-logloss:0.56204	validation_1-logloss:0.59385
# [595]	validation_0-logloss:0.56199	validation_1-logloss:0.59385
# [596]	validation_0-logloss:0.56195	validation_1-logloss:0.59386
# [597]	validation_0-logloss:0.56189	validation_1-logloss:0.59385
# [598]	validation_0-logloss:0.56184	validation_1-logloss:0.59384
# [599]	validation_0-logloss:0.56175	validation_1-logloss:0.59379
# [600]	validation_0-logloss:0.56170	validation_1-logloss:0.59377
# [601]	validation_0-logloss:0.56165	validation_1-logloss:0.59378
# [602]	validation_0-logloss:0.56157	validation_1-logloss:0.59374
# [603]	validation_0-logloss:0.56153	validation_1-logloss:0.59376
# [604]	validation_0-logloss:0.56147	validation_1-logloss:0.59377
# [605]	validation_0-logloss:0.56142	validation_1-logloss:0.59377
# [606]	validation_0-logloss:0.56137	validation_1-logloss:0.59377
# [607]	validation_0-logloss:0.56132	validation_1-logloss:0.59378
# [608]	validation_0-logloss:0.56124	validation_1-logloss:0.59374
# [609]	validation_0-logloss:0.56115	validation_1-logloss:0.59370
# [610]	validation_0-logloss:0.56111	validation_1-logloss:0.59370
# [611]	validation_0-logloss:0.56105	validation_1-logloss:0.59370
# [612]	validation_0-logloss:0.56099	validation_1-logloss:0.59372
# [613]	validation_0-logloss:0.56094	validation_1-logloss:0.59371
# [614]	validation_0-logloss:0.56089	validation_1-logloss:0.59372
# [615]	validation_0-logloss:0.56084	validation_1-logloss:0.59373
# [616]	validation_0-logloss:0.56079	validation_1-logloss:0.59374
# [617]	validation_0-logloss:0.56074	validation_1-logloss:0.59373
# [618]	validation_0-logloss:0.56067	validation_1-logloss:0.59372
# [619]	validation_0-logloss:0.56061	validation_1-logloss:0.59373
# [620]	validation_0-logloss:0.56055	validation_1-logloss:0.59372
# [621]	validation_0-logloss:0.56050	validation_1-logloss:0.59371
# [622]	validation_0-logloss:0.56039	validation_1-logloss:0.59366
# [623]	validation_0-logloss:0.56033	validation_1-logloss:0.59365
# [624]	validation_0-logloss:0.56025	validation_1-logloss:0.59365
# [625]	validation_0-logloss:0.56020	validation_1-logloss:0.59363
# [626]	validation_0-logloss:0.56015	validation_1-logloss:0.59361
# [627]	validation_0-logloss:0.56010	validation_1-logloss:0.59362
# [628]	validation_0-logloss:0.56003	validation_1-logloss:0.59362
# [629]	validation_0-logloss:0.55997	validation_1-logloss:0.59363
# [630]	validation_0-logloss:0.55992	validation_1-logloss:0.59363
# [631]	validation_0-logloss:0.55985	validation_1-logloss:0.59363
# [632]	validation_0-logloss:0.55980	validation_1-logloss:0.59363
# [633]	validation_0-logloss:0.55976	validation_1-logloss:0.59364
# [634]	validation_0-logloss:0.55972	validation_1-logloss:0.59364
# [635]	validation_0-logloss:0.55967	validation_1-logloss:0.59363
# [636]	validation_0-logloss:0.55962	validation_1-logloss:0.59363
# [637]	validation_0-logloss:0.55957	validation_1-logloss:0.59364
# [638]	validation_0-logloss:0.55950	validation_1-logloss:0.59364
# [639]	validation_0-logloss:0.55944	validation_1-logloss:0.59364
# [640]	validation_0-logloss:0.55939	validation_1-logloss:0.59364
# [641]	validation_0-logloss:0.55933	validation_1-logloss:0.59365
# [642]	validation_0-logloss:0.55927	validation_1-logloss:0.59365
# [643]	validation_0-logloss:0.55922	validation_1-logloss:0.59364
# [644]	validation_0-logloss:0.55916	validation_1-logloss:0.59364
# [645]	validation_0-logloss:0.55911	validation_1-logloss:0.59365
# [646]	validation_0-logloss:0.55904	validation_1-logloss:0.59366
# [647]	validation_0-logloss:0.55899	validation_1-logloss:0.59366
# [648]	validation_0-logloss:0.55895	validation_1-logloss:0.59366
# [649]	validation_0-logloss:0.55890	validation_1-logloss:0.59367
# [650]	validation_0-logloss:0.55884	validation_1-logloss:0.59368
# [651]	validation_0-logloss:0.55879	validation_1-logloss:0.59368
# [652]	validation_0-logloss:0.55873	validation_1-logloss:0.59368
# [653]	validation_0-logloss:0.55868	validation_1-logloss:0.59368
# [654]	validation_0-logloss:0.55863	validation_1-logloss:0.59368
# [655]	validation_0-logloss:0.55858	validation_1-logloss:0.59368
# [656]	validation_0-logloss:0.55850	validation_1-logloss:0.59365
# [657]	validation_0-logloss:0.55837	validation_1-logloss:0.59358
# [658]	validation_0-logloss:0.55826	validation_1-logloss:0.59352
# [659]	validation_0-logloss:0.55821	validation_1-logloss:0.59351
# [660]	validation_0-logloss:0.55814	validation_1-logloss:0.59349
# [661]	validation_0-logloss:0.55807	validation_1-logloss:0.59348
# [662]	validation_0-logloss:0.55800	validation_1-logloss:0.59349
# [663]	validation_0-logloss:0.55796	validation_1-logloss:0.59348
# [664]	validation_0-logloss:0.55791	validation_1-logloss:0.59348
# [665]	validation_0-logloss:0.55787	validation_1-logloss:0.59350
# [666]	validation_0-logloss:0.55780	validation_1-logloss:0.59349
# [667]	validation_0-logloss:0.55776	validation_1-logloss:0.59348
# [668]	validation_0-logloss:0.55770	validation_1-logloss:0.59347
# [669]	validation_0-logloss:0.55765	validation_1-logloss:0.59347
# [670]	validation_0-logloss:0.55759	validation_1-logloss:0.59346
# [671]	validation_0-logloss:0.55753	validation_1-logloss:0.59347
# [672]	validation_0-logloss:0.55746	validation_1-logloss:0.59346
# [673]	validation_0-logloss:0.55741	validation_1-logloss:0.59346
# [674]	validation_0-logloss:0.55738	validation_1-logloss:0.59346
# [675]	validation_0-logloss:0.55731	validation_1-logloss:0.59346
# [676]	validation_0-logloss:0.55728	validation_1-logloss:0.59346
# [677]	validation_0-logloss:0.55721	validation_1-logloss:0.59345
# [678]	validation_0-logloss:0.55716	validation_1-logloss:0.59346
# [679]	validation_0-logloss:0.55710	validation_1-logloss:0.59346
# [680]	validation_0-logloss:0.55704	validation_1-logloss:0.59347
# [681]	validation_0-logloss:0.55699	validation_1-logloss:0.59347
# [682]	validation_0-logloss:0.55694	validation_1-logloss:0.59347
# [683]	validation_0-logloss:0.55688	validation_1-logloss:0.59346
# [684]	validation_0-logloss:0.55684	validation_1-logloss:0.59347
# [685]	validation_0-logloss:0.55679	validation_1-logloss:0.59348
# [686]	validation_0-logloss:0.55674	validation_1-logloss:0.59348
# [687]	validation_0-logloss:0.55667	validation_1-logloss:0.59349
# [688]	validation_0-logloss:0.55661	validation_1-logloss:0.59348
# [689]	validation_0-logloss:0.55657	validation_1-logloss:0.59347
# [690]	validation_0-logloss:0.55652	validation_1-logloss:0.59348
# [691]	validation_0-logloss:0.55645	validation_1-logloss:0.59348
# [692]	validation_0-logloss:0.55639	validation_1-logloss:0.59348
# [693]	validation_0-logloss:0.55633	validation_1-logloss:0.59348
# [694]	validation_0-logloss:0.55629	validation_1-logloss:0.59349
# [695]	validation_0-logloss:0.55624	validation_1-logloss:0.59349
# [696]	validation_0-logloss:0.55621	validation_1-logloss:0.59350
# [697]	validation_0-logloss:0.55617	validation_1-logloss:0.59351
# [698]	validation_0-logloss:0.55613	validation_1-logloss:0.59350
# [699]	validation_0-logloss:0.55608	validation_1-logloss:0.59351
# [700]	validation_0-logloss:0.55602	validation_1-logloss:0.59349
# [701]	validation_0-logloss:0.55596	validation_1-logloss:0.59349
# [702]	validation_0-logloss:0.55590	validation_1-logloss:0.59348
# [703]	validation_0-logloss:0.55582	validation_1-logloss:0.59346
# [704]	validation_0-logloss:0.55577	validation_1-logloss:0.59346
# [705]	validation_0-logloss:0.55571	validation_1-logloss:0.59348
# [706]	validation_0-logloss:0.55566	validation_1-logloss:0.59348
# [707]	validation_0-logloss:0.55560	validation_1-logloss:0.59347
# [708]	validation_0-logloss:0.55554	validation_1-logloss:0.59346
# [709]	validation_0-logloss:0.55550	validation_1-logloss:0.59345
# [710]	validation_0-logloss:0.55544	validation_1-logloss:0.59346
# [711]	validation_0-logloss:0.55539	validation_1-logloss:0.59346
# [712]	validation_0-logloss:0.55533	validation_1-logloss:0.59346
# [713]	validation_0-logloss:0.55528	validation_1-logloss:0.59346
# [714]	validation_0-logloss:0.55521	validation_1-logloss:0.59345
# [715]	validation_0-logloss:0.55515	validation_1-logloss:0.59345
# [716]	validation_0-logloss:0.55510	validation_1-logloss:0.59345
# [717]	validation_0-logloss:0.55504	validation_1-logloss:0.59346
# [718]	validation_0-logloss:0.55499	validation_1-logloss:0.59346
# [719]	validation_0-logloss:0.55492	validation_1-logloss:0.59342
# [720]	validation_0-logloss:0.55485	validation_1-logloss:0.59342
# [721]	validation_0-logloss:0.55480	validation_1-logloss:0.59343
# [722]	validation_0-logloss:0.55475	validation_1-logloss:0.59343
# [723]	validation_0-logloss:0.55470	validation_1-logloss:0.59342
# [724]	validation_0-logloss:0.55464	validation_1-logloss:0.59342
# [725]	validation_0-logloss:0.55456	validation_1-logloss:0.59339
# [726]	validation_0-logloss:0.55449	validation_1-logloss:0.59337
# [727]	validation_0-logloss:0.55444	validation_1-logloss:0.59337
# [728]	validation_0-logloss:0.55439	validation_1-logloss:0.59337
# [729]	validation_0-logloss:0.55433	validation_1-logloss:0.59336
# [730]	validation_0-logloss:0.55428	validation_1-logloss:0.59338
# [731]	validation_0-logloss:0.55423	validation_1-logloss:0.59337
# [732]	validation_0-logloss:0.55416	validation_1-logloss:0.59335
# [733]	validation_0-logloss:0.55410	validation_1-logloss:0.59335
# [734]	validation_0-logloss:0.55401	validation_1-logloss:0.59333
# [735]	validation_0-logloss:0.55394	validation_1-logloss:0.59332
# [736]	validation_0-logloss:0.55387	validation_1-logloss:0.59329
# [737]	validation_0-logloss:0.55381	validation_1-logloss:0.59326
# [738]	validation_0-logloss:0.55373	validation_1-logloss:0.59323
# [739]	validation_0-logloss:0.55369	validation_1-logloss:0.59323
# [740]	validation_0-logloss:0.55362	validation_1-logloss:0.59323
# [741]	validation_0-logloss:0.55356	validation_1-logloss:0.59323
# [742]	validation_0-logloss:0.55352	validation_1-logloss:0.59323
# [743]	validation_0-logloss:0.55347	validation_1-logloss:0.59323
# [744]	validation_0-logloss:0.55341	validation_1-logloss:0.59323
# [745]	validation_0-logloss:0.55334	validation_1-logloss:0.59323
# [746]	validation_0-logloss:0.55328	validation_1-logloss:0.59324
# [747]	validation_0-logloss:0.55323	validation_1-logloss:0.59324
# [748]	validation_0-logloss:0.55317	validation_1-logloss:0.59325
# [749]	validation_0-logloss:0.55311	validation_1-logloss:0.59325
# [750]	validation_0-logloss:0.55302	validation_1-logloss:0.59322
# [751]	validation_0-logloss:0.55298	validation_1-logloss:0.59321
# [752]	validation_0-logloss:0.55292	validation_1-logloss:0.59322
# [753]	validation_0-logloss:0.55286	validation_1-logloss:0.59322
# [754]	validation_0-logloss:0.55280	validation_1-logloss:0.59322
# [755]	validation_0-logloss:0.55276	validation_1-logloss:0.59323
# [756]	validation_0-logloss:0.55270	validation_1-logloss:0.59323
# [757]	validation_0-logloss:0.55263	validation_1-logloss:0.59323
# [758]	validation_0-logloss:0.55258	validation_1-logloss:0.59322
# [759]	validation_0-logloss:0.55251	validation_1-logloss:0.59320
# [760]	validation_0-logloss:0.55246	validation_1-logloss:0.59320
# [761]	validation_0-logloss:0.55241	validation_1-logloss:0.59320
# [762]	validation_0-logloss:0.55235	validation_1-logloss:0.59320
# [763]	validation_0-logloss:0.55229	validation_1-logloss:0.59320
# [764]	validation_0-logloss:0.55224	validation_1-logloss:0.59320
# [765]	validation_0-logloss:0.55220	validation_1-logloss:0.59320
# [766]	validation_0-logloss:0.55215	validation_1-logloss:0.59319
# [767]	validation_0-logloss:0.55210	validation_1-logloss:0.59318
# [768]	validation_0-logloss:0.55205	validation_1-logloss:0.59319
# [769]	validation_0-logloss:0.55200	validation_1-logloss:0.59319
# [770]	validation_0-logloss:0.55195	validation_1-logloss:0.59319
# [771]	validation_0-logloss:0.55190	validation_1-logloss:0.59320
# [772]	validation_0-logloss:0.55185	validation_1-logloss:0.59320
# [773]	validation_0-logloss:0.55179	validation_1-logloss:0.59320
# [774]	validation_0-logloss:0.55174	validation_1-logloss:0.59321
# [775]	validation_0-logloss:0.55169	validation_1-logloss:0.59322
# [776]	validation_0-logloss:0.55163	validation_1-logloss:0.59322
# [777]	validation_0-logloss:0.55156	validation_1-logloss:0.59322
# [778]	validation_0-logloss:0.55150	validation_1-logloss:0.59322
# [779]	validation_0-logloss:0.55145	validation_1-logloss:0.59321
# [780]	validation_0-logloss:0.55138	validation_1-logloss:0.59322
# [781]	validation_0-logloss:0.55133	validation_1-logloss:0.59320
# [782]	validation_0-logloss:0.55128	validation_1-logloss:0.59320
# [783]	validation_0-logloss:0.55122	validation_1-logloss:0.59320
# [784]	validation_0-logloss:0.55116	validation_1-logloss:0.59320
# [785]	validation_0-logloss:0.55110	validation_1-logloss:0.59320
# [786]	validation_0-logloss:0.55106	validation_1-logloss:0.59319
# [787]	validation_0-logloss:0.55100	validation_1-logloss:0.59319
# [788]	validation_0-logloss:0.55095	validation_1-logloss:0.59320
# [789]	validation_0-logloss:0.55090	validation_1-logloss:0.59321
# [790]	validation_0-logloss:0.55085	validation_1-logloss:0.59321
# [791]	validation_0-logloss:0.55081	validation_1-logloss:0.59320
# [792]	validation_0-logloss:0.55075	validation_1-logloss:0.59319
# [793]	validation_0-logloss:0.55070	validation_1-logloss:0.59319
# [794]	validation_0-logloss:0.55061	validation_1-logloss:0.59315
# [795]	validation_0-logloss:0.55055	validation_1-logloss:0.59314
# [796]	validation_0-logloss:0.55050	validation_1-logloss:0.59313
# [797]	validation_0-logloss:0.55041	validation_1-logloss:0.59308
# [798]	validation_0-logloss:0.55036	validation_1-logloss:0.59308
# [799]	validation_0-logloss:0.55031	validation_1-logloss:0.59310
# [800]	validation_0-logloss:0.55028	validation_1-logloss:0.59310
# [801]	validation_0-logloss:0.55023	validation_1-logloss:0.59310
# [802]	validation_0-logloss:0.55018	validation_1-logloss:0.59310
# [803]	validation_0-logloss:0.55013	validation_1-logloss:0.59310
# [804]	validation_0-logloss:0.55008	validation_1-logloss:0.59311
# [805]	validation_0-logloss:0.55003	validation_1-logloss:0.59312
# [806]	validation_0-logloss:0.54997	validation_1-logloss:0.59312
# [807]	validation_0-logloss:0.54993	validation_1-logloss:0.59312
# [808]	validation_0-logloss:0.54988	validation_1-logloss:0.59312
# [809]	validation_0-logloss:0.54983	validation_1-logloss:0.59311
# [810]	validation_0-logloss:0.54977	validation_1-logloss:0.59313
# [811]	validation_0-logloss:0.54971	validation_1-logloss:0.59314
# [812]	validation_0-logloss:0.54968	validation_1-logloss:0.59315
# [813]	validation_0-logloss:0.54964	validation_1-logloss:0.59315
# [814]	validation_0-logloss:0.54960	validation_1-logloss:0.59316
# [815]	validation_0-logloss:0.54956	validation_1-logloss:0.59315
# [816]	validation_0-logloss:0.54950	validation_1-logloss:0.59315
# [817]	validation_0-logloss:0.54945	validation_1-logloss:0.59315
# [818]	validation_0-logloss:0.54940	validation_1-logloss:0.59317
# [819]	validation_0-logloss:0.54936	validation_1-logloss:0.59318
# [820]	validation_0-logloss:0.54932	validation_1-logloss:0.59318
# [821]	validation_0-logloss:0.54927	validation_1-logloss:0.59318
# [822]	validation_0-logloss:0.54923	validation_1-logloss:0.59318
# [823]	validation_0-logloss:0.54917	validation_1-logloss:0.59318
# [824]	validation_0-logloss:0.54911	validation_1-logloss:0.59318
# [825]	validation_0-logloss:0.54906	validation_1-logloss:0.59318
# [826]	validation_0-logloss:0.54900	validation_1-logloss:0.59318
# [827]	validation_0-logloss:0.54895	validation_1-logloss:0.59319
# [828]	validation_0-logloss:0.54890	validation_1-logloss:0.59319
# [829]	validation_0-logloss:0.54886	validation_1-logloss:0.59319
# [830]	validation_0-logloss:0.54879	validation_1-logloss:0.59318
# [831]	validation_0-logloss:0.54875	validation_1-logloss:0.59318
# [832]	validation_0-logloss:0.54871	validation_1-logloss:0.59320
# [833]	validation_0-logloss:0.54866	validation_1-logloss:0.59319
# [834]	validation_0-logloss:0.54860	validation_1-logloss:0.59319
# [835]	validation_0-logloss:0.54855	validation_1-logloss:0.59318
# [836]	validation_0-logloss:0.54850	validation_1-logloss:0.59318
# [837]	validation_0-logloss:0.54846	validation_1-logloss:0.59316
# [838]	validation_0-logloss:0.54841	validation_1-logloss:0.59317
# [839]	validation_0-logloss:0.54837	validation_1-logloss:0.59316
# [840]	validation_0-logloss:0.54835	validation_1-logloss:0.59316
# [841]	validation_0-logloss:0.54830	validation_1-logloss:0.59316
# [842]	validation_0-logloss:0.54823	validation_1-logloss:0.59314
# [843]	validation_0-logloss:0.54815	validation_1-logloss:0.59309
# [844]	validation_0-logloss:0.54812	validation_1-logloss:0.59309
# [845]	validation_0-logloss:0.54807	validation_1-logloss:0.59309
# [846]	validation_0-logloss:0.54800	validation_1-logloss:0.59306
# [847]	validation_0-logloss:0.54793	validation_1-logloss:0.59306
# [848]	validation_0-logloss:0.54788	validation_1-logloss:0.59307
# [849]	validation_0-logloss:0.54784	validation_1-logloss:0.59307
# [850]	validation_0-logloss:0.54780	validation_1-logloss:0.59307
# [851]	validation_0-logloss:0.54775	validation_1-logloss:0.59308
# [852]	validation_0-logloss:0.54770	validation_1-logloss:0.59308
# [853]	validation_0-logloss:0.54766	validation_1-logloss:0.59309
# [854]	validation_0-logloss:0.54763	validation_1-logloss:0.59308
# [855]	validation_0-logloss:0.54758	validation_1-logloss:0.59309
# [856]	validation_0-logloss:0.54750	validation_1-logloss:0.59307
# [857]	validation_0-logloss:0.54745	validation_1-logloss:0.59308
# [858]	validation_0-logloss:0.54740	validation_1-logloss:0.59308
# [859]	validation_0-logloss:0.54733	validation_1-logloss:0.59309
# [860]	validation_0-logloss:0.54727	validation_1-logloss:0.59309
# [861]	validation_0-logloss:0.54722	validation_1-logloss:0.59307
# [862]	validation_0-logloss:0.54715	validation_1-logloss:0.59308
# [863]	validation_0-logloss:0.54709	validation_1-logloss:0.59307
# [864]	validation_0-logloss:0.54704	validation_1-logloss:0.59307
# [865]	validation_0-logloss:0.54699	validation_1-logloss:0.59307
# [866]	validation_0-logloss:0.54692	validation_1-logloss:0.59306
# [867]	validation_0-logloss:0.54687	validation_1-logloss:0.59306
# [868]	validation_0-logloss:0.54682	validation_1-logloss:0.59305
# [869]	validation_0-logloss:0.54676	validation_1-logloss:0.59304
# [870]	validation_0-logloss:0.54671	validation_1-logloss:0.59306
# [871]	validation_0-logloss:0.54666	validation_1-logloss:0.59305
# [872]	validation_0-logloss:0.54656	validation_1-logloss:0.59300
# [873]	validation_0-logloss:0.54651	validation_1-logloss:0.59299
# [874]	validation_0-logloss:0.54645	validation_1-logloss:0.59300
# [875]	validation_0-logloss:0.54640	validation_1-logloss:0.59301
# [876]	validation_0-logloss:0.54634	validation_1-logloss:0.59300
# [877]	validation_0-logloss:0.54629	validation_1-logloss:0.59300
# [878]	validation_0-logloss:0.54625	validation_1-logloss:0.59300
# [879]	validation_0-logloss:0.54619	validation_1-logloss:0.59301
# [880]	validation_0-logloss:0.54613	validation_1-logloss:0.59301
# [881]	validation_0-logloss:0.54608	validation_1-logloss:0.59302
# [882]	validation_0-logloss:0.54601	validation_1-logloss:0.59299
# [883]	validation_0-logloss:0.54596	validation_1-logloss:0.59299
# [884]	validation_0-logloss:0.54590	validation_1-logloss:0.59298
# [885]	validation_0-logloss:0.54585	validation_1-logloss:0.59299
# [886]	validation_0-logloss:0.54581	validation_1-logloss:0.59299
# [887]	validation_0-logloss:0.54576	validation_1-logloss:0.59298
# [888]	validation_0-logloss:0.54570	validation_1-logloss:0.59299
# [889]	validation_0-logloss:0.54565	validation_1-logloss:0.59299
# [890]	validation_0-logloss:0.54560	validation_1-logloss:0.59299
# [891]	validation_0-logloss:0.54555	validation_1-logloss:0.59299
# [892]	validation_0-logloss:0.54552	validation_1-logloss:0.59300
# [893]	validation_0-logloss:0.54545	validation_1-logloss:0.59301
# [894]	validation_0-logloss:0.54540	validation_1-logloss:0.59300
# [895]	validation_0-logloss:0.54535	validation_1-logloss:0.59301
# [896]	validation_0-logloss:0.54527	validation_1-logloss:0.59299
# [897]	validation_0-logloss:0.54522	validation_1-logloss:0.59299
# [898]	validation_0-logloss:0.54518	validation_1-logloss:0.59298
# [899]	validation_0-logloss:0.54513	validation_1-logloss:0.59298
# [900]	validation_0-logloss:0.54508	validation_1-logloss:0.59297
# [901]	validation_0-logloss:0.54502	validation_1-logloss:0.59298
# [902]	validation_0-logloss:0.54498	validation_1-logloss:0.59298
# [903]	validation_0-logloss:0.54493	validation_1-logloss:0.59298
# [904]	validation_0-logloss:0.54487	validation_1-logloss:0.59299
# [905]	validation_0-logloss:0.54481	validation_1-logloss:0.59300
# [906]	validation_0-logloss:0.54476	validation_1-logloss:0.59301
# [907]	validation_0-logloss:0.54470	validation_1-logloss:0.59301
# [908]	validation_0-logloss:0.54465	validation_1-logloss:0.59301
# [909]	validation_0-logloss:0.54460	validation_1-logloss:0.59303
# [910]	validation_0-logloss:0.54454	validation_1-logloss:0.59301
# [911]	validation_0-logloss:0.54449	validation_1-logloss:0.59300
# [912]	validation_0-logloss:0.54444	validation_1-logloss:0.59302
# [913]	validation_0-logloss:0.54440	validation_1-logloss:0.59302
# [914]	validation_0-logloss:0.54435	validation_1-logloss:0.59302
# [915]	validation_0-logloss:0.54430	validation_1-logloss:0.59301
# [916]	validation_0-logloss:0.54425	validation_1-logloss:0.59301
# [917]	validation_0-logloss:0.54421	validation_1-logloss:0.59301
# [918]	validation_0-logloss:0.54416	validation_1-logloss:0.59301
# [919]	validation_0-logloss:0.54412	validation_1-logloss:0.59302
# [920]	validation_0-logloss:0.54406	validation_1-logloss:0.59302
# [921]	validation_0-logloss:0.54401	validation_1-logloss:0.59302
# [922]	validation_0-logloss:0.54393	validation_1-logloss:0.59300
# [923]	validation_0-logloss:0.54388	validation_1-logloss:0.59300
# [924]	validation_0-logloss:0.54382	validation_1-logloss:0.59300
# [925]	validation_0-logloss:0.54377	validation_1-logloss:0.59301
# [926]	validation_0-logloss:0.54372	validation_1-logloss:0.59302
# [927]	validation_0-logloss:0.54367	validation_1-logloss:0.59302
# [928]	validation_0-logloss:0.54363	validation_1-logloss:0.59303
# [929]	validation_0-logloss:0.54358	validation_1-logloss:0.59304
# [930]	validation_0-logloss:0.54353	validation_1-logloss:0.59303
# [931]	validation_0-logloss:0.54348	validation_1-logloss:0.59305
# [932]	validation_0-logloss:0.54343	validation_1-logloss:0.59305
# [933]	validation_0-logloss:0.54339	validation_1-logloss:0.59304
# [934]	validation_0-logloss:0.54332	validation_1-logloss:0.59303
# [935]	validation_0-logloss:0.54327	validation_1-logloss:0.59303
# [936]	validation_0-logloss:0.54322	validation_1-logloss:0.59302
# [937]	validation_0-logloss:0.54316	validation_1-logloss:0.59301
# [938]	validation_0-logloss:0.54309	validation_1-logloss:0.59301
# [939]	validation_0-logloss:0.54304	validation_1-logloss:0.59302
# [940]	validation_0-logloss:0.54299	validation_1-logloss:0.59303
# [941]	validation_0-logloss:0.54293	validation_1-logloss:0.59304
# [942]	validation_0-logloss:0.54288	validation_1-logloss:0.59305
# [943]	validation_0-logloss:0.54283	validation_1-logloss:0.59306
# [944]	validation_0-logloss:0.54278	validation_1-logloss:0.59307
# [945]	validation_0-logloss:0.54273	validation_1-logloss:0.59306
# [946]	validation_0-logloss:0.54269	validation_1-logloss:0.59306
# [947]	validation_0-logloss:0.54263	validation_1-logloss:0.59308
# [948]	validation_0-logloss:0.54257	validation_1-logloss:0.59307
# [949]	validation_0-logloss:0.54253	validation_1-logloss:0.59307
# [950]	validation_0-logloss:0.54247	validation_1-logloss:0.59308

# %%
# LOAD
classifier_spin = XGBClassifier()
classifier_spin.load_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta0.json")


y_score = classifier_spin.predict_proba(X_test_spin)[:, 1]


fpr, tpr, thresholds = roc_curve(y_test_spin, y_score)
roc_auc = roc_auc_score(y_test_spin, y_score)

print("Global AUC =", roc_auc)


plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + 'saved-results/ROC_classB.pdf', bbox_inches='tight')
plt.show()




keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$',
                #  r'$m_{\mathrm{LQ}}^{\mathrm{reg}}$',
                 r'$S_{\mathrm{Poiss}}$'])

feature_important = classifier_spin.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())


data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=12).remove()
plt.title(r'SLQ vs VLQ', fontsize=14)
# plt.savefig(mainfolder + 'saved-results/XG_feature_importance_classB.pdf', bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Global AUC = 0.741937698816
# [52, 19, 22, 53, 35, 18, 9, 15, 38, 36, 37, 45, 48, 3, 50]

# %%
S_column = X_test_spin[:, -1]

# mSLQ_plot = [1200, 1500, 1800]
# mVLQ_plot = [1600, 1900, 2200]

linestyles = ['-','-','-', '--','--','--', ':', ':', ':']
# colors_SLQ = ['lightcoral', 'red', 'firebrick']
# colors_VLQ = ['limegreen', 'green', 'darkgreen']

plt.figure(figsize=(6,5))

# evaluate per sector
for iit, S_id in enumerate(S_expected_SLQ):
    # if iit == 0 or iit == 1 or iit == 9:
    #     continue
    # else:
    if iit == 2 or iit == 5 or iit == 8:

        mask = (S_column < S_id * 1.1) & (0.9 * S_id < S_column)

        y_true_Spoiss = y_test_spin[mask]
        y_score_Spoiss = y_score[mask]

        fpr, tpr, _ = roc_curve(y_true_Spoiss, y_score_Spoiss)
        auc_sector = roc_auc_score(y_true_Spoiss, y_score_Spoiss)

        print(f"$m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV,   AUC = {auc_sector:.5f}")


        plt.plot(fpr, tpr, color='darkorange', linestyle=linestyles[iit], lw=2, label=f"AUC = {auc_sector:.3f}, $m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV - $m_{{LQ_3^V}}=${masses_VLQ[iit]} GeV")



plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=11.3)
# plt.savefig(mainfolder + 'saved-results/ROC_classB_multi.pdf', bbox_inches='tight')
plt.show()
# Out:
# $m_{LQ_3^S}=$1200 GeV,   AUC = 0.77677
# $m_{LQ_3^S}=$1500 GeV,   AUC = 0.72984
# $m_{LQ_3^S}=$1800 GeV,   AUC = 0.70271

# %% [markdown]
# # JOIN BOTH ML

# %%
# --- Clasificador A: SM vs LQ ---

scoresA_SM = xgb_clf.predict_proba( df_SM_norm )[:,1]

scoresA_SLQ = {}
scoresA_VLQ = {}

m_SLQ = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
m_VLQ = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

S_exp_SLQ = S_expected_SLQ[2:]
S_exp_both = S_mean_fit_both[2:]

for m in m_SLQ:
    scoresA_SLQ[m] = xgb_clf.predict_proba( df_SLQ_norm[m] )[:,1]

for m in m_VLQ:
    scoresA_VLQ[m] = xgb_clf.predict_proba( df_VLQ_norm[m] )[:,1]

# %%
# --- Clasificador B: SLQ vs VLQ ---

X_sm = df_SM_norm

rand_samples_B =np.random.randint(1, S_exp_both[0] + S_std_fit_both[0], size=len(X_sm))

X_sm = np.column_stack([X_sm, rand_samples_B])

scoresB_SM = classifier_spin.predict_proba(X_sm)[:,1]


scoresB_SLQ = {}
scoresB_VLQ = {}

for iit, S_id in enumerate(m_SLQ):

    X_s = df_SLQ_norm[m_SLQ[iit]].values
    X_v = df_VLQ_norm[m_VLQ[iit]].values

    poisson_samples_SLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_s))
    poisson_samples_VLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_v))

    X_s = np.column_stack([X_s, poisson_samples_SLQ])
    X_v = np.column_stack([X_v, poisson_samples_VLQ])

    scoresB_SLQ[m_SLQ[iit]] = classifier_spin.predict_proba(X_s)[:,1]
    scoresB_VLQ[m_VLQ[iit]] = classifier_spin.predict_proba(X_v)[:,1]

# %%
# --- Juntar los scores del clasificador A y B

events_SM = np.column_stack([scoresA_SM, scoresB_SM])

events_SLQ = {}
for m in scoresA_SLQ:
    events_SLQ[m] = np.column_stack([scoresA_SLQ[m], scoresB_SLQ[m]])

events_VLQ = {}
for m in scoresA_VLQ:
    events_VLQ[m] = np.column_stack([scoresA_VLQ[m], scoresB_VLQ[m]])

# %% [markdown]
# #### Define the test statistic

# %%
def compute_test_statistic(scoresA, scoresB, threshold):
    """
    Sum of Log-Likelihood Ratios (LLR)

    T = Sum log (P(VLQ) / P(SLQ))

    P(VLQ) = score SLQ vs VLQ classifier
    P(SLQ) = 1 - score SLQ vs VLQ classifier
    """

    mask = scoresA > threshold

    scoresB_sel = scoresB[mask]

    if len(scoresB_sel) == 0:
        return 0

    eps = 1e-6
    s = np.clip(scoresB_sel, eps, 1-eps)

    T = np.sum(np.log(s/(1-s)))

    return T

# %% [markdown]
# ### For all the masses

# %%
# funcion para generar pseudo experimentos (da los scores de ambos clasificadores para ese pseudo)

def generate_pseudo(events_B, events_S, N_B, N_S):

    sample_B = events_B[np.random.randint(len(events_B), size=N_B)]
    sample_S = events_S[np.random.randint(len(events_S), size=N_S)]

    sample_all = np.vstack([sample_B, sample_S])

    scoresA = sample_all[:,0]
    scoresB = sample_all[:,1]

    return scoresA, scoresB

# %%
B_expected = 45962

S_exp_SLQ = [round(fid_xsec_SLQ_14TeV(mmm, beta) * Lum) for mmm in m_SLQ]
S_exp_VLQ = [round(fid_xsec_VLQ_14TeV(mmm, beta) * Lum) for mmm in m_VLQ]

print('beta = ', beta)
print('\nB_expected: ', B_expected)
print('\nS_exp_SLQ: ', S_exp_SLQ, '   m =', m_SLQ)
print('S_exp_VLQ: ', S_exp_VLQ, '   m =', m_VLQ)
print('S_exp_both: ', S_exp_both)
# Out:
# beta =  0.0
#
# B_expected:  45962
#
# S_exp_SLQ:  [98, 55, 31, 18, 11, 6, 4, 2]    m = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_exp_VLQ:  [105, 62, 36, 22, 13, 8, 5, 3]    m = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_exp_both:  [np.float64(93.75623451458402), np.float64(54.122570339749856), np.float64(31.410387355827854), np.float64(18.952262251534734), np.float64(12.646023347218758), np.float64(8.860403610098034), np.float64(7.4960551817572725), np.float64(5.835719136928903)]

# %% [markdown]
# #### Distribution of the statistic with only SLQ and only VLQ

# %%
n_pseudo_TRUE = 1000
threshold_A = 0.95

# %%
mu_S = []
mu_V = []

sigma_S = []
sigma_V = []

for S_it in range(len(S_exp_SLQ)):

    print("\n==========================")
    print("S_expected SLQ =", S_exp_SLQ[S_it])
    # print("S_expected VLQ =", S_exp_VLQ[S_it]) # same number of events

    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[S_it]
    mass_VLQ = m_VLQ[S_it]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    for i in range(n_pseudo_TRUE):

        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_exp_SLQ[S_it])

        scoresA, scoresB = generate_pseudo( events_SM, events_SLQ[mass_SLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)


        N_S = np.random.poisson(S_exp_SLQ[S_it]) # same number of events

        scoresA, scoresB = generate_pseudo( events_SM, events_VLQ[mass_VLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

        # Compute the Z of the distributions
    mu_S.append( np.mean(T_SLQ) )
    mu_V.append( np.mean(T_VLQ) )

    sigma_S.append( np.std(T_SLQ) )
    sigma_V.append( np.std(T_VLQ) )

print(mu_S)
print(mu_V)

print(sigma_S)
print(sigma_V)
# Out:
# ==========================
# S_expected SLQ = 98
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
#
# ==========================
# S_expected SLQ = 55
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
#
# ==========================
# S_expected SLQ = 31
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
#
# ==========================
# S_expected SLQ = 18
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
#
# ==========================
# S_expected SLQ = 11
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
#
# ==========================
# S_expected SLQ = 6
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
#
# ==========================
# S_expected SLQ = 4
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
#
# ==========================
# S_expected SLQ = 2
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# [np.float32(-57.11261), np.float32(-40.90549), np.float32(-30.599907), np.float32(-24.91663), np.float32(-22.891285), np.float32(-21.21305), np.float32(-20.443653), np.float32(-19.622011)]
# [np.float32(47.807167), np.float32(12.530654), np.float32(-4.3727336), np.float32(-11.85368), np.float32(-15.639789), np.float32(-17.347277), np.float32(-18.407547), np.float32(-18.4161)]
# [np.float32(13.715941), np.float32(12.696116), np.float32(11.864164), np.float32(11.526486), np.float32(11.33807), np.float32(11.387192), np.float32(11.412686), np.float32(11.448017)]
# [np.float32(17.504576), np.float32(13.866327), np.float32(12.45058), np.float32(12.310761), np.float32(11.946875), np.float32(11.022984), np.float32(11.508316), np.float32(11.310037)]

# %%
f_mu_S = interp1d(S_exp_SLQ, mu_S, kind='linear', fill_value="extrapolate")
f_mu_V = interp1d(S_exp_SLQ, mu_V, kind='linear', fill_value="extrapolate")

f_sigma_S = interp1d(S_exp_SLQ, sigma_S, kind='linear', fill_value="extrapolate")
f_sigma_V = interp1d(S_exp_SLQ, sigma_V, kind='linear', fill_value="extrapolate")



S_plot = np.linspace(min(S_exp_SLQ), max(S_exp_SLQ), 100)



plt.scatter(S_exp_SLQ, mu_S, marker='o')
plt.plot(S_plot, f_mu_S(S_plot))
plt.scatter(S_exp_SLQ, mu_V, marker='o')
plt.plot(S_plot, f_mu_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\mu$", fontsize=14)

plt.grid()
plt.show()


plt.scatter(S_exp_SLQ, sigma_S, marker='o')
plt.plot(S_plot, f_sigma_S(S_plot))
plt.scatter(S_exp_SLQ, sigma_V, marker='o')
plt.plot(S_plot, f_sigma_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\sigma$", fontsize=14)

plt.grid()
plt.show()

# %%
Z_threshold = 5

results_Z_gauss = []

for pair_it in range(len(mu_S)):
    Z = abs(mu_V[pair_it] - mu_S[pair_it]) / np.sqrt(sigma_S[pair_it]**2 + sigma_V[pair_it]**2)

    results_Z_gauss.append(Z)


plt.plot(S_exp_SLQ, results_Z_gauss, marker='o')

plt.xlabel("Expected signal events", fontsize=14)
plt.ylabel("Distribution discrimination Z", fontsize=14)

plt.grid()
plt.show()


#  interpolate
f_results_Z = interp1d(S_exp_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mSLQ = interp1d(m_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mVLQ = interp1d(m_VLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")


# find the S or the mass such that we get Z_threshold
S_threshold = fsolve(lambda x: f_results_Z(x) - Z_threshold,150)[0]
mSLQ_threshold = fsolve(lambda x: f_results_Z_mSLQ(x) - Z_threshold,1500)[0]
mVLQ_threshold = fsolve(lambda x: f_results_Z_mVLQ(x) - Z_threshold,1900)[0]

print(' Z:       ', Z_threshold)
print(' S:       ', S_threshold)
print(' m_SLQ:   ', mSLQ_threshold, ' [GeV]')
print(' m_VLQ:   ', mVLQ_threshold, ' [GeV]\n')
# Out:
#  Z:        5
#  S:        104.46460087623802
#  m_SLQ:    1184.9660444738652  [GeV]
#  m_VLQ:    1584.9660444738652  [GeV]
# /tmp/ipykernel_13959/699503059.py:28: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   mSLQ_threshold = fsolve(lambda x: f_results_Z_mSLQ(x) - Z_threshold,1500)[0]
# /tmp/ipykernel_13959/699503059.py:29: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   mVLQ_threshold = fsolve(lambda x: f_results_Z_mVLQ(x) - Z_threshold,1900)[0]

# %% [markdown]
# #### Prepare the data

# %% [markdown]
# ##### To compute S_expected for each pseudo using the 1st classifier we need the PDFs

# %%
# --- Clasificador A: SM vs LQ ---

# output of all the signal events
scoresA_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]



bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scoresA_SM, bins=bins, density=True)
hist_S, _ = np.histogram(scoresA_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %% [markdown]
# ##### to compute the closest mass/index/bechmark

# %%
def search_bench(S_pseudo, S_list_means, S_list_std, masses_list=None):
    """ finds the index of the closest benchmark

    Inputs:
    -----------
    S_pseudo : float -> S computed or fitted (e.g. muS_fits_SLQ[i]).
    S_list_means : list/array -> S_mean_fit_both_NEW.
    S_list_std : list/array -> S_std_fit_both_NEW.
    masses_list : list/array (optional) -> masses_NEW.

    Outputs:
    --------
    if masses_list es None -> returns only the index
    if masses_list se incluye -> returns (index, closest mass).
    """
    # convert to array
    means = np.array(S_list_means)
    stds = np.array(S_list_std)

    # do not divide by 0
    stds = np.where(stds == 0, 1e-10, stds)

    # compute the distance to the means, weighted by the std
    z_scores = np.abs(S_pseudo - means) / stds

    # seach the closest index
    idx_min = np.argmin(z_scores)

    # if you also want the mass
    if masses_list is not None:
        best_mass = masses_list[idx_min]
        return idx_min, best_mass

    return idx_min

# %% [markdown]
# ### Super loop

# %%
Z_threshold = 1.96

n_pseudo = 1000

# benchmarks
classification_SLQ_BPOK = []
classification_VLQ_BPOK = []

# interpolate
classification_SLQ_inter = []
classification_VLQ_inter = []

# previously known PDFs
classification_SLQ_prev = []
classification_VLQ_prev = []


Z_SLQ_BPOK = []
Z_VLQ_BPOK = []

Z_SLQ_inter = []
Z_VLQ_inter = []

Z_SLQ_prev = []
Z_VLQ_prev = []


mu_TSLQ = []
std_TSLQ = []
mu_TVLQ = []
std_TVLQ = []



for ii_S, S_exp in enumerate(S_exp_SLQ):

    print("\n==========================")

    print("S_expected_SLQ =", S_exp_SLQ[ii_S])
    # print("S_expected_VLQ =", S_exp_VLQ[ii_S]) # same number of events


    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[ii_S]
    mass_VLQ = m_VLQ[ii_S]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    # compute the number of events
    muS_fits_SLQ = []
    muS_fits_VLQ = []


    for i in range(n_pseudo):

        N_B = np.random.poisson(B_expected)

        # indices of the events
        idx_B = np.random.choice(len(events_SM[:,0]), N_B)

        scoresA_B = events_SM[:,0][idx_B]
        scoresB_B = events_SM[:,1][idx_B]



        ###########
        # FOR SLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S])

        # indices of the events
        idx_S = np.random.choice(len(events_SLQ[mass_SLQ][:,0]), N_S)

        scoresA_S = events_SLQ[mass_SLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_SLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_S = df_SLQ_norm[mass_SLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_S = np.column_stack([X_pseudo_S, np.full(len(X_pseudo_S), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_S)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)




        ###########
        # FOR VLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S]) # same number of events

        # indices of the events
        idx_S = np.random.choice(len(events_VLQ[mass_VLQ][:,0]), N_S)

        scoresA_S = events_VLQ[mass_VLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_VLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_V = df_VLQ_norm[mass_VLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_V = np.column_stack([X_pseudo_V, np.full(len(X_pseudo_V), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_V)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

    # Compute the characteristics of the psedo-experiment T distributions
    mu_TSLQ.append( np.mean(T_SLQ) )
    mu_TVLQ.append( np.mean(T_VLQ) )

    std_TSLQ.append( np.std(T_SLQ) )
    std_TVLQ.append( np.std(T_VLQ) )




    # rango común para plotear
    xmin = min(np.min(T_SLQ), np.min(T_VLQ))
    xmax = max(np.max(T_SLQ), np.max(T_VLQ))
    x = np.linspace(xmin, xmax, 500)

    # gaussianas
    gauss_S = (1/(sigma_S[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_S[ii_S])**2 / (2*sigma_S[ii_S]**2))
    gauss_V = (1/(sigma_V[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_V[ii_S])**2 / (2*sigma_V[ii_S]**2))


    # plot gaussian PDFs + pseudo-experiments (of the same sector) distributions
    plt.figure(figsize=(6,5))

    plt.hist(T_SLQ, bins=20, density=True, color='red', alpha=0.6, label="SLQ pseudos")
    plt.hist(T_VLQ, bins=20, density=True, color='green', alpha=0.6, label="VLQ pseudos")

    # gaussianas
    plt.plot(x, gauss_S, color='darkred', linewidth=2, linestyle='--', label=f"Gaussian SLQ true\nμ={mu_S[ii_S]:.2f}, σ={sigma_S[ii_S]:.2f}")
    plt.plot(x, gauss_V, color='darkgreen', linewidth=2, linestyle='--', label=f"Gaussian VLQ true\nμ={mu_V[ii_S]:.2f}, σ={sigma_V[ii_S]:.2f}")

    plt.xlabel("Test statistic T")
    plt.ylabel("Probability density")
    plt.title(f"S_expected = {S_exp}")
    plt.legend()

    plt.show()


    plt.hist(muS_fits_SLQ, bins=10, histtype='step', linestyle='--', edgecolor='red', linewidth=2, density=True)
    plt.hist(muS_fits_SLQ, bins=10, color='red', alpha=0.6, density=True)
    plt.hist(muS_fits_VLQ, bins=10, histtype='step', linestyle=':', edgecolor='green', linewidth=2, density=True)
    plt.hist(muS_fits_VLQ, bins=10, color='green', alpha=0.6, density=True)
    plt.xlabel("S")
    plt.ylabel("Fraction (prediction)")
    plt.show()

    print('S mean SLQ: ', np.mean(muS_fits_SLQ))
    print('S std SLQ: ', np.std(muS_fits_SLQ))
    print('S mean VLQ: ', np.mean(muS_fits_VLQ))
    print('S std VLQ: ', np.std(muS_fits_VLQ))
    print('')


    # COMPARING WITH DISCRETE MASS EXAMPLES (following S)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_BPOK_step = []
    Z_VLQ_BPOK_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        index_pseudo = search_bench(muS_fits_SLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_SLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        index_pseudo = search_bench(muS_fits_VLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_VLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_BPOK.append(np.array(Z_SLQ_BPOK_step))
    Z_VLQ_BPOK.append(np.array(Z_VLQ_BPOK_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH DISCRETE MASS EXAMPLES (following S) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_BPOK.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_BPOK.append(pred_counts_VLQ)





    # COMPARING WITH CONTINUOUS MASSES (interpolation)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_inter_step = []
    Z_VLQ_inter_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_SLQ[i])) / f_sigma_S(muS_fits_SLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_SLQ[i])) / f_sigma_V(muS_fits_SLQ[i])

        Z_SLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_VLQ[i])) / f_sigma_S(muS_fits_VLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_VLQ[i])) / f_sigma_V(muS_fits_VLQ[i])

        Z_VLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_inter.append(np.array(Z_SLQ_inter_step))
    Z_VLQ_inter.append(np.array(Z_VLQ_inter_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH CONTINUOUS MASSES (interpolation) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_inter.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_inter.append(pred_counts_VLQ)





    # COMPARING WITH THE PREVIOUSLY KNOWN PDF

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_prev_step = []
    Z_VLQ_prev_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_SLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_VLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_prev.append(np.array(Z_SLQ_prev_step))
    Z_VLQ_prev.append(np.array(Z_VLQ_prev_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH THE PREVIOUSLY KNOWN PDF ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_prev.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_prev.append(pred_counts_VLQ)
# Out:
# ==========================
# S_expected_SLQ = 98
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
# S mean SLQ:  89.88982344620273
# S std SLQ:  16.564368227118763
# S mean VLQ:  97.8047720816896
# S std VLQ:  15.972800414987534
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.88
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.12
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.9
# 2 = both     : 0.0
# 3 = neither  : 0.1
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.887
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.113
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.942
# 2 = both     : 0.0
# 3 = neither  : 0.058
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.939
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.061
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.867
# 2 = both     : 0.0
# 3 = neither  : 0.133
#
# ==========================
# S_expected_SLQ = 55
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
# S mean SLQ:  54.04075430783943
# S std SLQ:  14.558279276361473
# S mean VLQ:  56.680526367017
# S std VLQ:  14.760579839683302
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.879
# 1 = VLQ only : 0.016
# 2 = both     : 0.032
# 3 = neither  : 0.073
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.022
# 1 = VLQ only : 0.853
# 2 = both     : 0.055
# 3 = neither  : 0.07
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.894
# 1 = VLQ only : 0.013
# 2 = both     : 0.031
# 3 = neither  : 0.062
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.018
# 1 = VLQ only : 0.881
# 2 = both     : 0.052
# 3 = neither  : 0.049
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.955
# 1 = VLQ only : 0.023
# 2 = both     : 0.0
# 3 = neither  : 0.022
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.035
# 1 = VLQ only : 0.89
# 2 = both     : 0.0
# 3 = neither  : 0.075
#
# ==========================
# S_expected_SLQ = 31
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
# S mean SLQ:  31.02060817315003
# S std SLQ:  12.794555284630345
# S mean VLQ:  31.693104862990502
# S std VLQ:  13.15394363768764
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.491
# 1 = VLQ only : 0.04
# 2 = both     : 0.442
# 3 = neither  : 0.027
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.029
# 1 = VLQ only : 0.548
# 2 = both     : 0.385
# 3 = neither  : 0.038
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.493
# 1 = VLQ only : 0.039
# 2 = both     : 0.44
# 3 = neither  : 0.028
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.022
# 1 = VLQ only : 0.565
# 2 = both     : 0.384
# 3 = neither  : 0.029
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.497
# 1 = VLQ only : 0.032
# 2 = both     : 0.452
# 3 = neither  : 0.019
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.024
# 1 = VLQ only : 0.552
# 2 = both     : 0.378
# 3 = neither  : 0.046
#
# ==========================
# S_expected_SLQ = 18
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
# S mean SLQ:  19.225881390687462
# S std SLQ:  12.148179667131489
# S mean VLQ:  19.452577156298393
# S std VLQ:  12.096898903059309
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.199
# 1 = VLQ only : 0.045
# 2 = both     : 0.723
# 3 = neither  : 0.033
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.028
# 1 = VLQ only : 0.261
# 2 = both     : 0.683
# 3 = neither  : 0.028
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.191
# 1 = VLQ only : 0.04
# 2 = both     : 0.73
# 3 = neither  : 0.039
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.023
# 1 = VLQ only : 0.256
# 2 = both     : 0.692
# 3 = neither  : 0.029
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.131
# 1 = VLQ only : 0.026
# 2 = both     : 0.813
# 3 = neither  : 0.03
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.028
# 1 = VLQ only : 0.191
# 2 = both     : 0.743
# 3 = neither  : 0.038
#
# ==========================
# S_expected_SLQ = 11
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
# S mean SLQ:  13.58141277135709
# S std SLQ:  11.091716466665014
# S mean VLQ:  13.425866236027195
# S std VLQ:  11.077352852840237
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.11
# 1 = VLQ only : 0.048
# 2 = both     : 0.815
# 3 = neither  : 0.027
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.038
# 1 = VLQ only : 0.123
# 2 = both     : 0.816
# 3 = neither  : 0.023
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.096
# 1 = VLQ only : 0.044
# 2 = both     : 0.825
# 3 = neither  : 0.035
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.033
# 1 = VLQ only : 0.117
# 2 = both     : 0.827
# 3 = neither  : 0.023
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.051
# 1 = VLQ only : 0.031
# 2 = both     : 0.887
# 3 = neither  : 0.031
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.012
# 1 = VLQ only : 0.081
# 2 = both     : 0.868
# 3 = neither  : 0.039
#
# ==========================
# S_expected_SLQ = 6
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
# S mean SLQ:  8.969787126553069
# S std SLQ:  9.660897088347664
# S mean VLQ:  8.862826192874627
# S std VLQ:  9.374543194469787
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.065
# 1 = VLQ only : 0.033
# 2 = both     : 0.882
# 3 = neither  : 0.02
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.04
# 1 = VLQ only : 0.062
# 2 = both     : 0.873
# 3 = neither  : 0.025
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.062
# 1 = VLQ only : 0.032
# 2 = both     : 0.881
# 3 = neither  : 0.025
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.037
# 1 = VLQ only : 0.058
# 2 = both     : 0.875
# 3 = neither  : 0.03
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.035
# 1 = VLQ only : 0.013
# 2 = both     : 0.922
# 3 = neither  : 0.03
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.02
# 1 = VLQ only : 0.026
# 2 = both     : 0.914
# 3 = neither  : 0.04
#
# ==========================
# S_expected_SLQ = 4
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
# S mean SLQ:  7.414192693978446
# S std SLQ:  8.452309786933704
# S mean VLQ:  7.256049982792949
# S std VLQ:  8.43615466729507
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.046
# 1 = VLQ only : 0.03
# 2 = both     : 0.894
# 3 = neither  : 0.03
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.031
# 1 = VLQ only : 0.048
# 2 = both     : 0.893
# 3 = neither  : 0.028
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.034
# 1 = VLQ only : 0.026
# 2 = both     : 0.904
# 3 = neither  : 0.036
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.019
# 1 = VLQ only : 0.035
# 2 = both     : 0.91
# 3 = neither  : 0.036
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.008
# 1 = VLQ only : 0.007
# 2 = both     : 0.943
# 3 = neither  : 0.042
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.003
# 1 = VLQ only : 0.015
# 2 = both     : 0.939
# 3 = neither  : 0.043
#
# ==========================
# S_expected_SLQ = 2
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# S mean SLQ:  6.213627102211801
# S std SLQ:  8.094942280370201
# S mean VLQ:  6.258579921866427
# S std VLQ:  8.101997070780182
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.042
# 1 = VLQ only : 0.028
# 2 = both     : 0.905
# 3 = neither  : 0.025
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.036
# 1 = VLQ only : 0.035
# 2 = both     : 0.902
# 3 = neither  : 0.027
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.028
# 1 = VLQ only : 0.021
# 2 = both     : 0.92
# 3 = neither  : 0.031
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.027
# 1 = VLQ only : 0.028
# 2 = both     : 0.914
# 3 = neither  : 0.031
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.003
# 1 = VLQ only : 0.005
# 2 = both     : 0.959
# 3 = neither  : 0.033
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.006
# 1 = VLQ only : 0.002
# 2 = both     : 0.956
# 3 = neither  : 0.036

# %%
def Z_processor(lista_Z, select):
    """computes the median and error (percentiles 16 y 84)
    select = 1 ---> SLQ (true) vs VLQ
    select = 0 ---> VLQ (true) vs SLQ
    """
    medians = []
    err_inf = []
    err_sup = []

    for z_matriz in lista_Z:
        z_valores = z_matriz[:, select]
        med = np.median(z_valores)
        p16 = np.percentile(z_valores, 16)
        p84 = np.percentile(z_valores, 84)

        medians.append(med)
        err_inf.append(med - p16)  # percentile
        err_sup.append(p84 - med)  # percentile

    return np.array(medians), [np.array(err_inf), np.array(err_sup)]

# Compute
z_BPOK_SLQ, err_BPOK_SLQ = Z_processor(Z_SLQ_BPOK, select=1)
z_BPOK_VLQ, err_BPOK_VLQ = Z_processor(Z_VLQ_BPOK, select=0)
z_inter_SLQ, err_inter_SLQ = Z_processor(Z_SLQ_inter, select=1)
z_inter_VLQ, err_inter_VLQ = Z_processor(Z_VLQ_inter, select=0)
z_prev_SLQ, err_prev_SLQ = Z_processor(Z_SLQ_prev, select=1)
z_prev_VLQ, err_prev_VLQ = Z_processor(Z_VLQ_prev, select=0)



# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(m_SLQ), z_BPOK_SLQ, err_BPOK_SLQ)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(m_VLQ), z_BPOK_VLQ, err_BPOK_VLQ)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(m_SLQ), z_inter_SLQ, err_inter_SLQ)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(m_VLQ), z_inter_VLQ, err_inter_VLQ)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(m_SLQ), z_prev_SLQ, err_prev_SLQ)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(m_VLQ), z_prev_VLQ, err_prev_VLQ)


# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')


# PLOT
plt.figure(figsize=(7, 6))

plt.errorbar(m_SLQ, z_BPOK_SLQ, yerr=err_BPOK_SLQ, color='red', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Benchmarks)')
plt.errorbar(m_VLQ, z_BPOK_VLQ, yerr=err_BPOK_VLQ, color='green', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Benchmarks)')
plt.errorbar(m_SLQ, z_inter_SLQ, yerr=err_inter_SLQ, color='darkred', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Interpolated)')
plt.errorbar(m_VLQ, z_inter_VLQ, yerr=err_inter_VLQ, color='darkgreen', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Interpolated)')
plt.errorbar(m_SLQ, z_prev_SLQ, yerr=err_prev_SLQ, color='pink', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Known PDF)')
plt.errorbar(m_VLQ, z_prev_VLQ, yerr=err_prev_VLQ, color='lime', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Known PDF)')

plt.axhline(y=5.0, color='blue', linestyle='-', linewidth=1.5, label='5σ')

# plt.ylim(0, 25)
plt.xlabel(r"$m_{LQ}$ [GeV]", fontsize=12)
plt.ylabel(r"$Z$", fontsize=12)
plt.grid(True)
plt.legend(fontsize=12, loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1242.042042042042 [GeV]      ( 1200.0 - 1286.886886886887 )
# VLQ mass:  1677.7777777777778 [GeV]      ( 1631.5315315315315 - 1733.8338338338338 )
#
# Interpolated
# SLQ mass:  1242.7427427427428 [GeV]      ( 1203.5035035035035 - 1287.5875875875877 )
# VLQ mass:  1679.179179179179 [GeV]      ( 1631.5315315315315 - 1733.8338338338338 )
#
# Known PDF
# SLQ mass:  1248.3483483483483 [GeV]      ( 1212.6126126126126 - 1286.886886886887 )
# VLQ mass:  1677.7777777777778 [GeV]      ( 1635.7357357357357 - 1725.4254254254254 )

# %%
class_SLQ_BPOK_array = np.array(classification_SLQ_BPOK) # Forma (N, 4)
class_VLQ_BPOK_array = np.array(classification_VLQ_BPOK) # Forma (N, 4)

class_SLQ_inter_array = np.array(classification_SLQ_inter) # Forma (N, 4)
class_VLQ_inter_array = np.array(classification_VLQ_inter) # Forma (N, 4)

class_SLQ_prev_array = np.array(classification_SLQ_prev) # Forma (N, 4)
class_VLQ_prev_array = np.array(classification_VLQ_prev) # Forma (N, 4)

# SAVE

file_path = mainfolder + 'saved-results/vs14TeV_err_beta0.txt'

# Combine all data into a single array
data_to_save = np.column_stack([
    S_expected_SLQ[2:],
    m_SLQ,
    m_VLQ,
    mu_S,
    sigma_S,
    mu_V,
    sigma_V,
    mu_TSLQ,
    std_TSLQ,
    mu_TVLQ,
    std_TVLQ,
    class_SLQ_BPOK_array,
    class_VLQ_BPOK_array,
    class_SLQ_inter_array,
    class_VLQ_inter_array,
    class_SLQ_prev_array,
    class_VLQ_prev_array,
    z_BPOK_SLQ,
    err_BPOK_SLQ[0],
    err_BPOK_SLQ[1],
    z_BPOK_VLQ,
    err_BPOK_VLQ[0],
    err_BPOK_VLQ[1],
    z_inter_SLQ,
    err_inter_SLQ[0],
    err_inter_SLQ[1],
    z_inter_VLQ,
    err_inter_VLQ[0],
    err_inter_VLQ[1],
    z_prev_SLQ,
    err_prev_SLQ[0],
    err_prev_SLQ[1],
    z_prev_VLQ,
    err_prev_VLQ[0],
    err_prev_VLQ[1],
])

# Save data to a text file
np.savetxt(file_path, data_to_save, fmt='%.6f',
           header='# S_expected mass_list_SLQ mass_list_SLQ mu_S sigma_S mu_V sigma_V mu_TSLQ std_TSLQ mu_TVLQ std_TVLQ classification_SLQ classification_VLQ',
           comments='')

print(f"Data saved to: {file_path}")
# Out:
# Data saved to: /content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/saved-results/vs14TeV_err_beta0.txt

# %%
# LOAD

file_path = mainfolder + 'saved-results/vs14TeV_err_beta0.txt'

loaded_data = np.loadtxt(file_path)

S_expected = loaded_data[:, 0]
mass_list_SLQ = loaded_data[:, 1]
mass_list_VLQ = loaded_data[:, 2]
mu_S = loaded_data[:, 3]
sigma_S = loaded_data[:, 4]
mu_V = loaded_data[:, 5]
sigma_V = loaded_data[:, 6]
mu_TSLQ = loaded_data[:, 7]
std_TSLQ = loaded_data[:, 8]
mu_TVLQ = loaded_data[:, 9]
std_TVLQ = loaded_data[:, 10]
classification_SLQ_BPOK = loaded_data[:, 11:15]
classification_VLQ_BPOK = loaded_data[:, 15:19]
classification_SLQ_inter = loaded_data[:, 19:23]
classification_VLQ_inter = loaded_data[:, 23:27]
classification_SLQ_prev = loaded_data[:, 27:31]
classification_VLQ_prev = loaded_data[:, 31:35]
z_BPOK_SLQ = loaded_data[:, 35]
err_BPOK_SLQ = np.concatenate([loaded_data[:, 36], loaded_data[:, 37]])
z_BPOK_VLQ = loaded_data[:, 38]
err_BPOK_VLQ = np.concatenate([loaded_data[:, 39], loaded_data[:, 40]])
z_inter_SLQ = loaded_data[:, 41]
err_inter_SLQ = np.concatenate([loaded_data[:, 42], loaded_data[:, 43]])
z_inter_VLQ = loaded_data[:, 44]
err_inter_VLQ = np.concatenate([loaded_data[:, 45], loaded_data[:, 46]])
z_prev_SLQ = loaded_data[:, 47]
err_prev_SLQ = np.concatenate([loaded_data[:, 48], loaded_data[:, 49]])
z_prev_VLQ = loaded_data[:, 50]
err_prev_VLQ = np.concatenate([loaded_data[:, 51], loaded_data[:, 52]])





n_pseudo_TRUE = 1000
threshold_A = 0.95

print('n_pseudo_TRUE: ', n_pseudo_TRUE)
print('threshold_A: ', threshold_A)
# Out:
# n_pseudo_TRUE:  1000
# threshold_A:  0.95

# %%
# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_BPOK_SLQ, err_BPOK_SLQ, z_target=5.0)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_BPOK_VLQ, err_BPOK_VLQ, z_target=5.0)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_inter_SLQ, err_inter_SLQ, z_target=5.0)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_inter_VLQ, err_inter_VLQ, z_target=5.0)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_prev_SLQ, err_prev_SLQ, z_target=5.0)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_prev_VLQ, err_prev_VLQ, z_target=5.0)

# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1242.042042042042 [GeV]      ( 1200.0 - 1290.3903903903904 )
# VLQ mass:  1677.7777777777778 [GeV]      ( 1630.8308308308308 - 1739.4394394394394 )
#
# Interpolated
# SLQ mass:  1242.7427427427428 [GeV]      ( 1203.5035035035035 - 1290.3903903903904 )
# VLQ mass:  1679.179179179179 [GeV]      ( 1629.4294294294293 - 1737.3373373373374 )
#
# Known PDF
# SLQ mass:  1248.3483483483483 [GeV]      ( 1213.3133133133133 - 1288.2882882882882 )
# VLQ mass:  1677.7777777777778 [GeV]      ( 1632.932932932933 - 1727.5275275275276 )

# %%
# LOAD

file_path = mainfolder + 'saved-results/Z13TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_13TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_13TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_13TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_13TeV = loaded_data[:, 4]
m_BL_exc_SLQ_13TeV = loaded_data[:, 5]
m_BL_dis_SLQ_13TeV = loaded_data[:, 6]
m_BL_exc_VLQ_13TeV = loaded_data[:, 7]
m_BL_dis_VLQ_13TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_13TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_13TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_13TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_13TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_13TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_13TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_13TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_13TeV = loaded_data[:, 16]


# LOAD

file_path = mainfolder + 'saved-results/Z136TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_136TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_136TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_136TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_136TeV = loaded_data[:, 4]
m_BL_exc_SLQ_136TeV = loaded_data[:, 5]
m_BL_dis_SLQ_136TeV = loaded_data[:, 6]
m_BL_exc_VLQ_136TeV = loaded_data[:, 7]
m_BL_dis_VLQ_136TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_136TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_136TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_136TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_136TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_136TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_136TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_136TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_136TeV = loaded_data[:, 16]




# LOAD

file_path = mainfolder + 'saved-results/Z14TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_14TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_14TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_14TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_14TeV = loaded_data[:, 4]
m_BL_exc_SLQ_14TeV = loaded_data[:, 5]
m_BL_dis_SLQ_14TeV = loaded_data[:, 6]
m_BL_exc_VLQ_14TeV = loaded_data[:, 7]
m_BL_dis_VLQ_14TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_14TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_14TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_14TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_14TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_14TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_14TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_14TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_14TeV = loaded_data[:, 16]

# %%
# plot BINNED LIKEHOOD

plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_SLQ_13TeV, betas, 'o:', c='red', label='13 TeV, 139 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_high_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_14TeV, betas, 'o-', c='red', label='14 TeV, 3000 fb-1 (Dis SLQ)')
plt.plot(m_BL_dis_SLQ_low_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_high_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_14TeV, betas, 'o--', c='red', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_14TeV, betas, '--', c='red', alpha=0.25)
plt.plot(m_BL_exc_SLQ_high_14TeV, betas, '--', c='red', alpha=0.25)


# benchmarks
m_SLQ_T_Z5 = [[m5_BPOK_SLQ - m5_BPOK_SLQ_inf], [m5_BPOK_SLQ_sup - m5_BPOK_SLQ]]
plt.errorbar(m5_BPOK_SLQ, 0.04, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (BP)')

# interpolated
m_SLQ_T_Z5 = [[m5_inter_SLQ - m5_inter_SLQ_inf], [m5_inter_SLQ_sup - m5_inter_SLQ]]
plt.errorbar(m5_inter_SLQ, 0.00, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (interpolated)')

# known pdf
m_SLQ_T_Z5 = [[m5_prev_SLQ - m5_prev_SLQ_inf], [m5_prev_SLQ_sup - m5_prev_SLQ]]
plt.errorbar(m5_prev_SLQ, -0.04, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()





plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_VLQ_13TeV, betas, 'o:', c='green', label='13 TeV, 139 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_high_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_14TeV, betas, 'o-', c='green', label='14 TeV, 3000 fb-1 (Dis VLQ)')
plt.plot(m_BL_dis_VLQ_low_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_high_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_14TeV, betas, 'o--', c='green', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_14TeV, betas, '-', c='green', alpha=0.25)
plt.plot(m_BL_exc_VLQ_high_14TeV, betas, '-', c='green', alpha=0.25)


# benchmarks
m_VLQ_T_Z5 = [[m5_BPOK_VLQ - m5_BPOK_VLQ_inf], [m5_BPOK_VLQ_sup - m5_BPOK_VLQ]]
plt.errorbar(m5_BPOK_VLQ, 0.04, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (BP)')

# interpolated
m_VLQ_T_Z5 = [[m5_inter_VLQ - m5_inter_VLQ_inf], [m5_inter_VLQ_sup - m5_inter_VLQ]]
plt.errorbar(m5_inter_VLQ, 0.00, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (interpolated)')

# knwon pdf
m_VLQ_T_Z5 = [[m5_prev_VLQ - m5_prev_VLQ_inf], [m5_prev_VLQ_sup - m5_prev_VLQ]]
plt.errorbar(m5_prev_VLQ, -0.04, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
