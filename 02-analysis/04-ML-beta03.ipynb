# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mainfolder = '/content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec

import os
import joblib  # to save the scaler

from numba import njit # for the LQ mass reconstruction

from scipy.optimize import fsolve, minimize
from scipy import stats
from scipy.stats import poisson
from scipy.stats import ks_2samp
from scipy.stats import anderson_ksamp
from scipy.stats import wasserstein_distance
from scipy.stats import chisquare
from scipy.interpolate import interp1d

import math
import random

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc, accuracy_score
from sklearn.metrics import mean_squared_error, r2_score

from xgboost import XGBRegressor, XGBClassifier
import xgboost as xgb

# %% [markdown]
# # LOAD DATA

# %% [markdown]
# ## Background

# %%
CHs_selected = ["tt", "singletP1", "singletP2", "Wbbjets", "ttW", "ttZ", "ttH"]


df_B_all = {}
X_B_all = {}


output_folder = mainfolder + "../DATA/backgrounds/data_df/"

for CH_sel in CHs_selected:
    # Read the file
    if CH_sel == 'singletP2':
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-singlet-comp/df_' + CH_sel + ".csv"
    else:
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-' + CH_sel + '/df_' + CH_sel + ".csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_B_all[CH_sel] = df_temp
    X_B_all[CH_sel] = df_temp[feats_label].values

    # Print
    print(f"X_{CH_sel}.shape: {X_B_all[CH_sel].shape}")
# Out:
# X_tt.shape: (826022, 53)
# X_singletP1.shape: (179677, 53)
# X_singletP2.shape: (94219, 53)
# X_Wbbjets.shape: (162448, 53)
# X_ttW.shape: (141919, 53)
# X_ttZ.shape: (16178, 53)
# X_ttH.shape: (12068, 53)

# %% [markdown]
# ## Signal SLQ

# %%
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2200]
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]


df_SLQ_all = {}
X_SLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_SLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-SLQ-' + str(mass_sel) + 'GeV/df_SLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_SLQ_all[mass_sel] = df_temp
    X_SLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_SLQ_{mass_sel}GeV.shape: {X_SLQ_all[mass_sel].shape}")
# Out:
# X_SLQ_1000GeV.shape: (267452, 53)
# X_SLQ_1100GeV.shape: (271062, 53)
# X_SLQ_1200GeV.shape: (534247, 53)
# X_SLQ_1300GeV.shape: (196510, 53)
# X_SLQ_1400GeV.shape: (506381, 53)
# X_SLQ_1500GeV.shape: (185940, 53)
# X_SLQ_1600GeV.shape: (481827, 53)
# X_SLQ_1700GeV.shape: (173573, 53)
# X_SLQ_1800GeV.shape: (301687, 53)
# X_SLQ_1900GeV.shape: (64690, 53)

# %% [markdown]
# ## Signal VLQ

# %%
masses_VLQ = [1200, 1500, 1400, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
masses_VLQ = [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]


df_VLQ_all = {}
X_VLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_VLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-VLQ-' + str(mass_sel) + 'GeV/df_VLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_VLQ_all[mass_sel] = df_temp
    X_VLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_VLQ_{mass_sel}GeV.shape: {X_VLQ_all[mass_sel].shape}")
# Out:
# X_VLQ_1400GeV.shape: (139696, 53)
# X_VLQ_1500GeV.shape: (293700, 53)
# X_VLQ_1600GeV.shape: (134774, 53)
# X_VLQ_1700GeV.shape: (192819, 53)
# X_VLQ_1800GeV.shape: (127670, 53)
# X_VLQ_1900GeV.shape: (75898, 53)
# X_VLQ_2000GeV.shape: (184097, 53)
# X_VLQ_2100GeV.shape: (72762, 53)
# X_VLQ_2200GeV.shape: (232166, 53)
# X_VLQ_2300GeV.shape: (64705, 53)

# %% [markdown]
# # Cross Section

# %%
Lum = 3000

# %%
# -------------------------
# cross sections
# -------------------------
k_LQ = 1.8877462860822058

xsec_file_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV.txt'

xsec_data_14TeV = np.loadtxt(xsec_file_14TeV, comments='#')

# columns: 0=mass, 1=SLQ, 2=VLQ
masses_14TeV = xsec_data_14TeV[:,0].astype(int)
fidxsec_SLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,1]*k_LQ))
fidxsec_VLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,2]*k_LQ))


masses_SLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]
masses_VLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]

fidxsec_SLQ_non0_14TeV = [fidxsec_SLQ_14TeV[ii] for ii in masses_SLQ_14TeV]
fidxsec_VLQ_non0_14TeV = [fidxsec_VLQ_14TeV[ii] for ii in masses_VLQ_14TeV]


#  interpolate
f_xsec_SLQ_log_14TeV = interp1d(masses_SLQ_14TeV, np.log10(fidxsec_SLQ_non0_14TeV), kind='linear', fill_value="extrapolate")
f_xsec_VLQ_log_14TeV = interp1d(masses_VLQ_14TeV, np.log10(fidxsec_VLQ_non0_14TeV), kind='linear', fill_value="extrapolate")



# -------------------------
# cross sections
# -------------------------
xsec_file_betas_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV-betas.txt'

xsec_data_betas_14TeV = np.loadtxt(xsec_file_betas_14TeV, comments='#')

# columns: 0=beta, 1,...=SLQ, -1=ratio=fid_xsec(beta)/fid_xsec(beta=0.5)
betas = xsec_data_betas_14TeV[:,0]
ratio_mean_14TeV = xsec_data_betas_14TeV[:,-1]

#  interpolate
f_ratio_SLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")
f_ratio_VLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")



# FINAL FUNCTIONS
def fid_xsec_SLQ_14TeV(mass, beta):
    return 10**f_xsec_SLQ_log_14TeV(mass) * f_ratio_SLQ_log_14TeV(beta)

def fid_xsec_VLQ_14TeV(mass, beta):
    return 10**f_xsec_VLQ_log_14TeV(mass) * f_ratio_VLQ_log_14TeV(beta)

# %%
masses = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

beta = 0.3

fidxsec_SLQ = dict(zip(masses, fid_xsec_SLQ_14TeV(masses, beta)))
fidxsec_VLQ = dict(zip(masses, fid_xsec_VLQ_14TeV(masses, beta)))


print('masses: ', masses)
print(fidxsec_SLQ[1200], '[fb]')
print(fidxsec_VLQ[1600], '[fb]')
# Out:
# masses:  [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# 0.22059829192114244 [fb]
# 0.23646500046296887 [fb]

# %%
# -----------------------------------
# LQs number and fid cross sections
# -----------------------------------


for m_it in masses_SLQ:
    print(f"# eventos SLQ {m_it} GeV:", len(X_SLQ_all[m_it]), "  fid_xsec = ", fidxsec_SLQ[m_it], "[fb]")

print(" ")
for m_it in masses_VLQ:
    print(f"# eventos VLQ {m_it} GeV:", len(X_VLQ_all[m_it]), "  fid_xsec = ", fidxsec_VLQ[m_it], "[fb]")
# Out:
# # eventos SLQ 1000 GeV: 267452   fid_xsec =  0.6908443389608215 [fb]
# # eventos SLQ 1100 GeV: 271062   fid_xsec =  0.3903832490747368 [fb]
# # eventos SLQ 1200 GeV: 534247   fid_xsec =  0.22059829192114244 [fb]
# # eventos SLQ 1300 GeV: 196510   fid_xsec =  0.12465597976825382 [fb]
# # eventos SLQ 1400 GeV: 506381   fid_xsec =  0.07044076885934407 [fb]
# # eventos SLQ 1500 GeV: 185940   fid_xsec =  0.040847859108013855 [fb]
# # eventos SLQ 1600 GeV: 481827   fid_xsec =  0.023687242781803 [fb]
# # eventos SLQ 1700 GeV: 173573   fid_xsec =  0.013719861727992359 [fb]
# # eventos SLQ 1800 GeV: 301687   fid_xsec =  0.007946665957248298 [fb]
# # eventos SLQ 1900 GeV: 64690   fid_xsec =  0.004690117664304568 [fb]
#
# # eventos VLQ 1400 GeV: 139696   fid_xsec =  0.7115030328088947 [fb]
# # eventos VLQ 1500 GeV: 293700   fid_xsec =  0.41017747985787695 [fb]
# # eventos VLQ 1600 GeV: 134774   fid_xsec =  0.23646500046296887 [fb]
# # eventos VLQ 1700 GeV: 192819   fid_xsec =  0.13853208379439635 [fb]
# # eventos VLQ 1800 GeV: 127670   fid_xsec =  0.08115847251324217 [fb]
# # eventos VLQ 1900 GeV: 75898   fid_xsec =  0.04850850050377812 [fb]
# # eventos VLQ 2000 GeV: 184097   fid_xsec =  0.028993579453347927 [fb]
# # eventos VLQ 2100 GeV: 72762   fid_xsec =  0.017661759621171596 [fb]
# # eventos VLQ 2200 GeV: 232166   fid_xsec =  0.010758856229461775 [fb]
# # eventos VLQ 2300 GeV: 64705   fid_xsec =  0.006553876275581988 [fb]

# %%
# FOR 14 TeV

k_fakett = 1.1053030485310749
crossfid_fakett = 0.244
k_tt = 1.2593273872014419
crossfid_tt = (7.74198*k_tt) + (crossfid_fakett * k_fakett)


fidxsec_SM = {'tt': crossfid_tt,
              'singletP1': 0.632632 * 3.440676833094312,
              'singletP2': 0.3182704 * 3.440676833094312,
              'Wbbjets': 1.6542420183645095 * 0.9781509289273502,
              'ttW': 0.03683196 * 3.056401327463198,
              'ttZ': 0.0715444 * 3.056401327463198,
              'ttH': 0.03630132 * 2.2127445612386474
              }

for ch_it in fidxsec_SM:
    print(f"# eventos {ch_it}:", len(X_B_all[ch_it]), "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]")
# Out:
# # eventos tt: 826022   fid_xsec =  10.019381389007401 [fb]
# # eventos singletP1: 179677   fid_xsec =  2.1766822662741205 [fb]
# # eventos singletP2: 94219   fid_xsec =  1.09506559193966 [fb]
# # eventos Wbbjets: 162448   fid_xsec =  1.6180983669338997 [fb]
# # eventos ttW: 141919   fid_xsec =  0.1125732514370714 [fb]
# # eventos ttZ: 16178   fid_xsec =  0.218668399132558 [fb]
# # eventos ttH: 12068   fid_xsec =  0.08032554839578374 [fb]

# %%
# MAX SM dataset
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])


weigth_gen_SM = {}

for ch_it in fidxsec_SM:

    print(f"fraction of {ch_it}:", fidxsec_SM[ch_it] / totalcrossSM )

    weigth_gen_SM[ch_it] = len(X_B_all[ch_it]) / (fidxsec_SM[ch_it] / totalcrossSM)

print('\nchannel limiting the SM background: ', min(weigth_gen_SM, key=weigth_gen_SM.get) , '\n')


max_evs_SM = {}

for ch_it in fidxsec_SM:
    max_evs_SM[ch_it] = round( min(weigth_gen_SM.values()) * (fidxsec_SM[ch_it] / totalcrossSM) )
    print(f"# eventos {ch_it} (max):", max_evs_SM[ch_it])

max_SM_dataset = sum(max_evs_SM.values())
print('\nmax SM dataset length: ', max_SM_dataset )
# Out:
# fraction of tt: 0.6539726894865112
# fraction of singletP1: 0.14207371698562551
# fraction of singletP2: 0.07147576906400852
# fraction of Wbbjets: 0.10561451848099845
# fraction of ttW: 0.0073477422555561795
# fraction of ttZ: 0.014272653723245071
# fraction of ttH: 0.005242910004055022
#
# channel limiting the SM background:  ttZ
#
# # eventos tt (max): 741276
# # eventos singletP1 (max): 161040
# # eventos singletP2 (max): 81018
# # eventos Wbbjets (max): 119714
# # eventos ttW (max): 8329
# # eventos ttZ (max): 16178
# # eventos ttH (max): 5943
#
# max SM dataset length:  1133498

# %% [markdown]
# ## Number of events to get a balanced dataset

# %%
# -------------------------
# Step 1: minimim number of events in LQs (selected mass)
# -------------------------

num_data_SLQ = [len(X_SLQ_all[m_it]) for m_it in masses_SLQ]

num_data_VLQ = [len(X_VLQ_all[m_it]) for m_it in masses_VLQ]


max_SM_dataset = min(1000000, max_SM_dataset)

num_data_NP = min(int(max_SM_dataset / (len(masses_SLQ) + len(masses_VLQ))) , min(num_data_SLQ + num_data_VLQ) )

print('SIGNAL: # events per-class chosen =', num_data_NP)



# -------------------------
# Step 2: background total fid_xsec
# -------------------------
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])



# -------------------------
# Step 3: number of events per chanel, proportional to xsec
# -------------------------
num_data_SM_dict = {}
for ch_it in fidxsec_SM:
    if ch_it == 'tt':
        # set at the end to have exactly the same # events (otherwise can be a difference of 1 due to rounding)
        continue
    fraction = fidxsec_SM[ch_it]/totalcrossSM
    num_data_SM_dict[ch_it] = round(num_data_NP * fraction * (len(masses_SLQ) + len(masses_VLQ)) )

# Set tt such that the total matches num_data_NP
num_data_SM_dict['tt'] = num_data_NP * (len(masses_SLQ) + len(masses_VLQ)) - sum([v for k,v in num_data_SM_dict.items() if k != 'tt'])




print('\nBACKGROUND events chosen (weighted by xsec):')
for ch_it in fidxsec_SM:
    print(f'# {ch_it}: {num_data_SM_dict[ch_it]}')
print('# total B events chosen: ', sum(num_data_SM_dict.values()))
# Out:
# SIGNAL: # events per-class chosen = 50000
#
# BACKGROUND events chosen (weighted by xsec):
# # tt: 653971
# # singletP1: 142074
# # singletP2: 71476
# # Wbbjets: 105615
# # ttW: 7348
# # ttZ: 14273
# # ttH: 5243
# # total B events chosen:  1000000

# %%
# keep just the events needed

for m_it in masses_SLQ:
    X_SLQ_all[m_it] = X_SLQ_all[m_it][:num_data_NP]
    df_SLQ_all[m_it] = df_SLQ_all[m_it][:num_data_NP]

print(" ")
for m_it in masses_VLQ:
    X_VLQ_all[m_it] = X_VLQ_all[m_it][:num_data_NP]
    df_VLQ_all[m_it] = df_VLQ_all[m_it][:num_data_NP]

print("")
for ch_it in fidxsec_SM:
    X_B_all[ch_it] = X_B_all[ch_it][:num_data_SM_dict[ch_it]]
    df_B_all[ch_it] = df_B_all[ch_it][:num_data_SM_dict[ch_it]]

# %%
B_expected = round(Lum * totalcrossSM)    # luminosity * cross * aceptance
print('B_expected: ', B_expected)

for ch_it in fidxsec_SM:
    print(f" channel {ch_it}:", "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]", " B_exp_ch: ", round(Lum * fidxsec_SM[ch_it]) )



S_expected_SLQ = []

for m_it in masses_SLQ:
    S_expected_SLQ.append( round(Lum * fidxsec_SLQ[m_it]) )

print('\nmasses:           ', masses_SLQ)
print('S_expected (SLQ): ', S_expected_SLQ)    # luminosity * cross * aceptance



S_expected_VLQ = []

for m_it in masses_VLQ:
    S_expected_VLQ.append( round(Lum * fidxsec_VLQ[m_it]) )

print('\nmasses:           ', masses_VLQ)
print('S_expected (VLQ): ', S_expected_VLQ)    # luminosity * cross * aceptance
# Out:
# B_expected:  45962
#  channel tt:   fid_xsec =  10.019381389007401 [fb]  B_exp_ch:  30058
#  channel singletP1:   fid_xsec =  2.1766822662741205 [fb]  B_exp_ch:  6530
#  channel singletP2:   fid_xsec =  1.09506559193966 [fb]  B_exp_ch:  3285
#  channel Wbbjets:   fid_xsec =  1.6180983669338997 [fb]  B_exp_ch:  4854
#  channel ttW:   fid_xsec =  0.1125732514370714 [fb]  B_exp_ch:  338
#  channel ttZ:   fid_xsec =  0.218668399132558 [fb]  B_exp_ch:  656
#  channel ttH:   fid_xsec =  0.08032554839578374 [fb]  B_exp_ch:  241
#
# masses:            [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_expected (SLQ):  [2073, 1171, 662, 374, 211, 123, 71, 41, 24, 14]
#
# masses:            [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_expected (VLQ):  [2135, 1231, 709, 416, 243, 146, 87, 53, 32, 20]

# %%
plt.plot(masses_SLQ, S_expected_SLQ, color='red', label='SLQ')
plt.plot(masses_VLQ, S_expected_VLQ, color='green', label='VLQ')
# plt.yscale('log')
plt.xlabel("$m_{LQ}$ [GeV]", fontsize=16)
plt.ylabel("S expected", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # 1. DATA FORMAT for CLASSIFIERS

# %%
# to save memory
del X_SLQ_all
del X_VLQ_all
del X_B_all

# %%
# ---------------------------
# Concatenate all for normalization
# ---------------------------
df_SM = pd.concat(df_B_all.values(), ignore_index=True)
del df_B_all

df_all = pd.concat([df_SM] + list(df_SLQ_all.values()) + list(df_VLQ_all.values()), ignore_index=True)

# ---------------------------
# Normalization
# ---------------------------
scaler = MinMaxScaler()
scaler.fit(df_all)

# Save the scaler
# joblib.dump(scaler, mainfolder + 'saved-models/scaler_features.pkl')

# Apply normalization
df_SM_norm = pd.DataFrame(scaler.transform(df_SM), columns=df_SM.columns)
df_SLQ_norm = {mass: pd.DataFrame(scaler.transform(df_SLQ_all[mass]), columns=df_SLQ_all[mass].columns) for mass in df_SLQ_all}
df_VLQ_norm = {mass: pd.DataFrame(scaler.transform(df_VLQ_all[mass]), columns=df_VLQ_all[mass].columns) for mass in df_VLQ_all}






# ---------------------------
# Divide datasets into train/val/test/pseudo
# ---------------------------
def split_class(df, test_ratio=0.25, val_ratio=0.10, pseudo_ratio=0.25):
    X = df.values
    aux_val_ratio = val_ratio / (1 - test_ratio)
    aux_pseudo_ratio = pseudo_ratio / (1 - test_ratio - val_ratio)

    X_aux, X_test = train_test_split(X, test_size=test_ratio, random_state=42, shuffle=True)
    X_aux2, X_val = train_test_split(X_aux, test_size=aux_val_ratio, random_state=42, shuffle=True)
    X_train, X_pseudo = train_test_split(X_aux2, test_size=aux_pseudo_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, X_pseudo



# ---------------------------
# Divide the datasets
# ---------------------------
split_SM = split_class(df_SM_norm)
split_SLQ = {mass: split_class(df_SLQ_norm[mass]) for mass in df_SLQ_norm}
split_VLQ = {mass: split_class(df_VLQ_norm[mass]) for mass in df_VLQ_norm}



# Example of how to use them
X_train_SM, X_val_SM, X_test_SM, X_pseudo_SM = split_SM
X_train_SLQ1200, X_val_SLQ1200, X_test_SLQ1200, X_pseudo_SLQ1200 = split_SLQ[1200]
X_train_VLQ1600, X_val_VLQ1600, X_test_VLQ1600, X_pseudo_VLQ1600 = split_VLQ[1600]

print('')
print('X_train_SM : ', X_train_SM.shape)
print('X_val_SM : ', X_val_SM.shape)
print('X_test_SM : ', X_test_SM.shape)
print('X_pseudo_SM : ', X_pseudo_SM.shape)

print('')
print('X_train_SLQ1200 : ', X_train_SLQ1200.shape)
print('X_val_SLQ1200 : ', X_val_SLQ1200.shape)
print('X_test_SLQ1200 : ', X_test_SLQ1200.shape)
print('X_pseudo_SLQ1200 : ', X_pseudo_SLQ1200.shape)

print('')
print('X_train_VLQ1600 : ', X_train_VLQ1600.shape)
print('X_val_VLQ1600 : ', X_val_VLQ1600.shape)
print('X_test_VLQ1600 : ', X_test_VLQ1600.shape)
print('X_pseudo_VLQ1600 : ', X_pseudo_VLQ1600.shape)
# Out:
# X_train_SM :  (400000, 53)
# X_val_SM :  (100000, 53)
# X_test_SM :  (250000, 53)
# X_pseudo_SM :  (250000, 53)
#
# X_train_SLQ1200 :  (20000, 53)
# X_val_SLQ1200 :  (5000, 53)
# X_test_SLQ1200 :  (12500, 53)
# X_pseudo_SLQ1200 :  (12500, 53)
#
# X_train_VLQ1600 :  (20000, 53)
# X_val_VLQ1600 :  (5000, 53)
# X_test_VLQ1600 :  (12500, 53)
# X_pseudo_VLQ1600 :  (12500, 53)

# %%
# to save memory
del df_SM
del df_SLQ_all
del df_VLQ_all

# %% [markdown]
# ## SM vs LQ

# %%
# --- 1. Combinar todos los LQ en un solo DataFrame ---
df_LQ_list = list(df_SLQ_norm.values()) + list(df_VLQ_norm.values())
df_LQ_norm = pd.concat(df_LQ_list, ignore_index=True)


# --- 2. Igualar número de eventos con SM ---
n_SM = len(df_SM_norm)
n_LQ = len(df_LQ_norm)
n_events = min(n_SM, n_LQ)

print(n_SM, n_LQ, n_events)

df_SM_sample = df_SM_norm.sample(n=n_events, random_state=42)
df_LQ_sample = df_LQ_norm.sample(n=n_events, random_state=42)


# --- 3. Crear X, y ---
X = pd.concat([df_SM_sample, df_LQ_sample], ignore_index=True)
y = np.hstack([np.zeros(n_events), np.ones(n_events)])  # 0=SM, 1=LQ


def split_class(X, Y, test_ratio=0.25, val_ratio=0.25):

    aux_val_ratio = val_ratio / (1 - test_ratio)

    X_aux, X_test, Y_aux, Y_test = train_test_split(X, Y, test_size=test_ratio, random_state=42, shuffle=True)
    X_train, X_val, Y_train, Y_val = train_test_split(X_aux, Y_aux, test_size=val_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, Y_train, Y_val, Y_test


# Divide into train, validation and test
X_train, X_val, X_test, y_train, y_val, y_test = split_class(X, y)


print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# 1000000 1000000 1000000
# (1125000, 53)
# (375000, 53)
# (500000, 53)

# %%
# LOAD
xgb_clf = XGBClassifier()
xgb_clf.load_model(mainfolder + "saved-models/modelA_SMLQ_14TeV_full.json")


# Evaluate
y_pred = xgb_clf.predict(X_test)
y_pred_proba = xgb_clf.predict_proba(X_test)[:,1]

acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)
print(f"Accuracy: {acc:.3f}, ROC-AUC: {auc:.5f}")

# ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC={auc:.3f}')
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SM vs LQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + "saved-results/ROC_classA.pdf", bbox_inches='tight')
plt.show()


# Feature importance
keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$'])

feature_important = xgb_clf.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=14).remove()
plt.title(r'SM vs LQ', fontsize=14)
# plt.savefig(mainfolder + "saved-results/XG_feature_importance_classA.pdf", bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Accuracy: 0.973, ROC-AUC: 0.99660
# [52, 47, 35, 17, 15, 36, 50, 46, 32, 45, 6, 37, 51, 38, 12]

# %% [markdown]
# ## Compute S_pred for pseudo-experiments

# %%
# output of all the background events
scores_B = xgb_clf.predict_proba( df_SM_norm )[:, 1]

# output of all the signal events (for the pdf of the general LQ case)
scores_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]

# %%
# output of all the signal events per class (to build the pseudo-experiments)
scores_S_SLQ = {mass: xgb_clf.predict_proba(df_SLQ_norm[mass])[:, 1] for mass in df_SLQ_norm}
scores_S_VLQ = {mass: xgb_clf.predict_proba(df_VLQ_norm[mass])[:, 1] for mass in df_VLQ_norm}

# %%
def Z_asimov(S, B):
    if S <= 0 or B <= 0:
        return 0
    return np.sqrt(2 * ((S+B) * np.log(1 + S/B) - S))

# %% [markdown]
# ###### binned likelihood fit

# %%
bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scores_B, bins=bins, density=True)
hist_S, _ = np.histogram(scores_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %%
# FOR SLQ #

S_expected = S_expected_SLQ


n_pseudo = 1000


# to save
S_mean_fit_N = {}
S_std_fit_N  = {}
Z_fit_N = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_N[S_it] = []
    S_std_fit_N[S_it]  = []
    Z_fit_N[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_SLQ[masses_SLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_N[S_it].append(mean_muS)
    S_std_fit_N[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_N[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  2073
# S = 1650.9239180135737 +- 49.31935544115925
# Z = 73.82611813891904
#
#
# ----------------
# S_expected =  1171
# S = 1016.2772587797158 +- 37.720893811487095
# Z = 54.490794465486125
#
#
# ----------------
# S_expected =  662
# S = 614.6091713335024 +- 31.151604763794296
# Z = 36.692099189401695
#
#
# ----------------
# S_expected =  374
# S = 363.0672502065131 +- 22.31041808830771
# Z = 23.90841523150416
#
#
# ----------------
# S_expected =  211
# S = 211.0542606966279 +- 19.23862291051092
# Z = 14.741991237457889
#
#
# ----------------
# S_expected =  123
# S = 127.56580890215855 +- 16.45582202659511
# Z = 8.215333376483326
#
#
# ----------------
# S_expected =  71
# S = 75.32950511464814 +- 15.01248281934835
# Z = 5.570604439703502
#
#
# ----------------
# S_expected =  41
# S = 44.323329672022574 +- 13.351077561425098
# Z = 3.1622041899524986
#
#
# ----------------
# S_expected =  24
# S = 26.10933590257005 +- 12.443006294681886
# Z = 1.168346870346917
#
#
# ----------------
# S_expected =  14
# S = 16.506507375636364 +- 11.175693952587121
# Z = 1.275601951825029

# %%
# FOR VLQ #

S_expected = S_expected_SLQ # same number of events


n_pseudo = 1000


# to save
S_mean_fit_V = {}
S_std_fit_V  = {}
Z_fit_V = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_V[S_it] = []
    S_std_fit_V[S_it]  = []
    Z_fit_V[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_VLQ[masses_VLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_V[S_it].append(mean_muS)
    S_std_fit_V[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_V[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  2073
# S = 2012.4779715810423 +- 59.40196070885517
# Z = 83.39630281302328
#
#
# ----------------
# S_expected =  1171
# S = 1154.376832339125 +- 37.44454778585202
# Z = 56.817118228929075
#
#
# ----------------
# S_expected =  662
# S = 660.5812129802595 +- 26.984908798043712
# Z = 37.35759428618833
#
#
# ----------------
# S_expected =  374
# S = 380.4039773007694 +- 23.743363075495285
# Z = 25.314111672113608
#
#
# ----------------
# S_expected =  211
# S = 216.18881509285953 +- 19.411277650537627
# Z = 15.560357672625859
#
#
# ----------------
# S_expected =  123
# S = 126.77103789647744 +- 15.638368060708562
# Z = 8.968988102740758
#
#
# ----------------
# S_expected =  71
# S = 73.35585222182652 +- 14.66337905280633
# Z = 7.629272354986402
#
#
# ----------------
# S_expected =  41
# S = 42.80808436358324 +- 13.503603439939335
# Z = 3.328931963994904
#
#
# ----------------
# S_expected =  24
# S = 25.030091302997274 +- 12.328280177672527
# Z = 2.699446717421942
#
#
# ----------------
# S_expected =  14
# S = 16.330489308466543 +- 11.627701818798258
# Z = 1.4960254226082903

# %%
# mean between scalar and vector
S_mean_fit_both = []
S_std_fit_both = []

for i in S_mean_fit_N:

    S_mean_fit_both.append( np.mean([S_mean_fit_N[i][0], S_mean_fit_V[i][0]]) )
    S_std_fit_both.append( np.mean([S_std_fit_N[i][0], S_std_fit_V[i][0]]) )

# %% [markdown]
# # SLQ vs VLQ (include Poisson S_expected)

# %%
X_train_list, y_train_list, S_poiss_train_list = [], [], []
X_val_list,   y_val_list,   S_poiss_val_list   = [], [], []
X_test_list,  y_test_list,  S_poiss_test_list  = [], [], []

for iit, m_s in enumerate(masses_SLQ):

        # -------- SLQ --------
        X_train_s, X_val_s, X_test_s, _ = split_SLQ[masses_SLQ[iit]]

        X_train_list.append(X_train_s)
        y_train_list.append(np.zeros(len(X_train_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_s))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_s)
        y_val_list.append(np.zeros(len(X_val_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_s))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_s)
        y_test_list.append(np.zeros(len(X_test_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_s))
        S_poiss_test_list.append(poisson_samples)


# for iit, m_v in enumerate(masses_VLQ):

        # -------- VLQ --------
        X_train_v, X_val_v, X_test_v, _ = split_VLQ[masses_VLQ[iit]]

        X_train_list.append(X_train_v)
        y_train_list.append(np.ones(len(X_train_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_v))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_v)
        y_val_list.append(np.ones(len(X_val_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_v))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_v)
        y_test_list.append(np.ones(len(X_test_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_v))
        S_poiss_test_list.append(poisson_samples)


# Concatenate
# TRAIN
X_train_spin = np.vstack(X_train_list)
y_train_spin = np.concatenate(y_train_list)
S_poiss_train = np.concatenate(S_poiss_train_list)

# add S_poiss as extra feature
X_train_spin = np.column_stack([X_train_spin, S_poiss_train])


# VAL
X_val_spin = np.vstack(X_val_list)
y_val_spin = np.concatenate(y_val_list)
S_poiss_val = np.concatenate(S_poiss_val_list)

X_val_spin = np.column_stack([X_val_spin, S_poiss_val])


# TEST
X_test_spin = np.vstack(X_test_list)
y_test_spin = np.concatenate(y_test_list)
S_poiss_test = np.concatenate(S_poiss_test_list)

X_test_spin = np.column_stack([X_test_spin, S_poiss_test])


print(X_train_spin.shape)
print(X_val_spin.shape)
print(X_test_spin.shape)
# Out:
# (400000, 54)
# (100000, 54)
# (250000, 54)

# %%
classifier_spin = XGBClassifier(
    n_estimators=1500,
    learning_rate=0.1,
    max_depth=5,
    reg_lambda=1.0,
    reg_alpha=0.0,
    gamma=0.0,
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    random_state=42,
    early_stopping_rounds=50
)

classifier_spin.fit(
    X_train_spin, y_train_spin,
    eval_set=[(X_train_spin, y_train_spin),
              (X_val_spin, y_val_spin)],
    verbose=True
)

classifier_spin.save_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta03.json")
# Out:
# [0]	validation_0-logloss:0.68605	validation_1-logloss:0.68614
# [1]	validation_0-logloss:0.67995	validation_1-logloss:0.68016
# [2]	validation_0-logloss:0.67458	validation_1-logloss:0.67481
# [3]	validation_0-logloss:0.67002	validation_1-logloss:0.67035
# [4]	validation_0-logloss:0.66579	validation_1-logloss:0.66616
# [5]	validation_0-logloss:0.66221	validation_1-logloss:0.66262
# [6]	validation_0-logloss:0.65904	validation_1-logloss:0.65956
# [7]	validation_0-logloss:0.65624	validation_1-logloss:0.65685
# [8]	validation_0-logloss:0.65381	validation_1-logloss:0.65447
# [9]	validation_0-logloss:0.65144	validation_1-logloss:0.65218
# [10]	validation_0-logloss:0.64925	validation_1-logloss:0.64999
# [11]	validation_0-logloss:0.64724	validation_1-logloss:0.64810
# [12]	validation_0-logloss:0.64535	validation_1-logloss:0.64629
# [13]	validation_0-logloss:0.64380	validation_1-logloss:0.64481
# [14]	validation_0-logloss:0.64219	validation_1-logloss:0.64322
# [15]	validation_0-logloss:0.64085	validation_1-logloss:0.64194
# [16]	validation_0-logloss:0.63940	validation_1-logloss:0.64052
# [17]	validation_0-logloss:0.63836	validation_1-logloss:0.63953
# [18]	validation_0-logloss:0.63698	validation_1-logloss:0.63821
# [19]	validation_0-logloss:0.63595	validation_1-logloss:0.63720
# [20]	validation_0-logloss:0.63502	validation_1-logloss:0.63632
# [21]	validation_0-logloss:0.63399	validation_1-logloss:0.63527
# [22]	validation_0-logloss:0.63287	validation_1-logloss:0.63420
# [23]	validation_0-logloss:0.63203	validation_1-logloss:0.63344
# [24]	validation_0-logloss:0.63089	validation_1-logloss:0.63236
# [25]	validation_0-logloss:0.62937	validation_1-logloss:0.63089
# [26]	validation_0-logloss:0.62862	validation_1-logloss:0.63019
# [27]	validation_0-logloss:0.62699	validation_1-logloss:0.62859
# [28]	validation_0-logloss:0.62639	validation_1-logloss:0.62805
# [29]	validation_0-logloss:0.62591	validation_1-logloss:0.62761
# [30]	validation_0-logloss:0.62531	validation_1-logloss:0.62706
# [31]	validation_0-logloss:0.62467	validation_1-logloss:0.62644
# [32]	validation_0-logloss:0.62369	validation_1-logloss:0.62554
# [33]	validation_0-logloss:0.62303	validation_1-logloss:0.62491
# [34]	validation_0-logloss:0.62222	validation_1-logloss:0.62412
# [35]	validation_0-logloss:0.62166	validation_1-logloss:0.62361
# [36]	validation_0-logloss:0.62097	validation_1-logloss:0.62296
# [37]	validation_0-logloss:0.62030	validation_1-logloss:0.62235
# [38]	validation_0-logloss:0.61960	validation_1-logloss:0.62171
# [39]	validation_0-logloss:0.61912	validation_1-logloss:0.62127
# [40]	validation_0-logloss:0.61839	validation_1-logloss:0.62061
# [41]	validation_0-logloss:0.61773	validation_1-logloss:0.61996
# [42]	validation_0-logloss:0.61716	validation_1-logloss:0.61947
# [43]	validation_0-logloss:0.61679	validation_1-logloss:0.61912
# [44]	validation_0-logloss:0.61639	validation_1-logloss:0.61877
# [45]	validation_0-logloss:0.61605	validation_1-logloss:0.61849
# [46]	validation_0-logloss:0.61544	validation_1-logloss:0.61790
# [47]	validation_0-logloss:0.61507	validation_1-logloss:0.61757
# [48]	validation_0-logloss:0.61398	validation_1-logloss:0.61654
# [49]	validation_0-logloss:0.61356	validation_1-logloss:0.61619
# [50]	validation_0-logloss:0.61329	validation_1-logloss:0.61595
# [51]	validation_0-logloss:0.61297	validation_1-logloss:0.61566
# [52]	validation_0-logloss:0.61263	validation_1-logloss:0.61537
# [53]	validation_0-logloss:0.61190	validation_1-logloss:0.61470
# [54]	validation_0-logloss:0.61168	validation_1-logloss:0.61451
# [55]	validation_0-logloss:0.61146	validation_1-logloss:0.61435
# [56]	validation_0-logloss:0.61110	validation_1-logloss:0.61408
# [57]	validation_0-logloss:0.61048	validation_1-logloss:0.61353
# [58]	validation_0-logloss:0.61021	validation_1-logloss:0.61328
# [59]	validation_0-logloss:0.60999	validation_1-logloss:0.61309
# [60]	validation_0-logloss:0.60968	validation_1-logloss:0.61288
# [61]	validation_0-logloss:0.60947	validation_1-logloss:0.61270
# [62]	validation_0-logloss:0.60928	validation_1-logloss:0.61257
# [63]	validation_0-logloss:0.60905	validation_1-logloss:0.61241
# [64]	validation_0-logloss:0.60860	validation_1-logloss:0.61203
# [65]	validation_0-logloss:0.60832	validation_1-logloss:0.61177
# [66]	validation_0-logloss:0.60818	validation_1-logloss:0.61167
# [67]	validation_0-logloss:0.60797	validation_1-logloss:0.61150
# [68]	validation_0-logloss:0.60768	validation_1-logloss:0.61128
# [69]	validation_0-logloss:0.60747	validation_1-logloss:0.61111
# [70]	validation_0-logloss:0.60725	validation_1-logloss:0.61092
# [71]	validation_0-logloss:0.60710	validation_1-logloss:0.61084
# [72]	validation_0-logloss:0.60684	validation_1-logloss:0.61063
# [73]	validation_0-logloss:0.60664	validation_1-logloss:0.61049
# [74]	validation_0-logloss:0.60644	validation_1-logloss:0.61037
# [75]	validation_0-logloss:0.60614	validation_1-logloss:0.61006
# [76]	validation_0-logloss:0.60563	validation_1-logloss:0.60958
# [77]	validation_0-logloss:0.60526	validation_1-logloss:0.60925
# [78]	validation_0-logloss:0.60502	validation_1-logloss:0.60907
# [79]	validation_0-logloss:0.60469	validation_1-logloss:0.60881
# [80]	validation_0-logloss:0.60458	validation_1-logloss:0.60876
# [81]	validation_0-logloss:0.60444	validation_1-logloss:0.60867
# [82]	validation_0-logloss:0.60429	validation_1-logloss:0.60856
# [83]	validation_0-logloss:0.60416	validation_1-logloss:0.60846
# [84]	validation_0-logloss:0.60380	validation_1-logloss:0.60815
# [85]	validation_0-logloss:0.60365	validation_1-logloss:0.60809
# [86]	validation_0-logloss:0.60355	validation_1-logloss:0.60803
# [87]	validation_0-logloss:0.60340	validation_1-logloss:0.60794
# [88]	validation_0-logloss:0.60312	validation_1-logloss:0.60775
# [89]	validation_0-logloss:0.60286	validation_1-logloss:0.60753
# [90]	validation_0-logloss:0.60259	validation_1-logloss:0.60731
# [91]	validation_0-logloss:0.60243	validation_1-logloss:0.60718
# [92]	validation_0-logloss:0.60232	validation_1-logloss:0.60713
# [93]	validation_0-logloss:0.60210	validation_1-logloss:0.60696
# [94]	validation_0-logloss:0.60200	validation_1-logloss:0.60690
# [95]	validation_0-logloss:0.60179	validation_1-logloss:0.60676
# [96]	validation_0-logloss:0.60162	validation_1-logloss:0.60665
# [97]	validation_0-logloss:0.60132	validation_1-logloss:0.60639
# [98]	validation_0-logloss:0.60118	validation_1-logloss:0.60628
# [99]	validation_0-logloss:0.60092	validation_1-logloss:0.60611
# [100]	validation_0-logloss:0.60077	validation_1-logloss:0.60604
# [101]	validation_0-logloss:0.60063	validation_1-logloss:0.60595
# [102]	validation_0-logloss:0.60051	validation_1-logloss:0.60590
# [103]	validation_0-logloss:0.60034	validation_1-logloss:0.60578
# [104]	validation_0-logloss:0.60020	validation_1-logloss:0.60567
# [105]	validation_0-logloss:0.60008	validation_1-logloss:0.60562
# [106]	validation_0-logloss:0.59989	validation_1-logloss:0.60546
# [107]	validation_0-logloss:0.59976	validation_1-logloss:0.60539
# [108]	validation_0-logloss:0.59965	validation_1-logloss:0.60532
# [109]	validation_0-logloss:0.59956	validation_1-logloss:0.60528
# [110]	validation_0-logloss:0.59908	validation_1-logloss:0.60483
# [111]	validation_0-logloss:0.59901	validation_1-logloss:0.60480
# [112]	validation_0-logloss:0.59873	validation_1-logloss:0.60459
# [113]	validation_0-logloss:0.59836	validation_1-logloss:0.60429
# [114]	validation_0-logloss:0.59825	validation_1-logloss:0.60423
# [115]	validation_0-logloss:0.59815	validation_1-logloss:0.60419
# [116]	validation_0-logloss:0.59797	validation_1-logloss:0.60408
# [117]	validation_0-logloss:0.59778	validation_1-logloss:0.60396
# [118]	validation_0-logloss:0.59752	validation_1-logloss:0.60373
# [119]	validation_0-logloss:0.59720	validation_1-logloss:0.60346
# [120]	validation_0-logloss:0.59712	validation_1-logloss:0.60344
# [121]	validation_0-logloss:0.59700	validation_1-logloss:0.60336
# [122]	validation_0-logloss:0.59680	validation_1-logloss:0.60322
# [123]	validation_0-logloss:0.59672	validation_1-logloss:0.60319
# [124]	validation_0-logloss:0.59659	validation_1-logloss:0.60310
# [125]	validation_0-logloss:0.59643	validation_1-logloss:0.60302
# [126]	validation_0-logloss:0.59630	validation_1-logloss:0.60295
# [127]	validation_0-logloss:0.59619	validation_1-logloss:0.60290
# [128]	validation_0-logloss:0.59609	validation_1-logloss:0.60287
# [129]	validation_0-logloss:0.59593	validation_1-logloss:0.60280
# [130]	validation_0-logloss:0.59565	validation_1-logloss:0.60256
# [131]	validation_0-logloss:0.59552	validation_1-logloss:0.60248
# [132]	validation_0-logloss:0.59524	validation_1-logloss:0.60224
# [133]	validation_0-logloss:0.59513	validation_1-logloss:0.60219
# [134]	validation_0-logloss:0.59498	validation_1-logloss:0.60210
# [135]	validation_0-logloss:0.59487	validation_1-logloss:0.60205
# [136]	validation_0-logloss:0.59481	validation_1-logloss:0.60204
# [137]	validation_0-logloss:0.59467	validation_1-logloss:0.60196
# [138]	validation_0-logloss:0.59454	validation_1-logloss:0.60188
# [139]	validation_0-logloss:0.59445	validation_1-logloss:0.60184
# [140]	validation_0-logloss:0.59420	validation_1-logloss:0.60165
# [141]	validation_0-logloss:0.59409	validation_1-logloss:0.60160
# [142]	validation_0-logloss:0.59394	validation_1-logloss:0.60151
# [143]	validation_0-logloss:0.59376	validation_1-logloss:0.60137
# [144]	validation_0-logloss:0.59365	validation_1-logloss:0.60134
# [145]	validation_0-logloss:0.59354	validation_1-logloss:0.60129
# [146]	validation_0-logloss:0.59349	validation_1-logloss:0.60127
# [147]	validation_0-logloss:0.59340	validation_1-logloss:0.60124
# [148]	validation_0-logloss:0.59331	validation_1-logloss:0.60120
# [149]	validation_0-logloss:0.59316	validation_1-logloss:0.60111
# [150]	validation_0-logloss:0.59308	validation_1-logloss:0.60108
# [151]	validation_0-logloss:0.59300	validation_1-logloss:0.60106
# [152]	validation_0-logloss:0.59277	validation_1-logloss:0.60089
# [153]	validation_0-logloss:0.59271	validation_1-logloss:0.60086
# [154]	validation_0-logloss:0.59261	validation_1-logloss:0.60084
# [155]	validation_0-logloss:0.59251	validation_1-logloss:0.60081
# [156]	validation_0-logloss:0.59234	validation_1-logloss:0.60068
# [157]	validation_0-logloss:0.59224	validation_1-logloss:0.60063
# [158]	validation_0-logloss:0.59210	validation_1-logloss:0.60054
# [159]	validation_0-logloss:0.59192	validation_1-logloss:0.60043
# [160]	validation_0-logloss:0.59167	validation_1-logloss:0.60024
# [161]	validation_0-logloss:0.59156	validation_1-logloss:0.60020
# [162]	validation_0-logloss:0.59148	validation_1-logloss:0.60019
# [163]	validation_0-logloss:0.59138	validation_1-logloss:0.60013
# [164]	validation_0-logloss:0.59130	validation_1-logloss:0.60012
# [165]	validation_0-logloss:0.59103	validation_1-logloss:0.59987
# [166]	validation_0-logloss:0.59095	validation_1-logloss:0.59986
# [167]	validation_0-logloss:0.59084	validation_1-logloss:0.59981
# [168]	validation_0-logloss:0.59078	validation_1-logloss:0.59979
# [169]	validation_0-logloss:0.59071	validation_1-logloss:0.59978
# [170]	validation_0-logloss:0.59064	validation_1-logloss:0.59977
# [171]	validation_0-logloss:0.59057	validation_1-logloss:0.59976
# [172]	validation_0-logloss:0.59049	validation_1-logloss:0.59973
# [173]	validation_0-logloss:0.59043	validation_1-logloss:0.59974
# [174]	validation_0-logloss:0.59032	validation_1-logloss:0.59969
# [175]	validation_0-logloss:0.59014	validation_1-logloss:0.59955
# [176]	validation_0-logloss:0.59006	validation_1-logloss:0.59953
# [177]	validation_0-logloss:0.58997	validation_1-logloss:0.59948
# [178]	validation_0-logloss:0.58990	validation_1-logloss:0.59946
# [179]	validation_0-logloss:0.58982	validation_1-logloss:0.59945
# [180]	validation_0-logloss:0.58976	validation_1-logloss:0.59944
# [181]	validation_0-logloss:0.58964	validation_1-logloss:0.59937
# [182]	validation_0-logloss:0.58945	validation_1-logloss:0.59926
# [183]	validation_0-logloss:0.58939	validation_1-logloss:0.59925
# [184]	validation_0-logloss:0.58932	validation_1-logloss:0.59924
# [185]	validation_0-logloss:0.58926	validation_1-logloss:0.59922
# [186]	validation_0-logloss:0.58920	validation_1-logloss:0.59920
# [187]	validation_0-logloss:0.58909	validation_1-logloss:0.59915
# [188]	validation_0-logloss:0.58902	validation_1-logloss:0.59914
# [189]	validation_0-logloss:0.58894	validation_1-logloss:0.59913
# [190]	validation_0-logloss:0.58888	validation_1-logloss:0.59912
# [191]	validation_0-logloss:0.58882	validation_1-logloss:0.59911
# [192]	validation_0-logloss:0.58874	validation_1-logloss:0.59909
# [193]	validation_0-logloss:0.58861	validation_1-logloss:0.59904
# [194]	validation_0-logloss:0.58852	validation_1-logloss:0.59902
# [195]	validation_0-logloss:0.58842	validation_1-logloss:0.59896
# [196]	validation_0-logloss:0.58834	validation_1-logloss:0.59892
# [197]	validation_0-logloss:0.58822	validation_1-logloss:0.59887
# [198]	validation_0-logloss:0.58815	validation_1-logloss:0.59885
# [199]	validation_0-logloss:0.58806	validation_1-logloss:0.59882
# [200]	validation_0-logloss:0.58795	validation_1-logloss:0.59878
# [201]	validation_0-logloss:0.58781	validation_1-logloss:0.59870
# [202]	validation_0-logloss:0.58775	validation_1-logloss:0.59870
# [203]	validation_0-logloss:0.58769	validation_1-logloss:0.59869
# [204]	validation_0-logloss:0.58762	validation_1-logloss:0.59870
# [205]	validation_0-logloss:0.58754	validation_1-logloss:0.59867
# [206]	validation_0-logloss:0.58746	validation_1-logloss:0.59863
# [207]	validation_0-logloss:0.58717	validation_1-logloss:0.59836
# [208]	validation_0-logloss:0.58711	validation_1-logloss:0.59835
# [209]	validation_0-logloss:0.58702	validation_1-logloss:0.59832
# [210]	validation_0-logloss:0.58695	validation_1-logloss:0.59833
# [211]	validation_0-logloss:0.58687	validation_1-logloss:0.59830
# [212]	validation_0-logloss:0.58678	validation_1-logloss:0.59826
# [213]	validation_0-logloss:0.58672	validation_1-logloss:0.59824
# [214]	validation_0-logloss:0.58663	validation_1-logloss:0.59822
# [215]	validation_0-logloss:0.58652	validation_1-logloss:0.59816
# [216]	validation_0-logloss:0.58643	validation_1-logloss:0.59815
# [217]	validation_0-logloss:0.58639	validation_1-logloss:0.59815
# [218]	validation_0-logloss:0.58634	validation_1-logloss:0.59814
# [219]	validation_0-logloss:0.58624	validation_1-logloss:0.59810
# [220]	validation_0-logloss:0.58618	validation_1-logloss:0.59807
# [221]	validation_0-logloss:0.58601	validation_1-logloss:0.59796
# [222]	validation_0-logloss:0.58595	validation_1-logloss:0.59794
# [223]	validation_0-logloss:0.58584	validation_1-logloss:0.59790
# [224]	validation_0-logloss:0.58578	validation_1-logloss:0.59787
# [225]	validation_0-logloss:0.58568	validation_1-logloss:0.59782
# [226]	validation_0-logloss:0.58563	validation_1-logloss:0.59781
# [227]	validation_0-logloss:0.58555	validation_1-logloss:0.59780
# [228]	validation_0-logloss:0.58545	validation_1-logloss:0.59777
# [229]	validation_0-logloss:0.58537	validation_1-logloss:0.59774
# [230]	validation_0-logloss:0.58528	validation_1-logloss:0.59768
# [231]	validation_0-logloss:0.58520	validation_1-logloss:0.59765
# [232]	validation_0-logloss:0.58510	validation_1-logloss:0.59763
# [233]	validation_0-logloss:0.58497	validation_1-logloss:0.59754
# [234]	validation_0-logloss:0.58488	validation_1-logloss:0.59750
# [235]	validation_0-logloss:0.58477	validation_1-logloss:0.59745
# [236]	validation_0-logloss:0.58473	validation_1-logloss:0.59744
# [237]	validation_0-logloss:0.58461	validation_1-logloss:0.59737
# [238]	validation_0-logloss:0.58444	validation_1-logloss:0.59727
# [239]	validation_0-logloss:0.58437	validation_1-logloss:0.59725
# [240]	validation_0-logloss:0.58431	validation_1-logloss:0.59724
# [241]	validation_0-logloss:0.58426	validation_1-logloss:0.59724
# [242]	validation_0-logloss:0.58417	validation_1-logloss:0.59722
# [243]	validation_0-logloss:0.58405	validation_1-logloss:0.59716
# [244]	validation_0-logloss:0.58399	validation_1-logloss:0.59716
# [245]	validation_0-logloss:0.58391	validation_1-logloss:0.59712
# [246]	validation_0-logloss:0.58385	validation_1-logloss:0.59711
# [247]	validation_0-logloss:0.58381	validation_1-logloss:0.59711
# [248]	validation_0-logloss:0.58370	validation_1-logloss:0.59706
# [249]	validation_0-logloss:0.58353	validation_1-logloss:0.59694
# [250]	validation_0-logloss:0.58345	validation_1-logloss:0.59694
# [251]	validation_0-logloss:0.58337	validation_1-logloss:0.59693
# [252]	validation_0-logloss:0.58328	validation_1-logloss:0.59690
# [253]	validation_0-logloss:0.58321	validation_1-logloss:0.59690
# [254]	validation_0-logloss:0.58311	validation_1-logloss:0.59688
# [255]	validation_0-logloss:0.58304	validation_1-logloss:0.59686
# [256]	validation_0-logloss:0.58294	validation_1-logloss:0.59684
# [257]	validation_0-logloss:0.58281	validation_1-logloss:0.59677
# [258]	validation_0-logloss:0.58273	validation_1-logloss:0.59675
# [259]	validation_0-logloss:0.58267	validation_1-logloss:0.59675
# [260]	validation_0-logloss:0.58259	validation_1-logloss:0.59673
# [261]	validation_0-logloss:0.58248	validation_1-logloss:0.59666
# [262]	validation_0-logloss:0.58241	validation_1-logloss:0.59666
# [263]	validation_0-logloss:0.58234	validation_1-logloss:0.59663
# [264]	validation_0-logloss:0.58229	validation_1-logloss:0.59662
# [265]	validation_0-logloss:0.58223	validation_1-logloss:0.59662
# [266]	validation_0-logloss:0.58217	validation_1-logloss:0.59661
# [267]	validation_0-logloss:0.58210	validation_1-logloss:0.59658
# [268]	validation_0-logloss:0.58197	validation_1-logloss:0.59653
# [269]	validation_0-logloss:0.58187	validation_1-logloss:0.59649
# [270]	validation_0-logloss:0.58180	validation_1-logloss:0.59646
# [271]	validation_0-logloss:0.58174	validation_1-logloss:0.59647
# [272]	validation_0-logloss:0.58168	validation_1-logloss:0.59644
# [273]	validation_0-logloss:0.58160	validation_1-logloss:0.59641
# [274]	validation_0-logloss:0.58153	validation_1-logloss:0.59641
# [275]	validation_0-logloss:0.58147	validation_1-logloss:0.59641
# [276]	validation_0-logloss:0.58139	validation_1-logloss:0.59639
# [277]	validation_0-logloss:0.58131	validation_1-logloss:0.59639
# [278]	validation_0-logloss:0.58124	validation_1-logloss:0.59636
# [279]	validation_0-logloss:0.58117	validation_1-logloss:0.59635
# [280]	validation_0-logloss:0.58106	validation_1-logloss:0.59628
# [281]	validation_0-logloss:0.58093	validation_1-logloss:0.59620
# [282]	validation_0-logloss:0.58088	validation_1-logloss:0.59621
# [283]	validation_0-logloss:0.58082	validation_1-logloss:0.59619
# [284]	validation_0-logloss:0.58073	validation_1-logloss:0.59616
# [285]	validation_0-logloss:0.58068	validation_1-logloss:0.59616
# [286]	validation_0-logloss:0.58063	validation_1-logloss:0.59617
# [287]	validation_0-logloss:0.58057	validation_1-logloss:0.59618
# [288]	validation_0-logloss:0.58048	validation_1-logloss:0.59616
# [289]	validation_0-logloss:0.58044	validation_1-logloss:0.59617
# [290]	validation_0-logloss:0.58038	validation_1-logloss:0.59614
# [291]	validation_0-logloss:0.58032	validation_1-logloss:0.59615
# [292]	validation_0-logloss:0.58022	validation_1-logloss:0.59611
# [293]	validation_0-logloss:0.58013	validation_1-logloss:0.59610
# [294]	validation_0-logloss:0.58006	validation_1-logloss:0.59609
# [295]	validation_0-logloss:0.57997	validation_1-logloss:0.59606
# [296]	validation_0-logloss:0.57990	validation_1-logloss:0.59605
# [297]	validation_0-logloss:0.57982	validation_1-logloss:0.59603
# [298]	validation_0-logloss:0.57977	validation_1-logloss:0.59604
# [299]	validation_0-logloss:0.57972	validation_1-logloss:0.59603
# [300]	validation_0-logloss:0.57966	validation_1-logloss:0.59601
# [301]	validation_0-logloss:0.57959	validation_1-logloss:0.59600
# [302]	validation_0-logloss:0.57954	validation_1-logloss:0.59598
# [303]	validation_0-logloss:0.57946	validation_1-logloss:0.59598
# [304]	validation_0-logloss:0.57938	validation_1-logloss:0.59592
# [305]	validation_0-logloss:0.57931	validation_1-logloss:0.59592
# [306]	validation_0-logloss:0.57925	validation_1-logloss:0.59591
# [307]	validation_0-logloss:0.57920	validation_1-logloss:0.59591
# [308]	validation_0-logloss:0.57913	validation_1-logloss:0.59588
# [309]	validation_0-logloss:0.57907	validation_1-logloss:0.59589
# [310]	validation_0-logloss:0.57901	validation_1-logloss:0.59590
# [311]	validation_0-logloss:0.57893	validation_1-logloss:0.59587
# [312]	validation_0-logloss:0.57887	validation_1-logloss:0.59587
# [313]	validation_0-logloss:0.57882	validation_1-logloss:0.59586
# [314]	validation_0-logloss:0.57876	validation_1-logloss:0.59585
# [315]	validation_0-logloss:0.57871	validation_1-logloss:0.59585
# [316]	validation_0-logloss:0.57865	validation_1-logloss:0.59584
# [317]	validation_0-logloss:0.57857	validation_1-logloss:0.59582
# [318]	validation_0-logloss:0.57851	validation_1-logloss:0.59581
# [319]	validation_0-logloss:0.57845	validation_1-logloss:0.59581
# [320]	validation_0-logloss:0.57831	validation_1-logloss:0.59572
# [321]	validation_0-logloss:0.57813	validation_1-logloss:0.59557
# [322]	validation_0-logloss:0.57807	validation_1-logloss:0.59558
# [323]	validation_0-logloss:0.57795	validation_1-logloss:0.59550
# [324]	validation_0-logloss:0.57788	validation_1-logloss:0.59549
# [325]	validation_0-logloss:0.57782	validation_1-logloss:0.59547
# [326]	validation_0-logloss:0.57772	validation_1-logloss:0.59542
# [327]	validation_0-logloss:0.57765	validation_1-logloss:0.59539
# [328]	validation_0-logloss:0.57755	validation_1-logloss:0.59536
# [329]	validation_0-logloss:0.57749	validation_1-logloss:0.59534
# [330]	validation_0-logloss:0.57741	validation_1-logloss:0.59530
# [331]	validation_0-logloss:0.57728	validation_1-logloss:0.59521
# [332]	validation_0-logloss:0.57721	validation_1-logloss:0.59519
# [333]	validation_0-logloss:0.57713	validation_1-logloss:0.59516
# [334]	validation_0-logloss:0.57708	validation_1-logloss:0.59515
# [335]	validation_0-logloss:0.57700	validation_1-logloss:0.59511
# [336]	validation_0-logloss:0.57693	validation_1-logloss:0.59510
# [337]	validation_0-logloss:0.57681	validation_1-logloss:0.59505
# [338]	validation_0-logloss:0.57672	validation_1-logloss:0.59501
# [339]	validation_0-logloss:0.57660	validation_1-logloss:0.59493
# [340]	validation_0-logloss:0.57653	validation_1-logloss:0.59493
# [341]	validation_0-logloss:0.57646	validation_1-logloss:0.59492
# [342]	validation_0-logloss:0.57639	validation_1-logloss:0.59491
# [343]	validation_0-logloss:0.57633	validation_1-logloss:0.59491
# [344]	validation_0-logloss:0.57628	validation_1-logloss:0.59490
# [345]	validation_0-logloss:0.57619	validation_1-logloss:0.59488
# [346]	validation_0-logloss:0.57609	validation_1-logloss:0.59483
# [347]	validation_0-logloss:0.57602	validation_1-logloss:0.59483
# [348]	validation_0-logloss:0.57592	validation_1-logloss:0.59478
# [349]	validation_0-logloss:0.57584	validation_1-logloss:0.59476
# [350]	validation_0-logloss:0.57578	validation_1-logloss:0.59476
# [351]	validation_0-logloss:0.57574	validation_1-logloss:0.59476
# [352]	validation_0-logloss:0.57566	validation_1-logloss:0.59474
# [353]	validation_0-logloss:0.57560	validation_1-logloss:0.59475
# [354]	validation_0-logloss:0.57557	validation_1-logloss:0.59476
# [355]	validation_0-logloss:0.57552	validation_1-logloss:0.59475
# [356]	validation_0-logloss:0.57546	validation_1-logloss:0.59475
# [357]	validation_0-logloss:0.57540	validation_1-logloss:0.59475
# [358]	validation_0-logloss:0.57533	validation_1-logloss:0.59473
# [359]	validation_0-logloss:0.57524	validation_1-logloss:0.59470
# [360]	validation_0-logloss:0.57517	validation_1-logloss:0.59469
# [361]	validation_0-logloss:0.57509	validation_1-logloss:0.59464
# [362]	validation_0-logloss:0.57503	validation_1-logloss:0.59465
# [363]	validation_0-logloss:0.57494	validation_1-logloss:0.59460
# [364]	validation_0-logloss:0.57487	validation_1-logloss:0.59460
# [365]	validation_0-logloss:0.57479	validation_1-logloss:0.59459
# [366]	validation_0-logloss:0.57474	validation_1-logloss:0.59459
# [367]	validation_0-logloss:0.57466	validation_1-logloss:0.59457
# [368]	validation_0-logloss:0.57459	validation_1-logloss:0.59454
# [369]	validation_0-logloss:0.57452	validation_1-logloss:0.59454
# [370]	validation_0-logloss:0.57445	validation_1-logloss:0.59454
# [371]	validation_0-logloss:0.57439	validation_1-logloss:0.59455
# [372]	validation_0-logloss:0.57435	validation_1-logloss:0.59455
# [373]	validation_0-logloss:0.57428	validation_1-logloss:0.59455
# [374]	validation_0-logloss:0.57419	validation_1-logloss:0.59452
# [375]	validation_0-logloss:0.57414	validation_1-logloss:0.59453
# [376]	validation_0-logloss:0.57407	validation_1-logloss:0.59451
# [377]	validation_0-logloss:0.57398	validation_1-logloss:0.59446
# [378]	validation_0-logloss:0.57390	validation_1-logloss:0.59442
# [379]	validation_0-logloss:0.57385	validation_1-logloss:0.59442
# [380]	validation_0-logloss:0.57372	validation_1-logloss:0.59435
# [381]	validation_0-logloss:0.57365	validation_1-logloss:0.59433
# [382]	validation_0-logloss:0.57359	validation_1-logloss:0.59432
# [383]	validation_0-logloss:0.57350	validation_1-logloss:0.59428
# [384]	validation_0-logloss:0.57343	validation_1-logloss:0.59425
# [385]	validation_0-logloss:0.57338	validation_1-logloss:0.59425
# [386]	validation_0-logloss:0.57334	validation_1-logloss:0.59425
# [387]	validation_0-logloss:0.57329	validation_1-logloss:0.59425
# [388]	validation_0-logloss:0.57321	validation_1-logloss:0.59423
# [389]	validation_0-logloss:0.57310	validation_1-logloss:0.59416
# [390]	validation_0-logloss:0.57304	validation_1-logloss:0.59415
# [391]	validation_0-logloss:0.57297	validation_1-logloss:0.59414
# [392]	validation_0-logloss:0.57291	validation_1-logloss:0.59414
# [393]	validation_0-logloss:0.57285	validation_1-logloss:0.59415
# [394]	validation_0-logloss:0.57278	validation_1-logloss:0.59413
# [395]	validation_0-logloss:0.57270	validation_1-logloss:0.59412
# [396]	validation_0-logloss:0.57264	validation_1-logloss:0.59412
# [397]	validation_0-logloss:0.57259	validation_1-logloss:0.59412
# [398]	validation_0-logloss:0.57247	validation_1-logloss:0.59404
# [399]	validation_0-logloss:0.57237	validation_1-logloss:0.59401
# [400]	validation_0-logloss:0.57229	validation_1-logloss:0.59400
# [401]	validation_0-logloss:0.57220	validation_1-logloss:0.59395
# [402]	validation_0-logloss:0.57214	validation_1-logloss:0.59395
# [403]	validation_0-logloss:0.57208	validation_1-logloss:0.59395
# [404]	validation_0-logloss:0.57202	validation_1-logloss:0.59394
# [405]	validation_0-logloss:0.57197	validation_1-logloss:0.59396
# [406]	validation_0-logloss:0.57185	validation_1-logloss:0.59388
# [407]	validation_0-logloss:0.57180	validation_1-logloss:0.59387
# [408]	validation_0-logloss:0.57169	validation_1-logloss:0.59382
# [409]	validation_0-logloss:0.57158	validation_1-logloss:0.59376
# [410]	validation_0-logloss:0.57151	validation_1-logloss:0.59374
# [411]	validation_0-logloss:0.57146	validation_1-logloss:0.59374
# [412]	validation_0-logloss:0.57140	validation_1-logloss:0.59374
# [413]	validation_0-logloss:0.57134	validation_1-logloss:0.59374
# [414]	validation_0-logloss:0.57128	validation_1-logloss:0.59374
# [415]	validation_0-logloss:0.57123	validation_1-logloss:0.59371
# [416]	validation_0-logloss:0.57114	validation_1-logloss:0.59368
# [417]	validation_0-logloss:0.57104	validation_1-logloss:0.59364
# [418]	validation_0-logloss:0.57097	validation_1-logloss:0.59363
# [419]	validation_0-logloss:0.57092	validation_1-logloss:0.59363
# [420]	validation_0-logloss:0.57081	validation_1-logloss:0.59357
# [421]	validation_0-logloss:0.57075	validation_1-logloss:0.59356
# [422]	validation_0-logloss:0.57067	validation_1-logloss:0.59352
# [423]	validation_0-logloss:0.57063	validation_1-logloss:0.59352
# [424]	validation_0-logloss:0.57058	validation_1-logloss:0.59351
# [425]	validation_0-logloss:0.57055	validation_1-logloss:0.59352
# [426]	validation_0-logloss:0.57047	validation_1-logloss:0.59349
# [427]	validation_0-logloss:0.57042	validation_1-logloss:0.59350
# [428]	validation_0-logloss:0.57037	validation_1-logloss:0.59351
# [429]	validation_0-logloss:0.57030	validation_1-logloss:0.59349
# [430]	validation_0-logloss:0.57022	validation_1-logloss:0.59348
# [431]	validation_0-logloss:0.57014	validation_1-logloss:0.59348
# [432]	validation_0-logloss:0.57007	validation_1-logloss:0.59346
# [433]	validation_0-logloss:0.57001	validation_1-logloss:0.59346
# [434]	validation_0-logloss:0.56995	validation_1-logloss:0.59344
# [435]	validation_0-logloss:0.56989	validation_1-logloss:0.59344
# [436]	validation_0-logloss:0.56984	validation_1-logloss:0.59345
# [437]	validation_0-logloss:0.56974	validation_1-logloss:0.59338
# [438]	validation_0-logloss:0.56966	validation_1-logloss:0.59337
# [439]	validation_0-logloss:0.56958	validation_1-logloss:0.59335
# [440]	validation_0-logloss:0.56953	validation_1-logloss:0.59334
# [441]	validation_0-logloss:0.56942	validation_1-logloss:0.59329
# [442]	validation_0-logloss:0.56936	validation_1-logloss:0.59328
# [443]	validation_0-logloss:0.56929	validation_1-logloss:0.59329
# [444]	validation_0-logloss:0.56922	validation_1-logloss:0.59330
# [445]	validation_0-logloss:0.56917	validation_1-logloss:0.59329
# [446]	validation_0-logloss:0.56912	validation_1-logloss:0.59330
# [447]	validation_0-logloss:0.56908	validation_1-logloss:0.59330
# [448]	validation_0-logloss:0.56902	validation_1-logloss:0.59329
# [449]	validation_0-logloss:0.56894	validation_1-logloss:0.59326
# [450]	validation_0-logloss:0.56889	validation_1-logloss:0.59327
# [451]	validation_0-logloss:0.56883	validation_1-logloss:0.59326
# [452]	validation_0-logloss:0.56873	validation_1-logloss:0.59323
# [453]	validation_0-logloss:0.56863	validation_1-logloss:0.59322
# [454]	validation_0-logloss:0.56854	validation_1-logloss:0.59318
# [455]	validation_0-logloss:0.56850	validation_1-logloss:0.59317
# [456]	validation_0-logloss:0.56844	validation_1-logloss:0.59317
# [457]	validation_0-logloss:0.56840	validation_1-logloss:0.59317
# [458]	validation_0-logloss:0.56834	validation_1-logloss:0.59318
# [459]	validation_0-logloss:0.56828	validation_1-logloss:0.59318
# [460]	validation_0-logloss:0.56823	validation_1-logloss:0.59317
# [461]	validation_0-logloss:0.56817	validation_1-logloss:0.59316
# [462]	validation_0-logloss:0.56811	validation_1-logloss:0.59317
# [463]	validation_0-logloss:0.56805	validation_1-logloss:0.59317
# [464]	validation_0-logloss:0.56798	validation_1-logloss:0.59315
# [465]	validation_0-logloss:0.56794	validation_1-logloss:0.59314
# [466]	validation_0-logloss:0.56789	validation_1-logloss:0.59314
# [467]	validation_0-logloss:0.56785	validation_1-logloss:0.59314
# [468]	validation_0-logloss:0.56778	validation_1-logloss:0.59311
# [469]	validation_0-logloss:0.56772	validation_1-logloss:0.59312
# [470]	validation_0-logloss:0.56768	validation_1-logloss:0.59313
# [471]	validation_0-logloss:0.56763	validation_1-logloss:0.59313
# [472]	validation_0-logloss:0.56757	validation_1-logloss:0.59313
# [473]	validation_0-logloss:0.56749	validation_1-logloss:0.59313
# [474]	validation_0-logloss:0.56742	validation_1-logloss:0.59311
# [475]	validation_0-logloss:0.56736	validation_1-logloss:0.59313
# [476]	validation_0-logloss:0.56731	validation_1-logloss:0.59312
# [477]	validation_0-logloss:0.56725	validation_1-logloss:0.59312
# [478]	validation_0-logloss:0.56718	validation_1-logloss:0.59311
# [479]	validation_0-logloss:0.56709	validation_1-logloss:0.59309
# [480]	validation_0-logloss:0.56705	validation_1-logloss:0.59310
# [481]	validation_0-logloss:0.56698	validation_1-logloss:0.59308
# [482]	validation_0-logloss:0.56692	validation_1-logloss:0.59309
# [483]	validation_0-logloss:0.56687	validation_1-logloss:0.59309
# [484]	validation_0-logloss:0.56682	validation_1-logloss:0.59309
# [485]	validation_0-logloss:0.56671	validation_1-logloss:0.59303
# [486]	validation_0-logloss:0.56662	validation_1-logloss:0.59300
# [487]	validation_0-logloss:0.56658	validation_1-logloss:0.59300
# [488]	validation_0-logloss:0.56650	validation_1-logloss:0.59298
# [489]	validation_0-logloss:0.56643	validation_1-logloss:0.59298
# [490]	validation_0-logloss:0.56638	validation_1-logloss:0.59297
# [491]	validation_0-logloss:0.56632	validation_1-logloss:0.59297
# [492]	validation_0-logloss:0.56626	validation_1-logloss:0.59296
# [493]	validation_0-logloss:0.56620	validation_1-logloss:0.59297
# [494]	validation_0-logloss:0.56617	validation_1-logloss:0.59297
# [495]	validation_0-logloss:0.56610	validation_1-logloss:0.59296
# [496]	validation_0-logloss:0.56603	validation_1-logloss:0.59296
# [497]	validation_0-logloss:0.56598	validation_1-logloss:0.59294
# [498]	validation_0-logloss:0.56592	validation_1-logloss:0.59294
# [499]	validation_0-logloss:0.56587	validation_1-logloss:0.59295
# [500]	validation_0-logloss:0.56582	validation_1-logloss:0.59295
# [501]	validation_0-logloss:0.56577	validation_1-logloss:0.59294
# [502]	validation_0-logloss:0.56572	validation_1-logloss:0.59294
# [503]	validation_0-logloss:0.56565	validation_1-logloss:0.59292
# [504]	validation_0-logloss:0.56557	validation_1-logloss:0.59289
# [505]	validation_0-logloss:0.56551	validation_1-logloss:0.59291
# [506]	validation_0-logloss:0.56546	validation_1-logloss:0.59292
# [507]	validation_0-logloss:0.56539	validation_1-logloss:0.59290
# [508]	validation_0-logloss:0.56533	validation_1-logloss:0.59289
# [509]	validation_0-logloss:0.56527	validation_1-logloss:0.59288
# [510]	validation_0-logloss:0.56521	validation_1-logloss:0.59288
# [511]	validation_0-logloss:0.56516	validation_1-logloss:0.59288
# [512]	validation_0-logloss:0.56508	validation_1-logloss:0.59287
# [513]	validation_0-logloss:0.56503	validation_1-logloss:0.59286
# [514]	validation_0-logloss:0.56500	validation_1-logloss:0.59286
# [515]	validation_0-logloss:0.56495	validation_1-logloss:0.59287
# [516]	validation_0-logloss:0.56491	validation_1-logloss:0.59288
# [517]	validation_0-logloss:0.56486	validation_1-logloss:0.59287
# [518]	validation_0-logloss:0.56480	validation_1-logloss:0.59287
# [519]	validation_0-logloss:0.56473	validation_1-logloss:0.59287
# [520]	validation_0-logloss:0.56466	validation_1-logloss:0.59285
# [521]	validation_0-logloss:0.56461	validation_1-logloss:0.59284
# [522]	validation_0-logloss:0.56455	validation_1-logloss:0.59285
# [523]	validation_0-logloss:0.56448	validation_1-logloss:0.59284
# [524]	validation_0-logloss:0.56442	validation_1-logloss:0.59283
# [525]	validation_0-logloss:0.56435	validation_1-logloss:0.59281
# [526]	validation_0-logloss:0.56428	validation_1-logloss:0.59281
# [527]	validation_0-logloss:0.56422	validation_1-logloss:0.59281
# [528]	validation_0-logloss:0.56416	validation_1-logloss:0.59281
# [529]	validation_0-logloss:0.56413	validation_1-logloss:0.59282
# [530]	validation_0-logloss:0.56409	validation_1-logloss:0.59283
# [531]	validation_0-logloss:0.56403	validation_1-logloss:0.59283
# [532]	validation_0-logloss:0.56397	validation_1-logloss:0.59284
# [533]	validation_0-logloss:0.56393	validation_1-logloss:0.59282
# [534]	validation_0-logloss:0.56384	validation_1-logloss:0.59278
# [535]	validation_0-logloss:0.56378	validation_1-logloss:0.59277
# [536]	validation_0-logloss:0.56372	validation_1-logloss:0.59277
# [537]	validation_0-logloss:0.56366	validation_1-logloss:0.59277
# [538]	validation_0-logloss:0.56362	validation_1-logloss:0.59277
# [539]	validation_0-logloss:0.56356	validation_1-logloss:0.59278
# [540]	validation_0-logloss:0.56352	validation_1-logloss:0.59277
# [541]	validation_0-logloss:0.56346	validation_1-logloss:0.59276
# [542]	validation_0-logloss:0.56341	validation_1-logloss:0.59277
# [543]	validation_0-logloss:0.56336	validation_1-logloss:0.59279
# [544]	validation_0-logloss:0.56330	validation_1-logloss:0.59278
# [545]	validation_0-logloss:0.56323	validation_1-logloss:0.59277
# [546]	validation_0-logloss:0.56319	validation_1-logloss:0.59277
# [547]	validation_0-logloss:0.56309	validation_1-logloss:0.59273
# [548]	validation_0-logloss:0.56304	validation_1-logloss:0.59273
# [549]	validation_0-logloss:0.56298	validation_1-logloss:0.59274
# [550]	validation_0-logloss:0.56289	validation_1-logloss:0.59270
# [551]	validation_0-logloss:0.56284	validation_1-logloss:0.59269
# [552]	validation_0-logloss:0.56280	validation_1-logloss:0.59269
# [553]	validation_0-logloss:0.56271	validation_1-logloss:0.59264
# [554]	validation_0-logloss:0.56262	validation_1-logloss:0.59261
# [555]	validation_0-logloss:0.56256	validation_1-logloss:0.59260
# [556]	validation_0-logloss:0.56246	validation_1-logloss:0.59252
# [557]	validation_0-logloss:0.56234	validation_1-logloss:0.59244
# [558]	validation_0-logloss:0.56228	validation_1-logloss:0.59245
# [559]	validation_0-logloss:0.56223	validation_1-logloss:0.59246
# [560]	validation_0-logloss:0.56212	validation_1-logloss:0.59240
# [561]	validation_0-logloss:0.56206	validation_1-logloss:0.59240
# [562]	validation_0-logloss:0.56199	validation_1-logloss:0.59239
# [563]	validation_0-logloss:0.56193	validation_1-logloss:0.59239
# [564]	validation_0-logloss:0.56189	validation_1-logloss:0.59238
# [565]	validation_0-logloss:0.56184	validation_1-logloss:0.59238
# [566]	validation_0-logloss:0.56179	validation_1-logloss:0.59239
# [567]	validation_0-logloss:0.56172	validation_1-logloss:0.59239
# [568]	validation_0-logloss:0.56164	validation_1-logloss:0.59238
# [569]	validation_0-logloss:0.56160	validation_1-logloss:0.59237
# [570]	validation_0-logloss:0.56154	validation_1-logloss:0.59236
# [571]	validation_0-logloss:0.56149	validation_1-logloss:0.59236
# [572]	validation_0-logloss:0.56143	validation_1-logloss:0.59236
# [573]	validation_0-logloss:0.56138	validation_1-logloss:0.59236
# [574]	validation_0-logloss:0.56134	validation_1-logloss:0.59237
# [575]	validation_0-logloss:0.56128	validation_1-logloss:0.59238
# [576]	validation_0-logloss:0.56121	validation_1-logloss:0.59236
# [577]	validation_0-logloss:0.56113	validation_1-logloss:0.59234
# [578]	validation_0-logloss:0.56108	validation_1-logloss:0.59235
# [579]	validation_0-logloss:0.56102	validation_1-logloss:0.59234
# [580]	validation_0-logloss:0.56095	validation_1-logloss:0.59233
# [581]	validation_0-logloss:0.56090	validation_1-logloss:0.59233
# [582]	validation_0-logloss:0.56087	validation_1-logloss:0.59233
# [583]	validation_0-logloss:0.56081	validation_1-logloss:0.59232
# [584]	validation_0-logloss:0.56076	validation_1-logloss:0.59232
# [585]	validation_0-logloss:0.56069	validation_1-logloss:0.59232
# [586]	validation_0-logloss:0.56063	validation_1-logloss:0.59231
# [587]	validation_0-logloss:0.56054	validation_1-logloss:0.59226
# [588]	validation_0-logloss:0.56048	validation_1-logloss:0.59226
# [589]	validation_0-logloss:0.56042	validation_1-logloss:0.59227
# [590]	validation_0-logloss:0.56037	validation_1-logloss:0.59226
# [591]	validation_0-logloss:0.56032	validation_1-logloss:0.59226
# [592]	validation_0-logloss:0.56026	validation_1-logloss:0.59226
# [593]	validation_0-logloss:0.56018	validation_1-logloss:0.59223
# [594]	validation_0-logloss:0.56013	validation_1-logloss:0.59224
# [595]	validation_0-logloss:0.56006	validation_1-logloss:0.59223
# [596]	validation_0-logloss:0.55999	validation_1-logloss:0.59221
# [597]	validation_0-logloss:0.55993	validation_1-logloss:0.59222
# [598]	validation_0-logloss:0.55987	validation_1-logloss:0.59223
# [599]	validation_0-logloss:0.55982	validation_1-logloss:0.59223
# [600]	validation_0-logloss:0.55976	validation_1-logloss:0.59225
# [601]	validation_0-logloss:0.55972	validation_1-logloss:0.59224
# [602]	validation_0-logloss:0.55959	validation_1-logloss:0.59217
# [603]	validation_0-logloss:0.55955	validation_1-logloss:0.59216
# [604]	validation_0-logloss:0.55948	validation_1-logloss:0.59214
# [605]	validation_0-logloss:0.55942	validation_1-logloss:0.59215
# [606]	validation_0-logloss:0.55937	validation_1-logloss:0.59215
# [607]	validation_0-logloss:0.55931	validation_1-logloss:0.59216
# [608]	validation_0-logloss:0.55925	validation_1-logloss:0.59216
# [609]	validation_0-logloss:0.55919	validation_1-logloss:0.59216
# [610]	validation_0-logloss:0.55912	validation_1-logloss:0.59213
# [611]	validation_0-logloss:0.55908	validation_1-logloss:0.59213
# [612]	validation_0-logloss:0.55903	validation_1-logloss:0.59213
# [613]	validation_0-logloss:0.55898	validation_1-logloss:0.59214
# [614]	validation_0-logloss:0.55892	validation_1-logloss:0.59212
# [615]	validation_0-logloss:0.55889	validation_1-logloss:0.59212
# [616]	validation_0-logloss:0.55883	validation_1-logloss:0.59212
# [617]	validation_0-logloss:0.55878	validation_1-logloss:0.59212
# [618]	validation_0-logloss:0.55873	validation_1-logloss:0.59212
# [619]	validation_0-logloss:0.55867	validation_1-logloss:0.59213
# [620]	validation_0-logloss:0.55862	validation_1-logloss:0.59214
# [621]	validation_0-logloss:0.55849	validation_1-logloss:0.59205
# [622]	validation_0-logloss:0.55843	validation_1-logloss:0.59204
# [623]	validation_0-logloss:0.55836	validation_1-logloss:0.59205
# [624]	validation_0-logloss:0.55828	validation_1-logloss:0.59205
# [625]	validation_0-logloss:0.55822	validation_1-logloss:0.59204
# [626]	validation_0-logloss:0.55816	validation_1-logloss:0.59203
# [627]	validation_0-logloss:0.55810	validation_1-logloss:0.59200
# [628]	validation_0-logloss:0.55803	validation_1-logloss:0.59199
# [629]	validation_0-logloss:0.55797	validation_1-logloss:0.59198
# [630]	validation_0-logloss:0.55785	validation_1-logloss:0.59192
# [631]	validation_0-logloss:0.55780	validation_1-logloss:0.59192
# [632]	validation_0-logloss:0.55774	validation_1-logloss:0.59193
# [633]	validation_0-logloss:0.55770	validation_1-logloss:0.59193
# [634]	validation_0-logloss:0.55765	validation_1-logloss:0.59193
# [635]	validation_0-logloss:0.55760	validation_1-logloss:0.59193
# [636]	validation_0-logloss:0.55753	validation_1-logloss:0.59191
# [637]	validation_0-logloss:0.55746	validation_1-logloss:0.59192
# [638]	validation_0-logloss:0.55741	validation_1-logloss:0.59193
# [639]	validation_0-logloss:0.55737	validation_1-logloss:0.59193
# [640]	validation_0-logloss:0.55733	validation_1-logloss:0.59190
# [641]	validation_0-logloss:0.55723	validation_1-logloss:0.59186
# [642]	validation_0-logloss:0.55715	validation_1-logloss:0.59183
# [643]	validation_0-logloss:0.55710	validation_1-logloss:0.59183
# [644]	validation_0-logloss:0.55702	validation_1-logloss:0.59181
# [645]	validation_0-logloss:0.55694	validation_1-logloss:0.59176
# [646]	validation_0-logloss:0.55689	validation_1-logloss:0.59176
# [647]	validation_0-logloss:0.55683	validation_1-logloss:0.59175
# [648]	validation_0-logloss:0.55679	validation_1-logloss:0.59177
# [649]	validation_0-logloss:0.55673	validation_1-logloss:0.59176
# [650]	validation_0-logloss:0.55668	validation_1-logloss:0.59176
# [651]	validation_0-logloss:0.55662	validation_1-logloss:0.59176
# [652]	validation_0-logloss:0.55657	validation_1-logloss:0.59178
# [653]	validation_0-logloss:0.55652	validation_1-logloss:0.59178
# [654]	validation_0-logloss:0.55645	validation_1-logloss:0.59177
# [655]	validation_0-logloss:0.55639	validation_1-logloss:0.59176
# [656]	validation_0-logloss:0.55636	validation_1-logloss:0.59176
# [657]	validation_0-logloss:0.55630	validation_1-logloss:0.59175
# [658]	validation_0-logloss:0.55627	validation_1-logloss:0.59175
# [659]	validation_0-logloss:0.55622	validation_1-logloss:0.59175
# [660]	validation_0-logloss:0.55618	validation_1-logloss:0.59174
# [661]	validation_0-logloss:0.55612	validation_1-logloss:0.59174
# [662]	validation_0-logloss:0.55606	validation_1-logloss:0.59176
# [663]	validation_0-logloss:0.55600	validation_1-logloss:0.59170
# [664]	validation_0-logloss:0.55595	validation_1-logloss:0.59171
# [665]	validation_0-logloss:0.55590	validation_1-logloss:0.59172
# [666]	validation_0-logloss:0.55585	validation_1-logloss:0.59171
# [667]	validation_0-logloss:0.55579	validation_1-logloss:0.59171
# [668]	validation_0-logloss:0.55574	validation_1-logloss:0.59171
# [669]	validation_0-logloss:0.55568	validation_1-logloss:0.59171
# [670]	validation_0-logloss:0.55562	validation_1-logloss:0.59170
# [671]	validation_0-logloss:0.55557	validation_1-logloss:0.59170
# [672]	validation_0-logloss:0.55551	validation_1-logloss:0.59170
# [673]	validation_0-logloss:0.55544	validation_1-logloss:0.59170
# [674]	validation_0-logloss:0.55538	validation_1-logloss:0.59169
# [675]	validation_0-logloss:0.55533	validation_1-logloss:0.59169
# [676]	validation_0-logloss:0.55526	validation_1-logloss:0.59166
# [677]	validation_0-logloss:0.55520	validation_1-logloss:0.59166
# [678]	validation_0-logloss:0.55514	validation_1-logloss:0.59164
# [679]	validation_0-logloss:0.55510	validation_1-logloss:0.59164
# [680]	validation_0-logloss:0.55505	validation_1-logloss:0.59164
# [681]	validation_0-logloss:0.55499	validation_1-logloss:0.59165
# [682]	validation_0-logloss:0.55496	validation_1-logloss:0.59166
# [683]	validation_0-logloss:0.55491	validation_1-logloss:0.59167
# [684]	validation_0-logloss:0.55485	validation_1-logloss:0.59167
# [685]	validation_0-logloss:0.55478	validation_1-logloss:0.59168
# [686]	validation_0-logloss:0.55473	validation_1-logloss:0.59166
# [687]	validation_0-logloss:0.55468	validation_1-logloss:0.59168
# [688]	validation_0-logloss:0.55463	validation_1-logloss:0.59169
# [689]	validation_0-logloss:0.55458	validation_1-logloss:0.59169
# [690]	validation_0-logloss:0.55453	validation_1-logloss:0.59169
# [691]	validation_0-logloss:0.55448	validation_1-logloss:0.59169
# [692]	validation_0-logloss:0.55443	validation_1-logloss:0.59171
# [693]	validation_0-logloss:0.55435	validation_1-logloss:0.59167
# [694]	validation_0-logloss:0.55428	validation_1-logloss:0.59169
# [695]	validation_0-logloss:0.55422	validation_1-logloss:0.59169
# [696]	validation_0-logloss:0.55417	validation_1-logloss:0.59168
# [697]	validation_0-logloss:0.55412	validation_1-logloss:0.59168
# [698]	validation_0-logloss:0.55407	validation_1-logloss:0.59168
# [699]	validation_0-logloss:0.55401	validation_1-logloss:0.59168
# [700]	validation_0-logloss:0.55396	validation_1-logloss:0.59167
# [701]	validation_0-logloss:0.55390	validation_1-logloss:0.59169
# [702]	validation_0-logloss:0.55383	validation_1-logloss:0.59169
# [703]	validation_0-logloss:0.55379	validation_1-logloss:0.59169
# [704]	validation_0-logloss:0.55374	validation_1-logloss:0.59169
# [705]	validation_0-logloss:0.55368	validation_1-logloss:0.59170
# [706]	validation_0-logloss:0.55363	validation_1-logloss:0.59171
# [707]	validation_0-logloss:0.55359	validation_1-logloss:0.59171
# [708]	validation_0-logloss:0.55352	validation_1-logloss:0.59170
# [709]	validation_0-logloss:0.55347	validation_1-logloss:0.59170
# [710]	validation_0-logloss:0.55341	validation_1-logloss:0.59168
# [711]	validation_0-logloss:0.55338	validation_1-logloss:0.59168
# [712]	validation_0-logloss:0.55331	validation_1-logloss:0.59168
# [713]	validation_0-logloss:0.55321	validation_1-logloss:0.59163
# [714]	validation_0-logloss:0.55315	validation_1-logloss:0.59165
# [715]	validation_0-logloss:0.55309	validation_1-logloss:0.59165
# [716]	validation_0-logloss:0.55303	validation_1-logloss:0.59166
# [717]	validation_0-logloss:0.55297	validation_1-logloss:0.59165
# [718]	validation_0-logloss:0.55291	validation_1-logloss:0.59165
# [719]	validation_0-logloss:0.55286	validation_1-logloss:0.59166
# [720]	validation_0-logloss:0.55282	validation_1-logloss:0.59165
# [721]	validation_0-logloss:0.55277	validation_1-logloss:0.59165
# [722]	validation_0-logloss:0.55273	validation_1-logloss:0.59165
# [723]	validation_0-logloss:0.55266	validation_1-logloss:0.59164
# [724]	validation_0-logloss:0.55260	validation_1-logloss:0.59163
# [725]	validation_0-logloss:0.55254	validation_1-logloss:0.59164
# [726]	validation_0-logloss:0.55250	validation_1-logloss:0.59163
# [727]	validation_0-logloss:0.55244	validation_1-logloss:0.59163
# [728]	validation_0-logloss:0.55240	validation_1-logloss:0.59161
# [729]	validation_0-logloss:0.55235	validation_1-logloss:0.59161
# [730]	validation_0-logloss:0.55228	validation_1-logloss:0.59163
# [731]	validation_0-logloss:0.55223	validation_1-logloss:0.59161
# [732]	validation_0-logloss:0.55217	validation_1-logloss:0.59162
# [733]	validation_0-logloss:0.55212	validation_1-logloss:0.59164
# [734]	validation_0-logloss:0.55206	validation_1-logloss:0.59163
# [735]	validation_0-logloss:0.55199	validation_1-logloss:0.59163
# [736]	validation_0-logloss:0.55194	validation_1-logloss:0.59164
# [737]	validation_0-logloss:0.55188	validation_1-logloss:0.59165
# [738]	validation_0-logloss:0.55176	validation_1-logloss:0.59157
# [739]	validation_0-logloss:0.55170	validation_1-logloss:0.59155
# [740]	validation_0-logloss:0.55166	validation_1-logloss:0.59155
# [741]	validation_0-logloss:0.55157	validation_1-logloss:0.59152
# [742]	validation_0-logloss:0.55152	validation_1-logloss:0.59152
# [743]	validation_0-logloss:0.55147	validation_1-logloss:0.59152
# [744]	validation_0-logloss:0.55139	validation_1-logloss:0.59152
# [745]	validation_0-logloss:0.55135	validation_1-logloss:0.59151
# [746]	validation_0-logloss:0.55130	validation_1-logloss:0.59150
# [747]	validation_0-logloss:0.55124	validation_1-logloss:0.59152
# [748]	validation_0-logloss:0.55119	validation_1-logloss:0.59153
# [749]	validation_0-logloss:0.55113	validation_1-logloss:0.59153
# [750]	validation_0-logloss:0.55109	validation_1-logloss:0.59153
# ...
# [896]	validation_0-logloss:0.54333	validation_1-logloss:0.59115
# [897]	validation_0-logloss:0.54328	validation_1-logloss:0.59115
# [898]	validation_0-logloss:0.54324	validation_1-logloss:0.59115
# [899]	validation_0-logloss:0.54320	validation_1-logloss:0.59115
# [900]	validation_0-logloss:0.54315	validation_1-logloss:0.59115
# [901]	validation_0-logloss:0.54310	validation_1-logloss:0.59116
# [902]	validation_0-logloss:0.54306	validation_1-logloss:0.59116
# [903]	validation_0-logloss:0.54299	validation_1-logloss:0.59115
# [904]	validation_0-logloss:0.54295	validation_1-logloss:0.59116
# [905]	validation_0-logloss:0.54291	validation_1-logloss:0.59117
# [906]	validation_0-logloss:0.54288	validation_1-logloss:0.59117
# [907]	validation_0-logloss:0.54283	validation_1-logloss:0.59118
# [908]	validation_0-logloss:0.54280	validation_1-logloss:0.59117
# [909]	validation_0-logloss:0.54276	validation_1-logloss:0.59118
# [910]	validation_0-logloss:0.54271	validation_1-logloss:0.59119
# [911]	validation_0-logloss:0.54265	validation_1-logloss:0.59119
# [912]	validation_0-logloss:0.54257	validation_1-logloss:0.59116
# [913]	validation_0-logloss:0.54254	validation_1-logloss:0.59116
# [914]	validation_0-logloss:0.54248	validation_1-logloss:0.59116
# [915]	validation_0-logloss:0.54243	validation_1-logloss:0.59116
# [916]	validation_0-logloss:0.54235	validation_1-logloss:0.59114
# [917]	validation_0-logloss:0.54229	validation_1-logloss:0.59113
# [918]	validation_0-logloss:0.54223	validation_1-logloss:0.59113
# [919]	validation_0-logloss:0.54217	validation_1-logloss:0.59113
# [920]	validation_0-logloss:0.54212	validation_1-logloss:0.59113
# [921]	validation_0-logloss:0.54210	validation_1-logloss:0.59114
# [922]	validation_0-logloss:0.54205	validation_1-logloss:0.59113
# [923]	validation_0-logloss:0.54200	validation_1-logloss:0.59113
# [924]	validation_0-logloss:0.54196	validation_1-logloss:0.59113
# [925]	validation_0-logloss:0.54192	validation_1-logloss:0.59114
# [926]	validation_0-logloss:0.54187	validation_1-logloss:0.59115
# [927]	validation_0-logloss:0.54182	validation_1-logloss:0.59115
# [928]	validation_0-logloss:0.54178	validation_1-logloss:0.59116
# [929]	validation_0-logloss:0.54172	validation_1-logloss:0.59117
# [930]	validation_0-logloss:0.54168	validation_1-logloss:0.59117
# [931]	validation_0-logloss:0.54162	validation_1-logloss:0.59118
# [932]	validation_0-logloss:0.54157	validation_1-logloss:0.59117
# [933]	validation_0-logloss:0.54150	validation_1-logloss:0.59115
# [934]	validation_0-logloss:0.54144	validation_1-logloss:0.59112
# [935]	validation_0-logloss:0.54138	validation_1-logloss:0.59111
# [936]	validation_0-logloss:0.54133	validation_1-logloss:0.59109
# [937]	validation_0-logloss:0.54128	validation_1-logloss:0.59108
# [938]	validation_0-logloss:0.54123	validation_1-logloss:0.59109
# [939]	validation_0-logloss:0.54118	validation_1-logloss:0.59109
# [940]	validation_0-logloss:0.54112	validation_1-logloss:0.59108
# [941]	validation_0-logloss:0.54107	validation_1-logloss:0.59108
# [942]	validation_0-logloss:0.54102	validation_1-logloss:0.59108
# [943]	validation_0-logloss:0.54097	validation_1-logloss:0.59108
# [944]	validation_0-logloss:0.54091	validation_1-logloss:0.59108
# [945]	validation_0-logloss:0.54086	validation_1-logloss:0.59108
# [946]	validation_0-logloss:0.54082	validation_1-logloss:0.59107
# [947]	validation_0-logloss:0.54075	validation_1-logloss:0.59107
# [948]	validation_0-logloss:0.54070	validation_1-logloss:0.59107
# [949]	validation_0-logloss:0.54066	validation_1-logloss:0.59108
# [950]	validation_0-logloss:0.54060	validation_1-logloss:0.59108
# [951]	validation_0-logloss:0.54056	validation_1-logloss:0.59108
# [952]	validation_0-logloss:0.54051	validation_1-logloss:0.59107
# [953]	validation_0-logloss:0.54045	validation_1-logloss:0.59108
# [954]	validation_0-logloss:0.54042	validation_1-logloss:0.59107
# [955]	validation_0-logloss:0.54037	validation_1-logloss:0.59108
# [956]	validation_0-logloss:0.54032	validation_1-logloss:0.59107
# [957]	validation_0-logloss:0.54027	validation_1-logloss:0.59107
# [958]	validation_0-logloss:0.54023	validation_1-logloss:0.59107
# [959]	validation_0-logloss:0.54018	validation_1-logloss:0.59108
# [960]	validation_0-logloss:0.54014	validation_1-logloss:0.59108
# [961]	validation_0-logloss:0.54009	validation_1-logloss:0.59107
# [962]	validation_0-logloss:0.54003	validation_1-logloss:0.59107
# [963]	validation_0-logloss:0.53999	validation_1-logloss:0.59106
# [964]	validation_0-logloss:0.53993	validation_1-logloss:0.59107
# [965]	validation_0-logloss:0.53986	validation_1-logloss:0.59108
# [966]	validation_0-logloss:0.53980	validation_1-logloss:0.59106
# [967]	validation_0-logloss:0.53974	validation_1-logloss:0.59103
# [968]	validation_0-logloss:0.53967	validation_1-logloss:0.59104
# [969]	validation_0-logloss:0.53962	validation_1-logloss:0.59104
# [970]	validation_0-logloss:0.53958	validation_1-logloss:0.59105
# [971]	validation_0-logloss:0.53954	validation_1-logloss:0.59106
# [972]	validation_0-logloss:0.53951	validation_1-logloss:0.59107
# [973]	validation_0-logloss:0.53946	validation_1-logloss:0.59108
# [974]	validation_0-logloss:0.53940	validation_1-logloss:0.59108
# [975]	validation_0-logloss:0.53935	validation_1-logloss:0.59107
# [976]	validation_0-logloss:0.53929	validation_1-logloss:0.59107
# [977]	validation_0-logloss:0.53924	validation_1-logloss:0.59107
# [978]	validation_0-logloss:0.53919	validation_1-logloss:0.59106
# [979]	validation_0-logloss:0.53913	validation_1-logloss:0.59104
# [980]	validation_0-logloss:0.53906	validation_1-logloss:0.59102
# [981]	validation_0-logloss:0.53902	validation_1-logloss:0.59103
# [982]	validation_0-logloss:0.53897	validation_1-logloss:0.59101
# [983]	validation_0-logloss:0.53892	validation_1-logloss:0.59100
# [984]	validation_0-logloss:0.53887	validation_1-logloss:0.59100
# [985]	validation_0-logloss:0.53881	validation_1-logloss:0.59099
# [986]	validation_0-logloss:0.53877	validation_1-logloss:0.59099
# [987]	validation_0-logloss:0.53871	validation_1-logloss:0.59100
# [988]	validation_0-logloss:0.53866	validation_1-logloss:0.59101
# [989]	validation_0-logloss:0.53861	validation_1-logloss:0.59102
# [990]	validation_0-logloss:0.53858	validation_1-logloss:0.59102
# [991]	validation_0-logloss:0.53854	validation_1-logloss:0.59101
# [992]	validation_0-logloss:0.53847	validation_1-logloss:0.59100
# [993]	validation_0-logloss:0.53842	validation_1-logloss:0.59100
# [994]	validation_0-logloss:0.53836	validation_1-logloss:0.59100
# [995]	validation_0-logloss:0.53833	validation_1-logloss:0.59100
# [996]	validation_0-logloss:0.53829	validation_1-logloss:0.59100
# [997]	validation_0-logloss:0.53823	validation_1-logloss:0.59100
# [998]	validation_0-logloss:0.53817	validation_1-logloss:0.59101
# [999]	validation_0-logloss:0.53812	validation_1-logloss:0.59100
# [1000]	validation_0-logloss:0.53806	validation_1-logloss:0.59101
# [1001]	validation_0-logloss:0.53801	validation_1-logloss:0.59100
# [1002]	validation_0-logloss:0.53797	validation_1-logloss:0.59100
# [1003]	validation_0-logloss:0.53792	validation_1-logloss:0.59102
# [1004]	validation_0-logloss:0.53787	validation_1-logloss:0.59103
# [1005]	validation_0-logloss:0.53781	validation_1-logloss:0.59101
# [1006]	validation_0-logloss:0.53777	validation_1-logloss:0.59100
# [1007]	validation_0-logloss:0.53772	validation_1-logloss:0.59100
# [1008]	validation_0-logloss:0.53765	validation_1-logloss:0.59097
# [1009]	validation_0-logloss:0.53759	validation_1-logloss:0.59097
# [1010]	validation_0-logloss:0.53755	validation_1-logloss:0.59096
# [1011]	validation_0-logloss:0.53750	validation_1-logloss:0.59095
# [1012]	validation_0-logloss:0.53747	validation_1-logloss:0.59094
# [1013]	validation_0-logloss:0.53740	validation_1-logloss:0.59093
# [1014]	validation_0-logloss:0.53735	validation_1-logloss:0.59094
# [1015]	validation_0-logloss:0.53730	validation_1-logloss:0.59094
# [1016]	validation_0-logloss:0.53726	validation_1-logloss:0.59095
# [1017]	validation_0-logloss:0.53722	validation_1-logloss:0.59095
# [1018]	validation_0-logloss:0.53717	validation_1-logloss:0.59095
# [1019]	validation_0-logloss:0.53713	validation_1-logloss:0.59096
# [1020]	validation_0-logloss:0.53707	validation_1-logloss:0.59096
# [1021]	validation_0-logloss:0.53702	validation_1-logloss:0.59095
# [1022]	validation_0-logloss:0.53698	validation_1-logloss:0.59096
# [1023]	validation_0-logloss:0.53693	validation_1-logloss:0.59097
# [1024]	validation_0-logloss:0.53689	validation_1-logloss:0.59097
# [1025]	validation_0-logloss:0.53687	validation_1-logloss:0.59098
# [1026]	validation_0-logloss:0.53682	validation_1-logloss:0.59098
# [1027]	validation_0-logloss:0.53676	validation_1-logloss:0.59098
# [1028]	validation_0-logloss:0.53671	validation_1-logloss:0.59096
# [1029]	validation_0-logloss:0.53663	validation_1-logloss:0.59093
# [1030]	validation_0-logloss:0.53657	validation_1-logloss:0.59092
# [1031]	validation_0-logloss:0.53651	validation_1-logloss:0.59092
# [1032]	validation_0-logloss:0.53646	validation_1-logloss:0.59090
# [1033]	validation_0-logloss:0.53641	validation_1-logloss:0.59089
# [1034]	validation_0-logloss:0.53636	validation_1-logloss:0.59089
# [1035]	validation_0-logloss:0.53631	validation_1-logloss:0.59089
# [1036]	validation_0-logloss:0.53626	validation_1-logloss:0.59090
# [1037]	validation_0-logloss:0.53620	validation_1-logloss:0.59090
# [1038]	validation_0-logloss:0.53617	validation_1-logloss:0.59090
# [1039]	validation_0-logloss:0.53614	validation_1-logloss:0.59091
# [1040]	validation_0-logloss:0.53611	validation_1-logloss:0.59091
# [1041]	validation_0-logloss:0.53605	validation_1-logloss:0.59092
# [1042]	validation_0-logloss:0.53599	validation_1-logloss:0.59092
# [1043]	validation_0-logloss:0.53593	validation_1-logloss:0.59091
# [1044]	validation_0-logloss:0.53588	validation_1-logloss:0.59092
# [1045]	validation_0-logloss:0.53583	validation_1-logloss:0.59092
# [1046]	validation_0-logloss:0.53579	validation_1-logloss:0.59092
# [1047]	validation_0-logloss:0.53573	validation_1-logloss:0.59092
# [1048]	validation_0-logloss:0.53567	validation_1-logloss:0.59092
# [1049]	validation_0-logloss:0.53562	validation_1-logloss:0.59092
# [1050]	validation_0-logloss:0.53557	validation_1-logloss:0.59093
# [1051]	validation_0-logloss:0.53552	validation_1-logloss:0.59092
# [1052]	validation_0-logloss:0.53547	validation_1-logloss:0.59094
# [1053]	validation_0-logloss:0.53542	validation_1-logloss:0.59092
# [1054]	validation_0-logloss:0.53537	validation_1-logloss:0.59093
# [1055]	validation_0-logloss:0.53532	validation_1-logloss:0.59093
# [1056]	validation_0-logloss:0.53528	validation_1-logloss:0.59094
# [1057]	validation_0-logloss:0.53520	validation_1-logloss:0.59089
# [1058]	validation_0-logloss:0.53514	validation_1-logloss:0.59087
# [1059]	validation_0-logloss:0.53508	validation_1-logloss:0.59086
# [1060]	validation_0-logloss:0.53504	validation_1-logloss:0.59085
# [1061]	validation_0-logloss:0.53500	validation_1-logloss:0.59084
# [1062]	validation_0-logloss:0.53492	validation_1-logloss:0.59081
# [1063]	validation_0-logloss:0.53487	validation_1-logloss:0.59081
# [1064]	validation_0-logloss:0.53482	validation_1-logloss:0.59080
# [1065]	validation_0-logloss:0.53477	validation_1-logloss:0.59079
# [1066]	validation_0-logloss:0.53472	validation_1-logloss:0.59079
# [1067]	validation_0-logloss:0.53467	validation_1-logloss:0.59079
# [1068]	validation_0-logloss:0.53464	validation_1-logloss:0.59079
# [1069]	validation_0-logloss:0.53459	validation_1-logloss:0.59079
# [1070]	validation_0-logloss:0.53455	validation_1-logloss:0.59079
# [1071]	validation_0-logloss:0.53450	validation_1-logloss:0.59080
# [1072]	validation_0-logloss:0.53445	validation_1-logloss:0.59079
# [1073]	validation_0-logloss:0.53439	validation_1-logloss:0.59080
# [1074]	validation_0-logloss:0.53433	validation_1-logloss:0.59078
# [1075]	validation_0-logloss:0.53427	validation_1-logloss:0.59078
# [1076]	validation_0-logloss:0.53423	validation_1-logloss:0.59078
# [1077]	validation_0-logloss:0.53418	validation_1-logloss:0.59077
# [1078]	validation_0-logloss:0.53413	validation_1-logloss:0.59078
# [1079]	validation_0-logloss:0.53410	validation_1-logloss:0.59078
# [1080]	validation_0-logloss:0.53404	validation_1-logloss:0.59078
# [1081]	validation_0-logloss:0.53399	validation_1-logloss:0.59078
# [1082]	validation_0-logloss:0.53395	validation_1-logloss:0.59078
# [1083]	validation_0-logloss:0.53392	validation_1-logloss:0.59077
# [1084]	validation_0-logloss:0.53386	validation_1-logloss:0.59078
# [1085]	validation_0-logloss:0.53381	validation_1-logloss:0.59077
# [1086]	validation_0-logloss:0.53377	validation_1-logloss:0.59077
# [1087]	validation_0-logloss:0.53373	validation_1-logloss:0.59077
# [1088]	validation_0-logloss:0.53368	validation_1-logloss:0.59076
# [1089]	validation_0-logloss:0.53362	validation_1-logloss:0.59077
# [1090]	validation_0-logloss:0.53358	validation_1-logloss:0.59077
# [1091]	validation_0-logloss:0.53354	validation_1-logloss:0.59076
# [1092]	validation_0-logloss:0.53349	validation_1-logloss:0.59076
# [1093]	validation_0-logloss:0.53344	validation_1-logloss:0.59076
# [1094]	validation_0-logloss:0.53339	validation_1-logloss:0.59076
# [1095]	validation_0-logloss:0.53333	validation_1-logloss:0.59077
# [1096]	validation_0-logloss:0.53328	validation_1-logloss:0.59077
# [1097]	validation_0-logloss:0.53324	validation_1-logloss:0.59077
# [1098]	validation_0-logloss:0.53321	validation_1-logloss:0.59077
# [1099]	validation_0-logloss:0.53317	validation_1-logloss:0.59078
# [1100]	validation_0-logloss:0.53312	validation_1-logloss:0.59078
# [1101]	validation_0-logloss:0.53306	validation_1-logloss:0.59078
# [1102]	validation_0-logloss:0.53300	validation_1-logloss:0.59076
# [1103]	validation_0-logloss:0.53296	validation_1-logloss:0.59076
# [1104]	validation_0-logloss:0.53292	validation_1-logloss:0.59077
# [1105]	validation_0-logloss:0.53288	validation_1-logloss:0.59078
# [1106]	validation_0-logloss:0.53285	validation_1-logloss:0.59080
# [1107]	validation_0-logloss:0.53280	validation_1-logloss:0.59080
# [1108]	validation_0-logloss:0.53276	validation_1-logloss:0.59081
# [1109]	validation_0-logloss:0.53271	validation_1-logloss:0.59082
# [1110]	validation_0-logloss:0.53266	validation_1-logloss:0.59082
# [1111]	validation_0-logloss:0.53261	validation_1-logloss:0.59082
# [1112]	validation_0-logloss:0.53256	validation_1-logloss:0.59083
# [1113]	validation_0-logloss:0.53251	validation_1-logloss:0.59083
# [1114]	validation_0-logloss:0.53247	validation_1-logloss:0.59083
# [1115]	validation_0-logloss:0.53241	validation_1-logloss:0.59084
# [1116]	validation_0-logloss:0.53236	validation_1-logloss:0.59083
# [1117]	validation_0-logloss:0.53232	validation_1-logloss:0.59083
# [1118]	validation_0-logloss:0.53229	validation_1-logloss:0.59083
# [1119]	validation_0-logloss:0.53224	validation_1-logloss:0.59083
# [1120]	validation_0-logloss:0.53220	validation_1-logloss:0.59084
# [1121]	validation_0-logloss:0.53216	validation_1-logloss:0.59086
# [1122]	validation_0-logloss:0.53211	validation_1-logloss:0.59085
# [1123]	validation_0-logloss:0.53205	validation_1-logloss:0.59085
# [1124]	validation_0-logloss:0.53199	validation_1-logloss:0.59085
# [1125]	validation_0-logloss:0.53195	validation_1-logloss:0.59086
# [1126]	validation_0-logloss:0.53190	validation_1-logloss:0.59085
# [1127]	validation_0-logloss:0.53185	validation_1-logloss:0.59085
# [1128]	validation_0-logloss:0.53181	validation_1-logloss:0.59086
# [1129]	validation_0-logloss:0.53175	validation_1-logloss:0.59086
# [1130]	validation_0-logloss:0.53172	validation_1-logloss:0.59086
# [1131]	validation_0-logloss:0.53166	validation_1-logloss:0.59086
# [1132]	validation_0-logloss:0.53163	validation_1-logloss:0.59086
# [1133]	validation_0-logloss:0.53159	validation_1-logloss:0.59086
# [1134]	validation_0-logloss:0.53153	validation_1-logloss:0.59086
# [1135]	validation_0-logloss:0.53148	validation_1-logloss:0.59087
# [1136]	validation_0-logloss:0.53143	validation_1-logloss:0.59087
# [1137]	validation_0-logloss:0.53137	validation_1-logloss:0.59086
# [1138]	validation_0-logloss:0.53131	validation_1-logloss:0.59086
# [1139]	validation_0-logloss:0.53124	validation_1-logloss:0.59083
# [1140]	validation_0-logloss:0.53118	validation_1-logloss:0.59083
# [1141]	validation_0-logloss:0.53113	validation_1-logloss:0.59083
# [1142]	validation_0-logloss:0.53109	validation_1-logloss:0.59083

# %%
# LOAD
classifier_spin = XGBClassifier()
classifier_spin.load_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta03.json")


y_score = classifier_spin.predict_proba(X_test_spin)[:, 1]


fpr, tpr, thresholds = roc_curve(y_test_spin, y_score)
roc_auc = roc_auc_score(y_test_spin, y_score)

print("Global AUC =", roc_auc)


plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + 'saved-results/ROC_classB.pdf', bbox_inches='tight')
plt.show()




keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$',
                #  r'$m_{\mathrm{LQ}}^{\mathrm{reg}}$',
                 r'$S_{\mathrm{Poiss}}$'])

feature_important = classifier_spin.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())


data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=12).remove()
plt.title(r'SLQ vs VLQ', fontsize=14)
# plt.savefig(mainfolder + 'saved-results/XG_feature_importance_classB.pdf', bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Global AUC = 0.74436013024
# [52, 19, 22, 53, 35, 18, 9, 15, 38, 36, 45, 37, 48, 46, 3]

# %%
S_column = X_test_spin[:, -1]

# mSLQ_plot = [1200, 1500, 1800]
# mVLQ_plot = [1600, 1900, 2200]

linestyles = ['-','-','-', '--','--','--', ':', ':', ':']
# colors_SLQ = ['lightcoral', 'red', 'firebrick']
# colors_VLQ = ['limegreen', 'green', 'darkgreen']

plt.figure(figsize=(6,5))

# evaluate per sector
for iit, S_id in enumerate(S_expected_SLQ):
    # if iit == 0 or iit == 1 or iit == 9:
    #     continue
    # else:
    if iit == 2 or iit == 5 or iit == 8:

        mask = (S_column < S_id * 1.1) & (0.9 * S_id < S_column)

        y_true_Spoiss = y_test_spin[mask]
        y_score_Spoiss = y_score[mask]

        fpr, tpr, _ = roc_curve(y_true_Spoiss, y_score_Spoiss)
        auc_sector = roc_auc_score(y_true_Spoiss, y_score_Spoiss)

        print(f"$m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV,   AUC = {auc_sector:.5f}")


        plt.plot(fpr, tpr, color='darkorange', linestyle=linestyles[iit], lw=2, label=f"AUC = {auc_sector:.3f}, $m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV - $m_{{LQ_3^V}}=${masses_VLQ[iit]} GeV")



plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=11.3)
# plt.savefig(mainfolder + 'saved-results/ROC_classB_multi.pdf', bbox_inches='tight')
plt.show()
# Out:
# $m_{LQ_3^S}=$1200 GeV,   AUC = 0.77244
# $m_{LQ_3^S}=$1500 GeV,   AUC = 0.73022
# $m_{LQ_3^S}=$1800 GeV,   AUC = 0.69559

# %% [markdown]
# # JOIN BOTH ML

# %%
# --- Clasificador A: SM vs LQ ---

scoresA_SM = xgb_clf.predict_proba( df_SM_norm )[:,1]

scoresA_SLQ = {}
scoresA_VLQ = {}

m_SLQ = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
m_VLQ = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

S_exp_SLQ = S_expected_SLQ[2:]
S_exp_both = S_mean_fit_both[2:]

for m in m_SLQ:
    scoresA_SLQ[m] = xgb_clf.predict_proba( df_SLQ_norm[m] )[:,1]

for m in m_VLQ:
    scoresA_VLQ[m] = xgb_clf.predict_proba( df_VLQ_norm[m] )[:,1]

# %%
# --- Clasificador B: SLQ vs VLQ ---

X_sm = df_SM_norm

rand_samples_B =np.random.randint(1, S_exp_both[0] + S_std_fit_both[0], size=len(X_sm))

X_sm = np.column_stack([X_sm, rand_samples_B])

scoresB_SM = classifier_spin.predict_proba(X_sm)[:,1]


scoresB_SLQ = {}
scoresB_VLQ = {}

for iit, S_id in enumerate(m_SLQ):

    X_s = df_SLQ_norm[m_SLQ[iit]].values
    X_v = df_VLQ_norm[m_VLQ[iit]].values

    poisson_samples_SLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_s))
    poisson_samples_VLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_v))

    X_s = np.column_stack([X_s, poisson_samples_SLQ])
    X_v = np.column_stack([X_v, poisson_samples_VLQ])

    scoresB_SLQ[m_SLQ[iit]] = classifier_spin.predict_proba(X_s)[:,1]
    scoresB_VLQ[m_VLQ[iit]] = classifier_spin.predict_proba(X_v)[:,1]

# %%
# --- Juntar los scores del clasificador A y B

events_SM = np.column_stack([scoresA_SM, scoresB_SM])

events_SLQ = {}
for m in scoresA_SLQ:
    events_SLQ[m] = np.column_stack([scoresA_SLQ[m], scoresB_SLQ[m]])

events_VLQ = {}
for m in scoresA_VLQ:
    events_VLQ[m] = np.column_stack([scoresA_VLQ[m], scoresB_VLQ[m]])

# %% [markdown]
# #### Define the test statistic

# %%
def compute_test_statistic(scoresA, scoresB, threshold):
    """
    Sum of Log-Likelihood Ratios (LLR)

    T = Sum log (P(VLQ) / P(SLQ))

    P(VLQ) = score SLQ vs VLQ classifier
    P(SLQ) = 1 - score SLQ vs VLQ classifier
    """

    mask = scoresA > threshold

    scoresB_sel = scoresB[mask]

    if len(scoresB_sel) == 0:
        return 0

    eps = 1e-6
    s = np.clip(scoresB_sel, eps, 1-eps)

    T = np.sum(np.log(s/(1-s)))

    return T

# %% [markdown]
# ### For all the masses

# %%
# funcion para generar pseudo experimentos (da los scores de ambos clasificadores para ese pseudo)

def generate_pseudo(events_B, events_S, N_B, N_S):

    sample_B = events_B[np.random.randint(len(events_B), size=N_B)]
    sample_S = events_S[np.random.randint(len(events_S), size=N_S)]

    sample_all = np.vstack([sample_B, sample_S])

    scoresA = sample_all[:,0]
    scoresB = sample_all[:,1]

    return scoresA, scoresB

# %%
B_expected = 45962

S_exp_SLQ = [round(fid_xsec_SLQ_14TeV(mmm, beta) * Lum) for mmm in m_SLQ]
S_exp_VLQ = [round(fid_xsec_VLQ_14TeV(mmm, beta) * Lum) for mmm in m_VLQ]

print('beta = ', beta)
print('\nB_expected: ', B_expected)
print('\nS_exp_SLQ: ', S_exp_SLQ, '   m =', m_SLQ)
print('S_exp_VLQ: ', S_exp_VLQ, '   m =', m_VLQ)
print('S_exp_both: ', S_exp_both)
# Out:
# beta =  0.3
#
# B_expected:  45962
#
# S_exp_SLQ:  [662, 374, 211, 123, 71, 41, 24, 14]    m = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_exp_VLQ:  [709, 416, 243, 146, 87, 53, 32, 20]    m = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_exp_both:  [np.float64(637.595192156881), np.float64(371.73561375364125), np.float64(213.6215378947437), np.float64(127.16842339931799), np.float64(74.34267866823734), np.float64(43.56570701780291), np.float64(25.56971360278366), np.float64(16.418498342051453)]

# %% [markdown]
# #### Distribution of the statistic with only SLQ and only VLQ

# %%
n_pseudo_TRUE = 1000
threshold_A = 0.95

# %%
mu_S = []
mu_V = []

sigma_S = []
sigma_V = []

for S_it in range(len(S_exp_SLQ)):

    print("\n==========================")
    print("S_expected SLQ =", S_exp_SLQ[S_it])
    # print("S_expected VLQ =", S_exp_VLQ[S_it]) # same number of events

    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[S_it]
    mass_VLQ = m_VLQ[S_it]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    for i in range(n_pseudo_TRUE):

        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_exp_SLQ[S_it])

        scoresA, scoresB = generate_pseudo( events_SM, events_SLQ[mass_SLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)


        N_S = np.random.poisson(S_exp_SLQ[S_it]) # same number of events

        scoresA, scoresB = generate_pseudo( events_SM, events_VLQ[mass_VLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

        # Compute the Z of the distributions
    mu_S.append( np.mean(T_SLQ) )
    mu_V.append( np.mean(T_VLQ) )

    sigma_S.append( np.std(T_SLQ) )
    sigma_V.append( np.std(T_VLQ) )

print(mu_S)
print(mu_V)

print(sigma_S)
print(sigma_V)
# Out:
# ==========================
# S_expected SLQ = 662
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
#
# ==========================
# S_expected SLQ = 374
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
#
# ==========================
# S_expected SLQ = 211
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
#
# ==========================
# S_expected SLQ = 123
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
#
# ==========================
# S_expected SLQ = 71
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
#
# ==========================
# S_expected SLQ = 41
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
#
# ==========================
# S_expected SLQ = 24
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
#
# ==========================
# S_expected SLQ = 14
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# [np.float32(-288.84235), np.float32(-173.05922), np.float32(-102.78136), np.float32(-69.24629), np.float32(-48.208187), np.float32(-37.636993), np.float32(-31.912941), np.float32(-28.39318)]
# [np.float32(432.39783), np.float32(202.04846), np.float32(87.1663), np.float32(32.76574), np.float32(5.036908), np.float32(-8.506168), np.float32(-15.947113), np.float32(-18.739492)]
# [np.float32(25.005205), np.float32(19.46708), np.float32(16.01174), np.float32(13.922458), np.float32(12.098428), np.float32(11.443892), np.float32(10.842949), np.float32(10.499192)]
# [np.float32(37.44634), np.float32(27.554157), np.float32(20.327612), np.float32(16.241072), np.float32(13.497287), np.float32(11.93032), np.float32(10.956121), np.float32(10.801657)]

# %%
f_mu_S = interp1d(S_exp_SLQ, mu_S, kind='linear', fill_value="extrapolate")
f_mu_V = interp1d(S_exp_SLQ, mu_V, kind='linear', fill_value="extrapolate")

f_sigma_S = interp1d(S_exp_SLQ, sigma_S, kind='linear', fill_value="extrapolate")
f_sigma_V = interp1d(S_exp_SLQ, sigma_V, kind='linear', fill_value="extrapolate")



S_plot = np.linspace(min(S_exp_SLQ), max(S_exp_SLQ), 100)



plt.scatter(S_exp_SLQ, mu_S, marker='o')
plt.plot(S_plot, f_mu_S(S_plot))
plt.scatter(S_exp_SLQ, mu_V, marker='o')
plt.plot(S_plot, f_mu_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\mu$", fontsize=14)

plt.grid()
plt.show()


plt.scatter(S_exp_SLQ, sigma_S, marker='o')
plt.plot(S_plot, f_sigma_S(S_plot))
plt.scatter(S_exp_SLQ, sigma_V, marker='o')
plt.plot(S_plot, f_sigma_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\sigma$", fontsize=14)

plt.grid()
plt.show()

# %%
Z_threshold = 5

results_Z_gauss = []

for pair_it in range(len(mu_S)):
    Z = abs(mu_V[pair_it] - mu_S[pair_it]) / np.sqrt(sigma_S[pair_it]**2 + sigma_V[pair_it]**2)

    results_Z_gauss.append(Z)


plt.plot(S_exp_SLQ, results_Z_gauss, marker='o')

plt.xlabel("Expected signal events", fontsize=14)
plt.ylabel("Distribution discrimination Z", fontsize=14)

plt.grid()
plt.show()


#  interpolate
f_results_Z = interp1d(S_exp_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mSLQ = interp1d(m_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mVLQ = interp1d(m_VLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")


# find the S or the mass such that we get Z_threshold
S_threshold = fsolve(lambda x: f_results_Z(x) - Z_threshold,150)[0]
mSLQ_threshold = fsolve(lambda x: f_results_Z_mSLQ(x) - Z_threshold,1500)[0]
mVLQ_threshold = fsolve(lambda x: f_results_Z_mVLQ(x) - Z_threshold,1900)[0]

print(' Z:       ', Z_threshold)
print(' S:       ', S_threshold)
print(' m_SLQ:   ', mSLQ_threshold, ' [GeV]')
print(' m_VLQ:   ', mVLQ_threshold, ' [GeV]\n')
# Out:
#  Z:        5
#  S:        130.91252143319073
#  m_SLQ:    1491.0084983713741  [GeV]
#  m_VLQ:    1891.0084983713741  [GeV]
# /tmp/ipykernel_3040/699503059.py:28: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   mSLQ_threshold = fsolve(lambda x: f_results_Z_mSLQ(x) - Z_threshold,1500)[0]
# /tmp/ipykernel_3040/699503059.py:29: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   mVLQ_threshold = fsolve(lambda x: f_results_Z_mVLQ(x) - Z_threshold,1900)[0]

# %% [markdown]
# #### Prepare the data

# %% [markdown]
# ##### To compute S_expected for each pseudo using the 1st classifier we need the PDFs

# %%
# --- Clasificador A: SM vs LQ ---

# output of all the signal events
scoresA_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]



bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scoresA_SM, bins=bins, density=True)
hist_S, _ = np.histogram(scoresA_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %% [markdown]
# ##### to compute the closest mass/index/bechmark

# %%
def search_bench(S_pseudo, S_list_means, S_list_std, masses_list=None):
    """ finds the index of the closest benchmark

    Inputs:
    -----------
    S_pseudo : float -> S computed or fitted (e.g. muS_fits_SLQ[i]).
    S_list_means : list/array -> S_mean_fit_both_NEW.
    S_list_std : list/array -> S_std_fit_both_NEW.
    masses_list : list/array (optional) -> masses_NEW.

    Outputs:
    --------
    if masses_list es None -> returns only the index
    if masses_list se incluye -> returns (index, closest mass).
    """
    # convert to array
    means = np.array(S_list_means)
    stds = np.array(S_list_std)

    # do not divide by 0
    stds = np.where(stds == 0, 1e-10, stds)

    # compute the distance to the means, weighted by the std
    z_scores = np.abs(S_pseudo - means) / stds

    # seach the closest index
    idx_min = np.argmin(z_scores)

    # if you also want the mass
    if masses_list is not None:
        best_mass = masses_list[idx_min]
        return idx_min, best_mass

    return idx_min

# %% [markdown]
# ### Super loop

# %%
Z_threshold = 1.96

n_pseudo = 1000

# benchmarks
classification_SLQ_BPOK = []
classification_VLQ_BPOK = []

# interpolate
classification_SLQ_inter = []
classification_VLQ_inter = []

# previously known PDFs
classification_SLQ_prev = []
classification_VLQ_prev = []


Z_SLQ_BPOK = []
Z_VLQ_BPOK = []

Z_SLQ_inter = []
Z_VLQ_inter = []

Z_SLQ_prev = []
Z_VLQ_prev = []


mu_TSLQ = []
std_TSLQ = []
mu_TVLQ = []
std_TVLQ = []



for ii_S, S_exp in enumerate(S_exp_SLQ):

    print("\n==========================")

    print("S_expected_SLQ =", S_exp_SLQ[ii_S])
    # print("S_expected_VLQ =", S_exp_VLQ[ii_S]) # same number of events


    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[ii_S]
    mass_VLQ = m_VLQ[ii_S]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    # compute the number of events
    muS_fits_SLQ = []
    muS_fits_VLQ = []


    for i in range(n_pseudo):

        N_B = np.random.poisson(B_expected)

        # indices of the events
        idx_B = np.random.choice(len(events_SM[:,0]), N_B)

        scoresA_B = events_SM[:,0][idx_B]
        scoresB_B = events_SM[:,1][idx_B]



        ###########
        # FOR SLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S])

        # indices of the events
        idx_S = np.random.choice(len(events_SLQ[mass_SLQ][:,0]), N_S)

        scoresA_S = events_SLQ[mass_SLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_SLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_S = df_SLQ_norm[mass_SLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_S = np.column_stack([X_pseudo_S, np.full(len(X_pseudo_S), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_S)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)




        ###########
        # FOR VLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S]) # same number of events

        # indices of the events
        idx_S = np.random.choice(len(events_VLQ[mass_VLQ][:,0]), N_S)

        scoresA_S = events_VLQ[mass_VLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_VLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_V = df_VLQ_norm[mass_VLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_V = np.column_stack([X_pseudo_V, np.full(len(X_pseudo_V), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_V)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

    # Compute the characteristics of the psedo-experiment T distributions
    mu_TSLQ.append( np.mean(T_SLQ) )
    mu_TVLQ.append( np.mean(T_VLQ) )

    std_TSLQ.append( np.std(T_SLQ) )
    std_TVLQ.append( np.std(T_VLQ) )




    # rango común para plotear
    xmin = min(np.min(T_SLQ), np.min(T_VLQ))
    xmax = max(np.max(T_SLQ), np.max(T_VLQ))
    x = np.linspace(xmin, xmax, 500)

    # gaussianas
    gauss_S = (1/(sigma_S[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_S[ii_S])**2 / (2*sigma_S[ii_S]**2))
    gauss_V = (1/(sigma_V[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_V[ii_S])**2 / (2*sigma_V[ii_S]**2))


    # plot gaussian PDFs + pseudo-experiments (of the same sector) distributions
    plt.figure(figsize=(6,5))

    plt.hist(T_SLQ, bins=20, density=True, color='red', alpha=0.6, label="SLQ pseudos")
    plt.hist(T_VLQ, bins=20, density=True, color='green', alpha=0.6, label="VLQ pseudos")

    # gaussianas
    plt.plot(x, gauss_S, color='darkred', linewidth=2, linestyle='--', label=f"Gaussian SLQ true\nμ={mu_S[ii_S]:.2f}, σ={sigma_S[ii_S]:.2f}")
    plt.plot(x, gauss_V, color='darkgreen', linewidth=2, linestyle='--', label=f"Gaussian VLQ true\nμ={mu_V[ii_S]:.2f}, σ={sigma_V[ii_S]:.2f}")

    plt.xlabel("Test statistic T")
    plt.ylabel("Probability density")
    plt.title(f"S_expected = {S_exp}")
    plt.legend()

    plt.show()


    plt.hist(muS_fits_SLQ, bins=10, histtype='step', linestyle='--', edgecolor='red', linewidth=2, density=True)
    plt.hist(muS_fits_SLQ, bins=10, color='red', alpha=0.6, density=True)
    plt.hist(muS_fits_VLQ, bins=10, histtype='step', linestyle=':', edgecolor='green', linewidth=2, density=True)
    plt.hist(muS_fits_VLQ, bins=10, color='green', alpha=0.6, density=True)
    plt.xlabel("S")
    plt.ylabel("Fraction (prediction)")
    plt.show()

    print('S mean SLQ: ', np.mean(muS_fits_SLQ))
    print('S std SLQ: ', np.std(muS_fits_SLQ))
    print('S mean VLQ: ', np.mean(muS_fits_VLQ))
    print('S std VLQ: ', np.std(muS_fits_VLQ))
    print('')


    # COMPARING WITH DISCRETE MASS EXAMPLES (following S)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_BPOK_step = []
    Z_VLQ_BPOK_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        index_pseudo = search_bench(muS_fits_SLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_SLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        index_pseudo = search_bench(muS_fits_VLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_VLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_BPOK.append(np.array(Z_SLQ_BPOK_step))
    Z_VLQ_BPOK.append(np.array(Z_VLQ_BPOK_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH DISCRETE MASS EXAMPLES (following S) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_BPOK.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_BPOK.append(pred_counts_VLQ)





    # COMPARING WITH CONTINUOUS MASSES (interpolation)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_inter_step = []
    Z_VLQ_inter_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_SLQ[i])) / f_sigma_S(muS_fits_SLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_SLQ[i])) / f_sigma_V(muS_fits_SLQ[i])

        Z_SLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_VLQ[i])) / f_sigma_S(muS_fits_VLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_VLQ[i])) / f_sigma_V(muS_fits_VLQ[i])

        Z_VLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_inter.append(np.array(Z_SLQ_inter_step))
    Z_VLQ_inter.append(np.array(Z_VLQ_inter_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH CONTINUOUS MASSES (interpolation) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_inter.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_inter.append(pred_counts_VLQ)





    # COMPARING WITH THE PREVIOUSLY KNOWN PDF

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_prev_step = []
    Z_VLQ_prev_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_SLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_VLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_prev.append(np.array(Z_SLQ_prev_step))
    Z_VLQ_prev.append(np.array(Z_VLQ_prev_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH THE PREVIOUSLY KNOWN PDF ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_prev.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_prev.append(pred_counts_VLQ)
# Out:
# ==========================
# S_expected_SLQ = 662
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
# S mean SLQ:  612.1917812848793
# S std SLQ:  31.26054320776198
# S mean VLQ:  659.2990785332569
# S std VLQ:  28.61008308528269
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.813
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.187
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.694
# 2 = both     : 0.0
# 3 = neither  : 0.306
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.618
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.382
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.884
# 2 = both     : 0.0
# 3 = neither  : 0.116
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.906
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.094
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.8
# 2 = both     : 0.0
# 3 = neither  : 0.2
#
# ==========================
# S_expected_SLQ = 374
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
# S mean SLQ:  362.41989570953535
# S std SLQ:  23.789714742026028
# S mean VLQ:  378.87211465784605
# S std VLQ:  22.384528954445074
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.941
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.059
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.895
# 2 = both     : 0.0
# 3 = neither  : 0.105
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.939
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.061
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.963
# 2 = both     : 0.0
# 3 = neither  : 0.037
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.945
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.055
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.899
# 2 = both     : 0.0
# 3 = neither  : 0.101
#
# ==========================
# S_expected_SLQ = 211
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
# S mean SLQ:  211.09401069145457
# S std SLQ:  17.904726878226036
# S mean VLQ:  215.7238404841087
# S std VLQ:  18.917318567928405
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.962
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.038
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.889
# 2 = both     : 0.0
# 3 = neither  : 0.111
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.932
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.068
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.96
# 2 = both     : 0.0
# 3 = neither  : 0.04
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.962
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.038
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.882
# 2 = both     : 0.0
# 3 = neither  : 0.118
#
# ==========================
# S_expected_SLQ = 123
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
# S mean SLQ:  127.82246934487816
# S std SLQ:  16.78424627040417
# S mean VLQ:  128.00848773795613
# S std VLQ:  16.34620542558145
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.936
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.064
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.911
# 2 = both     : 0.0
# 3 = neither  : 0.089
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.942
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.058
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.935
# 2 = both     : 0.0
# 3 = neither  : 0.065
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.963
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.037
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.9
# 2 = both     : 0.0
# 3 = neither  : 0.1
#
# ==========================
# S_expected_SLQ = 71
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
# S mean SLQ:  75.35383665430959
# S std SLQ:  14.767913630014249
# S mean VLQ:  74.16366517876918
# S std VLQ:  14.599159659995168
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.918
# 1 = VLQ only : 0.008
# 2 = both     : 0.006
# 3 = neither  : 0.068
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.009
# 1 = VLQ only : 0.917
# 2 = both     : 0.019
# 3 = neither  : 0.055
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.932
# 1 = VLQ only : 0.009
# 2 = both     : 0.004
# 3 = neither  : 0.055
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.011
# 1 = VLQ only : 0.924
# 2 = both     : 0.014
# 3 = neither  : 0.051
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.958
# 1 = VLQ only : 0.014
# 2 = both     : 0.0
# 3 = neither  : 0.028
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.015
# 1 = VLQ only : 0.938
# 2 = both     : 0.0
# 3 = neither  : 0.047
#
# ==========================
# S_expected_SLQ = 41
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
# S mean SLQ:  44.06569004637483
# S std SLQ:  13.48864377755652
# S mean VLQ:  43.13076078569044
# S std VLQ:  13.341832634678148
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.638
# 1 = VLQ only : 0.032
# 2 = both     : 0.299
# 3 = neither  : 0.031
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.022
# 1 = VLQ only : 0.629
# 2 = both     : 0.31
# 3 = neither  : 0.039
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.658
# 1 = VLQ only : 0.042
# 2 = both     : 0.281
# 3 = neither  : 0.019
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.026
# 1 = VLQ only : 0.645
# 2 = both     : 0.3
# 3 = neither  : 0.029
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.65
# 1 = VLQ only : 0.027
# 2 = both     : 0.302
# 3 = neither  : 0.021
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.023
# 1 = VLQ only : 0.654
# 2 = both     : 0.294
# 3 = neither  : 0.029
#
# ==========================
# S_expected_SLQ = 24
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
# S mean SLQ:  26.924858942090285
# S std SLQ:  12.646755784813623
# S mean VLQ:  25.9347027280654
# S std VLQ:  12.82364907325587
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.323
# 1 = VLQ only : 0.057
# 2 = both     : 0.602
# 3 = neither  : 0.018
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.031
# 1 = VLQ only : 0.368
# 2 = both     : 0.577
# 3 = neither  : 0.024
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.321
# 1 = VLQ only : 0.049
# 2 = both     : 0.612
# 3 = neither  : 0.018
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.033
# 1 = VLQ only : 0.35
# 2 = both     : 0.592
# 3 = neither  : 0.025
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.265
# 1 = VLQ only : 0.029
# 2 = both     : 0.686
# 3 = neither  : 0.02
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.021
# 1 = VLQ only : 0.317
# 2 = both     : 0.624
# 3 = neither  : 0.038
#
# ==========================
# S_expected_SLQ = 14
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# S mean SLQ:  16.87241212111066
# S std SLQ:  11.139394693159392
# S mean VLQ:  15.743717198020429
# S std VLQ:  10.82211346694484
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.153
# 1 = VLQ only : 0.042
# 2 = both     : 0.788
# 3 = neither  : 0.017
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.041
# 1 = VLQ only : 0.188
# 2 = both     : 0.753
# 3 = neither  : 0.018
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.138
# 1 = VLQ only : 0.036
# 2 = both     : 0.8
# 3 = neither  : 0.026
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.035
# 1 = VLQ only : 0.156
# 2 = both     : 0.787
# 3 = neither  : 0.022
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.09
# 1 = VLQ only : 0.02
# 2 = both     : 0.857
# 3 = neither  : 0.033
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.028
# 1 = VLQ only : 0.138
# 2 = both     : 0.806
# 3 = neither  : 0.028

# %%
def Z_processor(lista_Z, select):
    """computes the median and error (percentiles 16 y 84)
    select = 1 ---> SLQ (true) vs VLQ
    select = 0 ---> VLQ (true) vs SLQ
    """
    medians = []
    err_inf = []
    err_sup = []

    for z_matriz in lista_Z:
        z_valores = z_matriz[:, select]
        med = np.median(z_valores)
        p16 = np.percentile(z_valores, 16)
        p84 = np.percentile(z_valores, 84)

        medians.append(med)
        err_inf.append(med - p16)  # percentile
        err_sup.append(p84 - med)  # percentile

    return np.array(medians), [np.array(err_inf), np.array(err_sup)]

# Compute
z_BPOK_SLQ, err_BPOK_SLQ = Z_processor(Z_SLQ_BPOK, select=1)
z_BPOK_VLQ, err_BPOK_VLQ = Z_processor(Z_VLQ_BPOK, select=0)
z_inter_SLQ, err_inter_SLQ = Z_processor(Z_SLQ_inter, select=1)
z_inter_VLQ, err_inter_VLQ = Z_processor(Z_VLQ_inter, select=0)
z_prev_SLQ, err_prev_SLQ = Z_processor(Z_SLQ_prev, select=1)
z_prev_VLQ, err_prev_VLQ = Z_processor(Z_VLQ_prev, select=0)



# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(m_SLQ), z_BPOK_SLQ, err_BPOK_SLQ)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(m_VLQ), z_BPOK_VLQ, err_BPOK_VLQ)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(m_SLQ), z_inter_SLQ, err_inter_SLQ)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(m_VLQ), z_inter_VLQ, err_inter_VLQ)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(m_SLQ), z_prev_SLQ, err_prev_SLQ)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(m_VLQ), z_prev_VLQ, err_prev_VLQ)


# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')


# PLOT
plt.figure(figsize=(7, 6))

plt.errorbar(m_SLQ, z_BPOK_SLQ, yerr=err_BPOK_SLQ, color='red', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Benchmarks)')
plt.errorbar(m_VLQ, z_BPOK_VLQ, yerr=err_BPOK_VLQ, color='green', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Benchmarks)')
plt.errorbar(m_SLQ, z_inter_SLQ, yerr=err_inter_SLQ, color='darkred', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Interpolated)')
plt.errorbar(m_VLQ, z_inter_VLQ, yerr=err_inter_VLQ, color='darkgreen', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Interpolated)')
plt.errorbar(m_SLQ, z_prev_SLQ, yerr=err_prev_SLQ, color='pink', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Known PDF)')
plt.errorbar(m_VLQ, z_prev_VLQ, yerr=err_prev_VLQ, color='lime', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Known PDF)')

plt.axhline(y=5.0, color='blue', linestyle='-', linewidth=1.5, label='5σ')

# plt.ylim(0, 25)
plt.xlabel(r"$m_{LQ}$ [GeV]", fontsize=12)
plt.ylabel(r"$Z$", fontsize=12)
plt.grid(True)
plt.legend(fontsize=12, loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1556.6566566566567 [GeV]      ( 1519.5195195195195 - 1595.8958958958958 )
# VLQ mass:  1979.079079079079 [GeV]      ( 1937.037037037037 - 2032.3323323323323 )
#
# Interpolated
# SLQ mass:  1559.4594594594594 [GeV]      ( 1521.6216216216217 - 1600.1001001001 )
# VLQ mass:  1980.4804804804805 [GeV]      ( 1936.3363363363364 - 2034.4344344344345 )
#
# Known PDF
# SLQ mass:  1553.1531531531532 [GeV]      ( 1520.2202202202202 - 1591.6916916916916 )
# VLQ mass:  1977.6776776776776 [GeV]      ( 1938.4384384384384 - 2026.026026026026 )

# %%
class_SLQ_BPOK_array = np.array(classification_SLQ_BPOK) # Forma (N, 4)
class_VLQ_BPOK_array = np.array(classification_VLQ_BPOK) # Forma (N, 4)

class_SLQ_inter_array = np.array(classification_SLQ_inter) # Forma (N, 4)
class_VLQ_inter_array = np.array(classification_VLQ_inter) # Forma (N, 4)

class_SLQ_prev_array = np.array(classification_SLQ_prev) # Forma (N, 4)
class_VLQ_prev_array = np.array(classification_VLQ_prev) # Forma (N, 4)

# SAVE

file_path = mainfolder + 'saved-results/vs14TeV_err_beta03.txt'

# Combine all data into a single array
data_to_save = np.column_stack([
    S_expected_SLQ[2:],
    m_SLQ,
    m_VLQ,
    mu_S,
    sigma_S,
    mu_V,
    sigma_V,
    mu_TSLQ,
    std_TSLQ,
    mu_TVLQ,
    std_TVLQ,
    class_SLQ_BPOK_array,
    class_VLQ_BPOK_array,
    class_SLQ_inter_array,
    class_VLQ_inter_array,
    class_SLQ_prev_array,
    class_VLQ_prev_array,
    z_BPOK_SLQ,
    err_BPOK_SLQ[0],
    err_BPOK_SLQ[1],
    z_BPOK_VLQ,
    err_BPOK_VLQ[0],
    err_BPOK_VLQ[1],
    z_inter_SLQ,
    err_inter_SLQ[0],
    err_inter_SLQ[1],
    z_inter_VLQ,
    err_inter_VLQ[0],
    err_inter_VLQ[1],
    z_prev_SLQ,
    err_prev_SLQ[0],
    err_prev_SLQ[1],
    z_prev_VLQ,
    err_prev_VLQ[0],
    err_prev_VLQ[1],
])

# Save data to a text file
np.savetxt(file_path, data_to_save, fmt='%.6f',
           header='# S_expected mass_list_SLQ mass_list_SLQ mu_S sigma_S mu_V sigma_V mu_TSLQ std_TSLQ mu_TVLQ std_TVLQ classification_SLQ classification_VLQ',
           comments='')

print(f"Data saved to: {file_path}")
# Out:
# Data saved to: /content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/saved-results/vs14TeV_err_beta03.txt

# %%
# LOAD

file_path = mainfolder + 'saved-results/vs14TeV_err_beta03.txt'

loaded_data = np.loadtxt(file_path)

S_expected = loaded_data[:, 0]
mass_list_SLQ = loaded_data[:, 1]
mass_list_VLQ = loaded_data[:, 2]
mu_S = loaded_data[:, 3]
sigma_S = loaded_data[:, 4]
mu_V = loaded_data[:, 5]
sigma_V = loaded_data[:, 6]
mu_TSLQ = loaded_data[:, 7]
std_TSLQ = loaded_data[:, 8]
mu_TVLQ = loaded_data[:, 9]
std_TVLQ = loaded_data[:, 10]
classification_SLQ_BPOK = loaded_data[:, 11:15]
classification_VLQ_BPOK = loaded_data[:, 15:19]
classification_SLQ_inter = loaded_data[:, 19:23]
classification_VLQ_inter = loaded_data[:, 23:27]
classification_SLQ_prev = loaded_data[:, 27:31]
classification_VLQ_prev = loaded_data[:, 31:35]
z_BPOK_SLQ = loaded_data[:, 35]
err_BPOK_SLQ = np.concatenate([loaded_data[:, 36], loaded_data[:, 37]])
z_BPOK_VLQ = loaded_data[:, 38]
err_BPOK_VLQ = np.concatenate([loaded_data[:, 39], loaded_data[:, 40]])
z_inter_SLQ = loaded_data[:, 41]
err_inter_SLQ = np.concatenate([loaded_data[:, 42], loaded_data[:, 43]])
z_inter_VLQ = loaded_data[:, 44]
err_inter_VLQ = np.concatenate([loaded_data[:, 45], loaded_data[:, 46]])
z_prev_SLQ = loaded_data[:, 47]
err_prev_SLQ = np.concatenate([loaded_data[:, 48], loaded_data[:, 49]])
z_prev_VLQ = loaded_data[:, 50]
err_prev_VLQ = np.concatenate([loaded_data[:, 51], loaded_data[:, 52]])





n_pseudo_TRUE = 1000
threshold_A = 0.95

print('n_pseudo_TRUE: ', n_pseudo_TRUE)
print('threshold_A: ', threshold_A)
# Out:
# n_pseudo_TRUE:  1000
# threshold_A:  0.95

# %%
# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_BPOK_SLQ, err_BPOK_SLQ, z_target=5.0)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_BPOK_VLQ, err_BPOK_VLQ, z_target=5.0)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_inter_SLQ, err_inter_SLQ, z_target=5.0)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_inter_VLQ, err_inter_VLQ, z_target=5.0)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_prev_SLQ, err_prev_SLQ, z_target=5.0)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_prev_VLQ, err_prev_VLQ, z_target=5.0)

# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1556.6566566566567 [GeV]      ( 1527.227227227227 - 1585.3853853853852 )
# VLQ mass:  1979.079079079079 [GeV]      ( 1910.4104104104103 - 2048.4484484484483 )
#
# Interpolated
# SLQ mass:  1559.4594594594594 [GeV]      ( 1530.03003003003 - 1590.990990990991 )
# VLQ mass:  1980.4804804804805 [GeV]      ( 1916.016016016016 - 2049.1491491491493 )
#
# Known PDF
# SLQ mass:  1553.1531531531532 [GeV]      ( 1524.4244244244244 - 1581.8818818818818 )
# VLQ mass:  1977.6776776776776 [GeV]      ( 1909.7097097097096 - 2044.9449449449448 )

# %%
# LOAD

file_path = mainfolder + 'saved-results/Z13TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_13TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_13TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_13TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_13TeV = loaded_data[:, 4]
m_BL_exc_SLQ_13TeV = loaded_data[:, 5]
m_BL_dis_SLQ_13TeV = loaded_data[:, 6]
m_BL_exc_VLQ_13TeV = loaded_data[:, 7]
m_BL_dis_VLQ_13TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_13TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_13TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_13TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_13TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_13TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_13TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_13TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_13TeV = loaded_data[:, 16]


# LOAD

file_path = mainfolder + 'saved-results/Z136TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_136TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_136TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_136TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_136TeV = loaded_data[:, 4]
m_BL_exc_SLQ_136TeV = loaded_data[:, 5]
m_BL_dis_SLQ_136TeV = loaded_data[:, 6]
m_BL_exc_VLQ_136TeV = loaded_data[:, 7]
m_BL_dis_VLQ_136TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_136TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_136TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_136TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_136TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_136TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_136TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_136TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_136TeV = loaded_data[:, 16]




# LOAD

file_path = mainfolder + 'saved-results/Z14TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_14TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_14TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_14TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_14TeV = loaded_data[:, 4]
m_BL_exc_SLQ_14TeV = loaded_data[:, 5]
m_BL_dis_SLQ_14TeV = loaded_data[:, 6]
m_BL_exc_VLQ_14TeV = loaded_data[:, 7]
m_BL_dis_VLQ_14TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_14TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_14TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_14TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_14TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_14TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_14TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_14TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_14TeV = loaded_data[:, 16]

# %%
# plot BINNED LIKEHOOD

plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_SLQ_13TeV, betas, 'o:', c='red', label='13 TeV, 139 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_high_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_14TeV, betas, 'o-', c='red', label='14 TeV, 3000 fb-1 (Dis SLQ)')
plt.plot(m_BL_dis_SLQ_low_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_high_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_14TeV, betas, 'o--', c='red', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_14TeV, betas, '--', c='red', alpha=0.25)
plt.plot(m_BL_exc_SLQ_high_14TeV, betas, '--', c='red', alpha=0.25)


# benchmarks
m_SLQ_T_Z5 = [[m5_BPOK_SLQ - m5_BPOK_SLQ_inf], [m5_BPOK_SLQ_sup - m5_BPOK_SLQ]]
plt.errorbar(m5_BPOK_SLQ, 0.34, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (BP)')

# interpolated
m_SLQ_T_Z5 = [[m5_inter_SLQ - m5_inter_SLQ_inf], [m5_inter_SLQ_sup - m5_inter_SLQ]]
plt.errorbar(m5_inter_SLQ, 0.3, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (interpolated)')

# known pdf
m_SLQ_T_Z5 = [[m5_prev_SLQ - m5_prev_SLQ_inf], [m5_prev_SLQ_sup - m5_prev_SLQ]]
plt.errorbar(m5_prev_SLQ, 0.26, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()





plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_VLQ_13TeV, betas, 'o:', c='green', label='13 TeV, 139 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_high_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_14TeV, betas, 'o-', c='green', label='14 TeV, 3000 fb-1 (Dis VLQ)')
plt.plot(m_BL_dis_VLQ_low_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_high_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_14TeV, betas, 'o--', c='green', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_14TeV, betas, '-', c='green', alpha=0.25)
plt.plot(m_BL_exc_VLQ_high_14TeV, betas, '-', c='green', alpha=0.25)


# benchmarks
m_VLQ_T_Z5 = [[m5_BPOK_VLQ - m5_BPOK_VLQ_inf], [m5_BPOK_VLQ_sup - m5_BPOK_VLQ]]
plt.errorbar(m5_BPOK_VLQ, 0.34, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (BP)')

# interpolated
m_VLQ_T_Z5 = [[m5_inter_VLQ - m5_inter_VLQ_inf], [m5_inter_VLQ_sup - m5_inter_VLQ]]
plt.errorbar(m5_inter_VLQ, 0.3, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (interpolated)')

# knwon pdf
m_VLQ_T_Z5 = [[m5_prev_VLQ - m5_prev_VLQ_inf], [m5_prev_VLQ_sup - m5_prev_VLQ]]
plt.errorbar(m5_prev_VLQ, 0.26, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
