# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mainfolder = '/content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec

import os
import joblib  # to save the scaler

from numba import njit # for the LQ mass reconstruction

from scipy.optimize import fsolve, minimize
from scipy import stats
from scipy.stats import poisson
from scipy.stats import ks_2samp
from scipy.stats import anderson_ksamp
from scipy.stats import wasserstein_distance
from scipy.stats import chisquare
from scipy.interpolate import interp1d

import math
import random

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc, accuracy_score
from sklearn.metrics import mean_squared_error, r2_score

from xgboost import XGBRegressor, XGBClassifier
import xgboost as xgb

# %% [markdown]
# # LOAD DATA

# %% [markdown]
# ## Background

# %%
CHs_selected = ["tt", "singletP1", "singletP2", "Wbbjets", "ttW", "ttZ", "ttH"]


df_B_all = {}
X_B_all = {}


output_folder = mainfolder + "../DATA/backgrounds/data_df/"

for CH_sel in CHs_selected:
    # Read the file
    if CH_sel == 'singletP2':
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-singlet-comp/df_' + CH_sel + ".csv"
    else:
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-' + CH_sel + '/df_' + CH_sel + ".csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_B_all[CH_sel] = df_temp
    X_B_all[CH_sel] = df_temp[feats_label].values

    # Print
    print(f"X_{CH_sel}.shape: {X_B_all[CH_sel].shape}")
# Out:
# X_tt.shape: (826022, 53)
# X_singletP1.shape: (179677, 53)
# X_singletP2.shape: (94219, 53)
# X_Wbbjets.shape: (162448, 53)
# X_ttW.shape: (141919, 53)
# X_ttZ.shape: (16178, 53)
# X_ttH.shape: (12068, 53)

# %% [markdown]
# ## Signal SLQ

# %%
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2200]
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]


df_SLQ_all = {}
X_SLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_SLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-SLQ-' + str(mass_sel) + 'GeV/df_SLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_SLQ_all[mass_sel] = df_temp
    X_SLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_SLQ_{mass_sel}GeV.shape: {X_SLQ_all[mass_sel].shape}")
# Out:
# X_SLQ_1000GeV.shape: (267452, 53)
# X_SLQ_1100GeV.shape: (271062, 53)
# X_SLQ_1200GeV.shape: (534247, 53)
# X_SLQ_1300GeV.shape: (196510, 53)
# X_SLQ_1400GeV.shape: (506381, 53)
# X_SLQ_1500GeV.shape: (185940, 53)
# X_SLQ_1600GeV.shape: (481827, 53)
# X_SLQ_1700GeV.shape: (173573, 53)
# X_SLQ_1800GeV.shape: (301687, 53)
# X_SLQ_1900GeV.shape: (64690, 53)

# %% [markdown]
# ## Signal VLQ

# %%
masses_VLQ = [1200, 1500, 1400, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
masses_VLQ = [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]


df_VLQ_all = {}
X_VLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_VLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-VLQ-' + str(mass_sel) + 'GeV/df_VLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_VLQ_all[mass_sel] = df_temp
    X_VLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_VLQ_{mass_sel}GeV.shape: {X_VLQ_all[mass_sel].shape}")
# Out:
# X_VLQ_1400GeV.shape: (139696, 53)
# X_VLQ_1500GeV.shape: (293700, 53)
# X_VLQ_1600GeV.shape: (134774, 53)
# X_VLQ_1700GeV.shape: (192819, 53)
# X_VLQ_1800GeV.shape: (127670, 53)
# X_VLQ_1900GeV.shape: (75898, 53)
# X_VLQ_2000GeV.shape: (184097, 53)
# X_VLQ_2100GeV.shape: (72762, 53)
# X_VLQ_2200GeV.shape: (232166, 53)
# X_VLQ_2300GeV.shape: (64705, 53)

# %% [markdown]
# # Cross Section

# %%
Lum = 3000

# %%
# -------------------------
# cross sections
# -------------------------
k_LQ = 1.8877462860822058

xsec_file_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV.txt'

xsec_data_14TeV = np.loadtxt(xsec_file_14TeV, comments='#')

# columns: 0=mass, 1=SLQ, 2=VLQ
masses_14TeV = xsec_data_14TeV[:,0].astype(int)
fidxsec_SLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,1]*k_LQ))
fidxsec_VLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,2]*k_LQ))


masses_SLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]
masses_VLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]

fidxsec_SLQ_non0_14TeV = [fidxsec_SLQ_14TeV[ii] for ii in masses_SLQ_14TeV]
fidxsec_VLQ_non0_14TeV = [fidxsec_VLQ_14TeV[ii] for ii in masses_VLQ_14TeV]


#  interpolate
f_xsec_SLQ_log_14TeV = interp1d(masses_SLQ_14TeV, np.log10(fidxsec_SLQ_non0_14TeV), kind='linear', fill_value="extrapolate")
f_xsec_VLQ_log_14TeV = interp1d(masses_VLQ_14TeV, np.log10(fidxsec_VLQ_non0_14TeV), kind='linear', fill_value="extrapolate")



# -------------------------
# cross sections
# -------------------------
xsec_file_betas_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV-betas.txt'

xsec_data_betas_14TeV = np.loadtxt(xsec_file_betas_14TeV, comments='#')

# columns: 0=beta, 1,...=SLQ, -1=ratio=fid_xsec(beta)/fid_xsec(beta=0.5)
betas = xsec_data_betas_14TeV[:,0]
ratio_mean_14TeV = xsec_data_betas_14TeV[:,-1]

#  interpolate
f_ratio_SLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")
f_ratio_VLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")



# FINAL FUNCTIONS
def fid_xsec_SLQ_14TeV(mass, beta):
    return 10**f_xsec_SLQ_log_14TeV(mass) * f_ratio_SLQ_log_14TeV(beta)

def fid_xsec_VLQ_14TeV(mass, beta):
    return 10**f_xsec_VLQ_log_14TeV(mass) * f_ratio_VLQ_log_14TeV(beta)

# %%
masses = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

beta = 0.7

fidxsec_SLQ = dict(zip(masses, fid_xsec_SLQ_14TeV(masses, beta)))
fidxsec_VLQ = dict(zip(masses, fid_xsec_VLQ_14TeV(masses, beta)))


print('masses: ', masses)
print(fidxsec_SLQ[1200], '[fb]')
print(fidxsec_VLQ[1600], '[fb]')
# Out:
# masses:  [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# 0.25114225279045466 [fb]
# 0.2692058601414503 [fb]

# %%
# -----------------------------------
# LQs number and fid cross sections
# -----------------------------------


for m_it in masses_SLQ:
    print(f"# eventos SLQ {m_it} GeV:", len(X_SLQ_all[m_it]), "  fid_xsec = ", fidxsec_SLQ[m_it], "[fb]")

print(" ")
for m_it in masses_VLQ:
    print(f"# eventos VLQ {m_it} GeV:", len(X_VLQ_all[m_it]), "  fid_xsec = ", fidxsec_VLQ[m_it], "[fb]")
# Out:
# # eventos SLQ 1000 GeV: 267452   fid_xsec =  0.7864983998886742 [fb]
# # eventos SLQ 1100 GeV: 271062   fid_xsec =  0.4444355745933594 [fb]
# # eventos SLQ 1200 GeV: 534247   fid_xsec =  0.25114225279045466 [fb]
# # eventos SLQ 1300 GeV: 196510   fid_xsec =  0.1419158022945696 [fb]
# # eventos SLQ 1400 GeV: 506381   fid_xsec =  0.08019397260769033 [fb]
# # eventos SLQ 1500 GeV: 185940   fid_xsec =  0.046503639120292255 [fb]
# # eventos SLQ 1600 GeV: 481827   fid_xsec =  0.026966969974286974 [fb]
# # eventos SLQ 1700 GeV: 173573   fid_xsec =  0.01561950889254055 [fb]
# # eventos SLQ 1800 GeV: 301687   fid_xsec =  0.009046958493178058 [fb]
# # eventos SLQ 1900 GeV: 64690   fid_xsec =  0.005339509684357914 [fb]
#
# # eventos VLQ 1400 GeV: 139696   fid_xsec =  0.8100174891233636 [fb]
# # eventos VLQ 1500 GeV: 293700   fid_xsec =  0.4669705075152744 [fb]
# # eventos VLQ 1600 GeV: 134774   fid_xsec =  0.2692058601414503 [fb]
# # eventos VLQ 1700 GeV: 192819   fid_xsec =  0.15771318673817117 [fb]
# # eventos VLQ 1800 GeV: 127670   fid_xsec =  0.09239564568928722 [fb]
# # eventos VLQ 1900 GeV: 75898   fid_xsec =  0.05522497019315383 [fb]
# # eventos VLQ 2000 GeV: 184097   fid_xsec =  0.03300802012998255 [fb]
# # eventos VLQ 2100 GeV: 72762   fid_xsec =  0.020107200562958692 [fb]
# # eventos VLQ 2200 GeV: 232166   fid_xsec =  0.012248523628104678 [fb]
# # eventos VLQ 2300 GeV: 64705   fid_xsec =  0.007461323648634399 [fb]

# %%
# FOR 14 TeV

k_fakett = 1.1053030485310749
crossfid_fakett = 0.244
k_tt = 1.2593273872014419
crossfid_tt = (7.74198*k_tt) + (crossfid_fakett * k_fakett)


fidxsec_SM = {'tt': crossfid_tt,
              'singletP1': 0.632632 * 3.440676833094312,
              'singletP2': 0.3182704 * 3.440676833094312,
              'Wbbjets': 1.6542420183645095 * 0.9781509289273502,
              'ttW': 0.03683196 * 3.056401327463198,
              'ttZ': 0.0715444 * 3.056401327463198,
              'ttH': 0.03630132 * 2.2127445612386474
              }

for ch_it in fidxsec_SM:
    print(f"# eventos {ch_it}:", len(X_B_all[ch_it]), "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]")
# Out:
# # eventos tt: 826022   fid_xsec =  10.019381389007401 [fb]
# # eventos singletP1: 179677   fid_xsec =  2.1766822662741205 [fb]
# # eventos singletP2: 94219   fid_xsec =  1.09506559193966 [fb]
# # eventos Wbbjets: 162448   fid_xsec =  1.6180983669338997 [fb]
# # eventos ttW: 141919   fid_xsec =  0.1125732514370714 [fb]
# # eventos ttZ: 16178   fid_xsec =  0.218668399132558 [fb]
# # eventos ttH: 12068   fid_xsec =  0.08032554839578374 [fb]

# %%
# MAX SM dataset
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])


weigth_gen_SM = {}

for ch_it in fidxsec_SM:

    print(f"fraction of {ch_it}:", fidxsec_SM[ch_it] / totalcrossSM )

    weigth_gen_SM[ch_it] = len(X_B_all[ch_it]) / (fidxsec_SM[ch_it] / totalcrossSM)

print('\nchannel limiting the SM background: ', min(weigth_gen_SM, key=weigth_gen_SM.get) , '\n')


max_evs_SM = {}

for ch_it in fidxsec_SM:
    max_evs_SM[ch_it] = round( min(weigth_gen_SM.values()) * (fidxsec_SM[ch_it] / totalcrossSM) )
    print(f"# eventos {ch_it} (max):", max_evs_SM[ch_it])

max_SM_dataset = sum(max_evs_SM.values())
print('\nmax SM dataset length: ', max_SM_dataset )
# Out:
# fraction of tt: 0.6539726894865112
# fraction of singletP1: 0.14207371698562551
# fraction of singletP2: 0.07147576906400852
# fraction of Wbbjets: 0.10561451848099845
# fraction of ttW: 0.0073477422555561795
# fraction of ttZ: 0.014272653723245071
# fraction of ttH: 0.005242910004055022
#
# channel limiting the SM background:  ttZ
#
# # eventos tt (max): 741276
# # eventos singletP1 (max): 161040
# # eventos singletP2 (max): 81018
# # eventos Wbbjets (max): 119714
# # eventos ttW (max): 8329
# # eventos ttZ (max): 16178
# # eventos ttH (max): 5943
#
# max SM dataset length:  1133498

# %% [markdown]
# ## Number of events to get a balanced dataset

# %%
# -------------------------
# Step 1: minimim number of events in LQs (selected mass)
# -------------------------

num_data_SLQ = [len(X_SLQ_all[m_it]) for m_it in masses_SLQ]

num_data_VLQ = [len(X_VLQ_all[m_it]) for m_it in masses_VLQ]


max_SM_dataset = min(1000000, max_SM_dataset)

num_data_NP = min(int(max_SM_dataset / (len(masses_SLQ) + len(masses_VLQ))) , min(num_data_SLQ + num_data_VLQ) )

print('SIGNAL: # events per-class chosen =', num_data_NP)



# -------------------------
# Step 2: background total fid_xsec
# -------------------------
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])



# -------------------------
# Step 3: number of events per chanel, proportional to xsec
# -------------------------
num_data_SM_dict = {}
for ch_it in fidxsec_SM:
    if ch_it == 'tt':
        # set at the end to have exactly the same # events (otherwise can be a difference of 1 due to rounding)
        continue
    fraction = fidxsec_SM[ch_it]/totalcrossSM
    num_data_SM_dict[ch_it] = round(num_data_NP * fraction * (len(masses_SLQ) + len(masses_VLQ)) )

# Set tt such that the total matches num_data_NP
num_data_SM_dict['tt'] = num_data_NP * (len(masses_SLQ) + len(masses_VLQ)) - sum([v for k,v in num_data_SM_dict.items() if k != 'tt'])




print('\nBACKGROUND events chosen (weighted by xsec):')
for ch_it in fidxsec_SM:
    print(f'# {ch_it}: {num_data_SM_dict[ch_it]}')
print('# total B events chosen: ', sum(num_data_SM_dict.values()))
# Out:
# SIGNAL: # events per-class chosen = 50000
#
# BACKGROUND events chosen (weighted by xsec):
# # tt: 653971
# # singletP1: 142074
# # singletP2: 71476
# # Wbbjets: 105615
# # ttW: 7348
# # ttZ: 14273
# # ttH: 5243
# # total B events chosen:  1000000

# %%
# keep just the events needed

for m_it in masses_SLQ:
    X_SLQ_all[m_it] = X_SLQ_all[m_it][:num_data_NP]
    df_SLQ_all[m_it] = df_SLQ_all[m_it][:num_data_NP]

print(" ")
for m_it in masses_VLQ:
    X_VLQ_all[m_it] = X_VLQ_all[m_it][:num_data_NP]
    df_VLQ_all[m_it] = df_VLQ_all[m_it][:num_data_NP]

print("")
for ch_it in fidxsec_SM:
    X_B_all[ch_it] = X_B_all[ch_it][:num_data_SM_dict[ch_it]]
    df_B_all[ch_it] = df_B_all[ch_it][:num_data_SM_dict[ch_it]]

# %%
B_expected = round(Lum * totalcrossSM)    # luminosity * cross * aceptance
print('B_expected: ', B_expected)

for ch_it in fidxsec_SM:
    print(f" channel {ch_it}:", "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]", " B_exp_ch: ", round(Lum * fidxsec_SM[ch_it]) )



S_expected_SLQ = []

for m_it in masses_SLQ:
    S_expected_SLQ.append( round(Lum * fidxsec_SLQ[m_it]) )

print('\nmasses:           ', masses_SLQ)
print('S_expected (SLQ): ', S_expected_SLQ)    # luminosity * cross * aceptance



S_expected_VLQ = []

for m_it in masses_VLQ:
    S_expected_VLQ.append( round(Lum * fidxsec_VLQ[m_it]) )

print('\nmasses:           ', masses_VLQ)
print('S_expected (VLQ): ', S_expected_VLQ)    # luminosity * cross * aceptance
# Out:
# B_expected:  45962
#  channel tt:   fid_xsec =  10.019381389007401 [fb]  B_exp_ch:  30058
#  channel singletP1:   fid_xsec =  2.1766822662741205 [fb]  B_exp_ch:  6530
#  channel singletP2:   fid_xsec =  1.09506559193966 [fb]  B_exp_ch:  3285
#  channel Wbbjets:   fid_xsec =  1.6180983669338997 [fb]  B_exp_ch:  4854
#  channel ttW:   fid_xsec =  0.1125732514370714 [fb]  B_exp_ch:  338
#  channel ttZ:   fid_xsec =  0.218668399132558 [fb]  B_exp_ch:  656
#  channel ttH:   fid_xsec =  0.08032554839578374 [fb]  B_exp_ch:  241
#
# masses:            [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_expected (SLQ):  [2359, 1333, 753, 426, 241, 140, 81, 47, 27, 16]
#
# masses:            [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_expected (VLQ):  [2430, 1401, 808, 473, 277, 166, 99, 60, 37, 22]

# %%
plt.plot(masses_SLQ, S_expected_SLQ, color='red', label='SLQ')
plt.plot(masses_VLQ, S_expected_VLQ, color='green', label='VLQ')
# plt.yscale('log')
plt.xlabel("$m_{LQ}$ [GeV]", fontsize=16)
plt.ylabel("S expected", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # 1. DATA FORMAT for CLASSIFIERS

# %%
# to save memory
del X_SLQ_all
del X_VLQ_all
del X_B_all

# %%
# ---------------------------
# Concatenate all for normalization
# ---------------------------
df_SM = pd.concat(df_B_all.values(), ignore_index=True)
del df_B_all

df_all = pd.concat([df_SM] + list(df_SLQ_all.values()) + list(df_VLQ_all.values()), ignore_index=True)

# ---------------------------
# Normalization
# ---------------------------
scaler = MinMaxScaler()
scaler.fit(df_all)

# Save the scaler
# joblib.dump(scaler, mainfolder + 'saved-models/scaler_features.pkl')

# Apply normalization
df_SM_norm = pd.DataFrame(scaler.transform(df_SM), columns=df_SM.columns)
df_SLQ_norm = {mass: pd.DataFrame(scaler.transform(df_SLQ_all[mass]), columns=df_SLQ_all[mass].columns) for mass in df_SLQ_all}
df_VLQ_norm = {mass: pd.DataFrame(scaler.transform(df_VLQ_all[mass]), columns=df_VLQ_all[mass].columns) for mass in df_VLQ_all}






# ---------------------------
# Divide datasets into train/val/test/pseudo
# ---------------------------
def split_class(df, test_ratio=0.25, val_ratio=0.10, pseudo_ratio=0.25):
    X = df.values
    aux_val_ratio = val_ratio / (1 - test_ratio)
    aux_pseudo_ratio = pseudo_ratio / (1 - test_ratio - val_ratio)

    X_aux, X_test = train_test_split(X, test_size=test_ratio, random_state=42, shuffle=True)
    X_aux2, X_val = train_test_split(X_aux, test_size=aux_val_ratio, random_state=42, shuffle=True)
    X_train, X_pseudo = train_test_split(X_aux2, test_size=aux_pseudo_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, X_pseudo



# ---------------------------
# Divide the datasets
# ---------------------------
split_SM = split_class(df_SM_norm)
split_SLQ = {mass: split_class(df_SLQ_norm[mass]) for mass in df_SLQ_norm}
split_VLQ = {mass: split_class(df_VLQ_norm[mass]) for mass in df_VLQ_norm}



# Example of how to use them
X_train_SM, X_val_SM, X_test_SM, X_pseudo_SM = split_SM
X_train_SLQ1200, X_val_SLQ1200, X_test_SLQ1200, X_pseudo_SLQ1200 = split_SLQ[1200]
X_train_VLQ1600, X_val_VLQ1600, X_test_VLQ1600, X_pseudo_VLQ1600 = split_VLQ[1600]

print('')
print('X_train_SM : ', X_train_SM.shape)
print('X_val_SM : ', X_val_SM.shape)
print('X_test_SM : ', X_test_SM.shape)
print('X_pseudo_SM : ', X_pseudo_SM.shape)

print('')
print('X_train_SLQ1200 : ', X_train_SLQ1200.shape)
print('X_val_SLQ1200 : ', X_val_SLQ1200.shape)
print('X_test_SLQ1200 : ', X_test_SLQ1200.shape)
print('X_pseudo_SLQ1200 : ', X_pseudo_SLQ1200.shape)

print('')
print('X_train_VLQ1600 : ', X_train_VLQ1600.shape)
print('X_val_VLQ1600 : ', X_val_VLQ1600.shape)
print('X_test_VLQ1600 : ', X_test_VLQ1600.shape)
print('X_pseudo_VLQ1600 : ', X_pseudo_VLQ1600.shape)
# Out:
# X_train_SM :  (400000, 53)
# X_val_SM :  (100000, 53)
# X_test_SM :  (250000, 53)
# X_pseudo_SM :  (250000, 53)
#
# X_train_SLQ1200 :  (20000, 53)
# X_val_SLQ1200 :  (5000, 53)
# X_test_SLQ1200 :  (12500, 53)
# X_pseudo_SLQ1200 :  (12500, 53)
#
# X_train_VLQ1600 :  (20000, 53)
# X_val_VLQ1600 :  (5000, 53)
# X_test_VLQ1600 :  (12500, 53)
# X_pseudo_VLQ1600 :  (12500, 53)

# %%
# to save memory
del df_SM
del df_SLQ_all
del df_VLQ_all

# %% [markdown]
# ## SM vs LQ

# %%
# --- 1. Combinar todos los LQ en un solo DataFrame ---
df_LQ_list = list(df_SLQ_norm.values()) + list(df_VLQ_norm.values())
df_LQ_norm = pd.concat(df_LQ_list, ignore_index=True)


# --- 2. Igualar número de eventos con SM ---
n_SM = len(df_SM_norm)
n_LQ = len(df_LQ_norm)
n_events = min(n_SM, n_LQ)

print(n_SM, n_LQ, n_events)

df_SM_sample = df_SM_norm.sample(n=n_events, random_state=42)
df_LQ_sample = df_LQ_norm.sample(n=n_events, random_state=42)


# --- 3. Crear X, y ---
X = pd.concat([df_SM_sample, df_LQ_sample], ignore_index=True)
y = np.hstack([np.zeros(n_events), np.ones(n_events)])  # 0=SM, 1=LQ


def split_class(X, Y, test_ratio=0.25, val_ratio=0.25):

    aux_val_ratio = val_ratio / (1 - test_ratio)

    X_aux, X_test, Y_aux, Y_test = train_test_split(X, Y, test_size=test_ratio, random_state=42, shuffle=True)
    X_train, X_val, Y_train, Y_val = train_test_split(X_aux, Y_aux, test_size=val_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, Y_train, Y_val, Y_test


# Divide into train, validation and test
X_train, X_val, X_test, y_train, y_val, y_test = split_class(X, y)


print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# 1000000 1000000 1000000
# (1125000, 53)
# (375000, 53)
# (500000, 53)

# %%
# LOAD
xgb_clf = XGBClassifier()
xgb_clf.load_model(mainfolder + "saved-models/modelA_SMLQ_14TeV_full.json")


# Evaluate
y_pred = xgb_clf.predict(X_test)
y_pred_proba = xgb_clf.predict_proba(X_test)[:,1]

acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)
print(f"Accuracy: {acc:.3f}, ROC-AUC: {auc:.5f}")

# ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC={auc:.3f}')
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SM vs LQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + "saved-results/ROC_classA.pdf", bbox_inches='tight')
plt.show()


# Feature importance
keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$'])

feature_important = xgb_clf.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=14).remove()
plt.title(r'SM vs LQ', fontsize=14)
# plt.savefig(mainfolder + "saved-results/XG_feature_importance_classA.pdf", bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Accuracy: 0.973, ROC-AUC: 0.99660
# [52, 47, 35, 17, 15, 36, 50, 46, 32, 45, 6, 37, 51, 38, 12]

# %% [markdown]
# ## Compute S_pred for pseudo-experiments

# %%
# output of all the background events
scores_B = xgb_clf.predict_proba( df_SM_norm )[:, 1]

# output of all the signal events (for the pdf of the general LQ case)
scores_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]

# %%
# output of all the signal events per class (to build the pseudo-experiments)
scores_S_SLQ = {mass: xgb_clf.predict_proba(df_SLQ_norm[mass])[:, 1] for mass in df_SLQ_norm}
scores_S_VLQ = {mass: xgb_clf.predict_proba(df_VLQ_norm[mass])[:, 1] for mass in df_VLQ_norm}

# %%
def Z_asimov(S, B):
    if S <= 0 or B <= 0:
        return 0
    return np.sqrt(2 * ((S+B) * np.log(1 + S/B) - S))

# %% [markdown]
# ###### binned likelihood fit

# %%
bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scores_B, bins=bins, density=True)
hist_S, _ = np.histogram(scores_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %%
# FOR SLQ #

S_expected = S_expected_SLQ


n_pseudo = 1000


# to save
S_mean_fit_N = {}
S_std_fit_N  = {}
Z_fit_N = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_N[S_it] = []
    S_std_fit_N[S_it]  = []
    Z_fit_N[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_SLQ[masses_SLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_N[S_it].append(mean_muS)
    S_std_fit_N[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_N[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  2359
# S = 1893.4689577350775 +- 50.16849992423442
# Z = 78.29632049737248
#
#
# ----------------
# S_expected =  1333
# S = 1158.9995001665675 +- 39.12794768121369
# Z = 55.540909446055835
#
#
# ----------------
# S_expected =  753
# S = 698.950161240643 +- 33.18128229172773
# Z = 38.76158166387097
#
#
# ----------------
# S_expected =  426
# S = 412.6571394550431 +- 25.01257540545493
# Z = 25.31887863528221
#
#
# ----------------
# S_expected =  241
# S = 242.05054738931622 +- 20.044130159619975
# Z = 15.026883273470833
#
#
# ----------------
# S_expected =  140
# S = 145.5148740073122 +- 17.774751491132697
# Z = 9.932422285173807
#
#
# ----------------
# S_expected =  81
# S = 85.78330743498981 +- 15.283780119862934
# Z = 7.667120662227318
#
#
# ----------------
# S_expected =  47
# S = 49.773108420981096 +- 13.779072507472902
# Z = 5.034076056456697
#
#
# ----------------
# S_expected =  27
# /tmp/ipykernel_750/1030940870.py:78: RuntimeWarning: invalid value encountered in sqrt
#   Z = np.sqrt(q0)
# S = 29.24844393652888 +- 12.348961117372625
# Z = nan
#
#
# ----------------
# S_expected =  16
# S = 17.748260289955507 +- 11.273532112665453
# Z = 1.629043036523396

# %%
# FOR VLQ #

S_expected = S_expected_SLQ # same number of events


n_pseudo = 1000


# to save
S_mean_fit_V = {}
S_std_fit_V  = {}
Z_fit_V = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_V[S_it] = []
    S_std_fit_V[S_it]  = []
    Z_fit_V[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_VLQ[masses_VLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_V[S_it].append(mean_muS)
    S_std_fit_V[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_V[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  2359
# S = 2296.48993015794 +- 68.56238669330223
# Z = 91.39318418909644
#
#
# ----------------
# S_expected =  1333
# S = 1313.0915153457709 +- 39.31474584871163
# Z = 64.26713267338032
#
#
# ----------------
# S_expected =  753
# S = 749.4585022010878 +- 28.409272586614318
# Z = 41.126062673824556
#
#
# ----------------
# S_expected =  426
# S = 429.3165322221532 +- 23.10157598779584
# Z = 24.976461204970477
#
#
# ----------------
# S_expected =  241
# S = 247.43258856652147 +- 19.93745475864837
# Z = 19.39545997452619
#
#
# ----------------
# S_expected =  140
# S = 144.5928262724009 +- 17.089107751469214
# Z = 8.784198909072403
#
#
# ----------------
# S_expected =  81
# S = 84.19148433154994 +- 15.403088308583417
# Z = 6.592691028420647
#
#
# ----------------
# S_expected =  47
# S = 48.89334689520228 +- 13.690241439540623
# Z = 3.5790405067541817
#
#
# ----------------
# S_expected =  27
# S = 28.264342701820954 +- 12.721599716135861
# Z = 1.723119425333999
#
#
# ----------------
# S_expected =  16
# S = 16.60994682607238 +- 11.436531465391294
# Z = nan
# /tmp/ipykernel_750/2772170123.py:78: RuntimeWarning: invalid value encountered in sqrt
#   Z = np.sqrt(q0)

# %%
# mean between scalar and vector
S_mean_fit_both = []
S_std_fit_both = []

for i in S_mean_fit_N:

    S_mean_fit_both.append( np.mean([S_mean_fit_N[i][0], S_mean_fit_V[i][0]]) )
    S_std_fit_both.append( np.mean([S_std_fit_N[i][0], S_std_fit_V[i][0]]) )

# %% [markdown]
# # SLQ vs VLQ (include Poisson S_expected)

# %%
X_train_list, y_train_list, S_poiss_train_list = [], [], []
X_val_list,   y_val_list,   S_poiss_val_list   = [], [], []
X_test_list,  y_test_list,  S_poiss_test_list  = [], [], []

for iit, m_s in enumerate(masses_SLQ):

        # -------- SLQ --------
        X_train_s, X_val_s, X_test_s, _ = split_SLQ[masses_SLQ[iit]]

        X_train_list.append(X_train_s)
        y_train_list.append(np.zeros(len(X_train_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_s))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_s)
        y_val_list.append(np.zeros(len(X_val_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_s))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_s)
        y_test_list.append(np.zeros(len(X_test_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_s))
        S_poiss_test_list.append(poisson_samples)


# for iit, m_v in enumerate(masses_VLQ):

        # -------- VLQ --------
        X_train_v, X_val_v, X_test_v, _ = split_VLQ[masses_VLQ[iit]]

        X_train_list.append(X_train_v)
        y_train_list.append(np.ones(len(X_train_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_v))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_v)
        y_val_list.append(np.ones(len(X_val_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_v))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_v)
        y_test_list.append(np.ones(len(X_test_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_v))
        S_poiss_test_list.append(poisson_samples)


# Concatenate
# TRAIN
X_train_spin = np.vstack(X_train_list)
y_train_spin = np.concatenate(y_train_list)
S_poiss_train = np.concatenate(S_poiss_train_list)

# add S_poiss as extra feature
X_train_spin = np.column_stack([X_train_spin, S_poiss_train])


# VAL
X_val_spin = np.vstack(X_val_list)
y_val_spin = np.concatenate(y_val_list)
S_poiss_val = np.concatenate(S_poiss_val_list)

X_val_spin = np.column_stack([X_val_spin, S_poiss_val])


# TEST
X_test_spin = np.vstack(X_test_list)
y_test_spin = np.concatenate(y_test_list)
S_poiss_test = np.concatenate(S_poiss_test_list)

X_test_spin = np.column_stack([X_test_spin, S_poiss_test])


print(X_train_spin.shape)
print(X_val_spin.shape)
print(X_test_spin.shape)
# Out:
# (400000, 54)
# (100000, 54)
# (250000, 54)

# %%
classifier_spin = XGBClassifier(
    n_estimators=1500,
    learning_rate=0.1,
    max_depth=5,
    reg_lambda=1.0,
    reg_alpha=0.0,
    gamma=0.0,
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    random_state=42,
    early_stopping_rounds=50
)

classifier_spin.fit(
    X_train_spin, y_train_spin,
    eval_set=[(X_train_spin, y_train_spin),
              (X_val_spin, y_val_spin)],
    verbose=True
)

classifier_spin.save_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta07.json")
# Out:
# [0]	validation_0-logloss:0.68605	validation_1-logloss:0.68615
# [1]	validation_0-logloss:0.67997	validation_1-logloss:0.68017
# [2]	validation_0-logloss:0.67455	validation_1-logloss:0.67475
# [3]	validation_0-logloss:0.67007	validation_1-logloss:0.67036
# [4]	validation_0-logloss:0.66592	validation_1-logloss:0.66623
# [5]	validation_0-logloss:0.66251	validation_1-logloss:0.66291
# [6]	validation_0-logloss:0.65938	validation_1-logloss:0.65976
# [7]	validation_0-logloss:0.65658	validation_1-logloss:0.65703
# [8]	validation_0-logloss:0.65389	validation_1-logloss:0.65439
# [9]	validation_0-logloss:0.65157	validation_1-logloss:0.65213
# [10]	validation_0-logloss:0.64928	validation_1-logloss:0.64991
# [11]	validation_0-logloss:0.64685	validation_1-logloss:0.64755
# [12]	validation_0-logloss:0.64492	validation_1-logloss:0.64566
# [13]	validation_0-logloss:0.64320	validation_1-logloss:0.64401
# [14]	validation_0-logloss:0.64167	validation_1-logloss:0.64258
# [15]	validation_0-logloss:0.64034	validation_1-logloss:0.64128
# [16]	validation_0-logloss:0.63900	validation_1-logloss:0.63997
# [17]	validation_0-logloss:0.63760	validation_1-logloss:0.63859
# [18]	validation_0-logloss:0.63656	validation_1-logloss:0.63761
# [19]	validation_0-logloss:0.63529	validation_1-logloss:0.63643
# [20]	validation_0-logloss:0.63438	validation_1-logloss:0.63555
# [21]	validation_0-logloss:0.63344	validation_1-logloss:0.63467
# [22]	validation_0-logloss:0.63229	validation_1-logloss:0.63355
# [23]	validation_0-logloss:0.63131	validation_1-logloss:0.63257
# [24]	validation_0-logloss:0.63050	validation_1-logloss:0.63180
# [25]	validation_0-logloss:0.62939	validation_1-logloss:0.63072
# [26]	validation_0-logloss:0.62874	validation_1-logloss:0.63013
# [27]	validation_0-logloss:0.62809	validation_1-logloss:0.62954
# [28]	validation_0-logloss:0.62752	validation_1-logloss:0.62902
# [29]	validation_0-logloss:0.62687	validation_1-logloss:0.62845
# [30]	validation_0-logloss:0.62628	validation_1-logloss:0.62789
# [31]	validation_0-logloss:0.62538	validation_1-logloss:0.62702
# [32]	validation_0-logloss:0.62393	validation_1-logloss:0.62561
# [33]	validation_0-logloss:0.62314	validation_1-logloss:0.62483
# [34]	validation_0-logloss:0.62253	validation_1-logloss:0.62428
# [35]	validation_0-logloss:0.62205	validation_1-logloss:0.62383
# [36]	validation_0-logloss:0.62098	validation_1-logloss:0.62277
# [37]	validation_0-logloss:0.62060	validation_1-logloss:0.62245
# [38]	validation_0-logloss:0.61980	validation_1-logloss:0.62172
# [39]	validation_0-logloss:0.61948	validation_1-logloss:0.62143
# [40]	validation_0-logloss:0.61877	validation_1-logloss:0.62074
# [41]	validation_0-logloss:0.61827	validation_1-logloss:0.62030
# [42]	validation_0-logloss:0.61735	validation_1-logloss:0.61947
# [43]	validation_0-logloss:0.61700	validation_1-logloss:0.61918
# [44]	validation_0-logloss:0.61657	validation_1-logloss:0.61877
# [45]	validation_0-logloss:0.61619	validation_1-logloss:0.61846
# [46]	validation_0-logloss:0.61534	validation_1-logloss:0.61768
# [47]	validation_0-logloss:0.61460	validation_1-logloss:0.61699
# [48]	validation_0-logloss:0.61409	validation_1-logloss:0.61653
# [49]	validation_0-logloss:0.61373	validation_1-logloss:0.61623
# [50]	validation_0-logloss:0.61339	validation_1-logloss:0.61592
# [51]	validation_0-logloss:0.61249	validation_1-logloss:0.61502
# [52]	validation_0-logloss:0.61224	validation_1-logloss:0.61482
# [53]	validation_0-logloss:0.61197	validation_1-logloss:0.61461
# [54]	validation_0-logloss:0.61169	validation_1-logloss:0.61436
# [55]	validation_0-logloss:0.61142	validation_1-logloss:0.61414
# [56]	validation_0-logloss:0.61107	validation_1-logloss:0.61387
# [57]	validation_0-logloss:0.61065	validation_1-logloss:0.61346
# [58]	validation_0-logloss:0.61021	validation_1-logloss:0.61308
# [59]	validation_0-logloss:0.60991	validation_1-logloss:0.61283
# [60]	validation_0-logloss:0.60970	validation_1-logloss:0.61264
# [61]	validation_0-logloss:0.60918	validation_1-logloss:0.61218
# [62]	validation_0-logloss:0.60871	validation_1-logloss:0.61177
# [63]	validation_0-logloss:0.60855	validation_1-logloss:0.61166
# [64]	validation_0-logloss:0.60838	validation_1-logloss:0.61153
# [65]	validation_0-logloss:0.60815	validation_1-logloss:0.61135
# [66]	validation_0-logloss:0.60795	validation_1-logloss:0.61122
# [67]	validation_0-logloss:0.60774	validation_1-logloss:0.61106
# [68]	validation_0-logloss:0.60723	validation_1-logloss:0.61054
# [69]	validation_0-logloss:0.60698	validation_1-logloss:0.61034
# [70]	validation_0-logloss:0.60656	validation_1-logloss:0.60998
# [71]	validation_0-logloss:0.60623	validation_1-logloss:0.60969
# [72]	validation_0-logloss:0.60603	validation_1-logloss:0.60952
# [73]	validation_0-logloss:0.60575	validation_1-logloss:0.60931
# [74]	validation_0-logloss:0.60564	validation_1-logloss:0.60924
# [75]	validation_0-logloss:0.60538	validation_1-logloss:0.60906
# [76]	validation_0-logloss:0.60510	validation_1-logloss:0.60883
# [77]	validation_0-logloss:0.60486	validation_1-logloss:0.60862
# [78]	validation_0-logloss:0.60471	validation_1-logloss:0.60852
# [79]	validation_0-logloss:0.60437	validation_1-logloss:0.60823
# [80]	validation_0-logloss:0.60423	validation_1-logloss:0.60816
# [81]	validation_0-logloss:0.60387	validation_1-logloss:0.60785
# [82]	validation_0-logloss:0.60376	validation_1-logloss:0.60778
# [83]	validation_0-logloss:0.60361	validation_1-logloss:0.60769
# [84]	validation_0-logloss:0.60345	validation_1-logloss:0.60761
# [85]	validation_0-logloss:0.60326	validation_1-logloss:0.60745
# [86]	validation_0-logloss:0.60307	validation_1-logloss:0.60735
# [87]	validation_0-logloss:0.60275	validation_1-logloss:0.60710
# [88]	validation_0-logloss:0.60260	validation_1-logloss:0.60699
# [89]	validation_0-logloss:0.60245	validation_1-logloss:0.60689
# [90]	validation_0-logloss:0.60222	validation_1-logloss:0.60669
# [91]	validation_0-logloss:0.60204	validation_1-logloss:0.60657
# [92]	validation_0-logloss:0.60191	validation_1-logloss:0.60650
# [93]	validation_0-logloss:0.60167	validation_1-logloss:0.60633
# [94]	validation_0-logloss:0.60157	validation_1-logloss:0.60628
# [95]	validation_0-logloss:0.60122	validation_1-logloss:0.60598
# [96]	validation_0-logloss:0.60111	validation_1-logloss:0.60591
# [97]	validation_0-logloss:0.60089	validation_1-logloss:0.60575
# [98]	validation_0-logloss:0.60074	validation_1-logloss:0.60568
# [99]	validation_0-logloss:0.60062	validation_1-logloss:0.60561
# [100]	validation_0-logloss:0.60040	validation_1-logloss:0.60545
# [101]	validation_0-logloss:0.60024	validation_1-logloss:0.60536
# [102]	validation_0-logloss:0.60010	validation_1-logloss:0.60529
# [103]	validation_0-logloss:0.59985	validation_1-logloss:0.60508
# [104]	validation_0-logloss:0.59975	validation_1-logloss:0.60504
# [105]	validation_0-logloss:0.59947	validation_1-logloss:0.60481
# [106]	validation_0-logloss:0.59932	validation_1-logloss:0.60472
# [107]	validation_0-logloss:0.59925	validation_1-logloss:0.60471
# [108]	validation_0-logloss:0.59911	validation_1-logloss:0.60462
# [109]	validation_0-logloss:0.59894	validation_1-logloss:0.60452
# [110]	validation_0-logloss:0.59881	validation_1-logloss:0.60445
# [111]	validation_0-logloss:0.59871	validation_1-logloss:0.60442
# [112]	validation_0-logloss:0.59849	validation_1-logloss:0.60422
# [113]	validation_0-logloss:0.59827	validation_1-logloss:0.60403
# [114]	validation_0-logloss:0.59806	validation_1-logloss:0.60385
# [115]	validation_0-logloss:0.59795	validation_1-logloss:0.60381
# [116]	validation_0-logloss:0.59759	validation_1-logloss:0.60351
# [117]	validation_0-logloss:0.59748	validation_1-logloss:0.60346
# [118]	validation_0-logloss:0.59733	validation_1-logloss:0.60335
# [119]	validation_0-logloss:0.59718	validation_1-logloss:0.60326
# [120]	validation_0-logloss:0.59695	validation_1-logloss:0.60309
# [121]	validation_0-logloss:0.59687	validation_1-logloss:0.60309
# [122]	validation_0-logloss:0.59680	validation_1-logloss:0.60306
# [123]	validation_0-logloss:0.59668	validation_1-logloss:0.60299
# [124]	validation_0-logloss:0.59657	validation_1-logloss:0.60294
# [125]	validation_0-logloss:0.59636	validation_1-logloss:0.60281
# [126]	validation_0-logloss:0.59623	validation_1-logloss:0.60273
# [127]	validation_0-logloss:0.59613	validation_1-logloss:0.60268
# [128]	validation_0-logloss:0.59572	validation_1-logloss:0.60231
# [129]	validation_0-logloss:0.59541	validation_1-logloss:0.60205
# [130]	validation_0-logloss:0.59527	validation_1-logloss:0.60197
# [131]	validation_0-logloss:0.59511	validation_1-logloss:0.60190
# [132]	validation_0-logloss:0.59498	validation_1-logloss:0.60184
# [133]	validation_0-logloss:0.59479	validation_1-logloss:0.60170
# [134]	validation_0-logloss:0.59462	validation_1-logloss:0.60159
# [135]	validation_0-logloss:0.59451	validation_1-logloss:0.60152
# [136]	validation_0-logloss:0.59441	validation_1-logloss:0.60150
# [137]	validation_0-logloss:0.59427	validation_1-logloss:0.60142
# [138]	validation_0-logloss:0.59409	validation_1-logloss:0.60129
# [139]	validation_0-logloss:0.59395	validation_1-logloss:0.60122
# [140]	validation_0-logloss:0.59384	validation_1-logloss:0.60118
# [141]	validation_0-logloss:0.59377	validation_1-logloss:0.60116
# [142]	validation_0-logloss:0.59354	validation_1-logloss:0.60096
# [143]	validation_0-logloss:0.59334	validation_1-logloss:0.60084
# [144]	validation_0-logloss:0.59321	validation_1-logloss:0.60076
# [145]	validation_0-logloss:0.59288	validation_1-logloss:0.60049
# [146]	validation_0-logloss:0.59280	validation_1-logloss:0.60047
# [147]	validation_0-logloss:0.59273	validation_1-logloss:0.60044
# [148]	validation_0-logloss:0.59263	validation_1-logloss:0.60041
# [149]	validation_0-logloss:0.59252	validation_1-logloss:0.60037
# [150]	validation_0-logloss:0.59242	validation_1-logloss:0.60032
# [151]	validation_0-logloss:0.59235	validation_1-logloss:0.60029
# [152]	validation_0-logloss:0.59217	validation_1-logloss:0.60015
# [153]	validation_0-logloss:0.59206	validation_1-logloss:0.60007
# [154]	validation_0-logloss:0.59190	validation_1-logloss:0.59995
# [155]	validation_0-logloss:0.59182	validation_1-logloss:0.59994
# [156]	validation_0-logloss:0.59175	validation_1-logloss:0.59993
# [157]	validation_0-logloss:0.59163	validation_1-logloss:0.59989
# [158]	validation_0-logloss:0.59154	validation_1-logloss:0.59985
# [159]	validation_0-logloss:0.59141	validation_1-logloss:0.59979
# [160]	validation_0-logloss:0.59134	validation_1-logloss:0.59976
# [161]	validation_0-logloss:0.59120	validation_1-logloss:0.59968
# [162]	validation_0-logloss:0.59110	validation_1-logloss:0.59965
# [163]	validation_0-logloss:0.59099	validation_1-logloss:0.59964
# [164]	validation_0-logloss:0.59093	validation_1-logloss:0.59964
# [165]	validation_0-logloss:0.59088	validation_1-logloss:0.59964
# [166]	validation_0-logloss:0.59081	validation_1-logloss:0.59963
# [167]	validation_0-logloss:0.59059	validation_1-logloss:0.59947
# [168]	validation_0-logloss:0.59052	validation_1-logloss:0.59944
# [169]	validation_0-logloss:0.59037	validation_1-logloss:0.59935
# [170]	validation_0-logloss:0.59023	validation_1-logloss:0.59925
# [171]	validation_0-logloss:0.59014	validation_1-logloss:0.59921
# [172]	validation_0-logloss:0.59003	validation_1-logloss:0.59914
# [173]	validation_0-logloss:0.58992	validation_1-logloss:0.59910
# [174]	validation_0-logloss:0.58980	validation_1-logloss:0.59903
# [175]	validation_0-logloss:0.58972	validation_1-logloss:0.59901
# [176]	validation_0-logloss:0.58964	validation_1-logloss:0.59900
# [177]	validation_0-logloss:0.58957	validation_1-logloss:0.59898
# [178]	validation_0-logloss:0.58949	validation_1-logloss:0.59897
# [179]	validation_0-logloss:0.58943	validation_1-logloss:0.59898
# [180]	validation_0-logloss:0.58935	validation_1-logloss:0.59894
# [181]	validation_0-logloss:0.58921	validation_1-logloss:0.59884
# [182]	validation_0-logloss:0.58913	validation_1-logloss:0.59881
# [183]	validation_0-logloss:0.58893	validation_1-logloss:0.59866
# [184]	validation_0-logloss:0.58885	validation_1-logloss:0.59864
# [185]	validation_0-logloss:0.58877	validation_1-logloss:0.59862
# [186]	validation_0-logloss:0.58860	validation_1-logloss:0.59852
# [187]	validation_0-logloss:0.58852	validation_1-logloss:0.59851
# [188]	validation_0-logloss:0.58844	validation_1-logloss:0.59848
# [189]	validation_0-logloss:0.58832	validation_1-logloss:0.59842
# [190]	validation_0-logloss:0.58826	validation_1-logloss:0.59841
# [191]	validation_0-logloss:0.58808	validation_1-logloss:0.59826
# [192]	validation_0-logloss:0.58800	validation_1-logloss:0.59824
# [193]	validation_0-logloss:0.58794	validation_1-logloss:0.59823
# [194]	validation_0-logloss:0.58775	validation_1-logloss:0.59808
# [195]	validation_0-logloss:0.58765	validation_1-logloss:0.59806
# [196]	validation_0-logloss:0.58754	validation_1-logloss:0.59801
# [197]	validation_0-logloss:0.58748	validation_1-logloss:0.59800
# [198]	validation_0-logloss:0.58730	validation_1-logloss:0.59789
# [199]	validation_0-logloss:0.58723	validation_1-logloss:0.59786
# [200]	validation_0-logloss:0.58711	validation_1-logloss:0.59780
# [201]	validation_0-logloss:0.58699	validation_1-logloss:0.59774
# [202]	validation_0-logloss:0.58684	validation_1-logloss:0.59764
# [203]	validation_0-logloss:0.58667	validation_1-logloss:0.59751
# [204]	validation_0-logloss:0.58660	validation_1-logloss:0.59749
# [205]	validation_0-logloss:0.58649	validation_1-logloss:0.59743
# [206]	validation_0-logloss:0.58641	validation_1-logloss:0.59742
# [207]	validation_0-logloss:0.58636	validation_1-logloss:0.59741
# [208]	validation_0-logloss:0.58629	validation_1-logloss:0.59740
# [209]	validation_0-logloss:0.58623	validation_1-logloss:0.59739
# [210]	validation_0-logloss:0.58614	validation_1-logloss:0.59736
# [211]	validation_0-logloss:0.58593	validation_1-logloss:0.59718
# [212]	validation_0-logloss:0.58585	validation_1-logloss:0.59717
# [213]	validation_0-logloss:0.58577	validation_1-logloss:0.59714
# [214]	validation_0-logloss:0.58570	validation_1-logloss:0.59713
# [215]	validation_0-logloss:0.58565	validation_1-logloss:0.59713
# [216]	validation_0-logloss:0.58550	validation_1-logloss:0.59706
# [217]	validation_0-logloss:0.58540	validation_1-logloss:0.59702
# [218]	validation_0-logloss:0.58530	validation_1-logloss:0.59698
# [219]	validation_0-logloss:0.58523	validation_1-logloss:0.59697
# [220]	validation_0-logloss:0.58514	validation_1-logloss:0.59696
# [221]	validation_0-logloss:0.58506	validation_1-logloss:0.59694
# [222]	validation_0-logloss:0.58499	validation_1-logloss:0.59693
# [223]	validation_0-logloss:0.58478	validation_1-logloss:0.59678
# [224]	validation_0-logloss:0.58470	validation_1-logloss:0.59676
# [225]	validation_0-logloss:0.58460	validation_1-logloss:0.59672
# [226]	validation_0-logloss:0.58453	validation_1-logloss:0.59670
# [227]	validation_0-logloss:0.58447	validation_1-logloss:0.59670
# [228]	validation_0-logloss:0.58439	validation_1-logloss:0.59667
# [229]	validation_0-logloss:0.58435	validation_1-logloss:0.59666
# [230]	validation_0-logloss:0.58430	validation_1-logloss:0.59665
# [231]	validation_0-logloss:0.58424	validation_1-logloss:0.59665
# [232]	validation_0-logloss:0.58417	validation_1-logloss:0.59664
# [233]	validation_0-logloss:0.58411	validation_1-logloss:0.59663
# [234]	validation_0-logloss:0.58402	validation_1-logloss:0.59660
# [235]	validation_0-logloss:0.58394	validation_1-logloss:0.59658
# [236]	validation_0-logloss:0.58386	validation_1-logloss:0.59656
# [237]	validation_0-logloss:0.58382	validation_1-logloss:0.59656
# [238]	validation_0-logloss:0.58375	validation_1-logloss:0.59656
# [239]	validation_0-logloss:0.58367	validation_1-logloss:0.59654
# [240]	validation_0-logloss:0.58358	validation_1-logloss:0.59652
# [241]	validation_0-logloss:0.58349	validation_1-logloss:0.59650
# [242]	validation_0-logloss:0.58341	validation_1-logloss:0.59648
# [243]	validation_0-logloss:0.58335	validation_1-logloss:0.59646
# [244]	validation_0-logloss:0.58329	validation_1-logloss:0.59647
# [245]	validation_0-logloss:0.58322	validation_1-logloss:0.59645
# [246]	validation_0-logloss:0.58315	validation_1-logloss:0.59646
# [247]	validation_0-logloss:0.58306	validation_1-logloss:0.59643
# [248]	validation_0-logloss:0.58296	validation_1-logloss:0.59641
# [249]	validation_0-logloss:0.58288	validation_1-logloss:0.59639
# [250]	validation_0-logloss:0.58278	validation_1-logloss:0.59632
# [251]	validation_0-logloss:0.58267	validation_1-logloss:0.59627
# [252]	validation_0-logloss:0.58261	validation_1-logloss:0.59627
# [253]	validation_0-logloss:0.58254	validation_1-logloss:0.59627
# [254]	validation_0-logloss:0.58246	validation_1-logloss:0.59625
# [255]	validation_0-logloss:0.58242	validation_1-logloss:0.59625
# [256]	validation_0-logloss:0.58237	validation_1-logloss:0.59624
# [257]	validation_0-logloss:0.58229	validation_1-logloss:0.59624
# [258]	validation_0-logloss:0.58224	validation_1-logloss:0.59624
# [259]	validation_0-logloss:0.58219	validation_1-logloss:0.59623
# [260]	validation_0-logloss:0.58199	validation_1-logloss:0.59608
# [261]	validation_0-logloss:0.58186	validation_1-logloss:0.59602
# [262]	validation_0-logloss:0.58175	validation_1-logloss:0.59598
# [263]	validation_0-logloss:0.58168	validation_1-logloss:0.59596
# [264]	validation_0-logloss:0.58160	validation_1-logloss:0.59593
# [265]	validation_0-logloss:0.58152	validation_1-logloss:0.59590
# [266]	validation_0-logloss:0.58141	validation_1-logloss:0.59586
# [267]	validation_0-logloss:0.58134	validation_1-logloss:0.59583
# [268]	validation_0-logloss:0.58129	validation_1-logloss:0.59583
# [269]	validation_0-logloss:0.58121	validation_1-logloss:0.59581
# [270]	validation_0-logloss:0.58115	validation_1-logloss:0.59580
# [271]	validation_0-logloss:0.58109	validation_1-logloss:0.59581
# [272]	validation_0-logloss:0.58096	validation_1-logloss:0.59572
# [273]	validation_0-logloss:0.58089	validation_1-logloss:0.59572
# [274]	validation_0-logloss:0.58080	validation_1-logloss:0.59570
# [275]	validation_0-logloss:0.58070	validation_1-logloss:0.59566
# [276]	validation_0-logloss:0.58058	validation_1-logloss:0.59560
# [277]	validation_0-logloss:0.58045	validation_1-logloss:0.59553
# [278]	validation_0-logloss:0.58037	validation_1-logloss:0.59550
# [279]	validation_0-logloss:0.58031	validation_1-logloss:0.59550
# [280]	validation_0-logloss:0.58027	validation_1-logloss:0.59550
# [281]	validation_0-logloss:0.58022	validation_1-logloss:0.59550
# [282]	validation_0-logloss:0.58015	validation_1-logloss:0.59549
# [283]	validation_0-logloss:0.58002	validation_1-logloss:0.59539
# [284]	validation_0-logloss:0.57993	validation_1-logloss:0.59536
# [285]	validation_0-logloss:0.57988	validation_1-logloss:0.59536
# [286]	validation_0-logloss:0.57982	validation_1-logloss:0.59534
# [287]	validation_0-logloss:0.57974	validation_1-logloss:0.59532
# [288]	validation_0-logloss:0.57969	validation_1-logloss:0.59530
# [289]	validation_0-logloss:0.57964	validation_1-logloss:0.59530
# [290]	validation_0-logloss:0.57953	validation_1-logloss:0.59525
# [291]	validation_0-logloss:0.57945	validation_1-logloss:0.59523
# [292]	validation_0-logloss:0.57938	validation_1-logloss:0.59522
# [293]	validation_0-logloss:0.57926	validation_1-logloss:0.59514
# [294]	validation_0-logloss:0.57918	validation_1-logloss:0.59512
# [295]	validation_0-logloss:0.57907	validation_1-logloss:0.59506
# [296]	validation_0-logloss:0.57899	validation_1-logloss:0.59506
# [297]	validation_0-logloss:0.57891	validation_1-logloss:0.59506
# [298]	validation_0-logloss:0.57885	validation_1-logloss:0.59506
# [299]	validation_0-logloss:0.57876	validation_1-logloss:0.59502
# [300]	validation_0-logloss:0.57872	validation_1-logloss:0.59503
# [301]	validation_0-logloss:0.57864	validation_1-logloss:0.59499
# [302]	validation_0-logloss:0.57856	validation_1-logloss:0.59498
# [303]	validation_0-logloss:0.57850	validation_1-logloss:0.59497
# [304]	validation_0-logloss:0.57839	validation_1-logloss:0.59488
# [305]	validation_0-logloss:0.57831	validation_1-logloss:0.59486
# [306]	validation_0-logloss:0.57820	validation_1-logloss:0.59480
# [307]	validation_0-logloss:0.57814	validation_1-logloss:0.59479
# [308]	validation_0-logloss:0.57804	validation_1-logloss:0.59473
# [309]	validation_0-logloss:0.57799	validation_1-logloss:0.59474
# [310]	validation_0-logloss:0.57793	validation_1-logloss:0.59473
# [311]	validation_0-logloss:0.57787	validation_1-logloss:0.59471
# [312]	validation_0-logloss:0.57780	validation_1-logloss:0.59469
# [313]	validation_0-logloss:0.57774	validation_1-logloss:0.59469
# [314]	validation_0-logloss:0.57767	validation_1-logloss:0.59467
# [315]	validation_0-logloss:0.57757	validation_1-logloss:0.59465
# [316]	validation_0-logloss:0.57745	validation_1-logloss:0.59458
# [317]	validation_0-logloss:0.57741	validation_1-logloss:0.59458
# [318]	validation_0-logloss:0.57736	validation_1-logloss:0.59458
# [319]	validation_0-logloss:0.57731	validation_1-logloss:0.59457
# [320]	validation_0-logloss:0.57722	validation_1-logloss:0.59456
# [321]	validation_0-logloss:0.57716	validation_1-logloss:0.59455
# [322]	validation_0-logloss:0.57704	validation_1-logloss:0.59449
# [323]	validation_0-logloss:0.57696	validation_1-logloss:0.59448
# [324]	validation_0-logloss:0.57689	validation_1-logloss:0.59447
# [325]	validation_0-logloss:0.57684	validation_1-logloss:0.59447
# [326]	validation_0-logloss:0.57676	validation_1-logloss:0.59446
# [327]	validation_0-logloss:0.57668	validation_1-logloss:0.59444
# [328]	validation_0-logloss:0.57664	validation_1-logloss:0.59444
# [329]	validation_0-logloss:0.57656	validation_1-logloss:0.59443
# [330]	validation_0-logloss:0.57645	validation_1-logloss:0.59438
# [331]	validation_0-logloss:0.57638	validation_1-logloss:0.59437
# [332]	validation_0-logloss:0.57628	validation_1-logloss:0.59433
# [333]	validation_0-logloss:0.57619	validation_1-logloss:0.59429
# [334]	validation_0-logloss:0.57606	validation_1-logloss:0.59422
# [335]	validation_0-logloss:0.57600	validation_1-logloss:0.59422
# [336]	validation_0-logloss:0.57591	validation_1-logloss:0.59416
# [337]	validation_0-logloss:0.57583	validation_1-logloss:0.59413
# [338]	validation_0-logloss:0.57576	validation_1-logloss:0.59411
# [339]	validation_0-logloss:0.57571	validation_1-logloss:0.59412
# [340]	validation_0-logloss:0.57566	validation_1-logloss:0.59411
# [341]	validation_0-logloss:0.57561	validation_1-logloss:0.59410
# [342]	validation_0-logloss:0.57552	validation_1-logloss:0.59408
# [343]	validation_0-logloss:0.57545	validation_1-logloss:0.59406
# [344]	validation_0-logloss:0.57539	validation_1-logloss:0.59405
# [345]	validation_0-logloss:0.57535	validation_1-logloss:0.59405
# [346]	validation_0-logloss:0.57528	validation_1-logloss:0.59403
# [347]	validation_0-logloss:0.57522	validation_1-logloss:0.59402
# [348]	validation_0-logloss:0.57515	validation_1-logloss:0.59403
# [349]	validation_0-logloss:0.57508	validation_1-logloss:0.59403
# [350]	validation_0-logloss:0.57501	validation_1-logloss:0.59402
# [351]	validation_0-logloss:0.57495	validation_1-logloss:0.59403
# [352]	validation_0-logloss:0.57491	validation_1-logloss:0.59402
# [353]	validation_0-logloss:0.57483	validation_1-logloss:0.59400
# [354]	validation_0-logloss:0.57477	validation_1-logloss:0.59399
# [355]	validation_0-logloss:0.57471	validation_1-logloss:0.59399
# [356]	validation_0-logloss:0.57465	validation_1-logloss:0.59399
# [357]	validation_0-logloss:0.57460	validation_1-logloss:0.59400
# [358]	validation_0-logloss:0.57457	validation_1-logloss:0.59400
# [359]	validation_0-logloss:0.57450	validation_1-logloss:0.59401
# [360]	validation_0-logloss:0.57444	validation_1-logloss:0.59400
# [361]	validation_0-logloss:0.57438	validation_1-logloss:0.59401
# [362]	validation_0-logloss:0.57430	validation_1-logloss:0.59400
# [363]	validation_0-logloss:0.57414	validation_1-logloss:0.59389
# [364]	validation_0-logloss:0.57406	validation_1-logloss:0.59388
# [365]	validation_0-logloss:0.57400	validation_1-logloss:0.59386
# [366]	validation_0-logloss:0.57395	validation_1-logloss:0.59386
# [367]	validation_0-logloss:0.57387	validation_1-logloss:0.59384
# [368]	validation_0-logloss:0.57381	validation_1-logloss:0.59383
# [369]	validation_0-logloss:0.57369	validation_1-logloss:0.59372
# [370]	validation_0-logloss:0.57358	validation_1-logloss:0.59368
# [371]	validation_0-logloss:0.57346	validation_1-logloss:0.59359
# [372]	validation_0-logloss:0.57341	validation_1-logloss:0.59358
# [373]	validation_0-logloss:0.57334	validation_1-logloss:0.59357
# [374]	validation_0-logloss:0.57326	validation_1-logloss:0.59356
# [375]	validation_0-logloss:0.57321	validation_1-logloss:0.59355
# [376]	validation_0-logloss:0.57314	validation_1-logloss:0.59354
# [377]	validation_0-logloss:0.57310	validation_1-logloss:0.59354
# [378]	validation_0-logloss:0.57303	validation_1-logloss:0.59354
# [379]	validation_0-logloss:0.57297	validation_1-logloss:0.59351
# [380]	validation_0-logloss:0.57291	validation_1-logloss:0.59352
# [381]	validation_0-logloss:0.57278	validation_1-logloss:0.59346
# [382]	validation_0-logloss:0.57271	validation_1-logloss:0.59346
# [383]	validation_0-logloss:0.57264	validation_1-logloss:0.59344
# [384]	validation_0-logloss:0.57258	validation_1-logloss:0.59344
# [385]	validation_0-logloss:0.57252	validation_1-logloss:0.59344
# [386]	validation_0-logloss:0.57243	validation_1-logloss:0.59340
# [387]	validation_0-logloss:0.57237	validation_1-logloss:0.59340
# [388]	validation_0-logloss:0.57230	validation_1-logloss:0.59337
# [389]	validation_0-logloss:0.57224	validation_1-logloss:0.59335
# [390]	validation_0-logloss:0.57218	validation_1-logloss:0.59332
# [391]	validation_0-logloss:0.57211	validation_1-logloss:0.59330
# [392]	validation_0-logloss:0.57203	validation_1-logloss:0.59328
# [393]	validation_0-logloss:0.57197	validation_1-logloss:0.59327
# [394]	validation_0-logloss:0.57191	validation_1-logloss:0.59326
# [395]	validation_0-logloss:0.57184	validation_1-logloss:0.59327
# [396]	validation_0-logloss:0.57175	validation_1-logloss:0.59324
# [397]	validation_0-logloss:0.57170	validation_1-logloss:0.59323
# [398]	validation_0-logloss:0.57164	validation_1-logloss:0.59323
# [399]	validation_0-logloss:0.57159	validation_1-logloss:0.59323
# [400]	validation_0-logloss:0.57152	validation_1-logloss:0.59323
# [401]	validation_0-logloss:0.57147	validation_1-logloss:0.59323
# [402]	validation_0-logloss:0.57142	validation_1-logloss:0.59324
# [403]	validation_0-logloss:0.57135	validation_1-logloss:0.59325
# [404]	validation_0-logloss:0.57128	validation_1-logloss:0.59323
# [405]	validation_0-logloss:0.57122	validation_1-logloss:0.59322
# [406]	validation_0-logloss:0.57118	validation_1-logloss:0.59322
# [407]	validation_0-logloss:0.57111	validation_1-logloss:0.59320
# [408]	validation_0-logloss:0.57104	validation_1-logloss:0.59322
# [409]	validation_0-logloss:0.57098	validation_1-logloss:0.59321
# [410]	validation_0-logloss:0.57094	validation_1-logloss:0.59321
# [411]	validation_0-logloss:0.57087	validation_1-logloss:0.59320
# [412]	validation_0-logloss:0.57079	validation_1-logloss:0.59320
# [413]	validation_0-logloss:0.57073	validation_1-logloss:0.59318
# [414]	validation_0-logloss:0.57065	validation_1-logloss:0.59315
# [415]	validation_0-logloss:0.57059	validation_1-logloss:0.59314
# [416]	validation_0-logloss:0.57053	validation_1-logloss:0.59316
# [417]	validation_0-logloss:0.57046	validation_1-logloss:0.59316
# [418]	validation_0-logloss:0.57039	validation_1-logloss:0.59315
# [419]	validation_0-logloss:0.57030	validation_1-logloss:0.59311
# [420]	validation_0-logloss:0.57023	validation_1-logloss:0.59310
# [421]	validation_0-logloss:0.57017	validation_1-logloss:0.59311
# [422]	validation_0-logloss:0.57012	validation_1-logloss:0.59309
# [423]	validation_0-logloss:0.57005	validation_1-logloss:0.59308
# [424]	validation_0-logloss:0.56998	validation_1-logloss:0.59308
# [425]	validation_0-logloss:0.56989	validation_1-logloss:0.59305
# [426]	validation_0-logloss:0.56980	validation_1-logloss:0.59302
# [427]	validation_0-logloss:0.56974	validation_1-logloss:0.59301
# [428]	validation_0-logloss:0.56966	validation_1-logloss:0.59300
# [429]	validation_0-logloss:0.56960	validation_1-logloss:0.59300
# [430]	validation_0-logloss:0.56952	validation_1-logloss:0.59298
# [431]	validation_0-logloss:0.56946	validation_1-logloss:0.59299
# [432]	validation_0-logloss:0.56939	validation_1-logloss:0.59298
# [433]	validation_0-logloss:0.56931	validation_1-logloss:0.59296
# [434]	validation_0-logloss:0.56926	validation_1-logloss:0.59298
# [435]	validation_0-logloss:0.56920	validation_1-logloss:0.59297
# [436]	validation_0-logloss:0.56914	validation_1-logloss:0.59297
# [437]	validation_0-logloss:0.56908	validation_1-logloss:0.59296
# [438]	validation_0-logloss:0.56904	validation_1-logloss:0.59297
# [439]	validation_0-logloss:0.56899	validation_1-logloss:0.59297
# [440]	validation_0-logloss:0.56893	validation_1-logloss:0.59296
# [441]	validation_0-logloss:0.56885	validation_1-logloss:0.59295
# [442]	validation_0-logloss:0.56880	validation_1-logloss:0.59294
# [443]	validation_0-logloss:0.56870	validation_1-logloss:0.59291
# [444]	validation_0-logloss:0.56862	validation_1-logloss:0.59289
# [445]	validation_0-logloss:0.56857	validation_1-logloss:0.59290
# [446]	validation_0-logloss:0.56849	validation_1-logloss:0.59287
# [447]	validation_0-logloss:0.56845	validation_1-logloss:0.59287
# [448]	validation_0-logloss:0.56839	validation_1-logloss:0.59288
# [449]	validation_0-logloss:0.56832	validation_1-logloss:0.59287
# [450]	validation_0-logloss:0.56826	validation_1-logloss:0.59286
# [451]	validation_0-logloss:0.56820	validation_1-logloss:0.59286
# [452]	validation_0-logloss:0.56814	validation_1-logloss:0.59286
# [453]	validation_0-logloss:0.56809	validation_1-logloss:0.59286
# [454]	validation_0-logloss:0.56801	validation_1-logloss:0.59286
# [455]	validation_0-logloss:0.56795	validation_1-logloss:0.59284
# [456]	validation_0-logloss:0.56788	validation_1-logloss:0.59284
# [457]	validation_0-logloss:0.56785	validation_1-logloss:0.59285
# [458]	validation_0-logloss:0.56779	validation_1-logloss:0.59286
# [459]	validation_0-logloss:0.56771	validation_1-logloss:0.59283
# [460]	validation_0-logloss:0.56761	validation_1-logloss:0.59279
# [461]	validation_0-logloss:0.56753	validation_1-logloss:0.59276
# [462]	validation_0-logloss:0.56746	validation_1-logloss:0.59275
# [463]	validation_0-logloss:0.56742	validation_1-logloss:0.59275
# [464]	validation_0-logloss:0.56734	validation_1-logloss:0.59273
# [465]	validation_0-logloss:0.56728	validation_1-logloss:0.59274
# [466]	validation_0-logloss:0.56724	validation_1-logloss:0.59274
# [467]	validation_0-logloss:0.56718	validation_1-logloss:0.59275
# [468]	validation_0-logloss:0.56710	validation_1-logloss:0.59271
# [469]	validation_0-logloss:0.56705	validation_1-logloss:0.59271
# [470]	validation_0-logloss:0.56697	validation_1-logloss:0.59269
# [471]	validation_0-logloss:0.56693	validation_1-logloss:0.59269
# [472]	validation_0-logloss:0.56687	validation_1-logloss:0.59269
# [473]	validation_0-logloss:0.56682	validation_1-logloss:0.59269
# [474]	validation_0-logloss:0.56677	validation_1-logloss:0.59268
# [475]	validation_0-logloss:0.56671	validation_1-logloss:0.59269
# [476]	validation_0-logloss:0.56665	validation_1-logloss:0.59268
# [477]	validation_0-logloss:0.56659	validation_1-logloss:0.59268
# [478]	validation_0-logloss:0.56655	validation_1-logloss:0.59267
# [479]	validation_0-logloss:0.56651	validation_1-logloss:0.59267
# [480]	validation_0-logloss:0.56646	validation_1-logloss:0.59268
# [481]	validation_0-logloss:0.56643	validation_1-logloss:0.59268
# [482]	validation_0-logloss:0.56635	validation_1-logloss:0.59265
# [483]	validation_0-logloss:0.56628	validation_1-logloss:0.59265
# [484]	validation_0-logloss:0.56618	validation_1-logloss:0.59259
# [485]	validation_0-logloss:0.56613	validation_1-logloss:0.59259
# [486]	validation_0-logloss:0.56610	validation_1-logloss:0.59260
# [487]	validation_0-logloss:0.56604	validation_1-logloss:0.59259
# [488]	validation_0-logloss:0.56597	validation_1-logloss:0.59259
# [489]	validation_0-logloss:0.56590	validation_1-logloss:0.59259
# [490]	validation_0-logloss:0.56582	validation_1-logloss:0.59256
# [491]	validation_0-logloss:0.56574	validation_1-logloss:0.59254
# [492]	validation_0-logloss:0.56567	validation_1-logloss:0.59254
# [493]	validation_0-logloss:0.56562	validation_1-logloss:0.59254
# [494]	validation_0-logloss:0.56552	validation_1-logloss:0.59251
# [495]	validation_0-logloss:0.56546	validation_1-logloss:0.59251
# [496]	validation_0-logloss:0.56543	validation_1-logloss:0.59252
# [497]	validation_0-logloss:0.56537	validation_1-logloss:0.59251
# [498]	validation_0-logloss:0.56532	validation_1-logloss:0.59251
# [499]	validation_0-logloss:0.56523	validation_1-logloss:0.59246
# [500]	validation_0-logloss:0.56517	validation_1-logloss:0.59244
# [501]	validation_0-logloss:0.56510	validation_1-logloss:0.59243
# [502]	validation_0-logloss:0.56503	validation_1-logloss:0.59241
# [503]	validation_0-logloss:0.56495	validation_1-logloss:0.59239
# [504]	validation_0-logloss:0.56486	validation_1-logloss:0.59235
# [505]	validation_0-logloss:0.56478	validation_1-logloss:0.59233
# [506]	validation_0-logloss:0.56470	validation_1-logloss:0.59232
# [507]	validation_0-logloss:0.56465	validation_1-logloss:0.59230
# [508]	validation_0-logloss:0.56460	validation_1-logloss:0.59231
# [509]	validation_0-logloss:0.56455	validation_1-logloss:0.59231
# [510]	validation_0-logloss:0.56448	validation_1-logloss:0.59231
# [511]	validation_0-logloss:0.56443	validation_1-logloss:0.59231
# [512]	validation_0-logloss:0.56437	validation_1-logloss:0.59231
# [513]	validation_0-logloss:0.56432	validation_1-logloss:0.59231
# [514]	validation_0-logloss:0.56425	validation_1-logloss:0.59230
# [515]	validation_0-logloss:0.56418	validation_1-logloss:0.59228
# [516]	validation_0-logloss:0.56412	validation_1-logloss:0.59225
# [517]	validation_0-logloss:0.56405	validation_1-logloss:0.59225
# [518]	validation_0-logloss:0.56401	validation_1-logloss:0.59225
# [519]	validation_0-logloss:0.56392	validation_1-logloss:0.59222
# [520]	validation_0-logloss:0.56385	validation_1-logloss:0.59222
# [521]	validation_0-logloss:0.56382	validation_1-logloss:0.59223
# [522]	validation_0-logloss:0.56377	validation_1-logloss:0.59225
# [523]	validation_0-logloss:0.56371	validation_1-logloss:0.59225
# [524]	validation_0-logloss:0.56365	validation_1-logloss:0.59224
# [525]	validation_0-logloss:0.56359	validation_1-logloss:0.59224
# [526]	validation_0-logloss:0.56353	validation_1-logloss:0.59222
# [527]	validation_0-logloss:0.56347	validation_1-logloss:0.59223
# [528]	validation_0-logloss:0.56344	validation_1-logloss:0.59223
# [529]	validation_0-logloss:0.56337	validation_1-logloss:0.59220
# [530]	validation_0-logloss:0.56331	validation_1-logloss:0.59220
# [531]	validation_0-logloss:0.56325	validation_1-logloss:0.59220
# [532]	validation_0-logloss:0.56321	validation_1-logloss:0.59220
# [533]	validation_0-logloss:0.56316	validation_1-logloss:0.59220
# [534]	validation_0-logloss:0.56309	validation_1-logloss:0.59218
# [535]	validation_0-logloss:0.56303	validation_1-logloss:0.59218
# [536]	validation_0-logloss:0.56298	validation_1-logloss:0.59216
# [537]	validation_0-logloss:0.56291	validation_1-logloss:0.59216
# [538]	validation_0-logloss:0.56284	validation_1-logloss:0.59213
# [539]	validation_0-logloss:0.56278	validation_1-logloss:0.59213
# [540]	validation_0-logloss:0.56273	validation_1-logloss:0.59211
# [541]	validation_0-logloss:0.56269	validation_1-logloss:0.59212
# [542]	validation_0-logloss:0.56263	validation_1-logloss:0.59211
# [543]	validation_0-logloss:0.56258	validation_1-logloss:0.59211
# [544]	validation_0-logloss:0.56252	validation_1-logloss:0.59209
# [545]	validation_0-logloss:0.56246	validation_1-logloss:0.59209
# [546]	validation_0-logloss:0.56240	validation_1-logloss:0.59210
# [547]	validation_0-logloss:0.56235	validation_1-logloss:0.59211
# [548]	validation_0-logloss:0.56229	validation_1-logloss:0.59210
# [549]	validation_0-logloss:0.56226	validation_1-logloss:0.59210
# [550]	validation_0-logloss:0.56219	validation_1-logloss:0.59209
# [551]	validation_0-logloss:0.56210	validation_1-logloss:0.59204
# [552]	validation_0-logloss:0.56202	validation_1-logloss:0.59200
# [553]	validation_0-logloss:0.56195	validation_1-logloss:0.59198
# [554]	validation_0-logloss:0.56191	validation_1-logloss:0.59197
# [555]	validation_0-logloss:0.56186	validation_1-logloss:0.59196
# [556]	validation_0-logloss:0.56179	validation_1-logloss:0.59195
# [557]	validation_0-logloss:0.56174	validation_1-logloss:0.59194
# [558]	validation_0-logloss:0.56168	validation_1-logloss:0.59194
# [559]	validation_0-logloss:0.56163	validation_1-logloss:0.59194
# [560]	validation_0-logloss:0.56159	validation_1-logloss:0.59194
# [561]	validation_0-logloss:0.56153	validation_1-logloss:0.59194
# [562]	validation_0-logloss:0.56147	validation_1-logloss:0.59193
# [563]	validation_0-logloss:0.56142	validation_1-logloss:0.59193
# [564]	validation_0-logloss:0.56135	validation_1-logloss:0.59195
# [565]	validation_0-logloss:0.56130	validation_1-logloss:0.59194
# [566]	validation_0-logloss:0.56126	validation_1-logloss:0.59194
# [567]	validation_0-logloss:0.56119	validation_1-logloss:0.59193
# [568]	validation_0-logloss:0.56112	validation_1-logloss:0.59194
# [569]	validation_0-logloss:0.56106	validation_1-logloss:0.59193
# [570]	validation_0-logloss:0.56100	validation_1-logloss:0.59193
# [571]	validation_0-logloss:0.56094	validation_1-logloss:0.59192
# [572]	validation_0-logloss:0.56088	validation_1-logloss:0.59193
# [573]	validation_0-logloss:0.56080	validation_1-logloss:0.59191
# [574]	validation_0-logloss:0.56074	validation_1-logloss:0.59192
# [575]	validation_0-logloss:0.56069	validation_1-logloss:0.59191
# [576]	validation_0-logloss:0.56063	validation_1-logloss:0.59192
# [577]	validation_0-logloss:0.56059	validation_1-logloss:0.59192
# [578]	validation_0-logloss:0.56053	validation_1-logloss:0.59190
# [579]	validation_0-logloss:0.56047	validation_1-logloss:0.59190
# [580]	validation_0-logloss:0.56042	validation_1-logloss:0.59190
# [581]	validation_0-logloss:0.56037	validation_1-logloss:0.59190
# [582]	validation_0-logloss:0.56032	validation_1-logloss:0.59190
# [583]	validation_0-logloss:0.56027	validation_1-logloss:0.59191
# [584]	validation_0-logloss:0.56022	validation_1-logloss:0.59191
# [585]	validation_0-logloss:0.56017	validation_1-logloss:0.59191
# [586]	validation_0-logloss:0.56012	validation_1-logloss:0.59192
# [587]	validation_0-logloss:0.56006	validation_1-logloss:0.59189
# [588]	validation_0-logloss:0.56000	validation_1-logloss:0.59191
# [589]	validation_0-logloss:0.55995	validation_1-logloss:0.59191
# [590]	validation_0-logloss:0.55989	validation_1-logloss:0.59190
# [591]	validation_0-logloss:0.55980	validation_1-logloss:0.59187
# [592]	validation_0-logloss:0.55971	validation_1-logloss:0.59184
# [593]	validation_0-logloss:0.55965	validation_1-logloss:0.59185
# [594]	validation_0-logloss:0.55959	validation_1-logloss:0.59186
# [595]	validation_0-logloss:0.55954	validation_1-logloss:0.59186
# [596]	validation_0-logloss:0.55950	validation_1-logloss:0.59186
# [597]	validation_0-logloss:0.55941	validation_1-logloss:0.59181
# [598]	validation_0-logloss:0.55935	validation_1-logloss:0.59180
# [599]	validation_0-logloss:0.55930	validation_1-logloss:0.59180
# [600]	validation_0-logloss:0.55924	validation_1-logloss:0.59179
# [601]	validation_0-logloss:0.55917	validation_1-logloss:0.59179
# [602]	validation_0-logloss:0.55911	validation_1-logloss:0.59178
# [603]	validation_0-logloss:0.55907	validation_1-logloss:0.59178
# [604]	validation_0-logloss:0.55900	validation_1-logloss:0.59178
# [605]	validation_0-logloss:0.55896	validation_1-logloss:0.59177
# [606]	validation_0-logloss:0.55892	validation_1-logloss:0.59175
# [607]	validation_0-logloss:0.55887	validation_1-logloss:0.59176
# [608]	validation_0-logloss:0.55879	validation_1-logloss:0.59172
# [609]	validation_0-logloss:0.55870	validation_1-logloss:0.59167
# [610]	validation_0-logloss:0.55865	validation_1-logloss:0.59168
# [611]	validation_0-logloss:0.55857	validation_1-logloss:0.59163
# [612]	validation_0-logloss:0.55852	validation_1-logloss:0.59165
# [613]	validation_0-logloss:0.55846	validation_1-logloss:0.59165
# [614]	validation_0-logloss:0.55840	validation_1-logloss:0.59164
# [615]	validation_0-logloss:0.55834	validation_1-logloss:0.59165
# [616]	validation_0-logloss:0.55827	validation_1-logloss:0.59165
# [617]	validation_0-logloss:0.55817	validation_1-logloss:0.59159
# [618]	validation_0-logloss:0.55809	validation_1-logloss:0.59157
# [619]	validation_0-logloss:0.55804	validation_1-logloss:0.59157
# [620]	validation_0-logloss:0.55798	validation_1-logloss:0.59155
# [621]	validation_0-logloss:0.55794	validation_1-logloss:0.59155
# [622]	validation_0-logloss:0.55787	validation_1-logloss:0.59155
# [623]	validation_0-logloss:0.55784	validation_1-logloss:0.59155
# [624]	validation_0-logloss:0.55779	validation_1-logloss:0.59156
# [625]	validation_0-logloss:0.55775	validation_1-logloss:0.59156
# [626]	validation_0-logloss:0.55770	validation_1-logloss:0.59154
# [627]	validation_0-logloss:0.55765	validation_1-logloss:0.59154
# [628]	validation_0-logloss:0.55761	validation_1-logloss:0.59154
# [629]	validation_0-logloss:0.55756	validation_1-logloss:0.59156
# [630]	validation_0-logloss:0.55751	validation_1-logloss:0.59157
# [631]	validation_0-logloss:0.55746	validation_1-logloss:0.59158
# [632]	validation_0-logloss:0.55740	validation_1-logloss:0.59158
# [633]	validation_0-logloss:0.55734	validation_1-logloss:0.59159
# [634]	validation_0-logloss:0.55728	validation_1-logloss:0.59158
# [635]	validation_0-logloss:0.55719	validation_1-logloss:0.59155
# [636]	validation_0-logloss:0.55713	validation_1-logloss:0.59155
# [637]	validation_0-logloss:0.55709	validation_1-logloss:0.59154
# [638]	validation_0-logloss:0.55701	validation_1-logloss:0.59152
# [639]	validation_0-logloss:0.55695	validation_1-logloss:0.59151
# [640]	validation_0-logloss:0.55688	validation_1-logloss:0.59150
# [641]	validation_0-logloss:0.55681	validation_1-logloss:0.59148
# [642]	validation_0-logloss:0.55672	validation_1-logloss:0.59147
# [643]	validation_0-logloss:0.55667	validation_1-logloss:0.59146
# [644]	validation_0-logloss:0.55660	validation_1-logloss:0.59147
# [645]	validation_0-logloss:0.55655	validation_1-logloss:0.59146
# [646]	validation_0-logloss:0.55649	validation_1-logloss:0.59146
# [647]	validation_0-logloss:0.55643	validation_1-logloss:0.59145
# [648]	validation_0-logloss:0.55638	validation_1-logloss:0.59146
# [649]	validation_0-logloss:0.55631	validation_1-logloss:0.59144
# [650]	validation_0-logloss:0.55625	validation_1-logloss:0.59143
# [651]	validation_0-logloss:0.55619	validation_1-logloss:0.59142
# [652]	validation_0-logloss:0.55613	validation_1-logloss:0.59143
# [653]	validation_0-logloss:0.55609	validation_1-logloss:0.59143
# [654]	validation_0-logloss:0.55603	validation_1-logloss:0.59143
# [655]	validation_0-logloss:0.55600	validation_1-logloss:0.59144
# [656]	validation_0-logloss:0.55597	validation_1-logloss:0.59144
# [657]	validation_0-logloss:0.55592	validation_1-logloss:0.59144
# [658]	validation_0-logloss:0.55585	validation_1-logloss:0.59144
# [659]	validation_0-logloss:0.55579	validation_1-logloss:0.59144
# [660]	validation_0-logloss:0.55574	validation_1-logloss:0.59145
# [661]	validation_0-logloss:0.55568	validation_1-logloss:0.59145
# [662]	validation_0-logloss:0.55561	validation_1-logloss:0.59145
# [663]	validation_0-logloss:0.55555	validation_1-logloss:0.59145
# [664]	validation_0-logloss:0.55549	validation_1-logloss:0.59143
# [665]	validation_0-logloss:0.55543	validation_1-logloss:0.59142
# [666]	validation_0-logloss:0.55537	validation_1-logloss:0.59141
# [667]	validation_0-logloss:0.55531	validation_1-logloss:0.59141
# [668]	validation_0-logloss:0.55525	validation_1-logloss:0.59142
# [669]	validation_0-logloss:0.55519	validation_1-logloss:0.59141
# [670]	validation_0-logloss:0.55514	validation_1-logloss:0.59141
# [671]	validation_0-logloss:0.55508	validation_1-logloss:0.59138
# [672]	validation_0-logloss:0.55502	validation_1-logloss:0.59138
# [673]	validation_0-logloss:0.55496	validation_1-logloss:0.59136
# [674]	validation_0-logloss:0.55491	validation_1-logloss:0.59135
# [675]	validation_0-logloss:0.55485	validation_1-logloss:0.59133
# [676]	validation_0-logloss:0.55479	validation_1-logloss:0.59134
# [677]	validation_0-logloss:0.55474	validation_1-logloss:0.59133
# [678]	validation_0-logloss:0.55468	validation_1-logloss:0.59132
# [679]	validation_0-logloss:0.55463	validation_1-logloss:0.59132
# [680]	validation_0-logloss:0.55456	validation_1-logloss:0.59132
# [681]	validation_0-logloss:0.55450	validation_1-logloss:0.59130
# [682]	validation_0-logloss:0.55444	validation_1-logloss:0.59131
# [683]	validation_0-logloss:0.55439	validation_1-logloss:0.59130
# [684]	validation_0-logloss:0.55433	validation_1-logloss:0.59130
# [685]	validation_0-logloss:0.55427	validation_1-logloss:0.59129
# [686]	validation_0-logloss:0.55421	validation_1-logloss:0.59128
# [687]	validation_0-logloss:0.55416	validation_1-logloss:0.59127
# [688]	validation_0-logloss:0.55412	validation_1-logloss:0.59126
# [689]	validation_0-logloss:0.55405	validation_1-logloss:0.59126
# [690]	validation_0-logloss:0.55400	validation_1-logloss:0.59127
# [691]	validation_0-logloss:0.55395	validation_1-logloss:0.59127
# [692]	validation_0-logloss:0.55392	validation_1-logloss:0.59127
# [693]	validation_0-logloss:0.55387	validation_1-logloss:0.59127
# [694]	validation_0-logloss:0.55380	validation_1-logloss:0.59124
# [695]	validation_0-logloss:0.55374	validation_1-logloss:0.59123
# [696]	validation_0-logloss:0.55365	validation_1-logloss:0.59121
# [697]	validation_0-logloss:0.55360	validation_1-logloss:0.59123
# [698]	validation_0-logloss:0.55355	validation_1-logloss:0.59123
# [699]	validation_0-logloss:0.55349	validation_1-logloss:0.59124
# [700]	validation_0-logloss:0.55344	validation_1-logloss:0.59124
# [701]	validation_0-logloss:0.55338	validation_1-logloss:0.59123
# [702]	validation_0-logloss:0.55330	validation_1-logloss:0.59118
# [703]	validation_0-logloss:0.55325	validation_1-logloss:0.59117
# [704]	validation_0-logloss:0.55321	validation_1-logloss:0.59115
# [705]	validation_0-logloss:0.55316	validation_1-logloss:0.59115
# [706]	validation_0-logloss:0.55309	validation_1-logloss:0.59114
# [707]	validation_0-logloss:0.55303	validation_1-logloss:0.59113
# [708]	validation_0-logloss:0.55298	validation_1-logloss:0.59113
# [709]	validation_0-logloss:0.55293	validation_1-logloss:0.59113
# [710]	validation_0-logloss:0.55288	validation_1-logloss:0.59112
# [711]	validation_0-logloss:0.55284	validation_1-logloss:0.59114
# [712]	validation_0-logloss:0.55275	validation_1-logloss:0.59110
# [713]	validation_0-logloss:0.55267	validation_1-logloss:0.59109
# [714]	validation_0-logloss:0.55261	validation_1-logloss:0.59109
# [715]	validation_0-logloss:0.55255	validation_1-logloss:0.59107
# [716]	validation_0-logloss:0.55249	validation_1-logloss:0.59108
# [717]	validation_0-logloss:0.55244	validation_1-logloss:0.59109
# [718]	validation_0-logloss:0.55239	validation_1-logloss:0.59109
# [719]	validation_0-logloss:0.55233	validation_1-logloss:0.59110
# [720]	validation_0-logloss:0.55228	validation_1-logloss:0.59109
# [721]	validation_0-logloss:0.55219	validation_1-logloss:0.59105
# [722]	validation_0-logloss:0.55214	validation_1-logloss:0.59104
# [723]	validation_0-logloss:0.55209	validation_1-logloss:0.59105
# [724]	validation_0-logloss:0.55204	validation_1-logloss:0.59103
# [725]	validation_0-logloss:0.55200	validation_1-logloss:0.59102
# [726]	validation_0-logloss:0.55194	validation_1-logloss:0.59103
# [727]	validation_0-logloss:0.55190	validation_1-logloss:0.59104
# [728]	validation_0-logloss:0.55186	validation_1-logloss:0.59105
# [729]	validation_0-logloss:0.55181	validation_1-logloss:0.59105
# [730]	validation_0-logloss:0.55175	validation_1-logloss:0.59106
# [731]	validation_0-logloss:0.55169	validation_1-logloss:0.59105
# [732]	validation_0-logloss:0.55164	validation_1-logloss:0.59106
# [733]	validation_0-logloss:0.55159	validation_1-logloss:0.59107
# [734]	validation_0-logloss:0.55153	validation_1-logloss:0.59107
# [735]	validation_0-logloss:0.55149	validation_1-logloss:0.59107
# [736]	validation_0-logloss:0.55144	validation_1-logloss:0.59106
# [737]	validation_0-logloss:0.55141	validation_1-logloss:0.59107
# [738]	validation_0-logloss:0.55137	validation_1-logloss:0.59108
# [739]	validation_0-logloss:0.55132	validation_1-logloss:0.59106
# [740]	validation_0-logloss:0.55124	validation_1-logloss:0.59104
# [741]	validation_0-logloss:0.55120	validation_1-logloss:0.59104
# [742]	validation_0-logloss:0.55115	validation_1-logloss:0.59104
# [743]	validation_0-logloss:0.55109	validation_1-logloss:0.59103
# [744]	validation_0-logloss:0.55103	validation_1-logloss:0.59103
# [745]	validation_0-logloss:0.55097	validation_1-logloss:0.59102
# [746]	validation_0-logloss:0.55089	validation_1-logloss:0.59101
# [747]	validation_0-logloss:0.55083	validation_1-logloss:0.59101
# [748]	validation_0-logloss:0.55078	validation_1-logloss:0.59101
# [749]	validation_0-logloss:0.55073	validation_1-logloss:0.59100
# [750]	validation_0-logloss:0.55068	validation_1-logloss:0.59101
# [751]	validation_0-logloss:0.55063	validation_1-logloss:0.59100
# [752]	validation_0-logloss:0.55056	validation_1-logloss:0.59099
# [753]	validation_0-logloss:0.55050	validation_1-logloss:0.59099
# [754]	validation_0-logloss:0.55047	validation_1-logloss:0.59100
# [755]	validation_0-logloss:0.55041	validation_1-logloss:0.59101
# [756]	validation_0-logloss:0.55034	validation_1-logloss:0.59099
# [757]	validation_0-logloss:0.55029	validation_1-logloss:0.59099
# [758]	validation_0-logloss:0.55023	validation_1-logloss:0.59100
# [759]	validation_0-logloss:0.55018	validation_1-logloss:0.59101
# [760]	validation_0-logloss:0.55013	validation_1-logloss:0.59100
# [761]	validation_0-logloss:0.55006	validation_1-logloss:0.59099
# [762]	validation_0-logloss:0.55001	validation_1-logloss:0.59100
# [763]	validation_0-logloss:0.54997	validation_1-logloss:0.59099
# [764]	validation_0-logloss:0.54992	validation_1-logloss:0.59099
# [765]	validation_0-logloss:0.54986	validation_1-logloss:0.59099
# [766]	validation_0-logloss:0.54980	validation_1-logloss:0.59098
# [767]	validation_0-logloss:0.54975	validation_1-logloss:0.59099
# [768]	validation_0-logloss:0.54968	validation_1-logloss:0.59095
# [769]	validation_0-logloss:0.54964	validation_1-logloss:0.59097
# [770]	validation_0-logloss:0.54956	validation_1-logloss:0.59094
# [771]	validation_0-logloss:0.54948	validation_1-logloss:0.59093
# [772]	validation_0-logloss:0.54945	validation_1-logloss:0.59092
# [773]	validation_0-logloss:0.54940	validation_1-logloss:0.59092
# [774]	validation_0-logloss:0.54933	validation_1-logloss:0.59090
# [775]	validation_0-logloss:0.54930	validation_1-logloss:0.59090
# [776]	validation_0-logloss:0.54924	validation_1-logloss:0.59091
# [777]	validation_0-logloss:0.54917	validation_1-logloss:0.59089
# [778]	validation_0-logloss:0.54906	validation_1-logloss:0.59081
# [779]	validation_0-logloss:0.54901	validation_1-logloss:0.59081
# [780]	validation_0-logloss:0.54895	validation_1-logloss:0.59079
# [781]	validation_0-logloss:0.54889	validation_1-logloss:0.59078
# [782]	validation_0-logloss:0.54883	validation_1-logloss:0.59077
# [783]	validation_0-logloss:0.54878	validation_1-logloss:0.59078
# [784]	validation_0-logloss:0.54872	validation_1-logloss:0.59079
# [785]	validation_0-logloss:0.54868	validation_1-logloss:0.59078
# [786]	validation_0-logloss:0.54863	validation_1-logloss:0.59078
# [787]	validation_0-logloss:0.54858	validation_1-logloss:0.59078
# [788]	validation_0-logloss:0.54854	validation_1-logloss:0.59080
# [789]	validation_0-logloss:0.54848	validation_1-logloss:0.59081
# [790]	validation_0-logloss:0.54843	validation_1-logloss:0.59081
# [791]	validation_0-logloss:0.54836	validation_1-logloss:0.59079
# [792]	validation_0-logloss:0.54829	validation_1-logloss:0.59079
# [793]	validation_0-logloss:0.54825	validation_1-logloss:0.59080
# [794]	validation_0-logloss:0.54821	validation_1-logloss:0.59080
# [795]	validation_0-logloss:0.54815	validation_1-logloss:0.59082
# [796]	validation_0-logloss:0.54808	validation_1-logloss:0.59080
# [797]	validation_0-logloss:0.54802	validation_1-logloss:0.59078
# [798]	validation_0-logloss:0.54797	validation_1-logloss:0.59078
# [799]	validation_0-logloss:0.54793	validation_1-logloss:0.59080
# [800]	validation_0-logloss:0.54788	validation_1-logloss:0.59079
# [801]	validation_0-logloss:0.54783	validation_1-logloss:0.59078
# [802]	validation_0-logloss:0.54777	validation_1-logloss:0.59077
# [803]	validation_0-logloss:0.54771	validation_1-logloss:0.59076
# [804]	validation_0-logloss:0.54765	validation_1-logloss:0.59076
# [805]	validation_0-logloss:0.54761	validation_1-logloss:0.59078
# [806]	validation_0-logloss:0.54758	validation_1-logloss:0.59078
# [807]	validation_0-logloss:0.54752	validation_1-logloss:0.59079
# [808]	validation_0-logloss:0.54748	validation_1-logloss:0.59080
# [809]	validation_0-logloss:0.54742	validation_1-logloss:0.59080
# [810]	validation_0-logloss:0.54738	validation_1-logloss:0.59081
# [811]	validation_0-logloss:0.54733	validation_1-logloss:0.59080
# [812]	validation_0-logloss:0.54729	validation_1-logloss:0.59080
# [813]	validation_0-logloss:0.54724	validation_1-logloss:0.59081
# [814]	validation_0-logloss:0.54719	validation_1-logloss:0.59081
# [815]	validation_0-logloss:0.54713	validation_1-logloss:0.59082
# [816]	validation_0-logloss:0.54708	validation_1-logloss:0.59083
# [817]	validation_0-logloss:0.54702	validation_1-logloss:0.59083
# [818]	validation_0-logloss:0.54697	validation_1-logloss:0.59082
# [819]	validation_0-logloss:0.54693	validation_1-logloss:0.59082
# [820]	validation_0-logloss:0.54688	validation_1-logloss:0.59082
# [821]	validation_0-logloss:0.54683	validation_1-logloss:0.59082
# [822]	validation_0-logloss:0.54678	validation_1-logloss:0.59082
# [823]	validation_0-logloss:0.54674	validation_1-logloss:0.59082
# [824]	validation_0-logloss:0.54668	validation_1-logloss:0.59080
# [825]	validation_0-logloss:0.54663	validation_1-logloss:0.59082
# [826]	validation_0-logloss:0.54657	validation_1-logloss:0.59082
# [827]	validation_0-logloss:0.54653	validation_1-logloss:0.59082
# [828]	validation_0-logloss:0.54646	validation_1-logloss:0.59083
# [829]	validation_0-logloss:0.54641	validation_1-logloss:0.59083
# [830]	validation_0-logloss:0.54635	validation_1-logloss:0.59083
# [831]	validation_0-logloss:0.54630	validation_1-logloss:0.59084
# [832]	validation_0-logloss:0.54624	validation_1-logloss:0.59083
# [833]	validation_0-logloss:0.54619	validation_1-logloss:0.59083
# [834]	validation_0-logloss:0.54614	validation_1-logloss:0.59083
# [835]	validation_0-logloss:0.54610	validation_1-logloss:0.59082
# [836]	validation_0-logloss:0.54602	validation_1-logloss:0.59079
# [837]	validation_0-logloss:0.54598	validation_1-logloss:0.59079
# [838]	validation_0-logloss:0.54593	validation_1-logloss:0.59080
# [839]	validation_0-logloss:0.54588	validation_1-logloss:0.59079
# [840]	validation_0-logloss:0.54582	validation_1-logloss:0.59078
# [841]	validation_0-logloss:0.54576	validation_1-logloss:0.59078
# [842]	validation_0-logloss:0.54571	validation_1-logloss:0.59077
# [843]	validation_0-logloss:0.54567	validation_1-logloss:0.59078
# [844]	validation_0-logloss:0.54562	validation_1-logloss:0.59078
# [845]	validation_0-logloss:0.54558	validation_1-logloss:0.59078
# [846]	validation_0-logloss:0.54553	validation_1-logloss:0.59077
# [847]	validation_0-logloss:0.54548	validation_1-logloss:0.59077
# [848]	validation_0-logloss:0.54542	validation_1-logloss:0.59077
# [849]	validation_0-logloss:0.54537	validation_1-logloss:0.59077
# [850]	validation_0-logloss:0.54532	validation_1-logloss:0.59078
# [851]	validation_0-logloss:0.54527	validation_1-logloss:0.59079
# [852]	validation_0-logloss:0.54522	validation_1-logloss:0.59078
# [853]	validation_0-logloss:0.54516	validation_1-logloss:0.59078

# %%
# LOAD
classifier_spin = XGBClassifier()
classifier_spin.load_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta07.json")


y_score = classifier_spin.predict_proba(X_test_spin)[:, 1]


fpr, tpr, thresholds = roc_curve(y_test_spin, y_score)
roc_auc = roc_auc_score(y_test_spin, y_score)

print("Global AUC =", roc_auc)


plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + 'saved-results/ROC_classB.pdf', bbox_inches='tight')
plt.show()




keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$',
                #  r'$m_{\mathrm{LQ}}^{\mathrm{reg}}$',
                 r'$S_{\mathrm{Poiss}}$'])

feature_important = classifier_spin.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())


data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=12).remove()
plt.title(r'SLQ vs VLQ', fontsize=14)
# plt.savefig(mainfolder + 'saved-results/XG_feature_importance_classB.pdf', bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Global AUC = 0.7447841617919999
# [52, 19, 22, 53, 35, 18, 15, 9, 38, 36, 37, 45, 48, 46, 3]

# %%
S_column = X_test_spin[:, -1]

# mSLQ_plot = [1200, 1500, 1800]
# mVLQ_plot = [1600, 1900, 2200]

linestyles = ['-','-','-', '--','--','--', ':', ':', ':']
# colors_SLQ = ['lightcoral', 'red', 'firebrick']
# colors_VLQ = ['limegreen', 'green', 'darkgreen']

plt.figure(figsize=(6,5))

# evaluate per sector
for iit, S_id in enumerate(S_expected_SLQ):
    # if iit == 0 or iit == 1 or iit == 9:
    #     continue
    # else:
    if iit == 2 or iit == 5 or iit == 8:

        mask = (S_column < S_id * 1.1) & (0.9 * S_id < S_column)

        y_true_Spoiss = y_test_spin[mask]
        y_score_Spoiss = y_score[mask]

        fpr, tpr, _ = roc_curve(y_true_Spoiss, y_score_Spoiss)
        auc_sector = roc_auc_score(y_true_Spoiss, y_score_Spoiss)

        print(f"$m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV,   AUC = {auc_sector:.5f}")


        plt.plot(fpr, tpr, color='darkorange', linestyle=linestyles[iit], lw=2, label=f"AUC = {auc_sector:.3f}, $m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV - $m_{{LQ_3^V}}=${masses_VLQ[iit]} GeV")



plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=11.3)
# plt.savefig(mainfolder + 'saved-results/ROC_classB_multi.pdf', bbox_inches='tight')
plt.show()
# Out:
# $m_{LQ_3^S}=$1200 GeV,   AUC = 0.77103
# $m_{LQ_3^S}=$1500 GeV,   AUC = 0.73489
# $m_{LQ_3^S}=$1800 GeV,   AUC = 0.70765

# %% [markdown]
# # JOIN BOTH ML

# %%
# --- Clasificador A: SM vs LQ ---

scoresA_SM = xgb_clf.predict_proba( df_SM_norm )[:,1]

scoresA_SLQ = {}
scoresA_VLQ = {}

m_SLQ = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
m_VLQ = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

S_exp_SLQ = S_expected_SLQ[2:]
S_exp_both = S_mean_fit_both[2:]

for m in m_SLQ:
    scoresA_SLQ[m] = xgb_clf.predict_proba( df_SLQ_norm[m] )[:,1]

for m in m_VLQ:
    scoresA_VLQ[m] = xgb_clf.predict_proba( df_VLQ_norm[m] )[:,1]

# %%
# --- Clasificador B: SLQ vs VLQ ---

X_sm = df_SM_norm

rand_samples_B =np.random.randint(1, S_exp_both[0] + S_std_fit_both[0], size=len(X_sm))

X_sm = np.column_stack([X_sm, rand_samples_B])

scoresB_SM = classifier_spin.predict_proba(X_sm)[:,1]


scoresB_SLQ = {}
scoresB_VLQ = {}

for iit, S_id in enumerate(m_SLQ):

    X_s = df_SLQ_norm[m_SLQ[iit]].values
    X_v = df_VLQ_norm[m_VLQ[iit]].values

    poisson_samples_SLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_s))
    poisson_samples_VLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_v))

    X_s = np.column_stack([X_s, poisson_samples_SLQ])
    X_v = np.column_stack([X_v, poisson_samples_VLQ])

    scoresB_SLQ[m_SLQ[iit]] = classifier_spin.predict_proba(X_s)[:,1]
    scoresB_VLQ[m_VLQ[iit]] = classifier_spin.predict_proba(X_v)[:,1]

# %%
# --- Juntar los scores del clasificador A y B

events_SM = np.column_stack([scoresA_SM, scoresB_SM])

events_SLQ = {}
for m in scoresA_SLQ:
    events_SLQ[m] = np.column_stack([scoresA_SLQ[m], scoresB_SLQ[m]])

events_VLQ = {}
for m in scoresA_VLQ:
    events_VLQ[m] = np.column_stack([scoresA_VLQ[m], scoresB_VLQ[m]])

# %% [markdown]
# #### Define the test statistic

# %%
def compute_test_statistic(scoresA, scoresB, threshold):
    """
    Sum of Log-Likelihood Ratios (LLR)

    T = Sum log (P(VLQ) / P(SLQ))

    P(VLQ) = score SLQ vs VLQ classifier
    P(SLQ) = 1 - score SLQ vs VLQ classifier
    """

    mask = scoresA > threshold

    scoresB_sel = scoresB[mask]

    if len(scoresB_sel) == 0:
        return 0

    eps = 1e-6
    s = np.clip(scoresB_sel, eps, 1-eps)

    T = np.sum(np.log(s/(1-s)))

    return T

# %% [markdown]
# ### For all the masses

# %%
# funcion para generar pseudo experimentos (da los scores de ambos clasificadores para ese pseudo)

def generate_pseudo(events_B, events_S, N_B, N_S):

    sample_B = events_B[np.random.randint(len(events_B), size=N_B)]
    sample_S = events_S[np.random.randint(len(events_S), size=N_S)]

    sample_all = np.vstack([sample_B, sample_S])

    scoresA = sample_all[:,0]
    scoresB = sample_all[:,1]

    return scoresA, scoresB

# %%
B_expected = 45962

S_exp_SLQ = [round(fid_xsec_SLQ_14TeV(mmm, beta) * Lum) for mmm in m_SLQ]
S_exp_VLQ = [round(fid_xsec_VLQ_14TeV(mmm, beta) * Lum) for mmm in m_VLQ]

print('beta = ', beta)
print('\nB_expected: ', B_expected)
print('\nS_exp_SLQ: ', S_exp_SLQ, '   m =', m_SLQ)
print('S_exp_VLQ: ', S_exp_VLQ, '   m =', m_VLQ)
print('S_exp_both: ', S_exp_both)
# Out:
# beta =  0.7
#
# B_expected:  45962
#
# S_exp_SLQ:  [753, 426, 241, 140, 81, 47, 27, 16]    m = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_exp_VLQ:  [808, 473, 277, 166, 99, 60, 37, 22]    m = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_exp_both:  [np.float64(724.2043317208654), np.float64(420.98683583859815), np.float64(244.74156797791886), np.float64(145.05385013985654), np.float64(84.98739588326987), np.float64(49.33322765809169), np.float64(28.75639331917492), np.float64(17.179103558013942)]

# %% [markdown]
# #### Distribution of the statistic with only SLQ and only VLQ

# %%
n_pseudo_TRUE = 1000
threshold_A = 0.95

# %%
mu_S = []
mu_V = []

sigma_S = []
sigma_V = []

for S_it in range(len(S_exp_SLQ)):

    print("\n==========================")
    print("S_expected SLQ =", S_exp_SLQ[S_it])
    # print("S_expected VLQ =", S_exp_VLQ[S_it]) # same number of events

    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[S_it]
    mass_VLQ = m_VLQ[S_it]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    for i in range(n_pseudo_TRUE):

        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_exp_SLQ[S_it])

        scoresA, scoresB = generate_pseudo( events_SM, events_SLQ[mass_SLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)


        N_S = np.random.poisson(S_exp_SLQ[S_it]) # same number of events

        scoresA, scoresB = generate_pseudo( events_SM, events_VLQ[mass_VLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

        # Compute the Z of the distributions
    mu_S.append( np.mean(T_SLQ) )
    mu_V.append( np.mean(T_VLQ) )

    sigma_S.append( np.std(T_SLQ) )
    sigma_V.append( np.std(T_VLQ) )

print(mu_S)
print(mu_V)

print(sigma_S)
print(sigma_V)
# Out:
# ==========================
# S_expected SLQ = 753
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
#
# ==========================
# S_expected SLQ = 426
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
#
# ==========================
# S_expected SLQ = 241
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
#
# ==========================
# S_expected SLQ = 140
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
#
# ==========================
# S_expected SLQ = 81
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
#
# ==========================
# S_expected SLQ = 47
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
#
# ==========================
# S_expected SLQ = 27
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
#
# ==========================
# S_expected SLQ = 16
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# [np.float32(-312.2101), np.float32(-188.30951), np.float32(-112.42225), np.float32(-73.50338), np.float32(-52.28207), np.float32(-39.499775), np.float32(-33.452568), np.float32(-29.234148)]
# [np.float32(479.89594), np.float32(223.19696), np.float32(97.094734), np.float32(37.328075), np.float32(5.9496965), np.float32(-8.238865), np.float32(-15.655434), np.float32(-19.671894)]
# [np.float32(26.671282), np.float32(19.687319), np.float32(16.46303), np.float32(13.48001), np.float32(12.060305), np.float32(11.386701), np.float32(10.578481), np.float32(10.551025)]
# [np.float32(38.6999), np.float32(26.839252), np.float32(20.875088), np.float32(16.497324), np.float32(13.351413), np.float32(12.558369), np.float32(11.075901), np.float32(10.458546)]

# %%
f_mu_S = interp1d(S_exp_SLQ, mu_S, kind='linear', fill_value="extrapolate")
f_mu_V = interp1d(S_exp_SLQ, mu_V, kind='linear', fill_value="extrapolate")

f_sigma_S = interp1d(S_exp_SLQ, sigma_S, kind='linear', fill_value="extrapolate")
f_sigma_V = interp1d(S_exp_SLQ, sigma_V, kind='linear', fill_value="extrapolate")



S_plot = np.linspace(min(S_exp_SLQ), max(S_exp_SLQ), 100)



plt.scatter(S_exp_SLQ, mu_S, marker='o')
plt.plot(S_plot, f_mu_S(S_plot))
plt.scatter(S_exp_SLQ, mu_V, marker='o')
plt.plot(S_plot, f_mu_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\mu$", fontsize=14)

plt.grid()
plt.show()


plt.scatter(S_exp_SLQ, sigma_S, marker='o')
plt.plot(S_plot, f_sigma_S(S_plot))
plt.scatter(S_exp_SLQ, sigma_V, marker='o')
plt.plot(S_plot, f_sigma_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\sigma$", fontsize=14)

plt.grid()
plt.show()

# %%
Z_threshold = 5

results_Z_gauss = []

for pair_it in range(len(mu_S)):
    Z = abs(mu_V[pair_it] - mu_S[pair_it]) / np.sqrt(sigma_S[pair_it]**2 + sigma_V[pair_it]**2)

    results_Z_gauss.append(Z)


plt.plot(S_exp_SLQ, results_Z_gauss, marker='o')

plt.xlabel("Expected signal events", fontsize=14)
plt.ylabel("Distribution discrimination Z", fontsize=14)

plt.grid()
plt.show()


#  interpolate
f_results_Z = interp1d(S_exp_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mSLQ = interp1d(m_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mVLQ = interp1d(m_VLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")


# find the S or the mass such that we get Z_threshold
S_threshold = fsolve(lambda x: f_results_Z(x) - Z_threshold,150)[0]
mSLQ_threshold = fsolve(lambda x: f_results_Z_mSLQ(x) - Z_threshold,1500)[0]
mVLQ_threshold = fsolve(lambda x: f_results_Z_mVLQ(x) - Z_threshold,1900)[0]

print(' Z:       ', Z_threshold)
print(' S:       ', S_threshold)
print(' m_SLQ:   ', mSLQ_threshold, ' [GeV]')
print(' m_VLQ:   ', mVLQ_threshold, ' [GeV]\n')
# Out:
#  Z:        5
#  S:        133.92796457792073
#  m_SLQ:    1510.2915854611513  [GeV]
#  m_VLQ:    1910.2915854611513  [GeV]
# /tmp/ipykernel_750/699503059.py:28: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   mSLQ_threshold = fsolve(lambda x: f_results_Z_mSLQ(x) - Z_threshold,1500)[0]
# /tmp/ipykernel_750/699503059.py:29: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   mVLQ_threshold = fsolve(lambda x: f_results_Z_mVLQ(x) - Z_threshold,1900)[0]

# %% [markdown]
# #### Prepare the data

# %% [markdown]
# ##### To compute S_expected for each pseudo using the 1st classifier we need the PDFs

# %%
# --- Clasificador A: SM vs LQ ---

# output of all the signal events
scoresA_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]



bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scoresA_SM, bins=bins, density=True)
hist_S, _ = np.histogram(scoresA_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %% [markdown]
# ##### to compute the closest mass/index/bechmark

# %%
def search_bench(S_pseudo, S_list_means, S_list_std, masses_list=None):
    """ finds the index of the closest benchmark

    Inputs:
    -----------
    S_pseudo : float -> S computed or fitted (e.g. muS_fits_SLQ[i]).
    S_list_means : list/array -> S_mean_fit_both_NEW.
    S_list_std : list/array -> S_std_fit_both_NEW.
    masses_list : list/array (optional) -> masses_NEW.

    Outputs:
    --------
    if masses_list es None -> returns only the index
    if masses_list se incluye -> returns (index, closest mass).
    """
    # convert to array
    means = np.array(S_list_means)
    stds = np.array(S_list_std)

    # do not divide by 0
    stds = np.where(stds == 0, 1e-10, stds)

    # compute the distance to the means, weighted by the std
    z_scores = np.abs(S_pseudo - means) / stds

    # seach the closest index
    idx_min = np.argmin(z_scores)

    # if you also want the mass
    if masses_list is not None:
        best_mass = masses_list[idx_min]
        return idx_min, best_mass

    return idx_min

# %% [markdown]
# ### Super loop

# %%
Z_threshold = 1.96

n_pseudo = 1000

# benchmarks
classification_SLQ_BPOK = []
classification_VLQ_BPOK = []

# interpolate
classification_SLQ_inter = []
classification_VLQ_inter = []

# previously known PDFs
classification_SLQ_prev = []
classification_VLQ_prev = []


Z_SLQ_BPOK = []
Z_VLQ_BPOK = []

Z_SLQ_inter = []
Z_VLQ_inter = []

Z_SLQ_prev = []
Z_VLQ_prev = []


mu_TSLQ = []
std_TSLQ = []
mu_TVLQ = []
std_TVLQ = []



for ii_S, S_exp in enumerate(S_exp_SLQ):

    print("\n==========================")

    print("S_expected_SLQ =", S_exp_SLQ[ii_S])
    # print("S_expected_VLQ =", S_exp_VLQ[ii_S]) # same number of events


    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[ii_S]
    mass_VLQ = m_VLQ[ii_S]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    # compute the number of events
    muS_fits_SLQ = []
    muS_fits_VLQ = []


    for i in range(n_pseudo):

        N_B = np.random.poisson(B_expected)

        # indices of the events
        idx_B = np.random.choice(len(events_SM[:,0]), N_B)

        scoresA_B = events_SM[:,0][idx_B]
        scoresB_B = events_SM[:,1][idx_B]



        ###########
        # FOR SLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S])

        # indices of the events
        idx_S = np.random.choice(len(events_SLQ[mass_SLQ][:,0]), N_S)

        scoresA_S = events_SLQ[mass_SLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_SLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_S = df_SLQ_norm[mass_SLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_S = np.column_stack([X_pseudo_S, np.full(len(X_pseudo_S), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_S)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)




        ###########
        # FOR VLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S]) # same number of events

        # indices of the events
        idx_S = np.random.choice(len(events_VLQ[mass_VLQ][:,0]), N_S)

        scoresA_S = events_VLQ[mass_VLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_VLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_V = df_VLQ_norm[mass_VLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_V = np.column_stack([X_pseudo_V, np.full(len(X_pseudo_V), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_V)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

    # Compute the characteristics of the psedo-experiment T distributions
    mu_TSLQ.append( np.mean(T_SLQ) )
    mu_TVLQ.append( np.mean(T_VLQ) )

    std_TSLQ.append( np.std(T_SLQ) )
    std_TVLQ.append( np.std(T_VLQ) )




    # rango común para plotear
    xmin = min(np.min(T_SLQ), np.min(T_VLQ))
    xmax = max(np.max(T_SLQ), np.max(T_VLQ))
    x = np.linspace(xmin, xmax, 500)

    # gaussianas
    gauss_S = (1/(sigma_S[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_S[ii_S])**2 / (2*sigma_S[ii_S]**2))
    gauss_V = (1/(sigma_V[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_V[ii_S])**2 / (2*sigma_V[ii_S]**2))


    # plot gaussian PDFs + pseudo-experiments (of the same sector) distributions
    plt.figure(figsize=(6,5))

    plt.hist(T_SLQ, bins=20, density=True, color='red', alpha=0.6, label="SLQ pseudos")
    plt.hist(T_VLQ, bins=20, density=True, color='green', alpha=0.6, label="VLQ pseudos")

    # gaussianas
    plt.plot(x, gauss_S, color='darkred', linewidth=2, linestyle='--', label=f"Gaussian SLQ true\nμ={mu_S[ii_S]:.2f}, σ={sigma_S[ii_S]:.2f}")
    plt.plot(x, gauss_V, color='darkgreen', linewidth=2, linestyle='--', label=f"Gaussian VLQ true\nμ={mu_V[ii_S]:.2f}, σ={sigma_V[ii_S]:.2f}")

    plt.xlabel("Test statistic T")
    plt.ylabel("Probability density")
    plt.title(f"S_expected = {S_exp}")
    plt.legend()

    plt.show()


    plt.hist(muS_fits_SLQ, bins=10, histtype='step', linestyle='--', edgecolor='red', linewidth=2, density=True)
    plt.hist(muS_fits_SLQ, bins=10, color='red', alpha=0.6, density=True)
    plt.hist(muS_fits_VLQ, bins=10, histtype='step', linestyle=':', edgecolor='green', linewidth=2, density=True)
    plt.hist(muS_fits_VLQ, bins=10, color='green', alpha=0.6, density=True)
    plt.xlabel("S")
    plt.ylabel("Fraction (prediction)")
    plt.show()

    print('S mean SLQ: ', np.mean(muS_fits_SLQ))
    print('S std SLQ: ', np.std(muS_fits_SLQ))
    print('S mean VLQ: ', np.mean(muS_fits_VLQ))
    print('S std VLQ: ', np.std(muS_fits_VLQ))
    print('')


    # COMPARING WITH DISCRETE MASS EXAMPLES (following S)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_BPOK_step = []
    Z_VLQ_BPOK_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        index_pseudo = search_bench(muS_fits_SLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_SLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        index_pseudo = search_bench(muS_fits_VLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_VLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_BPOK.append(np.array(Z_SLQ_BPOK_step))
    Z_VLQ_BPOK.append(np.array(Z_VLQ_BPOK_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH DISCRETE MASS EXAMPLES (following S) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_BPOK.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_BPOK.append(pred_counts_VLQ)





    # COMPARING WITH CONTINUOUS MASSES (interpolation)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_inter_step = []
    Z_VLQ_inter_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_SLQ[i])) / f_sigma_S(muS_fits_SLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_SLQ[i])) / f_sigma_V(muS_fits_SLQ[i])

        Z_SLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_VLQ[i])) / f_sigma_S(muS_fits_VLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_VLQ[i])) / f_sigma_V(muS_fits_VLQ[i])

        Z_VLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_inter.append(np.array(Z_SLQ_inter_step))
    Z_VLQ_inter.append(np.array(Z_VLQ_inter_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH CONTINUOUS MASSES (interpolation) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_inter.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_inter.append(pred_counts_VLQ)





    # COMPARING WITH THE PREVIOUSLY KNOWN PDF

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_prev_step = []
    Z_VLQ_prev_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_SLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_VLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_prev.append(np.array(Z_SLQ_prev_step))
    Z_VLQ_prev.append(np.array(Z_VLQ_prev_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH THE PREVIOUSLY KNOWN PDF ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_prev.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_prev.append(pred_counts_VLQ)
# Out:
# ==========================
# S_expected_SLQ = 753
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
# S mean SLQ:  699.5355203654191
# S std SLQ:  34.78202781047889
# S mean VLQ:  749.970169527677
# S std VLQ:  28.326163933732627
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.832
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.168
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.604
# 2 = both     : 0.0
# 3 = neither  : 0.396
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.646
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.354
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.808
# 2 = both     : 0.0
# 3 = neither  : 0.192
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.925
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.075
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.725
# 2 = both     : 0.0
# 3 = neither  : 0.275
#
# ==========================
# S_expected_SLQ = 426
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
# S mean SLQ:  412.06157325130675
# S std SLQ:  24.183813117382922
# S mean VLQ:  431.0651250073561
# S std VLQ:  25.198389215978523
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.933
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.067
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.782
# 2 = both     : 0.0
# 3 = neither  : 0.218
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.86
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.14
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.889
# 2 = both     : 0.0
# 3 = neither  : 0.111
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.94
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.06
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.791
# 2 = both     : 0.0
# 3 = neither  : 0.209
#
# ==========================
# S_expected_SLQ = 241
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
# S mean SLQ:  242.62638670930863
# S std SLQ:  19.650619758395102
# S mean VLQ:  245.76324899916443
# S std VLQ:  19.624435262387486
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.962
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.038
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.925
# 2 = both     : 0.0
# 3 = neither  : 0.075
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.957
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.043
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.957
# 2 = both     : 0.0
# 3 = neither  : 0.043
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.966
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.034
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.927
# 2 = both     : 0.0
# 3 = neither  : 0.073
#
# ==========================
# S_expected_SLQ = 140
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
# S mean SLQ:  144.94885620136344
# S std SLQ:  17.31278898704769
# S mean VLQ:  144.6434764949904
# S std VLQ:  16.91053339726881
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.939
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.061
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.928
# 2 = both     : 0.0
# 3 = neither  : 0.072
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.948
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.052
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.953
# 2 = both     : 0.0
# 3 = neither  : 0.047
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.947
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.053
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.923
# 2 = both     : 0.0
# 3 = neither  : 0.077
#
# ==========================
# S_expected_SLQ = 81
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
# S mean SLQ:  85.15107910766866
# S std SLQ:  14.860054291252967
# S mean VLQ:  83.75457585165344
# S std VLQ:  15.190813633507851
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.927
# 1 = VLQ only : 0.0
# 2 = both     : 0.007
# 3 = neither  : 0.066
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.004
# 1 = VLQ only : 0.939
# 2 = both     : 0.015
# 3 = neither  : 0.042
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.951
# 1 = VLQ only : 0.0
# 2 = both     : 0.003
# 3 = neither  : 0.046
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.007
# 1 = VLQ only : 0.95
# 2 = both     : 0.006
# 3 = neither  : 0.037
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.967
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.033
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.006
# 1 = VLQ only : 0.943
# 2 = both     : 0.0
# 3 = neither  : 0.051
#
# ==========================
# S_expected_SLQ = 47
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
# S mean SLQ:  50.07208315825676
# S std SLQ:  13.758727173571517
# S mean VLQ:  48.199144205020275
# S std VLQ:  13.922482730543972
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.715
# 1 = VLQ only : 0.027
# 2 = both     : 0.225
# 3 = neither  : 0.033
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.021
# 1 = VLQ only : 0.671
# 2 = both     : 0.272
# 3 = neither  : 0.036
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.75
# 1 = VLQ only : 0.031
# 2 = both     : 0.201
# 3 = neither  : 0.018
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.035
# 1 = VLQ only : 0.699
# 2 = both     : 0.24
# 3 = neither  : 0.026
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.717
# 1 = VLQ only : 0.026
# 2 = both     : 0.24
# 3 = neither  : 0.017
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.024
# 1 = VLQ only : 0.702
# 2 = both     : 0.25
# 3 = neither  : 0.024
#
# ==========================
# S_expected_SLQ = 27
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
# S mean SLQ:  30.08008063823286
# S std SLQ:  12.90886304402036
# S mean VLQ:  28.760691754897866
# S std VLQ:  12.691400196581656
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.343
# 1 = VLQ only : 0.05
# 2 = both     : 0.593
# 3 = neither  : 0.014
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.031
# 1 = VLQ only : 0.361
# 2 = both     : 0.579
# 3 = neither  : 0.029
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.336
# 1 = VLQ only : 0.041
# 2 = both     : 0.607
# 3 = neither  : 0.016
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.031
# 1 = VLQ only : 0.351
# 2 = both     : 0.586
# 3 = neither  : 0.032
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.302
# 1 = VLQ only : 0.036
# 2 = both     : 0.643
# 3 = neither  : 0.019
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.021
# 1 = VLQ only : 0.361
# 2 = both     : 0.59
# 3 = neither  : 0.028
#
# ==========================
# S_expected_SLQ = 16
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# S mean SLQ:  18.26668605203581
# S std SLQ:  11.846076065093476
# S mean VLQ:  17.342200054655244
# S std VLQ:  11.43886918564793
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.176
# 1 = VLQ only : 0.052
# 2 = both     : 0.76
# 3 = neither  : 0.012
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.033
# 1 = VLQ only : 0.201
# 2 = both     : 0.745
# 3 = neither  : 0.021
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.155
# 1 = VLQ only : 0.043
# 2 = both     : 0.784
# 3 = neither  : 0.018
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.029
# 1 = VLQ only : 0.162
# 2 = both     : 0.774
# 3 = neither  : 0.035
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.122
# 1 = VLQ only : 0.026
# 2 = both     : 0.833
# 3 = neither  : 0.019
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.02
# 1 = VLQ only : 0.129
# 2 = both     : 0.818
# 3 = neither  : 0.033

# %%
def Z_processor(lista_Z, select):
    """computes the median and error (percentiles 16 y 84)
    select = 1 ---> SLQ (true) vs VLQ
    select = 0 ---> VLQ (true) vs SLQ
    """
    medians = []
    err_inf = []
    err_sup = []

    for z_matriz in lista_Z:
        z_valores = z_matriz[:, select]
        med = np.median(z_valores)
        p16 = np.percentile(z_valores, 16)
        p84 = np.percentile(z_valores, 84)

        medians.append(med)
        err_inf.append(med - p16)  # percentile
        err_sup.append(p84 - med)  # percentile

    return np.array(medians), [np.array(err_inf), np.array(err_sup)]

# Compute
z_BPOK_SLQ, err_BPOK_SLQ = Z_processor(Z_SLQ_BPOK, select=1)
z_BPOK_VLQ, err_BPOK_VLQ = Z_processor(Z_VLQ_BPOK, select=0)
z_inter_SLQ, err_inter_SLQ = Z_processor(Z_SLQ_inter, select=1)
z_inter_VLQ, err_inter_VLQ = Z_processor(Z_VLQ_inter, select=0)
z_prev_SLQ, err_prev_SLQ = Z_processor(Z_SLQ_prev, select=1)
z_prev_VLQ, err_prev_VLQ = Z_processor(Z_VLQ_prev, select=0)



# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(m_SLQ), z_BPOK_SLQ, err_BPOK_SLQ)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(m_VLQ), z_BPOK_VLQ, err_BPOK_VLQ)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(m_SLQ), z_inter_SLQ, err_inter_SLQ)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(m_VLQ), z_inter_VLQ, err_inter_VLQ)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(m_SLQ), z_prev_SLQ, err_prev_SLQ)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(m_VLQ), z_prev_VLQ, err_prev_VLQ)


# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')


# PLOT
plt.figure(figsize=(7, 6))

plt.errorbar(m_SLQ, z_BPOK_SLQ, yerr=err_BPOK_SLQ, color='red', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Benchmarks)')
plt.errorbar(m_VLQ, z_BPOK_VLQ, yerr=err_BPOK_VLQ, color='green', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Benchmarks)')
plt.errorbar(m_SLQ, z_inter_SLQ, yerr=err_inter_SLQ, color='darkred', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Interpolated)')
plt.errorbar(m_VLQ, z_inter_VLQ, yerr=err_inter_VLQ, color='darkgreen', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Interpolated)')
plt.errorbar(m_SLQ, z_prev_SLQ, yerr=err_prev_SLQ, color='pink', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Known PDF)')
plt.errorbar(m_VLQ, z_prev_VLQ, yerr=err_prev_VLQ, color='lime', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Known PDF)')

plt.axhline(y=5.0, color='blue', linestyle='-', linewidth=1.5, label='5σ')

# plt.ylim(0, 25)
plt.xlabel(r"$m_{LQ}$ [GeV]", fontsize=12)
plt.ylabel(r"$Z$", fontsize=12)
plt.grid(True)
plt.legend(fontsize=12, loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1572.772772772773 [GeV]      ( 1539.1391391391392 - 1614.8148148148148 )
# VLQ mass:  1994.4944944944946 [GeV]      ( 1956.6566566566567 - 2045.6456456456456 )
#
# Interpolated
# SLQ mass:  1574.1741741741741 [GeV]      ( 1539.1391391391392 - 1617.6176176176177 )
# VLQ mass:  1993.7937937937938 [GeV]      ( 1954.5545545545547 - 2047.047047047047 )
#
# Known PDF
# SLQ mass:  1570.6706706706707 [GeV]      ( 1537.7377377377377 - 1609.9099099099099 )
# VLQ mass:  1993.7937937937938 [GeV]      ( 1958.0580580580581 - 2040.7407407407406 )

# %%
class_SLQ_BPOK_array = np.array(classification_SLQ_BPOK) # Forma (N, 4)
class_VLQ_BPOK_array = np.array(classification_VLQ_BPOK) # Forma (N, 4)

class_SLQ_inter_array = np.array(classification_SLQ_inter) # Forma (N, 4)
class_VLQ_inter_array = np.array(classification_VLQ_inter) # Forma (N, 4)

class_SLQ_prev_array = np.array(classification_SLQ_prev) # Forma (N, 4)
class_VLQ_prev_array = np.array(classification_VLQ_prev) # Forma (N, 4)

# SAVE

file_path = mainfolder + 'saved-results/vs14TeV_err_beta07.txt'

# Combine all data into a single array
data_to_save = np.column_stack([
    S_expected_SLQ[2:],
    m_SLQ,
    m_VLQ,
    mu_S,
    sigma_S,
    mu_V,
    sigma_V,
    mu_TSLQ,
    std_TSLQ,
    mu_TVLQ,
    std_TVLQ,
    class_SLQ_BPOK_array,
    class_VLQ_BPOK_array,
    class_SLQ_inter_array,
    class_VLQ_inter_array,
    class_SLQ_prev_array,
    class_VLQ_prev_array,
    z_BPOK_SLQ,
    err_BPOK_SLQ[0],
    err_BPOK_SLQ[1],
    z_BPOK_VLQ,
    err_BPOK_VLQ[0],
    err_BPOK_VLQ[1],
    z_inter_SLQ,
    err_inter_SLQ[0],
    err_inter_SLQ[1],
    z_inter_VLQ,
    err_inter_VLQ[0],
    err_inter_VLQ[1],
    z_prev_SLQ,
    err_prev_SLQ[0],
    err_prev_SLQ[1],
    z_prev_VLQ,
    err_prev_VLQ[0],
    err_prev_VLQ[1],
])

# Save data to a text file
np.savetxt(file_path, data_to_save, fmt='%.6f',
           header='# S_expected mass_list_SLQ mass_list_SLQ mu_S sigma_S mu_V sigma_V mu_TSLQ std_TSLQ mu_TVLQ std_TVLQ classification_SLQ classification_VLQ',
           comments='')

print(f"Data saved to: {file_path}")
# Out:
# Data saved to: /content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/saved-results/vs14TeV_err_beta07.txt

# %%
# LOAD

file_path = mainfolder + 'saved-results/vs14TeV_err_beta07.txt'

loaded_data = np.loadtxt(file_path)

S_expected = loaded_data[:, 0]
mass_list_SLQ = loaded_data[:, 1]
mass_list_VLQ = loaded_data[:, 2]
mu_S = loaded_data[:, 3]
sigma_S = loaded_data[:, 4]
mu_V = loaded_data[:, 5]
sigma_V = loaded_data[:, 6]
mu_TSLQ = loaded_data[:, 7]
std_TSLQ = loaded_data[:, 8]
mu_TVLQ = loaded_data[:, 9]
std_TVLQ = loaded_data[:, 10]
classification_SLQ_BPOK = loaded_data[:, 11:15]
classification_VLQ_BPOK = loaded_data[:, 15:19]
classification_SLQ_inter = loaded_data[:, 19:23]
classification_VLQ_inter = loaded_data[:, 23:27]
classification_SLQ_prev = loaded_data[:, 27:31]
classification_VLQ_prev = loaded_data[:, 31:35]
z_BPOK_SLQ = loaded_data[:, 35]
err_BPOK_SLQ = np.concatenate([loaded_data[:, 36], loaded_data[:, 37]])
z_BPOK_VLQ = loaded_data[:, 38]
err_BPOK_VLQ = np.concatenate([loaded_data[:, 39], loaded_data[:, 40]])
z_inter_SLQ = loaded_data[:, 41]
err_inter_SLQ = np.concatenate([loaded_data[:, 42], loaded_data[:, 43]])
z_inter_VLQ = loaded_data[:, 44]
err_inter_VLQ = np.concatenate([loaded_data[:, 45], loaded_data[:, 46]])
z_prev_SLQ = loaded_data[:, 47]
err_prev_SLQ = np.concatenate([loaded_data[:, 48], loaded_data[:, 49]])
z_prev_VLQ = loaded_data[:, 50]
err_prev_VLQ = np.concatenate([loaded_data[:, 51], loaded_data[:, 52]])





n_pseudo_TRUE = 1000
threshold_A = 0.95

print('n_pseudo_TRUE: ', n_pseudo_TRUE)
print('threshold_A: ', threshold_A)
# Out:
# n_pseudo_TRUE:  1000
# threshold_A:  0.95

# %%
# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_BPOK_SLQ, err_BPOK_SLQ, z_target=5.0)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_BPOK_VLQ, err_BPOK_VLQ, z_target=5.0)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_inter_SLQ, err_inter_SLQ, z_target=5.0)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_inter_VLQ, err_inter_VLQ, z_target=5.0)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_prev_SLQ, err_prev_SLQ, z_target=5.0)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_prev_VLQ, err_prev_VLQ, z_target=5.0)

# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1572.772772772773 [GeV]      ( 1544.7447447447448 - 1602.902902902903 )
# VLQ mass:  1994.4944944944946 [GeV]      ( 1927.227227227227 - 2078.5785785785783 )
#
# Interpolated
# SLQ mass:  1574.1741741741741 [GeV]      ( 1546.146146146146 - 1605.7057057057057 )
# VLQ mass:  1993.7937937937938 [GeV]      ( 1934.2342342342342 - 2079.97997997998 )
#
# Known PDF
# SLQ mass:  1570.6706706706707 [GeV]      ( 1543.3433433433433 - 1600.1001001001 )
# VLQ mass:  1993.7937937937938 [GeV]      ( 1927.9279279279278 - 2077.1771771771773 )

# %%
# LOAD

file_path = mainfolder + 'saved-results/Z13TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_13TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_13TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_13TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_13TeV = loaded_data[:, 4]
m_BL_exc_SLQ_13TeV = loaded_data[:, 5]
m_BL_dis_SLQ_13TeV = loaded_data[:, 6]
m_BL_exc_VLQ_13TeV = loaded_data[:, 7]
m_BL_dis_VLQ_13TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_13TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_13TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_13TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_13TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_13TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_13TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_13TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_13TeV = loaded_data[:, 16]


# LOAD

file_path = mainfolder + 'saved-results/Z136TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_136TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_136TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_136TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_136TeV = loaded_data[:, 4]
m_BL_exc_SLQ_136TeV = loaded_data[:, 5]
m_BL_dis_SLQ_136TeV = loaded_data[:, 6]
m_BL_exc_VLQ_136TeV = loaded_data[:, 7]
m_BL_dis_VLQ_136TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_136TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_136TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_136TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_136TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_136TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_136TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_136TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_136TeV = loaded_data[:, 16]




# LOAD

file_path = mainfolder + 'saved-results/Z14TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_14TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_14TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_14TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_14TeV = loaded_data[:, 4]
m_BL_exc_SLQ_14TeV = loaded_data[:, 5]
m_BL_dis_SLQ_14TeV = loaded_data[:, 6]
m_BL_exc_VLQ_14TeV = loaded_data[:, 7]
m_BL_dis_VLQ_14TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_14TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_14TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_14TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_14TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_14TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_14TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_14TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_14TeV = loaded_data[:, 16]

# %%
# plot BINNED LIKEHOOD

plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_SLQ_13TeV, betas, 'o:', c='red', label='13 TeV, 139 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_high_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_14TeV, betas, 'o-', c='red', label='14 TeV, 3000 fb-1 (Dis SLQ)')
plt.plot(m_BL_dis_SLQ_low_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_high_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_14TeV, betas, 'o--', c='red', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_14TeV, betas, '--', c='red', alpha=0.25)
plt.plot(m_BL_exc_SLQ_high_14TeV, betas, '--', c='red', alpha=0.25)


# benchmarks
m_SLQ_T_Z5 = [[m5_BPOK_SLQ - m5_BPOK_SLQ_inf], [m5_BPOK_SLQ_sup - m5_BPOK_SLQ]]
plt.errorbar(m5_BPOK_SLQ, 0.74, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (BP)')

# interpolated
m_SLQ_T_Z5 = [[m5_inter_SLQ - m5_inter_SLQ_inf], [m5_inter_SLQ_sup - m5_inter_SLQ]]
plt.errorbar(m5_inter_SLQ, 0.7, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (interpolated)')

# known pdf
m_SLQ_T_Z5 = [[m5_prev_SLQ - m5_prev_SLQ_inf], [m5_prev_SLQ_sup - m5_prev_SLQ]]
plt.errorbar(m5_prev_SLQ, 0.66, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()





plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_VLQ_13TeV, betas, 'o:', c='green', label='13 TeV, 139 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_high_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_14TeV, betas, 'o-', c='green', label='14 TeV, 3000 fb-1 (Dis VLQ)')
plt.plot(m_BL_dis_VLQ_low_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_high_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_14TeV, betas, 'o--', c='green', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_14TeV, betas, '-', c='green', alpha=0.25)
plt.plot(m_BL_exc_VLQ_high_14TeV, betas, '-', c='green', alpha=0.25)


# benchmarks
m_VLQ_T_Z5 = [[m5_BPOK_VLQ - m5_BPOK_VLQ_inf], [m5_BPOK_VLQ_sup - m5_BPOK_VLQ]]
plt.errorbar(m5_BPOK_VLQ, 0.74, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (BP)')

# interpolated
m_VLQ_T_Z5 = [[m5_inter_VLQ - m5_inter_VLQ_inf], [m5_inter_VLQ_sup - m5_inter_VLQ]]
plt.errorbar(m5_inter_VLQ, 0.7, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (interpolated)')

# knwon pdf
m_VLQ_T_Z5 = [[m5_prev_VLQ - m5_prev_VLQ_inf], [m5_prev_VLQ_sup - m5_prev_VLQ]]
plt.errorbar(m5_prev_VLQ, 0.66, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
