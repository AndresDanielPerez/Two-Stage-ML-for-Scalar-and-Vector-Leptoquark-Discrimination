# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
mainfolder = '/content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec

import os
import joblib  # to save the scaler

from numba import njit # for the LQ mass reconstruction

from scipy.optimize import fsolve, minimize
from scipy import stats
from scipy.stats import poisson
from scipy.stats import ks_2samp
from scipy.stats import anderson_ksamp
from scipy.stats import wasserstein_distance
from scipy.stats import chisquare
from scipy.interpolate import interp1d

import math
import random

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.callbacks import EarlyStopping

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn import preprocessing
from sklearn.metrics import roc_curve, roc_auc_score, auc, accuracy_score
from sklearn.metrics import mean_squared_error, r2_score

from xgboost import XGBRegressor, XGBClassifier
import xgboost as xgb

# %% [markdown]
# # LOAD DATA

# %% [markdown]
# ## Background

# %%
CHs_selected = ["tt", "singletP1", "singletP2", "Wbbjets", "ttW", "ttZ", "ttH"]


df_B_all = {}
X_B_all = {}


output_folder = mainfolder + "../DATA/backgrounds/data_df/"

for CH_sel in CHs_selected:
    # Read the file
    if CH_sel == 'singletP2':
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-singlet-comp/df_' + CH_sel + ".csv"
    else:
        filename = mainfolder + '../DATA-wjets/backgrounds/dats-' + CH_sel + '/df_' + CH_sel + ".csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_B_all[CH_sel] = df_temp
    X_B_all[CH_sel] = df_temp[feats_label].values

    # Print
    print(f"X_{CH_sel}.shape: {X_B_all[CH_sel].shape}")
# Out:
# X_tt.shape: (826022, 53)
# X_singletP1.shape: (179677, 53)
# X_singletP2.shape: (94219, 53)
# X_Wbbjets.shape: (162448, 53)
# X_ttW.shape: (141919, 53)
# X_ttZ.shape: (16178, 53)
# X_ttH.shape: (12068, 53)

# %% [markdown]
# ## Signal SLQ

# %%
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2200]
masses_SLQ = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]


df_SLQ_all = {}
X_SLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_SLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-SLQ-' + str(mass_sel) + 'GeV/df_SLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_SLQ_all[mass_sel] = df_temp
    X_SLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_SLQ_{mass_sel}GeV.shape: {X_SLQ_all[mass_sel].shape}")
# Out:
# X_SLQ_1000GeV.shape: (267452, 53)
# X_SLQ_1100GeV.shape: (271062, 53)
# X_SLQ_1200GeV.shape: (534247, 53)
# X_SLQ_1300GeV.shape: (196510, 53)
# X_SLQ_1400GeV.shape: (506381, 53)
# X_SLQ_1500GeV.shape: (185940, 53)
# X_SLQ_1600GeV.shape: (481827, 53)
# X_SLQ_1700GeV.shape: (173573, 53)
# X_SLQ_1800GeV.shape: (301687, 53)
# X_SLQ_1900GeV.shape: (64690, 53)

# %% [markdown]
# ## Signal VLQ

# %%
masses_VLQ = [1200, 1500, 1400, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
masses_VLQ = [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]


df_VLQ_all = {}
X_VLQ_all = {}


output_folder = mainfolder + "../DATA/signal/data_df/"

for mass_sel in masses_VLQ:
    # Read the file
    filename = mainfolder + '../DATA-wjets/signals/dats-VLQ-' + str(mass_sel) + 'GeV/df_VLQ_' + str(mass_sel) + "GeV.csv"

    df_temp = pd.read_csv(filename)

    # get the features
    feats_label = [c for c in df_temp.columns]

    # Save in the dictionary
    df_VLQ_all[mass_sel] = df_temp
    X_VLQ_all[mass_sel] = df_temp[feats_label].values

    # Print
    print(f"X_VLQ_{mass_sel}GeV.shape: {X_VLQ_all[mass_sel].shape}")
# Out:
# X_VLQ_1400GeV.shape: (139696, 53)
# X_VLQ_1500GeV.shape: (293700, 53)
# X_VLQ_1600GeV.shape: (134774, 53)
# X_VLQ_1700GeV.shape: (192819, 53)
# X_VLQ_1800GeV.shape: (127670, 53)
# X_VLQ_1900GeV.shape: (75898, 53)
# X_VLQ_2000GeV.shape: (184097, 53)
# X_VLQ_2100GeV.shape: (72762, 53)
# X_VLQ_2200GeV.shape: (232166, 53)
# X_VLQ_2300GeV.shape: (64705, 53)

# %% [markdown]
# # Cross Section

# %%
Lum = 3000

# %%
# -------------------------
# cross sections
# -------------------------
k_LQ = 1.8877462860822058

xsec_file_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV.txt'

xsec_data_14TeV = np.loadtxt(xsec_file_14TeV, comments='#')

# columns: 0=mass, 1=SLQ, 2=VLQ
masses_14TeV = xsec_data_14TeV[:,0].astype(int)
fidxsec_SLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,1]*k_LQ))
fidxsec_VLQ_14TeV = dict(zip(masses_14TeV, xsec_data_14TeV[:,2]*k_LQ))


masses_SLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]
masses_VLQ_14TeV = [1200, 1400, 1600, 1800, 2000, 2200]

fidxsec_SLQ_non0_14TeV = [fidxsec_SLQ_14TeV[ii] for ii in masses_SLQ_14TeV]
fidxsec_VLQ_non0_14TeV = [fidxsec_VLQ_14TeV[ii] for ii in masses_VLQ_14TeV]


#  interpolate
f_xsec_SLQ_log_14TeV = interp1d(masses_SLQ_14TeV, np.log10(fidxsec_SLQ_non0_14TeV), kind='linear', fill_value="extrapolate")
f_xsec_VLQ_log_14TeV = interp1d(masses_VLQ_14TeV, np.log10(fidxsec_VLQ_non0_14TeV), kind='linear', fill_value="extrapolate")



# -------------------------
# cross sections
# -------------------------
xsec_file_betas_14TeV = mainfolder + '../DATA-wjets/signals/LQs-xsec-14TeV-betas.txt'

xsec_data_betas_14TeV = np.loadtxt(xsec_file_betas_14TeV, comments='#')

# columns: 0=beta, 1,...=SLQ, -1=ratio=fid_xsec(beta)/fid_xsec(beta=0.5)
betas = xsec_data_betas_14TeV[:,0]
ratio_mean_14TeV = xsec_data_betas_14TeV[:,-1]

#  interpolate
f_ratio_SLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")
f_ratio_VLQ_log_14TeV = interp1d(betas, ratio_mean_14TeV, kind='linear', fill_value="extrapolate")



# FINAL FUNCTIONS
def fid_xsec_SLQ_14TeV(mass, beta):
    return 10**f_xsec_SLQ_log_14TeV(mass) * f_ratio_SLQ_log_14TeV(beta)

def fid_xsec_VLQ_14TeV(mass, beta):
    return 10**f_xsec_VLQ_log_14TeV(mass) * f_ratio_VLQ_log_14TeV(beta)

# %%
masses = [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

beta = 0.1

fidxsec_SLQ = dict(zip(masses, fid_xsec_SLQ_14TeV(masses, beta)))
fidxsec_VLQ = dict(zip(masses, fid_xsec_VLQ_14TeV(masses, beta)))


print('masses: ', masses)
print(fidxsec_SLQ[1200], '[fb]')
print(fidxsec_VLQ[1600], '[fb]')
# Out:
# masses:  [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# 0.14939454663581098 [fb]
# 0.16013986886186002 [fb]

# %%
# -----------------------------------
# LQs number and fid cross sections
# -----------------------------------


for m_it in masses_SLQ:
    print(f"# eventos SLQ {m_it} GeV:", len(X_SLQ_all[m_it]), "  fid_xsec = ", fidxsec_SLQ[m_it], "[fb]")

print(" ")
for m_it in masses_VLQ:
    print(f"# eventos VLQ {m_it} GeV:", len(X_VLQ_all[m_it]), "  fid_xsec = ", fidxsec_VLQ[m_it], "[fb]")
# Out:
# # eventos SLQ 1000 GeV: 267452   fid_xsec =  0.4678566452901752 [fb]
# # eventos SLQ 1100 GeV: 271062   fid_xsec =  0.26437706294926033 [fb]
# # eventos SLQ 1200 GeV: 534247   fid_xsec =  0.14939454663581098 [fb]
# # eventos SLQ 1300 GeV: 196510   fid_xsec =  0.08442007152792581 [fb]
# # eventos SLQ 1400 GeV: 506381   fid_xsec =  0.047704207665313636 [fb]
# # eventos SLQ 1500 GeV: 185940   fid_xsec =  0.027663167014306083 [fb]
# # eventos SLQ 1600 GeV: 481827   fid_xsec =  0.01604157886093173 [fb]
# # eventos SLQ 1700 GeV: 173573   fid_xsec =  0.009291425173374106 [fb]
# # eventos SLQ 1800 GeV: 301687   fid_xsec =  0.005381676111860957 [fb]
# # eventos SLQ 1900 GeV: 64690   fid_xsec =  0.0031762621370516404 [fb]
#
# # eventos VLQ 1400 GeV: 139696   fid_xsec =  0.4818472169063152 [fb]
# # eventos VLQ 1500 GeV: 293700   fid_xsec =  0.27778219908199575 [fb]
# # eventos VLQ 1600 GeV: 134774   fid_xsec =  0.16013986886186002 [fb]
# # eventos VLQ 1700 GeV: 192819   fid_xsec =  0.09381730779844942 [fb]
# # eventos VLQ 1800 GeV: 127670   fid_xsec =  0.05496249812806777 [fb]
# # eventos VLQ 1900 GeV: 75898   fid_xsec =  0.03285114031316027 [fb]
# # eventos VLQ 2000 GeV: 184097   fid_xsec =  0.01963515954752115 [fb]
# # eventos VLQ 2100 GeV: 72762   fid_xsec =  0.011960974622318547 [fb]
# # eventos VLQ 2200 GeV: 232166   fid_xsec =  0.007286159991188333 [fb]
# # eventos VLQ 2300 GeV: 64705   fid_xsec =  0.004438444950642561 [fb]

# %%
# FOR 14 TeV

k_fakett = 1.1053030485310749
crossfid_fakett = 0.244
k_tt = 1.2593273872014419
crossfid_tt = (7.74198*k_tt) + (crossfid_fakett * k_fakett)


fidxsec_SM = {'tt': crossfid_tt,
              'singletP1': 0.632632 * 3.440676833094312,
              'singletP2': 0.3182704 * 3.440676833094312,
              'Wbbjets': 1.6542420183645095 * 0.9781509289273502,
              'ttW': 0.03683196 * 3.056401327463198,
              'ttZ': 0.0715444 * 3.056401327463198,
              'ttH': 0.03630132 * 2.2127445612386474
              }

for ch_it in fidxsec_SM:
    print(f"# eventos {ch_it}:", len(X_B_all[ch_it]), "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]")
# Out:
# # eventos tt: 826022   fid_xsec =  10.019381389007401 [fb]
# # eventos singletP1: 179677   fid_xsec =  2.1766822662741205 [fb]
# # eventos singletP2: 94219   fid_xsec =  1.09506559193966 [fb]
# # eventos Wbbjets: 162448   fid_xsec =  1.6180983669338997 [fb]
# # eventos ttW: 141919   fid_xsec =  0.1125732514370714 [fb]
# # eventos ttZ: 16178   fid_xsec =  0.218668399132558 [fb]
# # eventos ttH: 12068   fid_xsec =  0.08032554839578374 [fb]

# %%
# MAX SM dataset
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])


weigth_gen_SM = {}

for ch_it in fidxsec_SM:

    print(f"fraction of {ch_it}:", fidxsec_SM[ch_it] / totalcrossSM )

    weigth_gen_SM[ch_it] = len(X_B_all[ch_it]) / (fidxsec_SM[ch_it] / totalcrossSM)

print('\nchannel limiting the SM background: ', min(weigth_gen_SM, key=weigth_gen_SM.get) , '\n')


max_evs_SM = {}

for ch_it in fidxsec_SM:
    max_evs_SM[ch_it] = round( min(weigth_gen_SM.values()) * (fidxsec_SM[ch_it] / totalcrossSM) )
    print(f"# eventos {ch_it} (max):", max_evs_SM[ch_it])

max_SM_dataset = sum(max_evs_SM.values())
print('\nmax SM dataset length: ', max_SM_dataset )
# Out:
# fraction of tt: 0.6539726894865112
# fraction of singletP1: 0.14207371698562551
# fraction of singletP2: 0.07147576906400852
# fraction of Wbbjets: 0.10561451848099845
# fraction of ttW: 0.0073477422555561795
# fraction of ttZ: 0.014272653723245071
# fraction of ttH: 0.005242910004055022
#
# channel limiting the SM background:  ttZ
#
# # eventos tt (max): 741276
# # eventos singletP1 (max): 161040
# # eventos singletP2 (max): 81018
# # eventos Wbbjets (max): 119714
# # eventos ttW (max): 8329
# # eventos ttZ (max): 16178
# # eventos ttH (max): 5943
#
# max SM dataset length:  1133498

# %% [markdown]
# ## Number of events to get a balanced dataset

# %%
# -------------------------
# Step 1: minimim number of events in LQs (selected mass)
# -------------------------

num_data_SLQ = [len(X_SLQ_all[m_it]) for m_it in masses_SLQ]

num_data_VLQ = [len(X_VLQ_all[m_it]) for m_it in masses_VLQ]


max_SM_dataset = min(1000000, max_SM_dataset)

num_data_NP = min(int(max_SM_dataset / (len(masses_SLQ) + len(masses_VLQ))) , min(num_data_SLQ + num_data_VLQ) )

print('SIGNAL: # events per-class chosen =', num_data_NP)



# -------------------------
# Step 2: background total fid_xsec
# -------------------------
totalcrossSM = sum([fidxsec_SM[ch_it] for ch_it in fidxsec_SM])



# -------------------------
# Step 3: number of events per chanel, proportional to xsec
# -------------------------
num_data_SM_dict = {}
for ch_it in fidxsec_SM:
    if ch_it == 'tt':
        # set at the end to have exactly the same # events (otherwise can be a difference of 1 due to rounding)
        continue
    fraction = fidxsec_SM[ch_it]/totalcrossSM
    num_data_SM_dict[ch_it] = round(num_data_NP * fraction * (len(masses_SLQ) + len(masses_VLQ)) )

# Set tt such that the total matches num_data_NP
num_data_SM_dict['tt'] = num_data_NP * (len(masses_SLQ) + len(masses_VLQ)) - sum([v for k,v in num_data_SM_dict.items() if k != 'tt'])




print('\nBACKGROUND events chosen (weighted by xsec):')
for ch_it in fidxsec_SM:
    print(f'# {ch_it}: {num_data_SM_dict[ch_it]}')
print('# total B events chosen: ', sum(num_data_SM_dict.values()))
# Out:
# SIGNAL: # events per-class chosen = 50000
#
# BACKGROUND events chosen (weighted by xsec):
# # tt: 653971
# # singletP1: 142074
# # singletP2: 71476
# # Wbbjets: 105615
# # ttW: 7348
# # ttZ: 14273
# # ttH: 5243
# # total B events chosen:  1000000

# %%
# keep just the events needed

for m_it in masses_SLQ:
    X_SLQ_all[m_it] = X_SLQ_all[m_it][:num_data_NP]
    df_SLQ_all[m_it] = df_SLQ_all[m_it][:num_data_NP]

print(" ")
for m_it in masses_VLQ:
    X_VLQ_all[m_it] = X_VLQ_all[m_it][:num_data_NP]
    df_VLQ_all[m_it] = df_VLQ_all[m_it][:num_data_NP]

print("")
for ch_it in fidxsec_SM:
    X_B_all[ch_it] = X_B_all[ch_it][:num_data_SM_dict[ch_it]]
    df_B_all[ch_it] = df_B_all[ch_it][:num_data_SM_dict[ch_it]]

# %%
B_expected = round(Lum * totalcrossSM)    # luminosity * cross * aceptance
print('B_expected: ', B_expected)

for ch_it in fidxsec_SM:
    print(f" channel {ch_it}:", "  fid_xsec = ", fidxsec_SM[ch_it], "[fb]", " B_exp_ch: ", round(Lum * fidxsec_SM[ch_it]) )



S_expected_SLQ = []

for m_it in masses_SLQ:
    S_expected_SLQ.append( round(Lum * fidxsec_SLQ[m_it]) )

print('\nmasses:           ', masses_SLQ)
print('S_expected (SLQ): ', S_expected_SLQ)    # luminosity * cross * aceptance



S_expected_VLQ = []

for m_it in masses_VLQ:
    S_expected_VLQ.append( round(Lum * fidxsec_VLQ[m_it]) )

print('\nmasses:           ', masses_VLQ)
print('S_expected (VLQ): ', S_expected_VLQ)    # luminosity * cross * aceptance
# Out:
# B_expected:  45962
#  channel tt:   fid_xsec =  10.019381389007401 [fb]  B_exp_ch:  30058
#  channel singletP1:   fid_xsec =  2.1766822662741205 [fb]  B_exp_ch:  6530
#  channel singletP2:   fid_xsec =  1.09506559193966 [fb]  B_exp_ch:  3285
#  channel Wbbjets:   fid_xsec =  1.6180983669338997 [fb]  B_exp_ch:  4854
#  channel ttW:   fid_xsec =  0.1125732514370714 [fb]  B_exp_ch:  338
#  channel ttZ:   fid_xsec =  0.218668399132558 [fb]  B_exp_ch:  656
#  channel ttH:   fid_xsec =  0.08032554839578374 [fb]  B_exp_ch:  241
#
# masses:            [1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_expected (SLQ):  [1404, 793, 448, 253, 143, 83, 48, 28, 16, 10]
#
# masses:            [1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_expected (VLQ):  [1446, 833, 480, 281, 165, 99, 59, 36, 22, 13]

# %%
plt.plot(masses_SLQ, S_expected_SLQ, color='red', label='SLQ')
plt.plot(masses_VLQ, S_expected_VLQ, color='green', label='VLQ')
# plt.yscale('log')
plt.xlabel("$m_{LQ}$ [GeV]", fontsize=16)
plt.ylabel("S expected", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.grid()
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# # 1. DATA FORMAT for CLASSIFIERS

# %%
# to save memory
del X_SLQ_all
del X_VLQ_all
del X_B_all

# %%
# ---------------------------
# Concatenate all for normalization
# ---------------------------
df_SM = pd.concat(df_B_all.values(), ignore_index=True)
del df_B_all

df_all = pd.concat([df_SM] + list(df_SLQ_all.values()) + list(df_VLQ_all.values()), ignore_index=True)

# ---------------------------
# Normalization
# ---------------------------
scaler = MinMaxScaler()
scaler.fit(df_all)

# Save the scaler
# joblib.dump(scaler, mainfolder + 'saved-models/scaler_features.pkl')

# Apply normalization
df_SM_norm = pd.DataFrame(scaler.transform(df_SM), columns=df_SM.columns)
df_SLQ_norm = {mass: pd.DataFrame(scaler.transform(df_SLQ_all[mass]), columns=df_SLQ_all[mass].columns) for mass in df_SLQ_all}
df_VLQ_norm = {mass: pd.DataFrame(scaler.transform(df_VLQ_all[mass]), columns=df_VLQ_all[mass].columns) for mass in df_VLQ_all}






# ---------------------------
# Divide datasets into train/val/test/pseudo
# ---------------------------
def split_class(df, test_ratio=0.25, val_ratio=0.10, pseudo_ratio=0.25):
    X = df.values
    aux_val_ratio = val_ratio / (1 - test_ratio)
    aux_pseudo_ratio = pseudo_ratio / (1 - test_ratio - val_ratio)

    X_aux, X_test = train_test_split(X, test_size=test_ratio, random_state=42, shuffle=True)
    X_aux2, X_val = train_test_split(X_aux, test_size=aux_val_ratio, random_state=42, shuffle=True)
    X_train, X_pseudo = train_test_split(X_aux2, test_size=aux_pseudo_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, X_pseudo



# ---------------------------
# Divide the datasets
# ---------------------------
split_SM = split_class(df_SM_norm)
split_SLQ = {mass: split_class(df_SLQ_norm[mass]) for mass in df_SLQ_norm}
split_VLQ = {mass: split_class(df_VLQ_norm[mass]) for mass in df_VLQ_norm}



# Example of how to use them
X_train_SM, X_val_SM, X_test_SM, X_pseudo_SM = split_SM
X_train_SLQ1200, X_val_SLQ1200, X_test_SLQ1200, X_pseudo_SLQ1200 = split_SLQ[1200]
X_train_VLQ1600, X_val_VLQ1600, X_test_VLQ1600, X_pseudo_VLQ1600 = split_VLQ[1600]

print('')
print('X_train_SM : ', X_train_SM.shape)
print('X_val_SM : ', X_val_SM.shape)
print('X_test_SM : ', X_test_SM.shape)
print('X_pseudo_SM : ', X_pseudo_SM.shape)

print('')
print('X_train_SLQ1200 : ', X_train_SLQ1200.shape)
print('X_val_SLQ1200 : ', X_val_SLQ1200.shape)
print('X_test_SLQ1200 : ', X_test_SLQ1200.shape)
print('X_pseudo_SLQ1200 : ', X_pseudo_SLQ1200.shape)

print('')
print('X_train_VLQ1600 : ', X_train_VLQ1600.shape)
print('X_val_VLQ1600 : ', X_val_VLQ1600.shape)
print('X_test_VLQ1600 : ', X_test_VLQ1600.shape)
print('X_pseudo_VLQ1600 : ', X_pseudo_VLQ1600.shape)
# Out:
# X_train_SM :  (400000, 53)
# X_val_SM :  (100000, 53)
# X_test_SM :  (250000, 53)
# X_pseudo_SM :  (250000, 53)
#
# X_train_SLQ1200 :  (20000, 53)
# X_val_SLQ1200 :  (5000, 53)
# X_test_SLQ1200 :  (12500, 53)
# X_pseudo_SLQ1200 :  (12500, 53)
#
# X_train_VLQ1600 :  (20000, 53)
# X_val_VLQ1600 :  (5000, 53)
# X_test_VLQ1600 :  (12500, 53)
# X_pseudo_VLQ1600 :  (12500, 53)

# %%
# to save memory
del df_SM
del df_SLQ_all
del df_VLQ_all

# %% [markdown]
# ## SM vs LQ

# %%
# --- 1. Combinar todos los LQ en un solo DataFrame ---
df_LQ_list = list(df_SLQ_norm.values()) + list(df_VLQ_norm.values())
df_LQ_norm = pd.concat(df_LQ_list, ignore_index=True)


# --- 2. Igualar número de eventos con SM ---
n_SM = len(df_SM_norm)
n_LQ = len(df_LQ_norm)
n_events = min(n_SM, n_LQ)

print(n_SM, n_LQ, n_events)

df_SM_sample = df_SM_norm.sample(n=n_events, random_state=42)
df_LQ_sample = df_LQ_norm.sample(n=n_events, random_state=42)


# --- 3. Crear X, y ---
X = pd.concat([df_SM_sample, df_LQ_sample], ignore_index=True)
y = np.hstack([np.zeros(n_events), np.ones(n_events)])  # 0=SM, 1=LQ


def split_class(X, Y, test_ratio=0.25, val_ratio=0.25):

    aux_val_ratio = val_ratio / (1 - test_ratio)

    X_aux, X_test, Y_aux, Y_test = train_test_split(X, Y, test_size=test_ratio, random_state=42, shuffle=True)
    X_train, X_val, Y_train, Y_val = train_test_split(X_aux, Y_aux, test_size=val_ratio, random_state=42, shuffle=True)

    return X_train, X_val, X_test, Y_train, Y_val, Y_test


# Divide into train, validation and test
X_train, X_val, X_test, y_train, y_val, y_test = split_class(X, y)


print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
# Out:
# 1000000 1000000 1000000
# (1125000, 53)
# (375000, 53)
# (500000, 53)

# %%
# LOAD
xgb_clf = XGBClassifier()
xgb_clf.load_model(mainfolder + "saved-models/modelA_SMLQ_14TeV_full.json")


# Evaluate
y_pred = xgb_clf.predict(X_test)
y_pred_proba = xgb_clf.predict_proba(X_test)[:,1]

acc = accuracy_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_proba)
print(f"Accuracy: {acc:.3f}, ROC-AUC: {auc:.5f}")

# ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC={auc:.3f}')
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SM vs LQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + "saved-results/ROC_classA.pdf", bbox_inches='tight')
plt.show()


# Feature importance
keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$'])

feature_important = xgb_clf.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=14).remove()
plt.title(r'SM vs LQ', fontsize=14)
# plt.savefig(mainfolder + "saved-results/XG_feature_importance_classA.pdf", bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Accuracy: 0.973, ROC-AUC: 0.99660
# [52, 47, 35, 17, 15, 36, 50, 46, 32, 45, 6, 37, 51, 38, 12]

# %% [markdown]
# ## Compute S_pred for pseudo-experiments

# %%
# output of all the background events
scores_B = xgb_clf.predict_proba( df_SM_norm )[:, 1]

# output of all the signal events (for the pdf of the general LQ case)
scores_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]

# %%
# output of all the signal events per class (to build the pseudo-experiments)
scores_S_SLQ = {mass: xgb_clf.predict_proba(df_SLQ_norm[mass])[:, 1] for mass in df_SLQ_norm}
scores_S_VLQ = {mass: xgb_clf.predict_proba(df_VLQ_norm[mass])[:, 1] for mass in df_VLQ_norm}

# %%
def Z_asimov(S, B):
    if S <= 0 or B <= 0:
        return 0
    return np.sqrt(2 * ((S+B) * np.log(1 + S/B) - S))

# %% [markdown]
# ###### binned likelihood fit

# %%
bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scores_B, bins=bins, density=True)
hist_S, _ = np.histogram(scores_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %%
# FOR SLQ #

S_expected = S_expected_SLQ


n_pseudo = 1000


# to save
S_mean_fit_N = {}
S_std_fit_N  = {}
Z_fit_N = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_N[S_it] = []
    S_std_fit_N[S_it]  = []
    Z_fit_N[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_SLQ[masses_SLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_N[S_it].append(mean_muS)
    S_std_fit_N[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_N[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  1404
# S = 1098.8962719031772 +- 38.24310610519849
# Z = 54.868298994219266
#
#
# ----------------
# S_expected =  793
# S = 683.8925976519369 +- 30.87692396952405
# Z = 39.91173020857374
#
#
# ----------------
# S_expected =  448
# S = 415.6186148450325 +- 26.49966845886382
# Z = 26.411898960613318
#
#
# ----------------
# S_expected =  253
# S = 244.1309509775347 +- 19.06999327487921
# Z = 17.584930377009897
#
#
# ----------------
# S_expected =  143
# S = 143.28576418783237 +- 16.075237892084484
# Z = 11.546723873490917
#
#
# ----------------
# S_expected =  83
# S = 85.59436586165839 +- 15.300694917128418
# Z = 8.22524807192483
#
#
# ----------------
# S_expected =  48
# S = 50.46997940245312 +- 13.928412173877168
# Z = 3.4846388404619146
#
#
# ----------------
# S_expected =  28
# S = 30.136744974787373 +- 12.774105046455203
# Z = 0.9760159717944852
#
#
# ----------------
# S_expected =  16
# S = 17.47421521266359 +- 11.8913689784845
# Z = 2.2427410829560324
#
#
# ----------------
# S_expected =  10
# S = 12.058114577522066 +- 10.079628273893235
# Z = 1.381927678808437

# %%
# FOR VLQ #

S_expected = S_expected_SLQ # same number of events


n_pseudo = 1000


# to save
S_mean_fit_V = {}
S_std_fit_V  = {}
Z_fit_V = {}



for ii_S, S_it in enumerate(S_expected):
    print('\n----------------')
    print('S_expected = ', S_it)

    S_mean_fit_V[S_it] = []
    S_std_fit_V[S_it]  = []
    Z_fit_V[S_it] = []


    muS_fits = []
    muB_fits = []

    for n_it in range(n_pseudo):

        # 1) pseudo experiment
        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_it)

        sample_B = np.random.choice(scores_B, N_B, replace=True)
        sample_S = np.random.choice(scores_S_VLQ[masses_VLQ[ii_S]], N_S, replace=True)

        data_scores = np.concatenate([sample_B, sample_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_it, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits.append(muS_fit)
        muB_fits.append(muB_fit)


    mean_muB = np.mean(muB_fits)

    mean_muS = np.mean(muS_fits)
    std_muS  = np.std(muS_fits)

    S_mean_fit_V[S_it].append(mean_muS)
    S_std_fit_V[S_it].append(std_muS)


    # significance
    logL_hat = -neg_logL([mean_muS, mean_muB])
    logL_null = -neg_logL([0, mean_muB])

    q0 = -2 * (logL_null - logL_hat)

    Z = np.sqrt(q0)

    Z_fit_V[S_it].append(Z)

    print("S =", mean_muS, "+-", std_muS)
    print("Z =", Z)
    print('')
# Out:
# ----------------
# S_expected =  1404
# S = 1362.7233312906033 +- 47.35864499865119
# Z = 64.37358050144512
#
#
# ----------------
# S_expected =  793
# S = 777.5691437490508 +- 31.927144287486062
# Z = 43.12621453939861
#
#
# ----------------
# S_expected =  448
# S = 447.73197950306724 +- 23.568629492326803
# Z = 27.986200030968337
#
#
# ----------------
# S_expected =  253
# S = 254.72350178314764 +- 20.281491760172933
# Z = 16.822727209973966
#
#
# ----------------
# S_expected =  143
# S = 146.81077798649576 +- 17.07284417699005
# Z = 11.711491489464636
#
#
# ----------------
# S_expected =  83
# S = 85.5751178472663 +- 14.773843041348629
# Z = 6.379350369251666
#
#
# ----------------
# S_expected =  48
# S = 49.93725810135967 +- 13.68891500550253
# Z = 4.433506000762182
#
#
# ----------------
# S_expected =  28
# S = 29.543980434569892 +- 13.11654276202536
# Z = 2.728157220086198
#
#
# ----------------
# S_expected =  16
# S = 17.785120601824634 +- 11.652553051432598
# Z = 1.6656682426811436
#
#
# ----------------
# S_expected =  10
# S = 11.909461251087274 +- 10.091896904177505
# Z = 0.5755816165899744

# %%
# mean between scalar and vector
S_mean_fit_both = []
S_std_fit_both = []

for i in S_mean_fit_N:

    S_mean_fit_both.append( np.mean([S_mean_fit_N[i][0], S_mean_fit_V[i][0]]) )
    S_std_fit_both.append( np.mean([S_std_fit_N[i][0], S_std_fit_V[i][0]]) )

# %% [markdown]
# # SLQ vs VLQ (include Poisson S_expected)

# %%
X_train_list, y_train_list, S_poiss_train_list = [], [], []
X_val_list,   y_val_list,   S_poiss_val_list   = [], [], []
X_test_list,  y_test_list,  S_poiss_test_list  = [], [], []

for iit, m_s in enumerate(masses_SLQ):

        # -------- SLQ --------
        X_train_s, X_val_s, X_test_s, _ = split_SLQ[masses_SLQ[iit]]

        X_train_list.append(X_train_s)
        y_train_list.append(np.zeros(len(X_train_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_s))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_s)
        y_val_list.append(np.zeros(len(X_val_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_s))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_s)
        y_test_list.append(np.zeros(len(X_test_s)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_s))
        S_poiss_test_list.append(poisson_samples)


# for iit, m_v in enumerate(masses_VLQ):

        # -------- VLQ --------
        X_train_v, X_val_v, X_test_v, _ = split_VLQ[masses_VLQ[iit]]

        X_train_list.append(X_train_v)
        y_train_list.append(np.ones(len(X_train_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_train_v))
        S_poiss_train_list.append(poisson_samples)

        X_val_list.append(X_val_v)
        y_val_list.append(np.ones(len(X_val_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_val_v))
        S_poiss_val_list.append(poisson_samples)

        X_test_list.append(X_test_v)
        y_test_list.append(np.ones(len(X_test_v)))
        poisson_samples = np.random.poisson(lam=S_mean_fit_both[iit], size=len(X_test_v))
        S_poiss_test_list.append(poisson_samples)


# Concatenate
# TRAIN
X_train_spin = np.vstack(X_train_list)
y_train_spin = np.concatenate(y_train_list)
S_poiss_train = np.concatenate(S_poiss_train_list)

# add S_poiss as extra feature
X_train_spin = np.column_stack([X_train_spin, S_poiss_train])


# VAL
X_val_spin = np.vstack(X_val_list)
y_val_spin = np.concatenate(y_val_list)
S_poiss_val = np.concatenate(S_poiss_val_list)

X_val_spin = np.column_stack([X_val_spin, S_poiss_val])


# TEST
X_test_spin = np.vstack(X_test_list)
y_test_spin = np.concatenate(y_test_list)
S_poiss_test = np.concatenate(S_poiss_test_list)

X_test_spin = np.column_stack([X_test_spin, S_poiss_test])


print(X_train_spin.shape)
print(X_val_spin.shape)
print(X_test_spin.shape)
# Out:
# (400000, 54)
# (100000, 54)
# (250000, 54)

# %%
classifier_spin = XGBClassifier(
    n_estimators=1500,
    learning_rate=0.1,
    max_depth=5,
    reg_lambda=1.0,
    reg_alpha=0.0,
    gamma=0.0,
    objective='binary:logistic',
    eval_metric='logloss',
    tree_method='hist',
    random_state=42,
    early_stopping_rounds=50
)

classifier_spin.fit(
    X_train_spin, y_train_spin,
    eval_set=[(X_train_spin, y_train_spin),
              (X_val_spin, y_val_spin)],
    verbose=True
)

classifier_spin.save_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta01.json")
# Out:
# [0]	validation_0-logloss:0.68607	validation_1-logloss:0.68617
# [1]	validation_0-logloss:0.67996	validation_1-logloss:0.68015
# [2]	validation_0-logloss:0.67455	validation_1-logloss:0.67479
# [3]	validation_0-logloss:0.67013	validation_1-logloss:0.67049
# [4]	validation_0-logloss:0.66590	validation_1-logloss:0.66618
# [5]	validation_0-logloss:0.66228	validation_1-logloss:0.66261
# [6]	validation_0-logloss:0.65891	validation_1-logloss:0.65934
# [7]	validation_0-logloss:0.65601	validation_1-logloss:0.65653
# [8]	validation_0-logloss:0.65336	validation_1-logloss:0.65390
# [9]	validation_0-logloss:0.65098	validation_1-logloss:0.65162
# [10]	validation_0-logloss:0.64888	validation_1-logloss:0.64952
# [11]	validation_0-logloss:0.64670	validation_1-logloss:0.64743
# [12]	validation_0-logloss:0.64496	validation_1-logloss:0.64577
# [13]	validation_0-logloss:0.64324	validation_1-logloss:0.64412
# [14]	validation_0-logloss:0.64166	validation_1-logloss:0.64266
# [15]	validation_0-logloss:0.64029	validation_1-logloss:0.64137
# [16]	validation_0-logloss:0.63892	validation_1-logloss:0.64001
# [17]	validation_0-logloss:0.63789	validation_1-logloss:0.63906
# [18]	validation_0-logloss:0.63640	validation_1-logloss:0.63762
# [19]	validation_0-logloss:0.63540	validation_1-logloss:0.63666
# [20]	validation_0-logloss:0.63420	validation_1-logloss:0.63549
# [21]	validation_0-logloss:0.63328	validation_1-logloss:0.63460
# [22]	validation_0-logloss:0.63167	validation_1-logloss:0.63305
# [23]	validation_0-logloss:0.63087	validation_1-logloss:0.63227
# [24]	validation_0-logloss:0.62976	validation_1-logloss:0.63119
# [25]	validation_0-logloss:0.62812	validation_1-logloss:0.62956
# [26]	validation_0-logloss:0.62732	validation_1-logloss:0.62882
# [27]	validation_0-logloss:0.62671	validation_1-logloss:0.62827
# [28]	validation_0-logloss:0.62580	validation_1-logloss:0.62742
# [29]	validation_0-logloss:0.62471	validation_1-logloss:0.62638
# [30]	validation_0-logloss:0.62417	validation_1-logloss:0.62587
# [31]	validation_0-logloss:0.62368	validation_1-logloss:0.62540
# [32]	validation_0-logloss:0.62280	validation_1-logloss:0.62454
# [33]	validation_0-logloss:0.62166	validation_1-logloss:0.62339
# [34]	validation_0-logloss:0.62112	validation_1-logloss:0.62291
# [35]	validation_0-logloss:0.62069	validation_1-logloss:0.62250
# [36]	validation_0-logloss:0.62019	validation_1-logloss:0.62205
# [37]	validation_0-logloss:0.61969	validation_1-logloss:0.62156
# [38]	validation_0-logloss:0.61935	validation_1-logloss:0.62127
# [39]	validation_0-logloss:0.61888	validation_1-logloss:0.62082
# [40]	validation_0-logloss:0.61849	validation_1-logloss:0.62049
# [41]	validation_0-logloss:0.61799	validation_1-logloss:0.62000
# [42]	validation_0-logloss:0.61762	validation_1-logloss:0.61966
# [43]	validation_0-logloss:0.61682	validation_1-logloss:0.61887
# [44]	validation_0-logloss:0.61630	validation_1-logloss:0.61840
# [45]	validation_0-logloss:0.61597	validation_1-logloss:0.61810
# [46]	validation_0-logloss:0.61501	validation_1-logloss:0.61716
# [47]	validation_0-logloss:0.61433	validation_1-logloss:0.61651
# [48]	validation_0-logloss:0.61405	validation_1-logloss:0.61627
# [49]	validation_0-logloss:0.61331	validation_1-logloss:0.61559
# [50]	validation_0-logloss:0.61294	validation_1-logloss:0.61526
# [51]	validation_0-logloss:0.61255	validation_1-logloss:0.61495
# [52]	validation_0-logloss:0.61199	validation_1-logloss:0.61446
# [53]	validation_0-logloss:0.61169	validation_1-logloss:0.61419
# [54]	validation_0-logloss:0.61103	validation_1-logloss:0.61358
# [55]	validation_0-logloss:0.61022	validation_1-logloss:0.61280
# [56]	validation_0-logloss:0.60992	validation_1-logloss:0.61257
# [57]	validation_0-logloss:0.60966	validation_1-logloss:0.61233
# [58]	validation_0-logloss:0.60942	validation_1-logloss:0.61216
# [59]	validation_0-logloss:0.60918	validation_1-logloss:0.61193
# [60]	validation_0-logloss:0.60887	validation_1-logloss:0.61169
# [61]	validation_0-logloss:0.60843	validation_1-logloss:0.61132
# [62]	validation_0-logloss:0.60827	validation_1-logloss:0.61122
# [63]	validation_0-logloss:0.60799	validation_1-logloss:0.61099
# [64]	validation_0-logloss:0.60776	validation_1-logloss:0.61077
# [65]	validation_0-logloss:0.60757	validation_1-logloss:0.61062
# [66]	validation_0-logloss:0.60729	validation_1-logloss:0.61042
# [67]	validation_0-logloss:0.60697	validation_1-logloss:0.61015
# [68]	validation_0-logloss:0.60678	validation_1-logloss:0.61001
# [69]	validation_0-logloss:0.60641	validation_1-logloss:0.60972
# [70]	validation_0-logloss:0.60629	validation_1-logloss:0.60964
# [71]	validation_0-logloss:0.60614	validation_1-logloss:0.60955
# [72]	validation_0-logloss:0.60590	validation_1-logloss:0.60935
# [73]	validation_0-logloss:0.60568	validation_1-logloss:0.60921
# [74]	validation_0-logloss:0.60547	validation_1-logloss:0.60905
# [75]	validation_0-logloss:0.60525	validation_1-logloss:0.60889
# [76]	validation_0-logloss:0.60499	validation_1-logloss:0.60868
# [77]	validation_0-logloss:0.60485	validation_1-logloss:0.60857
# [78]	validation_0-logloss:0.60470	validation_1-logloss:0.60851
# [79]	validation_0-logloss:0.60457	validation_1-logloss:0.60840
# [80]	validation_0-logloss:0.60407	validation_1-logloss:0.60799
# [81]	validation_0-logloss:0.60387	validation_1-logloss:0.60785
# [82]	validation_0-logloss:0.60349	validation_1-logloss:0.60751
# [83]	validation_0-logloss:0.60326	validation_1-logloss:0.60730
# [84]	validation_0-logloss:0.60309	validation_1-logloss:0.60720
# [85]	validation_0-logloss:0.60289	validation_1-logloss:0.60709
# [86]	validation_0-logloss:0.60272	validation_1-logloss:0.60700
# [87]	validation_0-logloss:0.60252	validation_1-logloss:0.60684
# [88]	validation_0-logloss:0.60234	validation_1-logloss:0.60669
# [89]	validation_0-logloss:0.60220	validation_1-logloss:0.60658
# [90]	validation_0-logloss:0.60206	validation_1-logloss:0.60651
# [91]	validation_0-logloss:0.60182	validation_1-logloss:0.60633
# [92]	validation_0-logloss:0.60171	validation_1-logloss:0.60627
# [93]	validation_0-logloss:0.60152	validation_1-logloss:0.60614
# [94]	validation_0-logloss:0.60139	validation_1-logloss:0.60604
# [95]	validation_0-logloss:0.60110	validation_1-logloss:0.60579
# [96]	validation_0-logloss:0.60094	validation_1-logloss:0.60567
# [97]	validation_0-logloss:0.60073	validation_1-logloss:0.60552
# [98]	validation_0-logloss:0.60053	validation_1-logloss:0.60537
# [99]	validation_0-logloss:0.60042	validation_1-logloss:0.60532
# [100]	validation_0-logloss:0.60032	validation_1-logloss:0.60525
# [101]	validation_0-logloss:0.60020	validation_1-logloss:0.60520
# [102]	validation_0-logloss:0.60008	validation_1-logloss:0.60516
# [103]	validation_0-logloss:0.59998	validation_1-logloss:0.60512
# [104]	validation_0-logloss:0.59989	validation_1-logloss:0.60509
# [105]	validation_0-logloss:0.59955	validation_1-logloss:0.60484
# [106]	validation_0-logloss:0.59927	validation_1-logloss:0.60462
# [107]	validation_0-logloss:0.59909	validation_1-logloss:0.60447
# [108]	validation_0-logloss:0.59878	validation_1-logloss:0.60424
# [109]	validation_0-logloss:0.59864	validation_1-logloss:0.60417
# [110]	validation_0-logloss:0.59855	validation_1-logloss:0.60412
# [111]	validation_0-logloss:0.59836	validation_1-logloss:0.60402
# [112]	validation_0-logloss:0.59823	validation_1-logloss:0.60391
# [113]	validation_0-logloss:0.59812	validation_1-logloss:0.60385
# [114]	validation_0-logloss:0.59798	validation_1-logloss:0.60378
# [115]	validation_0-logloss:0.59790	validation_1-logloss:0.60374
# [116]	validation_0-logloss:0.59782	validation_1-logloss:0.60371
# [117]	validation_0-logloss:0.59743	validation_1-logloss:0.60340
# [118]	validation_0-logloss:0.59706	validation_1-logloss:0.60309
# [119]	validation_0-logloss:0.59690	validation_1-logloss:0.60298
# [120]	validation_0-logloss:0.59682	validation_1-logloss:0.60295
# [121]	validation_0-logloss:0.59672	validation_1-logloss:0.60291
# [122]	validation_0-logloss:0.59657	validation_1-logloss:0.60280
# [123]	validation_0-logloss:0.59629	validation_1-logloss:0.60263
# [124]	validation_0-logloss:0.59617	validation_1-logloss:0.60256
# [125]	validation_0-logloss:0.59608	validation_1-logloss:0.60252
# [126]	validation_0-logloss:0.59600	validation_1-logloss:0.60251
# [127]	validation_0-logloss:0.59583	validation_1-logloss:0.60239
# [128]	validation_0-logloss:0.59568	validation_1-logloss:0.60229
# [129]	validation_0-logloss:0.59526	validation_1-logloss:0.60195
# [130]	validation_0-logloss:0.59516	validation_1-logloss:0.60189
# [131]	validation_0-logloss:0.59509	validation_1-logloss:0.60188
# [132]	validation_0-logloss:0.59498	validation_1-logloss:0.60182
# [133]	validation_0-logloss:0.59473	validation_1-logloss:0.60161
# [134]	validation_0-logloss:0.59464	validation_1-logloss:0.60157
# [135]	validation_0-logloss:0.59452	validation_1-logloss:0.60151
# [136]	validation_0-logloss:0.59424	validation_1-logloss:0.60128
# [137]	validation_0-logloss:0.59410	validation_1-logloss:0.60121
# [138]	validation_0-logloss:0.59392	validation_1-logloss:0.60109
# [139]	validation_0-logloss:0.59384	validation_1-logloss:0.60106
# [140]	validation_0-logloss:0.59377	validation_1-logloss:0.60104
# [141]	validation_0-logloss:0.59369	validation_1-logloss:0.60101
# [142]	validation_0-logloss:0.59361	validation_1-logloss:0.60097
# [143]	validation_0-logloss:0.59332	validation_1-logloss:0.60074
# [144]	validation_0-logloss:0.59322	validation_1-logloss:0.60070
# [145]	validation_0-logloss:0.59312	validation_1-logloss:0.60069
# [146]	validation_0-logloss:0.59300	validation_1-logloss:0.60064
# [147]	validation_0-logloss:0.59290	validation_1-logloss:0.60060
# [148]	validation_0-logloss:0.59284	validation_1-logloss:0.60058
# [149]	validation_0-logloss:0.59264	validation_1-logloss:0.60042
# [150]	validation_0-logloss:0.59242	validation_1-logloss:0.60025
# [151]	validation_0-logloss:0.59230	validation_1-logloss:0.60018
# [152]	validation_0-logloss:0.59220	validation_1-logloss:0.60015
# [153]	validation_0-logloss:0.59203	validation_1-logloss:0.60001
# [154]	validation_0-logloss:0.59187	validation_1-logloss:0.59989
# [155]	validation_0-logloss:0.59175	validation_1-logloss:0.59984
# [156]	validation_0-logloss:0.59164	validation_1-logloss:0.59981
# [157]	validation_0-logloss:0.59153	validation_1-logloss:0.59974
# [158]	validation_0-logloss:0.59146	validation_1-logloss:0.59974
# [159]	validation_0-logloss:0.59139	validation_1-logloss:0.59974
# [160]	validation_0-logloss:0.59128	validation_1-logloss:0.59970
# [161]	validation_0-logloss:0.59120	validation_1-logloss:0.59966
# [162]	validation_0-logloss:0.59112	validation_1-logloss:0.59963
# [163]	validation_0-logloss:0.59103	validation_1-logloss:0.59960
# [164]	validation_0-logloss:0.59081	validation_1-logloss:0.59941
# [165]	validation_0-logloss:0.59073	validation_1-logloss:0.59939
# [166]	validation_0-logloss:0.59062	validation_1-logloss:0.59931
# [167]	validation_0-logloss:0.59056	validation_1-logloss:0.59928
# [168]	validation_0-logloss:0.59047	validation_1-logloss:0.59925
# [169]	validation_0-logloss:0.59038	validation_1-logloss:0.59924
# [170]	validation_0-logloss:0.59025	validation_1-logloss:0.59916
# [171]	validation_0-logloss:0.59014	validation_1-logloss:0.59911
# [172]	validation_0-logloss:0.59008	validation_1-logloss:0.59910
# [173]	validation_0-logloss:0.59001	validation_1-logloss:0.59910
# [174]	validation_0-logloss:0.58993	validation_1-logloss:0.59907
# [175]	validation_0-logloss:0.58988	validation_1-logloss:0.59906
# [176]	validation_0-logloss:0.58982	validation_1-logloss:0.59906
# [177]	validation_0-logloss:0.58974	validation_1-logloss:0.59906
# [178]	validation_0-logloss:0.58962	validation_1-logloss:0.59901
# [179]	validation_0-logloss:0.58949	validation_1-logloss:0.59891
# [180]	validation_0-logloss:0.58943	validation_1-logloss:0.59891
# [181]	validation_0-logloss:0.58925	validation_1-logloss:0.59875
# [182]	validation_0-logloss:0.58905	validation_1-logloss:0.59861
# [183]	validation_0-logloss:0.58897	validation_1-logloss:0.59860
# [184]	validation_0-logloss:0.58893	validation_1-logloss:0.59860
# [185]	validation_0-logloss:0.58887	validation_1-logloss:0.59859
# [186]	validation_0-logloss:0.58872	validation_1-logloss:0.59849
# [187]	validation_0-logloss:0.58864	validation_1-logloss:0.59845
# [188]	validation_0-logloss:0.58852	validation_1-logloss:0.59840
# [189]	validation_0-logloss:0.58846	validation_1-logloss:0.59838
# [190]	validation_0-logloss:0.58832	validation_1-logloss:0.59830
# [191]	validation_0-logloss:0.58816	validation_1-logloss:0.59821
# [192]	validation_0-logloss:0.58807	validation_1-logloss:0.59818
# [193]	validation_0-logloss:0.58802	validation_1-logloss:0.59817
# [194]	validation_0-logloss:0.58774	validation_1-logloss:0.59790
# [195]	validation_0-logloss:0.58761	validation_1-logloss:0.59783
# [196]	validation_0-logloss:0.58754	validation_1-logloss:0.59782
# [197]	validation_0-logloss:0.58735	validation_1-logloss:0.59770
# [198]	validation_0-logloss:0.58724	validation_1-logloss:0.59764
# [199]	validation_0-logloss:0.58713	validation_1-logloss:0.59759
# [200]	validation_0-logloss:0.58701	validation_1-logloss:0.59754
# [201]	validation_0-logloss:0.58696	validation_1-logloss:0.59752
# [202]	validation_0-logloss:0.58688	validation_1-logloss:0.59749
# [203]	validation_0-logloss:0.58680	validation_1-logloss:0.59749
# [204]	validation_0-logloss:0.58673	validation_1-logloss:0.59748
# [205]	validation_0-logloss:0.58660	validation_1-logloss:0.59743
# [206]	validation_0-logloss:0.58653	validation_1-logloss:0.59742
# [207]	validation_0-logloss:0.58648	validation_1-logloss:0.59740
# [208]	validation_0-logloss:0.58642	validation_1-logloss:0.59738
# [209]	validation_0-logloss:0.58636	validation_1-logloss:0.59738
# [210]	validation_0-logloss:0.58630	validation_1-logloss:0.59737
# [211]	validation_0-logloss:0.58622	validation_1-logloss:0.59735
# [212]	validation_0-logloss:0.58615	validation_1-logloss:0.59734
# [213]	validation_0-logloss:0.58609	validation_1-logloss:0.59735
# [214]	validation_0-logloss:0.58594	validation_1-logloss:0.59725
# [215]	validation_0-logloss:0.58581	validation_1-logloss:0.59720
# [216]	validation_0-logloss:0.58566	validation_1-logloss:0.59711
# [217]	validation_0-logloss:0.58561	validation_1-logloss:0.59711
# [218]	validation_0-logloss:0.58546	validation_1-logloss:0.59699
# [219]	validation_0-logloss:0.58538	validation_1-logloss:0.59695
# [220]	validation_0-logloss:0.58533	validation_1-logloss:0.59695
# [221]	validation_0-logloss:0.58524	validation_1-logloss:0.59692
# [222]	validation_0-logloss:0.58518	validation_1-logloss:0.59691
# [223]	validation_0-logloss:0.58500	validation_1-logloss:0.59678
# [224]	validation_0-logloss:0.58488	validation_1-logloss:0.59672
# [225]	validation_0-logloss:0.58482	validation_1-logloss:0.59671
# [226]	validation_0-logloss:0.58475	validation_1-logloss:0.59671
# [227]	validation_0-logloss:0.58469	validation_1-logloss:0.59670
# [228]	validation_0-logloss:0.58465	validation_1-logloss:0.59671
# [229]	validation_0-logloss:0.58458	validation_1-logloss:0.59670
# [230]	validation_0-logloss:0.58441	validation_1-logloss:0.59657
# [231]	validation_0-logloss:0.58433	validation_1-logloss:0.59656
# [232]	validation_0-logloss:0.58427	validation_1-logloss:0.59655
# [233]	validation_0-logloss:0.58417	validation_1-logloss:0.59650
# [234]	validation_0-logloss:0.58408	validation_1-logloss:0.59647
# [235]	validation_0-logloss:0.58394	validation_1-logloss:0.59639
# [236]	validation_0-logloss:0.58387	validation_1-logloss:0.59639
# [237]	validation_0-logloss:0.58381	validation_1-logloss:0.59637
# [238]	validation_0-logloss:0.58374	validation_1-logloss:0.59635
# [239]	validation_0-logloss:0.58369	validation_1-logloss:0.59636
# [240]	validation_0-logloss:0.58359	validation_1-logloss:0.59632
# [241]	validation_0-logloss:0.58354	validation_1-logloss:0.59633
# [242]	validation_0-logloss:0.58346	validation_1-logloss:0.59631
# [243]	validation_0-logloss:0.58337	validation_1-logloss:0.59629
# [244]	validation_0-logloss:0.58332	validation_1-logloss:0.59627
# [245]	validation_0-logloss:0.58325	validation_1-logloss:0.59627
# [246]	validation_0-logloss:0.58315	validation_1-logloss:0.59623
# [247]	validation_0-logloss:0.58305	validation_1-logloss:0.59616
# [248]	validation_0-logloss:0.58297	validation_1-logloss:0.59614
# [249]	validation_0-logloss:0.58289	validation_1-logloss:0.59611
# [250]	validation_0-logloss:0.58277	validation_1-logloss:0.59605
# [251]	validation_0-logloss:0.58262	validation_1-logloss:0.59598
# [252]	validation_0-logloss:0.58254	validation_1-logloss:0.59597
# [253]	validation_0-logloss:0.58248	validation_1-logloss:0.59596
# [254]	validation_0-logloss:0.58239	validation_1-logloss:0.59595
# [255]	validation_0-logloss:0.58231	validation_1-logloss:0.59591
# [256]	validation_0-logloss:0.58222	validation_1-logloss:0.59586
# [257]	validation_0-logloss:0.58214	validation_1-logloss:0.59585
# [258]	validation_0-logloss:0.58210	validation_1-logloss:0.59585
# [259]	validation_0-logloss:0.58204	validation_1-logloss:0.59585
# [260]	validation_0-logloss:0.58196	validation_1-logloss:0.59583
# [261]	validation_0-logloss:0.58188	validation_1-logloss:0.59581
# [262]	validation_0-logloss:0.58183	validation_1-logloss:0.59579
# [263]	validation_0-logloss:0.58177	validation_1-logloss:0.59578
# [264]	validation_0-logloss:0.58173	validation_1-logloss:0.59578
# [265]	validation_0-logloss:0.58167	validation_1-logloss:0.59578
# [266]	validation_0-logloss:0.58159	validation_1-logloss:0.59579
# [267]	validation_0-logloss:0.58151	validation_1-logloss:0.59576
# [268]	validation_0-logloss:0.58144	validation_1-logloss:0.59577
# [269]	validation_0-logloss:0.58134	validation_1-logloss:0.59575
# [270]	validation_0-logloss:0.58126	validation_1-logloss:0.59574
# [271]	validation_0-logloss:0.58116	validation_1-logloss:0.59571
# [272]	validation_0-logloss:0.58109	validation_1-logloss:0.59569
# [273]	validation_0-logloss:0.58099	validation_1-logloss:0.59563
# [274]	validation_0-logloss:0.58094	validation_1-logloss:0.59562
# [275]	validation_0-logloss:0.58084	validation_1-logloss:0.59558
# [276]	validation_0-logloss:0.58077	validation_1-logloss:0.59558
# [277]	validation_0-logloss:0.58072	validation_1-logloss:0.59557
# [278]	validation_0-logloss:0.58067	validation_1-logloss:0.59557
# [279]	validation_0-logloss:0.58058	validation_1-logloss:0.59554
# [280]	validation_0-logloss:0.58051	validation_1-logloss:0.59555
# [281]	validation_0-logloss:0.58042	validation_1-logloss:0.59552
# [282]	validation_0-logloss:0.58030	validation_1-logloss:0.59546
# [283]	validation_0-logloss:0.58024	validation_1-logloss:0.59546
# [284]	validation_0-logloss:0.58017	validation_1-logloss:0.59546
# [285]	validation_0-logloss:0.58010	validation_1-logloss:0.59546
# [286]	validation_0-logloss:0.58002	validation_1-logloss:0.59543
# [287]	validation_0-logloss:0.57993	validation_1-logloss:0.59540
# [288]	validation_0-logloss:0.57987	validation_1-logloss:0.59538
# [289]	validation_0-logloss:0.57981	validation_1-logloss:0.59538
# [290]	validation_0-logloss:0.57975	validation_1-logloss:0.59537
# [291]	validation_0-logloss:0.57968	validation_1-logloss:0.59534
# [292]	validation_0-logloss:0.57962	validation_1-logloss:0.59534
# [293]	validation_0-logloss:0.57955	validation_1-logloss:0.59534
# [294]	validation_0-logloss:0.57940	validation_1-logloss:0.59524
# [295]	validation_0-logloss:0.57933	validation_1-logloss:0.59521
# [296]	validation_0-logloss:0.57925	validation_1-logloss:0.59519
# [297]	validation_0-logloss:0.57920	validation_1-logloss:0.59521
# [298]	validation_0-logloss:0.57915	validation_1-logloss:0.59521
# [299]	validation_0-logloss:0.57910	validation_1-logloss:0.59522
# [300]	validation_0-logloss:0.57901	validation_1-logloss:0.59520
# [301]	validation_0-logloss:0.57894	validation_1-logloss:0.59520
# [302]	validation_0-logloss:0.57888	validation_1-logloss:0.59519
# [303]	validation_0-logloss:0.57880	validation_1-logloss:0.59516
# [304]	validation_0-logloss:0.57875	validation_1-logloss:0.59516
# [305]	validation_0-logloss:0.57870	validation_1-logloss:0.59515
# [306]	validation_0-logloss:0.57865	validation_1-logloss:0.59514
# [307]	validation_0-logloss:0.57858	validation_1-logloss:0.59513
# [308]	validation_0-logloss:0.57849	validation_1-logloss:0.59512
# [309]	validation_0-logloss:0.57839	validation_1-logloss:0.59506
# [310]	validation_0-logloss:0.57834	validation_1-logloss:0.59505
# [311]	validation_0-logloss:0.57827	validation_1-logloss:0.59505
# [312]	validation_0-logloss:0.57819	validation_1-logloss:0.59504
# [313]	validation_0-logloss:0.57800	validation_1-logloss:0.59485
# [314]	validation_0-logloss:0.57794	validation_1-logloss:0.59483
# [315]	validation_0-logloss:0.57788	validation_1-logloss:0.59482
# [316]	validation_0-logloss:0.57782	validation_1-logloss:0.59481
# [317]	validation_0-logloss:0.57775	validation_1-logloss:0.59480
# [318]	validation_0-logloss:0.57770	validation_1-logloss:0.59481
# [319]	validation_0-logloss:0.57763	validation_1-logloss:0.59480
# [320]	validation_0-logloss:0.57758	validation_1-logloss:0.59480
# [321]	validation_0-logloss:0.57750	validation_1-logloss:0.59479
# [322]	validation_0-logloss:0.57745	validation_1-logloss:0.59479
# [323]	validation_0-logloss:0.57739	validation_1-logloss:0.59479
# [324]	validation_0-logloss:0.57733	validation_1-logloss:0.59479
# [325]	validation_0-logloss:0.57726	validation_1-logloss:0.59477
# [326]	validation_0-logloss:0.57721	validation_1-logloss:0.59475
# [327]	validation_0-logloss:0.57717	validation_1-logloss:0.59475
# [328]	validation_0-logloss:0.57712	validation_1-logloss:0.59475
# [329]	validation_0-logloss:0.57706	validation_1-logloss:0.59474
# [330]	validation_0-logloss:0.57699	validation_1-logloss:0.59475
# [331]	validation_0-logloss:0.57689	validation_1-logloss:0.59472
# [332]	validation_0-logloss:0.57684	validation_1-logloss:0.59471
# [333]	validation_0-logloss:0.57677	validation_1-logloss:0.59468
# [334]	validation_0-logloss:0.57668	validation_1-logloss:0.59466
# [335]	validation_0-logloss:0.57660	validation_1-logloss:0.59465
# [336]	validation_0-logloss:0.57655	validation_1-logloss:0.59464
# [337]	validation_0-logloss:0.57648	validation_1-logloss:0.59464
# [338]	validation_0-logloss:0.57642	validation_1-logloss:0.59463
# [339]	validation_0-logloss:0.57633	validation_1-logloss:0.59461
# [340]	validation_0-logloss:0.57627	validation_1-logloss:0.59460
# [341]	validation_0-logloss:0.57620	validation_1-logloss:0.59461
# [342]	validation_0-logloss:0.57614	validation_1-logloss:0.59459
# [343]	validation_0-logloss:0.57604	validation_1-logloss:0.59455
# [344]	validation_0-logloss:0.57598	validation_1-logloss:0.59455
# [345]	validation_0-logloss:0.57592	validation_1-logloss:0.59455
# [346]	validation_0-logloss:0.57588	validation_1-logloss:0.59455
# [347]	validation_0-logloss:0.57583	validation_1-logloss:0.59455
# [348]	validation_0-logloss:0.57577	validation_1-logloss:0.59455
# [349]	validation_0-logloss:0.57571	validation_1-logloss:0.59456
# [350]	validation_0-logloss:0.57565	validation_1-logloss:0.59455
# [351]	validation_0-logloss:0.57561	validation_1-logloss:0.59455
# [352]	validation_0-logloss:0.57553	validation_1-logloss:0.59453
# [353]	validation_0-logloss:0.57546	validation_1-logloss:0.59450
# [354]	validation_0-logloss:0.57541	validation_1-logloss:0.59451
# [355]	validation_0-logloss:0.57535	validation_1-logloss:0.59452
# [356]	validation_0-logloss:0.57529	validation_1-logloss:0.59453
# [357]	validation_0-logloss:0.57524	validation_1-logloss:0.59453
# [358]	validation_0-logloss:0.57518	validation_1-logloss:0.59453
# [359]	validation_0-logloss:0.57512	validation_1-logloss:0.59452
# [360]	validation_0-logloss:0.57506	validation_1-logloss:0.59452
# [361]	validation_0-logloss:0.57500	validation_1-logloss:0.59452
# [362]	validation_0-logloss:0.57494	validation_1-logloss:0.59452
# [363]	validation_0-logloss:0.57487	validation_1-logloss:0.59450
# [364]	validation_0-logloss:0.57483	validation_1-logloss:0.59451
# [365]	validation_0-logloss:0.57478	validation_1-logloss:0.59449
# [366]	validation_0-logloss:0.57467	validation_1-logloss:0.59444
# [367]	validation_0-logloss:0.57457	validation_1-logloss:0.59441
# [368]	validation_0-logloss:0.57451	validation_1-logloss:0.59440
# [369]	validation_0-logloss:0.57441	validation_1-logloss:0.59435
# [370]	validation_0-logloss:0.57432	validation_1-logloss:0.59431
# [371]	validation_0-logloss:0.57427	validation_1-logloss:0.59432
# [372]	validation_0-logloss:0.57421	validation_1-logloss:0.59431
# [373]	validation_0-logloss:0.57410	validation_1-logloss:0.59428
# [374]	validation_0-logloss:0.57402	validation_1-logloss:0.59426
# [375]	validation_0-logloss:0.57396	validation_1-logloss:0.59426
# [376]	validation_0-logloss:0.57384	validation_1-logloss:0.59419
# [377]	validation_0-logloss:0.57378	validation_1-logloss:0.59418
# [378]	validation_0-logloss:0.57362	validation_1-logloss:0.59408
# [379]	validation_0-logloss:0.57354	validation_1-logloss:0.59406
# [380]	validation_0-logloss:0.57346	validation_1-logloss:0.59405
# [381]	validation_0-logloss:0.57340	validation_1-logloss:0.59404
# [382]	validation_0-logloss:0.57331	validation_1-logloss:0.59404
# [383]	validation_0-logloss:0.57325	validation_1-logloss:0.59403
# [384]	validation_0-logloss:0.57317	validation_1-logloss:0.59400
# [385]	validation_0-logloss:0.57308	validation_1-logloss:0.59398
# [386]	validation_0-logloss:0.57302	validation_1-logloss:0.59397
# [387]	validation_0-logloss:0.57296	validation_1-logloss:0.59395
# [388]	validation_0-logloss:0.57288	validation_1-logloss:0.59394
# [389]	validation_0-logloss:0.57282	validation_1-logloss:0.59395
# [390]	validation_0-logloss:0.57277	validation_1-logloss:0.59395
# [391]	validation_0-logloss:0.57271	validation_1-logloss:0.59395
# [392]	validation_0-logloss:0.57258	validation_1-logloss:0.59387
# [393]	validation_0-logloss:0.57248	validation_1-logloss:0.59385
# [394]	validation_0-logloss:0.57241	validation_1-logloss:0.59385
# [395]	validation_0-logloss:0.57235	validation_1-logloss:0.59383
# [396]	validation_0-logloss:0.57229	validation_1-logloss:0.59382
# [397]	validation_0-logloss:0.57224	validation_1-logloss:0.59380
# [398]	validation_0-logloss:0.57218	validation_1-logloss:0.59379
# [399]	validation_0-logloss:0.57211	validation_1-logloss:0.59379
# [400]	validation_0-logloss:0.57204	validation_1-logloss:0.59377
# [401]	validation_0-logloss:0.57199	validation_1-logloss:0.59378
# [402]	validation_0-logloss:0.57193	validation_1-logloss:0.59378
# [403]	validation_0-logloss:0.57186	validation_1-logloss:0.59377
# [404]	validation_0-logloss:0.57178	validation_1-logloss:0.59375
# [405]	validation_0-logloss:0.57171	validation_1-logloss:0.59373
# [406]	validation_0-logloss:0.57161	validation_1-logloss:0.59370
# [407]	validation_0-logloss:0.57153	validation_1-logloss:0.59368
# [408]	validation_0-logloss:0.57147	validation_1-logloss:0.59368
# [409]	validation_0-logloss:0.57134	validation_1-logloss:0.59359
# [410]	validation_0-logloss:0.57130	validation_1-logloss:0.59359
# [411]	validation_0-logloss:0.57125	validation_1-logloss:0.59359
# [412]	validation_0-logloss:0.57118	validation_1-logloss:0.59357
# [413]	validation_0-logloss:0.57112	validation_1-logloss:0.59359
# [414]	validation_0-logloss:0.57105	validation_1-logloss:0.59357
# [415]	validation_0-logloss:0.57098	validation_1-logloss:0.59358
# [416]	validation_0-logloss:0.57092	validation_1-logloss:0.59357
# [417]	validation_0-logloss:0.57087	validation_1-logloss:0.59358
# [418]	validation_0-logloss:0.57082	validation_1-logloss:0.59357
# [419]	validation_0-logloss:0.57075	validation_1-logloss:0.59355
# [420]	validation_0-logloss:0.57069	validation_1-logloss:0.59356
# [421]	validation_0-logloss:0.57063	validation_1-logloss:0.59355
# [422]	validation_0-logloss:0.57056	validation_1-logloss:0.59355
# [423]	validation_0-logloss:0.57048	validation_1-logloss:0.59351
# [424]	validation_0-logloss:0.57042	validation_1-logloss:0.59350
# [425]	validation_0-logloss:0.57035	validation_1-logloss:0.59348
# [426]	validation_0-logloss:0.57029	validation_1-logloss:0.59347
# [427]	validation_0-logloss:0.57025	validation_1-logloss:0.59349
# [428]	validation_0-logloss:0.57019	validation_1-logloss:0.59348
# [429]	validation_0-logloss:0.57010	validation_1-logloss:0.59345
# [430]	validation_0-logloss:0.57001	validation_1-logloss:0.59342
# [431]	validation_0-logloss:0.56994	validation_1-logloss:0.59340
# [432]	validation_0-logloss:0.56990	validation_1-logloss:0.59340
# [433]	validation_0-logloss:0.56983	validation_1-logloss:0.59339
# [434]	validation_0-logloss:0.56979	validation_1-logloss:0.59339
# [435]	validation_0-logloss:0.56973	validation_1-logloss:0.59339
# [436]	validation_0-logloss:0.56969	validation_1-logloss:0.59340
# [437]	validation_0-logloss:0.56962	validation_1-logloss:0.59336
# [438]	validation_0-logloss:0.56957	validation_1-logloss:0.59337
# [439]	validation_0-logloss:0.56945	validation_1-logloss:0.59331
# [440]	validation_0-logloss:0.56940	validation_1-logloss:0.59332
# [441]	validation_0-logloss:0.56929	validation_1-logloss:0.59328
# [442]	validation_0-logloss:0.56920	validation_1-logloss:0.59325
# [443]	validation_0-logloss:0.56908	validation_1-logloss:0.59319
# [444]	validation_0-logloss:0.56901	validation_1-logloss:0.59318
# [445]	validation_0-logloss:0.56893	validation_1-logloss:0.59314
# [446]	validation_0-logloss:0.56886	validation_1-logloss:0.59313
# [447]	validation_0-logloss:0.56880	validation_1-logloss:0.59312
# [448]	validation_0-logloss:0.56875	validation_1-logloss:0.59311
# [449]	validation_0-logloss:0.56867	validation_1-logloss:0.59309
# [450]	validation_0-logloss:0.56862	validation_1-logloss:0.59309
# [451]	validation_0-logloss:0.56853	validation_1-logloss:0.59306
# [452]	validation_0-logloss:0.56839	validation_1-logloss:0.59295
# [453]	validation_0-logloss:0.56831	validation_1-logloss:0.59294
# [454]	validation_0-logloss:0.56826	validation_1-logloss:0.59294
# [455]	validation_0-logloss:0.56816	validation_1-logloss:0.59285
# [456]	validation_0-logloss:0.56810	validation_1-logloss:0.59286
# [457]	validation_0-logloss:0.56805	validation_1-logloss:0.59286
# [458]	validation_0-logloss:0.56797	validation_1-logloss:0.59281
# [459]	validation_0-logloss:0.56790	validation_1-logloss:0.59281
# [460]	validation_0-logloss:0.56782	validation_1-logloss:0.59279
# [461]	validation_0-logloss:0.56776	validation_1-logloss:0.59278
# [462]	validation_0-logloss:0.56772	validation_1-logloss:0.59278
# [463]	validation_0-logloss:0.56768	validation_1-logloss:0.59277
# [464]	validation_0-logloss:0.56762	validation_1-logloss:0.59278
# [465]	validation_0-logloss:0.56756	validation_1-logloss:0.59278
# [466]	validation_0-logloss:0.56749	validation_1-logloss:0.59276
# [467]	validation_0-logloss:0.56738	validation_1-logloss:0.59270
# [468]	validation_0-logloss:0.56731	validation_1-logloss:0.59270
# [469]	validation_0-logloss:0.56726	validation_1-logloss:0.59269
# [470]	validation_0-logloss:0.56719	validation_1-logloss:0.59269
# [471]	validation_0-logloss:0.56715	validation_1-logloss:0.59268
# [472]	validation_0-logloss:0.56709	validation_1-logloss:0.59268
# [473]	validation_0-logloss:0.56705	validation_1-logloss:0.59269
# [474]	validation_0-logloss:0.56698	validation_1-logloss:0.59267
# [475]	validation_0-logloss:0.56693	validation_1-logloss:0.59267
# [476]	validation_0-logloss:0.56686	validation_1-logloss:0.59267
# [477]	validation_0-logloss:0.56672	validation_1-logloss:0.59259
# [478]	validation_0-logloss:0.56666	validation_1-logloss:0.59257
# [479]	validation_0-logloss:0.56661	validation_1-logloss:0.59257
# [480]	validation_0-logloss:0.56656	validation_1-logloss:0.59256
# [481]	validation_0-logloss:0.56649	validation_1-logloss:0.59256
# [482]	validation_0-logloss:0.56642	validation_1-logloss:0.59255
# [483]	validation_0-logloss:0.56637	validation_1-logloss:0.59254
# [484]	validation_0-logloss:0.56630	validation_1-logloss:0.59253
# [485]	validation_0-logloss:0.56624	validation_1-logloss:0.59253
# [486]	validation_0-logloss:0.56618	validation_1-logloss:0.59251
# [487]	validation_0-logloss:0.56612	validation_1-logloss:0.59251
# [488]	validation_0-logloss:0.56604	validation_1-logloss:0.59251
# [489]	validation_0-logloss:0.56599	validation_1-logloss:0.59251
# [490]	validation_0-logloss:0.56594	validation_1-logloss:0.59252
# [491]	validation_0-logloss:0.56589	validation_1-logloss:0.59251
# [492]	validation_0-logloss:0.56583	validation_1-logloss:0.59251
# [493]	validation_0-logloss:0.56578	validation_1-logloss:0.59250
# [494]	validation_0-logloss:0.56574	validation_1-logloss:0.59251
# [495]	validation_0-logloss:0.56569	validation_1-logloss:0.59252
# [496]	validation_0-logloss:0.56564	validation_1-logloss:0.59252
# [497]	validation_0-logloss:0.56558	validation_1-logloss:0.59251
# [498]	validation_0-logloss:0.56553	validation_1-logloss:0.59251
# [499]	validation_0-logloss:0.56547	validation_1-logloss:0.59252
# [500]	validation_0-logloss:0.56543	validation_1-logloss:0.59253
# [501]	validation_0-logloss:0.56535	validation_1-logloss:0.59253
# [502]	validation_0-logloss:0.56529	validation_1-logloss:0.59251
# [503]	validation_0-logloss:0.56522	validation_1-logloss:0.59252
# [504]	validation_0-logloss:0.56517	validation_1-logloss:0.59253
# [505]	validation_0-logloss:0.56512	validation_1-logloss:0.59252
# [506]	validation_0-logloss:0.56504	validation_1-logloss:0.59249
# [507]	validation_0-logloss:0.56499	validation_1-logloss:0.59250
# [508]	validation_0-logloss:0.56491	validation_1-logloss:0.59247
# [509]	validation_0-logloss:0.56484	validation_1-logloss:0.59246
# [510]	validation_0-logloss:0.56480	validation_1-logloss:0.59245
# [511]	validation_0-logloss:0.56475	validation_1-logloss:0.59244
# [512]	validation_0-logloss:0.56466	validation_1-logloss:0.59241
# [513]	validation_0-logloss:0.56459	validation_1-logloss:0.59240
# [514]	validation_0-logloss:0.56453	validation_1-logloss:0.59240
# [515]	validation_0-logloss:0.56446	validation_1-logloss:0.59239
# [516]	validation_0-logloss:0.56440	validation_1-logloss:0.59239
# [517]	validation_0-logloss:0.56437	validation_1-logloss:0.59239
# [518]	validation_0-logloss:0.56431	validation_1-logloss:0.59239
# [519]	validation_0-logloss:0.56424	validation_1-logloss:0.59236
# [520]	validation_0-logloss:0.56418	validation_1-logloss:0.59236
# [521]	validation_0-logloss:0.56406	validation_1-logloss:0.59232
# [522]	validation_0-logloss:0.56401	validation_1-logloss:0.59231
# [523]	validation_0-logloss:0.56394	validation_1-logloss:0.59229
# [524]	validation_0-logloss:0.56388	validation_1-logloss:0.59230
# [525]	validation_0-logloss:0.56383	validation_1-logloss:0.59230
# [526]	validation_0-logloss:0.56378	validation_1-logloss:0.59231
# [527]	validation_0-logloss:0.56372	validation_1-logloss:0.59230
# [528]	validation_0-logloss:0.56368	validation_1-logloss:0.59231
# [529]	validation_0-logloss:0.56362	validation_1-logloss:0.59230
# [530]	validation_0-logloss:0.56356	validation_1-logloss:0.59230
# [531]	validation_0-logloss:0.56350	validation_1-logloss:0.59230
# [532]	validation_0-logloss:0.56345	validation_1-logloss:0.59231
# [533]	validation_0-logloss:0.56339	validation_1-logloss:0.59229
# [534]	validation_0-logloss:0.56332	validation_1-logloss:0.59228
# [535]	validation_0-logloss:0.56328	validation_1-logloss:0.59226
# [536]	validation_0-logloss:0.56313	validation_1-logloss:0.59217
# [537]	validation_0-logloss:0.56305	validation_1-logloss:0.59214
# [538]	validation_0-logloss:0.56295	validation_1-logloss:0.59210
# [539]	validation_0-logloss:0.56285	validation_1-logloss:0.59205
# [540]	validation_0-logloss:0.56278	validation_1-logloss:0.59205
# [541]	validation_0-logloss:0.56273	validation_1-logloss:0.59203
# [542]	validation_0-logloss:0.56270	validation_1-logloss:0.59203
# [543]	validation_0-logloss:0.56264	validation_1-logloss:0.59204
# [544]	validation_0-logloss:0.56257	validation_1-logloss:0.59204
# [545]	validation_0-logloss:0.56252	validation_1-logloss:0.59206
# [546]	validation_0-logloss:0.56248	validation_1-logloss:0.59206
# [547]	validation_0-logloss:0.56242	validation_1-logloss:0.59205
# [548]	validation_0-logloss:0.56238	validation_1-logloss:0.59205
# [549]	validation_0-logloss:0.56233	validation_1-logloss:0.59206
# [550]	validation_0-logloss:0.56223	validation_1-logloss:0.59200
# [551]	validation_0-logloss:0.56217	validation_1-logloss:0.59199
# [552]	validation_0-logloss:0.56210	validation_1-logloss:0.59196
# [553]	validation_0-logloss:0.56202	validation_1-logloss:0.59193
# [554]	validation_0-logloss:0.56198	validation_1-logloss:0.59193
# [555]	validation_0-logloss:0.56194	validation_1-logloss:0.59193
# [556]	validation_0-logloss:0.56189	validation_1-logloss:0.59192
# [557]	validation_0-logloss:0.56184	validation_1-logloss:0.59192
# [558]	validation_0-logloss:0.56178	validation_1-logloss:0.59192
# [559]	validation_0-logloss:0.56174	validation_1-logloss:0.59194
# [560]	validation_0-logloss:0.56168	validation_1-logloss:0.59192
# [561]	validation_0-logloss:0.56163	validation_1-logloss:0.59193
# [562]	validation_0-logloss:0.56157	validation_1-logloss:0.59193
# [563]	validation_0-logloss:0.56150	validation_1-logloss:0.59193
# [564]	validation_0-logloss:0.56145	validation_1-logloss:0.59193
# [565]	validation_0-logloss:0.56140	validation_1-logloss:0.59192
# [566]	validation_0-logloss:0.56134	validation_1-logloss:0.59192
# [567]	validation_0-logloss:0.56131	validation_1-logloss:0.59193
# [568]	validation_0-logloss:0.56125	validation_1-logloss:0.59192
# [569]	validation_0-logloss:0.56119	validation_1-logloss:0.59191
# [570]	validation_0-logloss:0.56114	validation_1-logloss:0.59190
# [571]	validation_0-logloss:0.56107	validation_1-logloss:0.59191
# [572]	validation_0-logloss:0.56102	validation_1-logloss:0.59191
# [573]	validation_0-logloss:0.56097	validation_1-logloss:0.59191
# [574]	validation_0-logloss:0.56090	validation_1-logloss:0.59187
# [575]	validation_0-logloss:0.56083	validation_1-logloss:0.59187
# [576]	validation_0-logloss:0.56078	validation_1-logloss:0.59188
# [577]	validation_0-logloss:0.56074	validation_1-logloss:0.59187
# [578]	validation_0-logloss:0.56067	validation_1-logloss:0.59187
# [579]	validation_0-logloss:0.56061	validation_1-logloss:0.59187
# [580]	validation_0-logloss:0.56057	validation_1-logloss:0.59187
# [581]	validation_0-logloss:0.56051	validation_1-logloss:0.59186
# [582]	validation_0-logloss:0.56043	validation_1-logloss:0.59184
# [583]	validation_0-logloss:0.56037	validation_1-logloss:0.59182
# [584]	validation_0-logloss:0.56032	validation_1-logloss:0.59182
# [585]	validation_0-logloss:0.56022	validation_1-logloss:0.59177
# [586]	validation_0-logloss:0.56017	validation_1-logloss:0.59177
# [587]	validation_0-logloss:0.56014	validation_1-logloss:0.59177
# [588]	validation_0-logloss:0.56008	validation_1-logloss:0.59176
# [589]	validation_0-logloss:0.56001	validation_1-logloss:0.59176
# [590]	validation_0-logloss:0.55996	validation_1-logloss:0.59176
# [591]	validation_0-logloss:0.55991	validation_1-logloss:0.59177
# [592]	validation_0-logloss:0.55985	validation_1-logloss:0.59176
# [593]	validation_0-logloss:0.55980	validation_1-logloss:0.59177
# [594]	validation_0-logloss:0.55977	validation_1-logloss:0.59176
# [595]	validation_0-logloss:0.55971	validation_1-logloss:0.59174
# [596]	validation_0-logloss:0.55964	validation_1-logloss:0.59175
# [597]	validation_0-logloss:0.55957	validation_1-logloss:0.59175
# [598]	validation_0-logloss:0.55952	validation_1-logloss:0.59175
# [599]	validation_0-logloss:0.55948	validation_1-logloss:0.59175
# [600]	validation_0-logloss:0.55942	validation_1-logloss:0.59174
# [601]	validation_0-logloss:0.55935	validation_1-logloss:0.59172
# [602]	validation_0-logloss:0.55929	validation_1-logloss:0.59171
# [603]	validation_0-logloss:0.55923	validation_1-logloss:0.59172
# [604]	validation_0-logloss:0.55916	validation_1-logloss:0.59170
# [605]	validation_0-logloss:0.55909	validation_1-logloss:0.59170
# [606]	validation_0-logloss:0.55902	validation_1-logloss:0.59167
# [607]	validation_0-logloss:0.55897	validation_1-logloss:0.59167
# [608]	validation_0-logloss:0.55893	validation_1-logloss:0.59167
# [609]	validation_0-logloss:0.55888	validation_1-logloss:0.59167
# [610]	validation_0-logloss:0.55881	validation_1-logloss:0.59166
# [611]	validation_0-logloss:0.55875	validation_1-logloss:0.59167
# [612]	validation_0-logloss:0.55869	validation_1-logloss:0.59168
# [613]	validation_0-logloss:0.55864	validation_1-logloss:0.59169
# [614]	validation_0-logloss:0.55858	validation_1-logloss:0.59168
# [615]	validation_0-logloss:0.55854	validation_1-logloss:0.59168
# [616]	validation_0-logloss:0.55850	validation_1-logloss:0.59169
# [617]	validation_0-logloss:0.55844	validation_1-logloss:0.59168
# [618]	validation_0-logloss:0.55840	validation_1-logloss:0.59168
# [619]	validation_0-logloss:0.55836	validation_1-logloss:0.59167
# [620]	validation_0-logloss:0.55831	validation_1-logloss:0.59167
# [621]	validation_0-logloss:0.55826	validation_1-logloss:0.59167
# [622]	validation_0-logloss:0.55819	validation_1-logloss:0.59167
# [623]	validation_0-logloss:0.55814	validation_1-logloss:0.59167
# [624]	validation_0-logloss:0.55809	validation_1-logloss:0.59166
# [625]	validation_0-logloss:0.55799	validation_1-logloss:0.59161
# [626]	validation_0-logloss:0.55794	validation_1-logloss:0.59160
# [627]	validation_0-logloss:0.55789	validation_1-logloss:0.59160
# [628]	validation_0-logloss:0.55783	validation_1-logloss:0.59159
# [629]	validation_0-logloss:0.55776	validation_1-logloss:0.59158
# [630]	validation_0-logloss:0.55771	validation_1-logloss:0.59157
# [631]	validation_0-logloss:0.55765	validation_1-logloss:0.59158
# [632]	validation_0-logloss:0.55760	validation_1-logloss:0.59158
# [633]	validation_0-logloss:0.55754	validation_1-logloss:0.59157
# [634]	validation_0-logloss:0.55749	validation_1-logloss:0.59156
# [635]	validation_0-logloss:0.55743	validation_1-logloss:0.59155
# [636]	validation_0-logloss:0.55737	validation_1-logloss:0.59155
# [637]	validation_0-logloss:0.55731	validation_1-logloss:0.59155
# [638]	validation_0-logloss:0.55725	validation_1-logloss:0.59155
# [639]	validation_0-logloss:0.55719	validation_1-logloss:0.59154
# [640]	validation_0-logloss:0.55714	validation_1-logloss:0.59156
# [641]	validation_0-logloss:0.55708	validation_1-logloss:0.59154
# [642]	validation_0-logloss:0.55703	validation_1-logloss:0.59157
# [643]	validation_0-logloss:0.55698	validation_1-logloss:0.59156
# [644]	validation_0-logloss:0.55692	validation_1-logloss:0.59156
# [645]	validation_0-logloss:0.55686	validation_1-logloss:0.59156
# [646]	validation_0-logloss:0.55682	validation_1-logloss:0.59155
# [647]	validation_0-logloss:0.55676	validation_1-logloss:0.59154
# [648]	validation_0-logloss:0.55671	validation_1-logloss:0.59156
# [649]	validation_0-logloss:0.55667	validation_1-logloss:0.59156
# [650]	validation_0-logloss:0.55661	validation_1-logloss:0.59157
# [651]	validation_0-logloss:0.55655	validation_1-logloss:0.59156
# [652]	validation_0-logloss:0.55650	validation_1-logloss:0.59157
# [653]	validation_0-logloss:0.55644	validation_1-logloss:0.59155
# [654]	validation_0-logloss:0.55640	validation_1-logloss:0.59156
# [655]	validation_0-logloss:0.55637	validation_1-logloss:0.59156
# [656]	validation_0-logloss:0.55630	validation_1-logloss:0.59154
# [657]	validation_0-logloss:0.55625	validation_1-logloss:0.59155
# [658]	validation_0-logloss:0.55621	validation_1-logloss:0.59154
# [659]	validation_0-logloss:0.55615	validation_1-logloss:0.59155
# [660]	validation_0-logloss:0.55609	validation_1-logloss:0.59154
# [661]	validation_0-logloss:0.55606	validation_1-logloss:0.59155
# [662]	validation_0-logloss:0.55599	validation_1-logloss:0.59154
# [663]	validation_0-logloss:0.55597	validation_1-logloss:0.59154
# [664]	validation_0-logloss:0.55592	validation_1-logloss:0.59153
# [665]	validation_0-logloss:0.55587	validation_1-logloss:0.59152
# [666]	validation_0-logloss:0.55579	validation_1-logloss:0.59151
# [667]	validation_0-logloss:0.55575	validation_1-logloss:0.59151
# [668]	validation_0-logloss:0.55570	validation_1-logloss:0.59152
# [669]	validation_0-logloss:0.55564	validation_1-logloss:0.59153
# [670]	validation_0-logloss:0.55555	validation_1-logloss:0.59149
# [671]	validation_0-logloss:0.55549	validation_1-logloss:0.59147
# [672]	validation_0-logloss:0.55543	validation_1-logloss:0.59147
# [673]	validation_0-logloss:0.55537	validation_1-logloss:0.59146
# [674]	validation_0-logloss:0.55532	validation_1-logloss:0.59147
# [675]	validation_0-logloss:0.55525	validation_1-logloss:0.59146
# [676]	validation_0-logloss:0.55519	validation_1-logloss:0.59146
# [677]	validation_0-logloss:0.55515	validation_1-logloss:0.59147
# [678]	validation_0-logloss:0.55510	validation_1-logloss:0.59147
# [679]	validation_0-logloss:0.55506	validation_1-logloss:0.59147
# [680]	validation_0-logloss:0.55501	validation_1-logloss:0.59147
# [681]	validation_0-logloss:0.55496	validation_1-logloss:0.59145
# [682]	validation_0-logloss:0.55490	validation_1-logloss:0.59146
# [683]	validation_0-logloss:0.55484	validation_1-logloss:0.59145
# [684]	validation_0-logloss:0.55480	validation_1-logloss:0.59146
# [685]	validation_0-logloss:0.55476	validation_1-logloss:0.59147
# [686]	validation_0-logloss:0.55469	validation_1-logloss:0.59147
# [687]	validation_0-logloss:0.55466	validation_1-logloss:0.59147
# [688]	validation_0-logloss:0.55460	validation_1-logloss:0.59146
# [689]	validation_0-logloss:0.55454	validation_1-logloss:0.59146
# [690]	validation_0-logloss:0.55447	validation_1-logloss:0.59145
# [691]	validation_0-logloss:0.55441	validation_1-logloss:0.59145
# [692]	validation_0-logloss:0.55435	validation_1-logloss:0.59146
# [693]	validation_0-logloss:0.55429	validation_1-logloss:0.59146
# [694]	validation_0-logloss:0.55426	validation_1-logloss:0.59147
# [695]	validation_0-logloss:0.55420	validation_1-logloss:0.59148
# [696]	validation_0-logloss:0.55415	validation_1-logloss:0.59148
# [697]	validation_0-logloss:0.55409	validation_1-logloss:0.59147
# [698]	validation_0-logloss:0.55404	validation_1-logloss:0.59148
# [699]	validation_0-logloss:0.55399	validation_1-logloss:0.59148
# [700]	validation_0-logloss:0.55394	validation_1-logloss:0.59148
# [701]	validation_0-logloss:0.55387	validation_1-logloss:0.59148
# [702]	validation_0-logloss:0.55382	validation_1-logloss:0.59148
# [703]	validation_0-logloss:0.55376	validation_1-logloss:0.59147
# [704]	validation_0-logloss:0.55371	validation_1-logloss:0.59149
# [705]	validation_0-logloss:0.55366	validation_1-logloss:0.59149
# [706]	validation_0-logloss:0.55359	validation_1-logloss:0.59149
# [707]	validation_0-logloss:0.55354	validation_1-logloss:0.59150
# [708]	validation_0-logloss:0.55347	validation_1-logloss:0.59145
# [709]	validation_0-logloss:0.55341	validation_1-logloss:0.59145
# [710]	validation_0-logloss:0.55335	validation_1-logloss:0.59146
# [711]	validation_0-logloss:0.55331	validation_1-logloss:0.59146
# [712]	validation_0-logloss:0.55323	validation_1-logloss:0.59146
# [713]	validation_0-logloss:0.55319	validation_1-logloss:0.59146
# [714]	validation_0-logloss:0.55312	validation_1-logloss:0.59145
# [715]	validation_0-logloss:0.55308	validation_1-logloss:0.59143
# [716]	validation_0-logloss:0.55301	validation_1-logloss:0.59142
# [717]	validation_0-logloss:0.55297	validation_1-logloss:0.59143
# [718]	validation_0-logloss:0.55289	validation_1-logloss:0.59142
# [719]	validation_0-logloss:0.55284	validation_1-logloss:0.59143
# [720]	validation_0-logloss:0.55278	validation_1-logloss:0.59140
# [721]	validation_0-logloss:0.55270	validation_1-logloss:0.59138
# [722]	validation_0-logloss:0.55266	validation_1-logloss:0.59137
# [723]	validation_0-logloss:0.55260	validation_1-logloss:0.59138
# [724]	validation_0-logloss:0.55255	validation_1-logloss:0.59138
# [725]	validation_0-logloss:0.55249	validation_1-logloss:0.59138
# [726]	validation_0-logloss:0.55245	validation_1-logloss:0.59139
# [727]	validation_0-logloss:0.55240	validation_1-logloss:0.59138
# [728]	validation_0-logloss:0.55232	validation_1-logloss:0.59133
# [729]	validation_0-logloss:0.55225	validation_1-logloss:0.59131
# [730]	validation_0-logloss:0.55221	validation_1-logloss:0.59131
# [731]	validation_0-logloss:0.55216	validation_1-logloss:0.59131
# [732]	validation_0-logloss:0.55211	validation_1-logloss:0.59132
# [733]	validation_0-logloss:0.55206	validation_1-logloss:0.59132
# [734]	validation_0-logloss:0.55202	validation_1-logloss:0.59134
# [735]	validation_0-logloss:0.55196	validation_1-logloss:0.59134
# [736]	validation_0-logloss:0.55191	validation_1-logloss:0.59134
# [737]	validation_0-logloss:0.55186	validation_1-logloss:0.59134
# [738]	validation_0-logloss:0.55182	validation_1-logloss:0.59134
# [739]	validation_0-logloss:0.55178	validation_1-logloss:0.59134
# [740]	validation_0-logloss:0.55175	validation_1-logloss:0.59135
# [741]	validation_0-logloss:0.55169	validation_1-logloss:0.59135
# [742]	validation_0-logloss:0.55163	validation_1-logloss:0.59134
# [743]	validation_0-logloss:0.55157	validation_1-logloss:0.59136
# [744]	validation_0-logloss:0.55152	validation_1-logloss:0.59136
# [745]	validation_0-logloss:0.55147	validation_1-logloss:0.59135
# [746]	validation_0-logloss:0.55142	validation_1-logloss:0.59136
# [747]	validation_0-logloss:0.55138	validation_1-logloss:0.59135
# [748]	validation_0-logloss:0.55134	validation_1-logloss:0.59135
# [749]	validation_0-logloss:0.55128	validation_1-logloss:0.59136
# [750]	validation_0-logloss:0.55123	validation_1-logloss:0.59136
# [751]	validation_0-logloss:0.55119	validation_1-logloss:0.59135
# [752]	validation_0-logloss:0.55116	validation_1-logloss:0.59135
# [753]	validation_0-logloss:0.55111	validation_1-logloss:0.59135
# [754]	validation_0-logloss:0.55105	validation_1-logloss:0.59135
# [755]	validation_0-logloss:0.55099	validation_1-logloss:0.59135
# [756]	validation_0-logloss:0.55093	validation_1-logloss:0.59134
# [757]	validation_0-logloss:0.55089	validation_1-logloss:0.59135
# [758]	validation_0-logloss:0.55084	validation_1-logloss:0.59135
# [759]	validation_0-logloss:0.55078	validation_1-logloss:0.59135
# [760]	validation_0-logloss:0.55074	validation_1-logloss:0.59137
# [761]	validation_0-logloss:0.55070	validation_1-logloss:0.59137
# [762]	validation_0-logloss:0.55065	validation_1-logloss:0.59137
# [763]	validation_0-logloss:0.55059	validation_1-logloss:0.59136
# [764]	validation_0-logloss:0.55053	validation_1-logloss:0.59136
# [765]	validation_0-logloss:0.55046	validation_1-logloss:0.59133
# [766]	validation_0-logloss:0.55041	validation_1-logloss:0.59133
# [767]	validation_0-logloss:0.55035	validation_1-logloss:0.59135
# [768]	validation_0-logloss:0.55030	validation_1-logloss:0.59135
# [769]	validation_0-logloss:0.55024	validation_1-logloss:0.59136
# [770]	validation_0-logloss:0.55018	validation_1-logloss:0.59134
# [771]	validation_0-logloss:0.55011	validation_1-logloss:0.59134
# [772]	validation_0-logloss:0.55007	validation_1-logloss:0.59133
# [773]	validation_0-logloss:0.55002	validation_1-logloss:0.59134
# [774]	validation_0-logloss:0.54999	validation_1-logloss:0.59134
# [775]	validation_0-logloss:0.54994	validation_1-logloss:0.59133
# [776]	validation_0-logloss:0.54988	validation_1-logloss:0.59133
# [777]	validation_0-logloss:0.54985	validation_1-logloss:0.59132
# [778]	validation_0-logloss:0.54980	validation_1-logloss:0.59132
# [779]	validation_0-logloss:0.54975	validation_1-logloss:0.59133
# [780]	validation_0-logloss:0.54971	validation_1-logloss:0.59132

# %%
# LOAD
classifier_spin = XGBClassifier()
classifier_spin.load_model(mainfolder + "saved-models/modelB_spin_S_poiss_beta01.json")


y_score = classifier_spin.predict_proba(X_test_spin)[:, 1]


fpr, tpr, thresholds = roc_curve(y_test_spin, y_score)
roc_auc = roc_auc_score(y_test_spin, y_score)

print("Global AUC =", roc_auc)


plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"AUC = {roc_auc:.3f}")
plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=14)
# plt.savefig(mainfolder + 'saved-results/ROC_classB.pdf', bbox_inches='tight')
plt.show()




keys = np.array([r'$p_T(b_1)$',r'$\eta(b_1)$',r'$\phi(b_1)$',
                 r'$p_T(b_2)$',r'$\eta(b_2)$',r'$\phi(b_2)$',
                 r'$p_T(\tau_h)$',r'$\eta(\tau_h)$',r'$\phi(\tau_h)$',
                 r'$p_T(jet_1)$',r'$\eta(jet_1)$',r'$\phi(jet_1)$',
                 r'$p_T(jet_2)$',r'$\eta(jet_2)$',r'$\phi(jet_2)$',
                 r'$E_T^{\mathrm{miss}}$',r'$\phi(E_T^{\mathrm{miss}})$',
                 r'$H_T$',r'$N_{\mathrm{jets}}$',r'$N_{b-\mathrm{jets}}$',
                 r'$\Delta R(\tau_h, b_1)$',r'$\Delta R(\tau_h, b_2)$',r'$\Delta R(b_1, b_2)$',
                 r'$\Delta R(j_1, b_1)$',r'$\Delta R(j_1, b_2)$',r'$\Delta R(j_1, \tau_h)$',
                 r'$\Delta R(j_2, b_1)$',r'$\Delta R(j_2, b_2)$',r'$\Delta R(j_2, \tau_h)$',
                 r'$\Delta R(j_1, j_2)$',
#                  r'$\Delta \phi(\tau_h, b_1)$',r'$\Delta \phi(\tau_h, b_2)$',r'$\Delta \phi(b_1, b_2)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, b_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, b_2)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$\Delta \phi(E_T^{\mathrm{miss}}, j_1)$',r'$\Delta \phi(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m(\tau_h, b_1)$',r'$m(\tau_h, b_2)$',r'$m(b_1, b_2)$',
                 r'$m(j_1, b_1)$',r'$m(j_1, b_2)$',r'$m(j_1, \tau_h)$',
                 r'$m(j_2, b_1)$',r'$m(j_2, b_2)$',r'$m(j_2, \tau_h)$',
                 r'$m(j_1, j_2)$',
                 r'$m_T(E_T^{\mathrm{miss}}, b_1)$',r'$m_T(E_T^{\mathrm{miss}}, b_2)$',r'$m_T(E_T^{\mathrm{miss}}, \tau_h)$',
                 r'$m_T(E_T^{\mathrm{miss}}, j_1)$',r'$m_T(E_T^{\mathrm{miss}}, j_2)$',
                 r'$m_T(b_1, b_2)$',r'$m_T(j_1, j_2)$',r'$s_T$',
                #  r'$m_{\mathrm{LQ}}^{\mathrm{reg}}$',
                 r'$S_{\mathrm{Poiss}}$'])

feature_important = classifier_spin.get_booster().get_score(importance_type='gain')
values = list(feature_important.values())


data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(15, columns="score").plot(kind='barh',figsize=(5.5,5)) ## plot top 15 features
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel("XGBoost Feature Importance (gain)", fontsize=14)
plt.legend( fontsize=12).remove()
plt.title(r'SLQ vs VLQ', fontsize=14)
# plt.savefig(mainfolder + 'saved-results/XG_feature_importance_classB.pdf', bbox_inches='tight')
plt.show()


# SELECT THE TOP INDICES
num_feats = 15

keys_list = list(keys)  # convert to list
top_names = data.nlargest(num_feats, columns="score").index.tolist()
feat_indices_LQSM = [keys_list.index(name) for name in top_names]

print(feat_indices_LQSM)
# Out:
# Global AUC = 0.7439329963200001
# [52, 19, 22, 53, 9, 35, 15, 18, 36, 38, 45, 37, 46, 48, 50]

# %%
S_column = X_test_spin[:, -1]

# mSLQ_plot = [1200, 1500, 1800]
# mVLQ_plot = [1600, 1900, 2200]

linestyles = ['-','-','-', '--','--','--', ':', ':', ':']
# colors_SLQ = ['lightcoral', 'red', 'firebrick']
# colors_VLQ = ['limegreen', 'green', 'darkgreen']

plt.figure(figsize=(6,5))

# evaluate per sector
for iit, S_id in enumerate(S_expected_SLQ):
    # if iit == 0 or iit == 1 or iit == 9:
    #     continue
    # else:
    if iit == 2 or iit == 5 or iit == 8:

        mask = (S_column < S_id * 1.1) & (0.9 * S_id < S_column)

        y_true_Spoiss = y_test_spin[mask]
        y_score_Spoiss = y_score[mask]

        fpr, tpr, _ = roc_curve(y_true_Spoiss, y_score_Spoiss)
        auc_sector = roc_auc_score(y_true_Spoiss, y_score_Spoiss)

        print(f"$m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV,   AUC = {auc_sector:.5f}")


        plt.plot(fpr, tpr, color='darkorange', linestyle=linestyles[iit], lw=2, label=f"AUC = {auc_sector:.3f}, $m_{{LQ_3^S}}=${masses_SLQ[iit]} GeV - $m_{{LQ_3^V}}=${masses_VLQ[iit]} GeV")



plt.plot([0, 1], [0, 1], color='navy', lw=1, linestyle='--')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve: SLQ vs VLQ", fontsize=14)
plt.grid(True)
plt.legend(fontsize=11.3)
# plt.savefig(mainfolder + 'saved-results/ROC_classB_multi.pdf', bbox_inches='tight')
plt.show()
# Out:
# $m_{LQ_3^S}=$1200 GeV,   AUC = 0.77350
# $m_{LQ_3^S}=$1500 GeV,   AUC = 0.72563
# $m_{LQ_3^S}=$1800 GeV,   AUC = 0.69030

# %% [markdown]
# # JOIN BOTH ML

# %%
# --- Clasificador A: SM vs LQ ---

scoresA_SM = xgb_clf.predict_proba( df_SM_norm )[:,1]

scoresA_SLQ = {}
scoresA_VLQ = {}

m_SLQ = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
m_VLQ = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]

S_exp_SLQ = S_expected_SLQ[2:]
S_exp_both = S_mean_fit_both[2:]

for m in m_SLQ:
    scoresA_SLQ[m] = xgb_clf.predict_proba( df_SLQ_norm[m] )[:,1]

for m in m_VLQ:
    scoresA_VLQ[m] = xgb_clf.predict_proba( df_VLQ_norm[m] )[:,1]

# %%
# --- Clasificador B: SLQ vs VLQ ---

X_sm = df_SM_norm

rand_samples_B =np.random.randint(1, S_exp_both[0] + S_std_fit_both[0], size=len(X_sm))

X_sm = np.column_stack([X_sm, rand_samples_B])

scoresB_SM = classifier_spin.predict_proba(X_sm)[:,1]


scoresB_SLQ = {}
scoresB_VLQ = {}

for iit, S_id in enumerate(m_SLQ):

    X_s = df_SLQ_norm[m_SLQ[iit]].values
    X_v = df_VLQ_norm[m_VLQ[iit]].values

    poisson_samples_SLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_s))
    poisson_samples_VLQ = np.random.poisson(lam=S_exp_both[iit], size=len(X_v))

    X_s = np.column_stack([X_s, poisson_samples_SLQ])
    X_v = np.column_stack([X_v, poisson_samples_VLQ])

    scoresB_SLQ[m_SLQ[iit]] = classifier_spin.predict_proba(X_s)[:,1]
    scoresB_VLQ[m_VLQ[iit]] = classifier_spin.predict_proba(X_v)[:,1]

# %%
# --- Juntar los scores del clasificador A y B

events_SM = np.column_stack([scoresA_SM, scoresB_SM])

events_SLQ = {}
for m in scoresA_SLQ:
    events_SLQ[m] = np.column_stack([scoresA_SLQ[m], scoresB_SLQ[m]])

events_VLQ = {}
for m in scoresA_VLQ:
    events_VLQ[m] = np.column_stack([scoresA_VLQ[m], scoresB_VLQ[m]])

# %% [markdown]
# #### Define the test statistic

# %%
def compute_test_statistic(scoresA, scoresB, threshold):
    """
    Sum of Log-Likelihood Ratios (LLR)

    T = Sum log (P(VLQ) / P(SLQ))

    P(VLQ) = score SLQ vs VLQ classifier
    P(SLQ) = 1 - score SLQ vs VLQ classifier
    """

    mask = scoresA > threshold

    scoresB_sel = scoresB[mask]

    if len(scoresB_sel) == 0:
        return 0

    eps = 1e-6
    s = np.clip(scoresB_sel, eps, 1-eps)

    T = np.sum(np.log(s/(1-s)))

    return T

# %% [markdown]
# ### For all the masses

# %%
# funcion para generar pseudo experimentos (da los scores de ambos clasificadores para ese pseudo)

def generate_pseudo(events_B, events_S, N_B, N_S):

    sample_B = events_B[np.random.randint(len(events_B), size=N_B)]
    sample_S = events_S[np.random.randint(len(events_S), size=N_S)]

    sample_all = np.vstack([sample_B, sample_S])

    scoresA = sample_all[:,0]
    scoresB = sample_all[:,1]

    return scoresA, scoresB

# %%
B_expected = 45962

S_exp_SLQ = [round(fid_xsec_SLQ_14TeV(mmm, beta) * Lum) for mmm in m_SLQ]
S_exp_VLQ = [round(fid_xsec_VLQ_14TeV(mmm, beta) * Lum) for mmm in m_VLQ]

print('beta = ', beta)
print('\nB_expected: ', B_expected)
print('\nS_exp_SLQ: ', S_exp_SLQ, '   m =', m_SLQ)
print('S_exp_VLQ: ', S_exp_VLQ, '   m =', m_VLQ)
print('S_exp_both: ', S_exp_both)
# Out:
# beta =  0.1
#
# B_expected:  45962
#
# S_exp_SLQ:  [448, 253, 143, 83, 48, 28, 16, 10]    m = [1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900]
# S_exp_VLQ:  [480, 281, 165, 99, 59, 36, 22, 13]    m = [1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300]
# S_exp_both:  [np.float64(431.6752971740499), np.float64(249.42722638034115), np.float64(145.04827108716407), np.float64(85.58474185446235), np.float64(50.20361875190639), np.float64(29.840362704678633), np.float64(17.629667907244112), np.float64(11.98378791430467)]

# %% [markdown]
# #### Distribution of the statistic with only SLQ and only VLQ

# %%
n_pseudo_TRUE = 1000
threshold_A = 0.95

# %%
mu_S = []
mu_V = []

sigma_S = []
sigma_V = []

for S_it in range(len(S_exp_SLQ)):

    print("\n==========================")
    print("S_expected SLQ =", S_exp_SLQ[S_it])
    # print("S_expected VLQ =", S_exp_VLQ[S_it]) # same number of events

    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[S_it]
    mass_VLQ = m_VLQ[S_it]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    for i in range(n_pseudo_TRUE):

        N_B = np.random.poisson(B_expected)
        N_S = np.random.poisson(S_exp_SLQ[S_it])

        scoresA, scoresB = generate_pseudo( events_SM, events_SLQ[mass_SLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)


        N_S = np.random.poisson(S_exp_SLQ[S_it]) # same number of events

        scoresA, scoresB = generate_pseudo( events_SM, events_VLQ[mass_VLQ], N_B, N_S )

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

        # Compute the Z of the distributions
    mu_S.append( np.mean(T_SLQ) )
    mu_V.append( np.mean(T_VLQ) )

    sigma_S.append( np.std(T_SLQ) )
    sigma_V.append( np.std(T_VLQ) )

print(mu_S)
print(mu_V)

print(sigma_S)
print(sigma_V)
# Out:
# ==========================
# S_expected SLQ = 448
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
#
# ==========================
# S_expected SLQ = 253
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
#
# ==========================
# S_expected SLQ = 143
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
#
# ==========================
# S_expected SLQ = 83
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
#
# ==========================
# S_expected SLQ = 48
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
#
# ==========================
# S_expected SLQ = 28
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
#
# ==========================
# S_expected SLQ = 16
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
#
# ==========================
# S_expected SLQ = 10
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# [np.float32(-191.44096), np.float32(-114.69556), np.float32(-73.4151), np.float32(-50.044407), np.float32(-38.13432), np.float32(-31.45062), np.float32(-27.46496), np.float32(-24.547796)]
# [np.float32(271.819), np.float32(123.23437), np.float32(48.426296), np.float32(13.960742), np.float32(-3.857238), np.float32(-12.787477), np.float32(-17.350945), np.float32(-18.59862)]
# [np.float32(20.744791), np.float32(16.696728), np.float32(13.204357), np.float32(12.137206), np.float32(10.846319), np.float32(10.615726), np.float32(10.665236), np.float32(10.155594)]
# [np.float32(30.31602), np.float32(21.103111), np.float32(17.061464), np.float32(14.37703), np.float32(11.424283), np.float32(10.914588), np.float32(10.924142), np.float32(10.524412)]

# %%
f_mu_S = interp1d(S_exp_SLQ, mu_S, kind='linear', fill_value="extrapolate")
f_mu_V = interp1d(S_exp_SLQ, mu_V, kind='linear', fill_value="extrapolate")

f_sigma_S = interp1d(S_exp_SLQ, sigma_S, kind='linear', fill_value="extrapolate")
f_sigma_V = interp1d(S_exp_SLQ, sigma_V, kind='linear', fill_value="extrapolate")



S_plot = np.linspace(min(S_exp_SLQ), max(S_exp_SLQ), 100)



plt.scatter(S_exp_SLQ, mu_S, marker='o')
plt.plot(S_plot, f_mu_S(S_plot))
plt.scatter(S_exp_SLQ, mu_V, marker='o')
plt.plot(S_plot, f_mu_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\mu$", fontsize=14)

plt.grid()
plt.show()


plt.scatter(S_exp_SLQ, sigma_S, marker='o')
plt.plot(S_plot, f_sigma_S(S_plot))
plt.scatter(S_exp_SLQ, sigma_V, marker='o')
plt.plot(S_plot, f_sigma_V(S_plot))

plt.xlabel("S", fontsize=14)
plt.ylabel(r"$\sigma$", fontsize=14)

plt.grid()
plt.show()

# %%
Z_threshold = 5

results_Z_gauss = []

for pair_it in range(len(mu_S)):
    Z = abs(mu_V[pair_it] - mu_S[pair_it]) / np.sqrt(sigma_S[pair_it]**2 + sigma_V[pair_it]**2)

    results_Z_gauss.append(Z)


plt.plot(S_exp_SLQ, results_Z_gauss, marker='o')

plt.xlabel("Expected signal events", fontsize=14)
plt.ylabel("Distribution discrimination Z", fontsize=14)

plt.grid()
plt.show()


#  interpolate
f_results_Z = interp1d(S_exp_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mSLQ = interp1d(m_SLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")
f_results_Z_mVLQ = interp1d(m_VLQ, results_Z_gauss, kind='linear', fill_value="extrapolate")


# find the S or the mass such that we get Z_threshold
S_threshold = fsolve(lambda x: f_results_Z(x) - Z_threshold,150)[0]
mSLQ_threshold = fsolve(lambda x: f_results_Z_mSLQ(x) - Z_threshold,1500)[0]
mVLQ_threshold = fsolve(lambda x: f_results_Z_mVLQ(x) - Z_threshold,1900)[0]

print(' Z:       ', Z_threshold)
print(' S:       ', S_threshold)
print(' m_SLQ:   ', mSLQ_threshold, ' [GeV]')
print(' m_VLQ:   ', mVLQ_threshold, ' [GeV]\n')
# Out:
#  Z:        5
#  S:        125.69971828258542
#  m_SLQ:    1428.8338028623577  [GeV]
#  m_VLQ:    1828.8338028623577  [GeV]
# /tmp/ipykernel_601/699503059.py:28: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   mSLQ_threshold = fsolve(lambda x: f_results_Z_mSLQ(x) - Z_threshold,1500)[0]
# /tmp/ipykernel_601/699503059.py:29: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   mVLQ_threshold = fsolve(lambda x: f_results_Z_mVLQ(x) - Z_threshold,1900)[0]

# %% [markdown]
# #### Prepare the data

# %% [markdown]
# ##### To compute S_expected for each pseudo using the 1st classifier we need the PDFs

# %%
# --- Clasificador A: SM vs LQ ---

# output of all the signal events
scoresA_S = xgb_clf.predict_proba( df_LQ_norm )[:, 1]



bins = np.linspace(0, 1, 30)

# normalized histograms of pure signal and pure background
hist_B, _ = np.histogram(scoresA_SM, bins=bins, density=True)
hist_S, _ = np.histogram(scoresA_S, bins=bins, density=True)


bin_width = bins[1] - bins[0]

pS = hist_S * bin_width
pB = hist_B * bin_width

# %% [markdown]
# ##### to compute the closest mass/index/bechmark

# %%
def search_bench(S_pseudo, S_list_means, S_list_std, masses_list=None):
    """ finds the index of the closest benchmark

    Inputs:
    -----------
    S_pseudo : float -> S computed or fitted (e.g. muS_fits_SLQ[i]).
    S_list_means : list/array -> S_mean_fit_both_NEW.
    S_list_std : list/array -> S_std_fit_both_NEW.
    masses_list : list/array (optional) -> masses_NEW.

    Outputs:
    --------
    if masses_list es None -> returns only the index
    if masses_list se incluye -> returns (index, closest mass).
    """
    # convert to array
    means = np.array(S_list_means)
    stds = np.array(S_list_std)

    # do not divide by 0
    stds = np.where(stds == 0, 1e-10, stds)

    # compute the distance to the means, weighted by the std
    z_scores = np.abs(S_pseudo - means) / stds

    # seach the closest index
    idx_min = np.argmin(z_scores)

    # if you also want the mass
    if masses_list is not None:
        best_mass = masses_list[idx_min]
        return idx_min, best_mass

    return idx_min

# %% [markdown]
# ### Super loop

# %%
Z_threshold = 1.96

n_pseudo = 1000

# benchmarks
classification_SLQ_BPOK = []
classification_VLQ_BPOK = []

# interpolate
classification_SLQ_inter = []
classification_VLQ_inter = []

# previously known PDFs
classification_SLQ_prev = []
classification_VLQ_prev = []


Z_SLQ_BPOK = []
Z_VLQ_BPOK = []

Z_SLQ_inter = []
Z_VLQ_inter = []

Z_SLQ_prev = []
Z_VLQ_prev = []


mu_TSLQ = []
std_TSLQ = []
mu_TVLQ = []
std_TVLQ = []



for ii_S, S_exp in enumerate(S_exp_SLQ):

    print("\n==========================")

    print("S_expected_SLQ =", S_exp_SLQ[ii_S])
    # print("S_expected_VLQ =", S_exp_VLQ[ii_S]) # same number of events


    # dado un S, le asigna la masa (del SLQ o VLQ) correspondiente
    mass_SLQ = m_SLQ[ii_S]
    mass_VLQ = m_VLQ[ii_S]
    print("mass_SLQ =", mass_SLQ, " GeV")
    print("mass_VLQ =", mass_VLQ, " GeV")


    # computamos el T statistic para todos los pseudo
    T_SLQ = []
    T_VLQ = []

    # compute the number of events
    muS_fits_SLQ = []
    muS_fits_VLQ = []


    for i in range(n_pseudo):

        N_B = np.random.poisson(B_expected)

        # indices of the events
        idx_B = np.random.choice(len(events_SM[:,0]), N_B)

        scoresA_B = events_SM[:,0][idx_B]
        scoresB_B = events_SM[:,1][idx_B]



        ###########
        # FOR SLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S])

        # indices of the events
        idx_S = np.random.choice(len(events_SLQ[mass_SLQ][:,0]), N_S)

        scoresA_S = events_SLQ[mass_SLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_SLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_S = df_SLQ_norm[mass_SLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_S = np.column_stack([X_pseudo_S, np.full(len(X_pseudo_S), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_S)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_SLQ.append(T)




        ###########
        # FOR VLQ #
        ###########

        N_S = np.random.poisson(S_exp_SLQ[ii_S]) # same number of events

        # indices of the events
        idx_S = np.random.choice(len(events_VLQ[mass_VLQ][:,0]), N_S)

        scoresA_S = events_VLQ[mass_VLQ][:,0][idx_S]


        data_scores = np.concatenate([scoresA_B, scoresA_S])

        hist_data, _ = np.histogram(data_scores, bins=bins)

        # 2) Define likelihood for this pseudo (gotta do it for the minimizer)
        def neg_logL(params):
            mu_S, mu_B = params

            lambda_i = mu_S * pS + mu_B * pB
            lambda_i = np.clip(lambda_i, 1e-10, None)

            return -np.sum(hist_data * np.log(lambda_i) - lambda_i)

        # 3) Minimizar
        result = minimize(
            neg_logL,
            x0=[S_exp, B_expected],
            bounds=[(0, None), (0, None)]
        )

        muS_fit, muB_fit = result.x

        muS_fits_VLQ.append(muS_fit)


        # the pseudo exp
        X_pseudo_V = df_VLQ_norm[mass_VLQ].loc[idx_S].values
        # add the S fitted
        X_pseudo_V = np.column_stack([X_pseudo_V, np.full(len(X_pseudo_V), muS_fit)])

        scoresB_S = classifier_spin.predict_proba(X_pseudo_V)[:,1]


        scoresA = np.concatenate([scoresA_B, scoresA_S])
        scoresB = np.concatenate([scoresB_B, scoresB_S])

        T = compute_test_statistic(scoresA, scoresB, threshold_A)

        T_VLQ.append(T)

    # Compute the characteristics of the psedo-experiment T distributions
    mu_TSLQ.append( np.mean(T_SLQ) )
    mu_TVLQ.append( np.mean(T_VLQ) )

    std_TSLQ.append( np.std(T_SLQ) )
    std_TVLQ.append( np.std(T_VLQ) )




    # rango común para plotear
    xmin = min(np.min(T_SLQ), np.min(T_VLQ))
    xmax = max(np.max(T_SLQ), np.max(T_VLQ))
    x = np.linspace(xmin, xmax, 500)

    # gaussianas
    gauss_S = (1/(sigma_S[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_S[ii_S])**2 / (2*sigma_S[ii_S]**2))
    gauss_V = (1/(sigma_V[ii_S]*np.sqrt(2*np.pi))) * np.exp(-(x - mu_V[ii_S])**2 / (2*sigma_V[ii_S]**2))


    # plot gaussian PDFs + pseudo-experiments (of the same sector) distributions
    plt.figure(figsize=(6,5))

    plt.hist(T_SLQ, bins=20, density=True, color='red', alpha=0.6, label="SLQ pseudos")
    plt.hist(T_VLQ, bins=20, density=True, color='green', alpha=0.6, label="VLQ pseudos")

    # gaussianas
    plt.plot(x, gauss_S, color='darkred', linewidth=2, linestyle='--', label=f"Gaussian SLQ true\nμ={mu_S[ii_S]:.2f}, σ={sigma_S[ii_S]:.2f}")
    plt.plot(x, gauss_V, color='darkgreen', linewidth=2, linestyle='--', label=f"Gaussian VLQ true\nμ={mu_V[ii_S]:.2f}, σ={sigma_V[ii_S]:.2f}")

    plt.xlabel("Test statistic T")
    plt.ylabel("Probability density")
    plt.title(f"S_expected = {S_exp}")
    plt.legend()

    plt.show()


    plt.hist(muS_fits_SLQ, bins=10, histtype='step', linestyle='--', edgecolor='red', linewidth=2, density=True)
    plt.hist(muS_fits_SLQ, bins=10, color='red', alpha=0.6, density=True)
    plt.hist(muS_fits_VLQ, bins=10, histtype='step', linestyle=':', edgecolor='green', linewidth=2, density=True)
    plt.hist(muS_fits_VLQ, bins=10, color='green', alpha=0.6, density=True)
    plt.xlabel("S")
    plt.ylabel("Fraction (prediction)")
    plt.show()

    print('S mean SLQ: ', np.mean(muS_fits_SLQ))
    print('S std SLQ: ', np.std(muS_fits_SLQ))
    print('S mean VLQ: ', np.mean(muS_fits_VLQ))
    print('S std VLQ: ', np.std(muS_fits_VLQ))
    print('')


    # COMPARING WITH DISCRETE MASS EXAMPLES (following S)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_BPOK_step = []
    Z_VLQ_BPOK_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        index_pseudo = search_bench(muS_fits_SLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_SLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        index_pseudo = search_bench(muS_fits_VLQ[i], S_mean_fit_both, S_std_fit_both )

        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(S_mean_fit_both[index_pseudo])) / f_sigma_S(S_mean_fit_both[index_pseudo])
        Z_VLQ_val = abs(T_obs - f_mu_V(S_mean_fit_both[index_pseudo])) / f_sigma_V(S_mean_fit_both[index_pseudo])

        Z_VLQ_BPOK_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_BPOK.append(np.array(Z_SLQ_BPOK_step))
    Z_VLQ_BPOK.append(np.array(Z_VLQ_BPOK_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH DISCRETE MASS EXAMPLES (following S) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_BPOK.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_BPOK.append(pred_counts_VLQ)





    # COMPARING WITH CONTINUOUS MASSES (interpolation)

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_inter_step = []
    Z_VLQ_inter_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_SLQ[i])) / f_sigma_S(muS_fits_SLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_SLQ[i])) / f_sigma_V(muS_fits_SLQ[i])

        Z_SLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - f_mu_S(muS_fits_VLQ[i])) / f_sigma_S(muS_fits_VLQ[i])
        Z_VLQ_val = abs(T_obs - f_mu_V(muS_fits_VLQ[i])) / f_sigma_V(muS_fits_VLQ[i])

        Z_VLQ_inter_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_inter.append(np.array(Z_SLQ_inter_step))
    Z_VLQ_inter.append(np.array(Z_VLQ_inter_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH CONTINUOUS MASSES (interpolation) ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_inter.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_inter.append(pred_counts_VLQ)





    # COMPARING WITH THE PREVIOUSLY KNOWN PDF

    # Vamos a clasificar cada pseudo
    # 0: SLQ
    # 1: VLQ
    # 2: compatible con ambos
    # 3: incompatible con ambos
    pred_counts_SLQ = [0,0,0,0]
    pred_counts_VLQ = [0,0,0,0]

    Z_SLQ_prev_step = []
    Z_VLQ_prev_step = []

    for i in range(n_pseudo):

        # TRUE: SLQ
        T_obs = T_SLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_SLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_SLQ[pred] += 1


        # TRUE: VLQ
        T_obs = T_VLQ[i]

        Z_SLQ_val = abs(T_obs - mu_S[ii_S]) / sigma_S[ii_S]
        Z_VLQ_val = abs(T_obs - mu_V[ii_S]) / sigma_V[ii_S]

        Z_VLQ_prev_step.append([Z_SLQ_val, Z_VLQ_val])

        SLQ_ok = Z_SLQ_val < Z_threshold
        VLQ_ok = Z_VLQ_val < Z_threshold


        if SLQ_ok and not VLQ_ok:
            pred = 0
        elif VLQ_ok and not SLQ_ok:
            pred = 1
        elif SLQ_ok and VLQ_ok:
            pred = 2
        else:
            pred = 3

        pred_counts_VLQ[pred] += 1


    Z_SLQ_prev.append(np.array(Z_SLQ_prev_step))
    Z_VLQ_prev.append(np.array(Z_VLQ_prev_step))


    # SLQ
    pred_counts_SLQ = np.array(pred_counts_SLQ) / n_pseudo

    print("\n------")
    print(" COMPARING WITH THE PREVIOUSLY KNOWN PDF ")

    print("TESTING SLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_SLQ[0])
    print("1 = VLQ only :", pred_counts_SLQ[1])
    print("2 = both     :", pred_counts_SLQ[2])
    print("3 = neither  :", pred_counts_SLQ[3])

    classification_SLQ_prev.append(pred_counts_SLQ)


    print('')

    # VLQ
    pred_counts_VLQ = np.array(pred_counts_VLQ) / n_pseudo

    print("TESTING VLQ")
    print("Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)")
    print("0 = SLQ only :", pred_counts_VLQ[0])
    print("1 = VLQ only :", pred_counts_VLQ[1])
    print("2 = both     :", pred_counts_VLQ[2])
    print("3 = neither  :", pred_counts_VLQ[3])

    classification_VLQ_prev.append(pred_counts_VLQ)
# Out:
# ==========================
# S_expected_SLQ = 448
# mass_SLQ = 1200  GeV
# mass_VLQ = 1600  GeV
# S mean SLQ:  414.0416366152217
# S std SLQ:  26.810523703082076
# S mean VLQ:  447.6027733744942
# S std VLQ:  23.026747167289642
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.935
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.065
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.729
# 2 = both     : 0.0
# 3 = neither  : 0.271
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.843
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.157
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.851
# 2 = both     : 0.0
# 3 = neither  : 0.149
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.961
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.039
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.778
# 2 = both     : 0.0
# 3 = neither  : 0.222
#
# ==========================
# S_expected_SLQ = 253
# mass_SLQ = 1300  GeV
# mass_VLQ = 1700  GeV
# S mean SLQ:  245.90425093538607
# S std SLQ:  20.61873447894272
# S mean VLQ:  256.3076268627438
# S std VLQ:  19.54435624440289
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.952
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.048
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.824
# 2 = both     : 0.0
# 3 = neither  : 0.176
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.907
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.093
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.934
# 2 = both     : 0.0
# 3 = neither  : 0.066
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.956
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.044
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.831
# 2 = both     : 0.0
# 3 = neither  : 0.169
#
# ==========================
# S_expected_SLQ = 143
# mass_SLQ = 1400  GeV
# mass_VLQ = 1800  GeV
# S mean SLQ:  143.94465961538648
# S std SLQ:  17.134877630856717
# S mean VLQ:  146.63496908004012
# S std VLQ:  16.52317063967314
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.924
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.076
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.909
# 2 = both     : 0.0
# 3 = neither  : 0.091
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.931
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.069
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.944
# 2 = both     : 0.0
# 3 = neither  : 0.056
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.94
# 1 = VLQ only : 0.0
# 2 = both     : 0.0
# 3 = neither  : 0.06
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.908
# 2 = both     : 0.0
# 3 = neither  : 0.092
#
# ==========================
# S_expected_SLQ = 83
# mass_SLQ = 1500  GeV
# mass_VLQ = 1900  GeV
# S mean SLQ:  85.79025660308376
# S std SLQ:  15.422945181239255
# S mean VLQ:  85.68319779754117
# S std VLQ:  15.099085978888064
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.94
# 1 = VLQ only : 0.002
# 2 = both     : 0.0
# 3 = neither  : 0.058
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.944
# 2 = both     : 0.004
# 3 = neither  : 0.052
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.947
# 1 = VLQ only : 0.002
# 2 = both     : 0.0
# 3 = neither  : 0.051
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.964
# 2 = both     : 0.002
# 3 = neither  : 0.034
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.964
# 1 = VLQ only : 0.002
# 2 = both     : 0.0
# 3 = neither  : 0.034
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.0
# 1 = VLQ only : 0.939
# 2 = both     : 0.0
# 3 = neither  : 0.061
#
# ==========================
# S_expected_SLQ = 48
# mass_SLQ = 1600  GeV
# mass_VLQ = 2000  GeV
# S mean SLQ:  51.08198267807707
# S std SLQ:  14.125433312528362
# S mean VLQ:  50.72998534580827
# S std VLQ:  14.164900823422254
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.762
# 1 = VLQ only : 0.024
# 2 = both     : 0.166
# 3 = neither  : 0.048
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.037
# 1 = VLQ only : 0.754
# 2 = both     : 0.161
# 3 = neither  : 0.048
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.793
# 1 = VLQ only : 0.034
# 2 = both     : 0.141
# 3 = neither  : 0.032
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.035
# 1 = VLQ only : 0.784
# 2 = both     : 0.152
# 3 = neither  : 0.029
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.795
# 1 = VLQ only : 0.03
# 2 = both     : 0.15
# 3 = neither  : 0.025
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.04
# 1 = VLQ only : 0.789
# 2 = both     : 0.123
# 3 = neither  : 0.048
#
# ==========================
# S_expected_SLQ = 28
# mass_SLQ = 1700  GeV
# mass_VLQ = 2100  GeV
# S mean SLQ:  30.204716421379107
# S std SLQ:  12.763171036555875
# S mean VLQ:  29.56279737337615
# S std VLQ:  12.892044591338847
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.419
# 1 = VLQ only : 0.037
# 2 = both     : 0.522
# 3 = neither  : 0.022
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.042
# 1 = VLQ only : 0.374
# 2 = both     : 0.558
# 3 = neither  : 0.026
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.418
# 1 = VLQ only : 0.033
# 2 = both     : 0.526
# 3 = neither  : 0.023
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.044
# 1 = VLQ only : 0.367
# 2 = both     : 0.564
# 3 = neither  : 0.025
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.374
# 1 = VLQ only : 0.02
# 2 = both     : 0.587
# 3 = neither  : 0.019
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.029
# 1 = VLQ only : 0.351
# 2 = both     : 0.59
# 3 = neither  : 0.03
#
# ==========================
# S_expected_SLQ = 16
# mass_SLQ = 1800  GeV
# mass_VLQ = 2200  GeV
# S mean SLQ:  18.100903138698026
# S std SLQ:  11.946285214854475
# S mean VLQ:  17.098580112586266
# S std VLQ:  11.494906920492147
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.148
# 1 = VLQ only : 0.033
# 2 = both     : 0.806
# 3 = neither  : 0.013
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.034
# 1 = VLQ only : 0.17
# 2 = both     : 0.783
# 3 = neither  : 0.013
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.143
# 1 = VLQ only : 0.04
# 2 = both     : 0.797
# 3 = neither  : 0.02
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.033
# 1 = VLQ only : 0.149
# 2 = both     : 0.799
# 3 = neither  : 0.019
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.084
# 1 = VLQ only : 0.019
# 2 = both     : 0.879
# 3 = neither  : 0.018
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.017
# 1 = VLQ only : 0.124
# 2 = both     : 0.843
# 3 = neither  : 0.016
#
# ==========================
# S_expected_SLQ = 10
# mass_SLQ = 1900  GeV
# mass_VLQ = 2300  GeV
# S mean SLQ:  11.966225146528078
# S std SLQ:  10.633938483749386
# S mean VLQ:  11.728316735371035
# S std VLQ:  10.423056989255432
#
#
# ------
#  COMPARING WITH DISCRETE MASS EXAMPLES (following S)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.081
# 1 = VLQ only : 0.04
# 2 = both     : 0.862
# 3 = neither  : 0.017
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.04
# 1 = VLQ only : 0.113
# 2 = both     : 0.833
# 3 = neither  : 0.014
#
# ------
#  COMPARING WITH CONTINUOUS MASSES (interpolation)
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.066
# 1 = VLQ only : 0.031
# 2 = both     : 0.873
# 3 = neither  : 0.03
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.03
# 1 = VLQ only : 0.074
# 2 = both     : 0.857
# 3 = neither  : 0.039
#
# ------
#  COMPARING WITH THE PREVIOUSLY KNOWN PDF
# TESTING SLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.045
# 1 = VLQ only : 0.025
# 2 = both     : 0.903
# 3 = neither  : 0.027
#
# TESTING VLQ
# Classification fractions: (p-value threshold: 0.05 <--> Z=1.96, two-tailed)
# 0 = SLQ only : 0.025
# 1 = VLQ only : 0.064
# 2 = both     : 0.887
# 3 = neither  : 0.024

# %%
def Z_processor(lista_Z, select):
    """computes the median and error (percentiles 16 y 84)
    select = 1 ---> SLQ (true) vs VLQ
    select = 0 ---> VLQ (true) vs SLQ
    """
    medians = []
    err_inf = []
    err_sup = []

    for z_matriz in lista_Z:
        z_valores = z_matriz[:, select]
        med = np.median(z_valores)
        p16 = np.percentile(z_valores, 16)
        p84 = np.percentile(z_valores, 84)

        medians.append(med)
        err_inf.append(med - p16)  # percentile
        err_sup.append(p84 - med)  # percentile

    return np.array(medians), [np.array(err_inf), np.array(err_sup)]

# Compute
z_BPOK_SLQ, err_BPOK_SLQ = Z_processor(Z_SLQ_BPOK, select=1)
z_BPOK_VLQ, err_BPOK_VLQ = Z_processor(Z_VLQ_BPOK, select=0)
z_inter_SLQ, err_inter_SLQ = Z_processor(Z_SLQ_inter, select=1)
z_inter_VLQ, err_inter_VLQ = Z_processor(Z_VLQ_inter, select=0)
z_prev_SLQ, err_prev_SLQ = Z_processor(Z_SLQ_prev, select=1)
z_prev_VLQ, err_prev_VLQ = Z_processor(Z_VLQ_prev, select=0)



# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(m_SLQ), z_BPOK_SLQ, err_BPOK_SLQ)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(m_VLQ), z_BPOK_VLQ, err_BPOK_VLQ)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(m_SLQ), z_inter_SLQ, err_inter_SLQ)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(m_VLQ), z_inter_VLQ, err_inter_VLQ)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(m_SLQ), z_prev_SLQ, err_prev_SLQ)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(m_VLQ), z_prev_VLQ, err_prev_VLQ)


# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')


# PLOT
plt.figure(figsize=(7, 6))

plt.errorbar(m_SLQ, z_BPOK_SLQ, yerr=err_BPOK_SLQ, color='red', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Benchmarks)')
plt.errorbar(m_VLQ, z_BPOK_VLQ, yerr=err_BPOK_VLQ, color='green', linestyle='-', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Benchmarks)')
plt.errorbar(m_SLQ, z_inter_SLQ, yerr=err_inter_SLQ, color='darkred', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Interpolated)')
plt.errorbar(m_VLQ, z_inter_VLQ, yerr=err_inter_VLQ, color='darkgreen', linestyle='--', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Interpolated)')
plt.errorbar(m_SLQ, z_prev_SLQ, yerr=err_prev_SLQ, color='pink', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='SLQ (Known PDF)')
plt.errorbar(m_VLQ, z_prev_VLQ, yerr=err_prev_VLQ, color='lime', linestyle=':', marker='o', capsize=4, elinewidth=1.2, alpha=0.8, label='VLQ (Known PDF)')

plt.axhline(y=5.0, color='blue', linestyle='-', linewidth=1.5, label='5σ')

# plt.ylim(0, 25)
plt.xlabel(r"$m_{LQ}$ [GeV]", fontsize=12)
plt.ylabel(r"$Z$", fontsize=12)
plt.grid(True)
plt.legend(fontsize=12, loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1482.3823823823823 [GeV]      ( 1451.5515515515515 - 1523.7237237237237 )
# VLQ mass:  1913.2132132132133 [GeV]      ( 1873.973973973974 - 1973.4734734734734 )
#
# Interpolated
# SLQ mass:  1484.4844844844845 [GeV]      ( 1451.5515515515515 - 1528.6286286286286 )
# VLQ mass:  1916.016016016016 [GeV]      ( 1873.2732732732734 - 1975.5755755755756 )
#
# Known PDF
# SLQ mass:  1480.2802802802803 [GeV]      ( 1450.8508508508507 - 1516.7167167167167 )
# VLQ mass:  1911.8118118118118 [GeV]      ( 1874.6746746746746 - 1967.1671671671672 )

# %%
class_SLQ_BPOK_array = np.array(classification_SLQ_BPOK) # Forma (N, 4)
class_VLQ_BPOK_array = np.array(classification_VLQ_BPOK) # Forma (N, 4)

class_SLQ_inter_array = np.array(classification_SLQ_inter) # Forma (N, 4)
class_VLQ_inter_array = np.array(classification_VLQ_inter) # Forma (N, 4)

class_SLQ_prev_array = np.array(classification_SLQ_prev) # Forma (N, 4)
class_VLQ_prev_array = np.array(classification_VLQ_prev) # Forma (N, 4)

# SAVE

file_path = mainfolder + 'saved-results/vs14TeV_err_beta01.txt'

# Combine all data into a single array
data_to_save = np.column_stack([
    S_expected_SLQ[2:],
    m_SLQ,
    m_VLQ,
    mu_S,
    sigma_S,
    mu_V,
    sigma_V,
    mu_TSLQ,
    std_TSLQ,
    mu_TVLQ,
    std_TVLQ,
    class_SLQ_BPOK_array,
    class_VLQ_BPOK_array,
    class_SLQ_inter_array,
    class_VLQ_inter_array,
    class_SLQ_prev_array,
    class_VLQ_prev_array,
    z_BPOK_SLQ,
    err_BPOK_SLQ[0],
    err_BPOK_SLQ[1],
    z_BPOK_VLQ,
    err_BPOK_VLQ[0],
    err_BPOK_VLQ[1],
    z_inter_SLQ,
    err_inter_SLQ[0],
    err_inter_SLQ[1],
    z_inter_VLQ,
    err_inter_VLQ[0],
    err_inter_VLQ[1],
    z_prev_SLQ,
    err_prev_SLQ[0],
    err_prev_SLQ[1],
    z_prev_VLQ,
    err_prev_VLQ[0],
    err_prev_VLQ[1],
])

# Save data to a text file
np.savetxt(file_path, data_to_save, fmt='%.6f',
           header='# S_expected mass_list_SLQ mass_list_SLQ mu_S sigma_S mu_V sigma_V mu_TSLQ std_TSLQ mu_TVLQ std_TVLQ classification_SLQ classification_VLQ',
           comments='')

print(f"Data saved to: {file_path}")
# Out:
# Data saved to: /content/drive/MyDrive/Trabajos/leptoquarks/scalar-vs-vector/03-pythons2026-junio/saved-results/vs14TeV_err_beta01.txt

# %%
# LOAD

file_path = mainfolder + 'saved-results/vs14TeV_err_beta01.txt'

loaded_data = np.loadtxt(file_path)

S_expected = loaded_data[:, 0]
mass_list_SLQ = loaded_data[:, 1]
mass_list_VLQ = loaded_data[:, 2]
mu_S = loaded_data[:, 3]
sigma_S = loaded_data[:, 4]
mu_V = loaded_data[:, 5]
sigma_V = loaded_data[:, 6]
mu_TSLQ = loaded_data[:, 7]
std_TSLQ = loaded_data[:, 8]
mu_TVLQ = loaded_data[:, 9]
std_TVLQ = loaded_data[:, 10]
classification_SLQ_BPOK = loaded_data[:, 11:15]
classification_VLQ_BPOK = loaded_data[:, 15:19]
classification_SLQ_inter = loaded_data[:, 19:23]
classification_VLQ_inter = loaded_data[:, 23:27]
classification_SLQ_prev = loaded_data[:, 27:31]
classification_VLQ_prev = loaded_data[:, 31:35]
z_BPOK_SLQ = loaded_data[:, 35]
err_BPOK_SLQ = np.concatenate([loaded_data[:, 36], loaded_data[:, 37]])
z_BPOK_VLQ = loaded_data[:, 38]
err_BPOK_VLQ = np.concatenate([loaded_data[:, 39], loaded_data[:, 40]])
z_inter_SLQ = loaded_data[:, 41]
err_inter_SLQ = np.concatenate([loaded_data[:, 42], loaded_data[:, 43]])
z_inter_VLQ = loaded_data[:, 44]
err_inter_VLQ = np.concatenate([loaded_data[:, 45], loaded_data[:, 46]])
z_prev_SLQ = loaded_data[:, 47]
err_prev_SLQ = np.concatenate([loaded_data[:, 48], loaded_data[:, 49]])
z_prev_VLQ = loaded_data[:, 50]
err_prev_VLQ = np.concatenate([loaded_data[:, 51], loaded_data[:, 52]])





n_pseudo_TRUE = 1000
threshold_A = 0.95

print('n_pseudo_TRUE: ', n_pseudo_TRUE)
print('threshold_A: ', threshold_A)
# Out:
# n_pseudo_TRUE:  1000
# threshold_A:  0.95

# %%
# Interpolate to find Z=5
def find_mass(mass_array, z_med, err_list, z_target=5.0):
    """Interpolate the mass and find the error, 1-sigma"""
    if np.max(z_med) < z_target and np.min(z_med) < z_target:
        return None, None, None # Z is not in this range

    # mass grid
    grid_masas = np.linspace(mass_array.min(), mass_array.max(), 1000)

    # curves
    z_sup_valores = z_med + err_list[1] # Median + err_sup (percentil 84)
    z_inf_valores = z_med - err_list[0] # Median - err_inf (percentil 16)

    f_med = interp1d(mass_array, z_med, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_sup = interp1d(mass_array, z_sup_valores, kind='linear', bounds_error=False, fill_value="extrapolate")
    f_inf = interp1d(mass_array, z_inf_valores, kind='linear', bounds_error=False, fill_value="extrapolate")

    # search for Z = z_target
    m5_central = grid_masas[np.argmin(np.abs(f_med(grid_masas) - z_target))]
    m5_inf     = grid_masas[np.argmin(np.abs(f_inf(grid_masas) - z_target))]
    m5_sup     = grid_masas[np.argmin(np.abs(f_sup(grid_masas) - z_target))]

    return m5_central, m5_inf, m5_sup

# Compute
m5_BPOK_SLQ, m5_BPOK_SLQ_inf, m5_BPOK_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_BPOK_SLQ, err_BPOK_SLQ, z_target=5.0)
m5_BPOK_VLQ, m5_BPOK_VLQ_inf, m5_BPOK_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_BPOK_VLQ, err_BPOK_VLQ, z_target=5.0)
m5_inter_SLQ, m5_inter_SLQ_inf, m5_inter_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_inter_SLQ, err_inter_SLQ, z_target=5.0)
m5_inter_VLQ, m5_inter_VLQ_inf, m5_inter_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_inter_VLQ, err_inter_VLQ, z_target=5.0)
m5_prev_SLQ, m5_prev_SLQ_inf, m5_prev_SLQ_sup = find_mass(np.array(mass_list_SLQ), z_prev_SLQ, err_prev_SLQ, z_target=5.0)
m5_prev_VLQ, m5_prev_VLQ_inf, m5_prev_VLQ_sup = find_mass(np.array(mass_list_VLQ), z_prev_VLQ, err_prev_VLQ, z_target=5.0)

# Print
print('5 sigmas:')
print('Benchmarks')
print('SLQ mass: ', m5_BPOK_SLQ, '[GeV]      (', m5_BPOK_SLQ_inf, '-', m5_BPOK_SLQ_sup, ')')
print('VLQ mass: ', m5_BPOK_VLQ, '[GeV]      (', m5_BPOK_VLQ_inf, '-', m5_BPOK_VLQ_sup, ')')
print('\nInterpolated')
print('SLQ mass: ', m5_inter_SLQ, '[GeV]      (', m5_inter_SLQ_inf, '-', m5_inter_SLQ_sup, ')')
print('VLQ mass: ', m5_inter_VLQ, '[GeV]      (', m5_inter_VLQ_inf, '-', m5_inter_VLQ_sup, ')')
print('\nKnown PDF')
print('SLQ mass: ', m5_prev_SLQ, '[GeV]      (', m5_prev_SLQ_inf, '-', m5_prev_SLQ_sup, ')')
print('VLQ mass: ', m5_prev_VLQ, '[GeV]      (', m5_prev_VLQ_inf, '-', m5_prev_VLQ_sup, ')')
# Out:
# 5 sigmas:
# Benchmarks
# SLQ mass:  1482.3823823823823 [GeV]      ( 1459.2592592592591 - 1518.1181181181182 )
# VLQ mass:  1913.2132132132133 [GeV]      ( 1855.0550550550552 - 1986.7867867867867 )
#
# Interpolated
# SLQ mass:  1484.4844844844845 [GeV]      ( 1460.6606606606606 - 1523.0230230230231 )
# VLQ mass:  1916.016016016016 [GeV]      ( 1857.1571571571571 - 1989.5895895895897 )
#
# Known PDF
# SLQ mass:  1480.2802802802803 [GeV]      ( 1458.5585585585586 - 1513.9139139139138 )
# VLQ mass:  1911.8118118118118 [GeV]      ( 1855.0550550550552 - 1986.7867867867867 )

# %%
# LOAD

file_path = mainfolder + 'saved-results/Z13TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_13TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_13TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_13TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_13TeV = loaded_data[:, 4]
m_BL_exc_SLQ_13TeV = loaded_data[:, 5]
m_BL_dis_SLQ_13TeV = loaded_data[:, 6]
m_BL_exc_VLQ_13TeV = loaded_data[:, 7]
m_BL_dis_VLQ_13TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_13TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_13TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_13TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_13TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_13TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_13TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_13TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_13TeV = loaded_data[:, 16]


# LOAD

file_path = mainfolder + 'saved-results/Z136TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_136TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_136TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_136TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_136TeV = loaded_data[:, 4]
m_BL_exc_SLQ_136TeV = loaded_data[:, 5]
m_BL_dis_SLQ_136TeV = loaded_data[:, 6]
m_BL_exc_VLQ_136TeV = loaded_data[:, 7]
m_BL_dis_VLQ_136TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_136TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_136TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_136TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_136TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_136TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_136TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_136TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_136TeV = loaded_data[:, 16]




# LOAD

file_path = mainfolder + 'saved-results/Z14TeV_err.txt'

loaded_data = np.loadtxt(file_path)

loaded_betas = loaded_data[:, 0]
m_asimov_exc_SLQ_14TeV = loaded_data[:, 1]
m_asimov_dis_SLQ_14TeV = loaded_data[:, 2]
m_asimov_exc_VLQ_14TeV = loaded_data[:, 3]
m_asimov_dis_VLQ_14TeV = loaded_data[:, 4]
m_BL_exc_SLQ_14TeV = loaded_data[:, 5]
m_BL_dis_SLQ_14TeV = loaded_data[:, 6]
m_BL_exc_VLQ_14TeV = loaded_data[:, 7]
m_BL_dis_VLQ_14TeV = loaded_data[:, 8]
m_BL_exc_SLQ_low_14TeV = loaded_data[:, 9]
m_BL_dis_SLQ_low_14TeV = loaded_data[:, 10]
m_BL_exc_VLQ_low_14TeV = loaded_data[:, 11]
m_BL_dis_VLQ_low_14TeV = loaded_data[:, 12]
m_BL_exc_SLQ_high_14TeV = loaded_data[:, 13]
m_BL_dis_SLQ_high_14TeV = loaded_data[:, 14]
m_BL_exc_VLQ_high_14TeV = loaded_data[:, 15]
m_BL_dis_VLQ_high_14TeV = loaded_data[:, 16]

# %%
# plot BINNED LIKEHOOD

plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_SLQ_13TeV, betas, 'o:', c='red', label='13 TeV, 139 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_high_13TeV, betas, ':', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_14TeV, betas, 'o-', c='red', label='14 TeV, 3000 fb-1 (Dis SLQ)')
plt.plot(m_BL_dis_SLQ_low_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_dis_SLQ_high_14TeV, betas, '-', c='red', alpha=0.5)
plt.plot(m_BL_exc_SLQ_14TeV, betas, 'o--', c='red', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc SLQ)')
plt.plot(m_BL_exc_SLQ_low_14TeV, betas, '--', c='red', alpha=0.25)
plt.plot(m_BL_exc_SLQ_high_14TeV, betas, '--', c='red', alpha=0.25)


# benchmarks
m_SLQ_T_Z5 = [[m5_BPOK_SLQ - m5_BPOK_SLQ_inf], [m5_BPOK_SLQ_sup - m5_BPOK_SLQ]]
plt.errorbar(m5_BPOK_SLQ, 0.14, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (BP)')

# interpolated
m_SLQ_T_Z5 = [[m5_inter_SLQ - m5_inter_SLQ_inf], [m5_inter_SLQ_sup - m5_inter_SLQ]]
plt.errorbar(m5_inter_SLQ, 0.1, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (interpolated)')

# known pdf
m_SLQ_T_Z5 = [[m5_prev_SLQ - m5_prev_SLQ_inf], [m5_prev_SLQ_sup - m5_prev_SLQ]]
plt.errorbar(m5_prev_SLQ, 0.06, xerr=m_SLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (SLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()





plt.figure(figsize=(12, 6))

plt.plot(m_BL_exc_VLQ_13TeV, betas, 'o:', c='green', label='13 TeV, 139 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_high_13TeV, betas, ':', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_14TeV, betas, 'o-', c='green', label='14 TeV, 3000 fb-1 (Dis VLQ)')
plt.plot(m_BL_dis_VLQ_low_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_dis_VLQ_high_14TeV, betas, '-', c='green', alpha=0.5)
plt.plot(m_BL_exc_VLQ_14TeV, betas, 'o--', c='green', alpha=0.25, label='14 TeV, 3000 fb-1 (Exc VLQ)')
plt.plot(m_BL_exc_VLQ_low_14TeV, betas, '-', c='green', alpha=0.25)
plt.plot(m_BL_exc_VLQ_high_14TeV, betas, '-', c='green', alpha=0.25)


# benchmarks
m_VLQ_T_Z5 = [[m5_BPOK_VLQ - m5_BPOK_VLQ_inf], [m5_BPOK_VLQ_sup - m5_BPOK_VLQ]]
plt.errorbar(m5_BPOK_VLQ, 0.14, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (BP)')

# interpolated
m_VLQ_T_Z5 = [[m5_inter_VLQ - m5_inter_VLQ_inf], [m5_inter_VLQ_sup - m5_inter_VLQ]]
plt.errorbar(m5_inter_VLQ, 0.1, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (interpolated)')

# knwon pdf
m_VLQ_T_Z5 = [[m5_prev_VLQ - m5_prev_VLQ_inf], [m5_prev_VLQ_sup - m5_prev_VLQ]]
plt.errorbar(m5_prev_VLQ, 0.06, xerr=m_VLQ_T_Z5, fmt='o', capsize=5, color='dodgerblue', label='14 TeV, 3000 fb-1 (VLQ id Z=5) (known PDF)')


# plt.axhline(y=5, linestyle='--', color='black')
# plt.axhline(y=2, linestyle=':', color='black')
plt.xlim(1000,2400)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel(r"$m_{LQ}$ [GeV]",fontsize=16)
plt.ylabel(r"BR(LQ$\rightarrow b \tau$)",fontsize=16)
plt.title('Binned Likelihood', fontsize=16)
plt.grid(True)
plt.legend(fontsize=14, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
